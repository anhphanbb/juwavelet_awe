# %% [markdown]
# ## One way of slicing, applying noise filtering.

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Dict, Any, List

import copy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

try:
    from scipy import stats
except Exception:
    stats = None

# --------------------------
# User params
# --------------------------
FILE_PATH = "awe_l3a_tmp_2024165T2120_03175_v01.nc"
FRAME_IDX = 0

# Slicing on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)
SLICE_PAD = 50  # extend each slice by this many UNBINNED pixels on each side

# Choose ONE slicing offset (no comparisons)
X_OFFSET = 0  # set to 0 or 300 or whatever you want

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 24
JT = 18
ASPECT = 1

# Pixel spacing (km per pixel)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Red noise style filtering (robust WPS thresholding per scale)
APPLY_RED_NOISE_FILTER = True

# Optional diagnostics output from the red noise filter
SAVE_REDNOISE_DIAGNOSTICS = True

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices_single_noise_filtering_tmp")
SAVE_DPI = 200

# --------------------------
# Parameter runs (edit this list)
# --------------------------
RUNS: List[Dict[str, Any]] = [
    dict(
        name="amp1p5",
        MIN_AMP=1.5,
        THR=0.25,
        WHITE_NOISE_THRESHOLD=0.15,
        WPS_NOISE_THRESHOLD=8.0,
    ),
    dict(
        name="amp1p2(base)",
        MIN_AMP=1.2,
        THR=0.25,
        WHITE_NOISE_THRESHOLD=0.15,
        WPS_NOISE_THRESHOLD=8.0,
    ),
    dict(
        name="amp1p0",
        MIN_AMP=1.0,
        THR=0.25,
        WHITE_NOISE_THRESHOLD=0.15,
        WPS_NOISE_THRESHOLD=8.0,
    ),
    dict(
        name="wnoisep1",
        MIN_AMP=1.2,
        THR=0.25,
        WHITE_NOISE_THRESHOLD=0.10,
        WPS_NOISE_THRESHOLD=8.0,
    ),
        dict(
        name="rednoise4",
        MIN_AMP=1.2,
        THR=0.25,
        WHITE_NOISE_THRESHOLD=0.15,
        WPS_NOISE_THRESHOLD=4.0,
    ),
]

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Small helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def diverging_limits(*arrays: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    vals = []
    for A in arrays:
        if A is None:
            continue
        a = np.asarray(A)
        good = np.isfinite(a)
        if np.any(good):
            vals.append(a[good].ravel())
    if not vals:
        return (-1.0, 1.0)
    stacked = np.concatenate(vals)
    lo, hi = np.nanpercentile(stacked, [p_lo, p_hi])
    vmax = max(abs(lo), abs(hi))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    return (-vmax, vmax)


# --------------------------
# Data helpers
# --------------------------
def read_radiance_frame(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        rad = nc.variables["Temperature"][:]  # (t, y, x)
    if rad.ndim != 3:
        raise ValueError(f"Temperature expected 3D (t,y,x); got {rad.shape}")
    if not (0 <= frame_idx < rad.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{rad.shape[0]-1}")
    return np.asarray(rad[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    return np.cos(theta_xy), np.sin(theta_xy)


# --------------------------
# Red noise style filtering helper
# --------------------------
def apply_red_noise_filter_cwt(
    cwt: dict,
    white_noise_threshold: float = 0.1,
    wps_noise_threshold: float = 8.0,
) -> Tuple[dict, Dict[str, Any]]:
    """
    Robust per scale WPS filtering.

    Returns filtered_cwt (deep copy) and a small diagnostics dict.
    """
    diag: Dict[str, Any] = {}
    if stats is None:
        diag["skipped"] = True
        diag["reason"] = "scipy not available"
        return cwt, diag

    cwt_copy = copy.deepcopy(cwt)
    dec = cwt_copy["decomposition"]  # (ns, nt, nx, ny) complex

    WPS0 = np.abs(dec) ** 2
    diag["n_coeff_total"] = int(WPS0.size)

    mask_1 = WPS0 < (float(white_noise_threshold) ** 2)
    dec[mask_1] = 0

    WPS1 = np.abs(dec) ** 2
    diag["n_zero_after_white"] = int(np.count_nonzero(WPS1 == 0))

    median_WPS = np.median(WPS1, axis=(1, 2, 3))  # (ns,)
    mad = stats.median_abs_deviation(WPS1, axis=(1, 2, 3), scale=1.0)  # (ns,)
    sMAD_WPS = 1.4826 * mad

    sMAD_safe = np.where(sMAD_WPS > 0, sMAD_WPS, np.nan)
    WPS_scaled = (WPS1 - median_WPS[:, None, None, None]) / sMAD_safe[:, None, None, None]

    mask = WPS_scaled < float(wps_noise_threshold)
    dec[mask] = 0

    WPS2 = np.abs(dec) ** 2
    diag["n_zero_after_scaled"] = int(np.count_nonzero(WPS2 == 0))

    finite_scaled = np.isfinite(WPS_scaled)

    diag["sMAD_min"] = float(np.nanmin(sMAD_WPS))
    diag["sMAD_median"] = float(np.nanmedian(sMAD_WPS))

    if np.any(finite_scaled):
        diag["WPS_scaled_min"] = float(np.nanmin(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_median"] = float(np.nanmedian(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_max"] = float(np.nanmax(WPS_scaled[finite_scaled]))
    else:
        diag["WPS_scaled_min"] = np.nan
        diag["WPS_scaled_median"] = np.nan
        diag["WPS_scaled_max"] = np.nan

    return cwt_copy, diag


# --------------------------
# Quicklook plots
# --------------------------
def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("Radiance (arb)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
    wavy_after_noise_xy: np.ndarray | None = None,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    arrays = [orig_c, bg_c, rem_c, rem_tapered_c]
    if wavy_after_noise_xy is not None:
        arrays.append(wavy_after_noise_xy)

    vmin, vmax = diverging_limits(*arrays, p_lo=1, p_hi=99)

    fig, axs = plt.subplots(2, 3, figsize=(16, 10), constrained_layout=True)
    axs = axs.flatten()

    panels = [
        (orig_c, "Original (median sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    if wavy_after_noise_xy is not None:
        panels.append((wavy_after_noise_xy, "Wavy stuff (wavelet reconstruction after noise filtering)"))

    im0 = None
    for ax, (Z, title) in zip(axs, panels):
        im0 = ax.pcolormesh(
            x1d_km, y1d_km, Z,
            shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    for ax in axs[len(panels):]:
        ax.axis("off")

    cbar = fig.colorbar(im0, ax=axs[:len(panels)], orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("Radiance (arb)")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2
    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])
        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_vmin, bg_vmax = diverging_limits(bg_xy, p_lo=2, p_hi=98)
    cl_vmin, cl_vmax = diverging_limits(rec_xy, p_lo=2, p_hi=98)

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if (not np.isfinite(lam_vmin)) or (not np.isfinite(lam_vmax)) or (lam_vmin == lam_vmax):
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n"
            + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        arrow_len_km = 40.0
        u = u * arrow_len_km
        v = v * arrow_len_km

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)


# --------------------------
# Slice pipeline
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
    cfg: Dict[str, Any],
) -> Dict[str, Any]:
    """
    Runs processing on an extended slice (x_slice),
    but returns only CORE tiles for stitching.

    Step 08 (power) intentionally removed.

    Figure 1 includes extra panel: wavelet reconstruction after noise filtering.
    Figure 9 has 3 panels:
      Remaining (input to CWT)
      Wavy reconstruction after noise filtering
      Reconstruction after clustering (all clusters)
    """
    outdir.mkdir(parents=True, exist_ok=True)

    min_amp = float(cfg.get("MIN_AMP"))
    thr = float(cfg.get("THR"))
    white_noise_threshold = float(cfg.get("WHITE_NOISE_THRESHOLD"))
    wps_noise_threshold = float(cfg.get("WPS_NOISE_THRESHOLD"))
    run_name = str(cfg.get("name", "run"))

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        f = int(BIN_FACTOR)
        dx_km = DX_KM_BASE * f
        dy_km = DY_KM_BASE * f
    else:
        f = 1
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f
    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    raw_win = np.asarray(rad2d_flat[Y_SLICE, x_slice], dtype=float)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"Temperature (window, flattened){bin_tag}\n{run_name} MIN_AMP={min_amp} THR={thr}",
        outdir / "00_temperature_window.png",
    )

    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt_raw = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    if APPLY_RED_NOISE_FILTER:
        cwt, diag = apply_red_noise_filter_cwt(
            cwt_raw,
            white_noise_threshold=white_noise_threshold,
            wps_noise_threshold=wps_noise_threshold,
        )
        if SAVE_REDNOISE_DIAGNOSTICS:
            lines = []
            lines.append("Red noise filter diagnostics\n\n")
            lines.append(f"name                = {run_name}\n")
            lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
            lines.append(f"WPS_NOISE_THRESHOLD   = {wps_noise_threshold}\n\n")
            if diag.get("skipped", False):
                lines.append(f"SKIPPED: {diag.get('reason','unknown')}\n")
            else:
                lines.append(f"n_coeff_total        = {diag.get('n_coeff_total')}\n")
                lines.append(f"n_zero_after_white   = {diag.get('n_zero_after_white')}\n")
                lines.append(f"n_zero_after_scaled  = {diag.get('n_zero_after_scaled')}\n")
                lines.append(f"sMAD_WPS min         = {diag.get('sMAD_min')}\n")
                lines.append(f"sMAD_WPS median      = {diag.get('sMAD_median')}\n")
                lines.append(f"WPS_scaled min       = {diag.get('WPS_scaled_min')}\n")
                lines.append(f"WPS_scaled median    = {diag.get('WPS_scaled_median')}\n")
                lines.append(f"WPS_scaled max       = {diag.get('WPS_scaled_max')}\n")
            (outdir / "02a_rednoise_diagnostics.txt").write_text("".join(lines))
    else:
        cwt = cwt_raw

    rec_wavy = transform.reconstruct2d(cwt)  # (nx, ny)
    wavy_xy = rec_wavy.T - np.median(rec_wavy)

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_5panel.png",
        wavy_after_noise_xy=wavy_xy,
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=min_amp, thr=thr)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N
    )
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text(
            "No clusters found.\n\n"
            f"Run name: {run_name}\n"
            f"Used MIN_AMP={min_amp}, THR={thr}\n"
            f"Used WHITE_NOISE_THRESHOLD={white_noise_threshold}, WPS_NOISE_THRESHOLD={wps_noise_threshold}\n\n"
            "Try lowering MIN_AMP or THR.\n"
            "If red noise filter is on, try lowering WPS_NOISE_THRESHOLD or WHITE_NOISE_THRESHOLD.\n"
        )
        remaining_core_xy = crop_pad_core(proc)
        nan_core = np.full_like(remaining_core_xy, np.nan)
        return {
            "has_clusters": False,
            "x_start_unbinned": core_start_unbinned,
            "dx_km": dx_km,
            "dy_km": dy_km,
            "remaining_xy": remaining_core_xy,
            "wavy_xy": nan_core,
            "rec_all_xy": nan_core,
        }

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    lines = []
    lines.append("Cluster power ranking (clustered only)\n\n")
    lines.append(f"name = {run_name}\n")
    lines.append(f"MIN_AMP = {min_amp}\n")
    lines.append(f"THR = {thr}\n")
    lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
    lines.append(f"WPS_NOISE_THRESHOLD = {wps_noise_threshold}\n\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))
    theta_vals = np.asarray(cwt["theta"], dtype=float)

    def plot_cluster_grid(kind: str, outname: str) -> None:
        fig, axs = plt.subplots(nrow, ncol, figsize=(12, 10))
        axs = np.atleast_1d(axs).reshape(-1)

        bg_vmin, bg_vmax = diverging_limits(bg, p_lo=2, p_hi=98)
        number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}

        for ax, kcl in zip(axs, biggest):
            decomposition[:] = orig_decomp
            decomposition[iwave != kcl] = 0
            rec = transform.reconstruct2d(cwt)
            rec_centered = rec.T - np.median(rec)

            s_idx = int(idxs[kcl][0])
            t_idx = int(idxs[kcl][1])
            _, _, lam = effective_lambda(cwt, s_idx, t_idx)

            theta_dom_rad = float(theta_vals[t_idx])
            theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

            ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
            Pk = float(P_abs_sorted[ii])
            pk = float(P_pct_sorted[ii])

            if kind == "standalone":
                ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0)
            elif kind == "overlay":
                ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
                ax.pcolormesh(
                    x1d_km, y1d_km, rec_centered,
                    shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0, alpha=0.6
                )
            else:
                raise ValueError(kind)

            ax.set_title(
                rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
                + "\n"
                + rf"P={Pk:.2e} ({pk:.1f}%)"
            )
            ax.set_aspect("equal", adjustable="box")

        for ax in axs[n_show:]:
            ax.axis("off")
        for ax in axs[:n_show]:
            ax.set_xlabel("x (km)")
            ax.set_ylabel("y (km)")

        for i, ax in enumerate(axs, start=1):
            if ax.has_data():
                ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

        fig.tight_layout()
        save_fig(fig, outdir / outname)

    plot_cluster_grid("standalone", "05_clusters_standalone.png")
    plot_cluster_grid("overlay", "06_clusters_overlay.png")

    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
        )

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)
    decomposition[:] = orig_decomp

    remaining_after_preproc_xy = proc
    vmin, vmax = diverging_limits(remaining_after_preproc_xy, wavy_xy, rec_all_xy, p_lo=2, p_hi=98)

    figR, (ax1, ax2, ax3) = plt.subplots(
        3, 1, figsize=(18, 8), constrained_layout=True, sharex=True, sharey=True
    )

    im1 = ax1.pcolormesh(
        x1d_km, y1d_km, remaining_after_preproc_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    ax1.set_title("Remaining (after preprocessing, input to CWT)")
    ax1.set_xlabel("x (km)")
    ax1.set_ylabel("y (km)")
    ax1.set_aspect("equal", adjustable="box")

    im2 = ax2.pcolormesh(
        x1d_km, y1d_km, wavy_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    ax2.set_title("Wavy stuff (wavelet reconstruction after noise filtering)")
    ax2.set_xlabel("x (km)")
    ax2.set_ylabel("y (km)")
    ax2.set_aspect("equal", adjustable="box")

    im3 = ax3.pcolormesh(
        x1d_km, y1d_km, rec_all_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    ax3.set_title("Reconstruction after clustering (all clusters combined)")
    ax3.set_xlabel("x (km)")
    ax3.set_ylabel("y (km)")
    ax3.set_aspect("equal", adjustable="box")

    cbar = figR.colorbar(im1, ax=[ax1, ax2, ax3], orientation="vertical", fraction=0.015, pad=0.01)
    cbar.set_label("arb")
    save_fig(figR, outdir / "09_remaining_vs_wavy_vs_allclusters.png")

    remaining_core_xy = crop_pad_core(remaining_after_preproc_xy)
    wavy_core_xy = crop_pad_core(wavy_xy)
    rec_all_core_xy = crop_pad_core(rec_all_xy)

    return {
        "has_clusters": True,
        "x_start_unbinned": core_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "remaining_xy": remaining_core_xy,
        "wavy_xy": wavy_core_xy,
        "rec_all_xy": rec_all_core_xy,
    }


def stitch_and_save_final_09(slice_results: List[Dict[str, Any]], outroot: Path, tag: str) -> None:
    if not slice_results:
        return

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE

    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    wavy_stitched = np.concatenate([d["wavy_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)

    ny, nx_tot = remaining_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    vmin, vmax = diverging_limits(remaining_stitched, wavy_stitched, rec_all_stitched, p_lo=2, p_hi=98)

    figR, (axT, axM, axB) = plt.subplots(
        3, 1, figsize=(18, 6), constrained_layout=True, sharex=True, sharey=True
    )

    imT = axT.pcolormesh(
        x1d_km, y1d_km, remaining_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axT.set_title(f"STITCHED (core tiles) {tag}: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imM = axM.pcolormesh(
        x1d_km, y1d_km, wavy_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axM.set_title(f"STITCHED (core tiles) {tag}: Wavy stuff (wavelet reconstruction after noise filtering)")
    axM.set_xlabel("x (km)")
    axM.set_ylabel("y (km)")
    axM.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(
        x1d_km, y1d_km, rec_all_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axB.set_title(f"STITCHED (core tiles) {tag}: Reconstruction after clustering (all clusters combined)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    axT.set_xlim(600, 10000)

    cbar = figR.colorbar(imT, ax=[axT, axM, axB], orientation="vertical", fraction=0.012, pad=0.01)
    cbar.set_label("K (Relative)")
    save_fig(figR, outroot / f"FINAL_09_remaining_vs_wavy_vs_allclusters_STITCHED_{tag}.png")


def run_all_slices_single_offset(cfg: Dict[str, Any]) -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_radiance_frame(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    x_offset = int(X_OFFSET)
    if x_offset >= nx_total:
        raise ValueError(f"X_OFFSET={x_offset} too large for nx_total={nx_total}")

    run_name = str(cfg.get("name", "run"))
    outroot = OUTPUT_ROOT / f"{run_name}_offset_{x_offset:04d}"
    outroot.mkdir(parents=True, exist_ok=True)

    (outroot / "RUN_CONFIG.txt").write_text("\n".join([f"{k} = {v}" for k, v in cfg.items()]) + "\n")

    core_starts = list(range(x_offset, nx_total, X_CHUNK))
    stitch_results: List[Dict[str, Any]] = []

    for core_start in core_starts:
        core_end = min(core_start + X_CHUNK, nx_total)

        ext_start = max(0, core_start - SLICE_PAD)
        ext_end = min(nx_total, core_end + SLICE_PAD)
        x_slice = slice(ext_start, ext_end)

        outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
        print(f"[{run_name} | offset {x_offset}] core={core_start}:{core_end} ext={ext_start}:{ext_end} saved to {outdir}")

        res = run_pipeline_for_slice(
            rad2d_flat=rad2d_flat,
            x_slice=x_slice,
            outdir=outdir,
            x_start_unbinned=ext_start,
            core_start_unbinned=core_start,
            core_end_unbinned=core_end,
            cfg=cfg,
        )
        stitch_results.append(res)

    stitch_and_save_final_09(stitch_results, outroot, tag=f"{run_name}_offset_{x_offset:04d}")
    print("Done. Outputs in", outroot.resolve())


for cfg in RUNS:
    run_all_slices_single_offset(cfg)
# Out:
# [amp1p5 | offset 0] core=0:600 ext=0:650 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_00000_00600_xext_00000_00650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 43.26it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p5 | offset 0] core=600:1200 ext=550:1250 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_00600_01200_xext_00550_01250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.2118315886656936 idx= (4, 9, 225, 12)
# selected elements: 17926
# ------------
# cluster= 1
# amplitude= 1.8028785849896138 idx= (6, 9, 285, 135)
# selected elements: 19923
# ------------
# cluster= 2
# amplitude= 1.7822382136992843 idx= (10, 9, 184, 42)
# selected elements: 43976
# ------------
# cluster= 3
# amplitude= 1.6113031513508014 idx= (1, 9, 194, 68)
# selected elements: 4537
# ------------
# cluster= 4
# amplitude= 1.5937568512564615 idx= (4, 9, 221, 88)
# selected elements: 7374
# ------------
# cluster= 5
# amplitude= 1.5833531101208662 idx= (0, 9, 192, 49)
# selected elements: 1115
# ------------
# cluster= 6
# amplitude= 1.508483095732299 idx= (1, 9, 210, 48)
# selected elements: 3642
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 71.33it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p5 | offset 0] core=1200:1800 ext=1150:1850 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_01200_01800_xext_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.7008862437826677 idx= (6, 14, 86, 41)
# selected elements: 18158
# ------------
# cluster= 1
# amplitude= 1.5382846395339949 idx= (7, 14, 85, 14)
# selected elements: 1441
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 72.08it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p5 | offset 0] core=1800:2400 ext=1750:2450 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_01800_02400_xext_01750_02450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 74.19it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p5 | offset 0] core=2400:3000 ext=2350:3050 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_02400_03000_xext_02350_03050
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.5837521748376762 idx= (4, 9, 230, 76)
# selected elements: 22839
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 71.75it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p5 | offset 0] core=3000:3600 ext=2950:3650 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_03000_03600_xext_02950_03650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.5895438241042705 idx= (9, 13, 192, 93)
# selected elements: 62586
# ------------
# cluster= 1
# amplitude= 1.978046821584319 idx= (6, 11, 197, 69)
# selected elements: 36930
# ------------
# cluster= 2
# amplitude= 1.855477317257426 idx= (11, 14, 237, 129)
# selected elements: 18921
# ------------
# cluster= 3
# amplitude= 1.7548081030848313 idx= (9, 13, 234, 123)
# selected elements: 6004
# ------------
# cluster= 4
# amplitude= 1.6052537927157147 idx= (3, 10, 108, 58)
# selected elements: 97202
# ------------
# cluster= 5
# amplitude= 1.595196718855586 idx= (11, 12, 270, 133)
# selected elements: 16676
# ------------
# cluster= 6
# amplitude= 1.5718087625222557 idx= (0, 3, 123, 41)
# selected elements: 29206
# ------------
# cluster= 7
# amplitude= 1.5316573973908594 idx= (6, 3, 61, 108)
# selected elements: 68801
# ------------
# cluster= 8
# amplitude= 1.5316115425125234 idx= (17, 12, 255, 126)
# selected elements: 22431
# ------------
# cluster= 9
# amplitude= 1.5002148804093756 idx= (7, 15, 203, 104)
# selected elements: 2527
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 72.95it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p5 | offset 0] core=3600:4200 ext=3550:4250 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_03600_04200_xext_03550_04250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.5547231036638032 idx= (13, 9, 26, 127)
# selected elements: 242987
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 41.82it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p5 | offset 0] core=4200:4800 ext=4150:4850 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_04200_04800_xext_04150_04850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.6114467166769586 idx= (0, 3, 231, 96)
# selected elements: 291368
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 70.70it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p5 | offset 0] core=4800:5400 ext=4750:5450 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_04800_05400_xext_04750_05450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 3.0157737424094386 idx= (0, 0, 234, 134)
# selected elements: 529227
# ------------
# cluster= 1
# amplitude= 1.9976981203532842 idx= (1, 17, 233, 132)
# selected elements: 63461
# ------------
# cluster= 2
# amplitude= 1.726819776260001 idx= (12, 17, 233, 132)
# selected elements: 141446
# ------------
# cluster= 3
# amplitude= 1.5522893025731321 idx= (4, 9, 86, 131)
# selected elements: 601511
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 70.99it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p5 | offset 0] core=5400:5451 ext=5350:5451 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000/xcore_05400_05451_xext_05350_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 82.55it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Done. Outputs in /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p5_offset_0000
# [amp1p2(base) | offset 0] core=0:600 ext=0:650 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_00000_00600_xext_00000_00650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.3266691109164115 idx= (15, 11, 265, 75)
# selected elements: 954463
# ------------
# cluster= 1
# amplitude= 1.2536499519230178 idx= (5, 10, 220, 81)
# selected elements: 192447
# ------------
# cluster= 2
# amplitude= 1.2435902033493922 idx= (2, 9, 218, 76)
# selected elements: 46320
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 68.81it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p2(base) | offset 0] core=600:1200 ext=550:1250 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_00600_01200_xext_00550_01250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.2118315886656936 idx= (4, 9, 225, 12)
# selected elements: 17926
# ------------
# cluster= 1
# amplitude= 1.8028785849896138 idx= (6, 9, 285, 135)
# selected elements: 19923
# ------------
# cluster= 2
# amplitude= 1.7822382136992843 idx= (10, 9, 184, 42)
# selected elements: 43976
# ------------
# cluster= 3
# amplitude= 1.6113031513508014 idx= (1, 9, 194, 68)
# selected elements: 4537
# ------------
# cluster= 4
# amplitude= 1.5937568512564615 idx= (4, 9, 221, 88)
# selected elements: 7374
# ------------
# cluster= 5
# amplitude= 1.5833531101208662 idx= (0, 9, 192, 49)
# selected elements: 1115
# ------------
# cluster= 6
# amplitude= 1.508483095732299 idx= (1, 9, 210, 48)
# selected elements: 3642
# ------------
# cluster= 7
# amplitude= 1.4995320994940224 idx= (12, 8, 314, 127)
# selected elements: 19418
# ------------
# cluster= 8
# amplitude= 1.4772109093415784 idx= (0, 10, 152, 83)
# selected elements: 3016
# ------------
# cluster= 9
# amplitude= 1.468202078814194 idx= (0, 9, 226, 92)
# selected elements: 261
# ------------
# cluster= 10
# amplitude= 1.4454109751119992 idx= (6, 9, 174, 57)
# selected elements: 2170
# ------------
# cluster= 11
# amplitude= 1.4449293322772043 idx= (2, 9, 315, 105)
# selected elements: 5942
# ------------
# cluster= 12
# amplitude= 1.3973482126138796 idx= (9, 10, 130, 63)
# selected elements: 11534
# ------------
# cluster= 13
# amplitude= 1.397221402675915 idx= (10, 11, 194, 95)
# selected elements: 16450
# ------------
# cluster= 14
# amplitude= 1.3549816537166974 idx= (7, 10, 125, 62)
# selected elements: 4164
# ------------
# cluster= 15
# amplitude= 1.3509361286775468 idx= (8, 8, 226, 42)
# selected elements: 8543
# ------------
# cluster= 16
# amplitude= 1.3268751604160336 idx= (0, 9, 139, 69)
# selected elements: 428
# ------------
# cluster= 17
# amplitude= 1.3113289464299054 idx= (9, 9, 228, 118)
# selected elements: 8273
# ------------
# cluster= 18
# amplitude= 1.2880589295266405 idx= (0, 8, 110, 112)
# selected elements: 596
# ------------
# cluster= 19
# amplitude= 1.2772593368881906 idx= (13, 12, 192, 93)
# selected elements: 3989
# ------------
# cluster= 20
# amplitude= 1.2687277429817148 idx= (0, 9, 233, 53)
# selected elements: 688
# ------------
# cluster= 21
# amplitude= 1.2639132416856294 idx= (5, 9, 233, 138)
# selected elements: 3873
# ------------
# cluster= 22
# amplitude= 1.2609939680779827 idx= (6, 10, 160, 84)
# selected elements: 1621
# ------------
# cluster= 23
# amplitude= 1.2609729639880243 idx= (13, 10, 240, 48)
# selected elements: 11335
# ------------
# cluster= 24
# amplitude= 1.248263562603713 idx= (10, 11, 68, 40)
# selected elements: 8658
# ------------
# cluster= 25
# amplitude= 1.2479498868313397 idx= (0, 9, 41, 33)
# selected elements: 909
# ------------
# cluster= 26
# amplitude= 1.2289798942222292 idx= (1, 9, 258, 108)
# selected elements: 1678
# ------------
# cluster= 27
# amplitude= 1.2257034487132639 idx= (5, 10, 152, 19)
# selected elements: 5061
# ------------
# cluster= 28
# amplitude= 1.2209304952789561 idx= (0, 9, 113, 139)
# selected elements: 919
# ------------
# cluster= 29
# amplitude= 1.2106050297195379 idx= (7, 8, 302, 102)
# selected elements: 1294
# ------------
# cluster= 30
# amplitude= 1.2080689901925485 idx= (23, 12, 53, 26)
# selected elements: 8479
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 73.19it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p2(base) | offset 0] core=1200:1800 ext=1150:1850 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_01200_01800_xext_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.7008862437826677 idx= (6, 14, 86, 41)
# selected elements: 18158
# ------------
# cluster= 1
# amplitude= 1.5382846395339949 idx= (7, 14, 85, 14)
# selected elements: 1441
# ------------
# cluster= 2
# amplitude= 1.4434243335259018 idx= (2, 9, 15, 105)
# selected elements: 5364
# ------------
# cluster= 3
# amplitude= 1.296023294627679 idx= (8, 8, 47, 62)
# selected elements: 5291
# ------------
# cluster= 4
# amplitude= 1.278865431153435 idx= (11, 8, 19, 126)
# selected elements: 10541
# ------------
# cluster= 5
# amplitude= 1.2787255152662675 idx= (4, 2, 323, 13)
# selected elements: 2902
# ------------
# cluster= 6
# amplitude= 1.2452600750361478 idx= (6, 11, 321, 131)
# selected elements: 5277
# ------------
# cluster= 7
# amplitude= 1.2044015945438042 idx= (5, 9, 317, 134)
# selected elements: 858
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 76.70it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p2(base) | offset 0] core=1800:2400 ext=1750:2450 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_01800_02400_xext_01750_02450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.4601471512853637 idx= (0, 9, 222, 103)
# selected elements: 2295
# ------------
# cluster= 1
# amplitude= 1.279338150928395 idx= (4, 2, 23, 13)
# selected elements: 4002
# ------------
# cluster= 2
# amplitude= 1.2487207219384684 idx= (6, 10, 20, 134)
# selected elements: 7490
# ------------
# cluster= 3
# amplitude= 1.2035750893968642 idx= (7, 11, 19, 135)
# selected elements: 457
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 76.02it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p2(base) | offset 0] core=2400:3000 ext=2350:3050 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_02400_03000_xext_02350_03050
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.5837521748376762 idx= (4, 9, 230, 76)
# selected elements: 22839
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 71.72it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p2(base) | offset 0] core=3000:3600 ext=2950:3650 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_03000_03600_xext_02950_03650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.5895438241042705 idx= (9, 13, 192, 93)
# selected elements: 62586
# ------------
# cluster= 1
# amplitude= 1.978046821584319 idx= (6, 11, 197, 69)
# selected elements: 36930
# ------------
# cluster= 2
# amplitude= 1.855477317257426 idx= (11, 14, 237, 129)
# selected elements: 18921
# ------------
# cluster= 3
# amplitude= 1.7548081030848313 idx= (9, 13, 234, 123)
# selected elements: 6004
# ------------
# cluster= 4
# amplitude= 1.6052537927157147 idx= (3, 10, 108, 58)
# selected elements: 97202
# ------------
# cluster= 5
# amplitude= 1.595196718855586 idx= (11, 12, 270, 133)
# selected elements: 16676
# ------------
# cluster= 6
# amplitude= 1.5718087625222557 idx= (0, 3, 123, 41)
# selected elements: 29206
# ------------
# cluster= 7
# amplitude= 1.5316573973908594 idx= (6, 3, 61, 108)
# selected elements: 68801
# ------------
# cluster= 8
# amplitude= 1.5316115425125234 idx= (17, 12, 255, 126)
# selected elements: 22431
# ------------
# cluster= 9
# amplitude= 1.5002148804093756 idx= (7, 15, 203, 104)
# selected elements: 2527
# ------------
# cluster= 10
# amplitude= 1.456855594899672 idx= (19, 13, 246, 124)
# selected elements: 9662
# ------------
# cluster= 11
# amplitude= 1.4517344627641209 idx= (13, 9, 326, 126)
# selected elements: 30445
# ------------
# cluster= 12
# amplitude= 1.443958160867366 idx= (20, 9, 168, 9)
# selected elements: 31803
# ------------
# cluster= 13
# amplitude= 1.3743017127069144 idx= (7, 17, 58, 68)
# selected elements: 18546
# ------------
# cluster= 14
# amplitude= 1.35023768046927 idx= (6, 13, 100, 48)
# selected elements: 6136
# ------------
# cluster= 15
# amplitude= 1.3414365098231995 idx= (13, 9, 167, 10)
# selected elements: 10432
# ------------
# cluster= 16
# amplitude= 1.330676411671847 idx= (10, 15, 202, 104)
# selected elements: 2504
# ------------
# cluster= 17
# amplitude= 1.296004056801924 idx= (12, 8, 211, 127)
# selected elements: 9717
# ------------
# cluster= 18
# amplitude= 1.2582009972741377 idx= (20, 0, 7, 118)
# selected elements: 17018
# ------------
# cluster= 19
# amplitude= 1.2354685719805276 idx= (0, 9, 221, 133)
# selected elements: 54751
# ------------
# cluster= 20
# amplitude= 1.2001361111464526 idx= (7, 0, 54, 73)
# selected elements: 14780
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 76.87it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p2(base) | offset 0] core=3600:4200 ext=3550:4250 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_03600_04200_xext_03550_04250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.5547231036638032 idx= (13, 9, 26, 127)
# selected elements: 242987
# ------------
# cluster= 1
# amplitude= 1.2377583201086488 idx= (0, 9, 38, 85)
# selected elements: 128422
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 74.88it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p2(base) | offset 0] core=4200:4800 ext=4150:4850 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_04200_04800_xext_04150_04850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.6114467166769586 idx= (0, 3, 231, 96)
# selected elements: 291368
# ------------
# cluster= 1
# amplitude= 1.4925183472595422 idx= (0, 9, 259, 37)
# selected elements: 4886
# ------------
# cluster= 2
# amplitude= 1.4744034681151648 idx= (2, 9, 326, 9)
# selected elements: 106572
# ------------
# cluster= 3
# amplitude= 1.4443418564488542 idx= (1, 9, 242, 61)
# selected elements: 2613
# ------------
# cluster= 4
# amplitude= 1.3993281617617812 idx= (3, 4, 231, 97)
# selected elements: 2661
# ------------
# cluster= 5
# amplitude= 1.3286722113816747 idx= (2, 11, 297, 41)
# selected elements: 2026
# ------------
# cluster= 6
# amplitude= 1.3129183573554255 idx= (8, 8, 244, 35)
# selected elements: 121406
# ------------
# cluster= 7
# amplitude= 1.3086657839480247 idx= (4, 9, 209, 126)
# selected elements: 14508
# ------------
# cluster= 8
# amplitude= 1.2918835226794583 idx= (2, 9, 310, 124)
# selected elements: 3442
# ------------
# cluster= 9
# amplitude= 1.2407394967451573 idx= (0, 7, 278, 13)
# selected elements: 669
# ------------
# cluster= 10
# amplitude= 1.2406654055108681 idx= (0, 9, 293, 31)
# selected elements: 639
# ------------
# cluster= 11
# amplitude= 1.235783838984099 idx= (6, 10, 255, 60)
# selected elements: 7319
# ------------
# cluster= 12
# amplitude= 1.2087411075705887 idx= (0, 10, 282, 71)
# selected elements: 840
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 73.16it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p2(base) | offset 0] core=4800:5400 ext=4750:5450 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_04800_05400_xext_04750_05450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 3.0157737424094386 idx= (0, 0, 234, 134)
# selected elements: 529227
# ------------
# cluster= 1
# amplitude= 1.9976981203532842 idx= (1, 17, 233, 132)
# selected elements: 63461
# ------------
# cluster= 2
# amplitude= 1.726819776260001 idx= (12, 17, 233, 132)
# selected elements: 141446
# ------------
# cluster= 3
# amplitude= 1.5522893025731321 idx= (4, 9, 86, 131)
# selected elements: 601511
# ------------
# cluster= 4
# amplitude= 1.468294939714883 idx= (1, 9, 26, 9)
# selected elements: 14794
# ------------
# cluster= 5
# amplitude= 1.405391677679908 idx= (1, 8, 197, 98)
# selected elements: 3253
# ------------
# cluster= 6
# amplitude= 1.404510794199412 idx= (5, 12, 146, 136)
# selected elements: 175177
# ------------
# cluster= 7
# amplitude= 1.3370389621092347 idx= (0, 0, 161, 139)
# selected elements: 55814
# ------------
# cluster= 8
# amplitude= 1.2730793200975956 idx= (16, 9, 198, 18)
# selected elements: 94614
# ------------
# cluster= 9
# amplitude= 1.2549854677252563 idx= (1, 10, 224, 34)
# selected elements: 27187
# ------------
# cluster= 10
# amplitude= 1.2519701480623078 idx= (0, 1, 128, 130)
# selected elements: 5606
# ------------
# cluster= 11
# amplitude= 1.244422566755048 idx= (0, 9, 153, 15)
# selected elements: 29925
# ------------
# cluster= 12
# amplitude= 1.2201803153732196 idx= (0, 17, 159, 138)
# selected elements: 7070
# ------------
# cluster= 13
# amplitude= 1.2188274790933797 idx= (0, 11, 57, 115)
# selected elements: 5678
# ------------
# cluster= 14
# amplitude= 1.2130025086437957 idx= (1, 9, 11, 125)
# selected elements: 4185
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 73.73it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p2(base) | offset 0] core=5400:5451 ext=5350:5451 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000/xcore_05400_05451_xext_05350_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 84.53it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Done. Outputs in /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p2(base)_offset_0000
# [amp1p0 | offset 0] core=0:600 ext=0:650 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p0_offset_0000/xcore_00000_00600_xext_00000_00650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.3266691109164115 idx= (15, 11, 265, 75)
# selected elements: 954463
# ------------
# cluster= 1
# amplitude= 1.2536499519230178 idx= (5, 10, 220, 81)
# selected elements: 192447
# ------------
# cluster= 2
# amplitude= 1.2435902033493922 idx= (2, 9, 218, 76)
# selected elements: 46320
# ------------
# cluster= 3
# amplitude= 1.1748059169920966 idx= (20, 9, 214, 79)
# selected elements: 168198
# ------------
# cluster= 4
# amplitude= 1.0864051731957742 idx= (9, 0, 122, 67)
# selected elements: 95495
# ------------
# cluster= 5
# amplitude= 1.0354825787714501 idx= (11, 11, 141, 69)
# selected elements: 194185
# ------------
# cluster= 6
# amplitude= 1.0106553447262208 idx= (13, 11, 162, 128)
# selected elements: 4991
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 77.41it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p0 | offset 0] core=600:1200 ext=550:1250 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p0_offset_0000/xcore_00600_01200_xext_00550_01250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.2118315886656936 idx= (4, 9, 225, 12)
# selected elements: 17926
# ------------
# cluster= 1
# amplitude= 1.8028785849896138 idx= (6, 9, 285, 135)
# selected elements: 19923
# ------------
# cluster= 2
# amplitude= 1.7822382136992843 idx= (10, 9, 184, 42)
# selected elements: 43976
# ------------
# cluster= 3
# amplitude= 1.6113031513508014 idx= (1, 9, 194, 68)
# selected elements: 4537
# ------------
# cluster= 4
# amplitude= 1.5937568512564615 idx= (4, 9, 221, 88)
# selected elements: 7374
# ------------
# cluster= 5
# amplitude= 1.5833531101208662 idx= (0, 9, 192, 49)
# selected elements: 1115
# ------------
# cluster= 6
# amplitude= 1.508483095732299 idx= (1, 9, 210, 48)
# selected elements: 3642
# ------------
# cluster= 7
# amplitude= 1.4995320994940224 idx= (12, 8, 314, 127)
# selected elements: 19418
# ------------
# cluster= 8
# amplitude= 1.4772109093415784 idx= (0, 10, 152, 83)
# selected elements: 3016
# ------------
# cluster= 9
# amplitude= 1.468202078814194 idx= (0, 9, 226, 92)
# selected elements: 261
# ------------
# cluster= 10
# amplitude= 1.4454109751119992 idx= (6, 9, 174, 57)
# selected elements: 2170
# ------------
# cluster= 11
# amplitude= 1.4449293322772043 idx= (2, 9, 315, 105)
# selected elements: 5942
# ------------
# cluster= 12
# amplitude= 1.3973482126138796 idx= (9, 10, 130, 63)
# selected elements: 11534
# ------------
# cluster= 13
# amplitude= 1.397221402675915 idx= (10, 11, 194, 95)
# selected elements: 16450
# ------------
# cluster= 14
# amplitude= 1.3549816537166974 idx= (7, 10, 125, 62)
# selected elements: 4164
# ------------
# cluster= 15
# amplitude= 1.3509361286775468 idx= (8, 8, 226, 42)
# selected elements: 8543
# ------------
# cluster= 16
# amplitude= 1.3268751604160336 idx= (0, 9, 139, 69)
# selected elements: 428
# ------------
# cluster= 17
# amplitude= 1.3113289464299054 idx= (9, 9, 228, 118)
# selected elements: 8273
# ------------
# cluster= 18
# amplitude= 1.2880589295266405 idx= (0, 8, 110, 112)
# selected elements: 596
# ------------
# cluster= 19
# amplitude= 1.2772593368881906 idx= (13, 12, 192, 93)
# selected elements: 3989
# ------------
# cluster= 20
# amplitude= 1.2687277429817148 idx= (0, 9, 233, 53)
# selected elements: 688
# ------------
# cluster= 21
# amplitude= 1.2639132416856294 idx= (5, 9, 233, 138)
# selected elements: 3873
# ------------
# cluster= 22
# amplitude= 1.2609939680779827 idx= (6, 10, 160, 84)
# selected elements: 1621
# ------------
# cluster= 23
# amplitude= 1.2609729639880243 idx= (13, 10, 240, 48)
# selected elements: 11335
# ------------
# cluster= 24
# amplitude= 1.248263562603713 idx= (10, 11, 68, 40)
# selected elements: 8658
# ------------
# cluster= 25
# amplitude= 1.2479498868313397 idx= (0, 9, 41, 33)
# selected elements: 909
# ------------
# cluster= 26
# amplitude= 1.2289798942222292 idx= (1, 9, 258, 108)
# selected elements: 1678
# ------------
# cluster= 27
# amplitude= 1.2257034487132639 idx= (5, 10, 152, 19)
# selected elements: 5061
# ------------
# cluster= 28
# amplitude= 1.2209304952789561 idx= (0, 9, 113, 139)
# selected elements: 919
# ------------
# cluster= 29
# amplitude= 1.2106050297195379 idx= (7, 8, 302, 102)
# selected elements: 1294
# ------------
# cluster= 30
# amplitude= 1.2080689901925485 idx= (23, 12, 53, 26)
# selected elements: 8479
# ------------
# cluster= 31
# amplitude= 1.1785881105942015 idx= (6, 9, 336, 135)
# selected elements: 1657
# ------------
# cluster= 32
# amplitude= 1.1697708242184617 idx= (6, 10, 205, 48)
# selected elements: 1137
# ------------
# cluster= 33
# amplitude= 1.1681183221936027 idx= (4, 9, 248, 10)
# selected elements: 345
# ------------
# cluster= 34
# amplitude= 1.1679012534443378 idx= (0, 11, 120, 135)
# selected elements: 628
# ------------
# cluster= 35
# amplitude= 1.1606939358424517 idx= (15, 9, 327, 138)
# selected elements: 5440
# ------------
# cluster= 36
# amplitude= 1.1518846574313897 idx= (4, 9, 137, 72)
# selected elements: 1263
# ------------
# cluster= 37
# amplitude= 1.1482882288424054 idx= (14, 9, 263, 124)
# selected elements: 12655
# ------------
# cluster= 38
# amplitude= 1.1330982617264505 idx= (10, 8, 295, 107)
# selected elements: 2638
# ------------
# cluster= 39
# amplitude= 1.127590388101122 idx= (6, 10, 248, 12)
# selected elements: 2111
# ------------
# cluster= 40
# amplitude= 1.1257596209748093 idx= (0, 10, 252, 83)
# selected elements: 1273
# ------------
# cluster= 41
# amplitude= 1.1251735920664971 idx= (4, 9, 295, 115)
# selected elements: 1682
# ------------
# cluster= 42
# amplitude= 1.1244293790541482 idx= (1, 10, 266, 57)
# selected elements: 1456
# ------------
# cluster= 43
# amplitude= 1.120400104404034 idx= (5, 10, 271, 69)
# selected elements: 5751
# ------------
# cluster= 44
# amplitude= 1.117463707913323 idx= (3, 9, 192, 48)
# selected elements: 121
# ------------
# cluster= 45
# amplitude= 1.115278550051709 idx= (2, 9, 303, 82)
# selected elements: 1645
# ------------
# cluster= 46
# amplitude= 1.1088103995816443 idx= (3, 9, 166, 8)
# selected elements: 1432
# ------------
# cluster= 47
# amplitude= 1.1056806436562445 idx= (20, 8, 119, 18)
# selected elements: 5837
# ------------
# cluster= 48
# amplitude= 1.1013977523143546 idx= (6, 7, 317, 118)
# selected elements: 2418
# ------------
# cluster= 49
# amplitude= 1.1009605884434965 idx= (1, 10, 172, 129)
# selected elements: 787
# ------------
# cluster= 50
# amplitude= 1.099547750870442 idx= (8, 9, 184, 12)
# selected elements: 956
# ------------
# cluster= 51
# amplitude= 1.099531967938126 idx= (2, 8, 158, 80)
# selected elements: 528
# ------------
# cluster= 52
# amplitude= 1.0978227226681352 idx= (6, 7, 276, 109)
# selected elements: 1992
# ------------
# cluster= 53
# amplitude= 1.096706553154565 idx= (0, 9, 171, 76)
# selected elements: 205
# ------------
# cluster= 54
# amplitude= 1.093869554203111 idx= (4, 9, 337, 136)
# selected elements: 965
# ------------
# cluster= 55
# amplitude= 1.0929509119039162 idx= (11, 11, 271, 98)
# selected elements: 5844
# ------------
# cluster= 56
# amplitude= 1.0846206993200873 idx= (9, 9, 261, 92)
# selected elements: 1943
# ------------
# cluster= 57
# amplitude= 1.081207333342939 idx= (5, 8, 185, 21)
# selected elements: 583
# ------------
# cluster= 58
# amplitude= 1.0732811481089812 idx= (5, 10, 334, 135)
# selected elements: 552
# ------------
# cluster= 59
# amplitude= 1.071180447109068 idx= (22, 9, 174, 11)
# selected elements: 12026
# ------------
# cluster= 60
# amplitude= 1.0479428341767054 idx= (9, 9, 252, 17)
# selected elements: 2631
# ------------
# cluster= 61
# amplitude= 1.0470178533200507 idx= (0, 9, 292, 91)
# selected elements: 411
# ------------
# cluster= 62
# amplitude= 1.0352536858892067 idx= (2, 8, 175, 14)
# selected elements: 442
# ------------
# cluster= 63
# amplitude= 1.0338444567848626 idx= (4, 9, 206, 134)
# selected elements: 1254
# ------------
# cluster= 64
# amplitude= 1.031612548315305 idx= (9, 9, 204, 72)
# selected elements: 884
# ------------
# cluster= 65
# amplitude= 1.0270730780121868 idx= (0, 9, 243, 33)
# selected elements: 416
# ------------
# cluster= 66
# amplitude= 1.0238449781990118 idx= (0, 10, 259, 32)
# selected elements: 263
# ------------
# cluster= 67
# amplitude= 1.0236412585893095 idx= (6, 9, 272, 29)
# selected elements: 1353
# ------------
# cluster= 68
# amplitude= 1.0159888408989277 idx= (5, 8, 211, 54)
# selected elements: 658
# ------------
# cluster= 69
# amplitude= 1.0138450591687362 idx= (2, 8, 59, 129)
# selected elements: 898
# ------------
# cluster= 70
# amplitude= 1.0138319655736787 idx= (10, 8, 175, 73)
# selected elements: 649
# ------------
# cluster= 71
# amplitude= 1.0104730619816777 idx= (3, 8, 192, 26)
# selected elements: 416
# ------------
# cluster= 72
# amplitude= 1.0082738191462495 idx= (17, 7, 155, 63)
# selected elements: 7438
# ------------
# cluster= 73
# amplitude= 1.0069266412271674 idx= (20, 11, 73, 49)
# selected elements: 5666
# ------------
# cluster= 74
# amplitude= 1.0063946502517647 idx= (4, 9, 270, 116)
# selected elements: 203
# ------------
# cluster= 75
# amplitude= 1.0041982939433276 idx= (4, 9, 165, 37)
# selected elements: 766
# ------------
# cluster= 76
# amplitude= 1.0035932544578765 idx= (1, 8, 295, 123)
# selected elements: 338
# ------------
# cluster= 77
# amplitude= 1.001849580008444 idx= (2, 9, 310, 32)
# selected elements: 785
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 73.02it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp1p0 | offset 0] core=1200:1800 ext=1150:1850 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/amp1p0_offset_0000/xcore_01200_01800_xext_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.7008862437826677 idx= (6, 14, 86, 41)
# selected elements: 18158
# ------------
# cluster= 1
# amplitude= 1.5382846395339949 idx= (7, 14, 85, 14)
# selected elements: 1441
# ------------
# cluster= 2
# amplitude= 1.4434243335259018 idx= (2, 9, 15, 105)
# selected elements: 5364
# ------------
# cluster= 3
# amplitude= 1.296023294627679 idx= (8, 8, 47, 62)
# selected elements: 5291
# ------------
# cluster= 4
# amplitude= 1.278865431153435 idx= (11, 8, 19, 126)
# selected elements: 10541
# ------------
# cluster= 5
# amplitude= 1.2787255152662675 idx= (4, 2, 323, 13)
# selected elements: 2902
# ------------
# cluster= 6
# ...
#   fig.tight_layout()
# [rednoise4 | offset 0] core=1200:1800 ext=1150:1850 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/rednoise4_offset_0000/xcore_01200_01800_xext_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.7008862437826677 idx= (6, 14, 86, 41)
# selected elements: 37054
# ------------
# cluster= 1
# amplitude= 1.4434243335259018 idx= (2, 9, 15, 105)
# selected elements: 14526
# ------------
# cluster= 2
# amplitude= 1.296023294627679 idx= (8, 8, 47, 62)
# selected elements: 30007
# ------------
# cluster= 3
# amplitude= 1.278865431153435 idx= (11, 8, 19, 126)
# selected elements: 37277
# ------------
# cluster= 4
# amplitude= 1.2787255152662675 idx= (4, 2, 323, 13)
# selected elements: 9603
# ------------
# cluster= 5
# amplitude= 1.2452600750361478 idx= (6, 11, 321, 131)
# selected elements: 14721
# ------------
# cluster= 6
# amplitude= 1.2044015945438042 idx= (5, 9, 317, 134)
# selected elements: 1405
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 76.92it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=1800:2400 ext=1750:2450 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/rednoise4_offset_0000/xcore_01800_02400_xext_01750_02450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.4601471512853637 idx= (0, 9, 222, 103)
# selected elements: 8238
# ------------
# cluster= 1
# amplitude= 1.279338150928395 idx= (4, 2, 23, 13)
# selected elements: 12632
# ------------
# cluster= 2
# amplitude= 1.2487207219384684 idx= (6, 10, 20, 134)
# selected elements: 22164
# ------------
# cluster= 3
# amplitude= 1.2035750893968642 idx= (7, 11, 19, 135)
# selected elements: 714
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 67.95it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=2400:3000 ext=2350:3050 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/rednoise4_offset_0000/xcore_02400_03000_xext_02350_03050
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.5837521748376762 idx= (4, 9, 230, 76)
# selected elements: 76139
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 71.29it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=3000:3600 ext=2950:3650 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/rednoise4_offset_0000/xcore_03000_03600_xext_02950_03650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.5895438241042705 idx= (9, 13, 192, 93)
# selected elements: 101258
# ------------
# cluster= 1
# amplitude= 1.978046821584319 idx= (6, 11, 197, 69)
# selected elements: 44537
# ------------
# cluster= 2
# amplitude= 1.855477317257426 idx= (11, 14, 237, 129)
# selected elements: 51810
# ------------
# cluster= 3
# amplitude= 1.6052537927157147 idx= (3, 10, 108, 58)
# selected elements: 108719
# ------------
# cluster= 4
# amplitude= 1.595196718855586 idx= (11, 12, 270, 133)
# selected elements: 12819
# ------------
# cluster= 5
# amplitude= 1.58816491614977 idx= (8, 13, 234, 123)
# selected elements: 6687
# ------------
# cluster= 6
# amplitude= 1.5718087625222557 idx= (0, 3, 123, 41)
# selected elements: 26716
# ------------
# cluster= 7
# amplitude= 1.5316573973908594 idx= (6, 3, 61, 108)
# selected elements: 105359
# ------------
# cluster= 8
# amplitude= 1.5316115425125234 idx= (17, 12, 255, 126)
# selected elements: 80017
# ------------
# cluster= 9
# amplitude= 1.456855594899672 idx= (19, 13, 246, 124)
# selected elements: 24922
# ------------
# cluster= 10
# amplitude= 1.4517344627641209 idx= (13, 9, 326, 126)
# selected elements: 64804
# ------------
# cluster= 11
# amplitude= 1.443958160867366 idx= (20, 9, 168, 9)
# selected elements: 70870
# ------------
# cluster= 12
# amplitude= 1.3743017127069144 idx= (7, 17, 58, 68)
# selected elements: 28468
# ------------
# cluster= 13
# amplitude= 1.3414365098231995 idx= (13, 9, 167, 10)
# selected elements: 22938
# ------------
# cluster= 14
# amplitude= 1.3126588636808654 idx= (23, 9, 177, 8)
# selected elements: 4240
# ------------
# cluster= 15
# amplitude= 1.296004056801924 idx= (12, 8, 211, 127)
# selected elements: 24639
# ------------
# cluster= 16
# amplitude= 1.2604224427775408 idx= (8, 13, 101, 48)
# selected elements: 14284
# ------------
# cluster= 17
# amplitude= 1.2582009972741377 idx= (20, 0, 7, 118)
# selected elements: 59008
# ------------
# cluster= 18
# amplitude= 1.2363564509677936 idx= (6, 15, 203, 104)
# selected elements: 1907
# ------------
# cluster= 19
# amplitude= 1.2354685719805276 idx= (0, 9, 221, 133)
# selected elements: 54751
# ------------
# cluster= 20
# amplitude= 1.2014307830491622 idx= (8, 12, 272, 135)
# selected elements: 3765
# ------------
# cluster= 21
# amplitude= 1.2001361111464526 idx= (7, 0, 54, 73)
# selected elements: 20076
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 76.56it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=3600:4200 ext=3550:4250 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/rednoise4_offset_0000/xcore_03600_04200_xext_03550_04250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.5547231036638032 idx= (13, 9, 26, 127)
# selected elements: 279421
# ------------
# cluster= 1
# amplitude= 1.2377583201086488 idx= (0, 9, 38, 85)
# selected elements: 130146
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 72.85it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=4200:4800 ext=4150:4850 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/rednoise4_offset_0000/xcore_04200_04800_xext_04150_04850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.6114467166769586 idx= (0, 3, 231, 96)
# selected elements: 304438
# ------------
# cluster= 1
# amplitude= 1.4925183472595422 idx= (0, 9, 259, 37)
# selected elements: 30787
# ------------
# cluster= 2
# amplitude= 1.4744034681151648 idx= (2, 9, 326, 9)
# selected elements: 111720
# ------------
# cluster= 3
# amplitude= 1.3993281617617812 idx= (3, 4, 231, 97)
# selected elements: 3602
# ------------
# cluster= 4
# amplitude= 1.3750200470691014 idx= (0, 9, 242, 61)
# selected elements: 1017
# ------------
# cluster= 5
# amplitude= 1.3286722113816747 idx= (2, 11, 297, 41)
# selected elements: 7541
# ------------
# cluster= 6
# amplitude= 1.3129183573554255 idx= (8, 8, 244, 35)
# selected elements: 94735
# ------------
# cluster= 7
# amplitude= 1.3086657839480247 idx= (4, 9, 209, 126)
# selected elements: 25118
# ------------
# cluster= 8
# amplitude= 1.2918835226794583 idx= (2, 9, 310, 124)
# selected elements: 9920
# ------------
# cluster= 9
# amplitude= 1.2436747833028308 idx= (7, 9, 244, 38)
# selected elements: 14443
# ------------
# cluster= 10
# amplitude= 1.2407394967451573 idx= (0, 7, 278, 13)
# selected elements: 1780
# ------------
# cluster= 11
# amplitude= 1.2406654055108681 idx= (0, 9, 293, 31)
# selected elements: 967
# ------------
# cluster= 12
# amplitude= 1.2087411075705887 idx= (0, 10, 282, 71)
# selected elements: 2990
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 71.38it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=4800:5400 ext=4750:5450 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/rednoise4_offset_0000/xcore_04800_05400_xext_04750_05450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 3.0157737424094386 idx= (0, 0, 234, 134)
# selected elements: 577131
# ------------
# cluster= 1
# amplitude= 1.9976981203532842 idx= (1, 17, 233, 132)
# selected elements: 65092
# ------------
# cluster= 2
# amplitude= 1.726819776260001 idx= (12, 17, 233, 132)
# selected elements: 174278
# ------------
# cluster= 3
# amplitude= 1.5522893025731321 idx= (4, 9, 86, 131)
# selected elements: 641866
# ------------
# cluster= 4
# amplitude= 1.468294939714883 idx= (1, 9, 26, 9)
# selected elements: 16205
# ------------
# cluster= 5
# amplitude= 1.405391677679908 idx= (1, 8, 197, 98)
# selected elements: 28532
# ------------
# cluster= 6
# amplitude= 1.404510794199412 idx= (5, 12, 146, 136)
# selected elements: 93069
# ------------
# cluster= 7
# amplitude= 1.3370389621092347 idx= (0, 0, 161, 139)
# selected elements: 46471
# ------------
# cluster= 8
# amplitude= 1.2730793200975956 idx= (16, 9, 198, 18)
# selected elements: 224111
# ------------
# cluster= 9
# amplitude= 1.2549854677252563 idx= (1, 10, 224, 34)
# selected elements: 33208
# ------------
# cluster= 10
# amplitude= 1.2519701480623078 idx= (0, 1, 128, 130)
# selected elements: 8194
# ------------
# cluster= 11
# amplitude= 1.244422566755048 idx= (0, 9, 153, 15)
# selected elements: 25166
# ------------
# cluster= 12
# amplitude= 1.2201803153732196 idx= (0, 17, 159, 138)
# selected elements: 20298
# ------------
# cluster= 13
# amplitude= 1.2188274790933797 idx= (0, 11, 57, 115)
# selected elements: 11745
# ------------
# cluster= 14
# amplitude= 1.2130025086437957 idx= (1, 9, 11, 125)
# selected elements: 6993
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 73.13it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=5400:5451 ext=5350:5451 saved to outputs_decompose2d_slices_single_noise_filtering_tmp/rednoise4_offset_0000/xcore_05400_05451_xext_05350_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 84.78it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Done. Outputs in /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_decompose2d_slices_single_noise_filtering_tmp/rednoise4_offset_0000
