# %% [markdown]
# ## Comparing two ways of stitching

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Dict, Any, List

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

# --------------------------
# User params
# --------------------------
FILE_PATH = "awe_l5c_q20_2024165T2120_03175_v01.nc"
FRAME_IDX = 0

# Slicing on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)
SLICE_PAD = 50  # extend each slice by this many UNBINNED pixels on each side

# Choose ONE slicing offset (no comparisons)
X_OFFSET = 0  # set to 0 or 300 or whatever you want

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 16
JT = 18
ASPECT = 1

# Pixel spacing (km per pixel)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# Clustering thresholds
MIN_AMP = 0.2
THR = 0.1

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices_single")
SAVE_DPI = 200

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Small helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def diverging_limits(*arrays: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    vals = []
    for A in arrays:
        if A is None:
            continue
        a = np.asarray(A)
        good = np.isfinite(a)
        if np.any(good):
            vals.append(a[good].ravel())
    if not vals:
        return (-1.0, 1.0)
    stacked = np.concatenate(vals)
    lo, hi = np.nanpercentile(stacked, [p_lo, p_hi])
    vmax = max(abs(lo), abs(hi))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    return (-vmax, vmax)


# --------------------------
# Data helpers
# --------------------------
def read_radiance_frame(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        rad = nc.variables["Radiance"][:]  # (t, y, x)
    if rad.ndim != 3:
        raise ValueError(f"Radiance expected 3D (t,y,x); got {rad.shape}")
    if not (0 <= frame_idx < rad.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{rad.shape[0]-1}")
    return np.asarray(rad[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    return np.cos(theta_xy), np.sin(theta_xy)


def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("Radiance (arb)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    vmin, vmax = diverging_limits(orig_c, bg_c, rem_c, rem_tapered_c, p_lo=1, p_hi=99)

    fig, axs = plt.subplots(2, 2, figsize=(12, 10), constrained_layout=True)
    axes = axs.flatten()

    panels = [
        (orig_c, "Original (median-sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    im0 = None
    for ax, (Z, title) in zip(axes, panels):
        im0 = ax.pcolormesh(
            x1d_km, y1d_km, Z, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    cbar = fig.colorbar(im0, ax=axs, orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("Radiance (arb)")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2
    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])
        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_vmin, bg_vmax = diverging_limits(bg_xy, p_lo=2, p_hi=98)
    cl_vmin, cl_vmax = diverging_limits(rec_xy, p_lo=2, p_hi=98)

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if not np.isfinite(lam_vmin) or not np.isfinite(lam_vmax) or lam_vmin == lam_vmax:
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n"
            + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        ARROW_LEN_KM = 40.0
        u = u * ARROW_LEN_KM
        v = v * ARROW_LEN_KM

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)


# --------------------------
# Slice pipeline
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
) -> Dict[str, Any]:
    """
    Runs processing on an extended slice (x_slice),
    but returns only CORE tiles for stitching: core_start_unbinned..core_end_unbinned

    Step 08 (power) intentionally removed.
    """
    outdir.mkdir(parents=True, exist_ok=True)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        f = int(BIN_FACTOR)
        dx_km = DX_KM_BASE * f
        dy_km = DY_KM_BASE * f
    else:
        f = 1
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f
    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    raw_win = np.asarray(rad2d_flat[Y_SLICE, x_slice], dtype=float)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"Radiance (window, flattened){bin_tag}",
        outdir / "00_radiance_window.png",
    )

    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_4panel.png",
    )

    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=MIN_AMP, thr=THR)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N
    )
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text("No clusters found. Try lowering MIN_AMP or THR.\n")
        remaining_core_xy = crop_pad_core(proc)
        nan_core = np.full_like(remaining_core_xy, np.nan)
        return {
            "has_clusters": False,
            "x_start_unbinned": core_start_unbinned,
            "dx_km": dx_km,
            "dy_km": dy_km,
            "remaining_xy": remaining_core_xy,
            "rec_all_xy": nan_core,
        }

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    lines = []
    lines.append("Cluster power ranking (clustered only)\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))
    theta_vals = np.asarray(cwt["theta"], dtype=float)

    def plot_cluster_grid(kind: str, outname: str) -> None:
        fig, axs = plt.subplots(nrow, ncol, figsize=(12, 10))
        axs = np.atleast_1d(axs).reshape(-1)

        bg_vmin, bg_vmax = diverging_limits(bg, p_lo=2, p_hi=98)

        number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}

        for ax, kcl in zip(axs, biggest):
            decomposition[:] = orig_decomp
            decomposition[iwave != kcl] = 0
            rec = transform.reconstruct2d(cwt)
            rec_centered = rec.T - np.median(rec)

            s_idx = int(idxs[kcl][0])
            t_idx = int(idxs[kcl][1])
            _, _, lam = effective_lambda(cwt, s_idx, t_idx)

            theta_dom_rad = float(theta_vals[t_idx])
            theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

            ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
            Pk = float(P_abs_sorted[ii])
            pk = float(P_pct_sorted[ii])

            if kind == "standalone":
                ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0)
            elif kind == "overlay":
                ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
                ax.pcolormesh(
                    x1d_km, y1d_km, rec_centered,
                    shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0, alpha=0.6
                )
            else:
                raise ValueError(kind)

            ax.set_title(
                rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
                + "\n"
                + rf"P={Pk:.2e} ({pk:.1f}%)"
            )
            ax.set_aspect("equal", adjustable="box")

        for ax in axs[n_show:]:
            ax.axis("off")
        for ax in axs[:n_show]:
            ax.set_xlabel("x (km)")
            ax.set_ylabel("y (km)")

        for i, ax in enumerate(axs, start=1):
            if ax.has_data():
                ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

        fig.tight_layout()
        save_fig(fig, outdir / outname)

    plot_cluster_grid("standalone", "05_clusters_standalone.png")
    plot_cluster_grid("overlay", "06_clusters_overlay.png")

    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
        )

    # 09 per slice: remaining vs all clusters reconstruction
    remaining_after_preproc_xy = proc

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)

    vmin, vmax = diverging_limits(remaining_after_preproc_xy, rec_all_xy, p_lo=2, p_hi=98)

    figR, (axL, axR) = plt.subplots(1, 2, figsize=(16, 6), constrained_layout=True)
    imL = axL.pcolormesh(x1d_km, y1d_km, remaining_after_preproc_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axL.set_title("Remaining (after preprocessing, input to CWT)")
    axL.set_xlabel("x (km)")
    axL.set_ylabel("y (km)")
    axL.set_aspect("equal", adjustable="box")
    figR.colorbar(imL, ax=axL, fraction=0.046, pad=0.02).set_label("arb")

    imR = axR.pcolormesh(x1d_km, y1d_km, rec_all_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axR.set_title("All clusters combined (reconstruction)")
    axR.set_xlabel("x (km)")
    axR.set_ylabel("y (km)")
    axR.set_aspect("equal", adjustable="box")
    figR.colorbar(imR, ax=axR, fraction=0.046, pad=0.02).set_label("arb")
    save_fig(figR, outdir / "09_remaining_vs_all_clusters.png")

    decomposition[:] = orig_decomp

    remaining_core_xy = crop_pad_core(remaining_after_preproc_xy)
    rec_all_core_xy = crop_pad_core(rec_all_xy)

    return {
        "has_clusters": True,
        "x_start_unbinned": core_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "remaining_xy": remaining_core_xy,
        "rec_all_xy": rec_all_core_xy,
    }


def stitch_and_save_final_09(slice_results: List[Dict[str, Any]], outroot: Path, tag: str) -> None:
    if not slice_results:
        return

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE

    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)

    ny, nx_tot = remaining_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    vmin, vmax = diverging_limits(remaining_stitched, rec_all_stitched, p_lo=2, p_hi=98)

    figR, (axT, axB) = plt.subplots(2, 1, figsize=(18, 4), constrained_layout=True, sharex=True, sharey=True)

    imT = axT.pcolormesh(x1d_km, y1d_km, remaining_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axT.set_title(f"STITCHED (core tiles) {tag}: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(x1d_km, y1d_km, rec_all_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axB.set_title(f"STITCHED (core tiles) {tag}: All clusters combined (reconstruction)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    axT.set_xlim(600, 10000)

    cbar = figR.colorbar(imT, ax=[axT, axB], orientation="vertical", fraction=0.01, pad=0.01)
    cbar.set_label("kRayleigh (Relative)")
    save_fig(figR, outroot / f"FINAL_09_remaining_vs_all_clusters_STITCHED_{tag}.png")


# --------------------------
# Run one slicing scheme
# --------------------------
def run_all_slices_single_offset() -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_radiance_frame(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    x_offset = int(X_OFFSET)
    if x_offset >= nx_total:
        raise ValueError(f"X_OFFSET={x_offset} too large for nx_total={nx_total}")

    outroot = OUTPUT_ROOT / f"offset_{x_offset:04d}"
    outroot.mkdir(parents=True, exist_ok=True)

    core_starts = list(range(x_offset, nx_total, X_CHUNK))
    stitch_results: List[Dict[str, Any]] = []

    for core_start in core_starts:
        core_end = min(core_start + X_CHUNK, nx_total)

        ext_start = max(0, core_start - SLICE_PAD)
        ext_end = min(nx_total, core_end + SLICE_PAD)
        x_slice = slice(ext_start, ext_end)

        outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
        print(f"[offset {x_offset}] core={core_start}:{core_end}  ext={ext_start}:{ext_end}  saved to {outdir}")

        res = run_pipeline_for_slice(
            rad2d_flat=rad2d_flat,
            x_slice=x_slice,
            outdir=outdir,
            x_start_unbinned=ext_start,
            core_start_unbinned=core_start,
            core_end_unbinned=core_end,
        )
        stitch_results.append(res)

    stitch_and_save_final_09(stitch_results, outroot, tag=f"offset_{x_offset:04d}")
    print("Done. Outputs in", outroot.resolve())


run_all_slices_single_offset()
# Out:
# [offset 0] core=0:600  ext=0:650  saved to outputs_decompose2d_slices_single/offset_0000/xcore_00000_00600_xext_00000_00650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.37108038888739175 idx= (12, 9, 308, 58)
# selected elements: 159407
# ------------
# cluster= 1
# amplitude= 0.3444417504565404 idx= (13, 9, 205, 118)
# selected elements: 64010
# ------------
# cluster= 2
# amplitude= 0.31221373851265266 idx= (12, 7, 256, 71)
# selected elements: 30843
# ------------
# cluster= 3
# amplitude= 0.30603962397346623 idx= (10, 9, 255, 78)
# selected elements: 15591
# ------------
# cluster= 4
# amplitude= 0.2759813435543466 idx= (5, 7, 274, 60)
# selected elements: 10614
# ------------
# cluster= 5
# amplitude= 0.26529812480818515 idx= (5, 10, 197, 116)
# selected elements: 1744
# ------------
# cluster= 6
# amplitude= 0.2586889237913039 idx= (11, 12, 285, 58)
# selected elements: 6338
# ------------
# cluster= 7
# amplitude= 0.24621886606577267 idx= (9, 10, 159, 36)
# selected elements: 20459
# ------------
# cluster= 8
# amplitude= 0.21768271772666328 idx= (5, 10, 199, 29)
# selected elements: 6779
# ------------
# cluster= 9
# amplitude= 0.2125093455099971 idx= (15, 7, 243, 124)
# selected elements: 4807
# ------------
# cluster= 10
# amplitude= 0.21082208911597553 idx= (15, 13, 290, 46)
# selected elements: 4225
# ------------
# cluster= 11
# amplitude= 0.21051256241488664 idx= (14, 12, 153, 120)
# selected elements: 10607
# ------------
# cluster= 12
# amplitude= 0.20894104410732525 idx= (9, 11, 214, 57)
# selected elements: 7971
# ------------
# cluster= 13
# amplitude= 0.2078033251965815 idx= (9, 10, 140, 69)
# selected elements: 14115
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 67.16it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=600:1200  ext=550:1250  saved to outputs_decompose2d_slices_single/offset_0000/xcore_00600_01200_xext_00550_01250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.48025098934026705 idx= (6, 8, 241, 25)
# selected elements: 53690
# ------------
# cluster= 1
# amplitude= 0.47277683261286246 idx= (5, 9, 243, 24)
# selected elements: 5657
# ------------
# cluster= 2
# amplitude= 0.4083574722293721 idx= (8, 9, 48, 50)
# selected elements: 135036
# ------------
# cluster= 3
# amplitude= 0.4057785279312059 idx= (7, 8, 50, 51)
# selected elements: 2388
# ------------
# cluster= 4
# amplitude= 0.3723316141390129 idx= (15, 9, 246, 27)
# selected elements: 42268
# ------------
# cluster= 5
# amplitude= 0.33530692587411665 idx= (10, 11, 71, 43)
# selected elements: 38036
# ------------
# cluster= 6
# amplitude= 0.3333222246800942 idx= (10, 9, 199, 7)
# selected elements: 34263
# ------------
# cluster= 7
# amplitude= 0.29199315438429424 idx= (13, 8, 250, 28)
# selected elements: 8134
# ------------
# cluster= 8
# amplitude= 0.2821105973255177 idx= (13, 12, 19, 52)
# selected elements: 33626
# ------------
# cluster= 9
# amplitude= 0.27196833062886816 idx= (9, 10, 281, 10)
# selected elements: 6223
# ------------
# cluster= 10
# amplitude= 0.2646144330380939 idx= (2, 8, 57, 53)
# selected elements: 1806
# ------------
# cluster= 11
# amplitude= 0.252289020994592 idx= (13, 10, 158, 7)
# selected elements: 11158
# ------------
# cluster= 12
# amplitude= 0.23954182793681061 idx= (13, 7, 161, 61)
# selected elements: 38930
# ------------
# cluster= 13
# amplitude= 0.23411610464554305 idx= (10, 9, 108, 5)
# selected elements: 5884
# ------------
# cluster= 14
# amplitude= 0.23283427931253153 idx= (12, 10, 109, 7)
# selected elements: 1621
# ------------
# cluster= 15
# amplitude= 0.23231672953858867 idx= (11, 8, 301, 32)
# selected elements: 12663
# ------------
# cluster= 16
# amplitude= 0.21858124141791535 idx= (5, 9, 128, 66)
# selected elements: 4896
# ------------
# cluster= 17
# amplitude= 0.21777447868954353 idx= (11, 7, 77, 55)
# selected elements: 12554
# ------------
# cluster= 18
# amplitude= 0.21152829576239535 idx= (7, 9, 280, 11)
# selected elements: 1519
# ------------
# cluster= 19
# amplitude= 0.2009010551342877 idx= (3, 10, 106, 57)
# selected elements: 2116
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.11it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=1200:1800  ext=1150:1850  saved to outputs_decompose2d_slices_single/offset_0000/xcore_01200_01800_xext_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.28058267975080087 idx= (6, 10, 325, 134)
# selected elements: 13696
# ------------
# cluster= 1
# amplitude= 0.23826621503663226 idx= (9, 7, 157, 37)
# selected elements: 42677
# ------------
# cluster= 2
# amplitude= 0.22799194295356864 idx= (11, 13, 193, 94)
# selected elements: 20205
# ------------
# cluster= 3
# amplitude= 0.2200406757367188 idx= (13, 9, 173, 8)
# selected elements: 18350
# ------------
# cluster= 4
# amplitude= 0.2135749478263648 idx= (7, 4, 329, 125)
# selected elements: 8796
# ------------
# cluster= 5
# amplitude= 0.20804465749275744 idx= (6, 5, 152, 24)
# selected elements: 2967
# ------------
# cluster= 6
# amplitude= 0.20411067927736343 idx= (10, 14, 139, 110)
# selected elements: 11214
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.95it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=1800:2400  ext=1750:2450  saved to outputs_decompose2d_slices_single/offset_0000/xcore_01800_02400_xext_01750_02450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.31810958235042114 idx= (15, 8, 294, 125)
# selected elements: 63130
# ------------
# cluster= 1
# amplitude= 0.2818026053147679 idx= (6, 10, 25, 134)
# selected elements: 11345
# ------------
# cluster= 2
# amplitude= 0.24102163806222487 idx= (15, 9, 38, 8)
# selected elements: 19361
# ------------
# cluster= 3
# amplitude= 0.2345179562864613 idx= (10, 7, 53, 135)
# selected elements: 31606
# ------------
# cluster= 4
# amplitude= 0.21285623510781412 idx= (7, 4, 29, 126)
# selected elements: 11216
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 91.75it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=2400:3000  ext=2350:3050  saved to outputs_decompose2d_slices_single/offset_0000/xcore_02400_03000_xext_02350_03050
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.5073188037472124 idx= (15, 2, 332, 112)
# selected elements: 172637
# ------------
# cluster= 1
# amplitude= 0.44028277189678355 idx= (8, 2, 323, 128)
# selected elements: 37271
# ------------
# cluster= 2
# amplitude= 0.3535136289053397 idx= (14, 2, 289, 109)
# selected elements: 23871
# ------------
# cluster= 3
# amplitude= 0.3443464000221411 idx= (8, 5, 251, 80)
# selected elements: 85486
# ------------
# cluster= 4
# amplitude= 0.2867008512446188 idx= (14, 1, 342, 54)
# selected elements: 11644
# ------------
# cluster= 5
# amplitude= 0.2827535387468756 idx= (14, 6, 245, 86)
# selected elements: 9585
# ------------
# cluster= 6
# amplitude= 0.27481485619158913 idx= (14, 1, 141, 124)
# selected elements: 42397
# ------------
# cluster= 7
# amplitude= 0.25887743560684784 idx= (10, 1, 109, 105)
# selected elements: 15971
# ------------
# cluster= 8
# amplitude= 0.25702515380346436 idx= (13, 4, 251, 82)
# selected elements: 11066
# ------------
# cluster= 9
# amplitude= 0.2556270058382898 idx= (2, 3, 310, 114)
# selected elements: 1901
# ------------
# cluster= 10
# amplitude= 0.24995082048971037 idx= (15, 17, 342, 67)
# selected elements: 8023
# ------------
# cluster= 11
# amplitude= 0.24925003704379378 idx= (11, 11, 135, 113)
# selected elements: 31541
# ------------
# cluster= 12
# amplitude= 0.24743804089807744 idx= (10, 0, 344, 71)
# selected elements: 2895
# ------------
# cluster= 13
# amplitude= 0.24391141916818954 idx= (2, 8, 276, 82)
# selected elements: 3559
# ------------
# cluster= 14
# amplitude= 0.2436789592108028 idx= (4, 7, 275, 85)
# selected elements: 1501
# ------------
# cluster= 15
# amplitude= 0.23358840684743518 idx= (15, 9, 321, 8)
# selected elements: 14806
# ------------
# cluster= 16
# amplitude= 0.2303198168301527 idx= (14, 9, 299, 47)
# selected elements: 21240
# ------------
# cluster= 17
# amplitude= 0.22923797162738702 idx= (8, 9, 74, 74)
# selected elements: 38843
# ------------
# cluster= 18
# amplitude= 0.22877048948830647 idx= (3, 10, 275, 110)
# selected elements: 3089
# ------------
# cluster= 19
# amplitude= 0.22719200077602839 idx= (11, 4, 338, 92)
# selected elements: 3208
# ------------
# cluster= 20
# amplitude= 0.22718281510971702 idx= (12, 1, 342, 98)
# selected elements: 426
# ------------
# cluster= 21
# amplitude= 0.22536808410662804 idx= (7, 3, 251, 123)
# selected elements: 11305
# ------------
# cluster= 22
# amplitude= 0.223311876092104 idx= (3, 1, 332, 111)
# selected elements: 3924
# ------------
# cluster= 23
# amplitude= 0.22320931950177267 idx= (15, 8, 120, 62)
# selected elements: 18650
# ------------
# cluster= 24
# amplitude= 0.2230731854898252 idx= (9, 4, 298, 85)
# selected elements: 5804
# ------------
# cluster= 25
# amplitude= 0.21400661701534046 idx= (11, 4, 335, 51)
# selected elements: 8807
# ------------
# cluster= 26
# amplitude= 0.2065544450476023 idx= (15, 4, 121, 83)
# selected elements: 4602
# ------------
# cluster= 27
# amplitude= 0.20602602831673927 idx= (5, 1, 227, 71)
# selected elements: 8238
# ------------
# cluster= 28
# amplitude= 0.20542377375475687 idx= (15, 17, 345, 117)
# selected elements: 4506
# ------------
# cluster= 29
# amplitude= 0.20055609172243696 idx= (15, 11, 205, 60)
# selected elements: 10280
# ------------
# cluster= 30
# amplitude= 0.20013201274804365 idx= (15, 7, 317, 10)
# selected elements: 4072
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.93it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=3000:3600  ext=2950:3650  saved to outputs_decompose2d_slices_single/offset_0000/xcore_03000_03600_xext_02950_03650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.3214636561113875 idx= (9, 13, 192, 94)
# selected elements: 1775906
# ------------
# cluster= 1
# amplitude= 0.9003197682772737 idx= (15, 0, 76, 64)
# selected elements: 602992
# ------------
# cluster= 2
# amplitude= 0.6987886768105129 idx= (14, 11, 134, 71)
# selected elements: 25859
# ------------
# cluster= 3
# amplitude= 0.6738899013098673 idx= (2, 9, 173, 38)
# selected elements: 15897
# ------------
# cluster= 4
# amplitude= 0.6633018198683046 idx= (15, 15, 112, 122)
# selected elements: 62850
# ------------
# cluster= 5
# amplitude= 0.6321003850772021 idx= (2, 8, 205, 112)
# selected elements: 6978
# ------------
# cluster= 6
# amplitude= 0.5946466521224315 idx= (2, 12, 140, 65)
# selected elements: 10198
# ------------
# cluster= 7
# amplitude= 0.5748977187181881 idx= (15, 15, 208, 126)
# selected elements: 3020
# ------------
# cluster= 8
# amplitude= 0.5619048612177782 idx= (15, 5, 148, 77)
# selected elements: 46540
# ------------
# cluster= 9
# amplitude= 0.5514946678711187 idx= (10, 2, 66, 91)
# selected elements: 81839
# ------------
# cluster= 10
# amplitude= 0.5235622108851281 idx= (15, 10, 198, 121)
# selected elements: 32718
# ------------
# cluster= 11
# amplitude= 0.5101500127398403 idx= (14, 9, 153, 27)
# selected elements: 29448
# ------------
# cluster= 12
# amplitude= 0.47416570441741424 idx= (8, 0, 75, 60)
# selected elements: 46608
# ------------
# cluster= 13
# amplitude= 0.47107195201930246 idx= (1, 3, 97, 63)
# selected elements: 49179
# ------------
# cluster= 14
# amplitude= 0.45328823253373934 idx= (13, 4, 146, 74)
# selected elements: 18629
# ------------
# cluster= 15
# amplitude= 0.4225991033733493 idx= (8, 5, 148, 58)
# selected elements: 125060
# ------------
# cluster= 16
# amplitude= 0.41719501693471606 idx= (11, 8, 161, 26)
# selected elements: 18109
# ------------
# cluster= 17
# amplitude= 0.40709170969015607 idx= (15, 7, 157, 33)
# selected elements: 5659
# ------------
# cluster= 18
# amplitude= 0.3989089209590924 idx= (11, 10, 98, 144)
# selected elements: 1323
# ------------
# cluster= 19
# amplitude= 0.39889146273385023 idx= (11, 9, 85, 5)
# selected elements: 29549
# ------------
# cluster= 20
# amplitude= 0.39788706872873286 idx= (6, 2, 133, 116)
# selected elements: 17434
# ------------
# cluster= 21
# amplitude= 0.3900486911401334 idx= (11, 17, 76, 52)
# selected elements: 49702
# ------------
# cluster= 22
# amplitude= 0.3845408507049589 idx= (14, 16, 203, 133)
# selected elements: 13790
# ------------
# cluster= 23
# amplitude= 0.3780959765269905 idx= (6, 10, 169, 142)
# selected elements: 5694
# ------------
# cluster= 24
# amplitude= 0.37239480583145085 idx= (7, 7, 208, 114)
# selected elements: 27380
# ------------
# cluster= 25
# amplitude= 0.36870274155613997 idx= (11, 3, 77, 27)
# selected elements: 1430
# ------------
# cluster= 26
# amplitude= 0.35243911371492215 idx= (8, 13, 67, 95)
# selected elements: 1044
# ------------
# cluster= 27
# amplitude= 0.3451640038620158 idx= (12, 16, 106, 119)
# selected elements: 14949
# ------------
# cluster= 28
# amplitude= 0.34481139615122036 idx= (0, 3, 123, 41)
# selected elements: 1484
# ------------
# cluster= 29
# amplitude= 0.34462144916899706 idx= (15, 7, 111, 141)
# selected elements: 7452
# ------------
# cluster= 30
# amplitude= 0.34245949680856475 idx= (10, 0, 187, 70)
# selected elements: 2320
# ------------
# cluster= 31
# amplitude= 0.34129532463247997 idx= (6, 8, 124, 102)
# selected elements: 18727
# ------------
# cluster= 32
# amplitude= 0.34121342636904806 idx= (13, 8, 82, 58)
# selected elements: 1678
# ------------
# cluster= 33
# amplitude= 0.3383768526836366 idx= (15, 5, 57, 96)
# selected elements: 15623
# ------------
# cluster= 34
# amplitude= 0.3353029524701459 idx= (5, 3, 22, 128)
# selected elements: 12977
# ------------
# cluster= 35
# amplitude= 0.32658202637322054 idx= (6, 6, 188, 117)
# selected elements: 8930
# ------------
# cluster= 36
# amplitude= 0.320872469577909 idx= (7, 4, 140, 104)
# selected elements: 440
# ------------
# cluster= 37
# amplitude= 0.3186479570026206 idx= (3, 8, 245, 63)
# selected elements: 16860
# ------------
# cluster= 38
# amplitude= 0.31405696450119547 idx= (9, 11, 97, 142)
# selected elements: 2835
# ------------
# cluster= 39
# amplitude= 0.3138943896025435 idx= (8, 7, 127, 102)
# selected elements: 8221
# ------------
# cluster= 40
# amplitude= 0.31367887074355333 idx= (4, 4, 91, 49)
# selected elements: 10691
# ------------
# cluster= 41
# amplitude= 0.30706562712180885 idx= (9, 8, 84, 6)
# selected elements: 3979
# ------------
# cluster= 42
# amplitude= 0.3051168124278113 idx= (10, 0, 89, 135)
# selected elements: 5299
# ------------
# cluster= 43
# amplitude= 0.302818608774934 idx= (8, 9, 85, 6)
# selected elements: 2733
# ------------
# cluster= 44
# amplitude= 0.3016294180723692 idx= (5, 9, 99, 142)
# selected elements: 763
# ------------
# cluster= 45
# amplitude= 0.3010360246190825 idx= (5, 11, 71, 113)
# selected elements: 19442
# ------------
# cluster= 46
# amplitude= 0.30004706104970186 idx= (8, 4, 19, 130)
# selected elements: 13765
# ------------
# cluster= 47
# amplitude= 0.3000108256031408 idx= (2, 2, 124, 40)
# selected elements: 1161
# ------------
# cluster= 48
# amplitude= 0.29985881520278806 idx= (9, 16, 189, 82)
# selected elements: 5286
# ------------
# cluster= 49
# amplitude= 0.2980951214690299 idx= (15, 13, 299, 118)
# selected elements: 14948
# ------------
# cluster= 50
# amplitude= 0.2943816633184424 idx= (1, 12, 183, 75)
# selected elements: 925
# ------------
# cluster= 51
# amplitude= 0.2930989103827532 idx= (7, 16, 192, 81)
# selected elements: 1731
# ------------
# cluster= 52
# amplitude= 0.29253224916396225 idx= (7, 14, 64, 94)
# selected elements: 638
# ------------
# cluster= 53
# amplitude= 0.29096409866125805 idx= (9, 16, 101, 117)
# selected elements: 15137
# ------------
# cluster= 54
# amplitude= 0.28337130862800847 idx= (5, 9, 73, 104)
# selected elements: 1032
# ------------
# cluster= 55
# amplitude= 0.28234339055003316 idx= (5, 3, 49, 114)
# selected elements: 2238
# ------------
# cluster= 56
# amplitude= 0.2815822443097733 idx= (4, 7, 156, 68)
# selected elements: 1814
# ------------
# cluster= 57
# amplitude= 0.28047130260997827 idx= (3, 15, 162, 75)
# selected elements: 1823
# ------------
# cluster= 58
# amplitude= 0.28031429588432694 idx= (3, 4, 140, 103)
# selected elements: 1532
# ------------
# cluster= 59
# amplitude= 0.277547090076265 idx= (10, 11, 276, 134)
# selected elements: 1568
# ------------
# cluster= 60
# amplitude= 0.27484652318073793 idx= (4, 5, 189, 115)
# selected elements: 4159
# ------------
# cluster= 61
# amplitude= 0.27360922638925633 idx= (4, 1, 48, 123)
# selected elements: 5569
# ------------
# cluster= 62
# amplitude= 0.2713195032747061 idx= (1, 7, 179, 31)
# selected elements: 4217
# ------------
# cluster= 63
# amplitude= 0.26403579034370467 idx= (1, 4, 78, 99)
# selected elements: 5018
# ------------
# cluster= 64
# amplitude= 0.26224408741807886 idx= (4, 6, 288, 34)
# selected elements: 9323
# ------------
# cluster= 65
# amplitude= 0.260414750586672 idx= (2, 3, 203, 86)
# selected elements: 12588
# ------------
# cluster= 66
# amplitude= 0.26037069280481234 idx= (3, 10, 125, 78)
# selected elements: 1875
# ------------
# cluster= 67
# amplitude= 0.25964317860420694 idx= (2, 8, 152, 95)
# selected elements: 5406
# ------------
# cluster= 68
# amplitude= 0.2582224478875309 idx= (13, 8, 229, 11)
# selected elements: 2382
# ------------
# cluster= 69
# amplitude= 0.25692813397616937 idx= (13, 1, 25, 119)
# selected elements: 4569
# ------------
# cluster= 70
# amplitude= 0.256548154452872 idx= (14, 9, 164, 148)
# selected elements: 368
# ------------
# cluster= 71
# amplitude= 0.25634524785459356 idx= (3, 15, 195, 105)
# selected elements: 1515
# ------------
# cluster= 72
# amplitude= 0.25554594318234974 idx= (9, 0, 209, 103)
# selected elements: 7522
# ------------
# cluster= 73
# amplitude= 0.25551992781351346 idx= (0, 1, 65, 45)
# selected elements: 4812
# ------------
# cluster= 74
# amplitude= 0.2549871598553237 idx= (2, 14, 165, 77)
# selected elements: 698
# ------------
# cluster= 75
# amplitude= 0.25407543816839384 idx= (1, 5, 89, 17)
# selected elements: 5538
# ------------
# cluster= 76
# amplitude= 0.2539679381270547 idx= (8, 2, 79, 36)
# selected elements: 1574
# ------------
# cluster= 77
# amplitude= 0.2532041673005213 idx= (3, 6, 151, 47)
# selected elements: 2300
# ------------
# cluster= 78
# amplitude= 0.2530426461412684 idx= (3, 13, 103, 71)
# selected elements: 3104
# ------------
# cluster= 79
# amplitude= 0.25118990790737505 idx= (3, 9, 104, 90)
# selected elements: 2036
# ------------
# cluster= 80
# amplitude= 0.2500993917502038 idx= (5, 7, 153, 45)
# selected elements: 1504
# ------------
# cluster= 81
# amplitude= 0.249731735837463 idx= (14, 8, 256, 56)
# selected elements: 2734
# ------------
# cluster= 82
# amplitude= 0.24829135886419015 idx= (3, 9, 80, 60)
# selected elements: 9131
# ------------
# cluster= 83
# amplitude= 0.24701340492777796 idx= (10, 2, 185, 65)
# selected elements: 3660
# ------------
# cluster= 84
# amplitude= 0.2458339101749339 idx= (11, 11, 63, 96)
# selected elements: 1484
# ------------
# cluster= 85
# amplitude= 0.2428128398143983 idx= (4, 7, 227, 104)
# selected elements: 1852
# ------------
# cluster= 86
# amplitude= 0.24266031913959918 idx= (5, 2, 85, 72)
# selected elements: 164
# ------------
# cluster= 87
# amplitude= 0.24233648397605728 idx= (13, 0, 309, 136)
# selected elements: 18852
# ------------
# cluster= 88
# amplitude= 0.24201167046116068 idx= (7, 7, 186, 119)
# selected elements: 658
# ------------
# cluster= 89
# amplitude= 0.24170016216855625 idx= (13, 0, 194, 74)
# selected elements: 1020
# ------------
# cluster= 90
# amplitude= 0.24151010885312987 idx= (2, 2, 12, 112)
# selected elements: 1714
# ------------
# cluster= 91
# amplitude= 0.24128850316487024 idx= (4, 5, 139, 78)
# selected elements: 1683
# ------------
# cluster= 92
# amplitude= 0.24077465804360293 idx= (6, 6, 216, 90)
# selected elements: 1577
# ------------
# cluster= 93
# amplitude= 0.23933807388094952 idx= (8, 5, 99, 86)
# selected elements: 1889
# ------------
# cluster= 94
# amplitude= 0.2385680826072571 idx= (8, 4, 210, 84)
# selected elements: 4666
# ------------
# cluster= 95
# amplitude= 0.23649330610804592 idx= (7, 1, 117, 80)
# selected elements: 2379
# ------------
# cluster= 96
# amplitude= 0.2359044552447399 idx= (13, 8, 31, 145)
# selected elements: 670
# ------------
# cluster= 97
# amplitude= 0.23496792355990612 idx= (6, 4, 125, 128)
# selected elements: 8910
# ------------
# cluster= 98
# amplitude= 0.2345516536830293 idx= (4, 16, 160, 76)
# selected elements: 422
# ------------
# cluster= 99
# amplitude= 0.23426999856958303 idx= (10, 5, 180, 131)
# selected elements: 5013
# ------------
# cluster= 100
# amplitude= 0.23404891731484045 idx= (1, 10, 162, 80)
# selected elements: 326
# ------------
# cluster= 101
# amplitude= 0.2321237454103024 idx= (10, 7, 144, 27)
# selected elements: 1283
# ------------
# cluster= 102
# amplitude= 0.23082648258916133 idx= (7, 11, 146, 27)
# selected elements: 897
# ------------
# cluster= 103
# amplitude= 0.2307165122430266 idx= (1, 9, 185, 76)
# selected elements: 649
# ------------
# cluster= 104
# amplitude= 0.23046931141014934 idx= (2, 12, 213, 101)
# selected elements: 1585
# ------------
# cluster= 105
# amplitude= 0.22953891382848754 idx= (8, 11, 86, 68)
# selected elements: 2146
# ------------
# cluster= 106
# amplitude= 0.22909961158862077 idx= (7, 7, 145, 27)
# selected elements: 560
# ------------
# cluster= 107
# amplitude= 0.22773545935062767 idx= (6, 1, 51, 126)
# selected elements: 507
# ------------
# cluster= 108
# amplitude= 0.22674607129369306 idx= (3, 4, 97, 140)
# selected elements: 3675
# ------------
# cluster= 109
# amplitude= 0.2266767348235522 idx= (7, 0, 90, 133)
# selected elements: 2200
# ------------
# cluster= 110
# amplitude= 0.22551407260043324 idx= (4, 11, 114, 110)
# selected elements: 287
# ------------
# cluster= 111
# amplitude= 0.22485009403982456 idx= (0, 11, 183, 76)
# selected elements: 198
# ------------
# cluster= 112
# amplitude= 0.22484708175903906 idx= (1, 9, 215, 63)
# selected elements: 585
# ------------
# cluster= 113
# amplitude= 0.22446573997911873 idx= (13, 17, 70, 112)
# selected elements: 1768
# ------------
# cluster= 114
# amplitude= 0.224308153644484 idx= (10, 1, 180, 134)
# selected elements: 15069
# ------------
# cluster= 115
# amplitude= 0.22382332218428355 idx= (12, 5, 130, 121)
# selected elements: 2008
# ------------
# cluster= 116
# amplitude= 0.22369114288507502 idx= (7, 1, 153, 74)
# selected elements: 2072
# ------------
# cluster= 117
# amplitude= 0.22320438986665125 idx= (15, 9, 306, 59)
# selected elements: 3004
# ------------
# cluster= 118
# amplitude= 0.22276239792931835 idx= (8, 13, 176, 137)
# selected elements: 731
# ------------
# cluster= 119
# amplitude= 0.22207295431167318 idx= (5, 15, 232, 95)
# selected elements: 1322
# ------------
# cluster= 120
# amplitude= 0.22204156115120044 idx= (11, 6, 97, 80)
# selected elements: 1301
# ------------
# cluster= 121
# amplitude= 0.22203824835092956 idx= (4, 10, 99, 142)
# selected elements: 622
# ------------
# cluster= 122
# amplitude= 0.22156987881472026 idx= (0, 3, 61, 94)
# selected elements: 1564
# ------------
# cluster= 123
# amplitude= 0.2212618333201625 idx= (9, 8, 65, 137)
# selected elements: 3370
# ------------
# cluster= 124
# amplitude= 0.22096479144524675 idx= (15, 0, 190, 131)
# selected elements: 1828
# ------------
# cluster= 125
# amplitude= 0.22066246015237648 idx= (14, 17, 310, 137)
# selected elements: 5768
# ------------
# cluster= 126
# amplitude= 0.2200030908802821 idx= (1, 11, 204, 112)
# selected elements: 293
# ------------
# cluster= 127
# amplitude= 0.2198651502976577 idx= (9, 4, 179, 135)
# selected elements: 1215
# ------------
# cluster= 128
# amplitude= 0.21929335732013924 idx= (4, 1, 22, 130)
# selected elements: 718
# ------------
# cluster= 129
# amplitude= 0.21836926956998934 idx= (9, 5, 271, 16)
# selected elements: 22537
# ------------
# cluster= 130
# amplitude= 0.21805945316416905 idx= (2, 1, 55, 50)
# selected elements: 768
# ------------
# cluster= 131
# amplitude= 0.21791158778132755 idx= (10, 7, 205, 72)
# selected elements: 468
# ------------
# cluster= 132
# amplitude= 0.21749807783940023 idx= (11, 16, 188, 135)
# selected elements: 884
# ------------
# cluster= 133
# amplitude= 0.21738074025597004 idx= (0, 8, 163, 94)
# selected elements: 817
# ------------
# cluster= 134
# amplitude= 0.2169210312634768 idx= (4, 0, 57, 57)
# selected elements: 171
# ------------
# cluster= 135
# amplitude= 0.21564535262272302 idx= (10, 4, 78, 138)
# selected elements: 1389
# ------------
# cluster= 136
# amplitude= 0.21480695376636652 idx= (2, 2, 23, 129)
# selected elements: 957
# ------------
# cluster= 137
# amplitude= 0.21468298208440564 idx= (12, 5, 182, 126)
# selected elements: 1552
# ------------
# cluster= 138
# amplitude= 0.213551839774513 idx= (6, 4, 234, 61)
# selected elements: 10782
# ------------
# cluster= 139
# amplitude= 0.21341197391648345 idx= (15, 9, 318, 7)
# selected elements: 8198
# ------------
# cluster= 140
# amplitude= 0.2118322324884434 idx= (1, 11, 70, 86)
# selected elements: 2077
# ------------
# cluster= 141
# amplitude= 0.21160344255086158 idx= (7, 11, 278, 139)
# selected elements: 2695
# ------------
# cluster= 142
# amplitude= 0.2112803658196391 idx= (3, 12, 114, 110)
# selected elements: 272
# ------------
# cluster= 143
# amplitude= 0.21091853403798566 idx= (4, 11, 169, 142)
# selected elements: 447
# ------------
# cluster= 144
# amplitude= 0.2104979146600231 idx= (2, 4, 149, 74)
# selected elements: 2831
# ------------
# cluster= 145
# amplitude= 0.20940648227531505 idx= (6, 3, 52, 74)
# selected elements: 2008
# ------------
# cluster= 146
# amplitude= 0.20874162888924036 idx= (3, 2, 65, 137)
# selected elements: 2636
# ------------
# cluster= 147
# amplitude= 0.20819392040815923 idx= (3, 12, 238, 103)
# selected elements: 1040
# ------------
# cluster= 148
# amplitude= 0.20769175908080192 idx= (4, 2, 115, 81)
# selected elements: 886
# ------------
# cluster= 149
# amplitude= 0.20744514447756163 idx= (9, 16, 145, 81)
# selected elements: 667
# ------------
# cluster= 150
# amplitude= 0.20729892911659212 idx= (5, 16, 97, 129)
# selected elements: 2555
# ------------
# cluster= 151
# amplitude= 0.20729673732664203 idx= (3, 8, 212, 65)
# selected elements: 1153
# ------------
# cluster= 152
# amplitude= 0.20723691113966017 idx= (14, 3, 100, 135)
# selected elements: 509
# ------------
# cluster= 153
# amplitude= 0.20697432862190163 idx= (13, 10, 293, 139)
# selected elements: 2726
# ------------
# cluster= 154
# amplitude= 0.20546758204518667 idx= (0, 13, 157, 61)
# selected elements: 185
# ------------
# cluster= 155
# amplitude= 0.20508649012562766 idx= (4, 9, 207, 42)
# selected elements: 1547
# ------------
# cluster= 156
# amplitude= 0.20505472512202746 idx= (6, 3, 167, 49)
# selected elements: 6324
# ------------
# cluster= 157
# amplitude= 0.20489401664307133 idx= (7, 14, 101, 52)
# selected elements: 1652
# ------------
# cluster= 158
# amplitude= 0.20470801615289883 idx= (4, 1, 92, 124)
# selected elements: 4681
# ------------
# cluster= 159
# amplitude= 0.2044106386433461 idx= (12, 3, 227, 65)
# selected elements: 3056
# ------------
# cluster= 160
# amplitude= 0.20409015901386135 idx= (7, 11, 289, 119)
# selected elements: 3115
# ------------
# cluster= 161
# amplitude= 0.20405773557080564 idx= (15, 14, 98, 28)
# selected elements: 3443
# ------------
# cluster= 162
# amplitude= 0.20378444442392224 idx= (1, 3, 200, 103)
# selected elements: 743
# ------------
# cluster= 163
# amplitude= 0.2025696866375832 idx= (14, 9, 300, 141)
# selected elements: 3974
# ------------
# cluster= 164
# amplitude= 0.20235931940240076 idx= (4, 8, 122, 78)
# selected elements: 835
# ------------
# cluster= 165
# amplitude= 0.20072934598876624 idx= (3, 8, 184, 59)
# selected elements: 393
# ------------
# cluster= 166
# amplitude= 0.20063140727868717 idx= (6, 5, 173, 49)
# selected elements: 1168
# ------------
# cluster= 167
# amplitude= 0.20052944856757063 idx= (8, 12, 133, 97)
# selected elements: 137
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 91.02it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=3600:4200  ext=3550:4250  saved to outputs_decompose2d_slices_single/offset_0000/xcore_03600_04200_xext_03550_04250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.36295745893201914 idx= (10, 11, 122, 50)
# selected elements: 106611
# ------------
# cluster= 1
# amplitude= 0.2587942949206798 idx= (11, 13, 94, 104)
# selected elements: 63824
# ------------
# cluster= 2
# amplitude= 0.2512568020151063 idx= (15, 10, 248, 33)
# selected elements: 30997
# ------------
# cluster= 3
# amplitude= 0.24700474071253775 idx= (14, 14, 154, 117)
# selected elements: 22860
# ------------
# cluster= 4
# amplitude= 0.23663224259883173 idx= (9, 10, 151, 120)
# selected elements: 26145
# ------------
# cluster= 5
# amplitude= 0.23497265687626837 idx= (15, 16, 116, 74)
# selected elements: 7287
# ------------
# cluster= 6
# amplitude= 0.23491065743813092 idx= (15, 14, 40, 64)
# selected elements: 16096
# ------------
# cluster= 7
# amplitude= 0.21934395871271822 idx= (14, 9, 193, 6)
# selected elements: 51661
# ------------
# cluster= 8
# amplitude= 0.21592070666663998 idx= (11, 11, 60, 14)
# selected elements: 13768
# ------------
# cluster= 9
# amplitude= 0.21406074909044467 idx= (9, 10, 108, 111)
# selected elements: 3169
# ------------
# cluster= 10
# amplitude= 0.20911530968028133 idx= (14, 13, 41, 60)
# selected elements: 2589
# ------------
# cluster= 11
# amplitude= 0.2071931892453781 idx= (13, 15, 120, 72)
# selected elements: 3056
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 92.27it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=4200:4800  ext=4150:4850  saved to outputs_decompose2d_slices_single/offset_0000/xcore_04200_04800_xext_04150_04850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.48it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=4800:5400  ext=4750:5450  saved to outputs_decompose2d_slices_single/offset_0000/xcore_04800_05400_xext_04750_05450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 91.92it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=5400:5451  ext=5350:5451  saved to outputs_decompose2d_slices_single/offset_0000/xcore_05400_05451_xext_05350_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 97.21it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Done. Outputs in /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_decompose2d_slices_single/offset_0000

# %% [markdown]
# ## One way of slicing, applying noise filtering.

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Dict, Any, List

import copy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

try:
    from scipy import stats
except Exception:
    stats = None

# --------------------------
# User params
# --------------------------
FILE_PATH = "awe_l5c_q20_2024165T2120_03175_v01.nc"
FRAME_IDX = 0

# Slicing on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)
SLICE_PAD = 50  # extend each slice by this many UNBINNED pixels on each side

# Choose ONE slicing offset (no comparisons)
X_OFFSET = 0  # set to 0 or 300 or whatever you want

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 24
JT = 18
ASPECT = 1

# Pixel spacing (km per pixel)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Red noise style filtering (robust WPS thresholding per scale)
APPLY_RED_NOISE_FILTER = True

# Optional diagnostics output from the red noise filter
SAVE_REDNOISE_DIAGNOSTICS = True

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices_single_noise_filtering_q20")
SAVE_DPI = 200

# --------------------------
# Parameter runs (edit this list)
# --------------------------
RUNS: List[Dict[str, Any]] = [
    dict(
        name="amp0p15",
        MIN_AMP=0.15,
        THR=0.1,
        WHITE_NOISE_THRESHOLD=0.03,
        WPS_NOISE_THRESHOLD=8.0,
    ),
    dict(
        name="amp0p2(base)",
        MIN_AMP=0.2,
        THR=0.1,
        WHITE_NOISE_THRESHOLD=0.03,
        WPS_NOISE_THRESHOLD=8.0,
    ),
    dict(
        name="amp0p25",
        MIN_AMP=0.25,
        THR=0.1,
        WHITE_NOISE_THRESHOLD=0.03,
        WPS_NOISE_THRESHOLD=8.0,
    ),
    dict(
        name="wnoisep01",
        MIN_AMP=0.2,
        THR=0.1,
        WHITE_NOISE_THRESHOLD=0.01,
        WPS_NOISE_THRESHOLD=8.0,
    ),
        dict(
        name="rednoise4",
        MIN_AMP=0.2,
        THR=0.1,
        WHITE_NOISE_THRESHOLD=0.03,
        WPS_NOISE_THRESHOLD=4.0,
    ),
]

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Small helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def diverging_limits(*arrays: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    vals = []
    for A in arrays:
        if A is None:
            continue
        a = np.asarray(A)
        good = np.isfinite(a)
        if np.any(good):
            vals.append(a[good].ravel())
    if not vals:
        return (-1.0, 1.0)
    stacked = np.concatenate(vals)
    lo, hi = np.nanpercentile(stacked, [p_lo, p_hi])
    vmax = max(abs(lo), abs(hi))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    return (-vmax, vmax)


# --------------------------
# Data helpers
# --------------------------
def read_radiance_frame(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        rad = nc.variables["Radiance"][:]  # (t, y, x)
    if rad.ndim != 3:
        raise ValueError(f"Temperature expected 3D (t,y,x); got {rad.shape}")
    if not (0 <= frame_idx < rad.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{rad.shape[0]-1}")
    return np.asarray(rad[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    return np.cos(theta_xy), np.sin(theta_xy)


# --------------------------
# Red noise style filtering helper
# --------------------------
def apply_red_noise_filter_cwt(
    cwt: dict,
    white_noise_threshold: float = 0.1,
    wps_noise_threshold: float = 8.0,
) -> Tuple[dict, Dict[str, Any]]:
    """
    Robust per scale WPS filtering.

    Returns filtered_cwt (deep copy) and a small diagnostics dict.
    """
    diag: Dict[str, Any] = {}
    if stats is None:
        diag["skipped"] = True
        diag["reason"] = "scipy not available"
        return cwt, diag

    cwt_copy = copy.deepcopy(cwt)
    dec = cwt_copy["decomposition"]  # (ns, nt, nx, ny) complex

    WPS0 = np.abs(dec) ** 2
    diag["n_coeff_total"] = int(WPS0.size)

    mask_1 = WPS0 < (float(white_noise_threshold) ** 2)
    dec[mask_1] = 0

    WPS1 = np.abs(dec) ** 2
    diag["n_zero_after_white"] = int(np.count_nonzero(WPS1 == 0))

    median_WPS = np.median(WPS1, axis=(1, 2, 3))  # (ns,)
    mad = stats.median_abs_deviation(WPS1, axis=(1, 2, 3), scale=1.0)  # (ns,)
    sMAD_WPS = 1.4826 * mad

    sMAD_safe = np.where(sMAD_WPS > 0, sMAD_WPS, np.nan)
    WPS_scaled = (WPS1 - median_WPS[:, None, None, None]) / sMAD_safe[:, None, None, None]

    mask = WPS_scaled < float(wps_noise_threshold)
    dec[mask] = 0

    WPS2 = np.abs(dec) ** 2
    diag["n_zero_after_scaled"] = int(np.count_nonzero(WPS2 == 0))

    finite_scaled = np.isfinite(WPS_scaled)

    diag["sMAD_min"] = float(np.nanmin(sMAD_WPS))
    diag["sMAD_median"] = float(np.nanmedian(sMAD_WPS))

    if np.any(finite_scaled):
        diag["WPS_scaled_min"] = float(np.nanmin(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_median"] = float(np.nanmedian(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_max"] = float(np.nanmax(WPS_scaled[finite_scaled]))
    else:
        diag["WPS_scaled_min"] = np.nan
        diag["WPS_scaled_median"] = np.nan
        diag["WPS_scaled_max"] = np.nan

    return cwt_copy, diag


# --------------------------
# Quicklook plots
# --------------------------
def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("Radiance (arb)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
    wavy_after_noise_xy: np.ndarray | None = None,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    arrays = [orig_c, bg_c, rem_c, rem_tapered_c]
    if wavy_after_noise_xy is not None:
        arrays.append(wavy_after_noise_xy)

    vmin, vmax = diverging_limits(*arrays, p_lo=1, p_hi=99)

    fig, axs = plt.subplots(2, 3, figsize=(16, 10), constrained_layout=True)
    axs = axs.flatten()

    panels = [
        (orig_c, "Original (median sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    if wavy_after_noise_xy is not None:
        panels.append((wavy_after_noise_xy, "Wavy stuff (wavelet reconstruction after noise filtering)"))

    im0 = None
    for ax, (Z, title) in zip(axs, panels):
        im0 = ax.pcolormesh(
            x1d_km, y1d_km, Z,
            shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    for ax in axs[len(panels):]:
        ax.axis("off")

    cbar = fig.colorbar(im0, ax=axs[:len(panels)], orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("Radiance (arb)")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2
    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])
        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_vmin, bg_vmax = diverging_limits(bg_xy, p_lo=2, p_hi=98)
    cl_vmin, cl_vmax = diverging_limits(rec_xy, p_lo=2, p_hi=98)

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if (not np.isfinite(lam_vmin)) or (not np.isfinite(lam_vmax)) or (lam_vmin == lam_vmax):
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n"
            + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        arrow_len_km = 40.0
        u = u * arrow_len_km
        v = v * arrow_len_km

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)


# --------------------------
# Slice pipeline
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
    cfg: Dict[str, Any],
) -> Dict[str, Any]:
    """
    Runs processing on an extended slice (x_slice),
    but returns only CORE tiles for stitching.

    Step 08 (power) intentionally removed.

    Figure 1 includes extra panel: wavelet reconstruction after noise filtering.
    Figure 9 has 3 panels:
      Remaining (input to CWT)
      Wavy reconstruction after noise filtering
      Reconstruction after clustering (all clusters)
    """
    outdir.mkdir(parents=True, exist_ok=True)

    min_amp = float(cfg.get("MIN_AMP"))
    thr = float(cfg.get("THR"))
    white_noise_threshold = float(cfg.get("WHITE_NOISE_THRESHOLD"))
    wps_noise_threshold = float(cfg.get("WPS_NOISE_THRESHOLD"))
    run_name = str(cfg.get("name", "run"))

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        f = int(BIN_FACTOR)
        dx_km = DX_KM_BASE * f
        dy_km = DY_KM_BASE * f
    else:
        f = 1
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f
    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    raw_win = np.asarray(rad2d_flat[Y_SLICE, x_slice], dtype=float)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"Temperature (window, flattened){bin_tag}\n{run_name} MIN_AMP={min_amp} THR={thr}",
        outdir / "00_temperature_window.png",
    )

    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt_raw = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    if APPLY_RED_NOISE_FILTER:
        cwt, diag = apply_red_noise_filter_cwt(
            cwt_raw,
            white_noise_threshold=white_noise_threshold,
            wps_noise_threshold=wps_noise_threshold,
        )
        if SAVE_REDNOISE_DIAGNOSTICS:
            lines = []
            lines.append("Red noise filter diagnostics\n\n")
            lines.append(f"name                = {run_name}\n")
            lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
            lines.append(f"WPS_NOISE_THRESHOLD   = {wps_noise_threshold}\n\n")
            if diag.get("skipped", False):
                lines.append(f"SKIPPED: {diag.get('reason','unknown')}\n")
            else:
                lines.append(f"n_coeff_total        = {diag.get('n_coeff_total')}\n")
                lines.append(f"n_zero_after_white   = {diag.get('n_zero_after_white')}\n")
                lines.append(f"n_zero_after_scaled  = {diag.get('n_zero_after_scaled')}\n")
                lines.append(f"sMAD_WPS min         = {diag.get('sMAD_min')}\n")
                lines.append(f"sMAD_WPS median      = {diag.get('sMAD_median')}\n")
                lines.append(f"WPS_scaled min       = {diag.get('WPS_scaled_min')}\n")
                lines.append(f"WPS_scaled median    = {diag.get('WPS_scaled_median')}\n")
                lines.append(f"WPS_scaled max       = {diag.get('WPS_scaled_max')}\n")
            (outdir / "02a_rednoise_diagnostics.txt").write_text("".join(lines))
    else:
        cwt = cwt_raw

    rec_wavy = transform.reconstruct2d(cwt)  # (nx, ny)
    wavy_xy = rec_wavy.T - np.median(rec_wavy)

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_5panel.png",
        wavy_after_noise_xy=wavy_xy,
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=min_amp, thr=thr)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N
    )
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text(
            "No clusters found.\n\n"
            f"Run name: {run_name}\n"
            f"Used MIN_AMP={min_amp}, THR={thr}\n"
            f"Used WHITE_NOISE_THRESHOLD={white_noise_threshold}, WPS_NOISE_THRESHOLD={wps_noise_threshold}\n\n"
            "Try lowering MIN_AMP or THR.\n"
            "If red noise filter is on, try lowering WPS_NOISE_THRESHOLD or WHITE_NOISE_THRESHOLD.\n"
        )
        remaining_core_xy = crop_pad_core(proc)
        nan_core = np.full_like(remaining_core_xy, np.nan)
        return {
            "has_clusters": False,
            "x_start_unbinned": core_start_unbinned,
            "dx_km": dx_km,
            "dy_km": dy_km,
            "remaining_xy": remaining_core_xy,
            "wavy_xy": nan_core,
            "rec_all_xy": nan_core,
        }

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    lines = []
    lines.append("Cluster power ranking (clustered only)\n\n")
    lines.append(f"name = {run_name}\n")
    lines.append(f"MIN_AMP = {min_amp}\n")
    lines.append(f"THR = {thr}\n")
    lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
    lines.append(f"WPS_NOISE_THRESHOLD = {wps_noise_threshold}\n\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))
    theta_vals = np.asarray(cwt["theta"], dtype=float)

    def plot_cluster_grid(kind: str, outname: str) -> None:
        fig, axs = plt.subplots(nrow, ncol, figsize=(12, 10))
        axs = np.atleast_1d(axs).reshape(-1)

        bg_vmin, bg_vmax = diverging_limits(bg, p_lo=2, p_hi=98)
        number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}

        for ax, kcl in zip(axs, biggest):
            decomposition[:] = orig_decomp
            decomposition[iwave != kcl] = 0
            rec = transform.reconstruct2d(cwt)
            rec_centered = rec.T - np.median(rec)

            s_idx = int(idxs[kcl][0])
            t_idx = int(idxs[kcl][1])
            _, _, lam = effective_lambda(cwt, s_idx, t_idx)

            theta_dom_rad = float(theta_vals[t_idx])
            theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

            ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
            Pk = float(P_abs_sorted[ii])
            pk = float(P_pct_sorted[ii])

            if kind == "standalone":
                ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0)
            elif kind == "overlay":
                ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
                ax.pcolormesh(
                    x1d_km, y1d_km, rec_centered,
                    shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0, alpha=0.6
                )
            else:
                raise ValueError(kind)

            ax.set_title(
                rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
                + "\n"
                + rf"P={Pk:.2e} ({pk:.1f}%)"
            )
            ax.set_aspect("equal", adjustable="box")

        for ax in axs[n_show:]:
            ax.axis("off")
        for ax in axs[:n_show]:
            ax.set_xlabel("x (km)")
            ax.set_ylabel("y (km)")

        for i, ax in enumerate(axs, start=1):
            if ax.has_data():
                ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

        fig.tight_layout()
        save_fig(fig, outdir / outname)

    plot_cluster_grid("standalone", "05_clusters_standalone.png")
    plot_cluster_grid("overlay", "06_clusters_overlay.png")

    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
        )

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)
    decomposition[:] = orig_decomp

    remaining_after_preproc_xy = proc
    vmin, vmax = diverging_limits(remaining_after_preproc_xy, wavy_xy, rec_all_xy, p_lo=2, p_hi=98)

    figR, (ax1, ax2, ax3) = plt.subplots(
        3, 1, figsize=(18, 8), constrained_layout=True, sharex=True, sharey=True
    )

    im1 = ax1.pcolormesh(
        x1d_km, y1d_km, remaining_after_preproc_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    ax1.set_title("Remaining (after preprocessing, input to CWT)")
    ax1.set_xlabel("x (km)")
    ax1.set_ylabel("y (km)")
    ax1.set_aspect("equal", adjustable="box")

    im2 = ax2.pcolormesh(
        x1d_km, y1d_km, wavy_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    ax2.set_title("Wavy stuff (wavelet reconstruction after noise filtering)")
    ax2.set_xlabel("x (km)")
    ax2.set_ylabel("y (km)")
    ax2.set_aspect("equal", adjustable="box")

    im3 = ax3.pcolormesh(
        x1d_km, y1d_km, rec_all_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    ax3.set_title("Reconstruction after clustering (all clusters combined)")
    ax3.set_xlabel("x (km)")
    ax3.set_ylabel("y (km)")
    ax3.set_aspect("equal", adjustable="box")

    cbar = figR.colorbar(im1, ax=[ax1, ax2, ax3], orientation="vertical", fraction=0.015, pad=0.01)
    cbar.set_label("arb")
    save_fig(figR, outdir / "09_remaining_vs_wavy_vs_allclusters.png")

    remaining_core_xy = crop_pad_core(remaining_after_preproc_xy)
    wavy_core_xy = crop_pad_core(wavy_xy)
    rec_all_core_xy = crop_pad_core(rec_all_xy)

    return {
        "has_clusters": True,
        "x_start_unbinned": core_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "remaining_xy": remaining_core_xy,
        "wavy_xy": wavy_core_xy,
        "rec_all_xy": rec_all_core_xy,
    }


def stitch_and_save_final_09(slice_results: List[Dict[str, Any]], outroot: Path, tag: str) -> None:
    if not slice_results:
        return

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE

    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    wavy_stitched = np.concatenate([d["wavy_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)

    ny, nx_tot = remaining_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    vmin, vmax = diverging_limits(remaining_stitched, wavy_stitched, rec_all_stitched, p_lo=2, p_hi=98)

    figR, (axT, axM, axB) = plt.subplots(
        3, 1, figsize=(18, 6), constrained_layout=True, sharex=True, sharey=True
    )

    imT = axT.pcolormesh(
        x1d_km, y1d_km, remaining_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axT.set_title(f"STITCHED (core tiles) {tag}: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imM = axM.pcolormesh(
        x1d_km, y1d_km, wavy_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axM.set_title(f"STITCHED (core tiles) {tag}: Wavy stuff (wavelet reconstruction after noise filtering)")
    axM.set_xlabel("x (km)")
    axM.set_ylabel("y (km)")
    axM.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(
        x1d_km, y1d_km, rec_all_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axB.set_title(f"STITCHED (core tiles) {tag}: Reconstruction after clustering (all clusters combined)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    axT.set_xlim(600, 10000)

    cbar = figR.colorbar(imT, ax=[axT, axM, axB], orientation="vertical", fraction=0.012, pad=0.01)
    cbar.set_label("kRayleigh (Relative)")
    save_fig(figR, outroot / f"FINAL_09_remaining_vs_wavy_vs_allclusters_STITCHED_{tag}.png")


def run_all_slices_single_offset(cfg: Dict[str, Any]) -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_radiance_frame(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    x_offset = int(X_OFFSET)
    if x_offset >= nx_total:
        raise ValueError(f"X_OFFSET={x_offset} too large for nx_total={nx_total}")

    run_name = str(cfg.get("name", "run"))
    outroot = OUTPUT_ROOT / f"{run_name}_offset_{x_offset:04d}"
    outroot.mkdir(parents=True, exist_ok=True)

    (outroot / "RUN_CONFIG.txt").write_text("\n".join([f"{k} = {v}" for k, v in cfg.items()]) + "\n")

    core_starts = list(range(x_offset, nx_total, X_CHUNK))
    stitch_results: List[Dict[str, Any]] = []

    for core_start in core_starts:
        core_end = min(core_start + X_CHUNK, nx_total)

        ext_start = max(0, core_start - SLICE_PAD)
        ext_end = min(nx_total, core_end + SLICE_PAD)
        x_slice = slice(ext_start, ext_end)

        outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
        print(f"[{run_name} | offset {x_offset}] core={core_start}:{core_end} ext={ext_start}:{ext_end} saved to {outdir}")

        res = run_pipeline_for_slice(
            rad2d_flat=rad2d_flat,
            x_slice=x_slice,
            outdir=outdir,
            x_start_unbinned=ext_start,
            core_start_unbinned=core_start,
            core_end_unbinned=core_end,
            cfg=cfg,
        )
        stitch_results.append(res)

    stitch_and_save_final_09(stitch_results, outroot, tag=f"{run_name}_offset_{x_offset:04d}")
    print("Done. Outputs in", outroot.resolve())


for cfg in RUNS:
    run_all_slices_single_offset(cfg)
# Out:
# [amp0p15 | offset 0] core=0:600 ext=0:650 saved to outputs_decompose2d_slices_single_noise_filtering_q20/amp0p15_offset_0000/xcore_00000_00600_xext_00000_00650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.4215471455347078 idx= (21, 8, 224, 80)
# selected elements: 377389
# ------------
# cluster= 1
# amplitude= 0.37108038888739175 idx= (12, 9, 308, 58)
# selected elements: 117529
# ------------
# cluster= 2
# amplitude= 0.3444417504565404 idx= (13, 9, 205, 118)
# selected elements: 64323
# ------------
# cluster= 3
# amplitude= 0.31221373851265266 idx= (12, 7, 256, 71)
# selected elements: 31493
# ------------
# cluster= 4
# amplitude= 0.30603962397346623 idx= (10, 9, 255, 78)
# selected elements: 15592
# ------------
# cluster= 5
# amplitude= 0.29479282740050067 idx= (17, 8, 212, 118)
# selected elements: 7231
# ------------
# cluster= 6
# amplitude= 0.2759813435543466 idx= (5, 7, 274, 60)
# selected elements: 10614
# ------------
# cluster= 7
# amplitude= 0.26529812480818515 idx= (5, 10, 197, 116)
# selected elements: 1744
# ------------
# cluster= 8
# amplitude= 0.2641272551147941 idx= (23, 15, 308, 43)
# selected elements: 32632
# ------------
# cluster= 9
# amplitude= 0.2613101033353235 idx= (22, 6, 256, 73)
# selected elements: 17577
# ------------
# cluster= 10
# amplitude= 0.2586889237913039 idx= (11, 12, 285, 58)
# selected elements: 6338
# ------------
# cluster= 11
# amplitude= 0.24621886606577267 idx= (9, 10, 159, 36)
# selected elements: 20461
# ------------
# cluster= 12
# amplitude= 0.24562374245607355 idx= (21, 10, 155, 61)
# selected elements: 9875
# ------------
# cluster= 13
# amplitude= 0.2329343785295034 idx= (22, 11, 221, 127)
# selected elements: 14023
# ------------
# cluster= 14
# amplitude= 0.21768271772666328 idx= (5, 10, 199, 29)
# selected elements: 6779
# ------------
# cluster= 15
# amplitude= 0.21603170255806087 idx= (19, 10, 158, 50)
# selected elements: 8062
# ------------
# cluster= 16
# amplitude= 0.2125093455099971 idx= (15, 7, 243, 124)
# selected elements: 8861
# ------------
# cluster= 17
# amplitude= 0.21082208911597553 idx= (15, 13, 290, 46)
# selected elements: 6477
# ------------
# cluster= 18
# amplitude= 0.21051256241488664 idx= (14, 12, 153, 120)
# selected elements: 16267
# ------------
# cluster= 19
# amplitude= 0.20894104410732525 idx= (9, 11, 214, 57)
# selected elements: 7972
# ------------
# cluster= 20
# amplitude= 0.2085008376183357 idx= (19, 3, 302, 45)
# selected elements: 43690
# ------------
# cluster= 21
# amplitude= 0.2078033251965815 idx= (9, 10, 140, 69)
# selected elements: 14116
# ------------
# cluster= 22
# amplitude= 0.20458172379808676 idx= (18, 9, 158, 48)
# selected elements: 22681
# ------------
# cluster= 23
# amplitude= 0.1983544040178807 idx= (12, 10, 271, 110)
# selected elements: 4008
# ------------
# cluster= 24
# amplitude= 0.1933864891799075 idx= (2, 9, 218, 78)
# selected elements: 4431
# ------------
# cluster= 25
# amplitude= 0.1901451288537835 idx= (11, 8, 237, 125)
# selected elements: 4154
# ------------
# cluster= 26
# amplitude= 0.18987572796522734 idx= (12, 7, 238, 125)
# selected elements: 1295
# ------------
# cluster= 27
# amplitude= 0.18650792580903408 idx= (9, 9, 196, 25)
# selected elements: 3247
# ------------
# cluster= 28
# amplitude= 0.18579057022244996 idx= (23, 12, 164, 97)
# selected elements: 1116
# ------------
# cluster= 29
# amplitude= 0.1843983718810615 idx= (14, 9, 206, 15)
# selected elements: 9746
# ------------
# cluster= 30
# amplitude= 0.18347015789869736 idx= (13, 9, 274, 110)
# selected elements: 644
# ------------
# cluster= 31
# amplitude= 0.18161358959234392 idx= (5, 10, 134, 64)
# selected elements: 1893
# ------------
# cluster= 32
# amplitude= 0.18113579265597482 idx= (15, 6, 218, 55)
# selected elements: 8215
# ------------
# cluster= 33
# amplitude= 0.1799022911914217 idx= (11, 7, 172, 78)
# selected elements: 6107
# ------------
# cluster= 34
# amplitude= 0.1749423752673949 idx= (1, 8, 310, 57)
# selected elements: 956
# ------------
# cluster= 35
# amplitude= 0.17494226506055643 idx= (22, 14, 160, 87)
# selected elements: 6701
# ------------
# cluster= 36
# amplitude= 0.1738536795527308 idx= (7, 12, 286, 36)
# selected elements: 5063
# ------------
# cluster= 37
# amplitude= 0.17350336725567603 idx= (13, 14, 292, 50)
# selected elements: 5874
# ------------
# cluster= 38
# amplitude= 0.17269142773322282 idx= (17, 12, 267, 42)
# selected elements: 2952
# ------------
# cluster= 39
# amplitude= 0.17131461390742903 idx= (22, 4, 295, 83)
# selected elements: 1268
# ------------
# cluster= 40
# amplitude= 0.17047809877458828 idx= (23, 12, 234, 119)
# selected elements: 752
# ------------
# cluster= 41
# amplitude= 0.17010310222259512 idx= (17, 9, 301, 49)
# selected elements: 935
# ------------
# cluster= 42
# amplitude= 0.1693577322996035 idx= (6, 9, 240, 122)
# selected elements: 1498
# ------------
# cluster= 43
# amplitude= 0.1685642672563919 idx= (2, 9, 159, 70)
# selected elements: 1644
# ------------
# cluster= 44
# amplitude= 0.16712852820862767 idx= (9, 12, 289, 35)
# selected elements: 1206
# ------------
# cluster= 45
# amplitude= 0.165398923183855 idx= (12, 0, 320, 60)
# selected elements: 7731
# ------------
# cluster= 46
# amplitude= 0.1652296120191326 idx= (3, 11, 216, 64)
# selected elements: 347
# ------------
# cluster= 47
# amplitude= 0.16470671237373113 idx= (8, 12, 147, 72)
# selected elements: 1480
# ------------
# cluster= 48
# amplitude= 0.16445552140451858 idx= (8, 1, 132, 24)
# selected elements: 4235
# ------------
# cluster= 49
# amplitude= 0.1632163247703838 idx= (3, 11, 300, 49)
# selected elements: 2090
# ------------
# cluster= 50
# amplitude= 0.16270866984614774 idx= (11, 11, 168, 133)
# selected elements: 1297
# ------------
# cluster= 51
# amplitude= 0.16269346408040453 idx= (18, 10, 237, 141)
# selected elements: 3120
# ------------
# cluster= 52
# amplitude= 0.1626933664093105 idx= (13, 9, 283, 10)
# selected elements: 1745
# ------------
# cluster= 53
# amplitude= 0.16239422515614768 idx= (23, 4, 284, 90)
# selected elements: 180
# ------------
# cluster= 54
# amplitude= 0.16218713733806406 idx= (21, 17, 320, 63)
# selected elements: 814
# ------------
# cluster= 55
# amplitude= 0.16161400831212058 idx= (12, 6, 176, 53)
# selected elements: 1815
# ------------
# cluster= 56
# amplitude= 0.1612965848436449 idx= (18, 0, 317, 66)
# selected elements: 2362
# ------------
# cluster= 57
# amplitude= 0.15953450068554792 idx= (6, 11, 290, 62)
# selected elements: 1195
# ------------
# cluster= 58
# amplitude= 0.15938433749892494 idx= (8, 11, 293, 62)
# selected elements: 192
# ------------
# cluster= 59
# amplitude= 0.15879790178460293 idx= (7, 8, 200, 89)
# selected elements: 2104
# ------------
# cluster= 60
# amplitude= 0.15878905069276783 idx= (5, 10, 217, 63)
# selected elements: 184
# ------------
# cluster= 61
# amplitude= 0.15792827657919453 idx= (22, 13, 302, 50)
# selected elements: 567
# ------------
# cluster= 62
# amplitude= 0.15790618408286486 idx= (8, 10, 275, 106)
# selected elements: 1975
# ------------
# cluster= 63
# amplitude= 0.15736169559888208 idx= (8, 0, 124, 12)
# selected elements: 734
# ------------
# cluster= 64
# amplitude= 0.15666648305966305 idx= (16, 10, 286, 7)
# selected elements: 3165
# ------------
# cluster= 65
# amplitude= 0.15598444762931665 idx= (12, 10, 280, 9)
# selected elements: 1804
# ------------
# cluster= 66
# amplitude= 0.15426344086457644 idx= (22, 12, 165, 84)
# selected elements: 132
# ------------
# cluster= 67
# amplitude= 0.15425329699332296 idx= (22, 2, 321, 47)
# selected elements: 86
# ------------
# cluster= 68
# amplitude= 0.15415760577240445 idx= (21, 1, 318, 57)
# selected elements: 737
# ------------
# cluster= 69
# amplitude= 0.15330248972654054 idx= (21, 10, 293, 8)
# selected elements: 489
# ------------
# cluster= 70
# amplitude= 0.15249713427300915 idx= (9, 11, 314, 50)
# selected elements: 386
# ------------
# cluster= 71
# amplitude= 0.15088937641704522 idx= (20, 9, 293, 11)
# selected elements: 743
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 70.61it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp0p15 | offset 0] core=600:1200 ext=550:1250 saved to outputs_decompose2d_slices_single_noise_filtering_q20/amp0p15_offset_0000/xcore_00600_01200_xext_00550_01250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.48025098934026705 idx= (6, 8, 241, 25)
# selected elements: 53085
# ------------
# cluster= 1
# amplitude= 0.4728837602016013 idx= (22, 10, 223, 19)
# selected elements: 90413
# ------------
# cluster= 2
# amplitude= 0.47277683261286246 idx= (5, 9, 243, 24)
# selected elements: 5657
# ------------
# cluster= 3
# amplitude= 0.4083574722293721 idx= (8, 9, 48, 50)
# selected elements: 86925
# ------------
# cluster= 4
# amplitude= 0.4057785279312059 idx= (7, 8, 50, 51)
# selected elements: 2388
# ------------
# cluster= 5
# amplitude= 0.3804210229117072 idx= (17, 9, 247, 25)
# selected elements: 82872
# ------------
# cluster= 6
# amplitude= 0.3688470251762809 idx= (23, 7, 249, 30)
# selected elements: 40617
# ------------
# cluster= 7
# amplitude= 0.3545877295662272 idx= (20, 8, 106, 12)
# selected elements: 70475
# ------------
# cluster= 8
# amplitude= 0.33530692587411665 idx= (10, 11, 71, 43)
# selected elements: 24356
# ------------
# cluster= 9
# amplitude= 0.3333222246800942 idx= (10, 9, 199, 7)
# selected elements: 36121
# ------------
# cluster= 10
# amplitude= 0.2821105973255177 idx= (13, 12, 19, 52)
# selected elements: 25303
# ------------
# cluster= 11
# amplitude= 0.27196833062886816 idx= (9, 10, 281, 10)
# selected elements: 5890
# ------------
# cluster= 12
# amplitude= 0.2712327951515373 idx= (15, 10, 36, 58)
# selected elements: 12340
# ------------
# cluster= 13
# amplitude= 0.27121336906918136 idx= (14, 10, 111, 8)
# selected elements: 6639
# ------------
# cluster= 14
# amplitude= 0.26879217618401224 idx= (23, 7, 56, 63)
# selected elements: 5265
# ------------
# cluster= 15
# amplitude= 0.2672785109985788 idx= (22, 8, 181, 25)
# selected elements: 5792
# ------------
# cluster= 16
# amplitude= 0.2646144330380939 idx= (2, 8, 57, 53)
# selected elements: 1806
# ------------
# cluster= 17
# amplitude= 0.26058210772563656 idx= (15, 10, 159, 8)
# selected elements: 7049
# ------------
# cluster= 18
# amplitude= 0.26041055798399704 idx= (21, 11, 137, 17)
# selected elements: 14680
# ------------
# cluster= 19
# amplitude= 0.2514431142783243 idx= (18, 12, 69, 44)
# selected elements: 20815
# ------------
# cluster= 20
# amplitude= 0.24572376319830086 idx= (22, 6, 177, 43)
# selected elements: 2792
# ------------
# cluster= 21
# amplitude= 0.23954182793681061 idx= (13, 7, 161, 61)
# selected elements: 32408
# ------------
# cluster= 22
# amplitude= 0.23411610464554305 idx= (10, 9, 108, 5)
# selected elements: 5104
# ------------
# cluster= 23
# amplitude= 0.23392982975357174 idx= (23, 13, 97, 30)
# selected elements: 2306
# ------------
# cluster= 24
# amplitude= 0.23297512802025008 idx= (22, 8, 48, 62)
# selected elements: 1323
# ------------
# cluster= 25
# amplitude= 0.23283427931253153 idx= (12, 10, 109, 7)
# selected elements: 1542
# ------------
# cluster= 26
# amplitude= 0.23231672953858867 idx= (11, 8, 301, 32)
# selected elements: 11818
# ------------
# cluster= 27
# amplitude= 0.22615483351444415 idx= (23, 12, 57, 26)
# selected elements: 686
# ------------
# cluster= 28
# amplitude= 0.21858124141791535 idx= (5, 9, 128, 66)
# selected elements: 4896
# ------------
# cluster= 29
# amplitude= 0.21777447868954353 idx= (11, 7, 77, 55)
# selected elements: 7976
# ------------
# cluster= 30
# amplitude= 0.21722254978151953 idx= (21, 7, 323, 41)
# selected elements: 2143
# ------------
# cluster= 31
# amplitude= 0.21432670852758628 idx= (23, 6, 62, 42)
# selected elements: 23
# ------------
# cluster= 32
# amplitude= 0.21320679593592998 idx= (21, 12, 81, 36)
# selected elements: 2128
# ------------
# cluster= 33
# amplitude= 0.21152829576239535 idx= (7, 9, 280, 11)
# selected elements: 1519
# ------------
# cluster= 34
# amplitude= 0.21111312076485605 idx= (20, 8, 33, 71)
# selected elements: 3765
# ------------
# cluster= 35
# amplitude= 0.21092710558490016 idx= (20, 8, 188, 9)
# selected elements: 1045
# ------------
# cluster= 36
# amplitude= 0.209491903994779 idx= (18, 7, 183, 62)
# selected elements: 1171
# ------------
# cluster= 37
# amplitude= 0.20882683541008829 idx= (20, 10, 21, 7)
# selected elements: 2802
# ------------
# cluster= 38
# amplitude= 0.20730206277899996 idx= (19, 8, 33, 7)
# selected elements: 7470
# ------------
# cluster= 39
# amplitude= 0.20462065169036003 idx= (22, 6, 324, 41)
# selected elements: 103
# ------------
# cluster= 40
# amplitude= 0.20140455118185938 idx= (18, 7, 88, 19)
# selected elements: 2647
# ------------
# cluster= 41
# amplitude= 0.20130415883778316 idx= (15, 8, 25, 56)
# selected elements: 1505
# ------------
# cluster= 42
# amplitude= 0.2009010551342877 idx= (3, 10, 106, 57)
# selected elements: 2116
# ------------
# cluster= 43
# amplitude= 0.19688985419375357 idx= (11, 8, 192, 45)
# selected elements: 1807
# ------------
# cluster= 44
# amplitude= 0.1960797727215461 idx= (17, 7, 140, 26)
# selected elements: 1284
# ------------
# cluster= 45
# amplitude= 0.19329326497845284 idx= (18, 8, 135, 77)
# selected elements: 1839
# ------------
# cluster= 46
# amplitude= 0.19110017154734601 idx= (14, 8, 72, 39)
# selected elements: 1130
# ------------
# cluster= 47
# amplitude= 0.19083048185233992 idx= (5, 9, 103, 51)
# selected elements: 1442
# ------------
# cluster= 48
# amplitude= 0.1899145503211557 idx= (5, 11, 109, 59)
# selected elements: 1657
# ------------
# cluster= 49
# amplitude= 0.18957193030148564 idx= (18, 3, 21, 42)
# selected elements: 3482
# ------------
# cluster= 50
# amplitude= 0.18518538534973147 idx= (14, 10, 67, 32)
# selected elements: 1364
# ------------
# cluster= 51
# amplitude= 0.1837361561290796 idx= (9, 12, 18, 63)
# selected elements: 5386
# ------------
# cluster= 52
# amplitude= 0.18180413994052566 idx= (12, 7, 39, 62)
# selected elements: 2753
# ------------
# cluster= 53
# amplitude= 0.18042914686307127 idx= (14, 6, 203, 42)
# selected elements: 1576
# ------------
# cluster= 54
# amplitude= 0.18005025599547403 idx= (15, 7, 104, 13)
# selected elements: 1336
# ------------
# cluster= 55
# amplitude= 0.1785594549943473 idx= (15, 10, 210, 1)
# selected elements: 321
# ------------
# cluster= 56
# amplitude= 0.17675756877938265 idx= (4, 7, 227, 14)
# selected elements: 610
# ------------
# cluster= 57
# amplitude= 0.1753338374801546 idx= (18, 10, 52, 59)
# selected elements: 509
# ------------
# cluster= 58
# amplitude= 0.17479338334883895 idx= (1, 8, 35, 57)
# selected elements: 892
# ------------
# cluster= 59
# amplitude= 0.17433058466700088 idx= (14, 9, 154, 60)
# selected elements: 879
# ------------
# cluster= 60
# amplitude= 0.17420680621147092 idx= (17, 13, 155, 38)
# selected elements: 1787
# ------------
# cluster= 61
# amplitude= 0.174036304708312 idx= (18, 8, 22, 60)
# selected elements: 383
# ------------
# cluster= 62
# amplitude= 0.17253553853180167 idx= (6, 10, 282, 10)
# selected elements: 570
# ------------
# cluster= 63
# amplitude= 0.17252482535521607 idx= (7, 8, 332, 72)
# selected elements: 4065
# ------------
# cluster= 64
# amplitude= 0.17186052846706285 idx= (7, 8, 78, 52)
# selected elements: 676
# ------------
# cluster= 65
# amplitude= 0.17110643979200857 idx= (19, 6, 175, 59)
# selected elements: 295
# ------------
# cluster= 66
# amplitude= 0.16893059161499419 idx= (16, 8, 324, 129)
# selected elements: 1354
# ------------
# cluster= 67
# amplitude= 0.16699944820008286 idx= (8, 9, 183, 42)
# selected elements: 1413
# ------------
# cluster= 68
# amplitude= 0.16656102908918155 idx= (9, 7, 265, 22)
# selected elements: 1210
# ------------
# cluster= 69
# amplitude= 0.16589754461552797 idx= (19, 13, 148, 67)
# selected elements: 87
# ------------
# cluster= 70
# amplitude= 0.16564142141306212 idx= (4, 8, 71, 16)
# selected elements: 4559
# ------------
# cluster= 71
# amplitude= 0.16544207913685785 idx= (18, 10, 106, 53)
# selected elements: 389
# ------------
# cluster= 72
# amplitude= 0.16538670333329242 idx= (17, 9, 226, 139)
# selected elements: 971
# ------------
# cluster= 73
# amplitude= 0.16500314515251308 idx= (8, 12, 13, 35)
# selected elements: 4092
# ------------
# cluster= 74
# amplitude= 0.16469040369402382 idx= (3, 8, 101, 41)
# selected elements: 770
# ------------
# cluster= 75
# amplitude= 0.16408555748191234 idx= (16, 13, 56, 54)
# selected elements: 508
# ------------
# cluster= 76
# amplitude= 0.164031915181536 idx= (13, 7, 116, 27)
# selected elements: 1454
# ------------
# cluster= 77
# amplitude= 0.16402519378059272 idx= (19, 2, 159, 39)
# selected elements: 47
# ------------
# cluster= 78
# amplitude= 0.1628278149654635 idx= (7, 11, 263, 10)
# selected elements: 1376
# ------------
# cluster= 79
# amplitude= 0.16254851399941186 idx= (14, 6, 83, 26)
# selected elements: 1268
# ------------
# cluster= 80
# amplitude= 0.16115457508748696 idx= (7, 6, 11, 55)
# selected elements: 3530
# ------------
# cluster= 81
# amplitude= 0.1602502218852889 idx= (16, 12, 150, 10)
# selected elements: 241
# ------------
# cluster= 82
# amplitude= 0.1599653994191992 idx= (4, 10, 157, 6)
# selected elements: 790
# ------------
# cluster= 83
# amplitude= 0.15946955122756792 idx= (11, 9, 28, 7)
# selected elements: 1015
# ------------
# cluster= 84
# amplitude= 0.15846197630355974 idx= (2, 11, 27, 52)
# selected elements: 754
# ------------
# cluster= 85
# amplitude= 0.15806578101522875 idx= (16, 4, 69, 37)
# selected elements: 553
# ------------
# cluster= 86
# amplitude= 0.1580614070732885 idx= (14, 11, 247, 14)
# selected elements: 1813
# ------------
# cluster= 87
# amplitude= 0.15723884939408334 idx= (14, 3, 17, 62)
# selected elements: 890
# ------------
# cluster= 88
# amplitude= 0.15620395841679335 idx= (17, 6, 213, 46)
# selected elements: 77
# ------------
# cluster= 89
# amplitude= 0.15519444480058772 idx= (17, 9, 129, 75)
# selected elements: 73
# ------------
# cluster= 90
# amplitude= 0.15515304346665848 idx= (17, 8, 213, 122)
# selected elements: 164
# ------------
# cluster= 91
# amplitude= 0.1548294469635806 idx= (0, 9, 76, 53)
# selected elements: 374
# ------------
# cluster= 92
# amplitude= 0.1545415501967696 idx= (16, 9, 17, 91)
# selected elements: 128
# ------------
# cluster= 93
# amplitude= 0.15418471813246346 idx= (10, 7, 313, 126)
# selected elements: 3555
# ------------
# cluster= 94
# amplitude= 0.15384281960051607 idx= (12, 11, 225, 10)
# selected elements: 1302
# ------------
# cluster= 95
# amplitude= 0.15320749051890553 idx= (4, 11, 25, 47)
# selected elements: 520
# ------------
# cluster= 96
# amplitude= 0.15288380808249416 idx= (9, 7, 28, 52)
# selected elements: 256
# ------------
# cluster= 97
# amplitude= 0.15234495966590422 idx= (5, 10, 188, 6)
# selected elements: 346
# ------------
# cluster= 98
# amplitude= 0.15218441435308475 idx= (7, 8, 125, 38)
# selected elements: 1821
# ------------
# cluster= 99
# amplitude= 0.15139700150886215 idx= (15, 6, 131, 22)
# selected elements: 1026
# ------------
# cluster= 100
# amplitude= 0.15060575353720598 idx= (4, 8, 171, 7)
# selected elements: 678
# ------------
# cluster= 101
# amplitude= 0.15040719400987496 idx= (16, 13, 152, 46)
# selected elements: 149
# ------------
# cluster= 102
# amplitude= 0.1503065852482762 idx= (5, 8, 188, 26)
# selected elements: 858
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 26.75it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp0p15 | offset 0] core=1200:1800 ext=1150:1850 saved to outputs_decompose2d_slices_single_noise_filtering_q20/amp0p15_offset_0000/xcore_01200_01800_xext_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.28058267975080087 idx= (6, 10, 325, 134)
# selected elements: 11353
# ------------
# cluster= 1
# amplitude= 0.27010164768048706 idx= (23, 9, 179, 39)
# selected elements: 7888
# ------------
# cluster= 2
# amplitude= 0.2635684495667518 idx= (23, 3, 145, 92)
# selected elements: 5479
# ------------
# cluster= 3
# amplitude= 0.23826621503663226 idx= (9, 7, 157, 37)
# selected elements: 10148
# ------------
# cluster= 4
# amplitude= 0.2307674217908497 idx= (23, 5, 325, 113)
# selected elements: 3938
# ------------
# cluster= 5
# amplitude= 0.22799194295356864 idx= (11, 13, 193, 94)
# selected elements: 9585
# ------------
# cluster= 6
# amplitude= 0.2215972704943191 idx= (22, 8, 34, 55)
# selected elements: 1733
# ------------
# cluster= 7
# amplitude= 0.2200406757367188 idx= (13, 9, 173, 8)
# selected elements: 6219
# ------------
# cluster= 8
# amplitude= 0.21452986866809454 idx= (23, 7, 35, 42)
# selected elements: 17
# ------------
# cluster= 9
# amplitude= 0.2135749478263648 idx= (7, 4, 329, 125)
# selected elements: 5414
# ------------
# cluster= 10
# amplitude= 0.21191149614360003 idx= (22, 7, 162, 18)
# selected elements: 1645
# ------------
# cluster= 11
# amplitude= 0.20804465749275744 idx= (6, 5, 152, 24)
# selected elements: 2974
# ------------
# cluster= 12
# amplitude= 0.20802547758739284 idx= (15, 6, 157, 27)
# selected elements: 2836
# ------------
# cluster= 13
# amplitude= 0.20489169991892894 idx= (21, 10, 322, 127)
# selected elements: 1056
# ------------
# cluster= 14
# amplitude= 0.20442519702183407 idx= (12, 13, 205, 61)
# selected elements: 1877
# ------------
# cluster= 15
# amplitude= 0.20411067927736343 idx= (10, 14, 139, 110)
# selected elements: 4118
# ------------
# cluster= 16
# amplitude= 0.19749858352437272 idx= (19, 1, 140, 28)
# selected elements: 1140
# ------------
# cluster= 17
# amplitude= 0.19720934496645087 idx= (6, 2, 323, 17)
# selected elements: 3798
# ------------
# cluster= 18
# amplitude= 0.19356017378477894 idx= (20, 2, 141, 26)
# selected elements: 336
# ------------
# cluster= 19
# amplitude= 0.19168386201081877 idx= (21, 9, 37, 49)
# selected elements: 132
# ------------
# cluster= 20
# amplitude= 0.1892806343028394 idx= (21, 6, 327, 119)
# selected elements: 59
# ------------
# cluster= 21
# amplitude= 0.18768822665982127 idx= (21, 3, 168, 61)
# selected elements: 42
# ------------
# cluster= 22
# amplitude= 0.18721035369236766 idx= (21, 3, 330, 114)
# selected elements: 12
# ------------
# cluster= 23
# amplitude= 0.18573427975210172 idx= (12, 10, 173, 61)
# selected elements: 4698
# ------------
# cluster= 24
# amplitude= 0.18446734997285238 idx= (11, 2, 303, 41)
# selected elements: 3043
# ------------
# cluster= 25
# amplitude= 0.18402756017385974 idx= (20, 4, 326, 118)
# selected elements: 116
# ------------
# cluster= 26
# amplitude= 0.1823180195114685 idx= (11, 1, 159, 25)
# selected elements: 2012
# ------------
# cluster= 27
# amplitude= 0.18125623304865157 idx= (7, 9, 180, 101)
# selected elements: 8437
# ------------
# cluster= 28
# amplitude= 0.18104750252282364 idx= (17, 3, 311, 22)
# selected elements: 530
# ------------
# cluster= 29
# amplitude= 0.18072937492370664 idx= (6, 3, 204, 72)
# selected elements: 4768
# ------------
# cluster= 30
# amplitude= 0.17996901138722807 idx= (7, 8, 33, 72)
# selected elements: 3508
# ------------
# cluster= 31
# amplitude= 0.17572421328656526 idx= (6, 2, 281, 58)
# selected elements: 3300
# ------------
# cluster= 32
# amplitude= 0.17548387257222275 idx= (12, 3, 295, 50)
# selected elements: 789
# ------------
# cluster= 33
# amplitude= 0.17519450527307084 idx= (9, 9, 158, 126)
# selected elements: 1791
# ------------
# cluster= 34
# amplitude= 0.17469219528446756 idx= (9, 1, 303, 44)
# selected elements: 2078
# ------------
# cluster= 35
# amplitude= 0.1725721393979435 idx= (13, 8, 131, 110)
# selected elements: 2143
# ------------
# cluster= 36
# amplitude= 0.17252635146230155 idx= (17, 4, 311, 19)
# selected elements: 17
# ------------
# cluster= 37
# amplitude= 0.1722465323322341 idx= (9, 10, 118, 122)
# selected elements: 3041
# ------------
# cluster= 38
# amplitude= 0.17161849486406608 idx= (17, 2, 303, 34)
# selected elements: 4
# ------------
# cluster= 39
# amplitude= 0.16930528304247405 idx= (3, 2, 240, 42)
# selected elements: 2589
# ------------
# cluster= 40
# amplitude= 0.16882656408739635 idx= (14, 2, 292, 46)
# selected elements: 538
# ------------
# cluster= 41
# amplitude= 0.16762063673991076 idx= (9, 3, 312, 22)
# selected elements: 1352
# ------------
# cluster= 42
# amplitude= 0.1664121984366027 idx= (16, 11, 327, 51)
# selected elements: 82
# ------------
# cluster= 43
# amplitude= 0.16396671460869516 idx= (13, 2, 177, 25)
# selected elements: 779
# ------------
# cluster= 44
# amplitude= 0.16387844632431905 idx= (7, 12, 241, 103)
# selected elements: 2671
# ------------
# cluster= 45
# amplitude= 0.1636379921904329 idx= (10, 11, 187, 73)
# selected elements: 805
# ------------
# cluster= 46
# amplitude= 0.1634311789537779 idx= (16, 2, 299, 37)
# selected elements: 12
# ------------
# cluster= 47
# amplitude= 0.1634081656179602 idx= (16, 7, 177, 12)
# selected elements: 115
# ------------
# cluster= 48
# amplitude= 0.16295042916588248 idx= (13, 9, 102, 138)
# selected elements: 930
# ------------
# cluster= 49
# amplitude= 0.16274170236057214 idx= (10, 10, 326, 142)
# selected elements: 395
# ------------
# cluster= 50
# amplitude= 0.15910303035052314 idx= (15, 10, 332, 54)
# selected elements: 76
# ------------
# cluster= 51
# amplitude= 0.1587232869354263 idx= (11, 9, 123, 117)
# selected elements: 338
# ------------
# cluster= 52
# amplitude= 0.15844200186701707 idx= (13, 5, 148, 24)
# selected elements: 209
# ------------
# cluster= 53
# amplitude= 0.15819698640072144 idx= (15, 10, 153, 54)
# selected elements: 56
# ------------
# cluster= 54
# amplitude= 0.15799507005375682 idx= (7, 14, 174, 54)
# selected elements: 1752
# ------------
# cluster= 55
# amplitude= 0.1576677878491897 idx= (8, 8, 173, 70)
# selected elements: 798
# ------------
# cluster= 56
# amplitude= 0.1555854363972701 idx= (15, 4, 313, 18)
# selected elements: 8
# ------------
# cluster= 57
# amplitude= 0.15508275899388485 idx= (14, 9, 236, 139)
# selected elements: 195
# ------------
# cluster= 58
# amplitude= 0.1520865141018416 idx= (14, 9, 330, 8)
# selected elements: 261
# ------------
# cluster= 59
# amplitude= 0.15182755438914505 idx= (14, 10, 97, 137)
# selected elements: 58
# ------------
# cluster= 60
# amplitude= 0.1514724360910584 idx= (14, 11, 161, 50)
# selected elements: 133
# ------------
# cluster= 61
# amplitude= 0.15128176260147172 idx= (9, 10, 287, 137)
# selected elements: 1017
# ------------
# cluster= 62
# amplitude= 0.15109761103596747 idx= (10, 1, 330, 89)
# selected elements: 1609
# ------------
# cluster= 63
# amplitude= 0.15059893164320387 idx= (14, 12, 215, 59)
# selected elements: 90
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 23.81it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp0p15 | offset 0] core=1800:2400 ext=1750:2450 saved to outputs_decompose2d_slices_single_noise_filtering_q20/amp0p15_offset_0000/xcore_01800_02400_xext_01750_02450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.31810958235042114 idx= (15, 8, 294, 125)
# selected elements: 35279
# ------------
# cluster= 1
# amplitude= 0.299126648422862 idx= (22, 4, 321, 106)
# selected elements: 28801
# ------------
# cluster= 2
# amplitude= 0.2818026053147679 idx= (6, 10, 25, 134)
# selected elements: 9588
# ------------
# cluster= 3
# amplitude= 0.24102163806222487 idx= (15, 9, 38, 8)
# selected elements: 6180
# ------------
# cluster= 4
# amplitude= 0.24082593012049344 idx= (23, 4, 32, 112)
# selected elements: 3182
# ------------
# cluster= 5
# amplitude= 0.2345179562864613 idx= (10, 7, 53, 135)
# selected elements: 9519
# ------------
# cluster= 6
# amplitude= 0.23317446016947524 idx= (16, 6, 312, 108)
# selected elements: 3604
# ------------
# cluster= 7
# amplitude= 0.23124719360725027 idx= (18, 7, 309, 114)
# selected elements: 2201
# ------------
# cluster= 8
# amplitude= 0.2236390852677371 idx= (23, 9, 293, 93)
# selected elements: 829
# ------------
# cluster= 9
# amplitude= 0.2192127463175606 idx= (19, 2, 333, 86)
# selected elements: 2361
# ------------
# cluster= 10
# amplitude= 0.21477499703259245 idx= (20, 9, 35, 126)
# selected elements: 2937
# ------------
# cluster= 11
# amplitude= 0.21436019793828226 idx= (23, 3, 43, 113)
# selected elements: 181
# ------------
# cluster= 12
# amplitude= 0.21285623510781412 idx= (7, 4, 29, 126)
# selected elements: 5975
# ------------
# cluster= 13
# amplitude= 0.20911123920775865 idx= (21, 8, 64, 136)
# selected elements: 3133
# ------------
# cluster= 14
# amplitude= 0.20767001856728853 idx= (20, 5, 311, 117)
# selected elements: 824
# ------------
# cluster= 15
# amplitude= 0.20461755737452164 idx= (18, 9, 309, 127)
# selected elements: 1043
# ------------
# cluster= 16
# amplitude= 0.19908714738627545 idx= (10, 7, 241, 138)
# selected elements: 3287
# ------------
# cluster= 17
# amplitude= 0.19879118976531931 idx= (22, 3, 29, 101)
# selected elements: 31
# ------------
# cluster= 18
# amplitude= 0.1982676443780752 idx= (22, 9, 288, 108)
# selected elements: 5
# ------------
# cluster= 19
# amplitude= 0.19646121204712252 idx= (6, 2, 23, 17)
# selected elements: 3955
# ------------
# cluster= 20
# amplitude= 0.19478948442933974 idx= (21, 4, 23, 109)
# selected elements: 158
# ------------
# cluster= 21
# amplitude= 0.1925882096896273 idx= (20, 9, 304, 123)
# selected elements: 445
# ------------
# cluster= 22
# amplitude= 0.19012124291848911 idx= (10, 6, 304, 122)
# selected elements: 1451
# ------------
# cluster= 23
# amplitude= 0.18953198209790403 idx= (11, 6, 216, 45)
# selected elements: 3969
# ------------
# cluster= 24
# amplitude= 0.18359502154145033 idx= (20, 9, 33, 7)
# selected elements: 148
# ------------
# cluster= 25
# amplitude= 0.18348990313882801 idx= (16, 10, 34, 51)
# selected elements: 1557
# ------------
# cluster= 26
# amplitude= 0.18256532471223527 idx= (11, 3, 117, 131)
# selected elements: 2242
# ------------
# cluster= 27
# amplitude= 0.18211578997976646 idx= (5, 9, 225, 40)
# selected elements: 4864
# ------------
# cluster= 28
# amplitude= 0.1817267169262799 idx= (18, 11, 31, 52)
# selected elements: 473
# ------------
# cluster= 29
# amplitude= 0.1812755789984725 idx= (18, 8, 71, 138)
# selected elements: 151
# ------------
# cluster= 30
# amplitude= 0.18097206353717468 idx= (13, 9, 63, 136)
# selected elements: 941
# ------------
# cluster= 31
# amplitude= 0.1800281313466145 idx= (20, 6, 315, 113)
# selected elements: 104
# ------------
# cluster= 32
# amplitude= 0.1794438849303452 idx= (20, 8, 313, 120)
# selected elements: 45
# ------------
# cluster= 33
# amplitude= 0.17910234935247119 idx= (19, 10, 27, 128)
# selected elements: 162
# ------------
# cluster= 34
# amplitude= 0.17781630861421857 idx= (15, 8, 58, 142)
# selected elements: 187
# ------------
# cluster= 35
# amplitude= 0.17618570881903814 idx= (16, 3, 335, 85)
# selected elements: 242
# ------------
# cluster= 36
# amplitude= 0.17407376945145334 idx= (17, 2, 338, 85)
# selected elements: 24
# ------------
# cluster= 37
# amplitude= 0.17392442057955979 idx= (15, 2, 123, 92)
# selected elements: 352
# ------------
# cluster= 38
# amplitude= 0.17277930388010992 idx= (10, 10, 227, 139)
# selected elements: 1592
# ------------
# cluster= 39
# amplitude= 0.17233436129720056 idx= (11, 4, 82, 28)
# selected elements: 1242
# ------------
# cluster= 40
# amplitude= 0.17063111141038978 idx= (8, 1, 36, 87)
# selected elements: 2364
# ------------
# cluster= 41
# amplitude= 0.1700901250660351 idx= (8, 9, 218, 114)
# selected elements: 2609
# ------------
# cluster= 42
# amplitude= 0.16908646979215827 idx= (16, 9, 40, 49)
# selected elements: 96
# ------------
# cluster= 43
# amplitude= 0.16645186749717694 idx= (10, 10, 23, 142)
# selected elements: 555
# ------------
# cluster= 44
# amplitude= 0.16634170308183532 idx= (9, 3, 12, 22)
# selected elements: 864
# ------------
# cluster= 45
# amplitude= 0.1656847935592069 idx= (10, 3, 82, 26)
# selected elements: 1004
# ------------
# cluster= 46
# amplitude= 0.16422043842065767 idx= (9, 6, 321, 88)
# selected elements: 2132
# ------------
# cluster= 47
# amplitude= 0.163973343618385 idx= (10, 7, 175, 52)
# selected elements: 993
# ------------
# cluster= 48
# amplitude= 0.16348612225979012 idx= (16, 2, 124, 92)
# selected elements: 4
# ------------
# cluster= 49
# amplitude= 0.16256106550441343 idx= (8, 7, 239, 20)
# selected elements: 2203
# ------------
# cluster= 50
# amplitude= 0.16207473398746466 idx= (10, 5, 62, 31)
# selected elements: 1029
# ------------
# cluster= 51
# amplitude= 0.16175294028756648 idx= (14, 9, 209, 56)
# selected elements: 219
# ------------
# cluster= 52
# amplitude= 0.16051167656980123 idx= (15, 11, 25, 52)
# selected elements: 32
# ------------
# cluster= 53
# amplitude= 0.15958122092365867 idx= (3, 4, 214, 108)
# selected elements: 3174
# ------------
# cluster= 54
# amplitude= 0.15944943744658654 idx= (10, 5, 116, 97)
# selected elements: 1452
# ------------
# cluster= 55
# amplitude= 0.15898395826828648 idx= (3, 3, 83, 83)
# selected elements: 1661
# ------------
# cluster= 56
# amplitude= 0.15867506736682116 idx= (12, 8, 223, 45)
# selected elements: 211
# ------------
# cluster= 57
# amplitude= 0.15800960830834837 idx= (14, 17, 78, 49)
# selected elements: 185
# ------------
# cluster= 58
# amplitude= 0.15635815572431583 idx= (11, 6, 176, 53)
# selected elements: 241
# ------------
# cluster= 59
# amplitude= 0.15491957803656892 idx= (6, 8, 265, 56)
# selected elements: 3363
# ------------
# cluster= 60
# amplitude= 0.1537097086197615 idx= (4, 8, 321, 131)
# selected elements: 1505
# ------------
# cluster= 61
# amplitude= 0.15369735728679867 idx= (14, 6, 55, 139)
# selected elements: 9
# ------------
# cluster= 62
# amplitude= 0.15304578700642088 idx= (13, 10, 34, 57)
# selected elements: 56
# ------------
# cluster= 63
# amplitude= 0.15272720563925152 idx= (14, 0, 81, 48)
# selected elements: 5
# ------------
# cluster= 64
# amplitude= 0.15223519383530845 idx= (13, 5, 59, 138)
# selected elements: 99
# ------------
# cluster= 65
# amplitude= 0.1521563018312287 idx= (6, 6, 339, 43)
# selected elements: 1696
# ------------
# cluster= 66
# amplitude= 0.15206360897713794 idx= (13, 9, 134, 136)
# selected elements: 110
# ------------
# cluster= 67
# amplitude= 0.1501220529405218 idx= (12, 10, 28, 7)
# selected elements: 101
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 62.97it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [amp0p15 | offset 0] core=2400:3000 ext=2350:3050 saved to outputs_decompose2d_slices_single_noise_filtering_q20/amp0p15_offset_0000/xcore_02400_03000_xext_02350_03050
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.698144990688691 idx= (18, 2, 329, 115)
# selected elements: 150357
# ------------
# cluster= 1
# amplitude= 0.5731161961297186 idx= (22, 1, 334, 122)
# selected elements: 11733
# ------------
# cluster= 2
# amplitude= 0.44028277189678355 idx= (8, 2, 323, 128)
# selected elements: 31949
# ------------
# cluster= 3
# amplitude= 0.3634233935256345 idx= (23, 17, 334, 123)
# selected elements: 5817
# ------------
# cluster= 4
# amplitude= 0.3535136289053397 idx= (14, 2, 289, 109)
# selected elements: 9433
# ------------
# cluster= 5
# amplitude= 0.3443464000221411 idx= (8, 5, 251, 80)
# selected elements: 45876
# ------------
# cluster= 6
# amplitude= 0.3368185056159543 idx= (21, 7, 56, 70)
# selected elements: 21178
# ------------
# cluster= 7
# amplitude= 0.33591712978542576 idx= (16, 0, 341, 65)
# selected elements: 18562
# ------------
# cluster= 8
# amplitude= 0.3254897517615217 idx= (11, 2, 300, 101)
# selected elements: 873
# ------------
# cluster= 9
# amplitude= 0.31917347742224933 idx= (10, 1, 306, 103)
# selected elements: 5456
# ------------
# cluster= 10
# amplitude= 0.31524828512537 idx= (15, 1, 290, 112)
# selected elements: 1539
# ------------
# cluster= 11
# amplitude= 0.31195836944375727 idx= (21, 4, 23, 105)
# selected elements: 12984
# ------------
# cluster= 12
# amplitude= 0.29924283541028385 idx= (8, 4, 319, 130)
# selected elements: 3467
# ------------
# cluster= 13
# amplitude= 0.2947601118983877 idx= (21, 3, 112, 107)
# selected elements: 9684
# ------------
# cluster= 14
# amplitude= 0.29093799803306286 idx= (16, 4, 330, 94)
# selected elements: 3334
# ------------
# cluster= 15
# amplitude= 0.2888789403556107 idx= (23, 10, 279, 17)
# selected elements: 2532
# ------------
# cluster= 16
# amplitude= 0.28879824085776806 idx= (18, 17, 335, 63)
# selected elements: 6984
# ------------
# cluster= 17
# amplitude= 0.27738374485567596 idx= (23, 3, 134, 111)
# selected elements: 1130
# ------------
# cluster= 18
# amplitude= 0.27481485619158913 idx= (14, 1, 141, 124)
# selected elements: 7609
# ------------
# cluster= 19
# amplitude= 0.2685079394825531 idx= (18, 5, 116, 81)
# selected elements: 6657
# ------------
# cluster= 20
# amplitude= 0.2667227296836496 idx= (23, 5, 318, 130)
# selected elements: 712
# ------------
# cluster= 21
# amplitude= 0.25887743560684784 idx= (10, 1, 109, 105)
# selected elements: 6319
# ------------
# cluster= 22
# amplitude= 0.2557955843813359 idx= (12, 2, 336, 51)
# selected elements: 3549
# ------------
# cluster= 23
# amplitude= 0.2556270058382898 idx= (2, 3, 310, 114)
# selected elements: 1901
# ------------
# cluster= 24
# amplitude= 0.24925003704379378 idx= (11, 11, 135, 113)
# selected elements: 6870
# ------------
# cluster= 25
# amplitude= 0.2486475696877423 idx= (15, 8, 308, 51)
# selected elements: 5267
# ------------
# cluster= 26
# amplitude= 0.2485761484586935 idx= (16, 1, 127, 107)
# selected elements: 1164
# ------------
# cluster= 27
# amplitude= 0.24833909100144283 idx= (16, 9, 320, 10)
# selected elements: 5019
# ------------
# cluster= 28
# amplitude= 0.24799179523648263 idx= (17, 2, 251, 48)
# selected elements: 1513
# ------------
# cluster= 29
# amplitude= 0.2463315812538232 idx= (13, 1, 343, 100)
# selected elements: 754
# ------------
# cluster= 30
# amplitude= 0.24578052954489552 idx= (21, 2, 129, 96)
# selected elements: 1422
# ------------
# cluster= 31
# amplitude= 0.24553097616168787 idx= (19, 6, 310, 26)
# selected elements: 2210
# ------------
# cluster= 32
# amplitude= 0.24391141916818954 idx= (2, 8, 276, 82)
# selected elements: 3559
# ------------
# cluster= 33
# amplitude= 0.2436789592108028 idx= (4, 7, 275, 85)
# selected elements: 1028
# ------------
# cluster= 34
# amplitude= 0.24285565601164025 idx= (16, 2, 265, 125)
# selected elements: 878
# ------------
# cluster= 35
# amplitude= 0.24216646826352684 idx= (15, 7, 240, 86)
# selected elements: 587
# ------------
# cluster= 36
# amplitude= 0.24200416271449968 idx= (10, 3, 299, 90)
# selected elements: 653
# ------------
# cluster= 37
# amplitude= 0.24131670068884747 idx= (16, 6, 241, 73)
# selected elements: 504
# ------------
# cluster= 38
# amplitude= 0.24071067598723506 idx= (21, 10, 279, 8)
# selected elements: 1309
# ------------
# cluster= 39
# amplitude= 0.2377544944439978 idx= (19, 2, 248, 114)
# selected elements: 1896
# ------------
# cluster= 40
# amplitude= 0.23754509791595146 idx= (21, 2, 341, 49)
# selected elements: 225
# ------------
# cluster= 41
# amplitude= 0.23659586741455993 idx= (18, 17, 345, 117)
# selected elements: 877
# ------------
# cluster= 42
# amplitude= 0.23366097758183643 idx= (21, 2, 94, 120)
# selected elements: 266
# ------------
# cluster= 43
# amplitude= 0.23249017844792705 idx= (17, 3, 256, 67)
# selected elements: 1158
# ------------
# cluster= 44
# amplitude= 0.23008679715514235 idx= (17, 4, 245, 75)
# selected elements: 1008
# ------------
# cluster= 45
# amplitude= 0.22923797162738702 idx= (8, 9, 74, 74)
# selected elements: 12744
# ------------
# cluster= 46
# amplitude= 0.22877048948830647 idx= (3, 10, 275, 110)
# selected elements: 2706
# ------------
# cluster= 47
# amplitude= 0.228682565501422 idx= (17, 5, 234, 69)
# selected elements: 605
# ------------
# cluster= 48
# amplitude= 0.227916839930184 idx= (16, 11, 204, 61)
# selected elements: 838
# ------------
# cluster= 49
# amplitude= 0.22707014293157105 idx= (18, 3, 127, 90)
# selected elements: 339
# ------------
# cluster= 50
# amplitude= 0.2259532521587223 idx= (16, 8, 116, 66)
# selected elements: 1175
# ------------
# cluster= 51
# amplitude= 0.22536808410662804 idx= (7, 3, 251, 123)
# selected elements: 6611
# ------------
# cluster= 52
# amplitude= 0.223311876092104 idx= (3, 1, 332, 111)
# selected elements: 4121
# ------------
# cluster= 53
# amplitude= 0.2230731854898252 idx= (9, 4, 298, 85)
# selected elements: 3173
# ------------
# cluster= 54
# amplitude= 0.22136352021773187 idx= (7, 2, 312, 90)
# selected elements: 3949
# ------------
# cluster= 55
# amplitude= 0.22037591441899104 idx= (12, 9, 290, 45)
# selected elements: 2109
# ------------
# cluster= 56
# amplitude= 0.21934605501979762 idx= (16, 2, 342, 54)
# selected elements: 147
# ------------
# cluster= 57
# amplitude= 0.21802388170416137 idx= (19, 5, 309, 36)
# selected elements: 229
# ------------
# cluster= 58
# amplitude= 0.21782767338189593 idx= (10, 1, 342, 72)
# selected elements: 261
# ------------
# cluster= 59
# amplitude= 0.21626977754501178 idx= (20, 5, 304, 37)
# selected elements: 42
# ------------
# cluster= 60
# amplitude= 0.21613618024266326 idx= (16, 7, 116, 74)
# selected elements: 106
# ------------
# cluster= 61
# amplitude= 0.21400661701534046 idx= (11, 4, 335, 51)
# selected elements: 1123
# ------------
# cluster= 62
# amplitude= 0.21362694908121432 idx= (17, 1, 252, 39)
# selected elements: 320
# ------------
# cluster= 63
# amplitude= 0.21273149163951652 idx= (10, 7, 260, 57)
# selected elements: 2593
# ------------
# cluster= 64
# amplitude= 0.21157920033317465 idx= (18, 7, 316, 13)
# selected elements: 208
# ------------
# cluster= 65
# amplitude= 0.21146844349888477 idx= (19, 2, 250, 43)
# selected elements: 19
# ------------
# cluster= 66
# amplitude= 0.21116467257349603 idx= (19, 8, 49, 69)
# selected elements: 19
# ------------
# cluster= 67
# amplitude= 0.21084048152128995 idx= (18, 8, 290, 46)
# selected elements: 172
# ------------
# cluster= 68
# amplitude= 0.20888412926503158 idx= (12, 17, 343, 70)
# selected elements: 636
# ------------
# cluster= 69
# amplitude= 0.20885728315042718 idx= (15, 3, 271, 104)
# selected elements: 126
# ------------
# cluster= 70
# amplitude= 0.20876636271725663 idx= (18, 1, 249, 124)
# selected elements: 141
# ------------
# cluster= 71
# amplitude= 0.20745150657931827 idx= (16, 0, 114, 106)
# selected elements: 28
# ------------
# cluster= 72
# amplitude= 0.20698602174675937 idx= (15, 8, 330, 142)
# selected elements: 1207
# ------------
# cluster= 73
# amplitude= 0.20602602831673927 idx= (5, 1, 227, 71)
# selected elements: 3785
# ------------
# cluster= 74
# amplitude= 0.2060238062683943 idx= (17, 3, 128, 87)
# selected elements: 19
# ------------
# cluster= 75
# amplitude= 0.20493611415541377 idx= (17, 6, 17, 111)
# selected elements: 9
# ------------
# cluster= 76
# amplitude= 0.2046137094503604 idx= (18, 9, 177, 129)
# selected elements: 70
# ------------
# cluster= 77
# amplitude= 0.20297501210162078 idx= (9, 3, 337, 52)
# selected elements: 461
# ------------
# cluster= 78
# amplitude= 0.2022098114983806 idx= (18, 8, 324, 7)
# selected elements: 12
# ------------
# cluster= 79
# amplitude= 0.202108966511774 idx= (9, 0, 343, 118)
# selected elements: 1450
# ------------
# cluster= 80
# amplitude= 0.20207943451150914 idx= (18, 4, 272, 84)
# selected elements: 34
# ------------
# cluster= 81
# amplitude= 0.20040757855622257 idx= (15, 3, 246, 67)
# selected elements: 75
# ------------
# cluster= 82
# amplitude= 0.1996391372733332 idx= (15, 0, 121, 123)
# selected elements: 265
# ------------
# cluster= 83
# amplitude= 0.19856976671260396 idx= (13, 0, 299, 110)
# selected elements: 194
# ------------
# cluster= 84
# amplitude= 0.19814049494106048 idx= (14, 5, 281, 127)
# selected elements: 718
# ------------
# cluster= 85
# amplitude= 0.19810273693497135 idx= (8, 4, 195, 63)
# selected elements: 2540
# ------------
# cluster= 86
# amplitude= 0.19711291619844315 idx= (2, 4, 263, 67)
# selected elements: 1807
# ------------
# cluster= 87
# amplitude= 0.19648702929318987 idx= (11, 6, 269, 55)
# selected elements: 1029
# ------------
# cluster= 88
# amplitude= 0.19578106313176116 idx= (5, 9, 208, 23)
# selected elements: 3813
# ------------
# cluster= 89
# amplitude= 0.19535919200490215 idx= (6, 2, 335, 75)
# selected elements: 753
# ------------
# cluster= 90
# amplitude= 0.19530642472833132 idx= (15, 5, 122, 83)
# selected elements: 24
# ------------
# cluster= 91
# amplitude= 0.19386624612390335 idx= (15, 2, 149, 129)
# selected elements: 27
# ------------
# cluster= 92
# amplitude= 0.1926203919727902 idx= (13, 2, 148, 135)
# selected elements: 349
# ------------
# cluster= 93
# amplitude= 0.1919733846005267 idx= (4, 9, 274, 110)
# selected elements: 1615
# ------------
# cluster= 94
# amplitude= 0.19184129218656207 idx= (9, 4, 254, 136)
# selected elements: 1295
# ------------
# cluster= 95
# amplitude= 0.1916167508246321 idx= (3, 5, 216, 97)
# selected elements: 4099
# ------------
# cluster= 96
# amplitude= 0.18841665904801003 idx= (3, 8, 74, 60)
# selected elements: 2041
# ------------
# cluster= 97
# amplitude= 0.18822928440033568 idx= (8, 4, 334, 87)
# selected elements: 739
# ------------
# cluster= 98
# amplitude= 0.18792056862960246 idx= (13, 3, 252, 137)
# selected elements: 224
# ------------
# cluster= 99
# amplitude= 0.1872051712810442 idx= (7, 4, 303, 56)
# selected elements: 2128
# ------------
# cluster= 100
# amplitude= 0.18687576999809338 idx= (9, 6, 231, 72)
# selected elements: 163
# ------------
# cluster= 101
# amplitude= 0.18603212186948018 idx= (10, 3, 54, 17)
# selected elements: 1572
# ------------
# cluster= 102
# amplitude= 0.18581515041306257 idx= (7, 10, 159, 75)
# selected elements: 4107
# ------------
# cluster= 103
# amplitude= 0.1843480740202884 idx= (1, 8, 293, 102)
# selected elements: 1956
# ------------
# cluster= 104
# amplitude= 0.1834562407470723 idx= (14, 0, 296, 112)
# selected elements: 35
# ------------
# cluster= 105
# amplitude= 0.1822490315639137 idx= (7, 3, 100, 100)
# selected elements: 2986
# ------------
# cluster= 106
# amplitude= 0.18176850688093185 idx= (14, 4, 266, 108)
# selected elements: 43
# ------------
# cluster= 107
# amplitude= 0.1816919258276799 idx= (12, 4, 321, 138)
# selected elements: 132
# ------------
# cluster= 108
# amplitude= 0.18134957088423628 idx= (14, 4, 120, 84)
# selected elements: 29
# ------------
# cluster= 109
# amplitude= 0.18094560884651015 idx= (14, 1, 248, 35)
# selected elements: 35
# ------------
# cluster= 110
# amplitude= 0.17999944838389553 idx= (4, 1, 293, 47)
# selected elements: 2505
# ------------
# cluster= 111
# amplitude= 0.1798430164386144 idx= (3, 7, 206, 100)
# selected elements: 1552
# ------------
# cluster= 112
# amplitude= 0.17941319620565974 idx= (14, 3, 246, 71)
# selected elements: 13
# ------------
# cluster= 113
# amplitude= 0.17903688127986728 idx= (10, 6, 303, 80)
# selected elements: 1282
# ------------
# cluster= 114
# amplitude= 0.17867231307800074 idx= (3, 6, 288, 108)
# selected elements: 1938
# ------------
# cluster= 115
# ...
# selected elements: 24
# ------------
# cluster= 344
# amplitude= 0.2200030908802821 idx= (1, 11, 204, 112)
# selected elements: 293
# ------------
# cluster= 345
# amplitude= 0.2198107273070083 idx= (7, 3, 52, 75)
# selected elements: 1806
# ------------
# cluster= 346
# amplitude= 0.21836926956998934 idx= (9, 5, 271, 16)
# selected elements: 1070
# ------------
# cluster= 347
# amplitude= 0.21830199318260554 idx= (13, 7, 67, 16)
# selected elements: 22
# ------------
# cluster= 348
# amplitude= 0.21813736777612733 idx= (13, 7, 96, 112)
# selected elements: 23
# ------------
# cluster= 349
# amplitude= 0.21805945316416905 idx= (2, 1, 55, 50)
# selected elements: 765
# ------------
# cluster= 350
# amplitude= 0.21800012965170779 idx= (10, 12, 231, 60)
# selected elements: 123
# ------------
# cluster= 351
# amplitude= 0.21783989649504196 idx= (7, 2, 13, 90)
# selected elements: 1903
# ------------
# cluster= 352
# amplitude= 0.21780990107167472 idx= (12, 0, 64, 106)
# selected elements: 47
# ------------
# cluster= 353
# amplitude= 0.21749807783940023 idx= (11, 16, 188, 135)
# selected elements: 207
# ------------
# cluster= 354
# amplitude= 0.21738074025597004 idx= (0, 8, 163, 94)
# selected elements: 817
# ------------
# cluster= 355
# amplitude= 0.21693866472781798 idx= (7, 5, 163, 75)
# selected elements: 335
# ------------
# cluster= 356
# amplitude= 0.2169210312634768 idx= (4, 0, 57, 57)
# selected elements: 171
# ------------
# cluster= 357
# amplitude= 0.2167569370535843 idx= (8, 8, 178, 70)
# selected elements: 369
# ------------
# cluster= 358
# amplitude= 0.216372512799426 idx= (12, 4, 158, 45)
# selected elements: 47
# ------------
# cluster= 359
# amplitude= 0.21628358687509125 idx= (7, 8, 285, 59)
# selected elements: 3267
# ------------
# cluster= 360
# amplitude= 0.21598222827817506 idx= (13, 13, 71, 17)
# selected elements: 14
# ------------
# cluster= 361
# amplitude= 0.21515998474099482 idx= (7, 16, 228, 99)
# selected elements: 369
# ------------
# cluster= 362
# amplitude= 0.21491578183814714 idx= (11, 9, 187, 8)
# selected elements: 251
# ------------
# cluster= 363
# amplitude= 0.21454760003617607 idx= (8, 11, 62, 89)
# selected elements: 219
# ------------
# cluster= 364
# amplitude= 0.2144933093436572 idx= (5, 2, 115, 81)
# selected elements: 1334
# ------------
# cluster= 365
# amplitude= 0.2140721037587081 idx= (12, 4, 188, 33)
# selected elements: 150
# ------------
# cluster= 366
# amplitude= 0.21406004983594543 idx= (12, 13, 202, 144)
# selected elements: 147
# ------------
# cluster= 367
# amplitude= 0.21382632204963942 idx= (12, 3, 78, 139)
# selected elements: 29
# ------------
# cluster= 368
# amplitude= 0.213551839774513 idx= (6, 4, 234, 61)
# selected elements: 3727
# ------------
# cluster= 369
# amplitude= 0.21348341051283581 idx= (9, 3, 38, 53)
# selected elements: 315
# ------------
# cluster= 370
# amplitude= 0.2132225404458504 idx= (12, 8, 230, 9)
# selected elements: 45
# ------------
# cluster= 371
# amplitude= 0.2130917387669719 idx= (8, 5, 98, 60)
# selected elements: 721
# ------------
# cluster= 372
# amplitude= 0.21287876742598769 idx= (12, 5, 98, 65)
# selected elements: 35
# ------------
# cluster= 373
# amplitude= 0.21281453561878697 idx= (10, 10, 164, 26)
# selected elements: 353
# ------------
# cluster= 374
# amplitude= 0.2126929396132012 idx= (9, 0, 153, 84)
# selected elements: 621
# ------------
# cluster= 375
# amplitude= 0.21200675495669985 idx= (12, 3, 32, 55)
# selected elements: 43
# ------------
# cluster= 376
# amplitude= 0.21186874352155927 idx= (9, 15, 169, 135)
# selected elements: 209
# ------------
# cluster= 377
# amplitude= 0.2118322324884434 idx= (1, 11, 70, 86)
# selected elements: 1609
# ------------
# cluster= 378
# amplitude= 0.2112803658196391 idx= (3, 12, 114, 110)
# selected elements: 272
# ------------
# cluster= 379
# amplitude= 0.21096878509281078 idx= (8, 9, 257, 59)
# selected elements: 220
# ------------
# cluster= 380
# amplitude= 0.2109606601960826 idx= (12, 8, 181, 108)
# selected elements: 21
# ------------
# cluster= 381
# amplitude= 0.21091853403798566 idx= (4, 11, 169, 142)
# selected elements: 1021
# ------------
# cluster= 382
# amplitude= 0.21080890278238715 idx= (10, 4, 54, 77)
# selected elements: 229
# ------------
# cluster= 383
# amplitude= 0.2104979146600231 idx= (2, 4, 149, 74)
# selected elements: 2328
# ------------
# cluster= 384
# amplitude= 0.21032245113476797 idx= (7, 4, 80, 112)
# selected elements: 364
# ------------
# cluster= 385
# amplitude= 0.2100643446117321 idx= (12, 0, 183, 131)
# selected elements: 18
# ------------
# cluster= 386
# amplitude= 0.20995746436708715 idx= (5, 9, 147, 29)
# selected elements: 187
# ------------
# cluster= 387
# amplitude= 0.20935609030955057 idx= (11, 4, 19, 136)
# selected elements: 72
# ------------
# cluster= 388
# amplitude= 0.20874162888924036 idx= (3, 2, 65, 137)
# selected elements: 2519
# ------------
# cluster= 389
# amplitude= 0.20861922450212345 idx= (9, 0, 61, 100)
# selected elements: 145
# ------------
# cluster= 390
# amplitude= 0.20826454096388247 idx= (11, 4, 36, 92)
# selected elements: 254
# ------------
# cluster= 391
# amplitude= 0.20819392040815923 idx= (3, 12, 238, 103)
# selected elements: 995
# ------------
# cluster= 392
# amplitude= 0.20814183303927136 idx= (12, 15, 290, 131)
# selected elements: 18
# ------------
# cluster= 393
# amplitude= 0.20743743042734716 idx= (11, 3, 126, 79)
# selected elements: 78
# ------------
# cluster= 394
# amplitude= 0.20734287617870054 idx= (12, 1, 186, 129)
# selected elements: 11
# ------------
# cluster= 395
# amplitude= 0.20729892911659212 idx= (5, 16, 97, 129)
# selected elements: 2291
# ------------
# cluster= 396
# amplitude= 0.20729673732664203 idx= (3, 8, 212, 65)
# selected elements: 1153
# ------------
# cluster= 397
# amplitude= 0.20721945619367094 idx= (5, 17, 196, 94)
# selected elements: 888
# ------------
# cluster= 398
# amplitude= 0.2062004926550764 idx= (12, 7, 180, 78)
# selected elements: 43
# ------------
# cluster= 399
# amplitude= 0.20616920378648065 idx= (12, 16, 76, 44)
# selected elements: 3
# ------------
# cluster= 400
# amplitude= 0.20602302780129547 idx= (7, 13, 267, 109)
# selected elements: 647
# ------------
# cluster= 401
# amplitude= 0.2059315346019458 idx= (11, 12, 118, 119)
# selected elements: 38
# ------------
# cluster= 402
# amplitude= 0.20580234215022242 idx= (10, 10, 144, 27)
# selected elements: 72
# ------------
# cluster= 403
# amplitude= 0.20546758204518667 idx= (0, 13, 157, 61)
# selected elements: 185
# ------------
# cluster= 404
# amplitude= 0.20539784393175053 idx= (8, 5, 211, 62)
# selected elements: 145
# ------------
# cluster= 405
# amplitude= 0.20508649012562766 idx= (4, 9, 207, 42)
# selected elements: 1465
# ------------
# cluster= 406
# amplitude= 0.20505472512202746 idx= (6, 3, 167, 49)
# selected elements: 2962
# ------------
# cluster= 407
# amplitude= 0.20481482870512135 idx= (9, 17, 75, 24)
# selected elements: 146
# ------------
# cluster= 408
# amplitude= 0.2047328866227123 idx= (9, 17, 95, 135)
# selected elements: 233
# ------------
# cluster= 409
# amplitude= 0.2044671859337952 idx= (8, 13, 302, 136)
# selected elements: 478
# ------------
# cluster= 410
# amplitude= 0.2042699724540528 idx= (9, 12, 204, 138)
# selected elements: 241
# ------------
# cluster= 411
# amplitude= 0.20409015901386135 idx= (7, 11, 289, 119)
# selected elements: 1732
# ------------
# cluster= 412
# amplitude= 0.20378444442392224 idx= (1, 3, 200, 103)
# selected elements: 1939
# ------------
# cluster= 413
# amplitude= 0.20373843556005378 idx= (5, 3, 116, 60)
# selected elements: 827
# ------------
# cluster= 414
# amplitude= 0.20261580750444594 idx= (7, 3, 38, 87)
# selected elements: 770
# ------------
# cluster= 415
# amplitude= 0.20255324573184005 idx= (11, 12, 233, 83)
# selected elements: 29
# ------------
# cluster= 416
# amplitude= 0.20235931940240076 idx= (4, 8, 122, 78)
# selected elements: 1347
# ------------
# cluster= 417
# amplitude= 0.2021156792767973 idx= (9, 4, 131, 127)
# selected elements: 86
# ------------
# cluster= 418
# amplitude= 0.20141797622301338 idx= (11, 4, 204, 81)
# selected elements: 54
# ------------
# cluster= 419
# amplitude= 0.20126115237733508 idx= (11, 6, 241, 73)
# selected elements: 119
# ------------
# cluster= 420
# amplitude= 0.20072934598876624 idx= (3, 8, 184, 59)
# selected elements: 383
# ------------
# cluster= 421
# amplitude= 0.20052944856757063 idx= (8, 12, 133, 97)
# selected elements: 53
# ------------
# cluster= 422
# amplitude= 0.200490993461044 idx= (11, 16, 72, 44)
# selected elements: 35
# ------------
# cluster= 423
# amplitude= 0.2003782270916305 idx= (8, 0, 158, 61)
# selected elements: 469
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 72.58it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=3600:4200 ext=3550:4250 saved to outputs_decompose2d_slices_single_noise_filtering_q20/rednoise4_offset_0000/xcore_03600_04200_xext_03550_04250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.36295745893201914 idx= (10, 11, 122, 50)
# selected elements: 112005
# ------------
# cluster= 1
# amplitude= 0.31212685231674925 idx= (18, 13, 141, 19)
# selected elements: 90517
# ------------
# cluster= 2
# amplitude= 0.29552455279540324 idx= (23, 14, 140, 115)
# selected elements: 39074
# ------------
# cluster= 3
# amplitude= 0.2809540446049457 idx= (16, 10, 247, 31)
# selected elements: 76861
# ------------
# cluster= 4
# amplitude= 0.2587942949206798 idx= (11, 13, 94, 104)
# selected elements: 90645
# ------------
# cluster= 5
# amplitude= 0.2555802161913679 idx= (21, 6, 57, 49)
# selected elements: 68517
# ------------
# cluster= 6
# amplitude= 0.25386406990887334 idx= (20, 10, 88, 13)
# selected elements: 52435
# ------------
# cluster= 7
# amplitude= 0.24700474071253775 idx= (14, 14, 154, 117)
# selected elements: 22919
# ------------
# cluster= 8
# amplitude= 0.23967836304996223 idx= (16, 16, 115, 74)
# selected elements: 27246
# ------------
# cluster= 9
# amplitude= 0.23663224259883173 idx= (9, 10, 151, 120)
# selected elements: 25510
# ------------
# cluster= 10
# amplitude= 0.23491065743813092 idx= (15, 14, 40, 64)
# selected elements: 18172
# ------------
# cluster= 11
# amplitude= 0.23364431665303412 idx= (23, 7, 213, 84)
# selected elements: 12643
# ------------
# cluster= 12
# amplitude= 0.22721744680939515 idx= (17, 14, 42, 64)
# selected elements: 4881
# ------------
# cluster= 13
# amplitude= 0.22488495735294564 idx= (19, 8, 35, 60)
# selected elements: 15037
# ------------
# cluster= 14
# amplitude= 0.21934395871271822 idx= (14, 9, 193, 6)
# selected elements: 42415
# ------------
# cluster= 15
# amplitude= 0.21592070666663998 idx= (11, 11, 60, 14)
# selected elements: 12641
# ------------
# cluster= 16
# amplitude= 0.21450214855964705 idx= (16, 15, 153, 116)
# selected elements: 3850
# ------------
# cluster= 17
# amplitude= 0.21406074909044467 idx= (9, 10, 108, 111)
# selected elements: 3169
# ------------
# cluster= 18
# amplitude= 0.21190653758972516 idx= (23, 16, 12, 104)
# selected elements: 8305
# ------------
# cluster= 19
# amplitude= 0.20911530968028133 idx= (14, 13, 41, 60)
# selected elements: 1379
# ------------
# cluster= 20
# amplitude= 0.2071931892453781 idx= (13, 15, 120, 72)
# selected elements: 1489
# ------------
# cluster= 21
# amplitude= 0.2017704598291826 idx= (18, 14, 153, 114)
# selected elements: 1702
# ------------
# cluster= 22
# amplitude= 0.20137358868677122 idx= (23, 9, 165, 96)
# selected elements: 12975
# ------------
# cluster= 23
# amplitude= 0.2012713914721326 idx= (23, 16, 90, 30)
# selected elements: 14641
# ------------
# cluster= 24
# amplitude= 0.20053342436668228 idx= (21, 12, 86, 84)
# selected elements: 3827
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 72.05it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=4200:4800 ext=4150:4850 saved to outputs_decompose2d_slices_single_noise_filtering_q20/rednoise4_offset_0000/xcore_04200_04800_xext_04150_04850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 77.74it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=4800:5400 ext=4750:5450 saved to outputs_decompose2d_slices_single_noise_filtering_q20/rednoise4_offset_0000/xcore_04800_05400_xext_04750_05450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 76.49it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [rednoise4 | offset 0] core=5400:5451 ext=5350:5451 saved to outputs_decompose2d_slices_single_noise_filtering_q20/rednoise4_offset_0000/xcore_05400_05451_xext_05350_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 85.45it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Done. Outputs in /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_decompose2d_slices_single_noise_filtering_q20/rednoise4_offset_0000
