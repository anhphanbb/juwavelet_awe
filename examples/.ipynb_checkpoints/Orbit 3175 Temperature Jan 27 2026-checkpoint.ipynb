# %% [markdown]
# ## Loop
# Loops over X_SLICE = slice(0,600), slice(600,1200), ... until the end of the flattened swath
#
# If the last window is shorter than 600 px, it pads on the right to make it 600 (pads with the window median, so everything stays finite)
#
# Saves all figures into a subfolder (one subfolder per slice) instead of showing them

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Optional

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

# --------------------------
# User params
# --------------------------
FILE_PATH = "awe_l5c_q20_2024165T2120_03175_v01.nc"
FRAME_IDX = 0

# Loop settings on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 16
JT = 18
ASPECT = 1

# Pixel spacing (km/pixel) for plotting and CWT (wavelengths will be in km)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# Clustering thresholds
MIN_AMP = 0.25
THR = 0.1

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices")
SAVE_DPI = 200

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Helpers (yours, mostly unchanged)
# --------------------------
def read_radiance_frame(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        rad = nc.variables["Radiance"][:]  # (t, y, x)
    if rad.ndim != 3:
        raise ValueError(f"Radiance expected 3D (t,y,x); got {rad.shape}")
    if not (0 <= frame_idx < rad.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{rad.shape[0]-1}")
    return np.asarray(rad[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def load_radiance_window_from_array(
    Z: np.ndarray, xsl: slice, ysl: slice
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    win = np.asarray(Z[ysl, xsl], dtype=float)
    ny, nx = win.shape
    x = np.arange(nx, dtype=float)
    y = np.arange(ny, dtype=float)
    return x, y, win


def pad_window_to_width(win: np.ndarray, target_width: int) -> np.ndarray:
    ny, nx = win.shape
    if nx >= target_width:
        return win
    pad = target_width - nx
    med = float(np.nanmedian(win)) if np.isfinite(np.nanmedian(win)) else 0.0
    right = np.full((ny, pad), med, dtype=float)
    return np.concatenate([win, right], axis=1)


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    u = np.cos(theta_xy)
    v = np.sin(theta_xy)
    return u, v


def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("Radiance (arb)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    stacked = np.concatenate([orig_c.ravel(), bg_c.ravel(), rem_c.ravel(), rem_tapered_c.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [1, 99])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    fig, axs = plt.subplots(2, 2, figsize=(12, 10), constrained_layout=True)
    axes = axs.flatten()

    panels = [
        (orig_c, "Original (median-sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    im0 = None
    for ax, (Z, title) in zip(axes, panels):
        im0 = ax.pcolormesh(
            x1d_km, y1d_km, Z, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    cbar = fig.colorbar(im0, ax=axs, orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("Radiance (arb)")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2

    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_low, bg_high = np.nanpercentile(bg_xy, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax

    cl_low, cl_high = np.nanpercentile(rec_xy, [2, 98])
    cl_vmax = max(abs(cl_low), abs(cl_high))
    if not np.isfinite(cl_vmax) or cl_vmax == 0:
        cl_vmax = 1.0
    cl_vmin = -cl_vmax

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if not np.isfinite(lam_vmin) or not np.isfinite(lam_vmax) or lam_vmin == lam_vmax:
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n" + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        ARROW_LEN_KM = 40.0
        u = u * ARROW_LEN_KM
        v = v * ARROW_LEN_KM

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)


# --------------------------
# Main pipeline for one slice
# --------------------------
def run_pipeline_for_slice(rad2d_flat: np.ndarray, x_slice: slice, outdir: Path) -> None:
    outdir.mkdir(parents=True, exist_ok=True)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        dx_km = DX_KM_BASE * int(BIN_FACTOR)
        dy_km = DY_KM_BASE * int(BIN_FACTOR)
    else:
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE

    # Window on unbinned flattened field
    _, _, raw_win = load_radiance_window_from_array(rad2d_flat, x_slice, Y_SLICE)

    # Pad last chunk to width 600 if needed
    raw_win = pad_window_to_width(raw_win, X_CHUNK)

    # Optional binning
    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"Radiance (window, flattened){bin_tag}",
        outdir / "00_radiance_window.png",
    )

    # Background separation
    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_4panel.png",
    )

    # Preprocess for CWT
    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=MIN_AMP, thr=THR)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    # Overview decomposition plot
    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N
    )
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    # FOV wavelet spectrum (grab current fig after the call)
    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text("No clusters found. Try lowering MIN_AMP or THR.\n")
        return

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    # Write ranking to text file
    lines = []
    lines.append("Cluster power ranking (clustered only)\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))

    theta_vals = np.asarray(cwt["theta"], dtype=float)

    # Figure 1: standalone clusters
    fig1, axs1 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs1 = np.atleast_1d(axs1).reshape(-1)

    opts_cluster = {"cmap": "RdBu_r", "vmin": -1.0, "vmax": 1.0, "rasterized": True}

    for ax, kcl in zip(axs1, biggest):
        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", **opts_cluster)
        ax.set_aspect("equal", adjustable="box")

    for ax in axs1[n_show:]:
        ax.axis("off")
    for ax in axs1[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}
    for i, ax in enumerate(axs1, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig1.tight_layout()
    save_fig(fig1, outdir / "05_clusters_standalone.png")

    # Figure 2: overlays
    fig2, axs2 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs2 = np.atleast_1d(axs2).reshape(-1)

    bg_low, bg_high = np.nanpercentile(bg, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax
    cl_vmin, cl_vmax = -1.0, 1.0

    for ax, kcl in zip(axs2, biggest):
        ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)

        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.pcolormesh(
            x1d_km, y1d_km, rec_centered,
            shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
        )

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.set_aspect("equal", adjustable="box")

    for ax in axs2[n_show:]:
        ax.axis("off")
    for ax in axs2[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    for i, ax in enumerate(axs2, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig2.tight_layout()
    save_fig(fig2, outdir / "06_clusters_overlay.png")

    # Per cluster 2x2
    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
        )

    # --------------------------
    # Clustered-only total power per pixel
    # (linear power, log-scaled colorbar)
    # --------------------------
    dec0 = orig_decomp                       # (ns, nt, nx, ny)
    power4d = np.abs(dec0) ** 2

    # Keep ONLY clustered coefficients
    clustered_power4d = np.where(iwave >= 0, power4d, 0.0)

    # Sum over scale + orientation -> per-pixel POWER (linear)
    power_xy = np.sum(clustered_power4d, axis=(0, 1))  # (nx, ny)
    power_xy = power_xy.T                               # (ny, nx)

    # Mask zeros so LogNorm behaves nicely
    power_xy = np.where(power_xy > 0, power_xy, np.nan)

    # Color limits (linear values, robust)
    good = np.isfinite(power_xy)
    if np.any(good):
        vmin, vmax = np.nanpercentile(power_xy[good], [2, 98])
        vmin = max(vmin, np.nanmin(power_xy[good]))
        vmax = max(vmax, vmin * 10)
    else:
        vmin, vmax = 1e-6, 1.0

    figP, axP = plt.subplots(figsize=(12, 6), constrained_layout=True)

    imP = axP.pcolormesh(
        x1d_km,
        y1d_km,
        power_xy,
        shading="auto",
        cmap="magma",
        norm=matplotlib.colors.LogNorm(vmin=vmin, vmax=vmax),
    )

    axP.set_title("Clustered-only total wavelet power per pixel")
    axP.set_xlabel("x (km)")
    axP.set_ylabel("y (km)")
    axP.set_aspect("equal", adjustable="box")

    cbar = figP.colorbar(imP, ax=axP, fraction=0.046, pad=0.02)
    cbar.set_label(r"$\sum_{(s,t)\in clusters} |\mathrm{coeff}|^2$")

    save_fig(figP, outdir / "08_clustered_total_power_logcolor.png")

    # --------------------------
    # Remaining (after preprocessing) vs All clusters combined
    # --------------------------
    # "Remaining after preprocessing" = the field that went into the CWT (proc),
    # plotted in the same x-y orientation as everything else (ny, nx).
    remaining_after_preproc_xy = proc  # already (ny, nx)

    # "All clusters combined" = reconstruct using ONLY clustered coefficients (iwave >= 0)
    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)          # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)     # (ny, nx)

    # Robust, symmetric limits for both panels (keeps visuals comparable)
    stacked = np.concatenate(
        [remaining_after_preproc_xy.ravel(), rec_all_xy.ravel()]
    )
    p_low, p_high = np.nanpercentile(stacked, [2, 98])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    figR, (axL, axR) = plt.subplots(1, 2, figsize=(16, 6), constrained_layout=True)

    imL = axL.pcolormesh(
        x1d_km, y1d_km, remaining_after_preproc_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axL.set_title("Remaining (after preprocessing, input to CWT)")
    axL.set_xlabel("x (km)")
    axL.set_ylabel("y (km)")
    axL.set_aspect("equal", adjustable="box")
    figR.colorbar(imL, ax=axL, fraction=0.046, pad=0.02).set_label("arb")

    imR = axR.pcolormesh(
        x1d_km, y1d_km, rec_all_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axR.set_title("All clusters combined (reconstruction)")
    axR.set_xlabel("x (km)")
    axR.set_ylabel("y (km)")
    axR.set_aspect("equal", adjustable="box")
    figR.colorbar(imR, ax=axR, fraction=0.046, pad=0.02).set_label("arb")

    save_fig(figR, outdir / "09_remaining_vs_all_clusters.png")

    # Restore decomposition for anything that follows
    decomposition[:] = orig_decomp


# --------------------------
# Run all slices
# --------------------------
def run_all_slices() -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_radiance_frame(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    starts = list(range(0, nx_total, X_CHUNK))
    for start in starts:
        end = min(start + X_CHUNK, nx_total)
        x_slice = slice(start, end)

        outdir = OUTPUT_ROOT / f"x_{start:05d}_{end:05d}"
        print(f"Running slice x={start}:{end}  saved to {outdir}")
        run_pipeline_for_slice(rad2d_flat, x_slice, outdir)

    print(f"Done. Outputs in {OUTPUT_ROOT.resolve()}")


run_all_slices()
# Out:
# Running slice x=0:600  saved to outputs_decompose2d_slices\x_00000_00600
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.3633801038963466 idx= (np.int64(14), np.int64(11), np.int64(273), np.int64(48))
# selected elements: 93901
# ------------
# cluster= 1
# amplitude= 0.34361284116798607 idx= (np.int64(13), np.int64(9), np.int64(205), np.int64(118))
# selected elements: 80570
# ------------
# cluster= 2
# amplitude= 0.3323259916824853 idx= (np.int64(15), np.int64(8), np.int64(207), np.int64(114))
# selected elements: 10312
# ------------
# cluster= 3
# amplitude= 0.3177325833594557 idx= (np.int64(12), np.int64(8), np.int64(255), np.int64(74))
# selected elements: 13099
# ------------
# cluster= 4
# amplitude= 0.3060403313494669 idx= (np.int64(10), np.int64(9), np.int64(255), np.int64(78))
# selected elements: 15810
# ------------
# cluster= 5
# amplitude= 0.27599177604302805 idx= (np.int64(5), np.int64(7), np.int64(274), np.int64(60))
# selected elements: 11573
# ------------
# cluster= 6
# amplitude= 0.26529795328716194 idx= (np.int64(5), np.int64(10), np.int64(197), np.int64(116))
# selected elements: 1744
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 94.21it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=600:1200  saved to outputs_decompose2d_slices\x_00600_01200
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.48029566505987614 idx= (np.int64(6), np.int64(8), np.int64(216), np.int64(25))
# selected elements: 53071
# ------------
# cluster= 1
# amplitude= 0.47279106777584856 idx= (np.int64(5), np.int64(9), np.int64(218), np.int64(24))
# selected elements: 5651
# ------------
# cluster= 2
# amplitude= 0.4070410761070086 idx= (np.int64(8), np.int64(9), np.int64(24), np.int64(50))
# selected elements: 141658
# ------------
# cluster= 3
# amplitude= 0.4060660593723358 idx= (np.int64(7), np.int64(8), np.int64(25), np.int64(51))
# selected elements: 2190
# ------------
# cluster= 4
# amplitude= 0.33581535498628523 idx= (np.int64(10), np.int64(9), np.int64(175), np.int64(6))
# selected elements: 34772
# ------------
# cluster= 5
# amplitude= 0.33530601011687994 idx= (np.int64(10), np.int64(11), np.int64(46), np.int64(43))
# selected elements: 34096
# ------------
# cluster= 6
# amplitude= 0.29192079216239186 idx= (np.int64(13), np.int64(8), np.int64(225), np.int64(28))
# selected elements: 8181
# ------------
# cluster= 7
# amplitude= 0.272193972757914 idx= (np.int64(9), np.int64(10), np.int64(256), np.int64(10))
# selected elements: 6058
# ------------
# cluster= 8
# amplitude= 0.2646144304845612 idx= (np.int64(2), np.int64(8), np.int64(32), np.int64(53))
# selected elements: 1752
# ------------
# cluster= 9
# amplitude= 0.26188274310444415 idx= (np.int64(14), np.int64(10), np.int64(134), np.int64(8))
# selected elements: 18716
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 102.95it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=1200:1800  saved to outputs_decompose2d_slices\x_01200_01800
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 89.92it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=1800:2400  saved to outputs_decompose2d_slices\x_01800_02400
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.31431867394382457 idx= (np.int64(15), np.int64(8), np.int64(268), np.int64(125))
# selected elements: 60665
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 92.81it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=2400:3000  saved to outputs_decompose2d_slices\x_02400_03000
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.36556940836865687 idx= (np.int64(14), np.int64(2), np.int64(267), np.int64(109))
# selected elements: 69848
# ------------
# cluster= 1
# amplitude= 0.34434639833925845 idx= (np.int64(8), np.int64(5), np.int64(226), np.int64(80))
# selected elements: 126779
# ------------
# cluster= 2
# amplitude= 0.2748148536362068 idx= (np.int64(14), np.int64(1), np.int64(116), np.int64(124))
# selected elements: 42397
# ------------
# cluster= 3
# amplitude= 0.26606846962667713 idx= (np.int64(3), np.int64(3), np.int64(283), np.int64(113))
# selected elements: 17014
# ------------
# cluster= 4
# amplitude= 0.2588774345521047 idx= (np.int64(10), np.int64(1), np.int64(84), np.int64(105))
# selected elements: 15971
# ------------
# cluster= 5
# amplitude= 0.2507492546056884 idx= (np.int64(8), np.int64(2), np.int64(285), np.int64(92))
# selected elements: 8388
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 86.27it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=3000:3600  saved to outputs_decompose2d_slices\x_03000_03600
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.3214636569113676 idx= (np.int64(9), np.int64(13), np.int64(167), np.int64(94))
# selected elements: 1743278
# ------------
# cluster= 1
# amplitude= 0.8988716386603093 idx= (np.int64(15), np.int64(0), np.int64(51), np.int64(64))
# selected elements: 576349
# ------------
# cluster= 2
# amplitude= 0.6987886607191044 idx= (np.int64(14), np.int64(11), np.int64(109), np.int64(71))
# selected elements: 26660
# ------------
# cluster= 3
# amplitude= 0.6738899027615025 idx= (np.int64(2), np.int64(9), np.int64(148), np.int64(38))
# selected elements: 15892
# ------------
# cluster= 4
# amplitude= 0.6633018310661374 idx= (np.int64(15), np.int64(15), np.int64(87), np.int64(122))
# selected elements: 67812
# ------------
# cluster= 5
# amplitude= 0.6321003861487019 idx= (np.int64(2), np.int64(8), np.int64(180), np.int64(112))
# selected elements: 6978
# ------------
# cluster= 6
# amplitude= 0.594646650250417 idx= (np.int64(2), np.int64(12), np.int64(115), np.int64(65))
# selected elements: 10198
# ------------
# cluster= 7
# amplitude= 0.5748976990014023 idx= (np.int64(15), np.int64(15), np.int64(183), np.int64(126))
# selected elements: 3020
# ------------
# cluster= 8
# amplitude= 0.5619048658867282 idx= (np.int64(15), np.int64(5), np.int64(123), np.int64(77))
# selected elements: 46092
# ------------
# cluster= 9
# amplitude= 0.5514656651686213 idx= (np.int64(10), np.int64(2), np.int64(41), np.int64(91))
# selected elements: 77439
# ------------
# cluster= 10
# amplitude= 0.5276711820905067 idx= (np.int64(15), np.int64(10), np.int64(173), np.int64(121))
# selected elements: 30109
# ------------
# cluster= 11
# amplitude= 0.5067685875763034 idx= (np.int64(14), np.int64(9), np.int64(128), np.int64(27))
# selected elements: 26625
# ------------
# cluster= 12
# amplitude= 0.47416572200933 idx= (np.int64(8), np.int64(0), np.int64(50), np.int64(60))
# selected elements: 39860
# ------------
# cluster= 13
# amplitude= 0.47107194965875937 idx= (np.int64(1), np.int64(3), np.int64(72), np.int64(63))
# selected elements: 46935
# ------------
# cluster= 14
# amplitude= 0.4532882293631612 idx= (np.int64(13), np.int64(4), np.int64(121), np.int64(74))
# selected elements: 17966
# ------------
# cluster= 15
# amplitude= 0.4225991019507444 idx= (np.int64(8), np.int64(5), np.int64(123), np.int64(58))
# selected elements: 124755
# ------------
# cluster= 16
# amplitude= 0.4167611433871618 idx= (np.int64(11), np.int64(8), np.int64(136), np.int64(26))
# selected elements: 17675
# ------------
# cluster= 17
# amplitude= 0.4075510917664475 idx= (np.int64(15), np.int64(7), np.int64(132), np.int64(33))
# selected elements: 5660
# ------------
# cluster= 18
# amplitude= 0.39788706624400394 idx= (np.int64(6), np.int64(2), np.int64(108), np.int64(116))
# selected elements: 17434
# ------------
# cluster= 19
# amplitude= 0.3924616170898064 idx= (np.int64(11), np.int64(9), np.int64(60), np.int64(5))
# selected elements: 30802
# ------------
# cluster= 20
# amplitude= 0.390049220127853 idx= (np.int64(11), np.int64(17), np.int64(51), np.int64(52))
# selected elements: 52281
# ------------
# cluster= 21
# amplitude= 0.3873799605276408 idx= (np.int64(11), np.int64(10), np.int64(73), np.int64(144))
# selected elements: 1330
# ------------
# cluster= 22
# amplitude= 0.3845408614881244 idx= (np.int64(14), np.int64(16), np.int64(178), np.int64(133))
# selected elements: 13523
# ------------
# cluster= 23
# amplitude= 0.37840970828462006 idx= (np.int64(6), np.int64(10), np.int64(144), np.int64(142))
# selected elements: 5705
# ------------
# cluster= 24
# amplitude= 0.3723942404728696 idx= (np.int64(7), np.int64(7), np.int64(183), np.int64(114))
# selected elements: 27399
# ------------
# cluster= 25
# amplitude= 0.3687025572842864 idx= (np.int64(11), np.int64(3), np.int64(52), np.int64(27))
# selected elements: 1402
# ------------
# cluster= 26
# amplitude= 0.3524388440718544 idx= (np.int64(8), np.int64(13), np.int64(42), np.int64(95))
# selected elements: 1044
# ------------
# cluster= 27
# amplitude= 0.34516400756287324 idx= (np.int64(12), np.int64(16), np.int64(81), np.int64(119))
# selected elements: 14938
# ------------
# cluster= 28
# amplitude= 0.344811397033729 idx= (np.int64(0), np.int64(3), np.int64(98), np.int64(41))
# selected elements: 1484
# ------------
# cluster= 29
# amplitude= 0.34245949791872177 idx= (np.int64(10), np.int64(0), np.int64(162), np.int64(70))
# selected elements: 2320
# ------------
# cluster= 30
# amplitude= 0.3412953241796681 idx= (np.int64(6), np.int64(8), np.int64(99), np.int64(102))
# selected elements: 18733
# ------------
# cluster= 31
# amplitude= 0.34121347086667475 idx= (np.int64(13), np.int64(8), np.int64(57), np.int64(58))
# selected elements: 1658
# ------------
# cluster= 32
# amplitude= 0.3410830587981554 idx= (np.int64(15), np.int64(7), np.int64(87), np.int64(141))
# selected elements: 4518
# ------------
# cluster= 33
# amplitude= 0.33717631842853824 idx= (np.int64(15), np.int64(5), np.int64(32), np.int64(96))
# selected elements: 14250
# ------------
# cluster= 34
# amplitude= 0.3265820592486655 idx= (np.int64(6), np.int64(6), np.int64(163), np.int64(117))
# selected elements: 8930
# ------------
# cluster= 35
# amplitude= 0.32087246682486836 idx= (np.int64(7), np.int64(4), np.int64(115), np.int64(104))
# selected elements: 440
# ------------
# cluster= 36
# amplitude= 0.31864795769376164 idx= (np.int64(3), np.int64(8), np.int64(220), np.int64(63))
# selected elements: 16860
# ------------
# cluster= 37
# amplitude= 0.3138943916745157 idx= (np.int64(8), np.int64(7), np.int64(102), np.int64(102))
# selected elements: 8223
# ------------
# cluster= 38
# amplitude= 0.31367886863741284 idx= (np.int64(4), np.int64(4), np.int64(66), np.int64(49))
# selected elements: 10691
# ------------
# cluster= 39
# amplitude= 0.31217443235430503 idx= (np.int64(9), np.int64(11), np.int64(72), np.int64(142))
# selected elements: 2850
# ------------
# cluster= 40
# amplitude= 0.30511681378185307 idx= (np.int64(10), np.int64(0), np.int64(64), np.int64(135))
# selected elements: 5968
# ------------
# cluster= 41
# amplitude= 0.3042328583414054 idx= (np.int64(9), np.int64(8), np.int64(59), np.int64(6))
# selected elements: 3978
# ------------
# cluster= 42
# amplitude= 0.3010360165346891 idx= (np.int64(5), np.int64(11), np.int64(46), np.int64(113))
# selected elements: 19441
# ------------
# cluster= 43
# amplitude= 0.3000108260187276 idx= (np.int64(2), np.int64(2), np.int64(99), np.int64(40))
# selected elements: 1161
# ------------
# cluster= 44
# amplitude= 0.2998588155403538 idx= (np.int64(9), np.int64(16), np.int64(164), np.int64(82))
# selected elements: 5286
# ------------
# cluster= 45
# amplitude= 0.2991619670380612 idx= (np.int64(15), np.int64(13), np.int64(274), np.int64(118))
# selected elements: 12185
# ------------
# cluster= 46
# amplitude= 0.29909820312419927 idx= (np.int64(8), np.int64(9), np.int64(60), np.int64(6))
# selected elements: 2697
# ------------
# cluster= 47
# amplitude= 0.2985870814113529 idx= (np.int64(5), np.int64(9), np.int64(74), np.int64(142))
# selected elements: 753
# ------------
# cluster= 48
# amplitude= 0.2943816629464324 idx= (np.int64(1), np.int64(12), np.int64(158), np.int64(75))
# selected elements: 925
# ------------
# cluster= 49
# amplitude= 0.2930989084227787 idx= (np.int64(7), np.int64(16), np.int64(167), np.int64(81))
# selected elements: 1731
# ------------
# cluster= 50
# amplitude= 0.29253204267990013 idx= (np.int64(7), np.int64(14), np.int64(39), np.int64(94))
# selected elements: 638
# ------------
# cluster= 51
# amplitude= 0.29096409808591867 idx= (np.int64(9), np.int64(16), np.int64(76), np.int64(117))
# selected elements: 15136
# ------------
# cluster= 52
# amplitude= 0.283371310300965 idx= (np.int64(5), np.int64(9), np.int64(48), np.int64(104))
# selected elements: 1032
# ------------
# cluster= 53
# amplitude= 0.2827945017046249 idx= (np.int64(5), np.int64(3), np.int64(24), np.int64(114))
# selected elements: 9132
# ------------
# cluster= 54
# amplitude= 0.2815822432537519 idx= (np.int64(4), np.int64(7), np.int64(131), np.int64(68))
# selected elements: 1814
# ------------
# cluster= 55
# amplitude= 0.2804713037951085 idx= (np.int64(3), np.int64(15), np.int64(137), np.int64(75))
# selected elements: 1823
# ------------
# cluster= 56
# amplitude= 0.28031429384743656 idx= (np.int64(3), np.int64(4), np.int64(115), np.int64(103))
# selected elements: 1532
# ------------
# cluster= 57
# amplitude= 0.276652816279324 idx= (np.int64(10), np.int64(11), np.int64(251), np.int64(134))
# selected elements: 1532
# ------------
# cluster= 58
# amplitude= 0.274846524554634 idx= (np.int64(4), np.int64(5), np.int64(164), np.int64(115))
# selected elements: 4159
# ------------
# cluster= 59
# amplitude= 0.27315660641295564 idx= (np.int64(4), np.int64(1), np.int64(23), np.int64(123))
# selected elements: 4209
# ------------
# cluster= 60
# amplitude= 0.2713195022484877 idx= (np.int64(1), np.int64(7), np.int64(154), np.int64(31))
# selected elements: 4218
# ------------
# cluster= 61
# amplitude= 0.2640357877618977 idx= (np.int64(1), np.int64(4), np.int64(53), np.int64(99))
# selected elements: 5020
# ------------
# cluster= 62
# amplitude= 0.26224408928551746 idx= (np.int64(4), np.int64(6), np.int64(263), np.int64(34))
# selected elements: 9322
# ------------
# cluster= 63
# amplitude= 0.2604147492129025 idx= (np.int64(2), np.int64(3), np.int64(178), np.int64(86))
# selected elements: 12588
# ------------
# cluster= 64
# amplitude= 0.26037069100142823 idx= (np.int64(3), np.int64(10), np.int64(100), np.int64(78))
# selected elements: 1875
# ------------
# cluster= 65
# amplitude= 0.2596431770662751 idx= (np.int64(2), np.int64(8), np.int64(127), np.int64(95))
# selected elements: 5406
# ------------
# cluster= 66
# amplitude= 0.2576854506665016 idx= (np.int64(14), np.int64(9), np.int64(139), np.int64(148))
# selected elements: 371
# ------------
# cluster= 67
# amplitude= 0.25634524908844214 idx= (np.int64(3), np.int64(15), np.int64(170), np.int64(105))
# selected elements: 1515
# ------------
# cluster= 68
# amplitude= 0.2562538226482628 idx= (np.int64(8), np.int64(0), np.int64(65), np.int64(135))
# selected elements: 3571
# ------------
# cluster= 69
# amplitude= 0.25554594076722614 idx= (np.int64(9), np.int64(0), np.int64(184), np.int64(103))
# selected elements: 7522
# ------------
# cluster= 70
# amplitude= 0.2555199260925647 idx= (np.int64(0), np.int64(1), np.int64(40), np.int64(45))
# selected elements: 4824
# ------------
# cluster= 71
# amplitude= 0.254987158923106 idx= (np.int64(2), np.int64(14), np.int64(140), np.int64(77))
# selected elements: 698
# ------------
# cluster= 72
# amplitude= 0.25407544914852037 idx= (np.int64(1), np.int64(5), np.int64(64), np.int64(17))
# selected elements: 5538
# ------------
# cluster= 73
# amplitude= 0.2539679361970224 idx= (np.int64(8), np.int64(2), np.int64(54), np.int64(36))
# selected elements: 1574
# ------------
# cluster= 74
# amplitude= 0.2532041673175432 idx= (np.int64(3), np.int64(6), np.int64(126), np.int64(47))
# selected elements: 2300
# ------------
# cluster= 75
# amplitude= 0.25304264713238345 idx= (np.int64(3), np.int64(13), np.int64(78), np.int64(71))
# selected elements: 3104
# ------------
# cluster= 76
# amplitude= 0.25140087014873364 idx= (np.int64(12), np.int64(17), np.int64(9), np.int64(76))
# selected elements: 4110
# ------------
# cluster= 77
# amplitude= 0.25118990496852234 idx= (np.int64(3), np.int64(9), np.int64(79), np.int64(90))
# selected elements: 2036
# ------------
# cluster= 78
# amplitude= 0.25009939129817654 idx= (np.int64(5), np.int64(7), np.int64(128), np.int64(45))
# selected elements: 1504
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 96.82it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=3600:4200  saved to outputs_decompose2d_slices\x_03600_04200
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.3629574517315485 idx= (np.int64(10), np.int64(11), np.int64(97), np.int64(50))
# selected elements: 102787
# ------------
# cluster= 1
# amplitude= 0.2587942917665956 idx= (np.int64(11), np.int64(13), np.int64(69), np.int64(104))
# selected elements: 61239
# ------------
# cluster= 2
# amplitude= 0.2505652196591013 idx= (np.int64(15), np.int64(10), np.int64(223), np.int64(33))
# selected elements: 30893
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 68.16it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=4200:4800  saved to outputs_decompose2d_slices\x_04200_04800
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 90.19it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=4800:5400  saved to outputs_decompose2d_slices\x_04800_05400
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 60.15it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=5400:5451  saved to outputs_decompose2d_slices\x_05400_05451
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 65.70it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Done. Outputs in C:\Users\domin\juwavelet\examples\outputs_decompose2d_slices

# %% [markdown]
# ## Stitch all

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Optional, Dict, Any, List

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

# --------------------------
# User params
# --------------------------
FILE_PATH = "awe_l5c_q20_2024165T2120_03175_v01.nc"
FRAME_IDX = 0

# Loop settings on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 16
JT = 18
ASPECT = 1

# Pixel spacing (km/pixel) for plotting and CWT (wavelengths will be in km)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# Clustering thresholds
MIN_AMP = 0.25
THR = 0.1

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices")
SAVE_DPI = 200

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Helpers (yours, mostly unchanged)
# --------------------------
def read_radiance_frame(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        rad = nc.variables["Radiance"][:]  # (t, y, x)
    if rad.ndim != 3:
        raise ValueError(f"Radiance expected 3D (t,y,x); got {rad.shape}")
    if not (0 <= frame_idx < rad.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{rad.shape[0]-1}")
    return np.asarray(rad[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def load_radiance_window_from_array(
    Z: np.ndarray, xsl: slice, ysl: slice
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    win = np.asarray(Z[ysl, xsl], dtype=float)
    ny, nx = win.shape
    x = np.arange(nx, dtype=float)
    y = np.arange(ny, dtype=float)
    return x, y, win


def pad_window_to_width(win: np.ndarray, target_width: int) -> np.ndarray:
    ny, nx = win.shape
    if nx >= target_width:
        return win
    pad = target_width - nx
    med = float(np.nanmedian(win)) if np.isfinite(np.nanmedian(win)) else 0.0
    right = np.full((ny, pad), med, dtype=float)
    return np.concatenate([win, right], axis=1)


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    u = np.cos(theta_xy)
    v = np.sin(theta_xy)
    return u, v


def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("Radiance (arb)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    stacked = np.concatenate([orig_c.ravel(), bg_c.ravel(), rem_c.ravel(), rem_tapered_c.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [1, 99])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    fig, axs = plt.subplots(2, 2, figsize=(12, 10), constrained_layout=True)
    axes = axs.flatten()

    panels = [
        (orig_c, "Original (median-sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    im0 = None
    for ax, (Z, title) in zip(axes, panels):
        im0 = ax.pcolormesh(
            x1d_km, y1d_km, Z, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    cbar = fig.colorbar(im0, ax=axs, orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("Radiance (arb)")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2

    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_low, bg_high = np.nanpercentile(bg_xy, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax

    cl_low, cl_high = np.nanpercentile(rec_xy, [2, 98])
    cl_vmax = max(abs(cl_low), abs(cl_high))
    if not np.isfinite(cl_vmax) or cl_vmax == 0:
        cl_vmax = 1.0
    cl_vmin = -cl_vmax

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if not np.isfinite(lam_vmin) or not np.isfinite(lam_vmax) or lam_vmin == lam_vmax:
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n" + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        ARROW_LEN_KM = 40.0
        u = u * ARROW_LEN_KM
        v = v * ARROW_LEN_KM

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)


# --------------------------
# Main pipeline for one slice
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray, x_slice: slice, outdir: Path, x_start_unbinned: int
) -> Dict[str, Any]:
    """
    Returns minimal arrays needed to stitch final "08" and "09" across slices.
    Everything else is still saved per-slice in outdir.
    """
    outdir.mkdir(parents=True, exist_ok=True)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        dx_km = DX_KM_BASE * int(BIN_FACTOR)
        dy_km = DY_KM_BASE * int(BIN_FACTOR)
        f = int(BIN_FACTOR)
    else:
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE
        f = 1

    # Window on unbinned flattened field
    _, _, raw_win = load_radiance_window_from_array(rad2d_flat, x_slice, Y_SLICE)

    # Pad last chunk to width 600 if needed
    raw_win = pad_window_to_width(raw_win, X_CHUNK)

    # Optional binning
    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape

    # IMPORTANT:
    # Per-slice x is local; for stitched plots we'll offset by x_start_unbinned * DX_KM_BASE.
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"Radiance (window, flattened){bin_tag}",
        outdir / "00_radiance_window.png",
    )

    # Background separation
    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_4panel.png",
    )

    # Preprocess for CWT
    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=MIN_AMP, thr=THR)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    # Overview decomposition plot
    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N
    )
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    # FOV wavelet spectrum (grab current fig after the call)
    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text("No clusters found. Try lowering MIN_AMP or THR.\n")
        return {
            "has_clusters": False,
            "x_start_unbinned": x_start_unbinned,
            "dx_km": dx_km,
            "dy_km": dy_km,
            "power_xy": np.full_like(proc, np.nan),
            "remaining_xy": proc,
            "rec_all_xy": np.full_like(proc, np.nan),
        }

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    # Write ranking to text file
    lines = []
    lines.append("Cluster power ranking (clustered only)\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))

    theta_vals = np.asarray(cwt["theta"], dtype=float)

    # Figure 1: standalone clusters
    fig1, axs1 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs1 = np.atleast_1d(axs1).reshape(-1)

    opts_cluster = {"cmap": "RdBu_r", "vmin": -1.0, "vmax": 1.0, "rasterized": True}

    for ax, kcl in zip(axs1, biggest):
        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", **opts_cluster)
        ax.set_aspect("equal", adjustable="box")

    for ax in axs1[n_show:]:
        ax.axis("off")
    for ax in axs1[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}
    for i, ax in enumerate(axs1, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig1.tight_layout()
    save_fig(fig1, outdir / "05_clusters_standalone.png")

    # Figure 2: overlays
    fig2, axs2 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs2 = np.atleast_1d(axs2).reshape(-1)

    bg_low, bg_high = np.nanpercentile(bg, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax
    cl_vmin, cl_vmax = -1.0, 1.0

    for ax, kcl in zip(axs2, biggest):
        ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)

        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.pcolormesh(
            x1d_km, y1d_km, rec_centered,
            shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
        )

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.set_aspect("equal", adjustable="box")

    for ax in axs2[n_show:]:
        ax.axis("off")
    for ax in axs2[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    for i, ax in enumerate(axs2, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig2.tight_layout()
    save_fig(fig2, outdir / "06_clusters_overlay.png")

    # Per cluster 2x2
    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
        )

    # --------------------------
    # Clustered-only total power per pixel
    # (linear power, log-scaled colorbar)
    # --------------------------
    dec0 = orig_decomp
    power4d = np.abs(dec0) ** 2

    clustered_power4d = np.where(iwave >= 0, power4d, 0.0)

    power_xy = np.sum(clustered_power4d, axis=(0, 1))  # (nx, ny)
    power_xy = power_xy.T                               # (ny, nx)
    power_xy = np.where(power_xy > 0, power_xy, np.nan)

    good = np.isfinite(power_xy)
    if np.any(good):
        vmin, vmax = np.nanpercentile(power_xy[good], [2, 98])
        vmin = max(vmin, np.nanmin(power_xy[good]))
        vmax = max(vmax, vmin * 10)
    else:
        vmin, vmax = 1e-6, 1.0

    figP, axP = plt.subplots(figsize=(12, 6), constrained_layout=True)
    imP = axP.pcolormesh(
        x1d_km,
        y1d_km,
        power_xy,
        shading="auto",
        cmap="magma",
        norm=matplotlib.colors.LogNorm(vmin=vmin, vmax=vmax),
    )
    axP.set_title("Clustered-only total wavelet power per pixel")
    axP.set_xlabel("x (km)")
    axP.set_ylabel("y (km)")
    axP.set_aspect("equal", adjustable="box")
    cbar = figP.colorbar(imP, ax=axP, fraction=0.046, pad=0.02)
    cbar.set_label(r"$\sum_{(s,t)\in clusters} |\mathrm{coeff}|^2$")
    save_fig(figP, outdir / "08_clustered_total_power_logcolor.png")

    # --------------------------
    # Remaining (after preprocessing) vs All clusters combined
    # --------------------------
    remaining_after_preproc_xy = proc  # (ny, nx)

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)          # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)     # (ny, nx)

    stacked = np.concatenate([remaining_after_preproc_xy.ravel(), rec_all_xy.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [2, 98])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    figR, (axL, axR) = plt.subplots(1, 2, figsize=(16, 6), constrained_layout=True)

    imL = axL.pcolormesh(
        x1d_km, y1d_km, remaining_after_preproc_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axL.set_title("Remaining (after preprocessing, input to CWT)")
    axL.set_xlabel("x (km)")
    axL.set_ylabel("y (km)")
    axL.set_aspect("equal", adjustable="box")
    figR.colorbar(imL, ax=axL, fraction=0.046, pad=0.02).set_label("arb")

    imR = axR.pcolormesh(
        x1d_km, y1d_km, rec_all_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axR.set_title("All clusters combined (reconstruction)")
    axR.set_xlabel("x (km)")
    axR.set_ylabel("y (km)")
    axR.set_aspect("equal", adjustable="box")
    figR.colorbar(imR, ax=axR, fraction=0.046, pad=0.02).set_label("arb")

    save_fig(figR, outdir / "09_remaining_vs_all_clusters.png")

    # Restore decomposition for anything that follows
    decomposition[:] = orig_decomp

    return {
        "has_clusters": True,
        "x_start_unbinned": x_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "power_xy": power_xy,                       # (ny, nx)
        "remaining_xy": remaining_after_preproc_xy, # (ny, nx)
        "rec_all_xy": rec_all_xy,                   # (ny, nx)
    }

# --------------------------
# Stitch helper for final 08 and 09
# --------------------------
def stitch_and_save_final_08_09(slice_results: List[Dict[str, Any]], outroot: Path) -> None:
    if len(slice_results) == 0:
        return

    # Assume consistent binning across slices
    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    
    # --- how far from x=0 this run starts (in km) ---
    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE
    
    # --- number of columns to pad on the left (in BINNED pixels) ---
    n_pad = int(round(x0_km / dx_km))
    
    # Concatenate real data
    power_stitched = np.concatenate([d["power_xy"] for d in slice_results], axis=1)
    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)
    
    ny, nx_real = power_stitched.shape
    
    # --- pad left with NaNs so x starts at 0 km ---
    pad_shape = (ny, n_pad)
    pad = np.full(pad_shape, np.nan)
    
    power_stitched = np.concatenate([pad, power_stitched], axis=1)
    remaining_stitched = np.concatenate([pad, remaining_stitched], axis=1)
    rec_all_stitched = np.concatenate([pad, rec_all_stitched], axis=1)
    
    nx_tot = power_stitched.shape[1]
    
    # x and y coordinates now start at 0
    x1d_km = np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km


    # ----- Final 08: stitched clustered total power (log color) -----
    good = np.isfinite(power_stitched) & (power_stitched > 0)
    if np.any(good):
        vmin, vmax = np.nanpercentile(power_stitched[good], [2, 98])
        vmin = max(vmin, np.nanmin(power_stitched[good]))
        vmax = max(vmax, vmin * 10)
    else:
        vmin, vmax = 1e-6, 1.0

    figP, axP = plt.subplots(figsize=(18, 6), constrained_layout=True)
    imP = axP.pcolormesh(
        x1d_km, y1d_km, power_stitched,
        shading="auto", cmap="magma",
        norm=matplotlib.colors.LogNorm(vmin=vmin, vmax=vmax),
    )
    axP.set_title("STITCHED: Clustered-only total wavelet power per pixel")
    axP.set_xlabel("x (km)")
    axP.set_ylabel("y (km)")
    axP.set_aspect("equal", adjustable="box")
    cbar = figP.colorbar(imP, ax=axP, fraction=0.025, pad=0.02)
    cbar.set_label(r"$\sum_{(s,t)\in clusters} |\mathrm{coeff}|^2$")
    save_fig(figP, outroot / "FINAL_08_clustered_total_power_logcolor_STITCHED.png")

    # ----- Final 09: stitched remaining vs stitched all-clusters reconstruction (TOP/BOTTOM, one colorbar) -----
    stacked = np.concatenate([remaining_stitched.ravel(), rec_all_stitched.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [2, 98])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    figR, (axT, axB) = plt.subplots(2, 1, figsize=(18, 6), constrained_layout=True, sharex=True, sharey=True)

    imT = axT.pcolormesh(
        x1d_km, y1d_km, remaining_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axT.set_title("STITCHED: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(
        x1d_km, y1d_km, rec_all_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axB.set_title("STITCHED: All clusters combined (reconstruction)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")
    # set x range in km
    xmin_km = 600
    xmax_km = 10000
    
    axT.set_xlim(xmin_km, xmax_km)

    cbar = figR.colorbar(imT, ax=[axT, axB], orientation="vertical", fraction=0.01, pad=0.01)
    cbar.set_label("kRayleigh (Relative)")

    save_fig(figR, outroot / "FINAL_09_remaining_vs_all_clusters_STITCHED.png")

# --------------------------
# Run all slices
# --------------------------
def run_all_slices() -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_radiance_frame(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    for x_offset in [0, 300]:
        # Make sure we don't start beyond the image
        if x_offset >= nx_total:
            print(f"Skip offset {x_offset}: nx_total={nx_total}")
            continue

        outroot = OUTPUT_ROOT / f"offset_{x_offset:04d}"
        outroot.mkdir(parents=True, exist_ok=True)

        starts = list(range(x_offset, nx_total, X_CHUNK))

        stitch_results: List[Dict[str, Any]] = []

        for start in starts:
            end = min(start + X_CHUNK, nx_total)
            x_slice = slice(start, end)

            outdir = outroot / f"x_{start:05d}_{end:05d}"
            print(f"[offset {x_offset}] Running slice x={start}:{end}  saved to {outdir}")
            res = run_pipeline_for_slice(rad2d_flat, x_slice, outdir, x_start_unbinned=start)
            stitch_results.append(res)

        stitch_and_save_final_08_09(stitch_results, outroot)
        print(f"[offset {x_offset}] Done. Outputs in {outroot.resolve()}")


run_all_slices()
# Out:
# [offset 0] Running slice x=0:600  saved to outputs_decompose2d_slices\offset_0000\x_00000_00600
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.3633801038963466 idx= (np.int64(14), np.int64(11), np.int64(273), np.int64(48))
# selected elements: 93901
# ------------
# cluster= 1
# amplitude= 0.34361284116798607 idx= (np.int64(13), np.int64(9), np.int64(205), np.int64(118))
# selected elements: 80570
# ------------
# cluster= 2
# amplitude= 0.3323259916824853 idx= (np.int64(15), np.int64(8), np.int64(207), np.int64(114))
# selected elements: 10312
# ------------
# cluster= 3
# amplitude= 0.3177325833594557 idx= (np.int64(12), np.int64(8), np.int64(255), np.int64(74))
# selected elements: 13099
# ------------
# cluster= 4
# amplitude= 0.3060403313494669 idx= (np.int64(10), np.int64(9), np.int64(255), np.int64(78))
# selected elements: 15810
# ------------
# cluster= 5
# amplitude= 0.27599177604302805 idx= (np.int64(5), np.int64(7), np.int64(274), np.int64(60))
# selected elements: 11573
# ------------
# cluster= 6
# amplitude= 0.26529795328716194 idx= (np.int64(5), np.int64(10), np.int64(197), np.int64(116))
# selected elements: 1744
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|███████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 105.87it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Running slice x=600:1200  saved to outputs_decompose2d_slices\offset_0000\x_00600_01200
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.48029566505987614 idx= (np.int64(6), np.int64(8), np.int64(216), np.int64(25))
# selected elements: 53071
# ------------
# cluster= 1
# amplitude= 0.47279106777584856 idx= (np.int64(5), np.int64(9), np.int64(218), np.int64(24))
# selected elements: 5651
# ------------
# cluster= 2
# amplitude= 0.4070410761070086 idx= (np.int64(8), np.int64(9), np.int64(24), np.int64(50))
# selected elements: 141658
# ------------
# cluster= 3
# amplitude= 0.4060660593723358 idx= (np.int64(7), np.int64(8), np.int64(25), np.int64(51))
# selected elements: 2190
# ------------
# cluster= 4
# amplitude= 0.33581535498628523 idx= (np.int64(10), np.int64(9), np.int64(175), np.int64(6))
# selected elements: 34772
# ------------
# cluster= 5
# amplitude= 0.33530601011687994 idx= (np.int64(10), np.int64(11), np.int64(46), np.int64(43))
# selected elements: 34096
# ------------
# cluster= 6
# amplitude= 0.29192079216239186 idx= (np.int64(13), np.int64(8), np.int64(225), np.int64(28))
# selected elements: 8181
# ------------
# cluster= 7
# amplitude= 0.272193972757914 idx= (np.int64(9), np.int64(10), np.int64(256), np.int64(10))
# selected elements: 6058
# ------------
# cluster= 8
# amplitude= 0.2646144304845612 idx= (np.int64(2), np.int64(8), np.int64(32), np.int64(53))
# selected elements: 1752
# ------------
# cluster= 9
# amplitude= 0.26188274310444415 idx= (np.int64(14), np.int64(10), np.int64(134), np.int64(8))
# selected elements: 18716
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 84.74it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Running slice x=1200:1800  saved to outputs_decompose2d_slices\offset_0000\x_01200_01800
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 97.01it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Running slice x=1800:2400  saved to outputs_decompose2d_slices\offset_0000\x_01800_02400
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.31431867394382457 idx= (np.int64(15), np.int64(8), np.int64(268), np.int64(125))
# selected elements: 60665
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 92.56it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Running slice x=2400:3000  saved to outputs_decompose2d_slices\offset_0000\x_02400_03000
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.36556940836865687 idx= (np.int64(14), np.int64(2), np.int64(267), np.int64(109))
# selected elements: 69848
# ------------
# cluster= 1
# amplitude= 0.34434639833925845 idx= (np.int64(8), np.int64(5), np.int64(226), np.int64(80))
# selected elements: 126779
# ------------
# cluster= 2
# amplitude= 0.2748148536362068 idx= (np.int64(14), np.int64(1), np.int64(116), np.int64(124))
# selected elements: 42397
# ------------
# cluster= 3
# amplitude= 0.26606846962667713 idx= (np.int64(3), np.int64(3), np.int64(283), np.int64(113))
# selected elements: 17014
# ------------
# cluster= 4
# amplitude= 0.2588774345521047 idx= (np.int64(10), np.int64(1), np.int64(84), np.int64(105))
# selected elements: 15971
# ------------
# cluster= 5
# amplitude= 0.2507492546056884 idx= (np.int64(8), np.int64(2), np.int64(285), np.int64(92))
# selected elements: 8388
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 84.72it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Running slice x=3000:3600  saved to outputs_decompose2d_slices\offset_0000\x_03000_03600
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.3214636569113676 idx= (np.int64(9), np.int64(13), np.int64(167), np.int64(94))
# selected elements: 1743278
# ------------
# cluster= 1
# amplitude= 0.8988716386603093 idx= (np.int64(15), np.int64(0), np.int64(51), np.int64(64))
# selected elements: 576349
# ------------
# cluster= 2
# amplitude= 0.6987886607191044 idx= (np.int64(14), np.int64(11), np.int64(109), np.int64(71))
# selected elements: 26660
# ------------
# cluster= 3
# amplitude= 0.6738899027615025 idx= (np.int64(2), np.int64(9), np.int64(148), np.int64(38))
# selected elements: 15892
# ------------
# cluster= 4
# amplitude= 0.6633018310661374 idx= (np.int64(15), np.int64(15), np.int64(87), np.int64(122))
# selected elements: 67812
# ------------
# cluster= 5
# amplitude= 0.6321003861487019 idx= (np.int64(2), np.int64(8), np.int64(180), np.int64(112))
# selected elements: 6978
# ------------
# cluster= 6
# amplitude= 0.594646650250417 idx= (np.int64(2), np.int64(12), np.int64(115), np.int64(65))
# selected elements: 10198
# ------------
# cluster= 7
# amplitude= 0.5748976990014023 idx= (np.int64(15), np.int64(15), np.int64(183), np.int64(126))
# selected elements: 3020
# ------------
# cluster= 8
# amplitude= 0.5619048658867282 idx= (np.int64(15), np.int64(5), np.int64(123), np.int64(77))
# selected elements: 46092
# ------------
# cluster= 9
# amplitude= 0.5514656651686213 idx= (np.int64(10), np.int64(2), np.int64(41), np.int64(91))
# selected elements: 77439
# ------------
# cluster= 10
# amplitude= 0.5276711820905067 idx= (np.int64(15), np.int64(10), np.int64(173), np.int64(121))
# selected elements: 30109
# ------------
# cluster= 11
# amplitude= 0.5067685875763034 idx= (np.int64(14), np.int64(9), np.int64(128), np.int64(27))
# selected elements: 26625
# ------------
# cluster= 12
# amplitude= 0.47416572200933 idx= (np.int64(8), np.int64(0), np.int64(50), np.int64(60))
# selected elements: 39860
# ------------
# cluster= 13
# amplitude= 0.47107194965875937 idx= (np.int64(1), np.int64(3), np.int64(72), np.int64(63))
# selected elements: 46935
# ------------
# cluster= 14
# amplitude= 0.4532882293631612 idx= (np.int64(13), np.int64(4), np.int64(121), np.int64(74))
# selected elements: 17966
# ------------
# cluster= 15
# amplitude= 0.4225991019507444 idx= (np.int64(8), np.int64(5), np.int64(123), np.int64(58))
# selected elements: 124755
# ------------
# cluster= 16
# amplitude= 0.4167611433871618 idx= (np.int64(11), np.int64(8), np.int64(136), np.int64(26))
# selected elements: 17675
# ------------
# cluster= 17
# amplitude= 0.4075510917664475 idx= (np.int64(15), np.int64(7), np.int64(132), np.int64(33))
# selected elements: 5660
# ------------
# cluster= 18
# amplitude= 0.39788706624400394 idx= (np.int64(6), np.int64(2), np.int64(108), np.int64(116))
# selected elements: 17434
# ------------
# cluster= 19
# amplitude= 0.3924616170898064 idx= (np.int64(11), np.int64(9), np.int64(60), np.int64(5))
# selected elements: 30802
# ------------
# cluster= 20
# amplitude= 0.390049220127853 idx= (np.int64(11), np.int64(17), np.int64(51), np.int64(52))
# selected elements: 52281
# ------------
# cluster= 21
# amplitude= 0.3873799605276408 idx= (np.int64(11), np.int64(10), np.int64(73), np.int64(144))
# selected elements: 1330
# ------------
# cluster= 22
# amplitude= 0.3845408614881244 idx= (np.int64(14), np.int64(16), np.int64(178), np.int64(133))
# selected elements: 13523
# ------------
# cluster= 23
# amplitude= 0.37840970828462006 idx= (np.int64(6), np.int64(10), np.int64(144), np.int64(142))
# selected elements: 5705
# ------------
# cluster= 24
# amplitude= 0.3723942404728696 idx= (np.int64(7), np.int64(7), np.int64(183), np.int64(114))
# selected elements: 27399
# ------------
# cluster= 25
# amplitude= 0.3687025572842864 idx= (np.int64(11), np.int64(3), np.int64(52), np.int64(27))
# selected elements: 1402
# ------------
# cluster= 26
# amplitude= 0.3524388440718544 idx= (np.int64(8), np.int64(13), np.int64(42), np.int64(95))
# selected elements: 1044
# ------------
# cluster= 27
# amplitude= 0.34516400756287324 idx= (np.int64(12), np.int64(16), np.int64(81), np.int64(119))
# selected elements: 14938
# ------------
# cluster= 28
# amplitude= 0.344811397033729 idx= (np.int64(0), np.int64(3), np.int64(98), np.int64(41))
# selected elements: 1484
# ------------
# cluster= 29
# amplitude= 0.34245949791872177 idx= (np.int64(10), np.int64(0), np.int64(162), np.int64(70))
# selected elements: 2320
# ------------
# cluster= 30
# amplitude= 0.3412953241796681 idx= (np.int64(6), np.int64(8), np.int64(99), np.int64(102))
# selected elements: 18733
# ------------
# cluster= 31
# amplitude= 0.34121347086667475 idx= (np.int64(13), np.int64(8), np.int64(57), np.int64(58))
# selected elements: 1658
# ------------
# cluster= 32
# amplitude= 0.3410830587981554 idx= (np.int64(15), np.int64(7), np.int64(87), np.int64(141))
# selected elements: 4518
# ------------
# cluster= 33
# amplitude= 0.33717631842853824 idx= (np.int64(15), np.int64(5), np.int64(32), np.int64(96))
# selected elements: 14250
# ------------
# cluster= 34
# amplitude= 0.3265820592486655 idx= (np.int64(6), np.int64(6), np.int64(163), np.int64(117))
# selected elements: 8930
# ------------
# cluster= 35
# amplitude= 0.32087246682486836 idx= (np.int64(7), np.int64(4), np.int64(115), np.int64(104))
# selected elements: 440
# ------------
# cluster= 36
# amplitude= 0.31864795769376164 idx= (np.int64(3), np.int64(8), np.int64(220), np.int64(63))
# selected elements: 16860
# ------------
# cluster= 37
# amplitude= 0.3138943916745157 idx= (np.int64(8), np.int64(7), np.int64(102), np.int64(102))
# selected elements: 8223
# ------------
# cluster= 38
# amplitude= 0.31367886863741284 idx= (np.int64(4), np.int64(4), np.int64(66), np.int64(49))
# selected elements: 10691
# ------------
# cluster= 39
# amplitude= 0.31217443235430503 idx= (np.int64(9), np.int64(11), np.int64(72), np.int64(142))
# selected elements: 2850
# ------------
# cluster= 40
# amplitude= 0.30511681378185307 idx= (np.int64(10), np.int64(0), np.int64(64), np.int64(135))
# selected elements: 5968
# ------------
# cluster= 41
# amplitude= 0.3042328583414054 idx= (np.int64(9), np.int64(8), np.int64(59), np.int64(6))
# selected elements: 3978
# ------------
# cluster= 42
# amplitude= 0.3010360165346891 idx= (np.int64(5), np.int64(11), np.int64(46), np.int64(113))
# selected elements: 19441
# ------------
# cluster= 43
# amplitude= 0.3000108260187276 idx= (np.int64(2), np.int64(2), np.int64(99), np.int64(40))
# selected elements: 1161
# ------------
# cluster= 44
# amplitude= 0.2998588155403538 idx= (np.int64(9), np.int64(16), np.int64(164), np.int64(82))
# selected elements: 5286
# ------------
# cluster= 45
# amplitude= 0.2991619670380612 idx= (np.int64(15), np.int64(13), np.int64(274), np.int64(118))
# selected elements: 12185
# ------------
# cluster= 46
# amplitude= 0.29909820312419927 idx= (np.int64(8), np.int64(9), np.int64(60), np.int64(6))
# selected elements: 2697
# ------------
# cluster= 47
# amplitude= 0.2985870814113529 idx= (np.int64(5), np.int64(9), np.int64(74), np.int64(142))
# selected elements: 753
# ------------
# cluster= 48
# amplitude= 0.2943816629464324 idx= (np.int64(1), np.int64(12), np.int64(158), np.int64(75))
# selected elements: 925
# ------------
# cluster= 49
# amplitude= 0.2930989084227787 idx= (np.int64(7), np.int64(16), np.int64(167), np.int64(81))
# selected elements: 1731
# ------------
# cluster= 50
# amplitude= 0.29253204267990013 idx= (np.int64(7), np.int64(14), np.int64(39), np.int64(94))
# selected elements: 638
# ------------
# cluster= 51
# amplitude= 0.29096409808591867 idx= (np.int64(9), np.int64(16), np.int64(76), np.int64(117))
# selected elements: 15136
# ------------
# cluster= 52
# amplitude= 0.283371310300965 idx= (np.int64(5), np.int64(9), np.int64(48), np.int64(104))
# selected elements: 1032
# ------------
# cluster= 53
# amplitude= 0.2827945017046249 idx= (np.int64(5), np.int64(3), np.int64(24), np.int64(114))
# selected elements: 9132
# ------------
# cluster= 54
# amplitude= 0.2815822432537519 idx= (np.int64(4), np.int64(7), np.int64(131), np.int64(68))
# selected elements: 1814
# ------------
# cluster= 55
# amplitude= 0.2804713037951085 idx= (np.int64(3), np.int64(15), np.int64(137), np.int64(75))
# selected elements: 1823
# ------------
# cluster= 56
# amplitude= 0.28031429384743656 idx= (np.int64(3), np.int64(4), np.int64(115), np.int64(103))
# selected elements: 1532
# ------------
# cluster= 57
# amplitude= 0.276652816279324 idx= (np.int64(10), np.int64(11), np.int64(251), np.int64(134))
# selected elements: 1532
# ------------
# cluster= 58
# amplitude= 0.274846524554634 idx= (np.int64(4), np.int64(5), np.int64(164), np.int64(115))
# selected elements: 4159
# ------------
# cluster= 59
# amplitude= 0.27315660641295564 idx= (np.int64(4), np.int64(1), np.int64(23), np.int64(123))
# selected elements: 4209
# ------------
# cluster= 60
# amplitude= 0.2713195022484877 idx= (np.int64(1), np.int64(7), np.int64(154), np.int64(31))
# selected elements: 4218
# ------------
# cluster= 61
# amplitude= 0.2640357877618977 idx= (np.int64(1), np.int64(4), np.int64(53), np.int64(99))
# selected elements: 5020
# ------------
# cluster= 62
# amplitude= 0.26224408928551746 idx= (np.int64(4), np.int64(6), np.int64(263), np.int64(34))
# selected elements: 9322
# ------------
# cluster= 63
# amplitude= 0.2604147492129025 idx= (np.int64(2), np.int64(3), np.int64(178), np.int64(86))
# selected elements: 12588
# ------------
# cluster= 64
# amplitude= 0.26037069100142823 idx= (np.int64(3), np.int64(10), np.int64(100), np.int64(78))
# selected elements: 1875
# ------------
# cluster= 65
# amplitude= 0.2596431770662751 idx= (np.int64(2), np.int64(8), np.int64(127), np.int64(95))
# selected elements: 5406
# ------------
# cluster= 66
# amplitude= 0.2576854506665016 idx= (np.int64(14), np.int64(9), np.int64(139), np.int64(148))
# selected elements: 371
# ------------
# cluster= 67
# amplitude= 0.25634524908844214 idx= (np.int64(3), np.int64(15), np.int64(170), np.int64(105))
# selected elements: 1515
# ------------
# cluster= 68
# amplitude= 0.2562538226482628 idx= (np.int64(8), np.int64(0), np.int64(65), np.int64(135))
# selected elements: 3571
# ------------
# cluster= 69
# amplitude= 0.25554594076722614 idx= (np.int64(9), np.int64(0), np.int64(184), np.int64(103))
# selected elements: 7522
# ------------
# cluster= 70
# amplitude= 0.2555199260925647 idx= (np.int64(0), np.int64(1), np.int64(40), np.int64(45))
# selected elements: 4824
# ------------
# cluster= 71
# amplitude= 0.254987158923106 idx= (np.int64(2), np.int64(14), np.int64(140), np.int64(77))
# selected elements: 698
# ------------
# cluster= 72
# amplitude= 0.25407544914852037 idx= (np.int64(1), np.int64(5), np.int64(64), np.int64(17))
# selected elements: 5538
# ------------
# cluster= 73
# amplitude= 0.2539679361970224 idx= (np.int64(8), np.int64(2), np.int64(54), np.int64(36))
# selected elements: 1574
# ------------
# cluster= 74
# amplitude= 0.2532041673175432 idx= (np.int64(3), np.int64(6), np.int64(126), np.int64(47))
# selected elements: 2300
# ------------
# cluster= 75
# amplitude= 0.25304264713238345 idx= (np.int64(3), np.int64(13), np.int64(78), np.int64(71))
# selected elements: 3104
# ------------
# cluster= 76
# amplitude= 0.25140087014873364 idx= (np.int64(12), np.int64(17), np.int64(9), np.int64(76))
# selected elements: 4110
# ------------
# cluster= 77
# amplitude= 0.25118990496852234 idx= (np.int64(3), np.int64(9), np.int64(79), np.int64(90))
# selected elements: 2036
# ------------
# cluster= 78
# amplitude= 0.25009939129817654 idx= (np.int64(5), np.int64(7), np.int64(128), np.int64(45))
# selected elements: 1504
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 77.64it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Running slice x=3600:4200  saved to outputs_decompose2d_slices\offset_0000\x_03600_04200
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.3629574517315485 idx= (np.int64(10), np.int64(11), np.int64(97), np.int64(50))
# selected elements: 102787
# ------------
# cluster= 1
# amplitude= 0.2587942917665956 idx= (np.int64(11), np.int64(13), np.int64(69), np.int64(104))
# selected elements: 61239
# ------------
# cluster= 2
# amplitude= 0.2505652196591013 idx= (np.int64(15), np.int64(10), np.int64(223), np.int64(33))
# selected elements: 30893
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 98.36it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Running slice x=4200:4800  saved to outputs_decompose2d_slices\offset_0000\x_04200_04800
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 79.51it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Running slice x=4800:5400  saved to outputs_decompose2d_slices\offset_0000\x_04800_05400
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 78.03it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Running slice x=5400:5451  saved to outputs_decompose2d_slices\offset_0000\x_05400_05451
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 78.62it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Done. Outputs in C:\Users\domin\juwavelet\examples\outputs_decompose2d_slices\offset_0000
# [offset 300] Running slice x=300:900  saved to outputs_decompose2d_slices\offset_0300\x_00300_00900
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.40835748161299584 idx= (np.int64(8), np.int64(9), np.int64(173), np.int64(50))
# selected elements: 150499
# ------------
# cluster= 1
# amplitude= 0.4057785400059447 idx= (np.int64(7), np.int64(8), np.int64(175), np.int64(51))
# selected elements: 2391
# ------------
# cluster= 2
# amplitude= 0.365874307157586 idx= (np.int64(13), np.int64(12), np.int64(134), np.int64(52))
# selected elements: 57327
# ------------
# cluster= 3
# amplitude= 0.3613517820685231 idx= (np.int64(14), np.int64(9), np.int64(57), np.int64(119))
# selected elements: 97364
# ------------
# cluster= 4
# amplitude= 0.32289302896860395 idx= (np.int64(11), np.int64(11), np.int64(198), np.int64(43))
# selected elements: 16269
# ------------
# cluster= 5
# amplitude= 0.31993875745975364 idx= (np.int64(9), np.int64(11), np.int64(196), np.int64(42))
# selected elements: 10814
# ------------
# cluster= 6
# amplitude= 0.3122137387779015 idx= (np.int64(12), np.int64(7), np.int64(106), np.int64(71))
# selected elements: 35713
# ------------
# cluster= 7
# amplitude= 0.30603962867702217 idx= (np.int64(10), np.int64(9), np.int64(105), np.int64(78))
# selected elements: 7486
# ------------
# cluster= 8
# amplitude= 0.2759813481751512 idx= (np.int64(5), np.int64(7), np.int64(124), np.int64(60))
# selected elements: 13435
# ------------
# cluster= 9
# amplitude= 0.267475629281273 idx= (np.int64(14), np.int64(9), np.int64(235), np.int64(8))
# selected elements: 42709
# ------------
# cluster= 10
# amplitude= 0.2652989393707891 idx= (np.int64(5), np.int64(10), np.int64(47), np.int64(116))
# selected elements: 3753
# ------------
# cluster= 11
# amplitude= 0.26461442817615655 idx= (np.int64(2), np.int64(8), np.int64(182), np.int64(53))
# selected elements: 1806
# ------------
# cluster= 12
# amplitude= 0.2623755891393191 idx= (np.int64(15), np.int64(10), np.int64(281), np.int64(8))
# selected elements: 12335
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 87.60it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Running slice x=900:1500  saved to outputs_decompose2d_slices\offset_0300\x_00900_01500
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.48027429028638086 idx= (np.int64(6), np.int64(8), np.int64(66), np.int64(25))
# selected elements: 51789
# ------------
# cluster= 1
# amplitude= 0.47276604500055736 idx= (np.int64(5), np.int64(9), np.int64(68), np.int64(24))
# selected elements: 4500
# ------------
# cluster= 2
# amplitude= 0.3684121518500088 idx= (np.int64(15), np.int64(9), np.int64(71), np.int64(27))
# selected elements: 48502
# ------------
# cluster= 3
# amplitude= 0.33578394526400007 idx= (np.int64(10), np.int64(9), np.int64(26), np.int64(6))
# selected elements: 13936
# ------------
# cluster= 4
# amplitude= 0.269794132980486 idx= (np.int64(9), np.int64(10), np.int64(106), np.int64(10))
# selected elements: 6231
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 82.08it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Running slice x=1500:2100  saved to outputs_decompose2d_slices\offset_0300\x_01500_02100
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.28141825741829773 idx= (np.int64(6), np.int64(10), np.int64(150), np.int64(134))
# selected elements: 13837
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 61.73it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Running slice x=2100:2700  saved to outputs_decompose2d_slices\offset_0300\x_02100_02700
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.3163105327483466 idx= (np.int64(15), np.int64(8), np.int64(119), np.int64(125))
# selected elements: 61119
# ------------
# cluster= 1
# amplitude= 0.27465162089910394 idx= (np.int64(14), np.int64(1), np.int64(266), np.int64(124))
# selected elements: 41058
# ------------
# cluster= 2
# amplitude= 0.2588774357823666 idx= (np.int64(10), np.int64(1), np.int64(234), np.int64(105))
# selected elements: 15972
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 76.54it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Running slice x=2700:3300  saved to outputs_decompose2d_slices\offset_0300\x_02700_03300
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.4875074057675122 idx= (np.int64(6), np.int64(11), np.int64(283), np.int64(65))
# selected elements: 988504
# ------------
# cluster= 1
# amplitude= 0.9003193839073159 idx= (np.int64(15), np.int64(0), np.int64(201), np.int64(64))
# selected elements: 344531
# ------------
# cluster= 2
# amplitude= 0.858730429956854 idx= (np.int64(13), np.int64(12), np.int64(258), np.int64(72))
# selected elements: 12783
# ------------
# cluster= 3
# amplitude= 0.6632756342881492 idx= (np.int64(15), np.int64(15), np.int64(237), np.int64(122))
# selected elements: 149943
# ------------
# cluster= 4
# amplitude= 0.5680733982569666 idx= (np.int64(15), np.int64(5), np.int64(274), np.int64(78))
# selected elements: 23173
# ------------
# cluster= 5
# amplitude= 0.5475711826618544 idx= (np.int64(14), np.int64(8), np.int64(276), np.int64(29))
# selected elements: 152366
# ------------
# cluster= 6
# amplitude= 0.49749396559619485 idx= (np.int64(9), np.int64(1), np.int64(182), np.int64(76))
# selected elements: 45432
# ------------
# cluster= 7
# amplitude= 0.482945848587365 idx= (np.int64(10), np.int64(0), np.int64(197), np.int64(73))
# selected elements: 6010
# ------------
# cluster= 8
# amplitude= 0.4710719542645219 idx= (np.int64(1), np.int64(3), np.int64(222), np.int64(63))
# selected elements: 62650
# ------------
# cluster= 9
# amplitude= 0.4669946613561558 idx= (np.int64(13), np.int64(5), np.int64(269), np.int64(75))
# selected elements: 42746
# ------------
# cluster= 10
# amplitude= 0.4572655391899085 idx= (np.int64(2), np.int64(10), np.int64(284), np.int64(47))
# selected elements: 828
# ------------
# cluster= 11
# amplitude= 0.43368178254270695 idx= (np.int64(7), np.int64(3), np.int64(146), np.int64(129))
# selected elements: 26868
# ------------
# cluster= 12
# amplitude= 0.4196681499689177 idx= (np.int64(9), np.int64(5), np.int64(273), np.int64(63))
# selected elements: 5054
# ------------
# cluster= 13
# amplitude= 0.4107195015215687 idx= (np.int64(10), np.int64(9), np.int64(223), np.int64(143))
# selected elements: 10515
# ------------
# cluster= 14
# amplitude= 0.3978871220251387 idx= (np.int64(6), np.int64(2), np.int64(258), np.int64(116))
# selected elements: 20339
# ------------
# cluster= 15
# amplitude= 0.39779190599901937 idx= (np.int64(15), np.int64(10), np.int64(267), np.int64(74))
# selected elements: 18665
# ------------
# cluster= 16
# amplitude= 0.39701112326837645 idx= (np.int64(13), np.int64(7), np.int64(270), np.int64(88))
# selected elements: 44634
# ------------
# cluster= 17
# amplitude= 0.3900486870686147 idx= (np.int64(11), np.int64(17), np.int64(201), np.int64(52))
# selected elements: 14790
# ------------
# cluster= 18
# amplitude= 0.385883962226247 idx= (np.int64(6), np.int64(0), np.int64(200), np.int64(60))
# selected elements: 4522
# ------------
# cluster= 19
# amplitude= 0.3790383557676679 idx= (np.int64(5), np.int64(2), np.int64(148), np.int64(127))
# selected elements: 10012
# ------------
# cluster= 20
# amplitude= 0.37879563865255167 idx= (np.int64(10), np.int64(16), np.int64(289), np.int64(98))
# selected elements: 11732
# ------------
# cluster= 21
# amplitude= 0.36870273647276197 idx= (np.int64(11), np.int64(3), np.int64(202), np.int64(27))
# selected elements: 1430
# ------------
# cluster= 22
# amplitude= 0.36731898116721085 idx= (np.int64(11), np.int64(9), np.int64(210), np.int64(5))
# selected elements: 8652
# ------------
# cluster= 23
# amplitude= 0.36693518732479946 idx= (np.int64(6), np.int64(5), np.int64(273), np.int64(55))
# selected elements: 1379
# ------------
# cluster= 24
# amplitude= 0.35515984279351687 idx= (np.int64(7), np.int64(8), np.int64(272), np.int64(120))
# selected elements: 13478
# ------------
# cluster= 25
# amplitude= 0.3535188919653728 idx= (np.int64(14), np.int64(2), np.int64(114), np.int64(109))
# selected elements: 30529
# ------------
# cluster= 26
# amplitude= 0.35243910694812364 idx= (np.int64(8), np.int64(13), np.int64(192), np.int64(95))
# selected elements: 1044
# ------------
# cluster= 27
# amplitude= 0.3448113967839572 idx= (np.int64(0), np.int64(3), np.int64(248), np.int64(41))
# selected elements: 1484
# ------------
# cluster= 28
# amplitude= 0.34434639820243074 idx= (np.int64(8), np.int64(5), np.int64(76), np.int64(80))
# selected elements: 108878
# ------------
# cluster= 29
# amplitude= 0.34121513671635917 idx= (np.int64(13), np.int64(8), np.int64(207), np.int64(58))
# selected elements: 1679
# ------------
# cluster= 30
# amplitude= 0.33967831327220477 idx= (np.int64(15), np.int64(7), np.int64(239), np.int64(140))
# selected elements: 7939
# ------------
# cluster= 31
# amplitude= 0.33840010169759777 idx= (np.int64(15), np.int64(5), np.int64(182), np.int64(96))
# selected elements: 14082
# ------------
# cluster= 32
# amplitude= 0.33724181511003176 idx= (np.int64(8), np.int64(17), np.int64(199), np.int64(55))
# selected elements: 13579
# ------------
# cluster= 33
# amplitude= 0.3312029235558777 idx= (np.int64(5), np.int64(4), np.int64(265), np.int64(103))
# selected elements: 5591
# ------------
# cluster= 34
# amplitude= 0.3311532619103968 idx= (np.int64(12), np.int64(14), np.int64(285), np.int64(136))
# selected elements: 1687
# ------------
# cluster= 35
# amplitude= 0.3222450086291148 idx= (np.int64(12), np.int64(4), np.int64(201), np.int64(23))
# selected elements: 4391
# ------------
# cluster= 36
# amplitude= 0.3209442717103381 idx= (np.int64(0), np.int64(13), np.int64(263), np.int64(61))
# selected elements: 701
# ------------
# cluster= 37
# amplitude= 0.3208663463890421 idx= (np.int64(7), np.int64(4), np.int64(265), np.int64(104))
# selected elements: 438
# ------------
# cluster= 38
# amplitude= 0.31367887365920494 idx= (np.int64(4), np.int64(4), np.int64(216), np.int64(49))
# selected elements: 5486
# ------------
# cluster= 39
# amplitude= 0.31308132074880146 idx= (np.int64(7), np.int64(6), np.int64(277), np.int64(53))
# selected elements: 2405
# ------------
# cluster= 40
# amplitude= 0.30987944595476463 idx= (np.int64(9), np.int64(11), np.int64(222), np.int64(142))
# selected elements: 3497
# ------------
# cluster= 41
# amplitude= 0.3051168157814604 idx= (np.int64(10), np.int64(0), np.int64(214), np.int64(135))
# selected elements: 3086
# ------------
# cluster= 42
# amplitude= 0.3010360070670672 idx= (np.int64(5), np.int64(11), np.int64(196), np.int64(113))
# selected elements: 19440
# ------------
# cluster= 43
# amplitude= 0.30001082486320757 idx= (np.int64(2), np.int64(2), np.int64(249), np.int64(40))
# selected elements: 1161
# ------------
# cluster= 44
# amplitude= 0.299054807103865 idx= (np.int64(8), np.int64(4), np.int64(144), np.int64(130))
# selected elements: 4813
# ------------
# cluster= 45
# amplitude= 0.29867131381214146 idx= (np.int64(7), np.int64(8), np.int64(274), np.int64(26))
# selected elements: 3529
# ------------
# cluster= 46
# amplitude= 0.29663890457682723 idx= (np.int64(14), np.int64(13), np.int64(194), np.int64(94))
# selected elements: 8338
# ------------
# cluster= 47
# amplitude= 0.29505662477918915 idx= (np.int64(9), np.int64(8), np.int64(209), np.int64(6))
# selected elements: 12843
# ------------
# cluster= 48
# amplitude= 0.29436348622559827 idx= (np.int64(7), np.int64(4), np.int64(272), np.int64(58))
# selected elements: 5289
# ------------
# cluster= 49
# amplitude= 0.29316830739063954 idx= (np.int64(5), np.int64(9), np.int64(224), np.int64(142))
# selected elements: 740
# ------------
# cluster= 50
# amplitude= 0.29253224859797233 idx= (np.int64(7), np.int64(14), np.int64(189), np.int64(94))
# selected elements: 638
# ------------
# cluster= 51
# amplitude= 0.292150125313199 idx= (np.int64(13), np.int64(6), np.int64(253), np.int64(121))
# selected elements: 6825
# ------------
# cluster= 52
# amplitude= 0.28899065461343093 idx= (np.int64(11), np.int64(9), np.int64(288), np.int64(139))
# selected elements: 2943
# ------------
# cluster= 53
# amplitude= 0.2865889578129919 idx= (np.int64(10), np.int64(16), np.int64(226), np.int64(117))
# selected elements: 2295
# ------------
# cluster= 54
# amplitude= 0.28517312987219956 idx= (np.int64(8), np.int64(9), np.int64(210), np.int64(6))
# selected elements: 2439
# ------------
# cluster= 55
# amplitude= 0.2843858016723683 idx= (np.int64(1), np.int64(9), np.int64(291), np.int64(41))
# selected elements: 1181
# ------------
# cluster= 56
# amplitude= 0.28337131293772183 idx= (np.int64(5), np.int64(9), np.int64(198), np.int64(104))
# selected elements: 1032
# ------------
# cluster= 57
# amplitude= 0.28234339421545795 idx= (np.int64(5), np.int64(3), np.int64(174), np.int64(114))
# selected elements: 2238
# ------------
# cluster= 58
# amplitude= 0.2744588496534408 idx= (np.int64(2), np.int64(14), np.int64(261), np.int64(63))
# selected elements: 804
# ------------
# cluster= 59
# amplitude= 0.27360922576162344 idx= (np.int64(4), np.int64(1), np.int64(173), np.int64(123))
# selected elements: 5564
# ------------
# cluster= 60
# amplitude= 0.2729099391296334 idx= (np.int64(8), np.int64(12), np.int64(277), np.int64(29))
# selected elements: 1305
# ------------
# cluster= 61
# amplitude= 0.2716592759666232 idx= (np.int64(8), np.int64(4), np.int64(223), np.int64(63))
# selected elements: 7607
# ------------
# cluster= 62
# amplitude= 0.26931038977903476 idx= (np.int64(9), np.int64(8), np.int64(203), np.int64(65))
# selected elements: 3803
# ------------
# cluster= 63
# amplitude= 0.26855707331780676 idx= (np.int64(4), np.int64(6), np.int64(276), np.int64(47))
# selected elements: 3868
# ------------
# cluster= 64
# amplitude= 0.2676588269332288 idx= (np.int64(13), np.int64(10), np.int64(209), np.int64(4))
# selected elements: 1362
# ------------
# cluster= 65
# amplitude= 0.2669080345626387 idx= (np.int64(6), np.int64(12), np.int64(276), np.int64(29))
# selected elements: 497
# ------------
# cluster= 66
# amplitude= 0.2640357905067526 idx= (np.int64(1), np.int64(4), np.int64(203), np.int64(99))
# selected elements: 5018
# ------------
# cluster= 67
# amplitude= 0.26325995832425353 idx= (np.int64(14), np.int64(17), np.int64(285), np.int64(72))
# selected elements: 2701
# ------------
# cluster= 68
# amplitude= 0.26037069271708235 idx= (np.int64(3), np.int64(10), np.int64(250), np.int64(78))
# selected elements: 1875
# ------------
# cluster= 69
# amplitude= 0.259610057866734 idx= (np.int64(2), np.int64(8), np.int64(277), np.int64(95))
# selected elements: 5332
# ------------
# cluster= 70
# amplitude= 0.25632086200092236 idx= (np.int64(0), np.int64(10), np.int64(270), np.int64(71))
# selected elements: 1008
# ------------
# cluster= 71
# amplitude= 0.2556270034810833 idx= (np.int64(2), np.int64(3), np.int64(135), np.int64(114))
# selected elements: 2439
# ------------
# cluster= 72
# amplitude= 0.25551993044112165 idx= (np.int64(0), np.int64(1), np.int64(190), np.int64(45))
# selected elements: 4395
# ------------
# cluster= 73
# amplitude= 0.2540753994445444 idx= (np.int64(1), np.int64(5), np.int64(214), np.int64(17))
# selected elements: 5538
# ------------
# cluster= 74
# amplitude= 0.25396793969600434 idx= (np.int64(8), np.int64(2), np.int64(204), np.int64(36))
# selected elements: 1574
# ------------
# cluster= 75
# amplitude= 0.2530426446130883 idx= (np.int64(3), np.int64(13), np.int64(228), np.int64(71))
# selected elements: 3104
# ------------
# cluster= 76
# amplitude= 0.2521026018558945 idx= (np.int64(15), np.int64(7), np.int64(216), np.int64(63))
# selected elements: 4152
# ------------
# cluster= 77
# amplitude= 0.2511899116431523 idx= (np.int64(3), np.int64(9), np.int64(229), np.int64(90))
# selected elements: 2036
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 92.35it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Running slice x=3300:3900  saved to outputs_decompose2d_slices\offset_0300\x_03300_03900
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.2671317377137217 idx= (np.int64(9), np.int64(13), np.int64(18), np.int64(95))
# selected elements: 783474
# ------------
# cluster= 1
# amplitude= 0.7823912943253208 idx= (np.int64(15), np.int64(14), np.int64(28), np.int64(124))
# selected elements: 6333
# ------------
# cluster= 2
# amplitude= 0.6715291012488162 idx= (np.int64(14), np.int64(11), np.int64(26), np.int64(118))
# selected elements: 10045
# ------------
# cluster= 3
# amplitude= 0.6179377159805208 idx= (np.int64(1), np.int64(8), np.int64(30), np.int64(112))
# selected elements: 3898
# ------------
# cluster= 4
# amplitude= 0.5295263275150449 idx= (np.int64(15), np.int64(10), np.int64(24), np.int64(122))
# selected elements: 13331
# ------------
# cluster= 5
# amplitude= 0.479132157355297 idx= (np.int64(14), np.int64(9), np.int64(22), np.int64(120))
# selected elements: 9573
# ------------
# cluster= 6
# amplitude= 0.39437930404548754 idx= (np.int64(14), np.int64(7), np.int64(34), np.int64(81))
# selected elements: 40550
# ------------
# cluster= 7
# amplitude= 0.38514061122111315 idx= (np.int64(11), np.int64(0), np.int64(12), np.int64(72))
# selected elements: 68208
# ------------
# cluster= 8
# amplitude= 0.37241163919479703 idx= (np.int64(7), np.int64(7), np.int64(33), np.int64(114))
# selected elements: 53435
# ------------
# cluster= 9
# amplitude= 0.3697369726206502 idx= (np.int64(14), np.int64(16), np.int64(31), np.int64(132))
# selected elements: 19772
# ------------
# cluster= 10
# amplitude= 0.36295733992422546 idx= (np.int64(10), np.int64(11), np.int64(247), np.int64(50))
# selected elements: 100910
# ------------
# cluster= 11
# amplitude= 0.34560669844888653 idx= (np.int64(4), np.int64(15), np.int64(31), np.int64(104))
# selected elements: 2923
# ------------
# cluster= 12
# amplitude= 0.3226917005415874 idx= (np.int64(14), np.int64(5), np.int64(19), np.int64(25))
# selected elements: 13075
# ------------
# cluster= 13
# amplitude= 0.31864795256009404 idx= (np.int64(3), np.int64(8), np.int64(70), np.int64(63))
# selected elements: 20089
# ------------
# cluster= 14
# amplitude= 0.31284894078846903 idx= (np.int64(3), np.int64(9), np.int64(8), np.int64(59))
# selected elements: 1309
# ------------
# cluster= 15
# amplitude= 0.30662053794530847 idx= (np.int64(9), np.int64(13), np.int64(22), np.int64(53))
# selected elements: 695
# ------------
# cluster= 16
# amplitude= 0.29810376795826327 idx= (np.int64(15), np.int64(13), np.int64(124), np.int64(118))
# selected elements: 25635
# ------------
# cluster= 17
# amplitude= 0.2940730178760506 idx= (np.int64(10), np.int64(8), np.int64(59), np.int64(63))
# selected elements: 3267
# ------------
# cluster= 18
# amplitude= 0.2940702967473369 idx= (np.int64(3), np.int64(15), np.int64(8), np.int64(84))
# selected elements: 759
# ------------
# cluster= 19
# amplitude= 0.2812394557541781 idx= (np.int64(14), np.int64(8), np.int64(51), np.int64(11))
# selected elements: 6983
# ------------
# cluster= 20
# amplitude= 0.2798062292368763 idx= (np.int64(15), np.int64(9), np.int64(50), np.int64(7))
# selected elements: 1320
# ------------
# cluster= 21
# amplitude= 0.2782740590426104 idx= (np.int64(4), np.int64(5), np.int64(14), np.int64(115))
# selected elements: 3458
# ------------
# cluster= 22
# amplitude= 0.2768235090099895 idx= (np.int64(4), np.int64(7), np.int64(13), np.int64(119))
# selected elements: 279
# ------------
# cluster= 23
# amplitude= 0.27647524608159335 idx= (np.int64(10), np.int64(5), np.int64(14), np.int64(32))
# selected elements: 9894
# ------------
# cluster= 24
# amplitude= 0.27619133675063384 idx= (np.int64(10), np.int64(11), np.int64(100), np.int64(133))
# selected elements: 1568
# ------------
# cluster= 25
# amplitude= 0.2688521203618576 idx= (np.int64(14), np.int64(2), np.int64(22), np.int64(104))
# selected elements: 35411
# ------------
# cluster= 26
# amplitude= 0.2662558320073553 idx= (np.int64(1), np.int64(11), np.int64(22), np.int64(65))
# selected elements: 1376
# ------------
# cluster= 27
# amplitude= 0.26224408024193974 idx= (np.int64(4), np.int64(6), np.int64(113), np.int64(34))
# selected elements: 9321
# ------------
# cluster= 28
# amplitude= 0.2604145278749531 idx= (np.int64(2), np.int64(3), np.int64(28), np.int64(86))
# selected elements: 8805
# ------------
# cluster= 29
# amplitude= 0.2587942903566667 idx= (np.int64(11), np.int64(13), np.int64(219), np.int64(104))
# selected elements: 52952
# ------------
# cluster= 30
# amplitude= 0.2560123214589759 idx= (np.int64(10), np.int64(16), np.int64(13), np.int64(82))
# selected elements: 4840
# ------------
# cluster= 31
# amplitude= 0.25548294563355456 idx= (np.int64(9), np.int64(0), np.int64(34), np.int64(103))
# selected elements: 5730
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 93.65it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Running slice x=3900:4500  saved to outputs_decompose2d_slices\offset_0300\x_03900_04500
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.2538622351734073 idx= (np.int64(15), np.int64(10), np.int64(73), np.int64(32))
# selected elements: 23538
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 88.34it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Running slice x=4500:5100  saved to outputs_decompose2d_slices\offset_0300\x_04500_05100
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 89.40it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Running slice x=5100:5451  saved to outputs_decompose2d_slices\offset_0300\x_05100_05451
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 75.11it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Done. Outputs in C:\Users\domin\juwavelet\examples\outputs_decompose2d_slices\offset_0300
