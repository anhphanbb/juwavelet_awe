# %% [markdown]
# ## Loop
# Loops over X_SLICE = slice(0,600), slice(600,1200), ... until the end of the flattened swath
#
# If the last window is shorter than 600 px, it pads on the right to make it 600 (pads with the window median, so everything stays finite)
#
# Saves all figures into a subfolder (one subfolder per slice) instead of showing them

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Optional

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

# --------------------------
# User params
# --------------------------
FILE_PATH = "awe_l5c_q20_2024165T2120_03175_v01.nc"
FRAME_IDX = 0

# Loop settings on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)
SLICE_PAD = 50  # pixels on each side

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 16
JT = 18
ASPECT = 1

# Pixel spacing (km/pixel) for plotting and CWT (wavelengths will be in km)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# Clustering thresholds
MIN_AMP = 0.25
THR = 0.1

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices")
SAVE_DPI = 200

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Helpers (yours, mostly unchanged)
# --------------------------
def read_radiance_frame(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        rad = nc.variables["Radiance"][:]  # (t, y, x)
    if rad.ndim != 3:
        raise ValueError(f"Radiance expected 3D (t,y,x); got {rad.shape}")
    if not (0 <= frame_idx < rad.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{rad.shape[0]-1}")
    return np.asarray(rad[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def load_radiance_window_from_array(
    Z: np.ndarray, xsl: slice, ysl: slice
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    win = np.asarray(Z[ysl, xsl], dtype=float)
    ny, nx = win.shape
    x = np.arange(nx, dtype=float)
    y = np.arange(ny, dtype=float)
    return x, y, win


def pad_window_to_width(win: np.ndarray, target_width: int) -> np.ndarray:
    ny, nx = win.shape
    if nx >= target_width:
        return win
    pad = target_width - nx
    med = float(np.nanmedian(win)) if np.isfinite(np.nanmedian(win)) else 0.0
    right = np.full((ny, pad), med, dtype=float)
    return np.concatenate([win, right], axis=1)


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    u = np.cos(theta_xy)
    v = np.sin(theta_xy)
    return u, v


def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("Radiance (arb)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    stacked = np.concatenate([orig_c.ravel(), bg_c.ravel(), rem_c.ravel(), rem_tapered_c.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [1, 99])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    fig, axs = plt.subplots(2, 2, figsize=(12, 10), constrained_layout=True)
    axes = axs.flatten()

    panels = [
        (orig_c, "Original (median-sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    im0 = None
    for ax, (Z, title) in zip(axes, panels):
        im0 = ax.pcolormesh(
            x1d_km, y1d_km, Z, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    cbar = fig.colorbar(im0, ax=axs, orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("Radiance (arb)")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2

    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_low, bg_high = np.nanpercentile(bg_xy, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax

    cl_low, cl_high = np.nanpercentile(rec_xy, [2, 98])
    cl_vmax = max(abs(cl_low), abs(cl_high))
    if not np.isfinite(cl_vmax) or cl_vmax == 0:
        cl_vmax = 1.0
    cl_vmin = -cl_vmax

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if not np.isfinite(lam_vmin) or not np.isfinite(lam_vmax) or lam_vmin == lam_vmax:
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n" + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        ARROW_LEN_KM = 40.0
        u = u * ARROW_LEN_KM
        v = v * ARROW_LEN_KM

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)


# --------------------------
# Main pipeline for one slice
# --------------------------
def run_pipeline_for_slice(rad2d_flat: np.ndarray, x_slice: slice, outdir: Path) -> None:
    outdir.mkdir(parents=True, exist_ok=True)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        dx_km = DX_KM_BASE * int(BIN_FACTOR)
        dy_km = DY_KM_BASE * int(BIN_FACTOR)
    else:
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE

    # Window on unbinned flattened field
    _, _, raw_win = load_radiance_window_from_array(rad2d_flat, x_slice, Y_SLICE)

    # Pad last chunk to width 600 if needed
    raw_win = pad_window_to_width(raw_win, X_CHUNK)

    # Optional binning
    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"Radiance (window, flattened){bin_tag}",
        outdir / "00_radiance_window.png",
    )

    # Background separation
    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_4panel.png",
    )

    # Preprocess for CWT
    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=MIN_AMP, thr=THR)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    # Overview decomposition plot
    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N
    )
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    # FOV wavelet spectrum (grab current fig after the call)
    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text("No clusters found. Try lowering MIN_AMP or THR.\n")
        return

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    # Write ranking to text file
    lines = []
    lines.append("Cluster power ranking (clustered only)\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))

    theta_vals = np.asarray(cwt["theta"], dtype=float)

    # Figure 1: standalone clusters
    fig1, axs1 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs1 = np.atleast_1d(axs1).reshape(-1)

    opts_cluster = {"cmap": "RdBu_r", "vmin": -1.0, "vmax": 1.0, "rasterized": True}

    for ax, kcl in zip(axs1, biggest):
        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", **opts_cluster)
        ax.set_aspect("equal", adjustable="box")

    for ax in axs1[n_show:]:
        ax.axis("off")
    for ax in axs1[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}
    for i, ax in enumerate(axs1, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig1.tight_layout()
    save_fig(fig1, outdir / "05_clusters_standalone.png")

    # Figure 2: overlays
    fig2, axs2 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs2 = np.atleast_1d(axs2).reshape(-1)

    bg_low, bg_high = np.nanpercentile(bg, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax
    cl_vmin, cl_vmax = -1.0, 1.0

    for ax, kcl in zip(axs2, biggest):
        ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)

        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.pcolormesh(
            x1d_km, y1d_km, rec_centered,
            shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
        )

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.set_aspect("equal", adjustable="box")

    for ax in axs2[n_show:]:
        ax.axis("off")
    for ax in axs2[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    for i, ax in enumerate(axs2, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig2.tight_layout()
    save_fig(fig2, outdir / "06_clusters_overlay.png")

    # Per cluster 2x2
    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
        )

    # --------------------------
    # Clustered-only total power per pixel
    # (linear power, log-scaled colorbar)
    # --------------------------
    dec0 = orig_decomp                       # (ns, nt, nx, ny)
    power4d = np.abs(dec0) ** 2

    # Keep ONLY clustered coefficients
    clustered_power4d = np.where(iwave >= 0, power4d, 0.0)

    # Sum over scale + orientation -> per-pixel POWER (linear)
    power_xy = np.sum(clustered_power4d, axis=(0, 1))  # (nx, ny)
    power_xy = power_xy.T                               # (ny, nx)

    # Mask zeros so LogNorm behaves nicely
    power_xy = np.where(power_xy > 0, power_xy, np.nan)

    # Color limits (linear values, robust)
    good = np.isfinite(power_xy)
    if np.any(good):
        vmin, vmax = np.nanpercentile(power_xy[good], [2, 98])
        vmin = max(vmin, np.nanmin(power_xy[good]))
        vmax = max(vmax, vmin * 10)
    else:
        vmin, vmax = 1e-6, 1.0

    figP, axP = plt.subplots(figsize=(12, 6), constrained_layout=True)

    imP = axP.pcolormesh(
        x1d_km,
        y1d_km,
        power_xy,
        shading="auto",
        cmap="magma",
        norm=matplotlib.colors.LogNorm(vmin=vmin, vmax=vmax),
    )

    axP.set_title("Clustered-only total wavelet power per pixel")
    axP.set_xlabel("x (km)")
    axP.set_ylabel("y (km)")
    axP.set_aspect("equal", adjustable="box")

    cbar = figP.colorbar(imP, ax=axP, fraction=0.046, pad=0.02)
    cbar.set_label(r"$\sum_{(s,t)\in clusters} |\mathrm{coeff}|^2$")

    save_fig(figP, outdir / "08_clustered_total_power_logcolor.png")

    # --------------------------
    # Remaining (after preprocessing) vs All clusters combined
    # --------------------------
    # "Remaining after preprocessing" = the field that went into the CWT (proc),
    # plotted in the same x-y orientation as everything else (ny, nx).
    remaining_after_preproc_xy = proc  # already (ny, nx)

    # "All clusters combined" = reconstruct using ONLY clustered coefficients (iwave >= 0)
    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)          # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)     # (ny, nx)

    # Robust, symmetric limits for both panels (keeps visuals comparable)
    stacked = np.concatenate(
        [remaining_after_preproc_xy.ravel(), rec_all_xy.ravel()]
    )
    p_low, p_high = np.nanpercentile(stacked, [2, 98])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    figR, (axL, axR) = plt.subplots(1, 2, figsize=(16, 6), constrained_layout=True)

    imL = axL.pcolormesh(
        x1d_km, y1d_km, remaining_after_preproc_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axL.set_title("Remaining (after preprocessing, input to CWT)")
    axL.set_xlabel("x (km)")
    axL.set_ylabel("y (km)")
    axL.set_aspect("equal", adjustable="box")
    figR.colorbar(imL, ax=axL, fraction=0.046, pad=0.02).set_label("arb")

    imR = axR.pcolormesh(
        x1d_km, y1d_km, rec_all_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axR.set_title("All clusters combined (reconstruction)")
    axR.set_xlabel("x (km)")
    axR.set_ylabel("y (km)")
    axR.set_aspect("equal", adjustable="box")
    figR.colorbar(imR, ax=axR, fraction=0.046, pad=0.02).set_label("arb")

    save_fig(figR, outdir / "09_remaining_vs_all_clusters.png")

    # Restore decomposition for anything that follows
    decomposition[:] = orig_decomp


# --------------------------
# Run all slices
# --------------------------
def run_all_slices() -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_radiance_frame(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    core_starts = list(range(0, nx_total, X_CHUNK))

    for core_start in core_starts:
        core_end = min(core_start + X_CHUNK, nx_total)

        # Extend slice by ±50 pixels
        start = max(0, core_start - SLICE_PAD)
        end = min(nx_total, core_end + SLICE_PAD)

        x_slice = slice(start, end)

        outdir = OUTPUT_ROOT / f"x_{start:05d}_{end:05d}"
        print(f"Running slice x={start}:{end} (core {core_start}:{core_end}) saved to {outdir}")

        run_pipeline_for_slice(rad2d_flat, x_slice, outdir)

    print(f"Done. Outputs in {OUTPUT_ROOT.resolve()}")

run_all_slices()
# Out:
# Running slice x=0:650 (core 0:600) saved to outputs_decompose2d_slices/x_00000_00650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.37108038888739175 idx= (12, 9, 308, 58)
# selected elements: 159407
# ------------
# cluster= 1
# amplitude= 0.3444417504565404 idx= (13, 9, 205, 118)
# selected elements: 64010
# ------------
# cluster= 2
# amplitude= 0.31221373851265266 idx= (12, 7, 256, 71)
# selected elements: 30843
# ------------
# cluster= 3
# amplitude= 0.30603962397346623 idx= (10, 9, 255, 78)
# selected elements: 15591
# ------------
# cluster= 4
# amplitude= 0.2759813435543466 idx= (5, 7, 274, 60)
# selected elements: 10614
# ------------
# cluster= 5
# amplitude= 0.26529812480818515 idx= (5, 10, 197, 116)
# selected elements: 1744
# ------------
# cluster= 6
# amplitude= 0.2586889237913039 idx= (11, 12, 285, 58)
# selected elements: 6338
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 68.83it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=550:1250 (core 600:1200) saved to outputs_decompose2d_slices/x_00550_01250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.48025098934026705 idx= (6, 8, 241, 25)
# selected elements: 53690
# ------------
# cluster= 1
# amplitude= 0.47277683261286246 idx= (5, 9, 243, 24)
# selected elements: 5657
# ------------
# cluster= 2
# amplitude= 0.4083574722293721 idx= (8, 9, 48, 50)
# selected elements: 135036
# ------------
# cluster= 3
# amplitude= 0.4057785279312059 idx= (7, 8, 50, 51)
# selected elements: 2388
# ------------
# cluster= 4
# amplitude= 0.3723316141390129 idx= (15, 9, 246, 27)
# selected elements: 42268
# ------------
# cluster= 5
# amplitude= 0.33530692587411665 idx= (10, 11, 71, 43)
# selected elements: 38036
# ------------
# cluster= 6
# amplitude= 0.3333222246800942 idx= (10, 9, 199, 7)
# selected elements: 34263
# ------------
# cluster= 7
# amplitude= 0.29199315438429424 idx= (13, 8, 250, 28)
# selected elements: 8134
# ------------
# cluster= 8
# amplitude= 0.2821105973255177 idx= (13, 12, 19, 52)
# selected elements: 33626
# ------------
# cluster= 9
# amplitude= 0.27196833062886816 idx= (9, 10, 281, 10)
# selected elements: 6223
# ------------
# cluster= 10
# amplitude= 0.2646144330380939 idx= (2, 8, 57, 53)
# selected elements: 1806
# ------------
# cluster= 11
# amplitude= 0.252289020994592 idx= (13, 10, 158, 7)
# selected elements: 11158
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.94it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=1150:1850 (core 1200:1800) saved to outputs_decompose2d_slices/x_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.28058267975080087 idx= (6, 10, 325, 134)
# selected elements: 13696
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.12it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=1750:2450 (core 1800:2400) saved to outputs_decompose2d_slices/x_01750_02450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.31810958235042114 idx= (15, 8, 294, 125)
# selected elements: 63130
# ------------
# cluster= 1
# amplitude= 0.2818026053147679 idx= (6, 10, 25, 134)
# selected elements: 11345
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.92it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=2350:3050 (core 2400:3000) saved to outputs_decompose2d_slices/x_02350_03050
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.5073188037472124 idx= (15, 2, 332, 112)
# selected elements: 172637
# ------------
# cluster= 1
# amplitude= 0.44028277189678355 idx= (8, 2, 323, 128)
# selected elements: 37271
# ------------
# cluster= 2
# amplitude= 0.3535136289053397 idx= (14, 2, 289, 109)
# selected elements: 23871
# ------------
# cluster= 3
# amplitude= 0.3443464000221411 idx= (8, 5, 251, 80)
# selected elements: 85486
# ------------
# cluster= 4
# amplitude= 0.2867008512446188 idx= (14, 1, 342, 54)
# selected elements: 11644
# ------------
# cluster= 5
# amplitude= 0.2827535387468756 idx= (14, 6, 245, 86)
# selected elements: 9585
# ------------
# cluster= 6
# amplitude= 0.27481485619158913 idx= (14, 1, 141, 124)
# selected elements: 42397
# ------------
# cluster= 7
# amplitude= 0.25887743560684784 idx= (10, 1, 109, 105)
# selected elements: 15971
# ------------
# cluster= 8
# amplitude= 0.25702515380346436 idx= (13, 4, 251, 82)
# selected elements: 11066
# ------------
# cluster= 9
# amplitude= 0.2556270058382898 idx= (2, 3, 310, 114)
# selected elements: 1901
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.41it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=2950:3650 (core 3000:3600) saved to outputs_decompose2d_slices/x_02950_03650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.3214636561113875 idx= (9, 13, 192, 94)
# selected elements: 1775906
# ------------
# cluster= 1
# amplitude= 0.9003197682772737 idx= (15, 0, 76, 64)
# selected elements: 602992
# ------------
# cluster= 2
# amplitude= 0.6987886768105129 idx= (14, 11, 134, 71)
# selected elements: 25859
# ------------
# cluster= 3
# amplitude= 0.6738899013098673 idx= (2, 9, 173, 38)
# selected elements: 15897
# ------------
# cluster= 4
# amplitude= 0.6633018198683046 idx= (15, 15, 112, 122)
# selected elements: 62850
# ------------
# cluster= 5
# amplitude= 0.6321003850772021 idx= (2, 8, 205, 112)
# selected elements: 6978
# ------------
# cluster= 6
# amplitude= 0.5946466521224315 idx= (2, 12, 140, 65)
# selected elements: 10198
# ------------
# cluster= 7
# amplitude= 0.5748977187181881 idx= (15, 15, 208, 126)
# selected elements: 3020
# ------------
# cluster= 8
# amplitude= 0.5619048612177782 idx= (15, 5, 148, 77)
# selected elements: 46540
# ------------
# cluster= 9
# amplitude= 0.5514946678711187 idx= (10, 2, 66, 91)
# selected elements: 81839
# ------------
# cluster= 10
# amplitude= 0.5235622108851281 idx= (15, 10, 198, 121)
# selected elements: 32718
# ------------
# cluster= 11
# amplitude= 0.5101500127398403 idx= (14, 9, 153, 27)
# selected elements: 29448
# ------------
# cluster= 12
# amplitude= 0.47416570441741424 idx= (8, 0, 75, 60)
# selected elements: 46608
# ------------
# cluster= 13
# amplitude= 0.47107195201930246 idx= (1, 3, 97, 63)
# selected elements: 49179
# ------------
# cluster= 14
# amplitude= 0.45328823253373934 idx= (13, 4, 146, 74)
# selected elements: 18629
# ------------
# cluster= 15
# amplitude= 0.4225991033733493 idx= (8, 5, 148, 58)
# selected elements: 125060
# ------------
# cluster= 16
# amplitude= 0.41719501693471606 idx= (11, 8, 161, 26)
# selected elements: 18109
# ------------
# cluster= 17
# amplitude= 0.40709170969015607 idx= (15, 7, 157, 33)
# selected elements: 5659
# ------------
# cluster= 18
# amplitude= 0.3989089209590924 idx= (11, 10, 98, 144)
# selected elements: 1323
# ------------
# cluster= 19
# amplitude= 0.39889146273385023 idx= (11, 9, 85, 5)
# selected elements: 29549
# ------------
# cluster= 20
# amplitude= 0.39788706872873286 idx= (6, 2, 133, 116)
# selected elements: 17434
# ------------
# cluster= 21
# amplitude= 0.3900486911401334 idx= (11, 17, 76, 52)
# selected elements: 49702
# ------------
# cluster= 22
# amplitude= 0.3845408507049589 idx= (14, 16, 203, 133)
# selected elements: 13790
# ------------
# cluster= 23
# amplitude= 0.3780959765269905 idx= (6, 10, 169, 142)
# selected elements: 5694
# ------------
# cluster= 24
# amplitude= 0.37239480583145085 idx= (7, 7, 208, 114)
# selected elements: 27380
# ------------
# cluster= 25
# amplitude= 0.36870274155613997 idx= (11, 3, 77, 27)
# selected elements: 1430
# ------------
# cluster= 26
# amplitude= 0.35243911371492215 idx= (8, 13, 67, 95)
# selected elements: 1044
# ------------
# cluster= 27
# amplitude= 0.3451640038620158 idx= (12, 16, 106, 119)
# selected elements: 14949
# ------------
# cluster= 28
# amplitude= 0.34481139615122036 idx= (0, 3, 123, 41)
# selected elements: 1484
# ------------
# cluster= 29
# amplitude= 0.34462144916899706 idx= (15, 7, 111, 141)
# selected elements: 7452
# ------------
# cluster= 30
# amplitude= 0.34245949680856475 idx= (10, 0, 187, 70)
# selected elements: 2320
# ------------
# cluster= 31
# amplitude= 0.34129532463247997 idx= (6, 8, 124, 102)
# selected elements: 18727
# ------------
# cluster= 32
# amplitude= 0.34121342636904806 idx= (13, 8, 82, 58)
# selected elements: 1678
# ------------
# cluster= 33
# amplitude= 0.3383768526836366 idx= (15, 5, 57, 96)
# selected elements: 15623
# ------------
# cluster= 34
# amplitude= 0.3353029524701459 idx= (5, 3, 22, 128)
# selected elements: 12977
# ------------
# cluster= 35
# amplitude= 0.32658202637322054 idx= (6, 6, 188, 117)
# selected elements: 8930
# ------------
# cluster= 36
# amplitude= 0.320872469577909 idx= (7, 4, 140, 104)
# selected elements: 440
# ------------
# cluster= 37
# amplitude= 0.3186479570026206 idx= (3, 8, 245, 63)
# selected elements: 16860
# ------------
# cluster= 38
# amplitude= 0.31405696450119547 idx= (9, 11, 97, 142)
# selected elements: 2835
# ------------
# cluster= 39
# amplitude= 0.3138943896025435 idx= (8, 7, 127, 102)
# selected elements: 8221
# ------------
# cluster= 40
# amplitude= 0.31367887074355333 idx= (4, 4, 91, 49)
# selected elements: 10691
# ------------
# cluster= 41
# amplitude= 0.30706562712180885 idx= (9, 8, 84, 6)
# selected elements: 3979
# ------------
# cluster= 42
# amplitude= 0.3051168124278113 idx= (10, 0, 89, 135)
# selected elements: 5299
# ------------
# cluster= 43
# amplitude= 0.302818608774934 idx= (8, 9, 85, 6)
# selected elements: 2733
# ------------
# cluster= 44
# amplitude= 0.3016294180723692 idx= (5, 9, 99, 142)
# selected elements: 763
# ------------
# cluster= 45
# amplitude= 0.3010360246190825 idx= (5, 11, 71, 113)
# selected elements: 19442
# ------------
# cluster= 46
# amplitude= 0.30004706104970186 idx= (8, 4, 19, 130)
# selected elements: 13765
# ------------
# cluster= 47
# amplitude= 0.3000108256031408 idx= (2, 2, 124, 40)
# selected elements: 1161
# ------------
# cluster= 48
# amplitude= 0.29985881520278806 idx= (9, 16, 189, 82)
# selected elements: 5286
# ------------
# cluster= 49
# amplitude= 0.2980951214690299 idx= (15, 13, 299, 118)
# selected elements: 14948
# ------------
# cluster= 50
# amplitude= 0.2943816633184424 idx= (1, 12, 183, 75)
# selected elements: 925
# ------------
# cluster= 51
# amplitude= 0.2930989103827532 idx= (7, 16, 192, 81)
# selected elements: 1731
# ------------
# cluster= 52
# amplitude= 0.29253224916396225 idx= (7, 14, 64, 94)
# selected elements: 638
# ------------
# cluster= 53
# amplitude= 0.29096409866125805 idx= (9, 16, 101, 117)
# selected elements: 15137
# ------------
# cluster= 54
# amplitude= 0.28337130862800847 idx= (5, 9, 73, 104)
# selected elements: 1032
# ------------
# cluster= 55
# amplitude= 0.28234339055003316 idx= (5, 3, 49, 114)
# selected elements: 2238
# ------------
# cluster= 56
# amplitude= 0.2815822443097733 idx= (4, 7, 156, 68)
# selected elements: 1814
# ------------
# cluster= 57
# amplitude= 0.28047130260997827 idx= (3, 15, 162, 75)
# selected elements: 1823
# ------------
# cluster= 58
# amplitude= 0.28031429588432694 idx= (3, 4, 140, 103)
# selected elements: 1532
# ------------
# cluster= 59
# amplitude= 0.277547090076265 idx= (10, 11, 276, 134)
# selected elements: 1568
# ------------
# cluster= 60
# amplitude= 0.27484652318073793 idx= (4, 5, 189, 115)
# selected elements: 4159
# ------------
# cluster= 61
# amplitude= 0.27360922638925633 idx= (4, 1, 48, 123)
# selected elements: 5569
# ------------
# cluster= 62
# amplitude= 0.2713195032747061 idx= (1, 7, 179, 31)
# selected elements: 4217
# ------------
# cluster= 63
# amplitude= 0.26403579034370467 idx= (1, 4, 78, 99)
# selected elements: 5018
# ------------
# cluster= 64
# amplitude= 0.26224408741807886 idx= (4, 6, 288, 34)
# selected elements: 9323
# ------------
# cluster= 65
# amplitude= 0.260414750586672 idx= (2, 3, 203, 86)
# selected elements: 12588
# ------------
# cluster= 66
# amplitude= 0.26037069280481234 idx= (3, 10, 125, 78)
# selected elements: 1875
# ------------
# cluster= 67
# amplitude= 0.25964317860420694 idx= (2, 8, 152, 95)
# selected elements: 5406
# ------------
# cluster= 68
# amplitude= 0.2582224478875309 idx= (13, 8, 229, 11)
# selected elements: 2382
# ------------
# cluster= 69
# amplitude= 0.25692813397616937 idx= (13, 1, 25, 119)
# selected elements: 4569
# ------------
# cluster= 70
# amplitude= 0.256548154452872 idx= (14, 9, 164, 148)
# selected elements: 368
# ------------
# cluster= 71
# amplitude= 0.25634524785459356 idx= (3, 15, 195, 105)
# selected elements: 1515
# ------------
# cluster= 72
# amplitude= 0.25554594318234974 idx= (9, 0, 209, 103)
# selected elements: 7522
# ------------
# cluster= 73
# amplitude= 0.25551992781351346 idx= (0, 1, 65, 45)
# selected elements: 4812
# ------------
# cluster= 74
# amplitude= 0.2549871598553237 idx= (2, 14, 165, 77)
# selected elements: 698
# ------------
# cluster= 75
# amplitude= 0.25407543816839384 idx= (1, 5, 89, 17)
# selected elements: 5538
# ------------
# cluster= 76
# amplitude= 0.2539679381270547 idx= (8, 2, 79, 36)
# selected elements: 1574
# ------------
# cluster= 77
# amplitude= 0.2532041673005213 idx= (3, 6, 151, 47)
# selected elements: 2300
# ------------
# cluster= 78
# amplitude= 0.2530426461412684 idx= (3, 13, 103, 71)
# selected elements: 3104
# ------------
# cluster= 79
# amplitude= 0.25118990790737505 idx= (3, 9, 104, 90)
# selected elements: 2036
# ------------
# cluster= 80
# amplitude= 0.2500993917502038 idx= (5, 7, 153, 45)
# selected elements: 1504
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.89it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=3550:4250 (core 3600:4200) saved to outputs_decompose2d_slices/x_03550_04250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.36295745893201914 idx= (10, 11, 122, 50)
# selected elements: 106611
# ------------
# cluster= 1
# amplitude= 0.2587942949206798 idx= (11, 13, 94, 104)
# selected elements: 63824
# ------------
# cluster= 2
# amplitude= 0.2512568020151063 idx= (15, 10, 248, 33)
# selected elements: 30997
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.49it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=4150:4850 (core 4200:4800) saved to outputs_decompose2d_slices/x_04150_04850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 85.75it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=4750:5450 (core 4800:5400) saved to outputs_decompose2d_slices/x_04750_05450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 83.84it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Running slice x=5350:5451 (core 5400:5451) saved to outputs_decompose2d_slices/x_05350_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 91.78it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Done. Outputs in /Users/anhphan/juwavelet_awe/examples/outputs_decompose2d_slices

# %% [markdown]
# ## Stitch all

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Optional, Dict, Any, List

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

# --------------------------
# User params
# --------------------------
FILE_PATH = "awe_l5c_q20_2024165T2120_03175_v01.nc"
FRAME_IDX = 0

# Loop settings on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)

# Extend each slice by this many UNBINNED pixels on each side (overlap = 2*SLICE_PAD)
SLICE_PAD = 50

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 16
JT = 18
ASPECT = 1

# Pixel spacing (km/pixel) for plotting and CWT (wavelengths will be in km)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# Clustering thresholds
MIN_AMP = 0.25
THR = 0.1

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices")
SAVE_DPI = 200

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Helpers
# --------------------------
def read_radiance_frame(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        rad = nc.variables["Radiance"][:]  # (t, y, x)
    if rad.ndim != 3:
        raise ValueError(f"Radiance expected 3D (t,y,x); got {rad.shape}")
    if not (0 <= frame_idx < rad.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{rad.shape[0]-1}")
    return np.asarray(rad[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def load_radiance_window_from_array(
    Z: np.ndarray, xsl: slice, ysl: slice
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    win = np.asarray(Z[ysl, xsl], dtype=float)
    ny, nx = win.shape
    x = np.arange(nx, dtype=float)
    y = np.arange(ny, dtype=float)
    return x, y, win


def pad_window_to_width(win: np.ndarray, target_width: int) -> np.ndarray:
    ny, nx = win.shape
    if nx >= target_width:
        return win
    pad = target_width - nx
    med = float(np.nanmedian(win)) if np.isfinite(np.nanmedian(win)) else 0.0
    right = np.full((ny, pad), med, dtype=float)
    return np.concatenate([win, right], axis=1)


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    u = np.cos(theta_xy)
    v = np.sin(theta_xy)
    return u, v


def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("Radiance (arb)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    stacked = np.concatenate([orig_c.ravel(), bg_c.ravel(), rem_c.ravel(), rem_tapered_c.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [1, 99])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    fig, axs = plt.subplots(2, 2, figsize=(12, 10), constrained_layout=True)
    axes = axs.flatten()

    panels = [
        (orig_c, "Original (median-sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    im0 = None
    for ax, (Z, title) in zip(axes, panels):
        im0 = ax.pcolormesh(
            x1d_km, y1d_km, Z, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    cbar = fig.colorbar(im0, ax=axs, orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("Radiance (arb)")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2

    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_low, bg_high = np.nanpercentile(bg_xy, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax

    cl_low, cl_high = np.nanpercentile(rec_xy, [2, 98])
    cl_vmax = max(abs(cl_low), abs(cl_high))
    if not np.isfinite(cl_vmax) or cl_vmax == 0:
        cl_vmax = 1.0
    cl_vmin = -cl_vmax

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if not np.isfinite(lam_vmin) or not np.isfinite(lam_vmax) or lam_vmin == lam_vmax:
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n" + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        ARROW_LEN_KM = 40.0
        u = u * ARROW_LEN_KM
        v = v * ARROW_LEN_KM

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)


# --------------------------
# Main pipeline for one slice
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
) -> Dict[str, Any]:
    """
    Runs processing on an extended slice (x_slice), but returns only CORE tiles
    for stitching: core_start_unbinned..core_end_unbinned (typically 600 px wide).
    """
    outdir.mkdir(parents=True, exist_ok=True)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        dx_km = DX_KM_BASE * int(BIN_FACTOR)
        dy_km = DY_KM_BASE * int(BIN_FACTOR)
        f = int(BIN_FACTOR)
    else:
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE
        f = 1

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f
    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    # Window on unbinned flattened field
    _, _, raw_win = load_radiance_window_from_array(rad2d_flat, x_slice, Y_SLICE)

    # Only pad if we are shorter than X_CHUNK (helps last slice)
    raw_win = pad_window_to_width(raw_win, X_CHUNK)

    # Optional binning
    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"Radiance (window, flattened){bin_tag}",
        outdir / "00_radiance_window.png",
    )

    # Background separation
    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_4panel.png",
    )

    # Preprocess for CWT
    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=MIN_AMP, thr=THR)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    # Overview decomposition plot
    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N
    )
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    # FOV wavelet spectrum
    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)

    has_clusters = cluster_ids.size > 0

    if not has_clusters:
        (outdir / "NO_CLUSTERS.txt").write_text("No clusters found. Try lowering MIN_AMP or THR.\n")

        remaining_core_xy = crop_pad_core(proc)
        nan_core = np.full_like(remaining_core_xy, np.nan)

        return {
            "has_clusters": False,
            "x_start_unbinned": core_start_unbinned,
            "dx_km": dx_km,
            "dy_km": dy_km,
            "power_xy": nan_core,
            "remaining_xy": remaining_core_xy,
            "rec_all_xy": nan_core,
        }

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    # Write ranking to text file
    lines = []
    lines.append("Cluster power ranking (clustered only)\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))

    theta_vals = np.asarray(cwt["theta"], dtype=float)

    # Figure 1: standalone clusters
    fig1, axs1 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs1 = np.atleast_1d(axs1).reshape(-1)

    opts_cluster = {"cmap": "RdBu_r", "vmin": -1.0, "vmax": 1.0, "rasterized": True}

    for ax, kcl in zip(axs1, biggest):
        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", **opts_cluster)
        ax.set_aspect("equal", adjustable="box")

    for ax in axs1[n_show:]:
        ax.axis("off")
    for ax in axs1[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}
    for i, ax in enumerate(axs1, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig1.tight_layout()
    save_fig(fig1, outdir / "05_clusters_standalone.png")

    # Figure 2: overlays
    fig2, axs2 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs2 = np.atleast_1d(axs2).reshape(-1)

    bg_low, bg_high = np.nanpercentile(bg, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax
    cl_vmin, cl_vmax = -1.0, 1.0

    for ax, kcl in zip(axs2, biggest):
        ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)

        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.pcolormesh(
            x1d_km, y1d_km, rec_centered,
            shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
        )

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.set_aspect("equal", adjustable="box")

    for ax in axs2[n_show:]:
        ax.axis("off")
    for ax in axs2[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    for i, ax in enumerate(axs2, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig2.tight_layout()
    save_fig(fig2, outdir / "06_clusters_overlay.png")

    # Per cluster 2x2 maps
    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
        )

    # 08 per slice: clustered-only total power per pixel
    dec0 = orig_decomp
    power4d = np.abs(dec0) ** 2
    clustered_power4d = np.where(iwave >= 0, power4d, 0.0)
    power_xy = np.sum(clustered_power4d, axis=(0, 1))  # (nx, ny)
    power_xy = power_xy.T
    power_xy = np.where(power_xy > 0, power_xy, np.nan)

    good = np.isfinite(power_xy)
    if np.any(good):
        vmin, vmax = np.nanpercentile(power_xy[good], [2, 98])
        vmin = max(vmin, np.nanmin(power_xy[good]))
        vmax = max(vmax, vmin * 10)
    else:
        vmin, vmax = 1e-6, 1.0

    figP, axP = plt.subplots(figsize=(12, 6), constrained_layout=True)
    imP = axP.pcolormesh(
        x1d_km, y1d_km, power_xy,
        shading="auto", cmap="magma",
        norm=matplotlib.colors.LogNorm(vmin=vmin, vmax=vmax),
    )
    axP.set_title("Clustered-only total wavelet power per pixel")
    axP.set_xlabel("x (km)")
    axP.set_ylabel("y (km)")
    axP.set_aspect("equal", adjustable="box")
    cbar = figP.colorbar(imP, ax=axP, fraction=0.046, pad=0.02)
    cbar.set_label(r"$\sum_{(s,t)\in clusters} |\mathrm{coeff}|^2$")
    save_fig(figP, outdir / "08_clustered_total_power_logcolor.png")

    # 09 per slice: remaining vs all clusters reconstruction
    remaining_after_preproc_xy = proc

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)          # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)

    stacked = np.concatenate([remaining_after_preproc_xy.ravel(), rec_all_xy.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [2, 98])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    figR, (axL, axR) = plt.subplots(1, 2, figsize=(16, 6), constrained_layout=True)

    imL = axL.pcolormesh(
        x1d_km, y1d_km, remaining_after_preproc_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axL.set_title("Remaining (after preprocessing, input to CWT)")
    axL.set_xlabel("x (km)")
    axL.set_ylabel("y (km)")
    axL.set_aspect("equal", adjustable="box")
    figR.colorbar(imL, ax=axL, fraction=0.046, pad=0.02).set_label("arb")

    imR = axR.pcolormesh(
        x1d_km, y1d_km, rec_all_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axR.set_title("All clusters combined (reconstruction)")
    axR.set_xlabel("x (km)")
    axR.set_ylabel("y (km)")
    axR.set_aspect("equal", adjustable="box")
    figR.colorbar(imR, ax=axR, fraction=0.046, pad=0.02).set_label("arb")

    save_fig(figR, outdir / "09_remaining_vs_all_clusters.png")

    decomposition[:] = orig_decomp

    # Return only CORE tiles for stitching
    power_core_xy = crop_pad_core(power_xy)
    remaining_core_xy = crop_pad_core(remaining_after_preproc_xy)
    rec_all_core_xy = crop_pad_core(rec_all_xy)

    return {
        "has_clusters": True,
        "x_start_unbinned": core_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "power_xy": power_core_xy,
        "remaining_xy": remaining_core_xy,
        "rec_all_xy": rec_all_core_xy,
    }


# --------------------------
# Stitch helper for final 08 and 09 (CORE tiles only)
# --------------------------
def stitch_and_save_final_08_09(slice_results: List[Dict[str, Any]], outroot: Path) -> None:
    if len(slice_results) == 0:
        return

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])

    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE

    power_stitched = np.concatenate([d["power_xy"] for d in slice_results], axis=1)
    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)

    ny, nx_tot = power_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    # FINAL 08: stitched clustered total power (log color)
    good = np.isfinite(power_stitched) & (power_stitched > 0)
    if np.any(good):
        vmin, vmax = np.nanpercentile(power_stitched[good], [2, 98])
        vmin = max(vmin, np.nanmin(power_stitched[good]))
        vmax = max(vmax, vmin * 10)
    else:
        vmin, vmax = 1e-6, 1.0

    figP, axP = plt.subplots(figsize=(18, 6), constrained_layout=True)
    imP = axP.pcolormesh(
        x1d_km, y1d_km, power_stitched,
        shading="auto", cmap="magma",
        norm=matplotlib.colors.LogNorm(vmin=vmin, vmax=vmax),
    )
    axP.set_title("STITCHED (core tiles): Clustered-only total wavelet power per pixel")
    axP.set_xlabel("x (km)")
    axP.set_ylabel("y (km)")
    axP.set_aspect("equal", adjustable="box")
    cbar = figP.colorbar(imP, ax=axP, fraction=0.025, pad=0.02)
    cbar.set_label(r"$\sum_{(s,t)\in clusters} |\mathrm{coeff}|^2$")
    save_fig(figP, outroot / "FINAL_08_clustered_total_power_logcolor_STITCHED.png")

    # FINAL 09: stitched remaining vs stitched all-clusters reconstruction (top/bottom, one colorbar)
    stacked = np.concatenate([remaining_stitched.ravel(), rec_all_stitched.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [2, 98])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    figR, (axT, axB) = plt.subplots(2, 1, figsize=(18, 6), constrained_layout=True, sharex=True, sharey=True)

    imT = axT.pcolormesh(
        x1d_km, y1d_km, remaining_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axT.set_title("STITCHED (core tiles): Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(
        x1d_km, y1d_km, rec_all_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axB.set_title("STITCHED (core tiles): All clusters combined (reconstruction)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    xmin_km = 600
    xmax_km = 10000
    axT.set_xlim(xmin_km, xmax_km)

    cbar = figR.colorbar(imT, ax=[axT, axB], orientation="vertical", fraction=0.01, pad=0.01)
    cbar.set_label("kRayleigh (Relative)")

    save_fig(figR, outroot / "FINAL_09_remaining_vs_all_clusters_STITCHED.png")


# --------------------------
# Run all slices
# --------------------------
def run_all_slices() -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_radiance_frame(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    for x_offset in [0, 300]:
        if x_offset >= nx_total:
            print(f"Skip offset {x_offset}: nx_total={nx_total}")
            continue

        outroot = OUTPUT_ROOT / f"offset_{x_offset:04d}"
        outroot.mkdir(parents=True, exist_ok=True)

        core_starts = list(range(x_offset, nx_total, X_CHUNK))

        stitch_results: List[Dict[str, Any]] = []

        for core_start in core_starts:
            core_end = min(core_start + X_CHUNK, nx_total)

            ext_start = max(0, core_start - SLICE_PAD)
            ext_end = min(nx_total, core_end + SLICE_PAD)
            x_slice = slice(ext_start, ext_end)

            outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
            print(f"[offset {x_offset}] core={core_start}:{core_end}  ext={ext_start}:{ext_end}  saved to {outdir}")

            res = run_pipeline_for_slice(
                rad2d_flat=rad2d_flat,
                x_slice=x_slice,
                outdir=outdir,
                x_start_unbinned=ext_start,
                core_start_unbinned=core_start,
                core_end_unbinned=core_end,
            )
            stitch_results.append(res)

        stitch_and_save_final_08_09(stitch_results, outroot)
        print(f"[offset {x_offset}] Done. Outputs in {outroot.resolve()}")


run_all_slices()
# Out:
# [offset 0] core=0:600  ext=0:650  saved to outputs_decompose2d_slices/offset_0000/xcore_00000_00600_xext_00000_00650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.37108038888739175 idx= (12, 9, 308, 58)
# selected elements: 159407
# ------------
# cluster= 1
# amplitude= 0.3444417504565404 idx= (13, 9, 205, 118)
# selected elements: 64010
# ------------
# cluster= 2
# amplitude= 0.31221373851265266 idx= (12, 7, 256, 71)
# selected elements: 30843
# ------------
# cluster= 3
# amplitude= 0.30603962397346623 idx= (10, 9, 255, 78)
# selected elements: 15591
# ------------
# cluster= 4
# amplitude= 0.2759813435543466 idx= (5, 7, 274, 60)
# selected elements: 10614
# ------------
# cluster= 5
# amplitude= 0.26529812480818515 idx= (5, 10, 197, 116)
# selected elements: 1744
# ------------
# cluster= 6
# amplitude= 0.2586889237913039 idx= (11, 12, 285, 58)
# selected elements: 6338
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 76.90it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=600:1200  ext=550:1250  saved to outputs_decompose2d_slices/offset_0000/xcore_00600_01200_xext_00550_01250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.48025098934026705 idx= (6, 8, 241, 25)
# selected elements: 53690
# ------------
# cluster= 1
# amplitude= 0.47277683261286246 idx= (5, 9, 243, 24)
# selected elements: 5657
# ------------
# cluster= 2
# amplitude= 0.4083574722293721 idx= (8, 9, 48, 50)
# selected elements: 135036
# ------------
# cluster= 3
# amplitude= 0.4057785279312059 idx= (7, 8, 50, 51)
# selected elements: 2388
# ------------
# cluster= 4
# amplitude= 0.3723316141390129 idx= (15, 9, 246, 27)
# selected elements: 42268
# ------------
# cluster= 5
# amplitude= 0.33530692587411665 idx= (10, 11, 71, 43)
# selected elements: 38036
# ------------
# cluster= 6
# amplitude= 0.3333222246800942 idx= (10, 9, 199, 7)
# selected elements: 34263
# ------------
# cluster= 7
# amplitude= 0.29199315438429424 idx= (13, 8, 250, 28)
# selected elements: 8134
# ------------
# cluster= 8
# amplitude= 0.2821105973255177 idx= (13, 12, 19, 52)
# selected elements: 33626
# ------------
# cluster= 9
# amplitude= 0.27196833062886816 idx= (9, 10, 281, 10)
# selected elements: 6223
# ------------
# cluster= 10
# amplitude= 0.2646144330380939 idx= (2, 8, 57, 53)
# selected elements: 1806
# ------------
# cluster= 11
# amplitude= 0.252289020994592 idx= (13, 10, 158, 7)
# selected elements: 11158
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.27it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=1200:1800  ext=1150:1850  saved to outputs_decompose2d_slices/offset_0000/xcore_01200_01800_xext_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.28058267975080087 idx= (6, 10, 325, 134)
# selected elements: 13696
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 86.02it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=1800:2400  ext=1750:2450  saved to outputs_decompose2d_slices/offset_0000/xcore_01800_02400_xext_01750_02450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.31810958235042114 idx= (15, 8, 294, 125)
# selected elements: 63130
# ------------
# cluster= 1
# amplitude= 0.2818026053147679 idx= (6, 10, 25, 134)
# selected elements: 11345
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 47.13it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=2400:3000  ext=2350:3050  saved to outputs_decompose2d_slices/offset_0000/xcore_02400_03000_xext_02350_03050
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.5073188037472124 idx= (15, 2, 332, 112)
# selected elements: 172637
# ------------
# cluster= 1
# amplitude= 0.44028277189678355 idx= (8, 2, 323, 128)
# selected elements: 37271
# ------------
# cluster= 2
# amplitude= 0.3535136289053397 idx= (14, 2, 289, 109)
# selected elements: 23871
# ------------
# cluster= 3
# amplitude= 0.3443464000221411 idx= (8, 5, 251, 80)
# selected elements: 85486
# ------------
# cluster= 4
# amplitude= 0.2867008512446188 idx= (14, 1, 342, 54)
# selected elements: 11644
# ------------
# cluster= 5
# amplitude= 0.2827535387468756 idx= (14, 6, 245, 86)
# selected elements: 9585
# ------------
# cluster= 6
# amplitude= 0.27481485619158913 idx= (14, 1, 141, 124)
# selected elements: 42397
# ------------
# cluster= 7
# amplitude= 0.25887743560684784 idx= (10, 1, 109, 105)
# selected elements: 15971
# ------------
# cluster= 8
# amplitude= 0.25702515380346436 idx= (13, 4, 251, 82)
# selected elements: 11066
# ------------
# cluster= 9
# amplitude= 0.2556270058382898 idx= (2, 3, 310, 114)
# selected elements: 1901
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.76it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=3000:3600  ext=2950:3650  saved to outputs_decompose2d_slices/offset_0000/xcore_03000_03600_xext_02950_03650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.3214636561113875 idx= (9, 13, 192, 94)
# selected elements: 1775906
# ------------
# cluster= 1
# amplitude= 0.9003197682772737 idx= (15, 0, 76, 64)
# selected elements: 602992
# ------------
# cluster= 2
# amplitude= 0.6987886768105129 idx= (14, 11, 134, 71)
# selected elements: 25859
# ------------
# cluster= 3
# amplitude= 0.6738899013098673 idx= (2, 9, 173, 38)
# selected elements: 15897
# ------------
# cluster= 4
# amplitude= 0.6633018198683046 idx= (15, 15, 112, 122)
# selected elements: 62850
# ------------
# cluster= 5
# amplitude= 0.6321003850772021 idx= (2, 8, 205, 112)
# selected elements: 6978
# ------------
# cluster= 6
# amplitude= 0.5946466521224315 idx= (2, 12, 140, 65)
# selected elements: 10198
# ------------
# cluster= 7
# amplitude= 0.5748977187181881 idx= (15, 15, 208, 126)
# selected elements: 3020
# ------------
# cluster= 8
# amplitude= 0.5619048612177782 idx= (15, 5, 148, 77)
# selected elements: 46540
# ------------
# cluster= 9
# amplitude= 0.5514946678711187 idx= (10, 2, 66, 91)
# selected elements: 81839
# ------------
# cluster= 10
# amplitude= 0.5235622108851281 idx= (15, 10, 198, 121)
# selected elements: 32718
# ------------
# cluster= 11
# amplitude= 0.5101500127398403 idx= (14, 9, 153, 27)
# selected elements: 29448
# ------------
# cluster= 12
# amplitude= 0.47416570441741424 idx= (8, 0, 75, 60)
# selected elements: 46608
# ------------
# cluster= 13
# amplitude= 0.47107195201930246 idx= (1, 3, 97, 63)
# selected elements: 49179
# ------------
# cluster= 14
# amplitude= 0.45328823253373934 idx= (13, 4, 146, 74)
# selected elements: 18629
# ------------
# cluster= 15
# amplitude= 0.4225991033733493 idx= (8, 5, 148, 58)
# selected elements: 125060
# ------------
# cluster= 16
# amplitude= 0.41719501693471606 idx= (11, 8, 161, 26)
# selected elements: 18109
# ------------
# cluster= 17
# amplitude= 0.40709170969015607 idx= (15, 7, 157, 33)
# selected elements: 5659
# ------------
# cluster= 18
# amplitude= 0.3989089209590924 idx= (11, 10, 98, 144)
# selected elements: 1323
# ------------
# cluster= 19
# amplitude= 0.39889146273385023 idx= (11, 9, 85, 5)
# selected elements: 29549
# ------------
# cluster= 20
# amplitude= 0.39788706872873286 idx= (6, 2, 133, 116)
# selected elements: 17434
# ------------
# cluster= 21
# amplitude= 0.3900486911401334 idx= (11, 17, 76, 52)
# selected elements: 49702
# ------------
# cluster= 22
# amplitude= 0.3845408507049589 idx= (14, 16, 203, 133)
# selected elements: 13790
# ------------
# cluster= 23
# amplitude= 0.3780959765269905 idx= (6, 10, 169, 142)
# selected elements: 5694
# ------------
# cluster= 24
# amplitude= 0.37239480583145085 idx= (7, 7, 208, 114)
# selected elements: 27380
# ------------
# cluster= 25
# amplitude= 0.36870274155613997 idx= (11, 3, 77, 27)
# selected elements: 1430
# ------------
# cluster= 26
# amplitude= 0.35243911371492215 idx= (8, 13, 67, 95)
# selected elements: 1044
# ------------
# cluster= 27
# amplitude= 0.3451640038620158 idx= (12, 16, 106, 119)
# selected elements: 14949
# ------------
# cluster= 28
# amplitude= 0.34481139615122036 idx= (0, 3, 123, 41)
# selected elements: 1484
# ------------
# cluster= 29
# amplitude= 0.34462144916899706 idx= (15, 7, 111, 141)
# selected elements: 7452
# ------------
# cluster= 30
# amplitude= 0.34245949680856475 idx= (10, 0, 187, 70)
# selected elements: 2320
# ------------
# cluster= 31
# amplitude= 0.34129532463247997 idx= (6, 8, 124, 102)
# selected elements: 18727
# ------------
# cluster= 32
# amplitude= 0.34121342636904806 idx= (13, 8, 82, 58)
# selected elements: 1678
# ------------
# cluster= 33
# amplitude= 0.3383768526836366 idx= (15, 5, 57, 96)
# selected elements: 15623
# ------------
# cluster= 34
# amplitude= 0.3353029524701459 idx= (5, 3, 22, 128)
# selected elements: 12977
# ------------
# cluster= 35
# amplitude= 0.32658202637322054 idx= (6, 6, 188, 117)
# selected elements: 8930
# ------------
# cluster= 36
# amplitude= 0.320872469577909 idx= (7, 4, 140, 104)
# selected elements: 440
# ------------
# cluster= 37
# amplitude= 0.3186479570026206 idx= (3, 8, 245, 63)
# selected elements: 16860
# ------------
# cluster= 38
# amplitude= 0.31405696450119547 idx= (9, 11, 97, 142)
# selected elements: 2835
# ------------
# cluster= 39
# amplitude= 0.3138943896025435 idx= (8, 7, 127, 102)
# selected elements: 8221
# ------------
# cluster= 40
# amplitude= 0.31367887074355333 idx= (4, 4, 91, 49)
# selected elements: 10691
# ------------
# cluster= 41
# amplitude= 0.30706562712180885 idx= (9, 8, 84, 6)
# selected elements: 3979
# ------------
# cluster= 42
# amplitude= 0.3051168124278113 idx= (10, 0, 89, 135)
# selected elements: 5299
# ------------
# cluster= 43
# amplitude= 0.302818608774934 idx= (8, 9, 85, 6)
# selected elements: 2733
# ------------
# cluster= 44
# amplitude= 0.3016294180723692 idx= (5, 9, 99, 142)
# selected elements: 763
# ------------
# cluster= 45
# amplitude= 0.3010360246190825 idx= (5, 11, 71, 113)
# selected elements: 19442
# ------------
# cluster= 46
# amplitude= 0.30004706104970186 idx= (8, 4, 19, 130)
# selected elements: 13765
# ------------
# cluster= 47
# amplitude= 0.3000108256031408 idx= (2, 2, 124, 40)
# selected elements: 1161
# ------------
# cluster= 48
# amplitude= 0.29985881520278806 idx= (9, 16, 189, 82)
# selected elements: 5286
# ------------
# cluster= 49
# amplitude= 0.2980951214690299 idx= (15, 13, 299, 118)
# selected elements: 14948
# ------------
# cluster= 50
# amplitude= 0.2943816633184424 idx= (1, 12, 183, 75)
# selected elements: 925
# ------------
# cluster= 51
# amplitude= 0.2930989103827532 idx= (7, 16, 192, 81)
# selected elements: 1731
# ------------
# cluster= 52
# amplitude= 0.29253224916396225 idx= (7, 14, 64, 94)
# selected elements: 638
# ------------
# cluster= 53
# amplitude= 0.29096409866125805 idx= (9, 16, 101, 117)
# selected elements: 15137
# ------------
# cluster= 54
# amplitude= 0.28337130862800847 idx= (5, 9, 73, 104)
# selected elements: 1032
# ------------
# cluster= 55
# amplitude= 0.28234339055003316 idx= (5, 3, 49, 114)
# selected elements: 2238
# ------------
# cluster= 56
# amplitude= 0.2815822443097733 idx= (4, 7, 156, 68)
# selected elements: 1814
# ------------
# cluster= 57
# amplitude= 0.28047130260997827 idx= (3, 15, 162, 75)
# selected elements: 1823
# ------------
# cluster= 58
# amplitude= 0.28031429588432694 idx= (3, 4, 140, 103)
# selected elements: 1532
# ------------
# cluster= 59
# amplitude= 0.277547090076265 idx= (10, 11, 276, 134)
# selected elements: 1568
# ------------
# cluster= 60
# amplitude= 0.27484652318073793 idx= (4, 5, 189, 115)
# selected elements: 4159
# ------------
# cluster= 61
# amplitude= 0.27360922638925633 idx= (4, 1, 48, 123)
# selected elements: 5569
# ------------
# cluster= 62
# amplitude= 0.2713195032747061 idx= (1, 7, 179, 31)
# selected elements: 4217
# ------------
# cluster= 63
# amplitude= 0.26403579034370467 idx= (1, 4, 78, 99)
# selected elements: 5018
# ------------
# cluster= 64
# amplitude= 0.26224408741807886 idx= (4, 6, 288, 34)
# selected elements: 9323
# ------------
# cluster= 65
# amplitude= 0.260414750586672 idx= (2, 3, 203, 86)
# selected elements: 12588
# ------------
# cluster= 66
# amplitude= 0.26037069280481234 idx= (3, 10, 125, 78)
# selected elements: 1875
# ------------
# cluster= 67
# amplitude= 0.25964317860420694 idx= (2, 8, 152, 95)
# selected elements: 5406
# ------------
# cluster= 68
# amplitude= 0.2582224478875309 idx= (13, 8, 229, 11)
# selected elements: 2382
# ------------
# cluster= 69
# amplitude= 0.25692813397616937 idx= (13, 1, 25, 119)
# selected elements: 4569
# ------------
# cluster= 70
# amplitude= 0.256548154452872 idx= (14, 9, 164, 148)
# selected elements: 368
# ------------
# cluster= 71
# amplitude= 0.25634524785459356 idx= (3, 15, 195, 105)
# selected elements: 1515
# ------------
# cluster= 72
# amplitude= 0.25554594318234974 idx= (9, 0, 209, 103)
# selected elements: 7522
# ------------
# cluster= 73
# amplitude= 0.25551992781351346 idx= (0, 1, 65, 45)
# selected elements: 4812
# ------------
# cluster= 74
# amplitude= 0.2549871598553237 idx= (2, 14, 165, 77)
# selected elements: 698
# ------------
# cluster= 75
# amplitude= 0.25407543816839384 idx= (1, 5, 89, 17)
# selected elements: 5538
# ------------
# cluster= 76
# amplitude= 0.2539679381270547 idx= (8, 2, 79, 36)
# selected elements: 1574
# ------------
# cluster= 77
# amplitude= 0.2532041673005213 idx= (3, 6, 151, 47)
# selected elements: 2300
# ------------
# cluster= 78
# amplitude= 0.2530426461412684 idx= (3, 13, 103, 71)
# selected elements: 3104
# ------------
# cluster= 79
# amplitude= 0.25118990790737505 idx= (3, 9, 104, 90)
# selected elements: 2036
# ------------
# cluster= 80
# amplitude= 0.2500993917502038 idx= (5, 7, 153, 45)
# selected elements: 1504
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.12it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=3600:4200  ext=3550:4250  saved to outputs_decompose2d_slices/offset_0000/xcore_03600_04200_xext_03550_04250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.36295745893201914 idx= (10, 11, 122, 50)
# selected elements: 106611
# ------------
# cluster= 1
# amplitude= 0.2587942949206798 idx= (11, 13, 94, 104)
# selected elements: 63824
# ------------
# cluster= 2
# amplitude= 0.2512568020151063 idx= (15, 10, 248, 33)
# selected elements: 30997
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 93.17it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=4200:4800  ext=4150:4850  saved to outputs_decompose2d_slices/offset_0000/xcore_04200_04800_xext_04150_04850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 93.09it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=4800:5400  ext=4750:5450  saved to outputs_decompose2d_slices/offset_0000/xcore_04800_05400_xext_04750_05450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 93.09it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=5400:5451  ext=5350:5451  saved to outputs_decompose2d_slices/offset_0000/xcore_05400_05451_xext_05350_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 93.59it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Done. Outputs in /Users/anhphan/juwavelet_awe/examples/outputs_decompose2d_slices/offset_0000
# [offset 300] core=300:900  ext=250:950  saved to outputs_decompose2d_slices/offset_0300/xcore_00300_00900_xext_00250_00950
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.40835747961792257 idx= (8, 9, 198, 50)
# selected elements: 155300
# ------------
# cluster= 1
# amplitude= 0.40577853779423345 idx= (7, 8, 200, 51)
# selected elements: 2391
# ------------
# cluster= 2
# amplitude= 0.365874336271434 idx= (13, 12, 159, 52)
# selected elements: 57325
# ------------
# cluster= 3
# amplitude= 0.35993158931635366 idx= (14, 9, 81, 118)
# selected elements: 103775
# ------------
# cluster= 4
# amplitude= 0.3287651129529036 idx= (14, 9, 314, 9)
# selected elements: 51205
# ------------
# cluster= 5
# amplitude= 0.3228922740303705 idx= (11, 11, 223, 43)
# selected elements: 6990
# ------------
# cluster= 6
# amplitude= 0.3199388330861332 idx= (9, 11, 221, 42)
# selected elements: 10809
# ------------
# cluster= 7
# amplitude= 0.31221374493579435 idx= (12, 7, 131, 71)
# selected elements: 36030
# ------------
# cluster= 8
# amplitude= 0.30603962370670496 idx= (10, 9, 130, 78)
# selected elements: 7491
# ------------
# cluster= 9
# amplitude= 0.27598134647967487 idx= (5, 7, 149, 60)
# selected elements: 13435
# ------------
# cluster= 10
# amplitude= 0.26529880005454815 idx= (5, 10, 72, 116)
# selected elements: 1998
# ------------
# cluster= 11
# amplitude= 0.26461442882209163 idx= (2, 8, 207, 53)
# selected elements: 1806
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 93.27it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=900:1500  ext=850:1550  saved to outputs_decompose2d_slices/offset_0300/xcore_00900_01500_xext_00850_01550
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.4803051729364532 idx= (6, 8, 91, 25)
# selected elements: 53556
# ------------
# cluster= 1
# amplitude= 0.4727788379508776 idx= (5, 9, 93, 24)
# selected elements: 5453
# ------------
# cluster= 2
# amplitude= 0.365816894923951 idx= (15, 9, 96, 27)
# selected elements: 62101
# ------------
# cluster= 3
# amplitude= 0.3397957262930074 idx= (10, 9, 50, 6)
# selected elements: 19762
# ------------
# cluster= 4
# amplitude= 0.26975059850170374 idx= (9, 10, 131, 10)
# selected elements: 6241
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 94.08it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=1500:2100  ext=1450:2150  saved to outputs_decompose2d_slices/offset_0300/xcore_01500_02100_xext_01450_02150
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.28177092110348134 idx= (6, 10, 175, 134)
# selected elements: 13817
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 93.97it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=2100:2700  ext=2050:2750  saved to outputs_decompose2d_slices/offset_0300/xcore_02100_02700_xext_02050_02750
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.31646178834308264 idx= (15, 8, 144, 125)
# selected elements: 64015
# ------------
# cluster= 1
# amplitude= 0.2747996703753803 idx= (14, 1, 291, 124)
# selected elements: 42451
# ------------
# cluster= 2
# amplitude= 0.2588774346028878 idx= (10, 1, 259, 105)
# selected elements: 15971
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 93.55it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=2700:3300  ext=2650:3350  saved to outputs_decompose2d_slices/offset_0300/xcore_02700_03300_xext_02650_03350
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.845620990838224 idx= (7, 12, 333, 81)
# selected elements: 1316198
# ------------
# cluster= 1
# amplitude= 0.900319390326576 idx= (15, 0, 226, 64)
# selected elements: 374668
# ------------
# cluster= 2
# amplitude= 0.6738900795292716 idx= (2, 9, 323, 38)
# selected elements: 19693
# ------------
# cluster= 3
# amplitude= 0.6417423489767607 idx= (15, 14, 264, 112)
# selected elements: 11066
# ------------
# cluster= 4
# amplitude= 0.6231492510095625 idx= (6, 15, 342, 100)
# selected elements: 2863
# ------------
# cluster= 5
# amplitude= 0.6165027202782004 idx= (14, 15, 260, 120)
# selected elements: 106598
# ------------
# cluster= 6
# amplitude= 0.6161998622389802 idx= (15, 12, 282, 69)
# selected elements: 14523
# ------------
# cluster= 7
# amplitude= 0.5946466547857887 idx= (2, 12, 290, 65)
# selected elements: 10198
# ------------
# cluster= 8
# amplitude= 0.5514946717453004 idx= (10, 2, 216, 91)
# selected elements: 218494
# ------------
# cluster= 9
# amplitude= 0.48294584637696647 idx= (10, 0, 222, 73)
# selected elements: 6010
# ------------
# cluster= 10
# amplitude= 0.47107195565882637 idx= (1, 3, 247, 63)
# selected elements: 34300
# ------------
# cluster= 11
# amplitude= 0.45365791930520794 idx= (7, 0, 225, 60)
# selected elements: 3676
# ------------
# cluster= 12
# amplitude= 0.45327808737012215 idx= (13, 4, 296, 74)
# selected elements: 27931
# ------------
# cluster= 13
# amplitude= 0.4433517141256409 idx= (13, 10, 279, 70)
# selected elements: 38328
# ------------
# cluster= 14
# amplitude= 0.4281058584172503 idx= (2, 13, 341, 99)
# selected elements: 223
# ------------
# cluster= 15
# amplitude= 0.42259910984429416 idx= (8, 5, 298, 58)
# selected elements: 55763
# ------------
# cluster= 16
# amplitude= 0.41791235646463615 idx= (11, 8, 312, 26)
# selected elements: 20108
# ------------
# cluster= 17
# amplitude= 0.41160389626007415 idx= (8, 9, 249, 143)
# selected elements: 9064
# ------------
# cluster= 18
# amplitude= 0.4076256774634791 idx= (15, 7, 308, 33)
# selected elements: 3330
# ------------
# cluster= 19
# amplitude= 0.3978870680974239 idx= (6, 2, 283, 116)
# selected elements: 17434
# ------------
# cluster= 20
# amplitude= 0.3900486907728493 idx= (11, 17, 226, 52)
# selected elements: 49585
# ------------
# cluster= 21
# amplitude= 0.3817323557353711 idx= (11, 9, 235, 5)
# selected elements: 29573
# ------------
# cluster= 22
# amplitude= 0.37760579535788574 idx= (11, 10, 248, 143)
# selected elements: 1373
# ------------
# cluster= 23
# amplitude= 0.3756150245823661 idx= (11, 12, 324, 143)
# selected elements: 501
# ------------
# cluster= 24
# amplitude= 0.3687027392323991 idx= (11, 3, 227, 27)
# selected elements: 1430
# ------------
# cluster= 25
# amplitude= 0.36700651836909914 idx= (6, 10, 319, 142)
# selected elements: 8356
# ------------
# cluster= 26
# amplitude= 0.35351888894740335 idx= (14, 2, 139, 109)
# selected elements: 30794
# ------------
# cluster= 27
# amplitude= 0.35243910611797213 idx= (8, 13, 217, 95)
# selected elements: 1044
# ------------
# cluster= 28
# amplitude= 0.344811395567294 idx= (0, 3, 273, 41)
# selected elements: 1484
# ------------
# cluster= 29
# amplitude= 0.34434639673458906 idx= (8, 5, 101, 80)
# selected elements: 109450
# ------------
# cluster= 30
# amplitude= 0.34186896313093584 idx= (4, 6, 336, 119)
# selected elements: 23441
# ------------
# cluster= 31
# amplitude= 0.34121439715943697 idx= (13, 8, 232, 58)
# selected elements: 1678
# ------------
# cluster= 32
# amplitude= 0.34030503412387775 idx= (15, 7, 263, 140)
# selected elements: 7597
# ------------
# cluster= 33
# amplitude= 0.3384000738170678 idx= (15, 5, 207, 96)
# selected elements: 21864
# ------------
# cluster= 34
# amplitude= 0.335352081980858 idx= (5, 3, 172, 128)
# selected elements: 4357
# ------------
# cluster= 35
# amplitude= 0.32616228106317874 idx= (6, 7, 276, 102)
# selected elements: 9938
# ------------
# cluster= 36
# amplitude= 0.32087247339399694 idx= (7, 4, 290, 104)
# selected elements: 440
# ------------
# cluster= 37
# amplitude= 0.3184152867261436 idx= (3, 13, 344, 65)
# selected elements: 203
# ------------
# cluster= 38
# amplitude= 0.31462707455298544 idx= (11, 6, 289, 71)
# selected elements: 5209
# ------------
# cluster= 39
# amplitude= 0.3136788746865228 idx= (4, 4, 241, 49)
# selected elements: 15092
# ------------
# cluster= 40
# amplitude= 0.3107686907679364 idx= (9, 11, 247, 142)
# selected elements: 2860
# ------------
# cluster= 41
# amplitude= 0.30511681303811755 idx= (10, 0, 239, 135)
# selected elements: 5299
# ------------
# cluster= 42
# amplitude= 0.3010360042755926 idx= (5, 11, 221, 113)
# selected elements: 19441
# ------------
# cluster= 43
# amplitude= 0.30001082567267917 idx= (2, 2, 274, 40)
# selected elements: 1161
# ------------
# cluster= 44
# amplitude= 0.29905487277832243 idx= (8, 4, 169, 130)
# selected elements: 15911
# ------------
# cluster= 45
# amplitude= 0.29645238508983646 idx= (5, 0, 225, 59)
# selected elements: 1732
# ------------
# cluster= 46
# amplitude= 0.2952678020995204 idx= (5, 9, 249, 142)
# selected elements: 745
# ------------
# cluster= 47
# amplitude= 0.29332091526993775 idx= (8, 9, 235, 6)
# selected elements: 3788
# ------------
# cluster= 48
# amplitude= 0.29253224694584107 idx= (7, 14, 214, 94)
# selected elements: 638
# ------------
# cluster= 49
# amplitude= 0.2909640970979794 idx= (9, 16, 251, 117)
# selected elements: 15140
# ------------
# cluster= 50
# amplitude= 0.28881729397838346 idx= (6, 1, 231, 68)
# selected elements: 4657
# ------------
# cluster= 51
# amplitude= 0.28337131288284917 idx= (5, 9, 223, 104)
# selected elements: 1032
# ------------
# cluster= 52
# amplitude= 0.2821271693097444 idx= (11, 16, 338, 135)
# selected elements: 13911
# ------------
# cluster= 53
# amplitude= 0.281582248851642 idx= (4, 7, 306, 68)
# selected elements: 1813
# ------------
# cluster= 54
# amplitude= 0.28062132551365476 idx= (1, 14, 342, 99)
# selected elements: 290
# ------------
# cluster= 55
# amplitude= 0.2804713024353518 idx= (3, 15, 312, 75)
# selected elements: 1823
# ------------
# cluster= 56
# amplitude= 0.2803142964798099 idx= (3, 4, 290, 103)
# selected elements: 1532
# ------------
# cluster= 57
# amplitude= 0.27360922755845585 idx= (4, 1, 198, 123)
# selected elements: 5564
# ------------
# cluster= 58
# amplitude= 0.2713268687498326 idx= (1, 7, 329, 31)
# selected elements: 3595
# ------------
# cluster= 59
# amplitude= 0.26455360321104676 idx= (12, 0, 336, 132)
# selected elements: 5173
# ------------
# cluster= 60
# amplitude= 0.2640357908784433 idx= (1, 4, 228, 99)
# selected elements: 3695
# ------------
# cluster= 61
# amplitude= 0.2628821259388598 idx= (0, 13, 341, 99)
# selected elements: 527
# ------------
# cluster= 62
# amplitude= 0.2603706934319775 idx= (3, 10, 275, 78)
# selected elements: 1875
# ------------
# cluster= 63
# amplitude= 0.2556270015388024 idx= (2, 3, 160, 114)
# selected elements: 3106
# ------------
# cluster= 64
# amplitude= 0.25551993057823785 idx= (0, 1, 215, 45)
# selected elements: 4395
# ------------
# cluster= 65
# amplitude= 0.2549871584523559 idx= (2, 14, 315, 77)
# selected elements: 698
# ------------
# cluster= 66
# amplitude= 0.2544835523021684 idx= (13, 0, 345, 22)
# selected elements: 3720
# ------------
# cluster= 67
# amplitude= 0.2540754440337312 idx= (1, 5, 239, 17)
# selected elements: 5538
# ------------
# cluster= 68
# amplitude= 0.2539679409176337 idx= (8, 2, 229, 36)
# selected elements: 1574
# ------------
# cluster= 69
# amplitude= 0.2532041671971329 idx= (3, 6, 301, 47)
# selected elements: 2300
# ------------
# cluster= 70
# amplitude= 0.2530426430155004 idx= (3, 13, 253, 71)
# selected elements: 3104
# ------------
# cluster= 71
# amplitude= 0.2528618151471052 idx= (2, 9, 312, 82)
# selected elements: 3009
# ------------
# cluster= 72
# amplitude= 0.252101462224865 idx= (15, 7, 241, 63)
# selected elements: 4155
# ------------
# cluster= 73
# amplitude= 0.2511899126534481 idx= (3, 9, 254, 90)
# selected elements: 2036
# ------------
# cluster= 74
# amplitude= 0.25069906506143513 idx= (10, 5, 332, 130)
# selected elements: 11115
# ------------
# cluster= 75
# amplitude= 0.25009939508971474 idx= (5, 7, 303, 45)
# selected elements: 1504
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 94.00it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=3300:3900  ext=3250:3950  saved to outputs_decompose2d_slices/offset_0300/xcore_03300_03900_xext_03250_03950
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.3214639180094934 idx= (9, 13, 42, 94)
# selected elements: 1023087
# ------------
# cluster= 1
# amplitude= 0.685964642130868 idx= (14, 11, 51, 118)
# selected elements: 12418
# ------------
# cluster= 2
# amplitude= 0.6739164248790829 idx= (2, 9, 23, 38)
# selected elements: 10153
# ------------
# cluster= 3
# amplitude= 0.6321003896657056 idx= (2, 8, 55, 112)
# selected elements: 6981
# ------------
# cluster= 4
# amplitude= 0.5825633760226182 idx= (2, 12, 9, 64)
# selected elements: 3472
# ------------
# cluster= 5
# amplitude= 0.5748529016982926 idx= (15, 15, 58, 126)
# selected elements: 19702
# ------------
# cluster= 6
# amplitude= 0.5426812221037468 idx= (15, 10, 48, 122)
# selected elements: 14953
# ------------
# cluster= 7
# amplitude= 0.5314884037040707 idx= (8, 10, 19, 142)
# selected elements: 1257
# ------------
# cluster= 8
# amplitude= 0.4837358114610497 idx= (10, 10, 14, 73)
# selected elements: 862
# ------------
# cluster= 9
# amplitude= 0.46924091841291193 idx= (14, 9, 47, 121)
# selected elements: 14114
# ------------
# cluster= 10
# amplitude= 0.39868280096524594 idx= (6, 10, 19, 142)
# selected elements: 5862
# ------------
# cluster= 11
# amplitude= 0.3958034355191984 idx= (14, 7, 58, 81)
# selected elements: 52253
# ------------
# cluster= 12
# amplitude= 0.3915278245426776 idx= (13, 9, 15, 146)
# selected elements: 650
# ------------
# cluster= 13
# amplitude= 0.3846775415042877 idx= (14, 16, 53, 133)
# selected elements: 7446
# ------------
# cluster= 14
# amplitude= 0.3723925737741622 idx= (7, 7, 58, 114)
# selected elements: 119286
# ------------
# cluster= 15
# amplitude= 0.3672015731196952 idx= (11, 8, 17, 26)
# selected elements: 33497
# ------------
# cluster= 16
# amplitude= 0.36295738391101584 idx= (10, 11, 272, 50)
# selected elements: 106070
# ------------
# cluster= 17
# amplitude= 0.35886387089807725 idx= (12, 5, 42, 30)
# selected elements: 5903
# ------------
# cluster= 18
# amplitude= 0.3516297956609152 idx= (11, 0, 9, 62)
# selected elements: 77489
# ------------
# cluster= 19
# amplitude= 0.3387178026481602 idx= (9, 16, 10, 99)
# selected elements: 8752
# ------------
# cluster= 20
# amplitude= 0.31864795259313416 idx= (3, 8, 95, 63)
# selected elements: 20206
# ------------
# cluster= 21
# amplitude= 0.31583466048024106 idx= (15, 7, 12, 35)
# selected elements: 1162
# ------------
# cluster= 22
# amplitude= 0.29810487200443986 idx= (15, 13, 149, 118)
# selected elements: 25662
# ------------
# cluster= 23
# amplitude= 0.29536278394193294 idx= (15, 1, 6, 50)
# selected elements: 29744
# ------------
# cluster= 24
# amplitude= 0.2943816681435631 idx= (1, 12, 33, 75)
# selected elements: 925
# ------------
# cluster= 25
# amplitude= 0.29356007256287864 idx= (7, 15, 16, 81)
# selected elements: 2591
# ------------
# cluster= 26
# amplitude= 0.29325291915394985 idx= (6, 8, 14, 81)
# selected elements: 10357
# ------------
# cluster= 27
# amplitude= 0.287398609753827 idx= (15, 5, 42, 25)
# selected elements: 3919
# ------------
# cluster= 28
# amplitude= 0.28725350931948157 idx= (15, 10, 12, 147)
# selected elements: 534
# ------------
# cluster= 29
# amplitude= 0.2867022051592885 idx= (15, 9, 74, 7)
# selected elements: 1363
# ------------
# cluster= 30
# amplitude= 0.2846074652289457 idx= (3, 14, 7, 65)
# selected elements: 1072
# ------------
# cluster= 31
# amplitude= 0.2798515569067831 idx= (15, 15, 10, 123)
# selected elements: 1816
# ------------
# cluster= 32
# amplitude= 0.27662679659485323 idx= (10, 11, 125, 133)
# selected elements: 1570
# ------------
# cluster= 33
# amplitude= 0.2748465316072953 idx= (4, 5, 39, 115)
# selected elements: 3123
# ------------
# cluster= 34
# amplitude= 0.2713195097980908 idx= (1, 7, 29, 31)
# selected elements: 2238
# ------------
# cluster= 35
# amplitude= 0.26224408057379767 idx= (4, 6, 138, 34)
# selected elements: 9321
# ------------
# cluster= 36
# amplitude= 0.26132567305287335 idx= (14, 2, 47, 103)
# selected elements: 7875
# ------------
# cluster= 37
# amplitude= 0.2604147486113973 idx= (2, 3, 53, 86)
# selected elements: 12212
# ------------
# cluster= 38
# amplitude= 0.2587942921671606 idx= (11, 13, 244, 104)
# selected elements: 53800
# ------------
# cluster= 39
# amplitude= 0.25859235613428355 idx= (3, 8, 31, 77)
# selected elements: 2052
# ------------
# cluster= 40
# amplitude= 0.25665539825392203 idx= (5, 14, 6, 66)
# selected elements: 204
# ------------
# cluster= 41
# amplitude= 0.2563452523969603 idx= (3, 15, 45, 105)
# selected elements: 1515
# ------------
# cluster= 42
# amplitude= 0.2557526410046559 idx= (14, 0, 5, 19)
# selected elements: 5025
# ------------
# cluster= 43
# amplitude= 0.2555459377378855 idx= (9, 0, 59, 103)
# selected elements: 4838
# ------------
# cluster= 44
# amplitude= 0.2512050888614735 idx= (2, 9, 12, 82)
# selected elements: 1597
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 92.13it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=3900:4500  ext=3850:4550  saved to outputs_decompose2d_slices/offset_0300/xcore_03900_04500_xext_03850_04550
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.25282848418721937 idx= (15, 10, 98, 32)
# selected elements: 28004
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 93.99it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=4500:5100  ext=4450:5150  saved to outputs_decompose2d_slices/offset_0300/xcore_04500_05100_xext_04450_05150
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 94.25it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=5100:5451  ext=5050:5451  saved to outputs_decompose2d_slices/offset_0300/xcore_05100_05451_xext_05050_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 95.75it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Done. Outputs in /Users/anhphan/juwavelet_awe/examples/outputs_decompose2d_slices/offset_0300

# %% [markdown]
# ## Comparing two ways of stitching

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Dict, Any, List

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

# --------------------------
# User params
# --------------------------
FILE_PATH = "awe_l5c_q20_2024165T2120_03175_v01.nc"
FRAME_IDX = 0

# Loop settings on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)

# Extend each slice by this many UNBINNED pixels on each side (overlap = 2*SLICE_PAD)
SLICE_PAD = 50

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 16
JT = 18
ASPECT = 1

# Pixel spacing (km/pixel) for plotting and CWT (wavelengths will be in km)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# Clustering thresholds
MIN_AMP = 0.2
THR = 0.1

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices_p2_cs600")
SAVE_DPI = 200

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Helpers
# --------------------------
def read_radiance_frame(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        rad = nc.variables["Radiance"][:]  # (t, y, x)
    if rad.ndim != 3:
        raise ValueError(f"Radiance expected 3D (t,y,x); got {rad.shape}")
    if not (0 <= frame_idx < rad.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{rad.shape[0]-1}")
    return np.asarray(rad[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def load_radiance_window_from_array(
    Z: np.ndarray, xsl: slice, ysl: slice
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    win = np.asarray(Z[ysl, xsl], dtype=float)
    ny, nx = win.shape
    x = np.arange(nx, dtype=float)
    y = np.arange(ny, dtype=float)
    return x, y, win


def pad_window_to_width(win: np.ndarray, target_width: int) -> np.ndarray:
    ny, nx = win.shape
    if nx >= target_width:
        return win
    pad = target_width - nx
    med = float(np.nanmedian(win)) if np.isfinite(np.nanmedian(win)) else 0.0
    right = np.full((ny, pad), med, dtype=float)
    return np.concatenate([win, right], axis=1)


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    u = np.cos(theta_xy)
    v = np.sin(theta_xy)
    return u, v


def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("Radiance (arb)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    stacked = np.concatenate([orig_c.ravel(), bg_c.ravel(), rem_c.ravel(), rem_tapered_c.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [1, 99])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    fig, axs = plt.subplots(2, 2, figsize=(12, 10), constrained_layout=True)
    axes = axs.flatten()

    panels = [
        (orig_c, "Original (median-sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    im0 = None
    for ax, (Z, title) in zip(axes, panels):
        im0 = ax.pcolormesh(
            x1d_km, y1d_km, Z, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    cbar = fig.colorbar(im0, ax=axs, orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("Radiance (arb)")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2

    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_low, bg_high = np.nanpercentile(bg_xy, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax

    cl_low, cl_high = np.nanpercentile(rec_xy, [2, 98])
    cl_vmax = max(abs(cl_low), abs(cl_high))
    if not np.isfinite(cl_vmax) or cl_vmax == 0:
        cl_vmax = 1.0
    cl_vmin = -cl_vmax

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if not np.isfinite(lam_vmin) or not np.isfinite(lam_vmax) or lam_vmin == lam_vmax:
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n" + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        ARROW_LEN_KM = 40.0
        u = u * ARROW_LEN_KM
        v = v * ARROW_LEN_KM

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)


# --------------------------
# Main pipeline for one slice
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
) -> Dict[str, Any]:
    """
    Runs processing on an extended slice (x_slice), but returns only CORE tiles
    for stitching: core_start_unbinned..core_end_unbinned (typically 600 px wide).

    Step 08 (power) is removed.
    """
    outdir.mkdir(parents=True, exist_ok=True)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        dx_km = DX_KM_BASE * int(BIN_FACTOR)
        dy_km = DY_KM_BASE * int(BIN_FACTOR)
        f = int(BIN_FACTOR)
    else:
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE
        f = 1

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f
    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    # Window on unbinned flattened field
    _, _, raw_win = load_radiance_window_from_array(rad2d_flat, x_slice, Y_SLICE)

    # Only pad if we are shorter than X_CHUNK (helps last slice)
    raw_win = pad_window_to_width(raw_win, X_CHUNK)

    # Optional binning
    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"Radiance (window, flattened){bin_tag}",
        outdir / "00_radiance_window.png",
    )

    # Background separation
    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_4panel.png",
    )

    # Preprocess for CWT
    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=MIN_AMP, thr=THR)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    # Overview decomposition plot
    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N
    )
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    # FOV wavelet spectrum
    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)

    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text("No clusters found. Try lowering MIN_AMP or THR.\n")

        remaining_core_xy = crop_pad_core(proc)
        nan_core = np.full_like(remaining_core_xy, np.nan)

        return {
            "has_clusters": False,
            "x_start_unbinned": core_start_unbinned,
            "dx_km": dx_km,
            "dy_km": dy_km,
            "remaining_xy": remaining_core_xy,
            "rec_all_xy": nan_core,
        }

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    # Write ranking to text file
    lines = []
    lines.append("Cluster power ranking (clustered only)\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))

    theta_vals = np.asarray(cwt["theta"], dtype=float)

    # Figure 1: standalone clusters
    fig1, axs1 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs1 = np.atleast_1d(axs1).reshape(-1)

    opts_cluster = {"cmap": "RdBu_r", "vmin": -1.0, "vmax": 1.0, "rasterized": True}

    for ax, kcl in zip(axs1, biggest):
        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", **opts_cluster)
        ax.set_aspect("equal", adjustable="box")

    for ax in axs1[n_show:]:
        ax.axis("off")
    for ax in axs1[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}
    for i, ax in enumerate(axs1, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig1.tight_layout()
    save_fig(fig1, outdir / "05_clusters_standalone.png")

    # Figure 2: overlays
    fig2, axs2 = plt.subplots(nrow, ncol, figsize=(12, 10))
    axs2 = np.atleast_1d(axs2).reshape(-1)

    bg_low, bg_high = np.nanpercentile(bg, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax
    cl_vmin, cl_vmax = -1.0, 1.0

    for ax, kcl in zip(axs2, biggest):
        ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)

        decomposition[:] = orig_decomp
        decomposition[iwave != kcl] = 0
        rec = transform.reconstruct2d(cwt)
        rec_centered = rec.T - np.median(rec)

        s_idx = int(idxs[kcl][0])
        t_idx = int(idxs[kcl][1])
        _, _, lam = effective_lambda(cwt, s_idx, t_idx)

        theta_dom_rad = float(theta_vals[t_idx])
        theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

        ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
        Pk = float(P_abs_sorted[ii])
        pk = float(P_pct_sorted[ii])

        ax.pcolormesh(
            x1d_km, y1d_km, rec_centered,
            shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
        )

        ax.set_title(
            rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
            + "\n"
            + rf"P={Pk:.2e} ({pk:.1f}%)"
        )
        ax.set_aspect("equal", adjustable="box")

    for ax in axs2[n_show:]:
        ax.axis("off")
    for ax in axs2[:n_show]:
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")

    for i, ax in enumerate(axs2, start=1):
        if ax.has_data():
            ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

    fig2.tight_layout()
    save_fig(fig2, outdir / "06_clusters_overlay.png")

    # Per cluster 2x2 maps
    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
        )

    # 09 per slice: remaining vs all clusters reconstruction
    remaining_after_preproc_xy = proc

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)          # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)

    stacked = np.concatenate([remaining_after_preproc_xy.ravel(), rec_all_xy.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [2, 98])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    figR, (axL, axR) = plt.subplots(1, 2, figsize=(16, 6), constrained_layout=True)

    imL = axL.pcolormesh(
        x1d_km, y1d_km, remaining_after_preproc_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axL.set_title("Remaining (after preprocessing, input to CWT)")
    axL.set_xlabel("x (km)")
    axL.set_ylabel("y (km)")
    axL.set_aspect("equal", adjustable="box")
    figR.colorbar(imL, ax=axL, fraction=0.046, pad=0.02).set_label("arb")

    imR = axR.pcolormesh(
        x1d_km, y1d_km, rec_all_xy,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axR.set_title("All clusters combined (reconstruction)")
    axR.set_xlabel("x (km)")
    axR.set_ylabel("y (km)")
    axR.set_aspect("equal", adjustable="box")
    figR.colorbar(imR, ax=axR, fraction=0.046, pad=0.02).set_label("arb")

    save_fig(figR, outdir / "09_remaining_vs_all_clusters.png")

    decomposition[:] = orig_decomp

    # Return only CORE tiles for stitching
    remaining_core_xy = crop_pad_core(remaining_after_preproc_xy)
    rec_all_core_xy = crop_pad_core(rec_all_xy)

    return {
        "has_clusters": True,
        "x_start_unbinned": core_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "remaining_xy": remaining_core_xy,
        "rec_all_xy": rec_all_core_xy,
    }


# --------------------------
# Stitch helper: make stitched 09 + DIFFERENCE between offsets
# --------------------------
def stitch_rec_all(slice_results: List[Dict[str, Any]]) -> Tuple[np.ndarray, float, float, float]:
    """
    Returns:
      rec_all_stitched (ny, nx)
      x0_km, dx_km, dy_km
    """
    if len(slice_results) == 0:
        raise ValueError("No slice_results to stitch.")

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE

    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)
    return rec_all_stitched, x0_km, dx_km, dy_km


def stitch_and_save_final_09(slice_results: List[Dict[str, Any]], outroot: Path, tag: str) -> None:
    if len(slice_results) == 0:
        return

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE

    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)

    ny, nx_tot = remaining_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    stacked = np.concatenate([remaining_stitched.ravel(), rec_all_stitched.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [2, 98])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    figR, (axT, axB) = plt.subplots(2, 1, figsize=(18, 4), constrained_layout=True, sharex=True, sharey=True)

    imT = axT.pcolormesh(
        x1d_km, y1d_km, remaining_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axT.set_title(f"STITCHED (core tiles) {tag}: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(
        x1d_km, y1d_km, rec_all_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axB.set_title(f"STITCHED (core tiles) {tag}: All clusters combined (reconstruction)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    xmin_km = 600
    xmax_km = 10000
    axT.set_xlim(xmin_km, xmax_km)

    cbar = figR.colorbar(imT, ax=[axT, axB], orientation="vertical", fraction=0.01, pad=0.01)
    cbar.set_label("kRayleigh (Relative)")

    save_fig(figR, outroot / f"FINAL_09_remaining_vs_all_clusters_STITCHED_{tag}.png")


def save_offset_difference(
    rec0: np.ndarray,
    x0_km_0: float,
    rec1: np.ndarray,
    x0_km_1: float,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    """
    Subtract stitched reconstructions from two slicing offsets.
    We align them in km-space by trimming to the overlapping x-range.
    """
    if rec0.shape[0] != rec1.shape[0]:
        raise ValueError(f"Different ny: {rec0.shape[0]} vs {rec1.shape[0]}")

    # Compute overlapping x-range in km
    nx0 = rec0.shape[1]
    nx1 = rec1.shape[1]
    x0_min = x0_km_0
    x0_max = x0_km_0 + (nx0 - 1) * dx_km
    x1_min = x0_km_1
    x1_max = x0_km_1 + (nx1 - 1) * dx_km

    x_min = max(x0_min, x1_min)
    x_max = min(x0_max, x1_max)
    if x_max <= x_min:
        raise ValueError("No overlapping x-range between the two stitched reconstructions.")

    # Convert overlap endpoints to integer column indices
    j0_start = int(round((x_min - x0_km_0) / dx_km))
    j0_end = int(round((x_max - x0_km_0) / dx_km)) + 1

    j1_start = int(round((x_min - x0_km_1) / dx_km))
    j1_end = int(round((x_max - x0_km_1) / dx_km)) + 1

    rec0_sub = rec0[:, j0_start:j0_end]
    rec1_sub = rec1[:, j1_start:j1_end]

    nx = min(rec0_sub.shape[1], rec1_sub.shape[1])
    rec0_sub = rec0_sub[:, :nx]
    rec1_sub = rec1_sub[:, :nx]

    diff = rec0_sub - rec1_sub

    ny = diff.shape[0]
    x1d_km = x_min + np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    # symmetric limits
    p_low, p_high = np.nanpercentile(diff[np.isfinite(diff)], [2, 98]) if np.any(np.isfinite(diff)) else (-1, 1)
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    fig, ax = plt.subplots(figsize=(18, 4), constrained_layout=True)
    im = ax.pcolormesh(x1d_km, y1d_km, diff, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    ax.set_title("Difference of stitched reconstructions: offset 0 minus offset 300 (overlap region only)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_aspect("equal", adjustable="box")
    cbar = fig.colorbar(im, ax=ax, fraction=0.02, pad=0.01)
    cbar.set_label("kRayleigh (Relative)")
    xmin_km = 600
    xmax_km = 10000
    ax.set_xlim(xmin_km, xmax_km)

    save_fig(fig, outpath)

# --------------------------
# Run all slices
# --------------------------
def run_all_slices() -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_radiance_frame(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    stitched_recs: Dict[int, Tuple[np.ndarray, float, float, float]] = {}

    for x_offset in [0, 300]:
        if x_offset >= nx_total:
            print(f"Skip offset {x_offset}: nx_total={nx_total}")
            continue

        outroot = OUTPUT_ROOT / f"offset_{x_offset:04d}"
        outroot.mkdir(parents=True, exist_ok=True)

        core_starts = list(range(x_offset, nx_total, X_CHUNK))

        stitch_results: List[Dict[str, Any]] = []

        for core_start in core_starts:
            core_end = min(core_start + X_CHUNK, nx_total)

            ext_start = max(0, core_start - SLICE_PAD)
            ext_end = min(nx_total, core_end + SLICE_PAD)
            x_slice = slice(ext_start, ext_end)

            outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
            print(f"[offset {x_offset}] core={core_start}:{core_end}  ext={ext_start}:{ext_end}  saved to {outdir}")

            res = run_pipeline_for_slice(
                rad2d_flat=rad2d_flat,
                x_slice=x_slice,
                outdir=outdir,
                x_start_unbinned=ext_start,
                core_start_unbinned=core_start,
                core_end_unbinned=core_end,
            )
            stitch_results.append(res)

        stitch_and_save_final_09(stitch_results, outroot, tag=f"offset_{x_offset:04d}")

        rec_all_stitched, x0_km, dx_km, dy_km = stitch_rec_all(stitch_results)
        stitched_recs[x_offset] = (rec_all_stitched, x0_km, dx_km, dy_km)

        print(f"[offset {x_offset}] Done. Outputs in {outroot.resolve()}")

    # Subtract stitched reconstructions from the two ways of slicing (offset 0 vs offset 300)
    if 0 in stitched_recs and 300 in stitched_recs:
        rec0, x0_km_0, dx_km_0, dy_km_0 = stitched_recs[0]
        rec1, x0_km_1, dx_km_1, dy_km_1 = stitched_recs[300]

        if abs(dx_km_0 - dx_km_1) > 1e-9 or abs(dy_km_0 - dy_km_1) > 1e-9:
            raise ValueError("dx_km/dy_km differ between offsets. Check binning/settings.")

        save_offset_difference(
            rec0=rec0,
            x0_km_0=x0_km_0,
            rec1=rec1,
            x0_km_1=x0_km_1,
            dx_km=dx_km_0,
            dy_km=dy_km_0,
            outpath=OUTPUT_ROOT / "FINAL_DIFF_rec_all_offset0_minus_offset300.png",
        )
        print("Saved difference plot:", (OUTPUT_ROOT / "FINAL_DIFF_rec_all_offset0_minus_offset300.png").resolve())


run_all_slices()
# Out:
# [offset 0] core=0:600  ext=0:650  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_00000_00600_xext_00000_00650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.37108038888739175 idx= (12, 9, 308, 58)
# selected elements: 159407
# ------------
# cluster= 1
# amplitude= 0.3444417504565404 idx= (13, 9, 205, 118)
# selected elements: 64010
# ------------
# cluster= 2
# amplitude= 0.31221373851265266 idx= (12, 7, 256, 71)
# selected elements: 30843
# ------------
# cluster= 3
# amplitude= 0.30603962397346623 idx= (10, 9, 255, 78)
# selected elements: 15591
# ------------
# cluster= 4
# amplitude= 0.2759813435543466 idx= (5, 7, 274, 60)
# selected elements: 10614
# ------------
# cluster= 5
# amplitude= 0.26529812480818515 idx= (5, 10, 197, 116)
# selected elements: 1744
# ------------
# cluster= 6
# amplitude= 0.2586889237913039 idx= (11, 12, 285, 58)
# selected elements: 6338
# ------------
# cluster= 7
# amplitude= 0.24621886606577267 idx= (9, 10, 159, 36)
# selected elements: 20459
# ------------
# cluster= 8
# amplitude= 0.21768271772666328 idx= (5, 10, 199, 29)
# selected elements: 6779
# ------------
# cluster= 9
# amplitude= 0.2125093455099971 idx= (15, 7, 243, 124)
# selected elements: 4807
# ------------
# cluster= 10
# amplitude= 0.21082208911597553 idx= (15, 13, 290, 46)
# selected elements: 4225
# ------------
# cluster= 11
# amplitude= 0.21051256241488664 idx= (14, 12, 153, 120)
# selected elements: 10607
# ------------
# cluster= 12
# amplitude= 0.20894104410732525 idx= (9, 11, 214, 57)
# selected elements: 7971
# ------------
# cluster= 13
# amplitude= 0.2078033251965815 idx= (9, 10, 140, 69)
# selected elements: 14115
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 91.88it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=600:1200  ext=550:1250  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_00600_01200_xext_00550_01250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.48025098934026705 idx= (6, 8, 241, 25)
# selected elements: 53690
# ------------
# cluster= 1
# amplitude= 0.47277683261286246 idx= (5, 9, 243, 24)
# selected elements: 5657
# ------------
# cluster= 2
# amplitude= 0.4083574722293721 idx= (8, 9, 48, 50)
# selected elements: 135036
# ------------
# cluster= 3
# amplitude= 0.4057785279312059 idx= (7, 8, 50, 51)
# selected elements: 2388
# ------------
# cluster= 4
# amplitude= 0.3723316141390129 idx= (15, 9, 246, 27)
# selected elements: 42268
# ------------
# cluster= 5
# amplitude= 0.33530692587411665 idx= (10, 11, 71, 43)
# selected elements: 38036
# ------------
# cluster= 6
# amplitude= 0.3333222246800942 idx= (10, 9, 199, 7)
# selected elements: 34263
# ------------
# cluster= 7
# amplitude= 0.29199315438429424 idx= (13, 8, 250, 28)
# selected elements: 8134
# ------------
# cluster= 8
# amplitude= 0.2821105973255177 idx= (13, 12, 19, 52)
# selected elements: 33626
# ------------
# cluster= 9
# amplitude= 0.27196833062886816 idx= (9, 10, 281, 10)
# selected elements: 6223
# ------------
# cluster= 10
# amplitude= 0.2646144330380939 idx= (2, 8, 57, 53)
# selected elements: 1806
# ------------
# cluster= 11
# amplitude= 0.252289020994592 idx= (13, 10, 158, 7)
# selected elements: 11158
# ------------
# cluster= 12
# amplitude= 0.23954182793681061 idx= (13, 7, 161, 61)
# selected elements: 38930
# ------------
# cluster= 13
# amplitude= 0.23411610464554305 idx= (10, 9, 108, 5)
# selected elements: 5884
# ------------
# cluster= 14
# amplitude= 0.23283427931253153 idx= (12, 10, 109, 7)
# selected elements: 1621
# ------------
# cluster= 15
# amplitude= 0.23231672953858867 idx= (11, 8, 301, 32)
# selected elements: 12663
# ------------
# cluster= 16
# amplitude= 0.21858124141791535 idx= (5, 9, 128, 66)
# selected elements: 4896
# ------------
# cluster= 17
# amplitude= 0.21777447868954353 idx= (11, 7, 77, 55)
# selected elements: 12554
# ------------
# cluster= 18
# amplitude= 0.21152829576239535 idx= (7, 9, 280, 11)
# selected elements: 1519
# ------------
# cluster= 19
# amplitude= 0.2009010551342877 idx= (3, 10, 106, 57)
# selected elements: 2116
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.28it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=1200:1800  ext=1150:1850  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_01200_01800_xext_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.28058267975080087 idx= (6, 10, 325, 134)
# selected elements: 13696
# ------------
# cluster= 1
# amplitude= 0.23826621503663226 idx= (9, 7, 157, 37)
# selected elements: 42677
# ------------
# cluster= 2
# amplitude= 0.22799194295356864 idx= (11, 13, 193, 94)
# selected elements: 20205
# ------------
# cluster= 3
# amplitude= 0.2200406757367188 idx= (13, 9, 173, 8)
# selected elements: 18350
# ------------
# cluster= 4
# amplitude= 0.2135749478263648 idx= (7, 4, 329, 125)
# selected elements: 8796
# ------------
# cluster= 5
# amplitude= 0.20804465749275744 idx= (6, 5, 152, 24)
# selected elements: 2967
# ------------
# cluster= 6
# amplitude= 0.20411067927736343 idx= (10, 14, 139, 110)
# selected elements: 11214
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 80.18it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=1800:2400  ext=1750:2450  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_01800_02400_xext_01750_02450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.31810958235042114 idx= (15, 8, 294, 125)
# selected elements: 63130
# ------------
# cluster= 1
# amplitude= 0.2818026053147679 idx= (6, 10, 25, 134)
# selected elements: 11345
# ------------
# cluster= 2
# amplitude= 0.24102163806222487 idx= (15, 9, 38, 8)
# selected elements: 19361
# ------------
# cluster= 3
# amplitude= 0.2345179562864613 idx= (10, 7, 53, 135)
# selected elements: 31606
# ------------
# cluster= 4
# amplitude= 0.21285623510781412 idx= (7, 4, 29, 126)
# selected elements: 11216
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 31.62it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=2400:3000  ext=2350:3050  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_02400_03000_xext_02350_03050
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.5073188037472124 idx= (15, 2, 332, 112)
# selected elements: 172637
# ------------
# cluster= 1
# amplitude= 0.44028277189678355 idx= (8, 2, 323, 128)
# selected elements: 37271
# ------------
# cluster= 2
# amplitude= 0.3535136289053397 idx= (14, 2, 289, 109)
# selected elements: 23871
# ------------
# cluster= 3
# amplitude= 0.3443464000221411 idx= (8, 5, 251, 80)
# selected elements: 85486
# ------------
# cluster= 4
# amplitude= 0.2867008512446188 idx= (14, 1, 342, 54)
# selected elements: 11644
# ------------
# cluster= 5
# amplitude= 0.2827535387468756 idx= (14, 6, 245, 86)
# selected elements: 9585
# ------------
# cluster= 6
# amplitude= 0.27481485619158913 idx= (14, 1, 141, 124)
# selected elements: 42397
# ------------
# cluster= 7
# amplitude= 0.25887743560684784 idx= (10, 1, 109, 105)
# selected elements: 15971
# ------------
# cluster= 8
# amplitude= 0.25702515380346436 idx= (13, 4, 251, 82)
# selected elements: 11066
# ------------
# cluster= 9
# amplitude= 0.2556270058382898 idx= (2, 3, 310, 114)
# selected elements: 1901
# ------------
# cluster= 10
# amplitude= 0.24995082048971037 idx= (15, 17, 342, 67)
# selected elements: 8023
# ------------
# cluster= 11
# amplitude= 0.24925003704379378 idx= (11, 11, 135, 113)
# selected elements: 31541
# ------------
# cluster= 12
# amplitude= 0.24743804089807744 idx= (10, 0, 344, 71)
# selected elements: 2895
# ------------
# cluster= 13
# amplitude= 0.24391141916818954 idx= (2, 8, 276, 82)
# selected elements: 3559
# ------------
# cluster= 14
# amplitude= 0.2436789592108028 idx= (4, 7, 275, 85)
# selected elements: 1501
# ------------
# cluster= 15
# amplitude= 0.23358840684743518 idx= (15, 9, 321, 8)
# selected elements: 14806
# ------------
# cluster= 16
# amplitude= 0.2303198168301527 idx= (14, 9, 299, 47)
# selected elements: 21240
# ------------
# cluster= 17
# amplitude= 0.22923797162738702 idx= (8, 9, 74, 74)
# selected elements: 38843
# ------------
# cluster= 18
# amplitude= 0.22877048948830647 idx= (3, 10, 275, 110)
# selected elements: 3089
# ------------
# cluster= 19
# amplitude= 0.22719200077602839 idx= (11, 4, 338, 92)
# selected elements: 3208
# ------------
# cluster= 20
# amplitude= 0.22718281510971702 idx= (12, 1, 342, 98)
# selected elements: 426
# ------------
# cluster= 21
# amplitude= 0.22536808410662804 idx= (7, 3, 251, 123)
# selected elements: 11305
# ------------
# cluster= 22
# amplitude= 0.223311876092104 idx= (3, 1, 332, 111)
# selected elements: 3924
# ------------
# cluster= 23
# amplitude= 0.22320931950177267 idx= (15, 8, 120, 62)
# selected elements: 18650
# ------------
# cluster= 24
# amplitude= 0.2230731854898252 idx= (9, 4, 298, 85)
# selected elements: 5804
# ------------
# cluster= 25
# amplitude= 0.21400661701534046 idx= (11, 4, 335, 51)
# selected elements: 8807
# ------------
# cluster= 26
# amplitude= 0.2065544450476023 idx= (15, 4, 121, 83)
# selected elements: 4602
# ------------
# cluster= 27
# amplitude= 0.20602602831673927 idx= (5, 1, 227, 71)
# selected elements: 8238
# ------------
# cluster= 28
# amplitude= 0.20542377375475687 idx= (15, 17, 345, 117)
# selected elements: 4506
# ------------
# cluster= 29
# amplitude= 0.20055609172243696 idx= (15, 11, 205, 60)
# selected elements: 10280
# ------------
# cluster= 30
# amplitude= 0.20013201274804365 idx= (15, 7, 317, 10)
# selected elements: 4072
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 73.38it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=3000:3600  ext=2950:3650  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_03000_03600_xext_02950_03650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.3214636561113875 idx= (9, 13, 192, 94)
# selected elements: 1775906
# ------------
# cluster= 1
# amplitude= 0.9003197682772737 idx= (15, 0, 76, 64)
# selected elements: 602992
# ------------
# cluster= 2
# amplitude= 0.6987886768105129 idx= (14, 11, 134, 71)
# selected elements: 25859
# ------------
# cluster= 3
# amplitude= 0.6738899013098673 idx= (2, 9, 173, 38)
# selected elements: 15897
# ------------
# cluster= 4
# amplitude= 0.6633018198683046 idx= (15, 15, 112, 122)
# selected elements: 62850
# ------------
# cluster= 5
# amplitude= 0.6321003850772021 idx= (2, 8, 205, 112)
# selected elements: 6978
# ------------
# cluster= 6
# amplitude= 0.5946466521224315 idx= (2, 12, 140, 65)
# selected elements: 10198
# ------------
# cluster= 7
# amplitude= 0.5748977187181881 idx= (15, 15, 208, 126)
# selected elements: 3020
# ------------
# cluster= 8
# amplitude= 0.5619048612177782 idx= (15, 5, 148, 77)
# selected elements: 46540
# ------------
# cluster= 9
# amplitude= 0.5514946678711187 idx= (10, 2, 66, 91)
# selected elements: 81839
# ------------
# cluster= 10
# amplitude= 0.5235622108851281 idx= (15, 10, 198, 121)
# selected elements: 32718
# ------------
# cluster= 11
# amplitude= 0.5101500127398403 idx= (14, 9, 153, 27)
# selected elements: 29448
# ------------
# cluster= 12
# amplitude= 0.47416570441741424 idx= (8, 0, 75, 60)
# selected elements: 46608
# ------------
# cluster= 13
# amplitude= 0.47107195201930246 idx= (1, 3, 97, 63)
# selected elements: 49179
# ------------
# cluster= 14
# amplitude= 0.45328823253373934 idx= (13, 4, 146, 74)
# selected elements: 18629
# ------------
# cluster= 15
# amplitude= 0.4225991033733493 idx= (8, 5, 148, 58)
# selected elements: 125060
# ------------
# cluster= 16
# amplitude= 0.41719501693471606 idx= (11, 8, 161, 26)
# selected elements: 18109
# ------------
# cluster= 17
# amplitude= 0.40709170969015607 idx= (15, 7, 157, 33)
# selected elements: 5659
# ------------
# cluster= 18
# amplitude= 0.3989089209590924 idx= (11, 10, 98, 144)
# selected elements: 1323
# ------------
# cluster= 19
# amplitude= 0.39889146273385023 idx= (11, 9, 85, 5)
# selected elements: 29549
# ------------
# cluster= 20
# amplitude= 0.39788706872873286 idx= (6, 2, 133, 116)
# selected elements: 17434
# ------------
# cluster= 21
# amplitude= 0.3900486911401334 idx= (11, 17, 76, 52)
# selected elements: 49702
# ------------
# cluster= 22
# amplitude= 0.3845408507049589 idx= (14, 16, 203, 133)
# selected elements: 13790
# ------------
# cluster= 23
# amplitude= 0.3780959765269905 idx= (6, 10, 169, 142)
# selected elements: 5694
# ------------
# cluster= 24
# amplitude= 0.37239480583145085 idx= (7, 7, 208, 114)
# selected elements: 27380
# ------------
# cluster= 25
# amplitude= 0.36870274155613997 idx= (11, 3, 77, 27)
# selected elements: 1430
# ------------
# cluster= 26
# amplitude= 0.35243911371492215 idx= (8, 13, 67, 95)
# selected elements: 1044
# ------------
# cluster= 27
# amplitude= 0.3451640038620158 idx= (12, 16, 106, 119)
# selected elements: 14949
# ------------
# cluster= 28
# amplitude= 0.34481139615122036 idx= (0, 3, 123, 41)
# selected elements: 1484
# ------------
# cluster= 29
# amplitude= 0.34462144916899706 idx= (15, 7, 111, 141)
# selected elements: 7452
# ------------
# cluster= 30
# amplitude= 0.34245949680856475 idx= (10, 0, 187, 70)
# selected elements: 2320
# ------------
# cluster= 31
# amplitude= 0.34129532463247997 idx= (6, 8, 124, 102)
# selected elements: 18727
# ------------
# cluster= 32
# amplitude= 0.34121342636904806 idx= (13, 8, 82, 58)
# selected elements: 1678
# ------------
# cluster= 33
# amplitude= 0.3383768526836366 idx= (15, 5, 57, 96)
# selected elements: 15623
# ------------
# cluster= 34
# amplitude= 0.3353029524701459 idx= (5, 3, 22, 128)
# selected elements: 12977
# ------------
# cluster= 35
# amplitude= 0.32658202637322054 idx= (6, 6, 188, 117)
# selected elements: 8930
# ------------
# cluster= 36
# amplitude= 0.320872469577909 idx= (7, 4, 140, 104)
# selected elements: 440
# ------------
# cluster= 37
# amplitude= 0.3186479570026206 idx= (3, 8, 245, 63)
# selected elements: 16860
# ------------
# cluster= 38
# amplitude= 0.31405696450119547 idx= (9, 11, 97, 142)
# selected elements: 2835
# ------------
# cluster= 39
# amplitude= 0.3138943896025435 idx= (8, 7, 127, 102)
# selected elements: 8221
# ------------
# cluster= 40
# amplitude= 0.31367887074355333 idx= (4, 4, 91, 49)
# selected elements: 10691
# ------------
# cluster= 41
# amplitude= 0.30706562712180885 idx= (9, 8, 84, 6)
# selected elements: 3979
# ------------
# cluster= 42
# amplitude= 0.3051168124278113 idx= (10, 0, 89, 135)
# selected elements: 5299
# ------------
# cluster= 43
# amplitude= 0.302818608774934 idx= (8, 9, 85, 6)
# selected elements: 2733
# ------------
# cluster= 44
# amplitude= 0.3016294180723692 idx= (5, 9, 99, 142)
# selected elements: 763
# ------------
# cluster= 45
# amplitude= 0.3010360246190825 idx= (5, 11, 71, 113)
# selected elements: 19442
# ------------
# cluster= 46
# amplitude= 0.30004706104970186 idx= (8, 4, 19, 130)
# selected elements: 13765
# ------------
# cluster= 47
# amplitude= 0.3000108256031408 idx= (2, 2, 124, 40)
# selected elements: 1161
# ------------
# cluster= 48
# amplitude= 0.29985881520278806 idx= (9, 16, 189, 82)
# selected elements: 5286
# ------------
# cluster= 49
# amplitude= 0.2980951214690299 idx= (15, 13, 299, 118)
# selected elements: 14948
# ------------
# cluster= 50
# amplitude= 0.2943816633184424 idx= (1, 12, 183, 75)
# selected elements: 925
# ------------
# cluster= 51
# amplitude= 0.2930989103827532 idx= (7, 16, 192, 81)
# selected elements: 1731
# ------------
# cluster= 52
# amplitude= 0.29253224916396225 idx= (7, 14, 64, 94)
# selected elements: 638
# ------------
# cluster= 53
# amplitude= 0.29096409866125805 idx= (9, 16, 101, 117)
# selected elements: 15137
# ------------
# cluster= 54
# amplitude= 0.28337130862800847 idx= (5, 9, 73, 104)
# selected elements: 1032
# ------------
# cluster= 55
# amplitude= 0.28234339055003316 idx= (5, 3, 49, 114)
# selected elements: 2238
# ------------
# cluster= 56
# amplitude= 0.2815822443097733 idx= (4, 7, 156, 68)
# selected elements: 1814
# ------------
# cluster= 57
# amplitude= 0.28047130260997827 idx= (3, 15, 162, 75)
# selected elements: 1823
# ------------
# cluster= 58
# amplitude= 0.28031429588432694 idx= (3, 4, 140, 103)
# selected elements: 1532
# ------------
# cluster= 59
# amplitude= 0.277547090076265 idx= (10, 11, 276, 134)
# selected elements: 1568
# ------------
# cluster= 60
# amplitude= 0.27484652318073793 idx= (4, 5, 189, 115)
# selected elements: 4159
# ------------
# cluster= 61
# amplitude= 0.27360922638925633 idx= (4, 1, 48, 123)
# selected elements: 5569
# ------------
# cluster= 62
# amplitude= 0.2713195032747061 idx= (1, 7, 179, 31)
# selected elements: 4217
# ------------
# cluster= 63
# amplitude= 0.26403579034370467 idx= (1, 4, 78, 99)
# selected elements: 5018
# ------------
# cluster= 64
# amplitude= 0.26224408741807886 idx= (4, 6, 288, 34)
# selected elements: 9323
# ------------
# cluster= 65
# amplitude= 0.260414750586672 idx= (2, 3, 203, 86)
# selected elements: 12588
# ------------
# cluster= 66
# amplitude= 0.26037069280481234 idx= (3, 10, 125, 78)
# selected elements: 1875
# ------------
# cluster= 67
# amplitude= 0.25964317860420694 idx= (2, 8, 152, 95)
# selected elements: 5406
# ------------
# cluster= 68
# amplitude= 0.2582224478875309 idx= (13, 8, 229, 11)
# selected elements: 2382
# ------------
# cluster= 69
# amplitude= 0.25692813397616937 idx= (13, 1, 25, 119)
# selected elements: 4569
# ------------
# cluster= 70
# amplitude= 0.256548154452872 idx= (14, 9, 164, 148)
# selected elements: 368
# ------------
# cluster= 71
# amplitude= 0.25634524785459356 idx= (3, 15, 195, 105)
# selected elements: 1515
# ------------
# cluster= 72
# amplitude= 0.25554594318234974 idx= (9, 0, 209, 103)
# selected elements: 7522
# ------------
# cluster= 73
# amplitude= 0.25551992781351346 idx= (0, 1, 65, 45)
# selected elements: 4812
# ------------
# cluster= 74
# amplitude= 0.2549871598553237 idx= (2, 14, 165, 77)
# selected elements: 698
# ------------
# cluster= 75
# amplitude= 0.25407543816839384 idx= (1, 5, 89, 17)
# selected elements: 5538
# ------------
# cluster= 76
# amplitude= 0.2539679381270547 idx= (8, 2, 79, 36)
# selected elements: 1574
# ------------
# cluster= 77
# amplitude= 0.2532041673005213 idx= (3, 6, 151, 47)
# selected elements: 2300
# ------------
# cluster= 78
# amplitude= 0.2530426461412684 idx= (3, 13, 103, 71)
# selected elements: 3104
# ------------
# cluster= 79
# amplitude= 0.25118990790737505 idx= (3, 9, 104, 90)
# selected elements: 2036
# ------------
# cluster= 80
# amplitude= 0.2500993917502038 idx= (5, 7, 153, 45)
# selected elements: 1504
# ------------
# cluster= 81
# amplitude= 0.249731735837463 idx= (14, 8, 256, 56)
# selected elements: 2734
# ------------
# cluster= 82
# amplitude= 0.24829135886419015 idx= (3, 9, 80, 60)
# selected elements: 9131
# ------------
# cluster= 83
# amplitude= 0.24701340492777796 idx= (10, 2, 185, 65)
# selected elements: 3660
# ------------
# cluster= 84
# amplitude= 0.2458339101749339 idx= (11, 11, 63, 96)
# selected elements: 1484
# ------------
# cluster= 85
# amplitude= 0.2428128398143983 idx= (4, 7, 227, 104)
# selected elements: 1852
# ------------
# cluster= 86
# amplitude= 0.24266031913959918 idx= (5, 2, 85, 72)
# selected elements: 164
# ------------
# cluster= 87
# amplitude= 0.24233648397605728 idx= (13, 0, 309, 136)
# selected elements: 18852
# ------------
# cluster= 88
# amplitude= 0.24201167046116068 idx= (7, 7, 186, 119)
# selected elements: 658
# ------------
# cluster= 89
# amplitude= 0.24170016216855625 idx= (13, 0, 194, 74)
# selected elements: 1020
# ------------
# cluster= 90
# amplitude= 0.24151010885312987 idx= (2, 2, 12, 112)
# selected elements: 1714
# ------------
# cluster= 91
# amplitude= 0.24128850316487024 idx= (4, 5, 139, 78)
# selected elements: 1683
# ------------
# cluster= 92
# amplitude= 0.24077465804360293 idx= (6, 6, 216, 90)
# selected elements: 1577
# ------------
# cluster= 93
# amplitude= 0.23933807388094952 idx= (8, 5, 99, 86)
# selected elements: 1889
# ------------
# cluster= 94
# amplitude= 0.2385680826072571 idx= (8, 4, 210, 84)
# selected elements: 4666
# ------------
# cluster= 95
# amplitude= 0.23649330610804592 idx= (7, 1, 117, 80)
# selected elements: 2379
# ------------
# cluster= 96
# amplitude= 0.2359044552447399 idx= (13, 8, 31, 145)
# selected elements: 670
# ------------
# cluster= 97
# amplitude= 0.23496792355990612 idx= (6, 4, 125, 128)
# selected elements: 8910
# ------------
# cluster= 98
# amplitude= 0.2345516536830293 idx= (4, 16, 160, 76)
# selected elements: 422
# ------------
# cluster= 99
# amplitude= 0.23426999856958303 idx= (10, 5, 180, 131)
# selected elements: 5013
# ------------
# cluster= 100
# amplitude= 0.23404891731484045 idx= (1, 10, 162, 80)
# selected elements: 326
# ------------
# cluster= 101
# amplitude= 0.2321237454103024 idx= (10, 7, 144, 27)
# selected elements: 1283
# ------------
# cluster= 102
# amplitude= 0.23082648258916133 idx= (7, 11, 146, 27)
# selected elements: 897
# ------------
# cluster= 103
# amplitude= 0.2307165122430266 idx= (1, 9, 185, 76)
# selected elements: 649
# ------------
# cluster= 104
# amplitude= 0.23046931141014934 idx= (2, 12, 213, 101)
# selected elements: 1585
# ------------
# cluster= 105
# amplitude= 0.22953891382848754 idx= (8, 11, 86, 68)
# selected elements: 2146
# ------------
# cluster= 106
# amplitude= 0.22909961158862077 idx= (7, 7, 145, 27)
# selected elements: 560
# ------------
# cluster= 107
# amplitude= 0.22773545935062767 idx= (6, 1, 51, 126)
# selected elements: 507
# ------------
# cluster= 108
# amplitude= 0.22674607129369306 idx= (3, 4, 97, 140)
# selected elements: 3675
# ------------
# cluster= 109
# amplitude= 0.2266767348235522 idx= (7, 0, 90, 133)
# selected elements: 2200
# ------------
# cluster= 110
# amplitude= 0.22551407260043324 idx= (4, 11, 114, 110)
# selected elements: 287
# ------------
# cluster= 111
# amplitude= 0.22485009403982456 idx= (0, 11, 183, 76)
# selected elements: 198
# ------------
# cluster= 112
# amplitude= 0.22484708175903906 idx= (1, 9, 215, 63)
# selected elements: 585
# ------------
# cluster= 113
# amplitude= 0.22446573997911873 idx= (13, 17, 70, 112)
# selected elements: 1768
# ------------
# cluster= 114
# amplitude= 0.224308153644484 idx= (10, 1, 180, 134)
# selected elements: 15069
# ------------
# cluster= 115
# amplitude= 0.22382332218428355 idx= (12, 5, 130, 121)
# selected elements: 2008
# ------------
# cluster= 116
# amplitude= 0.22369114288507502 idx= (7, 1, 153, 74)
# selected elements: 2072
# ------------
# cluster= 117
# amplitude= 0.22320438986665125 idx= (15, 9, 306, 59)
# selected elements: 3004
# ------------
# cluster= 118
# amplitude= 0.22276239792931835 idx= (8, 13, 176, 137)
# selected elements: 731
# ------------
# cluster= 119
# amplitude= 0.22207295431167318 idx= (5, 15, 232, 95)
# selected elements: 1322
# ------------
# cluster= 120
# amplitude= 0.22204156115120044 idx= (11, 6, 97, 80)
# selected elements: 1301
# ------------
# cluster= 121
# amplitude= 0.22203824835092956 idx= (4, 10, 99, 142)
# selected elements: 622
# ------------
# cluster= 122
# amplitude= 0.22156987881472026 idx= (0, 3, 61, 94)
# selected elements: 1564
# ------------
# cluster= 123
# amplitude= 0.2212618333201625 idx= (9, 8, 65, 137)
# selected elements: 3370
# ------------
# cluster= 124
# amplitude= 0.22096479144524675 idx= (15, 0, 190, 131)
# selected elements: 1828
# ------------
# cluster= 125
# amplitude= 0.22066246015237648 idx= (14, 17, 310, 137)
# selected elements: 5768
# ------------
# cluster= 126
# amplitude= 0.2200030908802821 idx= (1, 11, 204, 112)
# selected elements: 293
# ------------
# cluster= 127
# amplitude= 0.2198651502976577 idx= (9, 4, 179, 135)
# selected elements: 1215
# ------------
# cluster= 128
# amplitude= 0.21929335732013924 idx= (4, 1, 22, 130)
# selected elements: 718
# ------------
# cluster= 129
# amplitude= 0.21836926956998934 idx= (9, 5, 271, 16)
# selected elements: 22537
# ------------
# cluster= 130
# amplitude= 0.21805945316416905 idx= (2, 1, 55, 50)
# selected elements: 768
# ------------
# cluster= 131
# amplitude= 0.21791158778132755 idx= (10, 7, 205, 72)
# selected elements: 468
# ------------
# cluster= 132
# amplitude= 0.21749807783940023 idx= (11, 16, 188, 135)
# selected elements: 884
# ------------
# cluster= 133
# amplitude= 0.21738074025597004 idx= (0, 8, 163, 94)
# selected elements: 817
# ------------
# cluster= 134
# amplitude= 0.2169210312634768 idx= (4, 0, 57, 57)
# selected elements: 171
# ------------
# cluster= 135
# amplitude= 0.21564535262272302 idx= (10, 4, 78, 138)
# selected elements: 1389
# ------------
# cluster= 136
# amplitude= 0.21480695376636652 idx= (2, 2, 23, 129)
# selected elements: 957
# ------------
# cluster= 137
# amplitude= 0.21468298208440564 idx= (12, 5, 182, 126)
# selected elements: 1552
# ------------
# cluster= 138
# amplitude= 0.213551839774513 idx= (6, 4, 234, 61)
# selected elements: 10782
# ------------
# cluster= 139
# amplitude= 0.21341197391648345 idx= (15, 9, 318, 7)
# selected elements: 8198
# ------------
# cluster= 140
# amplitude= 0.2118322324884434 idx= (1, 11, 70, 86)
# selected elements: 2077
# ------------
# cluster= 141
# amplitude= 0.21160344255086158 idx= (7, 11, 278, 139)
# selected elements: 2695
# ------------
# cluster= 142
# amplitude= 0.2112803658196391 idx= (3, 12, 114, 110)
# selected elements: 272
# ------------
# cluster= 143
# amplitude= 0.21091853403798566 idx= (4, 11, 169, 142)
# selected elements: 447
# ------------
# cluster= 144
# amplitude= 0.2104979146600231 idx= (2, 4, 149, 74)
# selected elements: 2831
# ------------
# cluster= 145
# amplitude= 0.20940648227531505 idx= (6, 3, 52, 74)
# selected elements: 2008
# ------------
# cluster= 146
# amplitude= 0.20874162888924036 idx= (3, 2, 65, 137)
# selected elements: 2636
# ------------
# cluster= 147
# amplitude= 0.20819392040815923 idx= (3, 12, 238, 103)
# selected elements: 1040
# ------------
# cluster= 148
# amplitude= 0.20769175908080192 idx= (4, 2, 115, 81)
# selected elements: 886
# ------------
# cluster= 149
# amplitude= 0.20744514447756163 idx= (9, 16, 145, 81)
# selected elements: 667
# ------------
# cluster= 150
# amplitude= 0.20729892911659212 idx= (5, 16, 97, 129)
# selected elements: 2555
# ------------
# cluster= 151
# amplitude= 0.20729673732664203 idx= (3, 8, 212, 65)
# selected elements: 1153
# ------------
# cluster= 152
# amplitude= 0.20723691113966017 idx= (14, 3, 100, 135)
# selected elements: 509
# ------------
# cluster= 153
# amplitude= 0.20697432862190163 idx= (13, 10, 293, 139)
# selected elements: 2726
# ------------
# cluster= 154
# amplitude= 0.20546758204518667 idx= (0, 13, 157, 61)
# selected elements: 185
# ------------
# cluster= 155
# amplitude= 0.20508649012562766 idx= (4, 9, 207, 42)
# selected elements: 1547
# ------------
# cluster= 156
# amplitude= 0.20505472512202746 idx= (6, 3, 167, 49)
# selected elements: 6324
# ------------
# cluster= 157
# amplitude= 0.20489401664307133 idx= (7, 14, 101, 52)
# selected elements: 1652
# ------------
# cluster= 158
# amplitude= 0.20470801615289883 idx= (4, 1, 92, 124)
# selected elements: 4681
# ------------
# cluster= 159
# amplitude= 0.2044106386433461 idx= (12, 3, 227, 65)
# selected elements: 3056
# ------------
# cluster= 160
# amplitude= 0.20409015901386135 idx= (7, 11, 289, 119)
# selected elements: 3115
# ------------
# cluster= 161
# amplitude= 0.20405773557080564 idx= (15, 14, 98, 28)
# selected elements: 3443
# ------------
# cluster= 162
# amplitude= 0.20378444442392224 idx= (1, 3, 200, 103)
# selected elements: 743
# ------------
# cluster= 163
# amplitude= 0.2025696866375832 idx= (14, 9, 300, 141)
# selected elements: 3974
# ------------
# cluster= 164
# amplitude= 0.20235931940240076 idx= (4, 8, 122, 78)
# selected elements: 835
# ------------
# cluster= 165
# amplitude= 0.20072934598876624 idx= (3, 8, 184, 59)
# selected elements: 393
# ------------
# cluster= 166
# amplitude= 0.20063140727868717 idx= (6, 5, 173, 49)
# selected elements: 1168
# ------------
# cluster= 167
# amplitude= 0.20052944856757063 idx= (8, 12, 133, 97)
# selected elements: 137
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 85.27it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=3600:4200  ext=3550:4250  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_03600_04200_xext_03550_04250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.36295745893201914 idx= (10, 11, 122, 50)
# selected elements: 106611
# ------------
# cluster= 1
# amplitude= 0.2587942949206798 idx= (11, 13, 94, 104)
# selected elements: 63824
# ------------
# cluster= 2
# amplitude= 0.2512568020151063 idx= (15, 10, 248, 33)
# selected elements: 30997
# ------------
# cluster= 3
# amplitude= 0.24700474071253775 idx= (14, 14, 154, 117)
# selected elements: 22860
# ------------
# cluster= 4
# amplitude= 0.23663224259883173 idx= (9, 10, 151, 120)
# selected elements: 26145
# ------------
# cluster= 5
# amplitude= 0.23497265687626837 idx= (15, 16, 116, 74)
# selected elements: 7287
# ------------
# cluster= 6
# amplitude= 0.23491065743813092 idx= (15, 14, 40, 64)
# selected elements: 16096
# ------------
# cluster= 7
# amplitude= 0.21934395871271822 idx= (14, 9, 193, 6)
# selected elements: 51661
# ------------
# cluster= 8
# amplitude= 0.21592070666663998 idx= (11, 11, 60, 14)
# selected elements: 13768
# ------------
# cluster= 9
# amplitude= 0.21406074909044467 idx= (9, 10, 108, 111)
# selected elements: 3169
# ------------
# cluster= 10
# amplitude= 0.20911530968028133 idx= (14, 13, 41, 60)
# selected elements: 2589
# ------------
# cluster= 11
# amplitude= 0.2071931892453781 idx= (13, 15, 120, 72)
# selected elements: 3056
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 60.05it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=4200:4800  ext=4150:4850  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_04200_04800_xext_04150_04850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.05it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=4800:5400  ext=4750:5450  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_04800_05400_xext_04750_05450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.68it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=5400:5451  ext=5350:5451  saved to outputs_decompose2d_slices_p2_cs600/offset_0000/xcore_05400_05451_xext_05350_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 88.32it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] Done. Outputs in /Users/anhphan/juwavelet_awe/examples/outputs_decompose2d_slices_p2_cs600/offset_0000
# [offset 300] core=300:900  ext=250:950  saved to outputs_decompose2d_slices_p2_cs600/offset_0300/xcore_00300_00900_xext_00250_00950
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.40835747961792257 idx= (8, 9, 198, 50)
# selected elements: 155300
# ------------
# cluster= 1
# amplitude= 0.40577853779423345 idx= (7, 8, 200, 51)
# selected elements: 2391
# ------------
# cluster= 2
# amplitude= 0.365874336271434 idx= (13, 12, 159, 52)
# selected elements: 57325
# ------------
# cluster= 3
# amplitude= 0.35993158931635366 idx= (14, 9, 81, 118)
# selected elements: 103775
# ------------
# cluster= 4
# amplitude= 0.3287651129529036 idx= (14, 9, 314, 9)
# selected elements: 51205
# ------------
# cluster= 5
# amplitude= 0.3228922740303705 idx= (11, 11, 223, 43)
# selected elements: 6990
# ------------
# cluster= 6
# amplitude= 0.3199388330861332 idx= (9, 11, 221, 42)
# selected elements: 10809
# ------------
# cluster= 7
# amplitude= 0.31221374493579435 idx= (12, 7, 131, 71)
# selected elements: 36030
# ------------
# cluster= 8
# amplitude= 0.30603962370670496 idx= (10, 9, 130, 78)
# selected elements: 7491
# ------------
# cluster= 9
# amplitude= 0.27598134647967487 idx= (5, 7, 149, 60)
# selected elements: 13435
# ------------
# cluster= 10
# amplitude= 0.26529880005454815 idx= (5, 10, 72, 116)
# selected elements: 1998
# ------------
# cluster= 11
# amplitude= 0.26461442882209163 idx= (2, 8, 207, 53)
# selected elements: 1806
# ------------
# cluster= 12
# amplitude= 0.24614194429792838 idx= (9, 10, 34, 36)
# selected elements: 20633
# ------------
# cluster= 13
# amplitude= 0.24038588525168983 idx= (7, 9, 134, 81)
# selected elements: 2312
# ------------
# cluster= 14
# amplitude= 0.239217641384865 idx= (13, 7, 311, 61)
# selected elements: 30595
# ------------
# cluster= 15
# amplitude= 0.23695563967382638 idx= (12, 9, 259, 6)
# selected elements: 6475
# ------------
# cluster= 16
# amplitude= 0.2185812353569346 idx= (5, 9, 278, 66)
# selected elements: 4892
# ------------
# cluster= 17
# amplitude= 0.21857075228467435 idx= (13, 10, 220, 36)
# selected elements: 3135
# ------------
# cluster= 18
# amplitude= 0.21777451791642277 idx= (11, 7, 227, 55)
# selected elements: 12567
# ------------
# cluster= 19
# amplitude= 0.21768983160653005 idx= (5, 10, 74, 29)
# selected elements: 6753
# ------------
# cluster= 20
# amplitude= 0.21554948357507805 idx= (15, 10, 262, 8)
# selected elements: 1492
# ------------
# cluster= 21
# amplitude= 0.2145082609997511 idx= (15, 7, 118, 125)
# selected elements: 5021
# ------------
# cluster= 22
# amplitude= 0.2131412532929919 idx= (10, 12, 162, 60)
# selected elements: 1003
# ------------
# cluster= 23
# amplitude= 0.20894104812473852 idx= (9, 11, 89, 57)
# selected elements: 7971
# ------------
# cluster= 24
# amplitude= 0.20817123768946325 idx= (14, 1, 341, 57)
# selected elements: 15750
# ------------
# cluster= 25
# amplitude= 0.20740962320057638 idx= (14, 12, 29, 120)
# selected elements: 7493
# ------------
# cluster= 26
# amplitude= 0.20198463376262865 idx= (9, 10, 16, 69)
# selected elements: 11689
# ------------
# cluster= 27
# amplitude= 0.20173159886380349 idx= (15, 11, 28, 123)
# selected elements: 2826
# ------------
# cluster= 28
# amplitude= 0.20090105459851476 idx= (3, 10, 256, 57)
# selected elements: 2116
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 84.38it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=900:1500  ext=850:1550  saved to outputs_decompose2d_slices_p2_cs600/offset_0300/xcore_00900_01500_xext_00850_01550
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.4803051729364532 idx= (6, 8, 91, 25)
# selected elements: 53556
# ------------
# cluster= 1
# amplitude= 0.4727788379508776 idx= (5, 9, 93, 24)
# selected elements: 5453
# ------------
# cluster= 2
# amplitude= 0.365816894923951 idx= (15, 9, 96, 27)
# selected elements: 62101
# ------------
# cluster= 3
# amplitude= 0.3397957262930074 idx= (10, 9, 50, 6)
# selected elements: 19762
# ------------
# cluster= 4
# amplitude= 0.26975059850170374 idx= (9, 10, 131, 10)
# selected elements: 6241
# ------------
# cluster= 5
# amplitude= 0.24013569654619574 idx= (12, 6, 15, 58)
# selected elements: 34352
# ------------
# cluster= 6
# amplitude= 0.2382660524617958 idx= (9, 7, 307, 37)
# selected elements: 41561
# ------------
# cluster= 7
# amplitude= 0.2325152528969672 idx= (11, 8, 151, 32)
# selected elements: 12729
# ------------
# cluster= 8
# amplitude= 0.20829767950028685 idx= (15, 6, 307, 27)
# selected elements: 7268
# ------------
# cluster= 9
# amplitude= 0.20824152845512853 idx= (7, 9, 130, 11)
# selected elements: 1480
# ------------
# cluster= 10
# amplitude= 0.20804451641134836 idx= (6, 5, 302, 24)
# selected elements: 2962
# ------------
# cluster= 11
# amplitude= 0.2041106796920941 idx= (10, 14, 289, 110)
# selected elements: 11214
# ------------
# cluster= 12
# amplitude= 0.20282113265609905 idx= (15, 0, 7, 35)
# selected elements: 6584
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 77.97it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=1500:2100  ext=1450:2150  saved to outputs_decompose2d_slices_p2_cs600/offset_0300/xcore_01500_02100_xext_01450_02150
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.28177092110348134 idx= (6, 10, 175, 134)
# selected elements: 13817
# ------------
# cluster= 1
# amplitude= 0.2350174992928976 idx= (10, 7, 203, 135)
# selected elements: 28505
# ------------
# cluster= 2
# amplitude= 0.22799876517220719 idx= (11, 13, 43, 94)
# selected elements: 20217
# ------------
# cluster= 3
# amplitude= 0.2212160266402606 idx= (12, 8, 206, 138)
# selected elements: 3748
# ------------
# cluster= 4
# amplitude= 0.2132669215552784 idx= (13, 9, 24, 7)
# selected elements: 19954
# ------------
# cluster= 5
# amplitude= 0.21285511451754327 idx= (7, 4, 179, 126)
# selected elements: 10310
# ------------
# cluster= 6
# amplitude= 0.20651258740157108 idx= (15, 9, 188, 9)
# selected elements: 15330
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 83.11it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=2100:2700  ext=2050:2750  saved to outputs_decompose2d_slices_p2_cs600/offset_0300/xcore_02100_02700_xext_02050_02750
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.31646178834308264 idx= (15, 8, 144, 125)
# selected elements: 64015
# ------------
# cluster= 1
# amplitude= 0.2747996703753803 idx= (14, 1, 291, 124)
# selected elements: 42451
# ------------
# cluster= 2
# amplitude= 0.2588774346028878 idx= (10, 1, 259, 105)
# selected elements: 15971
# ------------
# cluster= 3
# amplitude= 0.249253540603076 idx= (11, 11, 285, 113)
# selected elements: 30501
# ------------
# cluster= 4
# amplitude= 0.229237974075978 idx= (8, 9, 224, 74)
# selected elements: 38913
# ------------
# cluster= 5
# amplitude= 0.22321485598724045 idx= (15, 8, 270, 62)
# selected elements: 18564
# ------------
# cluster= 6
# amplitude= 0.20655440402456507 idx= (15, 4, 271, 83)
# selected elements: 4602
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 83.75it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=2700:3300  ext=2650:3350  saved to outputs_decompose2d_slices_p2_cs600/offset_0300/xcore_02700_03300_xext_02650_03350
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# ...
# selected elements: 2804
# ------------
# cluster= 137
# amplitude= 0.2040577449950209 idx= (15, 14, 248, 28)
# selected elements: 3442
# ------------
# cluster= 138
# amplitude= 0.2032945163157223 idx= (13, 9, 175, 6)
# selected elements: 8432
# ------------
# cluster= 139
# amplitude= 0.20235932040603635 idx= (4, 8, 272, 78)
# selected elements: 835
# ------------
# cluster= 140
# amplitude= 0.2006024450886884 idx= (6, 5, 323, 49)
# selected elements: 1023
# ------------
# cluster= 141
# amplitude= 0.20054184144583118 idx= (15, 11, 55, 60)
# selected elements: 9266
# ------------
# cluster= 142
# amplitude= 0.20052945475641892 idx= (8, 12, 283, 97)
# selected elements: 137
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.26it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=3300:3900  ext=3250:3950  saved to outputs_decompose2d_slices_p2_cs600/offset_0300/xcore_03300_03900_xext_03250_03950
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.3214639180094934 idx= (9, 13, 42, 94)
# selected elements: 1023087
# ------------
# cluster= 1
# amplitude= 0.685964642130868 idx= (14, 11, 51, 118)
# selected elements: 12418
# ------------
# cluster= 2
# amplitude= 0.6739164248790829 idx= (2, 9, 23, 38)
# selected elements: 10153
# ------------
# cluster= 3
# amplitude= 0.6321003896657056 idx= (2, 8, 55, 112)
# selected elements: 6981
# ------------
# cluster= 4
# amplitude= 0.5825633760226182 idx= (2, 12, 9, 64)
# selected elements: 3472
# ------------
# cluster= 5
# amplitude= 0.5748529016982926 idx= (15, 15, 58, 126)
# selected elements: 19702
# ------------
# cluster= 6
# amplitude= 0.5426812221037468 idx= (15, 10, 48, 122)
# selected elements: 14953
# ------------
# cluster= 7
# amplitude= 0.5314884037040707 idx= (8, 10, 19, 142)
# selected elements: 1257
# ------------
# cluster= 8
# amplitude= 0.4837358114610497 idx= (10, 10, 14, 73)
# selected elements: 862
# ------------
# cluster= 9
# amplitude= 0.46924091841291193 idx= (14, 9, 47, 121)
# selected elements: 14114
# ------------
# cluster= 10
# amplitude= 0.39868280096524594 idx= (6, 10, 19, 142)
# selected elements: 5862
# ------------
# cluster= 11
# amplitude= 0.3958034355191984 idx= (14, 7, 58, 81)
# selected elements: 52253
# ------------
# cluster= 12
# amplitude= 0.3915278245426776 idx= (13, 9, 15, 146)
# selected elements: 650
# ------------
# cluster= 13
# amplitude= 0.3846775415042877 idx= (14, 16, 53, 133)
# selected elements: 7446
# ------------
# cluster= 14
# amplitude= 0.3723925737741622 idx= (7, 7, 58, 114)
# selected elements: 119286
# ------------
# cluster= 15
# amplitude= 0.3672015731196952 idx= (11, 8, 17, 26)
# selected elements: 33497
# ------------
# cluster= 16
# amplitude= 0.36295738391101584 idx= (10, 11, 272, 50)
# selected elements: 106070
# ------------
# cluster= 17
# amplitude= 0.35886387089807725 idx= (12, 5, 42, 30)
# selected elements: 5903
# ------------
# cluster= 18
# amplitude= 0.3516297956609152 idx= (11, 0, 9, 62)
# selected elements: 77489
# ------------
# cluster= 19
# amplitude= 0.3387178026481602 idx= (9, 16, 10, 99)
# selected elements: 8752
# ------------
# cluster= 20
# amplitude= 0.31864795259313416 idx= (3, 8, 95, 63)
# selected elements: 20206
# ------------
# cluster= 21
# amplitude= 0.31583466048024106 idx= (15, 7, 12, 35)
# selected elements: 1162
# ------------
# cluster= 22
# amplitude= 0.29810487200443986 idx= (15, 13, 149, 118)
# selected elements: 25662
# ------------
# cluster= 23
# amplitude= 0.29536278394193294 idx= (15, 1, 6, 50)
# selected elements: 29744
# ------------
# cluster= 24
# amplitude= 0.2943816681435631 idx= (1, 12, 33, 75)
# selected elements: 925
# ------------
# cluster= 25
# amplitude= 0.29356007256287864 idx= (7, 15, 16, 81)
# selected elements: 2591
# ------------
# cluster= 26
# amplitude= 0.29325291915394985 idx= (6, 8, 14, 81)
# selected elements: 10357
# ------------
# cluster= 27
# amplitude= 0.287398609753827 idx= (15, 5, 42, 25)
# selected elements: 3919
# ------------
# cluster= 28
# amplitude= 0.28725350931948157 idx= (15, 10, 12, 147)
# selected elements: 534
# ------------
# cluster= 29
# amplitude= 0.2867022051592885 idx= (15, 9, 74, 7)
# selected elements: 1363
# ------------
# cluster= 30
# amplitude= 0.2846074652289457 idx= (3, 14, 7, 65)
# selected elements: 1072
# ------------
# cluster= 31
# amplitude= 0.2798515569067831 idx= (15, 15, 10, 123)
# selected elements: 1816
# ------------
# cluster= 32
# amplitude= 0.27662679659485323 idx= (10, 11, 125, 133)
# selected elements: 1570
# ------------
# cluster= 33
# amplitude= 0.2748465316072953 idx= (4, 5, 39, 115)
# selected elements: 3123
# ------------
# cluster= 34
# amplitude= 0.2713195097980908 idx= (1, 7, 29, 31)
# selected elements: 2238
# ------------
# cluster= 35
# amplitude= 0.26224408057379767 idx= (4, 6, 138, 34)
# selected elements: 9321
# ------------
# cluster= 36
# amplitude= 0.26132567305287335 idx= (14, 2, 47, 103)
# selected elements: 7875
# ------------
# cluster= 37
# amplitude= 0.2604147486113973 idx= (2, 3, 53, 86)
# selected elements: 12212
# ------------
# cluster= 38
# amplitude= 0.2587942921671606 idx= (11, 13, 244, 104)
# selected elements: 53800
# ------------
# cluster= 39
# amplitude= 0.25859235613428355 idx= (3, 8, 31, 77)
# selected elements: 2052
# ------------
# cluster= 40
# amplitude= 0.25665539825392203 idx= (5, 14, 6, 66)
# selected elements: 204
# ------------
# cluster= 41
# amplitude= 0.2563452523969603 idx= (3, 15, 45, 105)
# selected elements: 1515
# ------------
# cluster= 42
# amplitude= 0.2557526410046559 idx= (14, 0, 5, 19)
# selected elements: 5025
# ------------
# cluster= 43
# amplitude= 0.2555459377378855 idx= (9, 0, 59, 103)
# selected elements: 4838
# ------------
# cluster= 44
# amplitude= 0.2512050888614735 idx= (2, 9, 12, 82)
# selected elements: 1597
# ------------
# cluster= 45
# amplitude= 0.2497305114019833 idx= (14, 8, 106, 56)
# selected elements: 2669
# ------------
# cluster= 46
# amplitude= 0.2496873122497873 idx= (2, 14, 16, 77)
# selected elements: 568
# ------------
# cluster= 47
# amplitude= 0.24719149888753056 idx= (14, 14, 304, 117)
# selected elements: 22962
# ------------
# cluster= 48
# amplitude= 0.2470777746459063 idx= (13, 17, 341, 11)
# selected elements: 13491
# ------------
# cluster= 49
# amplitude= 0.24281284208982729 idx= (4, 7, 77, 104)
# selected elements: 1852
# ------------
# cluster= 50
# amplitude= 0.2426207820471395 idx= (13, 0, 159, 136)
# selected elements: 18765
# ------------
# cluster= 51
# amplitude= 0.24249896586415892 idx= (13, 0, 44, 74)
# selected elements: 1038
# ------------
# cluster= 52
# amplitude= 0.24204054323848628 idx= (7, 7, 36, 119)
# selected elements: 659
# ------------
# cluster= 53
# amplitude= 0.2413604235188315 idx= (2, 9, 11, 59)
# selected elements: 449
# ------------
# cluster= 54
# amplitude= 0.2407746560097556 idx= (6, 6, 66, 90)
# selected elements: 1577
# ------------
# cluster= 55
# amplitude= 0.24003830479671823 idx= (15, 4, 36, 106)
# selected elements: 4884
# ------------
# cluster= 56
# amplitude= 0.24002283169240585 idx= (14, 0, 341, 10)
# selected elements: 15501
# ------------
# cluster= 57
# amplitude= 0.23856808421029718 idx= (8, 4, 60, 84)
# selected elements: 8233
# ------------
# cluster= 58
# amplitude= 0.23656192003916357 idx= (9, 10, 301, 120)
# selected elements: 24150
# ------------
# cluster= 59
# amplitude= 0.23497263882991298 idx= (15, 16, 266, 74)
# selected elements: 7286
# ------------
# cluster= 60
# amplitude= 0.23438396480519239 idx= (15, 14, 190, 64)
# selected elements: 14872
# ------------
# cluster= 61
# amplitude= 0.23181358832472118 idx= (4, 3, 55, 85)
# selected elements: 1147
# ------------
# cluster= 62
# amplitude= 0.231783639244387 idx= (1, 10, 12, 80)
# selected elements: 418
# ------------
# cluster= 63
# amplitude= 0.23137127567900553 idx= (15, 17, 5, 20)
# selected elements: 7788
# ------------
# cluster= 64
# amplitude= 0.23046931528996467 idx= (2, 12, 63, 101)
# selected elements: 1585
# ------------
# cluster= 65
# amplitude= 0.22485009486827073 idx= (0, 11, 33, 76)
# selected elements: 198
# ------------
# cluster= 66
# amplitude= 0.2248470829746294 idx= (1, 9, 65, 63)
# selected elements: 585
# ------------
# cluster= 67
# amplitude= 0.22399347643733855 idx= (15, 9, 157, 59)
# selected elements: 3144
# ------------
# cluster= 68
# amplitude= 0.22316321723638088 idx= (8, 13, 26, 137)
# selected elements: 725
# ------------
# cluster= 69
# amplitude= 0.22207296042929872 idx= (5, 15, 82, 95)
# selected elements: 1322
# ------------
# cluster= 70
# amplitude= 0.2202274400900907 idx= (9, 1, 29, 135)
# selected elements: 10852
# ------------
# cluster= 71
# amplitude= 0.22020866471980302 idx= (9, 4, 29, 135)
# selected elements: 2282
# ------------
# cluster= 72
# amplitude= 0.2200155717760755 idx= (14, 17, 160, 137)
# selected elements: 5726
# ------------
# cluster= 73
# amplitude= 0.22000309855305783 idx= (1, 11, 54, 112)
# selected elements: 293
# ------------
# cluster= 74
# amplitude= 0.21931360390744156 idx= (15, 7, 80, 15)
# selected elements: 4179
# ------------
# cluster= 75
# amplitude= 0.2183628031709529 idx= (9, 5, 121, 16)
# selected elements: 21031
# ------------
# cluster= 76
# amplitude= 0.21791161883007124 idx= (10, 7, 55, 72)
# selected elements: 468
# ------------
# cluster= 77
# amplitude= 0.21644037023163987 idx= (4, 16, 12, 75)
# selected elements: 939
# ------------
# cluster= 78
# amplitude= 0.21526991074848614 idx= (6, 2, 11, 49)
# selected elements: 6430
# ------------
# cluster= 79
# amplitude= 0.21482841745484973 idx= (7, 6, 21, 52)
# selected elements: 995
# ------------
# cluster= 80
# amplitude= 0.21405852567461167 idx= (9, 10, 258, 111)
# selected elements: 3163
# ------------
# cluster= 81
# amplitude= 0.21355184370778066 idx= (6, 4, 84, 61)
# selected elements: 10782
# ------------
# cluster= 82
# amplitude= 0.21312984088789536 idx= (4, 11, 19, 142)
# selected elements: 453
# ------------
# cluster= 83
# amplitude= 0.21312877026048585 idx= (2, 5, 32, 35)
# selected elements: 2479
# ------------
# cluster= 84
# amplitude= 0.2128531724608316 idx= (11, 0, 31, 132)
# selected elements: 5375
# ------------
# cluster= 85
# amplitude= 0.21283172551667714 idx= (14, 7, 13, 143)
# selected elements: 2108
# ------------
# cluster= 86
# amplitude= 0.2115862622501463 idx= (11, 11, 210, 14)
# selected elements: 10583
# ------------
# cluster= 87
# amplitude= 0.21111484122683394 idx= (7, 11, 128, 139)
# selected elements: 2690
# ------------
# cluster= 88
# amplitude= 0.20991818833388917 idx= (0, 10, 11, 68)
# selected elements: 211
# ------------
# cluster= 89
# amplitude= 0.20923970374212905 idx= (14, 13, 190, 60)
# selected elements: 2622
# ------------
# cluster= 90
# amplitude= 0.20819392495354005 idx= (3, 12, 88, 103)
# selected elements: 1040
# ------------
# cluster= 91
# amplitude= 0.20729673610997512 idx= (3, 8, 62, 65)
# selected elements: 1153
# ------------
# cluster= 92
# amplitude= 0.20719319603055358 idx= (13, 15, 270, 72)
# selected elements: 3058
# ------------
# cluster= 93
# amplitude= 0.205086490629138 idx= (4, 9, 57, 42)
# selected elements: 1547
# ------------
# cluster= 94
# amplitude= 0.2040862557419484 idx= (7, 11, 139, 119)
# selected elements: 3101
# ------------
# cluster= 95
# amplitude= 0.20378444151270933 idx= (1, 3, 50, 103)
# selected elements: 743
# ------------
# cluster= 96
# amplitude= 0.20160857337280016 idx= (13, 10, 143, 139)
# selected elements: 2618
# ------------
# cluster= 97
# amplitude= 0.20072934672583947 idx= (3, 8, 34, 59)
# selected elements: 393
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 77.42it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=3900:4500  ext=3850:4550  saved to outputs_decompose2d_slices_p2_cs600/offset_0300/xcore_03900_04500_xext_03850_04550
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.25282848418721937 idx= (15, 10, 98, 32)
# selected elements: 28004
# ------------
# cluster= 1
# amplitude= 0.22719427259864322 idx= (14, 9, 43, 6)
# selected elements: 60923
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 83.49it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=4500:5100  ext=4450:5150  saved to outputs_decompose2d_slices_p2_cs600/offset_0300/xcore_04500_05100_xext_04450_05150
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 86.29it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=5100:5451  ext=5050:5451  saved to outputs_decompose2d_slices_p2_cs600/offset_0300/xcore_05100_05451_xext_05050_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.07it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] Done. Outputs in /Users/anhphan/juwavelet_awe/examples/outputs_decompose2d_slices_p2_cs600/offset_0300
# Saved difference plot: /Users/anhphan/juwavelet_awe/examples/outputs_decompose2d_slices_p2_cs600/FINAL_DIFF_rec_all_offset0_minus_offset300.png

# %% [markdown]
# ## Global Clustering

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Optional, Dict, Any, List

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

# --------------------------
# User params
# --------------------------
FILE_PATH = "awe_l5c_q20_2024165T2120_03175_v01.nc"
FRAME_IDX = 0

# Loop settings on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)

# Extend each slice by this many UNBINNED pixels on each side (overlap = 2*SLICE_PAD)
SLICE_PAD = 50

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 16
JT = 18
ASPECT = 1

# Pixel spacing (km/pixel) for plotting and CWT (wavelengths will be in km)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# Clustering thresholds
MIN_AMP = 0.25
THR = 0.1

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices")
SAVE_DPI = 200

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Helpers
# --------------------------
def read_radiance_frame(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        rad = nc.variables["Radiance"][:]  # (t, y, x)
    if rad.ndim != 3:
        raise ValueError(f"Radiance expected 3D (t,y,x); got {rad.shape}")
    if not (0 <= frame_idx < rad.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{rad.shape[0]-1}")
    return np.asarray(rad[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def load_radiance_window_from_array(
    Z: np.ndarray, xsl: slice, ysl: slice
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    win = np.asarray(Z[ysl, xsl], dtype=float)
    ny, nx = win.shape
    x = np.arange(nx, dtype=float)
    y = np.arange(ny, dtype=float)
    return x, y, win


def pad_window_to_width(win: np.ndarray, target_width: int) -> np.ndarray:
    ny, nx = win.shape
    if nx >= target_width:
        return win
    pad = target_width - nx
    med = float(np.nanmedian(win)) if np.isfinite(np.nanmedian(win)) else 0.0
    right = np.full((ny, pad), med, dtype=float)
    return np.concatenate([win, right], axis=1)


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    u = np.cos(theta_xy)
    v = np.sin(theta_xy)
    return u, v


def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("Radiance (arb)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    stacked = np.concatenate([orig_c.ravel(), bg_c.ravel(), rem_c.ravel(), rem_tapered_c.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [1, 99])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    fig, axs = plt.subplots(2, 2, figsize=(12, 10), constrained_layout=True)
    axes = axs.flatten()

    panels = [
        (orig_c, "Original (median-sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    im0 = None
    for ax, (Z, title) in zip(axes, panels):
        im0 = ax.pcolormesh(
            x1d_km, y1d_km, Z, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    cbar = fig.colorbar(im0, ax=axs, orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("Radiance (arb)")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2

    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_low, bg_high = np.nanpercentile(bg_xy, [2, 98])
    bg_vmax = max(abs(bg_low), abs(bg_high))
    if not np.isfinite(bg_vmax) or bg_vmax == 0:
        bg_vmax = 1.0
    bg_vmin = -bg_vmax

    cl_low, cl_high = np.nanpercentile(rec_xy, [2, 98])
    cl_vmax = max(abs(cl_low), abs(cl_high))
    if not np.isfinite(cl_vmax) or cl_vmax == 0:
        cl_vmax = 1.0
    cl_vmin = -cl_vmax

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if not np.isfinite(lam_vmin) or not np.isfinite(lam_vmax) or lam_vmin == lam_vmax:
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n" + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        ARROW_LEN_KM = 40.0
        u = u * ARROW_LEN_KM
        v = v * ARROW_LEN_KM

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)

# --------------------------
# Main pipeline for one slice
# --------------------------
GLOBAL_CLUSTERING = True  # stitch 4D decomposition across slices, then cluster once per offset


def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
) -> Dict[str, Any]:
    """
    Runs preprocessing and CWT on an extended slice, but returns CORE tiles for stitching.

    Returns per slice:
      decomp_core: stitched 4D decomposition core block (ns, nt, core_w_binned, ny)
      remaining_core_xy: stitched remaining core block (ny, core_w_binned)
      plus dx_km, dy_km and a cwt template (metadata) for global clustering
    """
    outdir.mkdir(parents=True, exist_ok=True)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        dx_km = DX_KM_BASE * int(BIN_FACTOR)
        dy_km = DY_KM_BASE * int(BIN_FACTOR)
        f = int(BIN_FACTOR)
    else:
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE
        f = 1

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f

    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core_2d(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    def crop_pad_core_4d(dec4: np.ndarray) -> np.ndarray:
        ns, nt, nxA, nyA = dec4.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = dec4[:, :, left:right, :]
        need = core_w_binned - core.shape[2]
        if need > 0:
            pad = np.zeros((ns, nt, need, nyA), dtype=dec4.dtype)
            core = np.concatenate([core, pad], axis=2)
        elif need < 0:
            core = core[:, :, :core_w_binned, :]
        return core

    # Window on unbinned flattened field
    _, _, raw_win = load_radiance_window_from_array(rad2d_flat, x_slice, Y_SLICE)

    # Only pad if we are shorter than X_CHUNK (helps last slice)
    raw_win = pad_window_to_width(raw_win, X_CHUNK)

    # Optional binning
    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"Radiance (window, flattened){bin_tag}",
        outdir / "00_radiance_window.png",
    )

    # Background separation
    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_4panel.png",
    )

    # Preprocess for CWT
    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    # Keep a pristine copy of this slice decomposition
    orig_decomp = np.asarray(cwt["decomposition"]).copy()

    # Optional: overview plots per slice (still useful to sanity check)
    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N
    )
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    # Return CORE blocks for stitching
    remaining_core_xy = crop_pad_core_2d(proc)  # (ny, core_w_binned)
    decomp_core = crop_pad_core_4d(orig_decomp)  # (ns, nt, core_w_binned, ny)

    return {
        "has_cwt": True,
        "x_start_unbinned": core_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "remaining_core_xy": remaining_core_xy,
        "decomp_core": decomp_core,
        "cwt_template": cwt,  # metadata template
    }


# --------------------------
# Global plotting helpers (stitched)
# --------------------------
def plot_stitched_remaining_vs_rec_all(
    remaining_stitched: np.ndarray,
    rec_all_stitched: np.ndarray,
    x0_km: float,
    dx_km: float,
    dy_km: float,
    outpath: Path,
    title_tag: str,
) -> None:
    ny, nx_tot = remaining_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    stacked = np.concatenate([remaining_stitched.ravel(), rec_all_stitched.ravel()])
    p_low, p_high = np.nanpercentile(stacked, [2, 98])
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    figR, (axT, axB) = plt.subplots(
        2, 1, figsize=(18, 6), constrained_layout=True, sharex=True, sharey=True
    )

    imT = axT.pcolormesh(
        x1d_km, y1d_km, remaining_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axT.set_title(f"STITCHED {title_tag}: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(
        x1d_km, y1d_km, rec_all_stitched,
        shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
    )
    axB.set_title(f"STITCHED {title_tag}: All clusters combined (reconstruction)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    xmin_km = 600
    xmax_km = 10000
    axT.set_xlim(xmin_km, xmax_km)

    cbar = figR.colorbar(imT, ax=[axT, axB], orientation="vertical", fraction=0.01, pad=0.01)
    cbar.set_label("kRayleigh (Relative)")

    save_fig(figR, outpath)


def save_offset_difference(
    rec0: np.ndarray,
    x0_km_0: float,
    rec1: np.ndarray,
    x0_km_1: float,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    """
    Subtract stitched reconstructions from two slicing offsets.
    Align in km space by trimming to the overlapping x range.
    """
    if rec0.shape[0] != rec1.shape[0]:
        raise ValueError(f"Different ny: {rec0.shape[0]} vs {rec1.shape[0]}")

    nx0 = rec0.shape[1]
    nx1 = rec1.shape[1]
    x0_min = x0_km_0
    x0_max = x0_km_0 + (nx0 - 1) * dx_km
    x1_min = x0_km_1
    x1_max = x0_km_1 + (nx1 - 1) * dx_km

    x_min = max(x0_min, x1_min)
    x_max = min(x0_max, x1_max)
    if x_max <= x_min:
        raise ValueError("No overlapping x range between the two stitched reconstructions")

    j0_start = int(round((x_min - x0_km_0) / dx_km))
    j0_end = int(round((x_max - x0_km_0) / dx_km)) + 1

    j1_start = int(round((x_min - x0_km_1) / dx_km))
    j1_end = int(round((x_max - x0_km_1) / dx_km)) + 1

    rec0_sub = rec0[:, j0_start:j0_end]
    rec1_sub = rec1[:, j1_start:j1_end]

    nx = min(rec0_sub.shape[1], rec1_sub.shape[1])
    rec0_sub = rec0_sub[:, :nx]
    rec1_sub = rec1_sub[:, :nx]

    diff = rec0_sub - rec1_sub

    ny = diff.shape[0]
    x1d_km = x_min + np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    if np.any(np.isfinite(diff)):
        p_low, p_high = np.nanpercentile(diff[np.isfinite(diff)], [2, 98])
    else:
        p_low, p_high = -1, 1
    vmax = max(abs(p_low), abs(p_high))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    vmin = -vmax

    fig, ax = plt.subplots(figsize=(18, 4), constrained_layout=True)
    im = ax.pcolormesh(x1d_km, y1d_km, diff, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    ax.set_title("Difference of stitched reconstructions: offset 0 minus offset 300 (overlap only)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_aspect("equal", adjustable="box")

    cbar = fig.colorbar(im, ax=ax, fraction=0.02, pad=0.01)
    cbar.set_label("kRayleigh (Relative)")

    xmin_km = 600
    xmax_km = 10000
    ax.set_xlim(xmin_km, xmax_km)

    save_fig(fig, outpath)


# --------------------------
# Run all slices (global stitch 4D, then cluster)
# --------------------------
def run_all_slices() -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_radiance_frame(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)

    nx_total_unbinned = rad2d_flat.shape[1]
    f = int(BIN_FACTOR) if (APPLY_BINNING and int(BIN_FACTOR) > 1) else 1
    nx_total_binned = (nx_total_unbinned // f)

    stitched_recs: Dict[int, Tuple[np.ndarray, float, float, float]] = {}

    for x_offset in [0, 300]:
        if x_offset >= nx_total_unbinned:
            print(f"Skip offset {x_offset}: nx_total={nx_total_unbinned}")
            continue

        outroot = OUTPUT_ROOT / f"offset_{x_offset:04d}"
        outroot.mkdir(parents=True, exist_ok=True)

        core_starts = list(range(x_offset, nx_total_unbinned, X_CHUNK))

        stitched_decomp = None         # (ns, nt, nx_total_binned, ny)
        stitched_remaining = None      # (ny, nx_total_binned)
        cwt_template_global = None
        dx_km = None
        dy_km = None

        for core_start in core_starts:
            core_end = min(core_start + X_CHUNK, nx_total_unbinned)

            ext_start = max(0, core_start - SLICE_PAD)
            ext_end = min(nx_total_unbinned, core_end + SLICE_PAD)
            x_slice = slice(ext_start, ext_end)

            outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
            print(f"[offset {x_offset}] core={core_start}:{core_end} ext={ext_start}:{ext_end} saved to {outdir}")

            res = run_pipeline_for_slice(
                rad2d_flat=rad2d_flat,
                x_slice=x_slice,
                outdir=outdir,
                x_start_unbinned=ext_start,
                core_start_unbinned=core_start,
                core_end_unbinned=core_end,
            )

            decomp_core = res["decomp_core"]              # (ns, nt, core_w_binned, ny)
            remaining_core_xy = res["remaining_core_xy"]  # (ny, core_w_binned)

            if cwt_template_global is None:
                cwt_template_global = res["cwt_template"]
                dx_km = float(res["dx_km"])
                dy_km = float(res["dy_km"])

                ns, nt, _, ny = decomp_core.shape
                stitched_decomp = np.zeros((ns, nt, nx_total_binned, ny), dtype=decomp_core.dtype)
                stitched_remaining = np.full((ny, nx_total_binned), np.nan, dtype=float)

            core_start_b = (core_start // f)
            core_end_b = core_start_b + decomp_core.shape[2]

            stitched_decomp[:, :, core_start_b:core_end_b, :] = decomp_core
            stitched_remaining[:, core_start_b:core_end_b] = remaining_core_xy

        if stitched_decomp is None:
            print(f"[offset {x_offset}] Nothing to stitch, skipping")
            continue

        # Build global cwt dict using template metadata and stitched decomposition
        cwtG = dict(cwt_template_global)
        cwtG["decomposition"] = stitched_decomp

        # Cluster once on the stitched 4D wavelet space
        ampsG, idxsG, iwaveG = utils.identify_cluster2d(cwtG, min_amp=MIN_AMP, thr=THR)

        cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwtG, iwaveG)
        if cluster_ids.size == 0:
            (outroot / "NO_CLUSTERS_GLOBAL.txt").write_text(
                "No clusters found on stitched decomposition. Try lowering MIN_AMP or THR.\n"
            )
            print(f"[offset {x_offset}] No global clusters found")
            continue

        order_power = np.argsort(P_abs)[::-1]
        cluster_ids_sorted = cluster_ids[order_power]
        P_abs_sorted = P_abs[order_power]
        P_pct_sorted = P_pct[order_power]

        lines = []
        lines.append("Global cluster power ranking (stitched 4D, clustered once)\n")
        lines.append("rank  kcl      P_abs           P_pct\n")
        for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
            lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
        (outroot / "GLOBAL_cluster_power_ranking.txt").write_text("".join(lines))

        # Reconstruct all clusters combined for the whole swath
        orig_decompG = stitched_decomp.copy()
        cwtG["decomposition"] = orig_decompG
        cwtG["decomposition"][iwaveG < 0] = 0
        rec_all = transform.reconstruct2d(cwtG)          # (nx_binned, ny)
        rec_all_xy = rec_all.T - np.median(rec_all)

        # Stitched 09 style plot
        x0_km = float(x_offset) * DX_KM_BASE
        plot_stitched_remaining_vs_rec_all(
            remaining_stitched=stitched_remaining,
            rec_all_stitched=rec_all_xy,
            x0_km=x0_km,
            dx_km=float(dx_km),
            dy_km=float(dy_km),
            outpath=outroot / f"FINAL_09_STITCHED_GLOBALCLUSTER_offset_{x_offset:04d}.png",
            title_tag=f"(global cluster) offset {x_offset:04d}",
        )

        stitched_recs[x_offset] = (rec_all_xy, x0_km, float(dx_km), float(dy_km))
        print(f"[offset {x_offset}] Done. Outputs in {outroot.resolve()}")

    # Compare offsets if both exist
    if 0 in stitched_recs and 300 in stitched_recs:
        rec0, x0_km_0, dx_km_0, dy_km_0 = stitched_recs[0]
        rec1, x0_km_1, dx_km_1, dy_km_1 = stitched_recs[300]

        if abs(dx_km_0 - dx_km_1) > 1e-9 or abs(dy_km_0 - dy_km_1) > 1e-9:
            raise ValueError("dx_km or dy_km differ between offsets. Check binning settings")

        save_offset_difference(
            rec0=rec0,
            x0_km_0=x0_km_0,
            rec1=rec1,
            x0_km_1=x0_km_1,
            dx_km=dx_km_0,
            dy_km=dy_km_0,
            outpath=OUTPUT_ROOT / "FINAL_DIFF_rec_all_offset0_minus_offset300_GLOBALCLUSTER.png",
        )
        print(
            "Saved difference plot:",
            (OUTPUT_ROOT / "FINAL_DIFF_rec_all_offset0_minus_offset300_GLOBALCLUSTER.png").resolve(),
        )


run_all_slices()
# Out:
# [offset 0] core=0:600 ext=0:650 saved to outputs_decompose2d_slices/offset_0000/xcore_00000_00600_xext_00000_00650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 87.96it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=600:1200 ext=550:1250 saved to outputs_decompose2d_slices/offset_0000/xcore_00600_01200_xext_00550_01250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 88.16it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=1200:1800 ext=1150:1850 saved to outputs_decompose2d_slices/offset_0000/xcore_01200_01800_xext_01150_01850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 87.18it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=1800:2400 ext=1750:2450 saved to outputs_decompose2d_slices/offset_0000/xcore_01800_02400_xext_01750_02450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 84.97it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=2400:3000 ext=2350:3050 saved to outputs_decompose2d_slices/offset_0000/xcore_02400_03000_xext_02350_03050
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 91.30it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=3000:3600 ext=2950:3650 saved to outputs_decompose2d_slices/offset_0000/xcore_03000_03600_xext_02950_03650
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 83.88it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=3600:4200 ext=3550:4250 saved to outputs_decompose2d_slices/offset_0000/xcore_03600_04200_xext_03550_04250
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 85.41it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=4200:4800 ext=4150:4850 saved to outputs_decompose2d_slices/offset_0000/xcore_04200_04800_xext_04150_04850
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 84.93it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=4800:5400 ext=4750:5450 saved to outputs_decompose2d_slices/offset_0000/xcore_04800_05400_xext_04750_05450
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 83.62it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 0] core=5400:5451 ext=5350:5451 saved to outputs_decompose2d_slices/offset_0000/xcore_05400_05451_xext_05350_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 84.36it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# ------------
# cluster= 0
# amplitude= 2.3214636561113875 idx= (9, 13, 1667, 94)
# selected elements: 1791775
# ------------
# cluster= 1
# amplitude= 0.9003197682772737 idx= (15, 0, 1551, 64)
# selected elements: 653380
# ------------
# cluster= 2
# amplitude= 0.6987886768105129 idx= (14, 11, 1609, 71)
# selected elements: 25859
# ------------
# cluster= 3
# amplitude= 0.6738899013098673 idx= (2, 9, 1648, 38)
# selected elements: 15897
# ------------
# cluster= 4
# amplitude= 0.6633018198683046 idx= (15, 15, 1587, 122)
# selected elements: 61725
# ------------
# cluster= 5
# amplitude= 0.6321003850772021 idx= (2, 8, 1680, 112)
# selected elements: 6978
# ------------
# cluster= 6
# amplitude= 0.5946466521224315 idx= (2, 12, 1615, 65)
# selected elements: 10198
# ------------
# cluster= 7
# amplitude= 0.5748977187181881 idx= (15, 15, 1683, 126)
# selected elements: 3020
# ------------
# cluster= 8
# amplitude= 0.5619048612177782 idx= (15, 5, 1623, 77)
# selected elements: 46450
# ------------
# cluster= 9
# amplitude= 0.5514946678711187 idx= (10, 2, 1541, 91)
# selected elements: 84269
# ------------
# cluster= 10
# amplitude= 0.5235622108851281 idx= (15, 10, 1673, 121)
# selected elements: 32186
# ------------
# cluster= 11
# amplitude= 0.5101500127398403 idx= (14, 9, 1628, 27)
# selected elements: 30181
# ------------
# cluster= 12
# amplitude= 0.48025098934026705 idx= (6, 8, 516, 25)
# selected elements: 53647
# ------------
# cluster= 13
# amplitude= 0.47416570441741424 idx= (8, 0, 1550, 60)
# selected elements: 46531
# ------------
# cluster= 14
# amplitude= 0.47277683261286246 idx= (5, 9, 518, 24)
# selected elements: 5657
# ------------
# cluster= 15
# amplitude= 0.47107195201930246 idx= (1, 3, 1572, 63)
# selected elements: 49310
# ------------
# cluster= 16
# amplitude= 0.45328823253373934 idx= (13, 4, 1621, 74)
# selected elements: 18594
# ------------
# cluster= 17
# amplitude= 0.4225991033733493 idx= (8, 5, 1623, 58)
# selected elements: 125242
# ------------
# cluster= 18
# amplitude= 0.41719501693471606 idx= (11, 8, 1636, 26)
# selected elements: 18109
# ------------
# cluster= 19
# amplitude= 0.4083574722293721 idx= (8, 9, 323, 50)
# selected elements: 188229
# ------------
# cluster= 20
# amplitude= 0.40709170969015607 idx= (15, 7, 1632, 33)
# selected elements: 5659
# ------------
# cluster= 21
# amplitude= 0.4057785279312059 idx= (7, 8, 325, 51)
# selected elements: 2389
# ------------
# cluster= 22
# amplitude= 0.3989089209590924 idx= (11, 10, 1573, 144)
# selected elements: 1323
# ------------
# cluster= 23
# amplitude= 0.39889146273385023 idx= (11, 9, 1560, 5)
# selected elements: 29862
# ------------
# cluster= 24
# amplitude= 0.39788706872873286 idx= (6, 2, 1608, 116)
# selected elements: 17434
# ------------
# cluster= 25
# amplitude= 0.3900486911401334 idx= (11, 17, 1551, 52)
# selected elements: 49578
# ------------
# cluster= 26
# amplitude= 0.3845408507049589 idx= (14, 16, 1678, 133)
# selected elements: 13730
# ------------
# cluster= 27
# amplitude= 0.3780959765269905 idx= (6, 10, 1644, 142)
# selected elements: 5694
# ------------
# cluster= 28
# amplitude= 0.37239480583145085 idx= (7, 7, 1683, 114)
# selected elements: 27380
# ------------
# cluster= 29
# amplitude= 0.3723316141390129 idx= (15, 9, 521, 27)
# selected elements: 55481
# ------------
# cluster= 30
# amplitude= 0.36870274155613997 idx= (11, 3, 1552, 27)
# selected elements: 1430
# ------------
# cluster= 31
# amplitude= 0.36609410509932694 idx= (13, 12, 284, 52)
# selected elements: 56557
# ------------
# cluster= 32
# amplitude= 0.36295745893201914 idx= (10, 11, 1897, 50)
# selected elements: 106235
# ------------
# cluster= 33
# amplitude= 0.3535136289053397 idx= (14, 2, 1464, 109)
# selected elements: 30610
# ------------
# cluster= 34
# amplitude= 0.35243911371492215 idx= (8, 13, 1542, 95)
# selected elements: 1044
# ------------
# cluster= 35
# amplitude= 0.3451640038620158 idx= (12, 16, 1581, 119)
# selected elements: 14949
# ------------
# cluster= 36
# amplitude= 0.34481139615122036 idx= (0, 3, 1598, 41)
# selected elements: 1484
# ------------
# cluster= 37
# amplitude= 0.34462144916899706 idx= (15, 7, 1586, 141)
# selected elements: 7632
# ------------
# cluster= 38
# amplitude= 0.3444417504565404 idx= (13, 9, 205, 118)
# selected elements: 79406
# ------------
# cluster= 39
# amplitude= 0.3443464000221411 idx= (8, 5, 1426, 80)
# selected elements: 85486
# ------------
# cluster= 40
# amplitude= 0.34245949680856475 idx= (10, 0, 1662, 70)
# selected elements: 2320
# ------------
# cluster= 41
# amplitude= 0.34129532463247997 idx= (6, 8, 1599, 102)
# selected elements: 18727
# ------------
# cluster= 42
# amplitude= 0.34121342636904806 idx= (13, 8, 1557, 58)
# selected elements: 1678
# ------------
# cluster= 43
# amplitude= 0.3383768526836366 idx= (15, 5, 1532, 96)
# selected elements: 15604
# ------------
# cluster= 44
# amplitude= 0.3353868125962063 idx= (5, 3, 1497, 128)
# selected elements: 14154
# ------------
# cluster= 45
# amplitude= 0.3333222246800942 idx= (10, 9, 474, 7)
# selected elements: 34426
# ------------
# cluster= 46
# amplitude= 0.32658202637322054 idx= (6, 6, 1663, 117)
# selected elements: 8930
# ------------
# cluster= 47
# amplitude= 0.3228889152765171 idx= (11, 11, 348, 43)
# selected elements: 13279
# ------------
# cluster= 48
# amplitude= 0.320872469577909 idx= (7, 4, 1615, 104)
# selected elements: 440
# ------------
# cluster= 49
# amplitude= 0.31993917359167307 idx= (9, 11, 346, 42)
# selected elements: 10805
# ------------
# cluster= 50
# amplitude= 0.3186479570026206 idx= (3, 8, 1720, 63)
# selected elements: 16860
# ------------
# cluster= 51
# amplitude= 0.31810958235042114 idx= (15, 8, 1169, 125)
# selected elements: 64571
# ------------
# cluster= 52
# amplitude= 0.31405696450119547 idx= (9, 11, 1572, 142)
# selected elements: 2835
# ------------
# cluster= 53
# amplitude= 0.3138943896025435 idx= (8, 7, 1602, 102)
# selected elements: 8221
# ------------
# cluster= 54
# amplitude= 0.31367887074355333 idx= (4, 4, 1566, 49)
# selected elements: 10691
# ------------
# cluster= 55
# amplitude= 0.31221373851265266 idx= (12, 7, 256, 71)
# selected elements: 36079
# ------------
# cluster= 56
# amplitude= 0.30706562712180885 idx= (9, 8, 1559, 6)
# selected elements: 3979
# ------------
# cluster= 57
# amplitude= 0.30603962397346623 idx= (10, 9, 255, 78)
# selected elements: 7518
# ------------
# cluster= 58
# amplitude= 0.3051168124278113 idx= (10, 0, 1564, 135)
# selected elements: 5299
# ------------
# cluster= 59
# amplitude= 0.302818608774934 idx= (8, 9, 1560, 6)
# selected elements: 2733
# ------------
# cluster= 60
# amplitude= 0.3016294180723692 idx= (5, 9, 1574, 142)
# selected elements: 763
# ------------
# cluster= 61
# amplitude= 0.3010360246190825 idx= (5, 11, 1546, 113)
# selected elements: 19442
# ------------
# cluster= 62
# amplitude= 0.3000108256031408 idx= (2, 2, 1599, 40)
# selected elements: 1161
# ------------
# cluster= 63
# amplitude= 0.29985881520278806 idx= (9, 16, 1664, 82)
# selected elements: 5286
# ------------
# cluster= 64
# amplitude= 0.29924283541028385 idx= (8, 4, 1494, 130)
# selected elements: 14882
# ------------
# cluster= 65
# amplitude= 0.2980951214690299 idx= (15, 13, 1774, 118)
# selected elements: 25322
# ------------
# cluster= 66
# amplitude= 0.2943816633184424 idx= (1, 12, 1658, 75)
# selected elements: 925
# ------------
# cluster= 67
# amplitude= 0.2930989103827532 idx= (7, 16, 1667, 81)
# selected elements: 1731
# ------------
# cluster= 68
# amplitude= 0.29253224916396225 idx= (7, 14, 1539, 94)
# selected elements: 638
# ------------
# cluster= 69
# amplitude= 0.29199315438429424 idx= (13, 8, 525, 28)
# selected elements: 8134
# ------------
# cluster= 70
# amplitude= 0.29096409866125805 idx= (9, 16, 1576, 117)
# selected elements: 15137
# ------------
# cluster= 71
# amplitude= 0.28337130862800847 idx= (5, 9, 1548, 104)
# selected elements: 1032
# ------------
# cluster= 72
# amplitude= 0.2827535387468756 idx= (14, 6, 1420, 86)
# selected elements: 9585
# ------------
# cluster= 73
# amplitude= 0.28234339055003316 idx= (5, 3, 1524, 114)
# selected elements: 2238
# ------------
# cluster= 74
# amplitude= 0.2818026053147679 idx= (6, 10, 900, 134)
# selected elements: 13527
# ------------
# cluster= 75
# amplitude= 0.2815822443097733 idx= (4, 7, 1631, 68)
# selected elements: 1814
# ------------
# cluster= 76
# amplitude= 0.28047130260997827 idx= (3, 15, 1637, 75)
# selected elements: 1823
# ------------
# cluster= 77
# amplitude= 0.28031429588432694 idx= (3, 4, 1615, 103)
# selected elements: 1532
# ------------
# cluster= 78
# amplitude= 0.277547090076265 idx= (10, 11, 1751, 134)
# selected elements: 1568
# ------------
# cluster= 79
# amplitude= 0.2759813435543466 idx= (5, 7, 274, 60)
# selected elements: 13431
# ------------
# cluster= 80
# amplitude= 0.27484652318073793 idx= (4, 5, 1664, 115)
# selected elements: 4159
# ------------
# cluster= 81
# amplitude= 0.27481485619158913 idx= (14, 1, 1316, 124)
# selected elements: 42397
# ------------
# cluster= 82
# amplitude= 0.27360922638925633 idx= (4, 1, 1523, 123)
# selected elements: 5564
# ------------
# cluster= 83
# amplitude= 0.27196833062886816 idx= (9, 10, 556, 10)
# selected elements: 6223
# ------------
# cluster= 84
# amplitude= 0.2713195032747061 idx= (1, 7, 1654, 31)
# selected elements: 4217
# ------------
# cluster= 85
# amplitude= 0.26529812480818515 idx= (5, 10, 197, 116)
# selected elements: 1744
# ------------
# cluster= 86
# amplitude= 0.2646144330380939 idx= (2, 8, 332, 53)
# selected elements: 1806
# ------------
# cluster= 87
# amplitude= 0.26403579034370467 idx= (1, 4, 1553, 99)
# selected elements: 5018
# ------------
# cluster= 88
# amplitude= 0.26224408741807886 idx= (4, 6, 1763, 34)
# selected elements: 9323
# ------------
# cluster= 89
# amplitude= 0.260414750586672 idx= (2, 3, 1678, 86)
# selected elements: 12588
# ------------
# cluster= 90
# amplitude= 0.26037069280481234 idx= (3, 10, 1600, 78)
# selected elements: 1875
# ------------
# cluster= 91
# amplitude= 0.25964317860420694 idx= (2, 8, 1627, 95)
# selected elements: 5406
# ------------
# cluster= 92
# amplitude= 0.25887743560684784 idx= (10, 1, 1284, 105)
# selected elements: 15971
# ------------
# cluster= 93
# amplitude= 0.2587942949206798 idx= (11, 13, 1869, 104)
# selected elements: 53181
# ------------
# cluster= 94
# amplitude= 0.2582224478875309 idx= (13, 8, 1704, 11)
# selected elements: 2382
# ------------
# cluster= 95
# amplitude= 0.25745404509223047 idx= (13, 10, 385, 8)
# selected elements: 6482
# ------------
# cluster= 96
# amplitude= 0.25702515380346436 idx= (13, 4, 1426, 82)
# selected elements: 11066
# ------------
# cluster= 97
# amplitude= 0.256548154452872 idx= (14, 9, 1639, 148)
# selected elements: 368
# ------------
# cluster= 98
# amplitude= 0.25634524785459356 idx= (3, 15, 1670, 105)
# selected elements: 1515
# ------------
# cluster= 99
# amplitude= 0.2556270058382898 idx= (2, 3, 1485, 114)
# selected elements: 1901
# ------------
# cluster= 100
# amplitude= 0.25554594318234974 idx= (9, 0, 1684, 103)
# selected elements: 7522
# ------------
# cluster= 101
# amplitude= 0.25551992781351346 idx= (0, 1, 1540, 45)
# selected elements: 4812
# ------------
# cluster= 102
# amplitude= 0.2549871598553237 idx= (2, 14, 1640, 77)
# selected elements: 698
# ------------
# cluster= 103
# amplitude= 0.25407543816839384 idx= (1, 5, 1564, 17)
# selected elements: 5538
# ------------
# cluster= 104
# amplitude= 0.2539679381270547 idx= (8, 2, 1554, 36)
# selected elements: 1574
# ------------
# cluster= 105
# amplitude= 0.2532041673005213 idx= (3, 6, 1626, 47)
# selected elements: 2300
# ------------
# cluster= 106
# amplitude= 0.2530426461412684 idx= (3, 13, 1578, 71)
# selected elements: 3104
# ------------
# cluster= 107
# amplitude= 0.252289020994592 idx= (13, 10, 433, 7)
# selected elements: 7824
# ------------
# cluster= 108
# amplitude= 0.2512568020151063 idx= (15, 10, 2023, 33)
# selected elements: 30997
# ------------
# cluster= 109
# amplitude= 0.25118990790737505 idx= (3, 9, 1579, 90)
# selected elements: 2036
# ------------
# cluster= 110
# amplitude= 0.2500993917502038 idx= (5, 7, 1628, 45)
# selected elements: 1504
# [offset 0] Done. Outputs in /Users/anhphan/juwavelet_awe/examples/outputs_decompose2d_slices/offset_0000
# [offset 300] core=300:900 ext=250:950 saved to outputs_decompose2d_slices/offset_0300/xcore_00300_00900_xext_00250_00950
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 88.94it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=900:1500 ext=850:1550 saved to outputs_decompose2d_slices/offset_0300/xcore_00900_01500_xext_00850_01550
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 91.39it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=1500:2100 ext=1450:2150 saved to outputs_decompose2d_slices/offset_0300/xcore_01500_02100_xext_01450_02150
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 83.85it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=2100:2700 ext=2050:2750 saved to outputs_decompose2d_slices/offset_0300/xcore_02100_02700_xext_02050_02750
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 88.85it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=2700:3300 ext=2650:3350 saved to outputs_decompose2d_slices/offset_0300/xcore_02700_03300_xext_02650_03350
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 83.45it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=3300:3900 ext=3250:3950 saved to outputs_decompose2d_slices/offset_0300/xcore_03300_03900_xext_03250_03950
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.84it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=3900:4500 ext=3850:4550 saved to outputs_decompose2d_slices/offset_0300/xcore_03900_04500_xext_03850_04550
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 86.66it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=4500:5100 ext=4450:5150 saved to outputs_decompose2d_slices/offset_0300/xcore_04500_05100_xext_04450_05150
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 48.54it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [offset 300] core=5100:5451 ext=5050:5451 saved to outputs_decompose2d_slices/offset_0300/xcore_05100_05451_xext_05050_05451
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 95.65it/s]
# /Users/anhphan/opt/anaconda3/envs/juwavelet_env/lib/python3.10/site-packages/juwavelet/utils.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# ------------
# cluster= 0
# amplitude= 2.3214639180094934 idx= (9, 13, 1667, 94)
# selected elements: 1784447
# ------------
# cluster= 1
# amplitude= 0.900319390326576 idx= (15, 0, 1551, 64)
# selected elements: 654717
# ------------
# cluster= 2
# amplitude= 0.6987882233501035 idx= (14, 11, 1609, 71)
# selected elements: 25908
# ------------
# cluster= 3
# amplitude= 0.6738900795292716 idx= (2, 9, 1648, 38)
# selected elements: 15900
# ------------
# cluster= 4
# amplitude= 0.6633018330110121 idx= (15, 15, 1587, 122)
# selected elements: 54770
# ------------
# cluster= 5
# amplitude= 0.6321003896657056 idx= (2, 8, 1680, 112)
# selected elements: 6978
# ------------
# cluster= 6
# amplitude= 0.5946466547857887 idx= (2, 12, 1615, 65)
# selected elements: 10198
# ------------
# cluster= 7
# amplitude= 0.5748529016982926 idx= (15, 15, 1683, 126)
# selected elements: 3027
# ------------
# cluster= 8
# amplitude= 0.561903910542127 idx= (15, 5, 1623, 77)
# selected elements: 46399
# ------------
# cluster= 9
# amplitude= 0.5514946717453004 idx= (10, 2, 1541, 91)
# selected elements: 84231
# ------------
# cluster= 10
# amplitude= 0.5426812221037468 idx= (15, 10, 1673, 122)
# selected elements: 32481
# ------------
# cluster= 11
# amplitude= 0.5246312065596264 idx= (14, 9, 1628, 26)
# selected elements: 31450
# ------------
# cluster= 12
# amplitude= 0.4803051729364532 idx= (6, 8, 516, 25)
# selected elements: 53664
# ------------
# cluster= 13
# amplitude= 0.4741657016529145 idx= (8, 0, 1550, 60)
# selected elements: 46527
# ------------
# cluster= 14
# amplitude= 0.4727788379508776 idx= (5, 9, 518, 24)
# selected elements: 5677
# ------------
# cluster= 15
# amplitude= 0.47107195565882637 idx= (1, 3, 1572, 63)
# selected elements: 49310
# ------------
# cluster= 16
# amplitude= 0.45327808737012215 idx= (13, 4, 1621, 74)
# selected elements: 18706
# ------------
# cluster= 17
# amplitude= 0.42259910984429416 idx= (8, 5, 1623, 58)
# selected elements: 125196
# ------------
# cluster= 18
# amplitude= 0.41791235646463615 idx= (11, 8, 1637, 26)
# selected elements: 18436
# ------------
# cluster= 19
# amplitude= 0.40835747961792257 idx= (8, 9, 323, 50)
# selected elements: 156267
# ------------
# cluster= 20
# amplitude= 0.4076256774634791 idx= (15, 7, 1633, 33)
# selected elements: 2901
# ------------
# cluster= 21
# amplitude= 0.40577853779423345 idx= (7, 8, 325, 51)
# selected elements: 2391
# ------------
# cluster= 22
# amplitude= 0.3978870680974239 idx= (6, 2, 1608, 116)
# selected elements: 17434
# ------------
# cluster= 23
# amplitude= 0.3900486907728493 idx= (11, 17, 1551, 52)
# selected elements: 49585
# ------------
# cluster= 24
# amplitude= 0.3846775415042877 idx= (14, 16, 1678, 133)
# selected elements: 12923
# ------------
# cluster= 25
# amplitude= 0.3817323557353711 idx= (11, 9, 1560, 5)
# selected elements: 29573
# ------------
# cluster= 26
# amplitude= 0.37760579535788574 idx= (11, 10, 1573, 143)
# selected elements: 1373
# ------------
# cluster= 27
# amplitude= 0.3723925737741622 idx= (7, 7, 1683, 114)
# selected elements: 27387
# ------------
# cluster= 28
# amplitude= 0.3687027392323991 idx= (11, 3, 1552, 27)
# selected elements: 1430
# ------------
# cluster= 29
# amplitude= 0.36700651836909914 idx= (6, 10, 1644, 142)
# selected elements: 5779
# ------------
# cluster= 30
# amplitude= 0.365874336271434 idx= (13, 12, 284, 52)
# selected elements: 57325
# ------------
# cluster= 31
# amplitude= 0.365816894923951 idx= (15, 9, 521, 27)
# selected elements: 96472
# ------------
# cluster= 32
# amplitude= 0.36295738391101584 idx= (10, 11, 1897, 50)
# selected elements: 106159
# ------------
# cluster= 33
# amplitude= 0.35993158931635366 idx= (14, 9, 206, 118)
# selected elements: 86018
# ------------
# cluster= 34
# amplitude= 0.35351888894740335 idx= (14, 2, 1464, 109)
# selected elements: 30794
# ------------
# cluster= 35
# amplitude= 0.35243910611797213 idx= (8, 13, 1542, 95)
# selected elements: 1044
# ------------
# cluster= 36
# amplitude= 0.3451640054806036 idx= (12, 16, 1581, 119)
# selected elements: 14957
# ------------
# cluster= 37
# amplitude= 0.344811395567294 idx= (0, 3, 1598, 41)
# selected elements: 1484
# ------------
# cluster= 38
# amplitude= 0.34434639673458906 idx= (8, 5, 1426, 80)
# selected elements: 109450
# ------------
# cluster= 39
# amplitude= 0.34278981225206157 idx= (10, 0, 1662, 70)
# selected elements: 2336
# ------------
# cluster= 40
# amplitude= 0.3412953330757935 idx= (6, 8, 1599, 102)
# selected elements: 18741
# ------------
# cluster= 41
# amplitude= 0.34121439715943697 idx= (13, 8, 1557, 58)
# selected elements: 1678
# ------------
# cluster= 42
# amplitude= 0.34030503412387775 idx= (15, 7, 1588, 140)
# selected elements: 7597
# ------------
# cluster= 43
# amplitude= 0.3397957262930074 idx= (10, 9, 475, 6)
# selected elements: 18189
# ------------
# cluster= 44
# amplitude= 0.3384000738170678 idx= (15, 5, 1532, 96)
# selected elements: 15643
# ------------
# cluster= 45
# amplitude= 0.335352081980858 idx= (5, 3, 1497, 128)
# selected elements: 14157
# ------------
# cluster= 46
# amplitude= 0.32658255084659993 idx= (6, 6, 1663, 117)
# selected elements: 8930
# ------------
# cluster= 47
# amplitude= 0.3228922740303705 idx= (11, 11, 348, 43)
# selected elements: 13205
# ------------
# cluster= 48
# amplitude= 0.32087247339399694 idx= (7, 4, 1615, 104)
# selected elements: 440
# ------------
# cluster= 49
# amplitude= 0.3199388330861332 idx= (9, 11, 346, 42)
# selected elements: 10809
# ------------
# cluster= 50
# amplitude= 0.31864795259313416 idx= (3, 8, 1720, 63)
# selected elements: 16860
# ------------
# cluster= 51
# amplitude= 0.31646178834308264 idx= (15, 8, 1169, 125)
# selected elements: 64015
# ------------
# cluster= 52
# amplitude= 0.313894395394952 idx= (8, 7, 1602, 102)
# selected elements: 8239
# ------------
# cluster= 53
# amplitude= 0.3136788746865228 idx= (4, 4, 1566, 49)
# selected elements: 10691
# ------------
# cluster= 54
# amplitude= 0.31221374493579435 idx= (12, 7, 256, 71)
# selected elements: 36030
# ------------
# cluster= 55
# amplitude= 0.3107686907679364 idx= (9, 11, 1572, 142)
# selected elements: 2860
# ------------
# cluster= 56
# amplitude= 0.30603962370670496 idx= (10, 9, 255, 78)
# selected elements: 7491
# ------------
# cluster= 57
# amplitude= 0.30511681303811755 idx= (10, 0, 1564, 135)
# selected elements: 5299
# ------------
# cluster= 58
# amplitude= 0.3010360042755926 idx= (5, 11, 1546, 113)
# selected elements: 19441
# ------------
# cluster= 59
# amplitude= 0.3003212655908209 idx= (9, 8, 1559, 6)
# selected elements: 3950
# ------------
# cluster= 60
# amplitude= 0.30001082567267917 idx= (2, 2, 1599, 40)
# selected elements: 1161
# ------------
# cluster= 61
# amplitude= 0.29986202153686287 idx= (9, 16, 1664, 82)
# selected elements: 5281
# ------------
# cluster= 62
# amplitude= 0.29905487277832243 idx= (8, 4, 1494, 130)
# selected elements: 14883
# ------------
# cluster= 63
# amplitude= 0.29810487200443986 idx= (15, 13, 1774, 118)
# selected elements: 32786
# ------------
# cluster= 64
# amplitude= 0.2952678020995204 idx= (5, 9, 1574, 142)
# selected elements: 745
# ------------
# cluster= 65
# amplitude= 0.2943816681435631 idx= (1, 12, 1658, 75)
# selected elements: 925
# ------------
# cluster= 66
# amplitude= 0.29332091526993775 idx= (8, 9, 1560, 6)
# selected elements: 2541
# ------------
# cluster= 67
# amplitude= 0.29309887773795035 idx= (7, 16, 1667, 81)
# selected elements: 1732
# ------------
# cluster= 68
# amplitude= 0.29253224694584107 idx= (7, 14, 1539, 94)
# selected elements: 638
# ------------
# cluster= 69
# amplitude= 0.2909640970979794 idx= (9, 16, 1576, 117)
# selected elements: 15140
# ------------
# cluster= 70
# amplitude= 0.2867022051592885 idx= (15, 9, 1699, 7)
# selected elements: 1363
# ------------
# cluster= 71
# amplitude= 0.28337131288284917 idx= (5, 9, 1548, 104)
# selected elements: 1032
# ------------
# cluster= 72
# amplitude= 0.2823433925626247 idx= (5, 3, 1524, 114)
# selected elements: 2238
# ------------
# cluster= 73
# amplitude= 0.28177092110348134 idx= (6, 10, 900, 134)
# selected elements: 13817
# ------------
# cluster= 74
# amplitude= 0.281582248851642 idx= (4, 7, 1631, 68)
# selected elements: 1813
# ------------
# cluster= 75
# amplitude= 0.2804713024353518 idx= (3, 15, 1637, 75)
# selected elements: 1823
# ------------
# cluster= 76
# amplitude= 0.2803142964798099 idx= (3, 4, 1615, 103)
# selected elements: 1532
# ------------
# cluster= 77
# amplitude= 0.27662679659485323 idx= (10, 11, 1750, 133)
# selected elements: 1570
# ------------
# cluster= 78
# amplitude= 0.27598134647967487 idx= (5, 7, 274, 60)
# selected elements: 13435
# ------------
# cluster= 79
# amplitude= 0.2748465316072953 idx= (4, 5, 1664, 115)
# selected elements: 4159
# ------------
# cluster= 80
# amplitude= 0.2747996703753803 idx= (14, 1, 1316, 124)
# selected elements: 42382
# ------------
# cluster= 81
# amplitude= 0.27360922755845585 idx= (4, 1, 1523, 123)
# selected elements: 5564
# ------------
# cluster= 82
# amplitude= 0.2713195097980908 idx= (1, 7, 1654, 31)
# selected elements: 3863
# ------------
# cluster= 83
# amplitude= 0.26975059850170374 idx= (9, 10, 556, 10)
# selected elements: 6241
# ------------
# cluster= 84
# amplitude= 0.26529880005454815 idx= (5, 10, 197, 116)
# selected elements: 1998
# ------------
# cluster= 85
# amplitude= 0.26461442882209163 idx= (2, 8, 332, 53)
# selected elements: 1806
# ------------
# cluster= 86
# amplitude= 0.2640357908784433 idx= (1, 4, 1553, 99)
# selected elements: 5018
# ------------
# cluster= 87
# amplitude= 0.26224408057379767 idx= (4, 6, 1763, 34)
# selected elements: 9321
# ------------
# cluster= 88
# amplitude= 0.2604147486113973 idx= (2, 3, 1678, 86)
# selected elements: 12589
# ------------
# cluster= 89
# amplitude= 0.2603706934319775 idx= (3, 10, 1600, 78)
# selected elements: 1875
# ------------
# cluster= 90
# amplitude= 0.2596431803946902 idx= (2, 8, 1627, 95)
# selected elements: 5406
# ------------
# cluster= 91
# amplitude= 0.2588774346028878 idx= (10, 1, 1284, 105)
# selected elements: 15971
# ------------
# cluster= 92
# amplitude= 0.2587942921671606 idx= (11, 13, 1869, 104)
# selected elements: 53648
# ------------
# cluster= 93
# amplitude= 0.2563452523969603 idx= (3, 15, 1670, 105)
# selected elements: 1515
# ------------
# cluster= 94
# amplitude= 0.2556270015388024 idx= (2, 3, 1485, 114)
# selected elements: 1901
# ------------
# cluster= 95
# amplitude= 0.2555459377378855 idx= (9, 0, 1684, 103)
# selected elements: 7514
# ------------
# cluster= 96
# amplitude= 0.25551993057823785 idx= (0, 1, 1540, 45)
# selected elements: 4812
# ------------
# cluster= 97
# amplitude= 0.2549871584523559 idx= (2, 14, 1640, 77)
# selected elements: 698
# ------------
# cluster= 98
# amplitude= 0.2540754440337312 idx= (1, 5, 1564, 17)
# selected elements: 5538
# ------------
# cluster= 99
# amplitude= 0.2539679409176337 idx= (8, 2, 1554, 36)
# selected elements: 1574
# ------------
# cluster= 100
# amplitude= 0.2532041671971329 idx= (3, 6, 1626, 47)
# selected elements: 2300
# ------------
# cluster= 101
# amplitude= 0.2530426430155004 idx= (3, 13, 1578, 71)
# selected elements: 3104
# ------------
# cluster= 102
# amplitude= 0.25282848418721937 idx= (15, 10, 2023, 32)
# selected elements: 30021
# ------------
# cluster= 103
# amplitude= 0.2511899126534481 idx= (3, 9, 1579, 90)
# selected elements: 2036
# ------------
# cluster= 104
# amplitude= 0.25009939508971474 idx= (5, 7, 1628, 45)
# selected elements: 1504
# [offset 300] Done. Outputs in /Users/anhphan/juwavelet_awe/examples/outputs_decompose2d_slices/offset_0300
# Saved difference plot: /Users/anhphan/juwavelet_awe/examples/outputs_decompose2d_slices/FINAL_DIFF_rec_all_offset0_minus_offset300_GLOBALCLUSTER.png
