# %% [markdown]
# ## This is the working version as of Feb 12 2026
# Changes to make:
#
#     - Run both l3c and l3a

# %% [markdown]
# ## Clustering, works for both l3c (l5c), and l3a

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Dict, Any, List

import copy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

try:
    from scipy import stats
except Exception:
    stats = None

# --------------------------
# User params
# --------------------------
FILE_PATH = r"C:\Users\domin\juwavelet\examples\CWT Whole Orbit\l3\OneFile\awe_l3a_tmp_2025153T1853_08658_v01.nc"  # can be L5C / L3C / L3A
FRAME_IDX = 0

# Slicing on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)
SLICE_PAD = 50  # extend each slice by this many UNBINNED pixels on each side

# Choose ONE slicing offset (no comparisons)
X_OFFSET = 0  # set to 0 or 300 or whatever you want

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 24
JT = 18
ASPECT = 1

# Pixel spacing (km per pixel)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Red noise style filtering (robust WPS thresholding per scale)
APPLY_RED_NOISE_FILTER = True

# Optional diagnostics output from the red noise filter
SAVE_REDNOISE_DIAGNOSTICS = True

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices_single_noise_filtering_AUTO")
SAVE_DPI = 200

# --------------------------
# Auto-detect product type
# --------------------------
file_name = Path(FILE_PATH).name.lower()
if "_l3a_" in file_name:
    PRODUCT_TYPE = "l3a"
elif "_l3c_" in file_name:
    PRODUCT_TYPE = "l3c"
elif "_l5c_" in file_name:
    PRODUCT_TYPE = "l5c"
else:
    raise ValueError(f"Cannot detect product type from file name: {FILE_PATH}")

print("Detected product type:", PRODUCT_TYPE)

# --------------------------
# Parameter runs (AUTO)
# --------------------------
if PRODUCT_TYPE == "l3a":
    RUNS: List[Dict[str, Any]] = [
        dict(
            name="base",
            MIN_AMP=1.25,
            THR=0.6,
            WHITE_NOISE_THRESHOLD=0.1,
            WPS_NOISE_THRESHOLD=8.0,
        ),
    ]
else:
    # l5c and l3c (Radiance) use the same settings
    RUNS = [
        dict(
            name="base",
            MIN_AMP=0.2,
            THR=0.1,
            WHITE_NOISE_THRESHOLD=0.02,
            WPS_NOISE_THRESHOLD=8.0,
        ),
    ]

print("Using RUNS:", RUNS)

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)

# --------------------------
# Small helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def diverging_limits(*arrays: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    vals = []
    for A in arrays:
        if A is None:
            continue
        a = np.asarray(A)
        good = np.isfinite(a)
        if np.any(good):
            vals.append(a[good].ravel())
    if not vals:
        return (-1.0, 1.0)
    stacked = np.concatenate(vals)
    lo, hi = np.nanpercentile(stacked, [p_lo, p_hi])
    vmax = max(abs(lo), abs(hi))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    return (-vmax, vmax)


# --------------------------
# Data helpers
# --------------------------
def read_frame_auto(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        if PRODUCT_TYPE == "l3a":
            varname = "Temperature"
        else:
            varname = "Radiance"

        data = nc.variables[varname][:]  # (t, y, x)

    if data.ndim != 3:
        raise ValueError(f"{varname} expected 3D (t,y,x); got {data.shape}")

    if not (0 <= frame_idx < data.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{data.shape[0]-1}")

    return np.asarray(data[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def unbin_repeat_xy(A: np.ndarray, factor: int) -> np.ndarray:
    """
    Nearest-neighbor upsample (repeat) from (y,x) to (y*factor, x*factor).
    Preserves NaNs by repetition.
    """
    if factor is None or int(factor) <= 1:
        return A
    f = int(factor)
    return np.repeat(np.repeat(A, f, axis=0), f, axis=1)


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    return np.cos(theta_xy), np.sin(theta_xy)


# --------------------------
# Red noise style filtering helper
# --------------------------
def apply_red_noise_filter_cwt(
    cwt: dict,
    white_noise_threshold: float = 0.1,
    wps_noise_threshold: float = 8.0,
) -> Tuple[dict, Dict[str, Any]]:
    """
    Robust per-scale WPS filtering.
    Returns filtered_cwt (deep copy) and a small diagnostics dict.
    """
    diag: Dict[str, Any] = {}
    if stats is None:
        diag["skipped"] = True
        diag["reason"] = "scipy not available"
        return cwt, diag

    cwt_copy = copy.deepcopy(cwt)
    dec = cwt_copy["decomposition"]  # (ns, nt, nx, ny) complex

    WPS0 = np.abs(dec) ** 2
    diag["n_coeff_total"] = int(WPS0.size)

    mask_1 = WPS0 < (float(white_noise_threshold) ** 2)
    dec[mask_1] = 0

    WPS1 = np.abs(dec) ** 2
    diag["n_zero_after_white"] = int(np.count_nonzero(WPS1 == 0))

    median_WPS = np.median(WPS1, axis=(1, 2, 3))  # (ns,)
    mad = stats.median_abs_deviation(WPS1, axis=(1, 2, 3), scale=1.0)  # (ns,)
    sMAD_WPS = 1.4826 * mad

    sMAD_safe = np.where(sMAD_WPS > 0, sMAD_WPS, np.nan)
    WPS_scaled = (WPS1 - median_WPS[:, None, None, None]) / sMAD_safe[:, None, None, None]

    mask = WPS_scaled < float(wps_noise_threshold)
    dec[mask] = 0

    WPS2 = np.abs(dec) ** 2
    diag["n_zero_after_scaled"] = int(np.count_nonzero(WPS2 == 0))

    finite_scaled = np.isfinite(WPS_scaled)

    diag["sMAD_min"] = float(np.nanmin(sMAD_WPS))
    diag["sMAD_median"] = float(np.nanmedian(sMAD_WPS))

    if np.any(finite_scaled):
        diag["WPS_scaled_min"] = float(np.nanmin(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_median"] = float(np.nanmedian(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_max"] = float(np.nanmax(WPS_scaled[finite_scaled]))
    else:
        diag["WPS_scaled_min"] = np.nan
        diag["WPS_scaled_median"] = np.nan
        diag["WPS_scaled_max"] = np.nan

    return cwt_copy, diag


# --------------------------
# Quicklook plots
# --------------------------
def quicklook_save(x1d: np.ndarray, y1d: np.ndarray, Z: np.ndarray, title: str, outpath: Path) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("arb")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
    wavy_after_noise_xy: np.ndarray | None = None,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    arrays = [orig_c, bg_c, rem_c, rem_tapered_c]
    if wavy_after_noise_xy is not None:
        arrays.append(wavy_after_noise_xy)

    vmin, vmax = diverging_limits(*arrays, p_lo=1, p_hi=99)

    fig, axs = plt.subplots(2, 3, figsize=(16, 10), constrained_layout=True)
    axs = axs.flatten()

    panels = [
        (orig_c, "Original (median sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    if wavy_after_noise_xy is not None:
        panels.append((wavy_after_noise_xy, "Wavy stuff (wavelet reconstruction after noise filtering)"))

    im0 = None
    for ax, (Z, title) in zip(axs, panels):
        im0 = ax.pcolormesh(x1d_km, y1d_km, Z, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    for ax in axs[len(panels) :]:
        ax.axis("off")

    cbar = fig.colorbar(im0, ax=axs[: len(panels)], orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("arb")
    save_fig(fig, outpath)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2
    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])
        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_vmin, bg_vmax = diverging_limits(bg_xy, p_lo=2, p_hi=98)
    cl_vmin, cl_vmax = diverging_limits(rec_xy, p_lo=2, p_hi=98)

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if (not np.isfinite(lam_vmin)) or (not np.isfinite(lam_vmax)) or (lam_vmin == lam_vmax):
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6)
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n"
            + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        arrow_len_km = 40.0
        u = u * arrow_len_km
        v = v * arrow_len_km

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good], Yqs[good], uqs[good], vqs[good],
            angles="xy", scale_units="xy", scale=QUIVER_SCALE, width=0.0025
        )

    save_fig(fig, outpath)


# --------------------------
# Cluster products (for L6C/L6A outputs)
# --------------------------
def cluster_dominant_lambda_map(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_mask_xy: np.ndarray | None = None,
) -> np.ndarray:
    """
    Per-pixel dominant wavelength map λ(x,y) for ONE cluster.
    Returns shape (ny, nx) in XY.

    If amp_mask_xy is provided (A_xy with NaNs), apply the same NaN mask to λ.
    """
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power0 = np.abs(dec) ** 2
    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power0.shape
    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)
    valid = np.isfinite(pmax) & (pmax > 0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T  # XY

    if amp_mask_xy is not None:
        lam_xy[~np.isfinite(amp_mask_xy)] = np.nan

    return lam_xy


def copy_lxc_to_l6x_with_clusters(
    lxc_path: str | Path,
    l6x_path: str | Path,
    clusters: List[Dict[str, Any]],
    y_dim: int,
    x_dim: int,
    unbin_factor: int = 1,
) -> None:
    """
    Copy everything from input file, then append cluster products.

    Adds:
      - dimension: cluster
      - dimension: y_cluster (=y_dim*unbin_factor), x_cluster (=x_dim*unbin_factor)
      - SlicesNo(cluster)
      - Area(cluster)
      - ClusterPowerAbs(cluster)
      - ClusterPowerPct(cluster)
      - Amplitude(cluster,y_cluster,x_cluster)
      - DominantWavelength(cluster,y_cluster,x_cluster)
      - Angle(cluster,y_cluster,x_cluster)
      - ClusterReconstruction(cluster,y_cluster,x_cluster)   (optional)

    If unbin_factor>1, upsample products by repetition.
    """
    def _unbin_repeat_xy(A: np.ndarray, factor: int) -> np.ndarray:
        if factor is None or int(factor) <= 1:
            return A
        f = int(factor)
        return np.repeat(np.repeat(A, f, axis=0), f, axis=1)

    lxc_path = Path(lxc_path)
    l6x_path = Path(l6x_path)
    l6x_path.parent.mkdir(parents=True, exist_ok=True)

    ncl = int(len(clusters))
    has_rec = any((c.get("rec_xy", None) is not None) for c in clusters)

    fup = int(unbin_factor) if (unbin_factor is not None and int(unbin_factor) > 1) else 1
    y_dim_w = int(y_dim) * fup
    x_dim_w = int(x_dim) * fup

    with Dataset(lxc_path, "r") as src, Dataset(l6x_path, "w", format="NETCDF4") as dst:
        dst.setncatts({k: src.getncattr(k) for k in src.ncattrs()})

        for dname, dim in src.dimensions.items():
            dst.createDimension(dname, (len(dim) if not dim.isunlimited() else None))

        for vname, var in src.variables.items():
            out = dst.createVariable(
                vname,
                var.datatype,
                var.dimensions,
                zlib=True,
                complevel=4,
                fill_value=getattr(var, "_FillValue", None),
            )
            out.setncatts({k: var.getncattr(k) for k in var.ncattrs()})
            out[:] = var[:]

        dst.createDimension("cluster", ncl)
        dst.createDimension("y_cluster", y_dim_w)
        dst.createDimension("x_cluster", x_dim_w)

        v_slice = dst.createVariable("SlicesNo", "i4", ("cluster",), zlib=True, complevel=4)
        v_area = dst.createVariable("Area", "f4", ("cluster",), zlib=True, complevel=4)
        v_pabs = dst.createVariable("ClusterPowerAbs", "f8", ("cluster",), zlib=True, complevel=4)
        v_ppct = dst.createVariable("ClusterPowerPct", "f4", ("cluster",), zlib=True, complevel=4)

        v_amp = dst.createVariable(
            "Amplitude", "f4", ("cluster", "y_cluster", "x_cluster"),
            zlib=True, complevel=4, fill_value=np.float32(np.nan)
        )
        v_lam = dst.createVariable(
            "DominantWavelength", "f4", ("cluster", "y_cluster", "x_cluster"),
            zlib=True, complevel=4, fill_value=np.float32(np.nan)
        )
        v_ang = dst.createVariable(
            "Angle", "f4", ("cluster", "y_cluster", "x_cluster"),
            zlib=True, complevel=4, fill_value=np.float32(np.nan)
        )

        v_rec = None
        if has_rec:
            v_rec = dst.createVariable(
                "ClusterReconstruction", "f4", ("cluster", "y_cluster", "x_cluster"),
                zlib=True, complevel=4, fill_value=np.float32(np.nan)
            )
            v_rec.units = "arb"
            v_rec.long_name = "Per-cluster wavelet reconstruction map (relative; median-subtracted)"

        v_area.units = "km2"
        v_lam.units = "km"
        v_ang.units = "rad"
        v_slice.long_name = "Slice index (starts at 0) for each cluster"
        v_pabs.units = "arb"
        v_ppct.units = "percent"

        if PRODUCT_TYPE == "l3a":
            v_amp.units = "K"
        else:
            v_amp.units = "kR"

        if ncl == 0:
            return

        v_slice[:] = np.asarray([c["slice_no"] for c in clusters], dtype=np.int32)
        v_area[:] = np.asarray([c["area_km2"] for c in clusters], dtype=np.float32)
        v_pabs[:] = np.asarray([c.get("power_abs", np.nan) for c in clusters], dtype=np.float64)
        v_ppct[:] = np.asarray([c.get("power_pct", np.nan) for c in clusters], dtype=np.float32)

        amp_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        lam_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        ang_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        rec_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32) if has_rec else None

        for i, c in enumerate(clusters):
            A = _unbin_repeat_xy(c["A_xy"], fup)
            L = _unbin_repeat_xy(c["lam_xy"], fup)
            T = _unbin_repeat_xy(c["theta_xy"], fup)

            def _force_shape(M: np.ndarray) -> np.ndarray:
                if M.shape == (y_dim_w, x_dim_w):
                    return M.astype(np.float32)
                tmp = np.full((y_dim_w, x_dim_w), np.nan, dtype=np.float32)
                yy = min(y_dim_w, M.shape[0])
                xx = min(x_dim_w, M.shape[1])
                tmp[:yy, :xx] = M[:yy, :xx]
                return tmp

            amp_stack[i] = _force_shape(A)
            lam_stack[i] = _force_shape(L)
            ang_stack[i] = _force_shape(T)

            if has_rec and rec_stack is not None and v_rec is not None:
                R = c.get("rec_xy", None)
                if R is not None:
                    R = _force_shape(_unbin_repeat_xy(R, fup))
                    rec_stack[i] = R

        v_amp[:] = amp_stack
        v_lam[:] = lam_stack
        v_ang[:] = ang_stack
        if has_rec and v_rec is not None and rec_stack is not None:
            v_rec[:] = rec_stack


def make_output_cluster_path(input_path: str | Path) -> Path:
    p = Path(input_path)
    name = p.name
    if "_l5c_" in name:
        name = name.replace("_l5c_", "_l6c_")
    elif "_l3c_" in name:
        name = name.replace("_l3c_", "_l6c_")
    elif "_l3a_" in name:
        name = name.replace("_l3a_", "_l6a_")
    else:
        name = p.stem + "_clusters.nc"
    return p.with_name(name)


# --------------------------
# Slice pipeline
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
    cfg: Dict[str, Any],
    slice_no: int,
) -> Dict[str, Any]:
    """
    Runs processing on an extended slice (x_slice), but returns only CORE tiles for stitching.
    Figure 1 includes extra panel: wavelet reconstruction after noise filtering.
    Figure 9 has 3 panels:
      Remaining (input to CWT)
      Wavy reconstruction after noise filtering
      Reconstruction after clustering (all clusters)
    """
    outdir.mkdir(parents=True, exist_ok=True)

    min_amp = float(cfg.get("MIN_AMP"))
    thr = float(cfg.get("THR"))
    white_noise_threshold = float(cfg.get("WHITE_NOISE_THRESHOLD"))
    wps_noise_threshold = float(cfg.get("WPS_NOISE_THRESHOLD"))
    run_name = str(cfg.get("name", "run"))

    STORE_CLUSTER_RECON = True  # save per-cluster recon maps to output NetCDF

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        f = int(BIN_FACTOR)
        dx_km = DX_KM_BASE * f
        dy_km = DY_KM_BASE * f
    else:
        f = 1
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f
    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    raw_win = np.asarray(rad2d_flat[Y_SLICE, x_slice], dtype=float)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""

    if PRODUCT_TYPE == "l3a":
        label0 = "Temperature"
    else:
        label0 = "Radiance"

    quicklook_save(
        x1d_km, y1d_km, raw_win,
        f"{label0} (window, flattened){bin_tag}\n{run_name} MIN_AMP={min_amp} THR={thr}",
        outdir / "00_window.png",
    )

    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt_raw = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    if APPLY_RED_NOISE_FILTER:
        cwt, diag = apply_red_noise_filter_cwt(
            cwt_raw,
            white_noise_threshold=white_noise_threshold,
            wps_noise_threshold=wps_noise_threshold,
        )
        if SAVE_REDNOISE_DIAGNOSTICS:
            lines = []
            lines.append("Red noise filter diagnostics\n\n")
            lines.append(f"name                  = {run_name}\n")
            lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
            lines.append(f"WPS_NOISE_THRESHOLD   = {wps_noise_threshold}\n\n")
            if diag.get("skipped", False):
                lines.append(f"SKIPPED: {diag.get('reason','unknown')}\n")
            else:
                lines.append(f"n_coeff_total        = {diag.get('n_coeff_total')}\n")
                lines.append(f"n_zero_after_white   = {diag.get('n_zero_after_white')}\n")
                lines.append(f"n_zero_after_scaled  = {diag.get('n_zero_after_scaled')}\n")
                lines.append(f"sMAD_WPS min         = {diag.get('sMAD_min')}\n")
                lines.append(f"sMAD_WPS median      = {diag.get('sMAD_median')}\n")
                lines.append(f"WPS_scaled min       = {diag.get('WPS_scaled_min')}\n")
                lines.append(f"WPS_scaled median    = {diag.get('WPS_scaled_median')}\n")
                lines.append(f"WPS_scaled max       = {diag.get('WPS_scaled_max')}\n")
            (outdir / "02a_rednoise_diagnostics.txt").write_text("".join(lines))
    else:
        cwt = cwt_raw

    rec_wavy = transform.reconstruct2d(cwt)  # (nx, ny)
    wavy_xy = rec_wavy.T - np.median(rec_wavy)

    quicklook_background_decomp_4panel_save(
        x1d_km, y1d_km,
        proc0, background, remaining, remaining_tapered, TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_5panel.png",
        wavy_after_noise_xy=wavy_xy,
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=min_amp, thr=thr)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N)
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png")

    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png")

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text(
            "No clusters found.\n\n"
            f"Run name: {run_name}\n"
            f"Used MIN_AMP={min_amp}, THR={thr}\n"
            f"Used WHITE_NOISE_THRESHOLD={white_noise_threshold}, WPS_NOISE_THRESHOLD={wps_noise_threshold}\n\n"
            "Try lowering MIN_AMP or THR.\n"
            "If red noise filter is on, try lowering WPS_NOISE_THRESHOLD or WHITE_NOISE_THRESHOLD.\n"
        )
        remaining_core_xy = crop_pad_core(proc)
        nan_core = np.full_like(remaining_core_xy, np.nan)
        return {
            "has_clusters": False,
            "x_start_unbinned": core_start_unbinned,
            "dx_km": dx_km,
            "dy_km": dy_km,
            "remaining_xy": remaining_core_xy,
            "wavy_xy": nan_core,
            "rec_all_xy": nan_core,
            "cluster_records": [],
        }

    power_abs_map = {int(k): float(p) for k, p in zip(cluster_ids, P_abs)}
    power_pct_map = {int(k): float(p) for k, p in zip(cluster_ids, P_pct)}

    cluster_records: List[Dict[str, Any]] = []
    for kcl in cluster_ids.astype(int):
        kcl = int(kcl)

        A_xy, theta_xy = cluster_amp_theta_maps(
            cwt, iwave, kcl,
            amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX,
        )
        lam_xy = cluster_dominant_lambda_map(cwt, iwave, kcl, amp_mask_xy=A_xy)

        rec_core = None
        if STORE_CLUSTER_RECON:
            decomposition[:] = orig_decomp
            decomposition[iwave != kcl] = 0
            rec = transform.reconstruct2d(cwt)  # (nx, ny)
            rec_xy = rec.T
            rec_xy = rec_xy - np.nanmedian(rec_xy)
            rec_core = crop_pad_core(rec_xy)
            decomposition[:] = orig_decomp

        A_core = crop_pad_core(A_xy)
        th_core = crop_pad_core(theta_xy)
        lam_core = crop_pad_core(lam_xy)

        n_pix = int(np.count_nonzero(np.isfinite(A_core)))
        area_km2 = float(n_pix) * float(dx_km) * float(dy_km)

        cluster_records.append(
            dict(
                slice_no=int(slice_no),
                kcl=kcl,
                area_km2=area_km2,
                power_abs=power_abs_map.get(kcl, np.nan),
                power_pct=power_pct_map.get(kcl, np.nan),
                A_xy=A_core,
                lam_xy=lam_core,
                theta_xy=th_core,
                rec_xy=rec_core,
            )
        )

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    lines = []
    lines.append("Cluster power ranking (clustered only)\n\n")
    lines.append(f"name = {run_name}\n")
    lines.append(f"MIN_AMP = {min_amp}\n")
    lines.append(f"THR = {thr}\n")
    lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
    lines.append(f"WPS_NOISE_THRESHOLD = {wps_noise_threshold}\n\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))
    theta_vals = np.asarray(cwt["theta"], dtype=float)

    def plot_cluster_grid(kind: str, outname: str) -> None:
        fig, axs = plt.subplots(nrow, ncol, figsize=(12, 10))
        axs = np.atleast_1d(axs).reshape(-1)

        bg_vmin, bg_vmax = diverging_limits(bg, p_lo=2, p_hi=98)
        number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}

        for ax, kcl in zip(axs, biggest):
            decomposition[:] = orig_decomp
            decomposition[iwave != kcl] = 0
            rec = transform.reconstruct2d(cwt)
            rec_centered = rec.T - np.median(rec)

            s_idx = int(idxs[kcl][0])
            t_idx = int(idxs[kcl][1])
            _, _, lam = effective_lambda(cwt, s_idx, t_idx)

            theta_dom_rad = float(theta_vals[t_idx])
            theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

            ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
            Pk = float(P_abs_sorted[ii])
            pk = float(P_pct_sorted[ii])

            if kind == "standalone":
                ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0)
            elif kind == "overlay":
                ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
                ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0, alpha=0.6)
            else:
                raise ValueError(kind)

            ax.set_title(rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$" + "\n" + rf"P={Pk:.2e} ({pk:.1f}%)")
            ax.set_aspect("equal", adjustable="box")

        for ax in axs[n_show:]:
            ax.axis("off")
        for ax in axs[:n_show]:
            ax.set_xlabel("x (km)")
            ax.set_ylabel("y (km)")

        for i, ax in enumerate(axs, start=1):
            if ax.has_data():
                ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

        fig.tight_layout()
        save_fig(fig, outdir / outname)

    plot_cluster_grid("standalone", "05_clusters_standalone.png")
    plot_cluster_grid("overlay", "06_clusters_overlay.png")

    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
        )

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)
    decomposition[:] = orig_decomp

    remaining_after_preproc_xy = proc
    vmin, vmax = diverging_limits(remaining_after_preproc_xy, wavy_xy, rec_all_xy, p_lo=2, p_hi=98)

    figR, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(18, 8), constrained_layout=True, sharex=True, sharey=True)

    im1 = ax1.pcolormesh(x1d_km, y1d_km, remaining_after_preproc_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    ax1.set_title("Remaining (after preprocessing, input to CWT)")
    ax1.set_xlabel("x (km)")
    ax1.set_ylabel("y (km)")
    ax1.set_aspect("equal", adjustable="box")

    im2 = ax2.pcolormesh(x1d_km, y1d_km, wavy_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    ax2.set_title("Wavy stuff (wavelet reconstruction after noise filtering)")
    ax2.set_xlabel("x (km)")
    ax2.set_ylabel("y (km)")
    ax2.set_aspect("equal", adjustable="box")

    im3 = ax3.pcolormesh(x1d_km, y1d_km, rec_all_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    ax3.set_title("Reconstruction after clustering (all clusters combined)")
    ax3.set_xlabel("x (km)")
    ax3.set_ylabel("y (km)")
    ax3.set_aspect("equal", adjustable="box")

    cbar = figR.colorbar(im1, ax=[ax1, ax2, ax3], orientation="vertical", fraction=0.015, pad=0.01)
    cbar.set_label("arb")
    save_fig(figR, outdir / "09_remaining_vs_wavy_vs_allclusters.png")

    remaining_core_xy = crop_pad_core(remaining_after_preproc_xy)
    wavy_core_xy = crop_pad_core(wavy_xy)
    rec_all_core_xy = crop_pad_core(rec_all_xy)

    return {
        "has_clusters": True,
        "x_start_unbinned": core_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "remaining_xy": remaining_core_xy,
        "wavy_xy": wavy_core_xy,
        "rec_all_xy": rec_all_core_xy,
        "cluster_records": cluster_records,
    }


def stitch_and_save_final_09(slice_results: List[Dict[str, Any]], outroot: Path, tag: str) -> None:
    if not slice_results:
        return

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE

    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    wavy_stitched = np.concatenate([d["wavy_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)

    ny, nx_tot = remaining_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    vmin, vmax = diverging_limits(remaining_stitched, wavy_stitched, rec_all_stitched, p_lo=2, p_hi=98)

    figR, (axT, axM, axB) = plt.subplots(3, 1, figsize=(18, 6), constrained_layout=True, sharex=True, sharey=True)

    imT = axT.pcolormesh(x1d_km, y1d_km, remaining_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axT.set_title(f"STITCHED (core tiles) {tag}: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imM = axM.pcolormesh(x1d_km, y1d_km, wavy_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axM.set_title(f"STITCHED (core tiles) {tag}: Wavy stuff (wavelet reconstruction after noise filtering)")
    axM.set_xlabel("x (km)")
    axM.set_ylabel("y (km)")
    axM.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(x1d_km, y1d_km, rec_all_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axB.set_title(f"STITCHED (core tiles) {tag}: Reconstruction after clustering (all clusters combined)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    axT.set_xlim(600, 10000)

    cbar = figR.colorbar(imT, ax=[axT, axM, axB], orientation="vertical", fraction=0.012, pad=0.01)
    if PRODUCT_TYPE == "l3a":
        cbar.set_label("K (Relative)")
    else:
        cbar.set_label("kRayleigh (Relative)")
    save_fig(figR, outroot / f"FINAL_09_remaining_vs_wavy_vs_allclusters_STITCHED_{tag}.png")


def run_all_slices_single_offset(cfg: Dict[str, Any]) -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_frame_auto(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    x_offset = int(X_OFFSET)
    if x_offset >= nx_total:
        raise ValueError(f"X_OFFSET={x_offset} too large for nx_total={nx_total}")

    run_name = str(cfg.get("name", "run"))
    outroot = OUTPUT_ROOT / f"{run_name}_offset_{x_offset:04d}"
    outroot.mkdir(parents=True, exist_ok=True)

    (outroot / "RUN_CONFIG.txt").write_text("\n".join([f"{k} = {v}" for k, v in cfg.items()]) + "\n")

    core_starts = list(range(x_offset, nx_total, X_CHUNK))
    stitch_results: List[Dict[str, Any]] = []
    all_cluster_records: List[Dict[str, Any]] = []

    f = int(BIN_FACTOR) if (APPLY_BINNING and int(BIN_FACTOR) > 1) else 1
    y_dim = int(rad2d_flat[Y_SLICE, :].shape[0] // f)
    x_dim = int(X_CHUNK // f)

    for slice_no, core_start in enumerate(core_starts):
        core_end = min(core_start + X_CHUNK, nx_total)

        ext_start = max(0, core_start - SLICE_PAD)
        ext_end = min(nx_total, core_end + SLICE_PAD)
        x_slice = slice(ext_start, ext_end)

        outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
        print(f"[{run_name} | offset {x_offset}] core={core_start}:{core_end} ext={ext_start}:{ext_end} saved to {outdir}")

        res = run_pipeline_for_slice(
            rad2d_flat=rad2d_flat,
            x_slice=x_slice,
            outdir=outdir,
            x_start_unbinned=ext_start,
            core_start_unbinned=core_start,
            core_end_unbinned=core_end,
            cfg=cfg,
            slice_no=slice_no,
        )
        stitch_results.append(res)
        all_cluster_records.extend(res.get("cluster_records", []))

    stitch_and_save_final_09(stitch_results, outroot, tag=f"{run_name}_offset_{x_offset:04d}")
    print("Done. Outputs in", outroot.resolve())

    out_path = make_output_cluster_path(FILE_PATH)
    out_path = outroot / out_path.name

    copy_lxc_to_l6x_with_clusters(
        lxc_path=FILE_PATH,
        l6x_path=out_path,
        clusters=all_cluster_records,
        y_dim=y_dim,
        x_dim=x_dim,
        unbin_factor=(BIN_FACTOR if (APPLY_BINNING and int(BIN_FACTOR) > 1) else 1),
    )

    print("Saved output with clusters:", out_path.resolve())


for cfg in RUNS:
    run_all_slices_single_offset(cfg)
# Out:
# Detected product type: l3a
# Using RUNS: [{'name': 'base', 'MIN_AMP': 1.25, 'THR': 0.6, 'WHITE_NOISE_THRESHOLD': 0.1, 'WPS_NOISE_THRESHOLD': 8.0}]
# [base | offset 0] core=0:600 ext=0:650 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\base_offset_0000\xcore_00000_00600_xext_00000_00650
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.454059374033663 idx= (np.int64(0), np.int64(9), np.int64(196), np.int64(57))
# selected elements: 12475
# ------------
# cluster= 1
# amplitude= 2.3194660964866136 idx= (np.int64(0), np.int64(9), np.int64(221), np.int64(80))
# selected elements: 3055
# ------------
# cluster= 2
# amplitude= 2.318932102514332 idx= (np.int64(1), np.int64(8), np.int64(220), np.int64(80))
# selected elements: 13220
# ------------
# cluster= 3
# amplitude= 2.1806095538475048 idx= (np.int64(8), np.int64(0), np.int64(109), np.int64(42))
# selected elements: 120192
# ------------
# cluster= 4
# amplitude= 2.1748891418823733 idx= (np.int64(23), np.int64(0), np.int64(111), np.int64(62))
# selected elements: 107667
# ------------
# cluster= 5
# amplitude= 2.0737386328499285 idx= (np.int64(9), np.int64(8), np.int64(232), np.int64(93))
# selected elements: 43814
# ------------
# cluster= 6
# amplitude= 1.7930299193402734 idx= (np.int64(6), np.int64(8), np.int64(232), np.int64(95))
# selected elements: 1797
# ------------
# cluster= 7
# amplitude= 1.7441205517801759 idx= (np.int64(6), np.int64(10), np.int64(199), np.int64(65))
# selected elements: 6148
# ------------
# cluster= 8
# amplitude= 1.7235346946940802 idx= (np.int64(0), np.int64(10), np.int64(235), np.int64(94))
# selected elements: 981
# ------------
# cluster= 9
# amplitude= 1.6907959836116033 idx= (np.int64(1), np.int64(9), np.int64(242), np.int64(105))
# selected elements: 3035
# ------------
# cluster= 10
# amplitude= 1.6721130681933456 idx= (np.int64(7), np.int64(9), np.int64(201), np.int64(66))
# selected elements: 940
# ------------
# cluster= 11
# amplitude= 1.4301534265202822 idx= (np.int64(2), np.int64(7), np.int64(195), np.int64(76))
# selected elements: 2015
# ------------
# cluster= 12
# amplitude= 1.4109566310190358 idx= (np.int64(5), np.int64(8), np.int64(219), np.int64(80))
# selected elements: 478
# ------------
# cluster= 13
# amplitude= 1.397711036682191 idx= (np.int64(0), np.int64(9), np.int64(199), np.int64(83))
# selected elements: 128
# ------------
# cluster= 14
# amplitude= 1.3901304421389717 idx= (np.int64(9), np.int64(17), np.int64(110), np.int64(44))
# selected elements: 36171
# ------------
# cluster= 15
# amplitude= 1.3869040929227814 idx= (np.int64(16), np.int64(15), np.int64(235), np.int64(88))
# selected elements: 77172
# ------------
# cluster= 16
# amplitude= 1.3694199095809227 idx= (np.int64(23), np.int64(17), np.int64(111), np.int64(49))
# selected elements: 40625
# ------------
# cluster= 17
# amplitude= 1.3691386067290203 idx= (np.int64(0), np.int64(9), np.int64(263), np.int64(38))
# selected elements: 1295
# ------------
# cluster= 18
# amplitude= 1.3489187346755644 idx= (np.int64(3), np.int64(8), np.int64(231), np.int64(95))
# selected elements: 264
# ------------
# cluster= 19
# amplitude= 1.258423077006077 idx= (np.int64(17), np.int64(10), np.int64(145), np.int64(130))
# selected elements: 31596
# ------------
# cluster= 20
# amplitude= 1.2511680274515669 idx= (np.int64(18), np.int64(17), np.int64(109), np.int64(58))
# selected elements: 20238
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 77.55it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=600:1200 ext=550:1250 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\base_offset_0000\xcore_00600_01200_xext_00550_01250
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 6.162472426157158 idx= (np.int64(0), np.int64(0), np.int64(206), np.int64(133))
# selected elements: 159737
# ------------
# cluster= 1
# amplitude= 4.740469283329296 idx= (np.int64(0), np.int64(17), np.int64(173), np.int64(34))
# selected elements: 251417
# ------------
# cluster= 2
# amplitude= 4.663141031699864 idx= (np.int64(13), np.int64(0), np.int64(172), np.int64(119))
# selected elements: 290191
# ------------
# cluster= 3
# amplitude= 3.966653770053178 idx= (np.int64(6), np.int64(17), np.int64(171), np.int64(124))
# selected elements: 64973
# ------------
# cluster= 4
# amplitude= 3.849873911878484 idx= (np.int64(2), np.int64(15), np.int64(190), np.int64(136))
# selected elements: 14454
# ------------
# cluster= 5
# amplitude= 3.760502850715519 idx= (np.int64(7), np.int64(1), np.int64(173), np.int64(138))
# selected elements: 7403
# ------------
# cluster= 6
# amplitude= 3.7443596945977844 idx= (np.int64(0), np.int64(6), np.int64(189), np.int64(121))
# selected elements: 130683
# ------------
# cluster= 7
# amplitude= 3.5931220909404087 idx= (np.int64(21), np.int64(0), np.int64(183), np.int64(103))
# selected elements: 124283
# ------------
# cluster= 8
# amplitude= 3.570894566201768 idx= (np.int64(1), np.int64(3), np.int64(176), np.int64(66))
# selected elements: 25197
# ------------
# cluster= 9
# amplitude= 3.4830782506241325 idx= (np.int64(5), np.int64(16), np.int64(194), np.int64(17))
# selected elements: 6014
# ------------
# cluster= 10
# amplitude= 3.44520653613821 idx= (np.int64(15), np.int64(17), np.int64(195), np.int64(133))
# selected elements: 127541
# ------------
# cluster= 11
# amplitude= 3.410831939897237 idx= (np.int64(2), np.int64(8), np.int64(192), np.int64(17))
# selected elements: 27914
# ------------
# cluster= 12
# amplitude= 3.373404407422423 idx= (np.int64(0), np.int64(6), np.int64(194), np.int64(21))
# selected elements: 2228
# ------------
# cluster= 13
# amplitude= 3.1446979468158847 idx= (np.int64(6), np.int64(2), np.int64(175), np.int64(141))
# selected elements: 3412
# ------------
# cluster= 14
# amplitude= 2.9846847032022805 idx= (np.int64(9), np.int64(9), np.int64(178), np.int64(134))
# selected elements: 76468
# ------------
# cluster= 15
# amplitude= 2.920531240183633 idx= (np.int64(0), np.int64(12), np.int64(185), np.int64(107))
# selected elements: 4647
# ------------
# cluster= 16
# amplitude= 2.8872678869678006 idx= (np.int64(0), np.int64(9), np.int64(339), np.int64(54))
# selected elements: 9449
# ------------
# cluster= 17
# amplitude= 2.8272396589096713 idx= (np.int64(13), np.int64(17), np.int64(179), np.int64(129))
# selected elements: 30930
# ------------
# cluster= 18
# amplitude= 2.820998118524091 idx= (np.int64(0), np.int64(9), np.int64(50), np.int64(57))
# selected elements: 13095
# ------------
# cluster= 19
# amplitude= 2.78977050079861 idx= (np.int64(4), np.int64(4), np.int64(198), np.int64(76))
# selected elements: 37020
# ------------
# cluster= 20
# amplitude= 2.758370816540854 idx= (np.int64(6), np.int64(14), np.int64(196), np.int64(10))
# selected elements: 18938
# ------------
# cluster= 21
# amplitude= 2.7436152885585416 idx= (np.int64(8), np.int64(12), np.int64(178), np.int64(138))
# selected elements: 1041
# ------------
# cluster= 22
# amplitude= 2.690310824335044 idx= (np.int64(10), np.int64(3), np.int64(193), np.int64(134))
# selected elements: 1183
# ------------
# cluster= 23
# amplitude= 2.629094572857277 idx= (np.int64(1), np.int64(9), np.int64(174), np.int64(131))
# selected elements: 903
# ------------
# cluster= 24
# amplitude= 2.610907071619329 idx= (np.int64(2), np.int64(8), np.int64(196), np.int64(118))
# selected elements: 7876
# ------------
# cluster= 25
# amplitude= 2.605908495854061 idx= (np.int64(7), np.int64(5), np.int64(199), np.int64(11))
# selected elements: 27252
# ------------
# cluster= 26
# amplitude= 2.588068353838384 idx= (np.int64(6), np.int64(1), np.int64(206), np.int64(102))
# selected elements: 765
# ------------
# cluster= 27
# amplitude= 2.582006906880729 idx= (np.int64(1), np.int64(13), np.int64(202), np.int64(16))
# selected elements: 258
# ------------
# cluster= 28
# amplitude= 2.545181291919765 idx= (np.int64(5), np.int64(17), np.int64(205), np.int64(118))
# selected elements: 851
# ------------
# cluster= 29
# amplitude= 2.503986772374202 idx= (np.int64(5), np.int64(9), np.int64(178), np.int64(136))
# selected elements: 536
# ------------
# cluster= 30
# amplitude= 2.454277366035242 idx= (np.int64(2), np.int64(15), np.int64(193), np.int64(61))
# selected elements: 2014
# ------------
# cluster= 31
# amplitude= 2.4420590647717946 idx= (np.int64(3), np.int64(3), np.int64(202), np.int64(26))
# selected elements: 1515
# ------------
# cluster= 32
# amplitude= 2.4322435984636024 idx= (np.int64(13), np.int64(3), np.int64(196), np.int64(140))
# selected elements: 7825
# ------------
# cluster= 33
# amplitude= 2.4011917763498096 idx= (np.int64(6), np.int64(8), np.int64(175), np.int64(84))
# selected elements: 5331
# ------------
# cluster= 34
# amplitude= 2.3902543163471917 idx= (np.int64(5), np.int64(3), np.int64(175), np.int64(141))
# selected elements: 608
# ------------
# cluster= 35
# amplitude= 2.3467863242620184 idx= (np.int64(0), np.int64(4), np.int64(181), np.int64(43))
# selected elements: 144
# ------------
# cluster= 36
# amplitude= 2.3261911762144223 idx= (np.int64(9), np.int64(10), np.int64(196), np.int64(49))
# selected elements: 74640
# ------------
# cluster= 37
# amplitude= 2.308860181961533 idx= (np.int64(3), np.int64(17), np.int64(203), np.int64(89))
# selected elements: 572
# ------------
# cluster= 38
# amplitude= 2.2865493926736256 idx= (np.int64(6), np.int64(10), np.int64(200), np.int64(118))
# selected elements: 3609
# ------------
# cluster= 39
# amplitude= 2.2483634323741937 idx= (np.int64(14), np.int64(4), np.int64(196), np.int64(139))
# selected elements: 3197
# ------------
# cluster= 40
# amplitude= 2.2482230701205026 idx= (np.int64(8), np.int64(15), np.int64(189), np.int64(115))
# selected elements: 2069
# ------------
# cluster= 41
# amplitude= 2.2441081487356076 idx= (np.int64(5), np.int64(13), np.int64(196), np.int64(82))
# selected elements: 4251
# ------------
# cluster= 42
# amplitude= 2.2327774065658583 idx= (np.int64(9), np.int64(4), np.int64(193), np.int64(134))
# selected elements: 2762
# ------------
# cluster= 43
# amplitude= 2.2309436543914285 idx= (np.int64(7), np.int64(16), np.int64(185), np.int64(66))
# selected elements: 988
# ------------
# cluster= 44
# amplitude= 2.179226573324915 idx= (np.int64(2), np.int64(6), np.int64(193), np.int64(140))
# selected elements: 333
# ------------
# cluster= 45
# amplitude= 2.1260496933317454 idx= (np.int64(9), np.int64(7), np.int64(187), np.int64(50))
# selected elements: 3615
# ------------
# cluster= 46
# amplitude= 2.12238202222306 idx= (np.int64(7), np.int64(11), np.int64(199), np.int64(117))
# selected elements: 1419
# ------------
# cluster= 47
# amplitude= 2.068849439239634 idx= (np.int64(6), np.int64(7), np.int64(201), np.int64(11))
# selected elements: 2030
# ------------
# cluster= 48
# amplitude= 2.050199637080872 idx= (np.int64(8), np.int64(8), np.int64(178), np.int64(80))
# selected elements: 1170
# ------------
# cluster= 49
# amplitude= 2.0377332946979316 idx= (np.int64(4), np.int64(13), np.int64(191), np.int64(63))
# selected elements: 461
# ------------
# cluster= 50
# amplitude= 2.0264926059364408 idx= (np.int64(13), np.int64(2), np.int64(193), np.int64(9))
# selected elements: 12386
# ------------
# cluster= 51
# amplitude= 2.001442792864571 idx= (np.int64(7), np.int64(2), np.int64(195), np.int64(129))
# selected elements: 1551
# ------------
# cluster= 52
# amplitude= 1.9955062214919095 idx= (np.int64(5), np.int64(2), np.int64(201), np.int64(51))
# selected elements: 3207
# ------------
# cluster= 53
# amplitude= 1.9747637041998238 idx= (np.int64(4), np.int64(10), np.int64(172), np.int64(138))
# selected elements: 326
# ------------
# cluster= 54
# amplitude= 1.950773573484814 idx= (np.int64(1), np.int64(4), np.int64(177), np.int64(8))
# selected elements: 1793
# ------------
# cluster= 55
# amplitude= 1.9318362963806663 idx= (np.int64(11), np.int64(3), np.int64(192), np.int64(8))
# selected elements: 3220
# ------------
# cluster= 56
# amplitude= 1.9230730851003641 idx= (np.int64(11), np.int64(15), np.int64(190), np.int64(141))
# selected elements: 4423
# ------------
# cluster= 57
# amplitude= 1.9097038910387798 idx= (np.int64(6), np.int64(12), np.int64(181), np.int64(66))
# selected elements: 4952
# ------------
# cluster= 58
# amplitude= 1.8933388600576504 idx= (np.int64(2), np.int64(6), np.int64(195), np.int64(90))
# selected elements: 232
# ------------
# cluster= 59
# amplitude= 1.8912938243973636 idx= (np.int64(2), np.int64(14), np.int64(200), np.int64(8))
# selected elements: 267
# ------------
# cluster= 60
# amplitude= 1.8770694333052564 idx= (np.int64(11), np.int64(16), np.int64(196), np.int64(116))
# selected elements: 1923
# ------------
# cluster= 61
# amplitude= 1.8747832219721978 idx= (np.int64(7), np.int64(16), np.int64(200), np.int64(35))
# selected elements: 489
# ------------
# cluster= 62
# amplitude= 1.8735190069827816 idx= (np.int64(1), np.int64(2), np.int64(169), np.int64(142))
# selected elements: 98
# ------------
# cluster= 63
# amplitude= 1.8622513074255822 idx= (np.int64(12), np.int64(13), np.int64(183), np.int64(136))
# selected elements: 7280
# ------------
# cluster= 64
# amplitude= 1.8420875656526312 idx= (np.int64(5), np.int64(13), np.int64(189), np.int64(140))
# selected elements: 1071
# ------------
# cluster= 65
# amplitude= 1.8303731825705605 idx= (np.int64(0), np.int64(7), np.int64(173), np.int64(23))
# selected elements: 350
# ------------
# cluster= 66
# amplitude= 1.82924435635829 idx= (np.int64(2), np.int64(12), np.int64(189), np.int64(141))
# selected elements: 924
# ------------
# cluster= 67
# amplitude= 1.8077559205033 idx= (np.int64(2), np.int64(3), np.int64(170), np.int64(141))
# selected elements: 271
# ------------
# cluster= 68
# amplitude= 1.7989295902181457 idx= (np.int64(9), np.int64(3), np.int64(186), np.int64(66))
# selected elements: 3311
# ------------
# cluster= 69
# amplitude= 1.786669777433812 idx= (np.int64(11), np.int64(10), np.int64(199), np.int64(23))
# selected elements: 1269
# ------------
# cluster= 70
# amplitude= 1.7799093336170628 idx= (np.int64(10), np.int64(0), np.int64(190), np.int64(12))
# selected elements: 450
# ------------
# cluster= 71
# amplitude= 1.7244014701491701 idx= (np.int64(7), np.int64(12), np.int64(200), np.int64(82))
# selected elements: 1309
# ------------
# cluster= 72
# amplitude= 1.7160841790992438 idx= (np.int64(7), np.int64(11), np.int64(179), np.int64(67))
# selected elements: 509
# ------------
# cluster= 73
# amplitude= 1.701114367332867 idx= (np.int64(15), np.int64(16), np.int64(198), np.int64(19))
# selected elements: 7779
# ------------
# cluster= 74
# amplitude= 1.6707467885661653 idx= (np.int64(2), np.int64(2), np.int64(190), np.int64(8))
# selected elements: 563
# ------------
# cluster= 75
# amplitude= 1.6631289053737108 idx= (np.int64(4), np.int64(4), np.int64(173), np.int64(144))
# selected elements: 405
# ------------
# cluster= 76
# amplitude= 1.6584979673366997 idx= (np.int64(0), np.int64(3), np.int64(341), np.int64(52))
# selected elements: 1560
# ------------
# cluster= 77
# amplitude= 1.6514833458159441 idx= (np.int64(3), np.int64(10), np.int64(337), np.int64(64))
# selected elements: 1120
# ------------
# cluster= 78
# amplitude= 1.6474798951761573 idx= (np.int64(11), np.int64(2), np.int64(188), np.int64(67))
# selected elements: 3109
# ------------
# cluster= 79
# amplitude= 1.6425751420910775 idx= (np.int64(12), np.int64(3), np.int64(187), np.int64(68))
# selected elements: 2305
# ------------
# cluster= 80
# amplitude= 1.6023500391846146 idx= (np.int64(7), np.int64(17), np.int64(169), np.int64(15))
# selected elements: 510
# ------------
# cluster= 81
# amplitude= 1.6009297652331234 idx= (np.int64(8), np.int64(15), np.int64(169), np.int64(91))
# selected elements: 439
# ------------
# cluster= 82
# amplitude= 1.5785697199603654 idx= (np.int64(10), np.int64(13), np.int64(201), np.int64(14))
# selected elements: 1550
# ------------
# cluster= 83
# amplitude= 1.5772030570923394 idx= (np.int64(8), np.int64(15), np.int64(184), np.int64(64))
# selected elements: 966
# ------------
# cluster= 84
# amplitude= 1.5711891531875097 idx= (np.int64(14), np.int64(12), np.int64(196), np.int64(24))
# selected elements: 2181
# ------------
# cluster= 85
# amplitude= 1.5592558142929176 idx= (np.int64(6), np.int64(1), np.int64(166), np.int64(13))
# selected elements: 765
# ------------
# cluster= 86
# amplitude= 1.5440939924167347 idx= (np.int64(2), np.int64(7), np.int64(302), np.int64(44))
# selected elements: 4198
# ------------
# cluster= 87
# amplitude= 1.5428771805568238 idx= (np.int64(1), np.int64(2), np.int64(205), np.int64(97))
# selected elements: 156
# ------------
# cluster= 88
# amplitude= 1.5372422288840808 idx= (np.int64(1), np.int64(9), np.int64(70), np.int64(11))
# selected elements: 3382
# ------------
# cluster= 89
# amplitude= 1.5330026886203194 idx= (np.int64(0), np.int64(13), np.int64(206), np.int64(131))
# selected elements: 238
# ------------
# cluster= 90
# amplitude= 1.5114435491815434 idx= (np.int64(11), np.int64(8), np.int64(182), np.int64(47))
# selected elements: 3497
# ------------
# cluster= 91
# amplitude= 1.510001777319971 idx= (np.int64(3), np.int64(13), np.int64(174), np.int64(118))
# selected elements: 582
# ------------
# cluster= 92
# amplitude= 1.4959868218624603 idx= (np.int64(2), np.int64(14), np.int64(200), np.int64(36))
# selected elements: 641
# ------------
# cluster= 93
# amplitude= 1.467637621234605 idx= (np.int64(10), np.int64(16), np.int64(185), np.int64(67))
# selected elements: 1809
# ------------
# cluster= 94
# amplitude= 1.4581864974849514 idx= (np.int64(4), np.int64(4), np.int64(187), np.int64(22))
# selected elements: 293
# ------------
# cluster= 95
# amplitude= 1.4543652820575355 idx= (np.int64(17), np.int64(17), np.int64(163), np.int64(109))
# selected elements: 2918
# ------------
# cluster= 96
# amplitude= 1.4524644953309465 idx= (np.int64(3), np.int64(8), np.int64(177), np.int64(84))
# selected elements: 235
# ------------
# cluster= 97
# amplitude= 1.4497062484823526 idx= (np.int64(1), np.int64(11), np.int64(336), np.int64(64))
# selected elements: 776
# ------------
# cluster= 98
# amplitude= 1.4432516169940728 idx= (np.int64(1), np.int64(17), np.int64(115), np.int64(140))
# selected elements: 1795
# ------------
# cluster= 99
# amplitude= 1.4404598354890452 idx= (np.int64(10), np.int64(17), np.int64(190), np.int64(10))
# selected elements: 1106
# ------------
# cluster= 100
# amplitude= 1.4372590875470956 idx= (np.int64(2), np.int64(0), np.int64(115), np.int64(140))
# selected elements: 3058
# ------------
# cluster= 101
# amplitude= 1.4270623682184385 idx= (np.int64(0), np.int64(12), np.int64(174), np.int64(7))
# selected elements: 178
# ------------
# cluster= 102
# amplitude= 1.4075916153713128 idx= (np.int64(6), np.int64(9), np.int64(201), np.int64(22))
# selected elements: 197
# ------------
# cluster= 103
# amplitude= 1.3957301173563648 idx= (np.int64(13), np.int64(15), np.int64(199), np.int64(118))
# selected elements: 1771
# ------------
# cluster= 104
# amplitude= 1.3872774908187897 idx= (np.int64(6), np.int64(16), np.int64(173), np.int64(11))
# selected elements: 344
# ------------
# cluster= 105
# amplitude= 1.3854807233976205 idx= (np.int64(3), np.int64(8), np.int64(207), np.int64(46))
# selected elements: 682
# ------------
# cluster= 106
# amplitude= 1.3746857085801354 idx= (np.int64(13), np.int64(14), np.int64(184), np.int64(92))
# selected elements: 3080
# ------------
# cluster= 107
# amplitude= 1.3692001954273378 idx= (np.int64(7), np.int64(16), np.int64(170), np.int64(44))
# selected elements: 265
# ------------
# cluster= 108
# amplitude= 1.3630121079006827 idx= (np.int64(0), np.int64(3), np.int64(203), np.int64(118))
# selected elements: 72
# ------------
# cluster= 109
# amplitude= 1.3583064639592783 idx= (np.int64(6), np.int64(11), np.int64(178), np.int64(7))
# selected elements: 686
# ------------
# cluster= 110
# amplitude= 1.3564285319303049 idx= (np.int64(6), np.int64(12), np.int64(179), np.int64(98))
# selected elements: 321
# ------------
# cluster= 111
# amplitude= 1.3471119190491134 idx= (np.int64(13), np.int64(5), np.int64(179), np.int64(28))
# selected elements: 3995
# ------------
# cluster= 112
# amplitude= 1.3395027475314547 idx= (np.int64(12), np.int64(6), np.int64(194), np.int64(127))
# selected elements: 3452
# ------------
# cluster= 113
# amplitude= 1.3253128915562018 idx= (np.int64(7), np.int64(14), np.int64(74), np.int64(41))
# selected elements: 6108
# ------------
# cluster= 114
# amplitude= 1.31794150253292 idx= (np.int64(3), np.int64(13), np.int64(174), np.int64(74))
# selected elements: 219
# ------------
# cluster= 115
# amplitude= 1.3029100751268536 idx= (np.int64(9), np.int64(10), np.int64(320), np.int64(55))
# selected elements: 9047
# ------------
# cluster= 116
# amplitude= 1.2917796183690091 idx= (np.int64(12), np.int64(16), np.int64(202), np.int64(14))
# selected elements: 1194
# ------------
# cluster= 117
# amplitude= 1.2824540362838863 idx= (np.int64(14), np.int64(4), np.int64(176), np.int64(21))
# selected elements: 1591
# ------------
# cluster= 118
# amplitude= 1.266094503901055 idx= (np.int64(3), np.int64(1), np.int64(188), np.int64(6))
# selected elements: 95
# ------------
# cluster= 119
# amplitude= 1.2575596606055204 idx= (np.int64(6), np.int64(6), np.int64(177), np.int64(141))
# selected elements: 1166
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 81.78it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=1200:1800 ext=1150:1850 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\base_offset_0000\xcore_01200_01800_xext_01150_01850
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 10.464151036646724 idx= (np.int64(0), np.int64(9), np.int64(115), np.int64(86))
# selected elements: 211624
# ------------
# cluster= 1
# amplitude= 10.280752669215683 idx= (np.int64(0), np.int64(9), np.int64(68), np.int64(38))
# selected elements: 5250
# ------------
# cluster= 2
# amplitude= 9.696332144252237 idx= (np.int64(2), np.int64(8), np.int64(69), np.int64(40))
# selected elements: 4891
# ------------
# cluster= 3
# amplitude= 6.829409086204234 idx= (np.int64(2), np.int64(8), np.int64(120), np.int64(62))
# selected elements: 1027
# ------------
# cluster= 4
# amplitude= 6.680439181815352 idx= (np.int64(1), np.int64(7), np.int64(119), np.int64(60))
# selected elements: 63993
# ------------
# cluster= 5
# amplitude= 6.552128726104207 idx= (np.int64(3), np.int64(10), np.int64(108), np.int64(38))
# selected elements: 66040
# ------------
# cluster= 6
# amplitude= 6.391336732317634 idx= (np.int64(5), np.int64(9), np.int64(68), np.int64(43))
# selected elements: 4159
# ------------
# cluster= 7
# amplitude= 6.329648703527018 idx= (np.int64(6), np.int64(8), np.int64(71), np.int64(42))
# selected elements: 664775
# ------------
# cluster= 8
# amplitude= 5.983645249662034 idx= (np.int64(4), np.int64(7), np.int64(70), np.int64(42))
# selected elements: 2527
# ------------
# cluster= 9
# amplitude= 5.909281974878818 idx= (np.int64(0), np.int64(6), np.int64(58), np.int64(46))
# selected elements: 1187
# ------------
# cluster= 10
# amplitude= 5.771109364306095 idx= (np.int64(0), np.int64(11), np.int64(117), np.int64(24))
# selected elements: 4874
# ------------
# cluster= 11
# amplitude= 5.411884930283241 idx= (np.int64(1), np.int64(8), np.int64(114), np.int64(121))
# selected elements: 6525
# ------------
# cluster= 12
# amplitude= 5.1640340991319 idx= (np.int64(3), np.int64(9), np.int64(119), np.int64(63))
# selected elements: 1290
# ------------
# cluster= 13
# amplitude= 4.98355171119961 idx= (np.int64(0), np.int64(6), np.int64(119), np.int64(59))
# selected elements: 374
# ------------
# cluster= 14
# amplitude= 4.952753912533702 idx= (np.int64(5), np.int64(9), np.int64(112), np.int64(122))
# selected elements: 42112
# ------------
# cluster= 15
# amplitude= 4.899615900903196 idx= (np.int64(7), np.int64(10), np.int64(115), np.int64(29))
# selected elements: 24026
# ------------
# cluster= 16
# amplitude= 4.809941053832554 idx= (np.int64(6), np.int64(11), np.int64(114), np.int64(122))
# selected elements: 30470
# ------------
# cluster= 17
# amplitude= 4.759446520583687 idx= (np.int64(1), np.int64(11), np.int64(100), np.int64(106))
# selected elements: 1043
# ------------
# cluster= 18
# amplitude= 4.7228180853819275 idx= (np.int64(1), np.int64(6), np.int64(112), np.int64(23))
# selected elements: 2978
# ------------
# cluster= 19
# amplitude= 4.633921795937043 idx= (np.int64(0), np.int64(2), np.int64(227), np.int64(9))
# selected elements: 15732
# ------------
# cluster= 20
# amplitude= 4.633721926626189 idx= (np.int64(1), np.int64(3), np.int64(226), np.int64(10))
# selected elements: 3453
# ------------
# cluster= 21
# amplitude= 4.444920475161228 idx= (np.int64(8), np.int64(8), np.int64(113), np.int64(121))
# selected elements: 27566
# ------------
# cluster= 22
# amplitude= 4.427554862237872 idx= (np.int64(2), np.int64(1), np.int64(154), np.int64(14))
# selected elements: 30312
# ------------
# cluster= 23
# amplitude= 4.329127662491627 idx= (np.int64(2), np.int64(12), np.int64(116), np.int64(62))
# selected elements: 587
# ------------
# cluster= 24
# amplitude= 4.2762573046557515 idx= (np.int64(1), np.int64(17), np.int64(118), np.int64(86))
# selected elements: 4287
# ------------
# cluster= 25
# amplitude= 4.224289340497045 idx= (np.int64(2), np.int64(11), np.int64(114), np.int64(121))
# selected elements: 964
# ------------
# cluster= 26
# amplitude= 4.2224313516666925 idx= (np.int64(4), np.int64(9), np.int64(150), np.int64(18))
# selected elements: 4085
# ------------
# cluster= 27
# amplitude= 4.1779189624188255 idx= (np.int64(1), np.int64(9), np.int64(227), np.int64(21))
# selected elements: 32309
# ------------
# cluster= 28
# amplitude= 4.157157967165096 idx= (np.int64(1), np.int64(8), np.int64(186), np.int64(47))
# selected elements: 7200
# ------------
# cluster= 29
# amplitude= 4.124982489505944 idx= (np.int64(4), np.int64(7), np.int64(116), np.int64(121))
# selected elements: 5499
# ------------
# cluster= 30
# amplitude= 4.001546769418464 idx= (np.int64(4), np.int64(17), np.int64(151), np.int64(15))
# selected elements: 22146
# ------------
# cluster= 31
# amplitude= 3.953486668287036 idx= (np.int64(5), np.int64(10), np.int64(230), np.int64(14))
# selected elements: 28824
# ------------
# cluster= 32
# amplitude= 3.918579274157316 idx= (np.int64(0), np.int64(0), np.int64(71), np.int64(45))
# selected elements: 7534
# ------------
# cluster= 33
# amplitude= 3.889369874612972 idx= (np.int64(2), np.int64(6), np.int64(57), np.int64(45))
# selected elements: 348
# ------------
# cluster= 34
# amplitude= 3.752983976766822 idx= (np.int64(2), np.int64(17), np.int64(149), np.int64(16))
# selected elements: 3059
# ------------
# cluster= 35
# amplitude= 3.730670300995521 idx= (np.int64(0), np.int64(13), np.int64(58), np.int64(45))
# selected elements: 9276
# ------------
# cluster= 36
# amplitude= 3.6733684771351736 idx= (np.int64(2), np.int64(10), np.int64(152), np.int64(16))
# selected elements: 3881
# ------------
# cluster= 37
# amplitude= 3.5980177754164373 idx= (np.int64(2), np.int64(0), np.int64(118), np.int64(86))
# selected elements: 3319
# ------------
# cluster= 38
# amplitude= 3.546571861634189 idx= (np.int64(6), np.int64(10), np.int64(66), np.int64(45))
# selected elements: 3657
# ------------
# cluster= 39
# amplitude= 3.536119158977912 idx= (np.int64(3), np.int64(3), np.int64(107), np.int64(26))
# selected elements: 7552
# ------------
# cluster= 40
# amplitude= 3.4621045976938554 idx= (np.int64(10), np.int64(8), np.int64(112), np.int64(121))
# selected elements: 3133
# ------------
# cluster= 41
# amplitude= 3.383527023880417 idx= (np.int64(7), np.int64(8), np.int64(117), np.int64(26))
# selected elements: 5652
# ------------
# cluster= 42
# amplitude= 3.3628552535738105 idx= (np.int64(14), np.int64(9), np.int64(66), np.int64(43))
# selected elements: 123990
# ------------
# cluster= 43
# amplitude= 3.3591267715678055 idx= (np.int64(0), np.int64(14), np.int64(152), np.int64(14))
# selected elements: 1017
# ------------
# cluster= 44
# amplitude= 3.337103224175027 idx= (np.int64(3), np.int64(8), np.int64(186), np.int64(47))
# selected elements: 1901
# ------------
# cluster= 45
# amplitude= 3.2531492930596073 idx= (np.int64(9), np.int64(7), np.int64(116), np.int64(28))
# selected elements: 23604
# ------------
# cluster= 46
# amplitude= 3.248555477736665 idx= (np.int64(0), np.int64(15), np.int64(112), np.int64(122))
# selected elements: 8896
# ------------
# cluster= 47
# amplitude= 3.245357213452362 idx= (np.int64(0), np.int64(12), np.int64(78), np.int64(36))
# selected elements: 294
# ------------
# cluster= 48
# amplitude= 3.152378452047007 idx= (np.int64(3), np.int64(15), np.int64(114), np.int64(10))
# selected elements: 594
# ------------
# cluster= 49
# amplitude= 3.1383644268861035 idx= (np.int64(0), np.int64(12), np.int64(132), np.int64(124))
# selected elements: 1741
# ------------
# cluster= 50
# amplitude= 3.112448081679755 idx= (np.int64(5), np.int64(14), np.int64(112), np.int64(36))
# selected elements: 8233
# ------------
# cluster= 51
# amplitude= 3.104530580929933 idx= (np.int64(0), np.int64(9), np.int64(154), np.int64(74))
# selected elements: 6094
# ------------
# cluster= 52
# amplitude= 3.0955298360606363 idx= (np.int64(0), np.int64(17), np.int64(70), np.int64(44))
# selected elements: 1407
# ------------
# cluster= 53
# amplitude= 3.074034336186875 idx= (np.int64(0), np.int64(17), np.int64(126), np.int64(20))
# selected elements: 403
# ------------
# cluster= 54
# amplitude= 3.0733251152742023 idx= (np.int64(10), np.int64(11), np.int64(114), np.int64(121))
# selected elements: 6526
# ------------
# cluster= 55
# amplitude= 3.031049097017635 idx= (np.int64(4), np.int64(11), np.int64(151), np.int64(17))
# selected elements: 716
# ------------
# cluster= 56
# amplitude= 3.0299183539223766 idx= (np.int64(0), np.int64(1), np.int64(116), np.int64(38))
# selected elements: 649
# ------------
# cluster= 57
# amplitude= 3.0125429701046014 idx= (np.int64(7), np.int64(4), np.int64(115), np.int64(29))
# selected elements: 1965
# ------------
# cluster= 58
# amplitude= 2.99919666566612 idx= (np.int64(1), np.int64(5), np.int64(99), np.int64(118))
# selected elements: 1079
# ------------
# cluster= 59
# amplitude= 2.954999539994224 idx= (np.int64(3), np.int64(16), np.int64(98), np.int64(116))
# selected elements: 1467
# ------------
# cluster= 60
# amplitude= 2.951218832615376 idx= (np.int64(6), np.int64(15), np.int64(113), np.int64(36))
# selected elements: 7410
# ------------
# cluster= 61
# amplitude= 2.923188874978813 idx= (np.int64(5), np.int64(2), np.int64(124), np.int64(123))
# selected elements: 959
# ------------
# cluster= 62
# amplitude= 2.88750018081234 idx= (np.int64(5), np.int64(9), np.int64(98), np.int64(105))
# selected elements: 1129
# ------------
# cluster= 63
# amplitude= 2.8551773606289337 idx= (np.int64(0), np.int64(13), np.int64(115), np.int64(64))
# selected elements: 820
# ------------
# cluster= 64
# amplitude= 2.8019000508267458 idx= (np.int64(4), np.int64(14), np.int64(69), np.int64(40))
# selected elements: 4077
# ------------
# cluster= 65
# amplitude= 2.793487473221203 idx= (np.int64(1), np.int64(8), np.int64(100), np.int64(106))
# selected elements: 321
# ------------
# cluster= 66
# amplitude= 2.79179777069024 idx= (np.int64(4), np.int64(1), np.int64(124), np.int64(124))
# selected elements: 2106
# ------------
# cluster= 67
# amplitude= 2.7896491374063026 idx= (np.int64(0), np.int64(16), np.int64(107), np.int64(111))
# selected elements: 165
# ------------
# cluster= 68
# amplitude= 2.7776079374050155 idx= (np.int64(6), np.int64(7), np.int64(120), np.int64(84))
# selected elements: 3855
# ------------
# cluster= 69
# amplitude= 2.7664035007682135 idx= (np.int64(2), np.int64(12), np.int64(79), np.int64(36))
# selected elements: 998
# ------------
# cluster= 70
# amplitude= 2.759384713442066 idx= (np.int64(0), np.int64(8), np.int64(79), np.int64(87))
# selected elements: 1468
# ------------
# cluster= 71
# amplitude= 2.758009034145775 idx= (np.int64(0), np.int64(3), np.int64(112), np.int64(122))
# selected elements: 1640
# ------------
# cluster= 72
# amplitude= 2.7511122268203008 idx= (np.int64(1), np.int64(3), np.int64(95), np.int64(67))
# selected elements: 863
# ------------
# cluster= 73
# amplitude= 2.744966998650917 idx= (np.int64(3), np.int64(13), np.int64(68), np.int64(41))
# selected elements: 644
# ------------
# cluster= 74
# amplitude= 2.7405394511431425 idx= (np.int64(2), np.int64(11), np.int64(96), np.int64(71))
# selected elements: 2158
# ------------
# cluster= 75
# amplitude= 2.7396250225304097 idx= (np.int64(3), np.int64(16), np.int64(65), np.int64(38))
# selected elements: 996
# ------------
# cluster= 76
# amplitude= 2.7149996720782594 idx= (np.int64(5), np.int64(13), np.int64(76), np.int64(37))
# selected elements: 5669
# ------------
# cluster= 77
# amplitude= 2.7042927235735648 idx= (np.int64(1), np.int64(6), np.int64(113), np.int64(39))
# selected elements: 120
# ------------
# cluster= 78
# amplitude= 2.697841450994366 idx= (np.int64(0), np.int64(2), np.int64(104), np.int64(27))
# selected elements: 115
# ------------
# cluster= 79
# amplitude= 2.6915250326254436 idx= (np.int64(0), np.int64(16), np.int64(67), np.int64(38))
# selected elements: 968
# ------------
# cluster= 80
# amplitude= 2.68166525758395 idx= (np.int64(0), np.int64(3), np.int64(126), np.int64(123))
# selected elements: 249
# ------------
# cluster= 81
# amplitude= 2.6810922295451043 idx= (np.int64(5), np.int64(1), np.int64(107), np.int64(29))
# selected elements: 5822
# ------------
# cluster= 82
# amplitude= 2.6424400387306273 idx= (np.int64(0), np.int64(9), np.int64(218), np.int64(104))
# selected elements: 5153
# ------------
# cluster= 83
# amplitude= 2.6376866424971492 idx= (np.int64(0), np.int64(5), np.int64(227), np.int64(20))
# selected elements: 412
# ------------
# cluster= 84
# amplitude= 2.6364200819607655 idx= (np.int64(0), np.int64(2), np.int64(83), np.int64(42))
# selected elements: 204
# ------------
# cluster= 85
# amplitude= 2.6178440589727217 idx= (np.int64(0), np.int64(14), np.int64(103), np.int64(34))
# selected elements: 440
# ------------
# cluster= 86
# amplitude= 2.6165414318028692 idx= (np.int64(4), np.int64(3), np.int64(124), np.int64(123))
# selected elements: 1762
# ------------
# cluster= 87
# amplitude= 2.6155173926572965 idx= (np.int64(0), np.int64(17), np.int64(106), np.int64(36))
# selected elements: 1434
# ------------
# cluster= 88
# amplitude= 2.599595115531732 idx= (np.int64(0), np.int64(1), np.int64(221), np.int64(100))
# selected elements: 2429
# ------------
# cluster= 89
# amplitude= 2.599073457204832 idx= (np.int64(1), np.int64(14), np.int64(94), np.int64(70))
# selected elements: 4908
# ------------
# cluster= 90
# amplitude= 2.5976541875458605 idx= (np.int64(0), np.int64(1), np.int64(226), np.int64(31))
# selected elements: 491
# ------------
# cluster= 91
# amplitude= 2.5848335007705523 idx= (np.int64(0), np.int64(12), np.int64(188), np.int64(47))
# selected elements: 1680
# ------------
# cluster= 92
# amplitude= 2.5758214684376814 idx= (np.int64(0), np.int64(11), np.int64(231), np.int64(9))
# selected elements: 5566
# ------------
# cluster= 93
# amplitude= 2.5745070383633233 idx= (np.int64(0), np.int64(1), np.int64(122), np.int64(90))
# selected elements: 765
# ------------
# cluster= 94
# amplitude= 2.5720967717856222 idx= (np.int64(0), np.int64(17), np.int64(56), np.int64(48))
# selected elements: 297
# ------------
# cluster= 95
# amplitude= 2.5446330375503194 idx= (np.int64(5), np.int64(15), np.int64(69), np.int64(39))
# selected elements: 3475
# ------------
# cluster= 96
# amplitude= 2.523569712701059 idx= (np.int64(0), np.int64(15), np.int64(149), np.int64(116))
# selected elements: 1022
# ------------
# cluster= 97
# amplitude= 2.5211788339651675 idx= (np.int64(7), np.int64(9), np.int64(226), np.int64(140))
# selected elements: 23416
# ------------
# cluster= 98
# amplitude= 2.5123120307599485 idx= (np.int64(0), np.int64(3), np.int64(44), np.int64(50))
# selected elements: 2045
# ------------
# cluster= 99
# amplitude= 2.51207795960244 idx= (np.int64(1), np.int64(17), np.int64(113), np.int64(9))
# selected elements: 368
# ------------
# cluster= 100
# amplitude= 2.4861360420565046 idx= (np.int64(3), np.int64(14), np.int64(117), np.int64(87))
# selected elements: 5009
# ------------
# cluster= 101
# amplitude= 2.4699150907872127 idx= (np.int64(1), np.int64(15), np.int64(67), np.int64(39))
# selected elements: 423
# ------------
# cluster= 102
# amplitude= 2.4694940802775625 idx= (np.int64(0), np.int64(1), np.int64(110), np.int64(11))
# selected elements: 1004
# ------------
# cluster= 103
# amplitude= 2.4639780314006625 idx= (np.int64(3), np.int64(11), np.int64(116), np.int64(8))
# selected elements: 923
# ------------
# cluster= 104
# amplitude= 2.4530135689721106 idx= (np.int64(0), np.int64(9), np.int64(90), np.int64(64))
# selected elements: 303
# ------------
# cluster= 105
# amplitude= 2.4490569955601504 idx= (np.int64(4), np.int64(11), np.int64(100), np.int64(105))
# selected elements: 731
# ------------
# cluster= 106
# amplitude= 2.447216254490396 idx= (np.int64(5), np.int64(15), np.int64(97), np.int64(116))
# selected elements: 490
# ------------
# cluster= 107
# amplitude= 2.431609557925322 idx= (np.int64(0), np.int64(2), np.int64(147), np.int64(115))
# selected elements: 4154
# ------------
# cluster= 108
# amplitude= 2.4315746166860834 idx= (np.int64(2), np.int64(14), np.int64(113), np.int64(9))
# selected elements: 641
# ------------
# cluster= 109
# amplitude= 2.4275955775614353 idx= (np.int64(11), np.int64(8), np.int64(151), np.int64(12))
# selected elements: 27665
# ------------
# cluster= 110
# amplitude= 2.4235033788915215 idx= (np.int64(3), np.int64(17), np.int64(113), np.int64(9))
# selected elements: 634
# ------------
# cluster= 111
# amplitude= 2.4097189351088057 idx= (np.int64(5), np.int64(9), np.int64(64), np.int64(14))
# selected elements: 1377
# ------------
# cluster= 112
# amplitude= 2.3858292586661087 idx= (np.int64(1), np.int64(2), np.int64(126), np.int64(123))
# selected elements: 122
# ------------
# cluster= 113
# amplitude= 2.37969596793921 idx= (np.int64(0), np.int64(9), np.int64(160), np.int64(50))
# selected elements: 584
# ------------
# cluster= 114
# amplitude= 2.3761257475581625 idx= (np.int64(0), np.int64(7), np.int64(150), np.int64(20))
# selected elements: 995
# ------------
# cluster= 115
# amplitude= 2.3695684444047336 idx= (np.int64(9), np.int64(16), np.int64(104), np.int64(114))
# selected elements: 13774
# ------------
# cluster= 116
# amplitude= 2.3677556692877952 idx= (np.int64(2), np.int64(9), np.int64(311), np.int64(16))
# selected elements: 6187
# ------------
# cluster= 117
# amplitude= 2.367323013983446 idx= (np.int64(8), np.int64(2), np.int64(107), np.int64(26))
# selected elements: 865
# ------------
# cluster= 118
# amplitude= 2.366822827359781 idx= (np.int64(4), np.int64(9), np.int64(259), np.int64(17))
# selected elements: 13019
# ------------
# cluster= 119
# amplitude= 2.3636368390714724 idx= (np.int64(0), np.int64(1), np.int64(208), np.int64(28))
# selected elements: 1514
# ------------
# cluster= 120
# amplitude= 2.357357744306098 idx= (np.int64(1), np.int64(2), np.int64(226), np.int64(31))
# selected elements: 4021
# ------------
# cluster= 121
# amplitude= 2.3459699494856596 idx= (np.int64(2), np.int64(7), np.int64(229), np.int64(30))
# selected elements: 1264
# ------------
# cluster= 122
# amplitude= 2.3414081426024027 idx= (np.int64(2), np.int64(14), np.int64(227), np.int64(28))
# selected elements: 5591
# ------------
# cluster= 123
# amplitude= 2.3393143487535126 idx= (np.int64(7), np.int64(11), np.int64(152), np.int64(16))
# selected elements: 4394
# ------------
# cluster= 124
# amplitude= 2.3198056189905256 idx= (np.int64(4), np.int64(8), np.int64(232), np.int64(15))
# selected elements: 266
# ------------
# cluster= 125
# amplitude= 2.3184577698602027 idx= (np.int64(0), np.int64(17), np.int64(224), np.int64(7))
# selected elements: 1070
# ------------
# cluster= 126
# amplitude= 2.3100224972579686 idx= (np.int64(2), np.int64(10), np.int64(173), np.int64(11))
# selected elements: 362
# ------------
# cluster= 127
# amplitude= 2.302175078826111 idx= (np.int64(4), np.int64(9), np.int64(122), np.int64(6))
# selected elements: 142
# ------------
# cluster= 128
# amplitude= 2.2949421833904347 idx= (np.int64(1), np.int64(5), np.int64(125), np.int64(125))
# selected elements: 175
# ------------
# cluster= 129
# amplitude= 2.288072815298553 idx= (np.int64(0), np.int64(16), np.int64(187), np.int64(47))
# selected elements: 1303
# ------------
# cluster= 130
# amplitude= 2.2415095162661647 idx= (np.int64(7), np.int64(12), np.int64(97), np.int64(25))
# selected elements: 1733
# ------------
# cluster= 131
# amplitude= 2.231064284545125 idx= (np.int64(0), np.int64(12), np.int64(132), np.int64(10))
# selected elements: 178
# ------------
# cluster= 132
# amplitude= 2.226986056508413 idx= (np.int64(0), np.int64(17), np.int64(115), np.int64(57))
# selected elements: 778
# ------------
# cluster= 133
# amplitude= 2.220978522387078 idx= (np.int64(1), np.int64(2), np.int64(110), np.int64(10))
# selected elements: 510
# ------------
# cluster= 134
# amplitude= 2.2198247515787664 idx= (np.int64(0), np.int64(17), np.int64(97), np.int64(69))
# selected elements: 173
# ------------
# cluster= 135
# amplitude= 2.2195165928757183 idx= (np.int64(0), np.int64(8), np.int64(207), np.int64(29))
# selected elements: 950
# ------------
# cluster= 136
# amplitude= 2.213568850442679 idx= (np.int64(13), np.int64(9), np.int64(113), np.int64(119))
# selected elements: 45836
# ------------
# cluster= 137
# amplitude= 2.212170240671302 idx= (np.int64(8), np.int64(10), np.int64(152), np.int64(13))
# selected elements: 3236
# ------------
# cluster= 138
# amplitude= 2.203777602418207 idx= (np.int64(0), np.int64(13), np.int64(148), np.int64(64))
# selected elements: 3543
# ------------
# cluster= 139
# amplitude= 2.1836057535796303 idx= (np.int64(7), np.int64(11), np.int64(123), np.int64(7))
# selected elements: 492
# ------------
# cluster= 140
# amplitude= 2.180041028230583 idx= (np.int64(5), np.int64(9), np.int64(180), np.int64(46))
# selected elements: 481
# ------------
# cluster= 141
# amplitude= 2.1728131633395766 idx= (np.int64(0), np.int64(2), np.int64(139), np.int64(44))
# selected elements: 1000
# ------------
# cluster= 142
# amplitude= 2.1727454141081766 idx= (np.int64(3), np.int64(15), np.int64(96), np.int64(27))
# selected elements: 773
# ------------
# cluster= 143
# amplitude= 2.1723164196756355 idx= (np.int64(9), np.int64(7), np.int64(116), np.int64(87))
# selected elements: 874
# ------------
# cluster= 144
# amplitude= 2.1672974333063433 idx= (np.int64(3), np.int64(7), np.int64(164), np.int64(44))
# selected elements: 10555
# ------------
# cluster= 145
# amplitude= 2.1644787064567357 idx= (np.int64(1), np.int64(5), np.int64(114), np.int64(9))
# selected elements: 324
# ------------
# cluster= 146
# amplitude= 2.1628927001034417 idx= (np.int64(5), np.int64(3), np.int64(103), np.int64(111))
# selected elements: 762
# ------------
# cluster= 147
# amplitude= 2.1543886831950605 idx= (np.int64(0), np.int64(8), np.int64(201), np.int64(106))
# selected elements: 1228
# ------------
# cluster= 148
# amplitude= 2.154249645116478 idx= (np.int64(0), np.int64(10), np.int64(91), np.int64(87))
# selected elements: 249
# ------------
# cluster= 149
# amplitude= 2.153425895754499 idx= (np.int64(3), np.int64(5), np.int64(55), np.int64(48))
# selected elements: 1269
# ------------
# cluster= 150
# amplitude= 2.1382465670178648 idx= (np.int64(3), np.int64(0), np.int64(103), np.int64(35))
# selected elements: 467
# ------------
# cluster= 151
# amplitude= 2.1336860246542004 idx= (np.int64(0), np.int64(11), np.int64(143), np.int64(45))
# selected elements: 951
# ------------
# cluster= 152
# amplitude= 2.1308041456122333 idx= (np.int64(5), np.int64(1), np.int64(101), np.int64(76))
# selected elements: 2352
# ------------
# cluster= 153
# amplitude= 2.125344026869587 idx= (np.int64(5), np.int64(6), np.int64(123), np.int64(84))
# selected elements: 273
# ------------
# cluster= 154
# amplitude= 2.1092943937466186 idx= (np.int64(3), np.int64(3), np.int64(95), np.int64(69))
# selected elements: 402
# ------------
# cluster= 155
# amplitude= 2.1080514315061136 idx= (np.int64(3), np.int64(10), np.int64(180), np.int64(46))
# selected elements: 3038
# ------------
# cluster= 156
# amplitude= 2.101742240970494 idx= (np.int64(4), np.int64(11), np.int64(66), np.int64(43))
# selected elements: 429
# ------------
# cluster= 157
# amplitude= 2.101167531815729 idx= (np.int64(0), np.int64(7), np.int64(105), np.int64(112))
# selected elements: 102
# ------------
# cluster= 158
# amplitude= 2.0935954880133685 idx= (np.int64(4), np.int64(4), np.int64(96), np.int64(71))
# selected elements: 2038
# ------------
# cluster= 159
# amplitude= 2.093054676693996 idx= (np.int64(0), np.int64(12), np.int64(95), np.int64(69))
# selected elements: 223
# ------------
# cluster= 160
# amplitude= 2.082418796050085 idx= (np.int64(0), np.int64(10), np.int64(130), np.int64(101))
# selected elements: 1319
# ------------
# cluster= 161
# amplitude= 2.082029953678704 idx= (np.int64(3), np.int64(14), np.int64(98), np.int64(116))
# selected elements: 1112
# ------------
# cluster= 162
# amplitude= 2.069769360804627 idx= (np.int64(0), np.int64(9), np.int64(148), np.int64(102))
# selected elements: 1999
# ------------
# cluster= 163
# amplitude= 2.057417895302182 idx= (np.int64(0), np.int64(11), np.int64(159), np.int64(83))
# selected elements: 1689
# ------------
# cluster= 164
# amplitude= 2.036301308357432 idx= (np.int64(0), np.int64(5), np.int64(109), np.int64(111))
# selected elements: 96
# ------------
# cluster= 165
# amplitude= 2.0160598736903026 idx= (np.int64(2), np.int64(14), np.int64(133), np.int64(125))
# selected elements: 880
# ------------
# cluster= 166
# amplitude= 2.012121884716664 idx= (np.int64(5), np.int64(14), np.int64(114), np.int64(8))
# selected elements: 950
# ------------
# cluster= 167
# amplitude= 2.011876575748965 idx= (np.int64(3), np.int64(5), np.int64(95), np.int64(72))
# selected elements: 203
# ------------
# cluster= 168
# amplitude= 2.0063936643259788 idx= (np.int64(0), np.int64(6), np.int64(92), np.int64(62))
# selected elements: 134
# ------------
# cluster= 169
# amplitude= 2.0035896902791253 idx= (np.int64(1), np.int64(1), np.int64(131), np.int64(14))
# selected elements: 65
# ------------
# cluster= 170
# amplitude= 2.0007889633601454 idx= (np.int64(2), np.int64(14), np.int64(95), np.int64(25))
# selected elements: 234
# ------------
# cluster= 171
# amplitude= 1.9976153670386532 idx= (np.int64(0), np.int64(4), np.int64(206), np.int64(29))
# selected elements: 237
# ------------
# cluster= 172
# amplitude= 1.9959628432884722 idx= (np.int64(0), np.int64(17), np.int64(192), np.int64(22))
# selected elements: 1880
# ------------
# cluster= 173
# amplitude= 1.9883195585858844 idx= (np.int64(2), np.int64(7), np.int64(236), np.int64(14))
# selected elements: 401
# ------------
# cluster= 174
# amplitude= 1.987669277474342 idx= (np.int64(3), np.int64(8), np.int64(154), np.int64(102))
# selected elements: 4612
# ------------
# cluster= 175
# amplitude= 1.9863027967741371 idx= (np.int64(4), np.int64(8), np.int64(230), np.int64(34))
# selected elements: 205
# ------------
# cluster= 176
# amplitude= 1.980251413156513 idx= (np.int64(3), np.int64(6), np.int64(131), np.int64(15))
# selected elements: 840
# ------------
# cluster= 177
# amplitude= 1.9758057200588537 idx= (np.int64(1), np.int64(2), np.int64(97), np.int64(117))
# selected elements: 311
# ------------
# cluster= 178
# amplitude= 1.9754618784090858 idx= (np.int64(0), np.int64(11), np.int64(159), np.int64(14))
# selected elements: 267
# ------------
# cluster= 179
# amplitude= 1.9660493525321485 idx= (np.int64(1), np.int64(4), np.int64(100), np.int64(36))
# selected elements: 210
# ------------
# cluster= 180
# amplitude= 1.9604800480443036 idx= (np.int64(20), np.int64(5), np.int64(115), np.int64(44))
# selected elements: 8990
# ------------
# cluster= 181
# amplitude= 1.9534057951723025 idx= (np.int64(0), np.int64(8), np.int64(251), np.int64(109))
# selected elements: 4150
# ------------
# cluster= 182
# ...
# selected elements: 2492
# ------------
# cluster= 38
# amplitude= 1.6687188039156595 idx= (np.int64(0), np.int64(9), np.int64(183), np.int64(41))
# selected elements: 147
# ------------
# cluster= 39
# amplitude= 1.66702728103932 idx= (np.int64(10), np.int64(2), np.int64(160), np.int64(12))
# selected elements: 9118
# ------------
# cluster= 40
# amplitude= 1.6572651238207106 idx= (np.int64(4), np.int64(6), np.int64(104), np.int64(97))
# selected elements: 14392
# ------------
# cluster= 41
# amplitude= 1.6473444164802966 idx= (np.int64(22), np.int64(17), np.int64(157), np.int64(41))
# selected elements: 1473
# ------------
# cluster= 42
# amplitude= 1.6446985460254762 idx= (np.int64(21), np.int64(7), np.int64(219), np.int64(94))
# selected elements: 1334
# ------------
# cluster= 43
# amplitude= 1.6008994858023324 idx= (np.int64(15), np.int64(6), np.int64(221), np.int64(85))
# selected elements: 2501
# ------------
# cluster= 44
# amplitude= 1.5998421060604144 idx= (np.int64(13), np.int64(2), np.int64(215), np.int64(43))
# selected elements: 1217
# ------------
# cluster= 45
# amplitude= 1.591341400591734 idx= (np.int64(14), np.int64(5), np.int64(221), np.int64(83))
# selected elements: 2672
# ------------
# cluster= 46
# amplitude= 1.5766980454919262 idx= (np.int64(1), np.int64(9), np.int64(104), np.int64(90))
# selected elements: 9907
# ------------
# cluster= 47
# amplitude= 1.5372134749525475 idx= (np.int64(23), np.int64(4), np.int64(52), np.int64(91))
# selected elements: 88
# ------------
# cluster= 48
# amplitude= 1.5365570529956762 idx= (np.int64(6), np.int64(8), np.int64(258), np.int64(123))
# selected elements: 7659
# ------------
# cluster= 49
# amplitude= 1.5304268395346707 idx= (np.int64(6), np.int64(12), np.int64(190), np.int64(43))
# selected elements: 267
# ------------
# cluster= 50
# amplitude= 1.527334885330305 idx= (np.int64(23), np.int64(9), np.int64(313), np.int64(32))
# selected elements: 38
# ------------
# cluster= 51
# amplitude= 1.5077881146098795 idx= (np.int64(1), np.int64(5), np.int64(112), np.int64(93))
# selected elements: 1281
# ------------
# cluster= 52
# amplitude= 1.4632008431351589 idx= (np.int64(16), np.int64(4), np.int64(222), np.int64(82))
# selected elements: 2100
# ------------
# cluster= 53
# amplitude= 1.4571631436861006 idx= (np.int64(13), np.int64(15), np.int64(173), np.int64(70))
# selected elements: 802
# ------------
# cluster= 54
# amplitude= 1.4493596015147172 idx= (np.int64(17), np.int64(16), np.int64(180), np.int64(49))
# selected elements: 1324
# ------------
# cluster= 55
# amplitude= 1.447061281438235 idx= (np.int64(9), np.int64(7), np.int64(183), np.int64(66))
# selected elements: 278
# ------------
# cluster= 56
# amplitude= 1.4311927475729407 idx= (np.int64(0), np.int64(14), np.int64(159), np.int64(57))
# selected elements: 81
# ------------
# cluster= 57
# amplitude= 1.4302650947189055 idx= (np.int64(17), np.int64(6), np.int64(173), np.int64(57))
# selected elements: 2137
# ------------
# cluster= 58
# amplitude= 1.4185113571414047 idx= (np.int64(4), np.int64(2), np.int64(322), np.int64(26))
# selected elements: 4914
# ------------
# cluster= 59
# amplitude= 1.40750828258793 idx= (np.int64(11), np.int64(13), np.int64(211), np.int64(39))
# selected elements: 4393
# ------------
# cluster= 60
# amplitude= 1.4072452075299784 idx= (np.int64(11), np.int64(4), np.int64(40), np.int64(96))
# selected elements: 14078
# ------------
# cluster= 61
# amplitude= 1.4046964820154864 idx= (np.int64(15), np.int64(0), np.int64(215), np.int64(42))
# selected elements: 1192
# ------------
# cluster= 62
# amplitude= 1.4009528304897463 idx= (np.int64(4), np.int64(9), np.int64(91), np.int64(113))
# selected elements: 3520
# ------------
# cluster= 63
# amplitude= 1.3972566139689162 idx= (np.int64(22), np.int64(0), np.int64(196), np.int64(42))
# selected elements: 148
# ------------
# cluster= 64
# amplitude= 1.3945066314977157 idx= (np.int64(22), np.int64(14), np.int64(257), np.int64(77))
# selected elements: 185
# ------------
# cluster= 65
# amplitude= 1.3936221982078303 idx= (np.int64(15), np.int64(4), np.int64(177), np.int64(53))
# selected elements: 4531
# ------------
# cluster= 66
# amplitude= 1.3853887385428512 idx= (np.int64(18), np.int64(5), np.int64(224), np.int64(84))
# selected elements: 521
# ------------
# cluster= 67
# amplitude= 1.3712880228332984 idx= (np.int64(20), np.int64(0), np.int64(221), np.int64(119))
# selected elements: 2391
# ------------
# cluster= 68
# amplitude= 1.3688346619102383 idx= (np.int64(11), np.int64(15), np.int64(206), np.int64(76))
# selected elements: 6417
# ------------
# cluster= 69
# amplitude= 1.3571509435127849 idx= (np.int64(3), np.int64(7), np.int64(182), np.int64(42))
# selected elements: 583
# ------------
# cluster= 70
# amplitude= 1.354998965071867 idx= (np.int64(0), np.int64(9), np.int64(119), np.int64(58))
# selected elements: 1268
# ------------
# cluster= 71
# amplitude= 1.3544902410525077 idx= (np.int64(11), np.int64(2), np.int64(325), np.int64(17))
# selected elements: 6433
# ------------
# cluster= 72
# amplitude= 1.3513494639566352 idx= (np.int64(13), np.int64(17), np.int64(220), np.int64(101))
# selected elements: 3452
# ------------
# cluster= 73
# amplitude= 1.3462285595751624 idx= (np.int64(15), np.int64(10), np.int64(216), np.int64(100))
# selected elements: 1469
# ------------
# cluster= 74
# amplitude= 1.3408073735315253 idx= (np.int64(11), np.int64(13), np.int64(281), np.int64(79))
# selected elements: 5603
# ------------
# cluster= 75
# amplitude= 1.3351215142153143 idx= (np.int64(17), np.int64(14), np.int64(241), np.int64(102))
# selected elements: 1034
# ------------
# cluster= 76
# amplitude= 1.3311501594579098 idx= (np.int64(7), np.int64(8), np.int64(179), np.int64(41))
# selected elements: 618
# ------------
# cluster= 77
# amplitude= 1.3238268477172965 idx= (np.int64(14), np.int64(3), np.int64(324), np.int64(18))
# selected elements: 1656
# ------------
# cluster= 78
# amplitude= 1.322220679863363 idx= (np.int64(17), np.int64(2), np.int64(160), np.int64(31))
# selected elements: 1404
# ------------
# cluster= 79
# amplitude= 1.3183801567464926 idx= (np.int64(11), np.int64(15), np.int64(232), np.int64(19))
# selected elements: 4482
# ------------
# cluster= 80
# amplitude= 1.3053179311639977 idx= (np.int64(10), np.int64(14), np.int64(203), np.int64(77))
# selected elements: 721
# ------------
# cluster= 81
# amplitude= 1.2986748755586648 idx= (np.int64(20), np.int64(17), np.int64(225), np.int64(62))
# selected elements: 1254
# ------------
# cluster= 82
# amplitude= 1.2918872086904964 idx= (np.int64(18), np.int64(0), np.int64(328), np.int64(82))
# selected elements: 1549
# ------------
# cluster= 83
# amplitude= 1.2904990292281229 idx= (np.int64(0), np.int64(10), np.int64(127), np.int64(79))
# selected elements: 353
# ------------
# cluster= 84
# amplitude= 1.288137946977628 idx= (np.int64(15), np.int64(17), np.int64(175), np.int64(39))
# selected elements: 523
# ------------
# cluster= 85
# amplitude= 1.2830232427227792 idx= (np.int64(21), np.int64(1), np.int64(186), np.int64(45))
# selected elements: 143
# ------------
# cluster= 86
# amplitude= 1.2756406557136533 idx= (np.int64(21), np.int64(3), np.int64(216), np.int64(43))
# selected elements: 110
# ------------
# cluster= 87
# amplitude= 1.2745280024396122 idx= (np.int64(21), np.int64(10), np.int64(307), np.int64(33))
# selected elements: 201
# ------------
# cluster= 88
# amplitude= 1.2665663172415942 idx= (np.int64(16), np.int64(15), np.int64(336), np.int64(64))
# selected elements: 1732
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 66.48it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=6600:7200 ext=6550:7250 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\base_offset_0000\xcore_06600_07200_xext_06550_07250
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.651210816436497 idx= (np.int64(16), np.int64(10), np.int64(51), np.int64(57))
# selected elements: 208250
# ------------
# cluster= 1
# amplitude= 2.2631377728821396 idx= (np.int64(21), np.int64(17), np.int64(28), np.int64(69))
# selected elements: 31619
# ------------
# cluster= 2
# amplitude= 2.0576193830348193 idx= (np.int64(23), np.int64(6), np.int64(52), np.int64(73))
# selected elements: 40299
# ------------
# cluster= 3
# amplitude= 1.9594095095400403 idx= (np.int64(21), np.int64(0), np.int64(14), np.int64(36))
# selected elements: 38335
# ------------
# cluster= 4
# amplitude= 1.9442341397230547 idx= (np.int64(11), np.int64(4), np.int64(124), np.int64(67))
# selected elements: 35733
# ------------
# cluster= 5
# amplitude= 1.7570209465786673 idx= (np.int64(0), np.int64(9), np.int64(285), np.int64(136))
# selected elements: 2948
# ------------
# cluster= 6
# amplitude= 1.733171723257024 idx= (np.int64(0), np.int64(9), np.int64(296), np.int64(37))
# selected elements: 2258
# ------------
# cluster= 7
# amplitude= 1.6310021044023078 idx= (np.int64(3), np.int64(9), np.int64(168), np.int64(84))
# selected elements: 4126
# ------------
# cluster= 8
# amplitude= 1.6026249754512183 idx= (np.int64(2), np.int64(9), np.int64(262), np.int64(79))
# selected elements: 2444
# ------------
# cluster= 9
# amplitude= 1.589117372665681 idx= (np.int64(7), np.int64(10), np.int64(179), np.int64(121))
# selected elements: 9759
# ------------
# cluster= 10
# amplitude= 1.5685285361284682 idx= (np.int64(1), np.int64(9), np.int64(126), np.int64(90))
# selected elements: 1836
# ------------
# cluster= 11
# amplitude= 1.5080742794947224 idx= (np.int64(3), np.int64(9), np.int64(79), np.int64(129))
# selected elements: 3629
# ------------
# cluster= 12
# amplitude= 1.4872786288135746 idx= (np.int64(0), np.int64(9), np.int64(204), np.int64(127))
# selected elements: 1884
# ------------
# cluster= 13
# amplitude= 1.4680381374030216 idx= (np.int64(16), np.int64(16), np.int64(27), np.int64(90))
# selected elements: 10944
# ------------
# cluster= 14
# amplitude= 1.4659891245064982 idx= (np.int64(1), np.int64(1), np.int64(297), np.int64(139))
# selected elements: 1237
# ------------
# cluster= 15
# amplitude= 1.42884104191362 idx= (np.int64(5), np.int64(8), np.int64(248), np.int64(22))
# selected elements: 4920
# ------------
# cluster= 16
# amplitude= 1.4204693699478343 idx= (np.int64(11), np.int64(2), np.int64(25), np.int64(16))
# selected elements: 10021
# ------------
# cluster= 17
# amplitude= 1.4174998863905517 idx= (np.int64(3), np.int64(2), np.int64(22), np.int64(26))
# selected elements: 1675
# ------------
# cluster= 18
# amplitude= 1.3958868566037113 idx= (np.int64(23), np.int64(9), np.int64(27), np.int64(42))
# selected elements: 4603
# ------------
# cluster= 19
# amplitude= 1.3943531916725376 idx= (np.int64(7), np.int64(8), np.int64(41), np.int64(64))
# selected elements: 3115
# ------------
# cluster= 20
# amplitude= 1.3923738710849425 idx= (np.int64(4), np.int64(7), np.int64(295), np.int64(137))
# selected elements: 2404
# ------------
# cluster= 21
# amplitude= 1.378926516730644 idx= (np.int64(15), np.int64(9), np.int64(319), np.int64(137))
# selected elements: 11346
# ------------
# cluster= 22
# amplitude= 1.3663554235296838 idx= (np.int64(10), np.int64(10), np.int64(241), np.int64(124))
# selected elements: 8987
# ------------
# cluster= 23
# amplitude= 1.3382989087919306 idx= (np.int64(0), np.int64(10), np.int64(212), np.int64(125))
# selected elements: 105
# ------------
# cluster= 24
# amplitude= 1.3199167230260092 idx= (np.int64(8), np.int64(8), np.int64(79), np.int64(49))
# selected elements: 5978
# ------------
# cluster= 25
# amplitude= 1.304888695157083 idx= (np.int64(14), np.int64(0), np.int64(5), np.int64(47))
# selected elements: 5761
# ------------
# cluster= 26
# amplitude= 1.291897532432275 idx= (np.int64(7), np.int64(8), np.int64(189), np.int64(128))
# selected elements: 1213
# ------------
# cluster= 27
# amplitude= 1.2859127627283473 idx= (np.int64(17), np.int64(0), np.int64(340), np.int64(119))
# selected elements: 8044
# ------------
# cluster= 28
# amplitude= 1.2847904414338294 idx= (np.int64(8), np.int64(9), np.int64(243), np.int64(133))
# selected elements: 1736
# ------------
# cluster= 29
# amplitude= 1.283361337263083 idx= (np.int64(0), np.int64(10), np.int64(65), np.int64(91))
# selected elements: 244
# ------------
# cluster= 30
# amplitude= 1.2811357246173956 idx= (np.int64(3), np.int64(9), np.int64(235), np.int64(87))
# selected elements: 2051
# ------------
# cluster= 31
# amplitude= 1.271577987254296 idx= (np.int64(1), np.int64(14), np.int64(291), np.int64(139))
# selected elements: 1186
# ------------
# cluster= 32
# amplitude= 1.2660612234555177 idx= (np.int64(1), np.int64(9), np.int64(314), np.int64(22))
# selected elements: 1098
# ------------
# cluster= 33
# amplitude= 1.2640260139839938 idx= (np.int64(0), np.int64(9), np.int64(188), np.int64(119))
# selected elements: 270
# ------------
# cluster= 34
# amplitude= 1.262986230115697 idx= (np.int64(10), np.int64(8), np.int64(37), np.int64(55))
# selected elements: 1025
# ------------
# cluster= 35
# amplitude= 1.2621203008410307 idx= (np.int64(4), np.int64(9), np.int64(185), np.int64(107))
# selected elements: 2478
# ------------
# cluster= 36
# amplitude= 1.2529029402463459 idx= (np.int64(0), np.int64(17), np.int64(294), np.int64(139))
# selected elements: 65
# ------------
# cluster= 37
# amplitude= 1.2519482165605957 idx= (np.int64(5), np.int64(10), np.int64(305), np.int64(23))
# selected elements: 1963
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 83.67it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=7200:7651 ext=7150:7651 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\base_offset_0000\xcore_07200_07651_xext_07150_07651
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 1.4850182196831998 idx= (np.int64(0), np.int64(8), np.int64(50), np.int64(42))
# selected elements: 3158
# ------------
# cluster= 1
# amplitude= 1.379369627376312 idx= (np.int64(4), np.int64(9), np.int64(80), np.int64(27))
# selected elements: 10259
# ------------
# cluster= 2
# amplitude= 1.3693997401893487 idx= (np.int64(0), np.int64(9), np.int64(14), np.int64(22))
# selected elements: 5609
# ------------
# cluster= 3
# amplitude= 1.3509944095293052 idx= (np.int64(1), np.int64(10), np.int64(104), np.int64(16))
# selected elements: 2212
# ------------
# cluster= 4
# amplitude= 1.283502121843403 idx= (np.int64(5), np.int64(13), np.int64(84), np.int64(25))
# selected elements: 4776
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.32it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Done. Outputs in C:\Users\domin\juwavelet\examples\CWT Whole Orbit\outputs_decompose2d_slices_single_noise_filtering_AUTO\base_offset_0000
# Saved output with clusters: C:\Users\domin\juwavelet\examples\CWT Whole Orbit\outputs_decompose2d_slices_single_noise_filtering_AUTO\base_offset_0000\awe_l6a_tmp_2025153T1853_08658_v01.nc

# %% [markdown]
# ## Clean up memory, optional saving plots

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Dict, Any, List

import copy
import gc

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

try:
    from scipy import stats
except Exception:
    stats = None


# --------------------------
# User params
# --------------------------
FILE_PATH = r"Z:\socfiles\l3c\2024\03_v23\awe_l3c_q20_2024075T0538_01770_v23.nc" # can be L5C / L3C / L3A
FRAME_IDX = 0

# Slicing on the UNBINNED flattened field
X_CHUNK = 600
Y_SLICE = slice(None, None)
SLICE_PAD = 50  # extend each slice by this many UNBINNED pixels on each side

# Choose ONE slicing offset (no comparisons)
X_OFFSET = 0  # set to 0 or 300 or whatever you want

# Optional preprocessing
REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

# Optional 2x2 binning BEFORE processing
APPLY_BINNING = True
BIN_FACTOR = 2

# Edge taper on remaining field (before CWT)
APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10  # in BINNED pixels if APPLY_BINNING else in original pixels

# Wavelet params
S0 = 16
DJ = 1 / 8
JS = 24
JT = 18
ASPECT = 1

# Pixel spacing (km per pixel)
DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

# How many clusters to show (largest by POWER)
N_SHOW = 6

# Per cluster maps
AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

# Red noise style filtering (robust WPS thresholding per scale)
APPLY_RED_NOISE_FILTER = True

# Optional diagnostics output from the red noise filter
SAVE_REDNOISE_DIAGNOSTICS = True

# Save settings
OUTPUT_ROOT = Path("outputs_decompose2d_slices_single_noise_filtering_AUTO/01770")
SAVE_DPI = 200

# NEW: plot saving switches
SAVE_SLICE_PLOTS = True        # saves everything inside each slice outdir
SAVE_STITCHED_PLOT = True      # saves the stitched plot at the run root


# --------------------------
# Auto detect product type
# --------------------------
file_name = Path(FILE_PATH).name.lower()
if "_l3a_" in file_name:
    PRODUCT_TYPE = "l3a"
elif "_l3c_" in file_name:
    PRODUCT_TYPE = "l3c"
elif "_l5c_" in file_name:
    PRODUCT_TYPE = "l5c"
else:
    raise ValueError(f"Cannot detect product type from file name: {FILE_PATH}")

print("Detected product type:", PRODUCT_TYPE)


# --------------------------
# Parameter runs (AUTO)
# --------------------------
if PRODUCT_TYPE == "l3a":
    RUNS: List[Dict[str, Any]] = [
        dict(
            name="base",
            MIN_AMP=1.25,
            THR=0.6,
            WHITE_NOISE_THRESHOLD=0.1,
            WPS_NOISE_THRESHOLD=8.0,
        ),
    ]
else:
    RUNS = [
        dict(
            name="base",
            MIN_AMP=0.2,
            THR=0.1,
            WHITE_NOISE_THRESHOLD=0.02,
            WPS_NOISE_THRESHOLD=8.0,
        ),
    ]

print("Using RUNS:", RUNS)


# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)


# --------------------------
# Small helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path, *, enable: bool = True) -> None:
    """
    Save and close a figure if enable=True.
    Always closes the figure to avoid matplotlib memory buildup.
    """
    try:
        if enable:
            outpath.parent.mkdir(parents=True, exist_ok=True)
            fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    finally:
        plt.close(fig)


def cleanup_memory() -> None:
    """
    Best effort cleanup after each slice to keep RAM stable.
    """
    try:
        plt.close("all")
    except Exception:
        pass
    gc.collect()


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def diverging_limits(*arrays: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    vals = []
    for A in arrays:
        if A is None:
            continue
        a = np.asarray(A)
        good = np.isfinite(a)
        if np.any(good):
            vals.append(a[good].ravel())
    if not vals:
        return (-1.0, 1.0)
    stacked = np.concatenate(vals)
    lo, hi = np.nanpercentile(stacked, [p_lo, p_hi])
    vmax = max(abs(lo), abs(hi))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    return (-vmax, vmax)


# --------------------------
# Data helpers
# --------------------------
def read_frame_auto(path: str, frame_idx: int) -> np.ndarray:
    with Dataset(path, "r") as nc:
        if PRODUCT_TYPE == "l3a":
            varname = "Temperature"
        else:
            varname = "Radiance"
        data = nc.variables[varname][:]  # (t, y, x)

    if data.ndim != 3:
        raise ValueError(f"{varname} expected 3D (t,y,x); got {data.shape}")

    if not (0 <= frame_idx < data.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{data.shape[0]-1}")

    return np.asarray(data[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def unbin_repeat_xy(A: np.ndarray, factor: int) -> np.ndarray:
    """
    Nearest neighbor upsample (repeat) from (y,x) to (y*factor, x*factor).
    Preserves NaNs by repetition.
    """
    if factor is None or int(factor) <= 1:
        return A
    f = int(factor)
    return np.repeat(np.repeat(A, f, axis=0), f, axis=1)


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    return np.cos(theta_xy), np.sin(theta_xy)


# --------------------------
# Red noise style filtering helper
# --------------------------
def apply_red_noise_filter_cwt(
    cwt: dict,
    white_noise_threshold: float = 0.1,
    wps_noise_threshold: float = 8.0,
) -> Tuple[dict, Dict[str, Any]]:
    """
    Robust per scale WPS filtering.
    Returns filtered_cwt (deep copy) and a small diagnostics dict.
    """
    diag: Dict[str, Any] = {}
    if stats is None:
        diag["skipped"] = True
        diag["reason"] = "scipy not available"
        return cwt, diag

    cwt_copy = copy.deepcopy(cwt)
    dec = cwt_copy["decomposition"]  # (ns, nt, nx, ny) complex

    WPS0 = np.abs(dec) ** 2
    diag["n_coeff_total"] = int(WPS0.size)

    mask_1 = WPS0 < (float(white_noise_threshold) ** 2)
    dec[mask_1] = 0

    WPS1 = np.abs(dec) ** 2
    diag["n_zero_after_white"] = int(np.count_nonzero(WPS1 == 0))

    median_WPS = np.median(WPS1, axis=(1, 2, 3))  # (ns,)
    mad = stats.median_abs_deviation(WPS1, axis=(1, 2, 3), scale=1.0)  # (ns,)
    sMAD_WPS = 1.4826 * mad

    sMAD_safe = np.where(sMAD_WPS > 0, sMAD_WPS, np.nan)
    WPS_scaled = (WPS1 - median_WPS[:, None, None, None]) / sMAD_safe[:, None, None, None]

    mask = WPS_scaled < float(wps_noise_threshold)
    dec[mask] = 0

    WPS2 = np.abs(dec) ** 2
    diag["n_zero_after_scaled"] = int(np.count_nonzero(WPS2 == 0))

    finite_scaled = np.isfinite(WPS_scaled)

    diag["sMAD_min"] = float(np.nanmin(sMAD_WPS))
    diag["sMAD_median"] = float(np.nanmedian(sMAD_WPS))

    if np.any(finite_scaled):
        diag["WPS_scaled_min"] = float(np.nanmin(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_median"] = float(np.nanmedian(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_max"] = float(np.nanmax(WPS_scaled[finite_scaled]))
    else:
        diag["WPS_scaled_min"] = np.nan
        diag["WPS_scaled_median"] = np.nan
        diag["WPS_scaled_max"] = np.nan

    return cwt_copy, diag


# --------------------------
# Quicklook plots
# --------------------------
def quicklook_save(
    x1d: np.ndarray,
    y1d: np.ndarray,
    Z: np.ndarray,
    title: str,
    outpath: Path,
    *,
    save_plots: bool,
) -> None:
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("arb")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath, enable=save_plots)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
    *,
    wavy_after_noise_xy: np.ndarray | None = None,
    save_plots: bool,
) -> None:
    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    arrays = [orig_c, bg_c, rem_c, rem_tapered_c]
    if wavy_after_noise_xy is not None:
        arrays.append(wavy_after_noise_xy)

    vmin, vmax = diverging_limits(*arrays, p_lo=1, p_hi=99)

    fig, axs = plt.subplots(2, 3, figsize=(16, 10), constrained_layout=True)
    axs = axs.flatten()

    panels = [
        (orig_c, "Original (median sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    if wavy_after_noise_xy is not None:
        panels.append((wavy_after_noise_xy, "Wavy stuff (wavelet reconstruction after noise filtering)"))

    im0 = None
    for ax, (Zp, title) in zip(axs, panels):
        im0 = ax.pcolormesh(x1d_km, y1d_km, Zp, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    for ax in axs[len(panels) :]:
        ax.axis("off")

    cbar = fig.colorbar(im0, ax=axs[: len(panels)], orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("arb")
    save_fig(fig, outpath, enable=save_plots)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
    *,
    save_plots: bool,
) -> None:
    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2
    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])
        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_vmin, bg_vmax = diverging_limits(bg_xy, p_lo=2, p_hi=98)
    cl_vmin, cl_vmax = diverging_limits(rec_xy, p_lo=2, p_hi=98)

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if (not np.isfinite(lam_vmin)) or (not np.isfinite(lam_vmax)) or (lam_vmin == lam_vmax):
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n"
            + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        arrow_len_km = 40.0
        u = u * arrow_len_km
        v = v * arrow_len_km

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good],
            Yqs[good],
            uqs[good],
            vqs[good],
            angles="xy",
            scale_units="xy",
            scale=QUIVER_SCALE,
            width=0.0025,
        )

    save_fig(fig, outpath, enable=save_plots)


# --------------------------
# Cluster products (for L6C/L6A outputs)
# --------------------------
def cluster_dominant_lambda_map(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_mask_xy: np.ndarray | None = None,
) -> np.ndarray:
    """
    Per pixel dominant wavelength map λ(x,y) for one cluster.
    Returns shape (ny, nx) in XY.

    If amp_mask_xy is provided (A_xy with NaNs), apply the same NaN mask to λ.
    """
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power0 = np.abs(dec) ** 2
    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power0.shape
    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)
    valid = np.isfinite(pmax) & (pmax > 0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T  # XY

    if amp_mask_xy is not None:
        lam_xy[~np.isfinite(amp_mask_xy)] = np.nan

    return lam_xy


def copy_lxc_to_l6x_with_clusters(
    lxc_path: str | Path,
    l6x_path: str | Path,
    clusters: List[Dict[str, Any]],
    y_dim: int,
    x_dim: int,
    unbin_factor: int = 1,
) -> None:
    """
    Copy everything from input file, then append cluster products.

    Adds:
      dimension: cluster
      dimension: y_cluster (=y_dim*unbin_factor), x_cluster (=x_dim*unbin_factor)
      SlicesNo(cluster)
      Area(cluster)
      ClusterPowerAbs(cluster)
      ClusterPowerPct(cluster)
      Amplitude(cluster,y_cluster,x_cluster)
      DominantWavelength(cluster,y_cluster,x_cluster)
      Angle(cluster,y_cluster,x_cluster)
      ClusterReconstruction(cluster,y_cluster,x_cluster) optional

    If unbin_factor>1, upsample products by repetition.
    """
    def _unbin_repeat_xy_local(A: np.ndarray, factor: int) -> np.ndarray:
        if factor is None or int(factor) <= 1:
            return A
        f = int(factor)
        return np.repeat(np.repeat(A, f, axis=0), f, axis=1)

    lxc_path = Path(lxc_path)
    l6x_path = Path(l6x_path)
    l6x_path.parent.mkdir(parents=True, exist_ok=True)

    ncl = int(len(clusters))
    has_rec = any((c.get("rec_xy", None) is not None) for c in clusters)

    fup = int(unbin_factor) if (unbin_factor is not None and int(unbin_factor) > 1) else 1
    y_dim_w = int(y_dim) * fup
    x_dim_w = int(x_dim) * fup

    with Dataset(lxc_path, "r") as src, Dataset(l6x_path, "w", format="NETCDF4") as dst:
        dst.setncatts({k: src.getncattr(k) for k in src.ncattrs()})

        for dname, dim in src.dimensions.items():
            dst.createDimension(dname, (len(dim) if not dim.isunlimited() else None))

        for vname, var in src.variables.items():
            out = dst.createVariable(
                vname,
                var.datatype,
                var.dimensions,
                zlib=True,
                complevel=4,
                fill_value=getattr(var, "_FillValue", None),
            )
            out.setncatts({k: var.getncattr(k) for k in var.ncattrs()})
            out[:] = var[:]

        dst.createDimension("cluster", ncl)
        dst.createDimension("y_cluster", y_dim_w)
        dst.createDimension("x_cluster", x_dim_w)

        v_slice = dst.createVariable("SlicesNo", "i4", ("cluster",), zlib=True, complevel=4)
        v_area = dst.createVariable("Area", "f4", ("cluster",), zlib=True, complevel=4)
        v_pabs = dst.createVariable("ClusterPowerAbs", "f8", ("cluster",), zlib=True, complevel=4)
        v_ppct = dst.createVariable("ClusterPowerPct", "f4", ("cluster",), zlib=True, complevel=4)

        v_amp = dst.createVariable(
            "Amplitude",
            "f4",
            ("cluster", "y_cluster", "x_cluster"),
            zlib=True,
            complevel=4,
            fill_value=np.float32(np.nan),
        )
        v_lam = dst.createVariable(
            "DominantWavelength",
            "f4",
            ("cluster", "y_cluster", "x_cluster"),
            zlib=True,
            complevel=4,
            fill_value=np.float32(np.nan),
        )
        v_ang = dst.createVariable(
            "Angle",
            "f4",
            ("cluster", "y_cluster", "x_cluster"),
            zlib=True,
            complevel=4,
            fill_value=np.float32(np.nan),
        )

        v_rec = None
        if has_rec:
            v_rec = dst.createVariable(
                "ClusterReconstruction",
                "f4",
                ("cluster", "y_cluster", "x_cluster"),
                zlib=True,
                complevel=4,
                fill_value=np.float32(np.nan),
            )
            v_rec.units = "arb"
            v_rec.long_name = "Per cluster wavelet reconstruction map (relative; median subtracted)"

        v_area.units = "km2"
        v_lam.units = "km"
        v_ang.units = "rad"
        v_slice.long_name = "Slice index (starts at 0) for each cluster"
        v_pabs.units = "arb"
        v_ppct.units = "percent"

        if PRODUCT_TYPE == "l3a":
            v_amp.units = "K"
        else:
            v_amp.units = "kR"

        if ncl == 0:
            return

        v_slice[:] = np.asarray([c["slice_no"] for c in clusters], dtype=np.int32)
        v_area[:] = np.asarray([c["area_km2"] for c in clusters], dtype=np.float32)
        v_pabs[:] = np.asarray([c.get("power_abs", np.nan) for c in clusters], dtype=np.float64)
        v_ppct[:] = np.asarray([c.get("power_pct", np.nan) for c in clusters], dtype=np.float32)

        amp_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        lam_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        ang_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        rec_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32) if has_rec else None

        def _force_shape(M: np.ndarray) -> np.ndarray:
            if M.shape == (y_dim_w, x_dim_w):
                return M.astype(np.float32)
            tmp = np.full((y_dim_w, x_dim_w), np.nan, dtype=np.float32)
            yy = min(y_dim_w, M.shape[0])
            xx = min(x_dim_w, M.shape[1])
            tmp[:yy, :xx] = M[:yy, :xx]
            return tmp

        for i, c in enumerate(clusters):
            A = _unbin_repeat_xy_local(c["A_xy"], fup)
            L = _unbin_repeat_xy_local(c["lam_xy"], fup)
            T = _unbin_repeat_xy_local(c["theta_xy"], fup)

            amp_stack[i] = _force_shape(A)
            lam_stack[i] = _force_shape(L)
            ang_stack[i] = _force_shape(T)

            if has_rec and rec_stack is not None and v_rec is not None:
                R = c.get("rec_xy", None)
                if R is not None:
                    R = _force_shape(_unbin_repeat_xy_local(R, fup))
                    rec_stack[i] = R

        v_amp[:] = amp_stack
        v_lam[:] = lam_stack
        v_ang[:] = ang_stack
        if has_rec and v_rec is not None and rec_stack is not None:
            v_rec[:] = rec_stack


def make_output_cluster_path(input_path: str | Path) -> Path:
    p = Path(input_path)
    name = p.name
    if "_l5c_" in name:
        name = name.replace("_l5c_", "_l6c_")
    elif "_l3c_" in name:
        name = name.replace("_l3c_", "_l6c_")
    elif "_l3a_" in name:
        name = name.replace("_l3a_", "_l6a_")
    else:
        name = p.stem + "_clusters.nc"
    return p.with_name(name)


# --------------------------
# Slice pipeline
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
    cfg: Dict[str, Any],
    slice_no: int,
) -> Dict[str, Any]:
    """
    Runs processing on an extended slice (x_slice), but returns only core tiles for stitching.

    Per slice plots are controlled by SAVE_SLICE_PLOTS.
    """
    outdir.mkdir(parents=True, exist_ok=True)
    save_plots = bool(SAVE_SLICE_PLOTS)

    min_amp = float(cfg.get("MIN_AMP"))
    thr = float(cfg.get("THR"))
    white_noise_threshold = float(cfg.get("WHITE_NOISE_THRESHOLD"))
    wps_noise_threshold = float(cfg.get("WPS_NOISE_THRESHOLD"))
    run_name = str(cfg.get("name", "run"))

    STORE_CLUSTER_RECON = True  # per cluster recon maps stored in output NetCDF

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        f = int(BIN_FACTOR)
        dx_km = DX_KM_BASE * f
        dy_km = DY_KM_BASE * f
    else:
        f = 1
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f
    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    raw_win = np.asarray(rad2d_flat[Y_SLICE, x_slice], dtype=float)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""

    label0 = "Temperature" if PRODUCT_TYPE == "l3a" else "Radiance"

    quicklook_save(
        x1d_km,
        y1d_km,
        raw_win,
        f"{label0} (window, flattened){bin_tag}\n{run_name} MIN_AMP={min_amp} THR={thr}",
        outdir / "00_window.png",
        save_plots=save_plots,
    )

    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt_raw = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    if APPLY_RED_NOISE_FILTER:
        cwt, diag = apply_red_noise_filter_cwt(
            cwt_raw,
            white_noise_threshold=white_noise_threshold,
            wps_noise_threshold=wps_noise_threshold,
        )
        if SAVE_REDNOISE_DIAGNOSTICS:
            lines = []
            lines.append("Red noise filter diagnostics\n\n")
            lines.append(f"name                  = {run_name}\n")
            lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
            lines.append(f"WPS_NOISE_THRESHOLD   = {wps_noise_threshold}\n\n")
            if diag.get("skipped", False):
                lines.append(f"SKIPPED: {diag.get('reason','unknown')}\n")
            else:
                lines.append(f"n_coeff_total        = {diag.get('n_coeff_total')}\n")
                lines.append(f"n_zero_after_white   = {diag.get('n_zero_after_white')}\n")
                lines.append(f"n_zero_after_scaled  = {diag.get('n_zero_after_scaled')}\n")
                lines.append(f"sMAD_WPS min         = {diag.get('sMAD_min')}\n")
                lines.append(f"sMAD_WPS median      = {diag.get('sMAD_median')}\n")
                lines.append(f"WPS_scaled min       = {diag.get('WPS_scaled_min')}\n")
                lines.append(f"WPS_scaled median    = {diag.get('WPS_scaled_median')}\n")
                lines.append(f"WPS_scaled max       = {diag.get('WPS_scaled_max')}\n")
            (outdir / "02a_rednoise_diagnostics.txt").write_text("".join(lines))
    else:
        cwt = cwt_raw

    rec_wavy = transform.reconstruct2d(cwt)  # (nx, ny)
    wavy_xy = rec_wavy.T - np.median(rec_wavy)

    quicklook_background_decomp_4panel_save(
        x1d_km,
        y1d_km,
        proc0,
        background,
        remaining,
        remaining_tapered,
        TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_5panel.png",
        wavy_after_noise_xy=wavy_xy,
        save_plots=save_plots,
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=min_amp, thr=thr)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    cmap_cwt = matplotlib.cm.turbo
    norm_cwt = matplotlib.colors.BoundaryNorm(np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N)
    fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
    save_fig(fig_cwt, outdir / "02_decomposition_overview.png", enable=save_plots)

    plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
    fig_spec = plt.gcf()
    save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png", enable=save_plots)

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text(
            "No clusters found.\n\n"
            f"Run name: {run_name}\n"
            f"Used MIN_AMP={min_amp}, THR={thr}\n"
            f"Used WHITE_NOISE_THRESHOLD={white_noise_threshold}, WPS_NOISE_THRESHOLD={wps_noise_threshold}\n\n"
            "Try lowering MIN_AMP or THR.\n"
            "If red noise filter is on, try lowering WPS_NOISE_THRESHOLD or WHITE_NOISE_THRESHOLD.\n"
        )
        remaining_core_xy = crop_pad_core(proc)
        nan_core = np.full_like(remaining_core_xy, np.nan)

        cleanup_memory()
        return {
            "has_clusters": False,
            "x_start_unbinned": core_start_unbinned,
            "dx_km": dx_km,
            "dy_km": dy_km,
            "remaining_xy": remaining_core_xy,
            "wavy_xy": nan_core,
            "rec_all_xy": nan_core,
            "cluster_records": [],
        }

    power_abs_map = {int(k): float(p) for k, p in zip(cluster_ids, P_abs)}
    power_pct_map = {int(k): float(p) for k, p in zip(cluster_ids, P_pct)}

    cluster_records: List[Dict[str, Any]] = []
    for kcl in cluster_ids.astype(int):
        kcl = int(kcl)

        A_xy, theta_xy = cluster_amp_theta_maps(
            cwt,
            iwave,
            kcl,
            amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX,
        )
        lam_xy = cluster_dominant_lambda_map(cwt, iwave, kcl, amp_mask_xy=A_xy)

        rec_core = None
        if STORE_CLUSTER_RECON:
            decomposition[:] = orig_decomp
            decomposition[iwave != kcl] = 0
            rec = transform.reconstruct2d(cwt)  # (nx, ny)
            rec_xy = rec.T
            rec_xy = rec_xy - np.nanmedian(rec_xy)
            rec_core = crop_pad_core(rec_xy)
            decomposition[:] = orig_decomp

        A_core = crop_pad_core(A_xy)
        th_core = crop_pad_core(theta_xy)
        lam_core = crop_pad_core(lam_xy)

        n_pix = int(np.count_nonzero(np.isfinite(A_core)))
        area_km2 = float(n_pix) * float(dx_km) * float(dy_km)

        cluster_records.append(
            dict(
                slice_no=int(slice_no),
                kcl=kcl,
                area_km2=area_km2,
                power_abs=power_abs_map.get(kcl, np.nan),
                power_pct=power_pct_map.get(kcl, np.nan),
                A_xy=A_core,
                lam_xy=lam_core,
                theta_xy=th_core,
                rec_xy=rec_core,
            )
        )

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    lines = []
    lines.append("Cluster power ranking (clustered only)\n\n")
    lines.append(f"name = {run_name}\n")
    lines.append(f"MIN_AMP = {min_amp}\n")
    lines.append(f"THR = {thr}\n")
    lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
    lines.append(f"WPS_NOISE_THRESHOLD = {wps_noise_threshold}\n\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]

    nrow = int(np.ceil(np.sqrt(n_show)))
    ncol = int(np.ceil(n_show / nrow))
    theta_vals = np.asarray(cwt["theta"], dtype=float)

    def plot_cluster_grid(kind: str, outname: str) -> None:
        fig, axs = plt.subplots(nrow, ncol, figsize=(12, 10))
        axs = np.atleast_1d(axs).reshape(-1)

        bg_vmin, bg_vmax = diverging_limits(bg, p_lo=2, p_hi=98)
        number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}

        for ax, kcl in zip(axs, biggest):
            decomposition[:] = orig_decomp
            decomposition[iwave != kcl] = 0
            rec = transform.reconstruct2d(cwt)
            rec_centered = rec.T - np.median(rec)

            s_idx = int(idxs[kcl][0])
            t_idx = int(idxs[kcl][1])
            _, _, lam = effective_lambda(cwt, s_idx, t_idx)

            theta_dom_rad = float(theta_vals[t_idx])
            theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

            ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
            Pk = float(P_abs_sorted[ii])
            pk = float(P_pct_sorted[ii])

            if kind == "standalone":
                ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0)
            elif kind == "overlay":
                ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
                ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0, alpha=0.6)
            else:
                raise ValueError(kind)

            ax.set_title(
                rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
                + "\n"
                + rf"P={Pk:.2e} ({pk:.1f}%)"
            )
            ax.set_aspect("equal", adjustable="box")

        for ax in axs[n_show:]:
            ax.axis("off")
        for ax in axs[:n_show]:
            ax.set_xlabel("x (km)")
            ax.set_ylabel("y (km)")

        for i, ax in enumerate(axs, start=1):
            if ax.has_data():
                ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

        fig.tight_layout()
        save_fig(fig, outdir / outname, enable=save_plots)

    plot_cluster_grid("standalone", "05_clusters_standalone.png")
    plot_cluster_grid("overlay", "06_clusters_overlay.png")

    for kcl in biggest:
        plot_cluster_individual_save(
            cwt=cwt,
            iwave=iwave,
            kcl=int(kcl),
            x1d_km=x1d_km,
            y1d_km=y1d_km,
            orig_decomp=orig_decomp,
            bg_xy=bg,
            dx_km=dx_km,
            dy_km=dy_km,
            outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
            save_plots=save_plots,
        )

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)
    decomposition[:] = orig_decomp

    remaining_after_preproc_xy = proc
    vmin, vmax = diverging_limits(remaining_after_preproc_xy, wavy_xy, rec_all_xy, p_lo=2, p_hi=98)

    figR, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(18, 8), constrained_layout=True, sharex=True, sharey=True)

    im1 = ax1.pcolormesh(x1d_km, y1d_km, remaining_after_preproc_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    ax1.set_title("Remaining (after preprocessing, input to CWT)")
    ax1.set_xlabel("x (km)")
    ax1.set_ylabel("y (km)")
    ax1.set_aspect("equal", adjustable="box")

    im2 = ax2.pcolormesh(x1d_km, y1d_km, wavy_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    ax2.set_title("Wavy stuff (wavelet reconstruction after noise filtering)")
    ax2.set_xlabel("x (km)")
    ax2.set_ylabel("y (km)")
    ax2.set_aspect("equal", adjustable="box")

    im3 = ax3.pcolormesh(x1d_km, y1d_km, rec_all_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    ax3.set_title("Reconstruction after clustering (all clusters combined)")
    ax3.set_xlabel("x (km)")
    ax3.set_ylabel("y (km)")
    ax3.set_aspect("equal", adjustable="box")

    cbar = figR.colorbar(im1, ax=[ax1, ax2, ax3], orientation="vertical", fraction=0.015, pad=0.01)
    cbar.set_label("arb")
    save_fig(figR, outdir / "09_remaining_vs_wavy_vs_allclusters.png", enable=save_plots)

    remaining_core_xy = crop_pad_core(remaining_after_preproc_xy)
    wavy_core_xy = crop_pad_core(wavy_xy)
    rec_all_core_xy = crop_pad_core(rec_all_xy)

    # Free big intermediates before returning
    try:
        del raw_win, proc0, plane, detrended, fourier_bg, background, remaining, remaining_tapered, proc, wave_xy
        del cwt_raw, cwt, amps, idxs, iwave, decomposition, orig_decomp, rec_wavy, rec_all
        del bg, cluster_ids, P_abs, P_pct, cluster_ids_sorted, P_abs_sorted, P_pct_sorted
    except Exception:
        pass
    cleanup_memory()

    return {
        "has_clusters": True,
        "x_start_unbinned": core_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "remaining_xy": remaining_core_xy,
        "wavy_xy": wavy_core_xy,
        "rec_all_xy": rec_all_core_xy,
        "cluster_records": cluster_records,
    }


def stitch_and_save_final_09(slice_results: List[Dict[str, Any]], outroot: Path, tag: str) -> None:
    if not slice_results:
        return

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE

    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    wavy_stitched = np.concatenate([d["wavy_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)

    ny, nx_tot = remaining_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    vmin, vmax = diverging_limits(remaining_stitched, wavy_stitched, rec_all_stitched, p_lo=2, p_hi=98)

    figR, (axT, axM, axB) = plt.subplots(3, 1, figsize=(18, 6), constrained_layout=True, sharex=True, sharey=True)

    imT = axT.pcolormesh(x1d_km, y1d_km, remaining_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axT.set_title(f"STITCHED (core tiles) {tag}: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imM = axM.pcolormesh(x1d_km, y1d_km, wavy_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axM.set_title(f"STITCHED (core tiles) {tag}: Wavy stuff (wavelet reconstruction after noise filtering)")
    axM.set_xlabel("x (km)")
    axM.set_ylabel("y (km)")
    axM.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(x1d_km, y1d_km, rec_all_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axB.set_title(f"STITCHED (core tiles) {tag}: Reconstruction after clustering (all clusters combined)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    # keep your xlim choice
    axT.set_xlim(600, 10000)

    cbar = figR.colorbar(imT, ax=[axT, axM, axB], orientation="vertical", fraction=0.012, pad=0.01)
    if PRODUCT_TYPE == "l3a":
        cbar.set_label("K (Relative)")
    else:
        cbar.set_label("kRayleigh (Relative)")

    save_fig(figR, outroot / f"FINAL_09_remaining_vs_wavy_vs_allclusters_STITCHED_{tag}.png", enable=bool(SAVE_STITCHED_PLOT))

    # stitched arrays can be large too
    try:
        del remaining_stitched, wavy_stitched, rec_all_stitched
    except Exception:
        pass
    cleanup_memory()


def run_all_slices_single_offset(cfg: Dict[str, Any]) -> None:
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    rad2d = read_frame_auto(FILE_PATH, FRAME_IDX)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    x_offset = int(X_OFFSET)
    if x_offset >= nx_total:
        raise ValueError(f"X_OFFSET={x_offset} too large for nx_total={nx_total}")

    run_name = str(cfg.get("name", "run"))
    outroot = OUTPUT_ROOT / f"{run_name}_offset_{x_offset:04d}"
    outroot.mkdir(parents=True, exist_ok=True)

    (outroot / "RUN_CONFIG.txt").write_text("\n".join([f"{k} = {v}" for k, v in cfg.items()]) + "\n")

    core_starts = list(range(x_offset, nx_total, X_CHUNK))
    stitch_results: List[Dict[str, Any]] = []
    all_cluster_records: List[Dict[str, Any]] = []

    f = int(BIN_FACTOR) if (APPLY_BINNING and int(BIN_FACTOR) > 1) else 1
    y_dim = int(rad2d_flat[Y_SLICE, :].shape[0] // f)
    x_dim = int(X_CHUNK // f)

    for slice_no, core_start in enumerate(core_starts):
        core_end = min(core_start + X_CHUNK, nx_total)

        ext_start = max(0, core_start - SLICE_PAD)
        ext_end = min(nx_total, core_end + SLICE_PAD)
        x_slice = slice(ext_start, ext_end)

        outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
        print(f"[{run_name} | offset {x_offset}] core={core_start}:{core_end} ext={ext_start}:{ext_end} saved to {outdir}")

        res = run_pipeline_for_slice(
            rad2d_flat=rad2d_flat,
            x_slice=x_slice,
            outdir=outdir,
            x_start_unbinned=ext_start,
            core_start_unbinned=core_start,
            core_end_unbinned=core_end,
            cfg=cfg,
            slice_no=slice_no,
        )

        stitch_results.append(res)
        all_cluster_records.extend(res.get("cluster_records", []))

        # slice level cleanup
        cleanup_memory()

    stitch_and_save_final_09(stitch_results, outroot, tag=f"{run_name}_offset_{x_offset:04d}")
    print("Done. Outputs in", outroot.resolve())

    out_path = make_output_cluster_path(FILE_PATH)
    out_path = outroot / out_path.name

    copy_lxc_to_l6x_with_clusters(
        lxc_path=FILE_PATH,
        l6x_path=out_path,
        clusters=all_cluster_records,
        y_dim=y_dim,
        x_dim=x_dim,
        unbin_factor=(BIN_FACTOR if (APPLY_BINNING and int(BIN_FACTOR) > 1) else 1),
    )

    print("Saved output with clusters:", out_path.resolve())

    # final cleanup
    try:
        del rad2d, rad2d_flat, stitch_results, all_cluster_records
    except Exception:
        pass
    cleanup_memory()


for cfg in RUNS:
    run_all_slices_single_offset(cfg)
# Out:
# Detected product type: l3c
# Using RUNS: [{'name': 'base', 'MIN_AMP': 0.2, 'THR': 0.1, 'WHITE_NOISE_THRESHOLD': 0.02, 'WPS_NOISE_THRESHOLD': 8.0}]
# [base | offset 0] core=0:600 ext=0:650 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_00000_00600_xext_00000_00650
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.36263973266648974 idx= (np.int64(9), np.int64(0), np.int64(124), np.int64(90))
# selected elements: 214884
# ------------
# cluster= 1
# amplitude= 0.2399267718806651 idx= (np.int64(20), np.int64(5), np.int64(215), np.int64(103))
# selected elements: 73714
# ------------
# cluster= 2
# amplitude= 0.22184215081310177 idx= (np.int64(23), np.int64(17), np.int64(126), np.int64(99))
# selected elements: 37676
# ------------
# cluster= 3
# amplitude= 0.2142571595130233 idx= (np.int64(9), np.int64(17), np.int64(124), np.int64(90))
# selected elements: 20792
# ------------
# cluster= 4
# amplitude= 0.21340207304854686 idx= (np.int64(15), np.int64(17), np.int64(125), np.int64(88))
# selected elements: 29047
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 85.28it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=600:1200 ext=550:1250 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_00600_01200_xext_00550_01250
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.30251293061893275 idx= (np.int64(0), np.int64(9), np.int64(322), np.int64(92))
# selected elements: 11915
# ------------
# cluster= 1
# amplitude= 0.20530777205144154 idx= (np.int64(11), np.int64(10), np.int64(310), np.int64(132))
# selected elements: 21657
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 87.53it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=1200:1800 ext=1150:1850 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_01200_01800_xext_01150_01850
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.39422487261875894 idx= (np.int64(4), np.int64(9), np.int64(63), np.int64(119))
# selected elements: 39767
# ------------
# cluster= 1
# amplitude= 0.30251421449155497 idx= (np.int64(0), np.int64(9), np.int64(22), np.int64(92))
# selected elements: 11591
# ------------
# cluster= 2
# amplitude= 0.29088116447996043 idx= (np.int64(23), np.int64(9), np.int64(46), np.int64(128))
# selected elements: 28727
# ------------
# cluster= 3
# amplitude= 0.28336736662586054 idx= (np.int64(20), np.int64(13), np.int64(278), np.int64(63))
# selected elements: 110549
# ------------
# cluster= 4
# amplitude= 0.2747495991126669 idx= (np.int64(6), np.int64(13), np.int64(316), np.int64(41))
# selected elements: 19508
# ------------
# cluster= 5
# amplitude= 0.258893110807917 idx= (np.int64(16), np.int64(9), np.int64(247), np.int64(8))
# selected elements: 37300
# ------------
# cluster= 6
# amplitude= 0.25443313256453426 idx= (np.int64(23), np.int64(12), np.int64(309), np.int64(44))
# selected elements: 12892
# ------------
# cluster= 7
# amplitude= 0.25177705283399243 idx= (np.int64(22), np.int64(15), np.int64(196), np.int64(93))
# selected elements: 36456
# ------------
# cluster= 8
# amplitude= 0.242205639705965 idx= (np.int64(12), np.int64(14), np.int64(186), np.int64(93))
# selected elements: 49997
# ------------
# cluster= 9
# amplitude= 0.23280925135776437 idx= (np.int64(22), np.int64(12), np.int64(221), np.int64(96))
# selected elements: 12617
# ------------
# cluster= 10
# amplitude= 0.2290477017568164 idx= (np.int64(16), np.int64(13), np.int64(298), np.int64(101))
# selected elements: 19534
# ------------
# cluster= 11
# amplitude= 0.22827852935838044 idx= (np.int64(12), np.int64(11), np.int64(68), np.int64(121))
# selected elements: 21585
# ------------
# cluster= 12
# amplitude= 0.2268533056480399 idx= (np.int64(16), np.int64(13), np.int64(164), np.int64(129))
# selected elements: 14907
# ------------
# cluster= 13
# amplitude= 0.21412607786706325 idx= (np.int64(10), np.int64(9), np.int64(245), np.int64(5))
# selected elements: 3958
# ------------
# cluster= 14
# amplitude= 0.21157640807751174 idx= (np.int64(3), np.int64(13), np.int64(181), np.int64(86))
# selected elements: 8783
# ------------
# cluster= 15
# amplitude= 0.20751382515170652 idx= (np.int64(17), np.int64(9), np.int64(30), np.int64(144))
# selected elements: 9897
# ------------
# cluster= 16
# amplitude= 0.20549135469820332 idx= (np.int64(9), np.int64(13), np.int64(157), np.int64(74))
# selected elements: 2062
# ------------
# cluster= 17
# amplitude= 0.20277902984820917 idx= (np.int64(8), np.int64(12), np.int64(112), np.int64(111))
# selected elements: 11169
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 80.31it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=1800:2400 ext=1750:2450 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_01800_02400_xext_01750_02450
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.904495054402696 idx= (np.int64(6), np.int64(11), np.int64(326), np.int64(69))
# selected elements: 681301
# ------------
# cluster= 1
# amplitude= 0.6888022873679569 idx= (np.int64(23), np.int64(12), np.int64(311), np.int64(61))
# selected elements: 512003
# ------------
# cluster= 2
# amplitude= 0.6802757365532129 idx= (np.int64(21), np.int64(11), np.int64(309), np.int64(64))
# selected elements: 61073
# ------------
# cluster= 3
# amplitude= 0.6004625430081533 idx= (np.int64(1), np.int64(11), np.int64(275), np.int64(94))
# selected elements: 15333
# ------------
# cluster= 4
# amplitude= 0.5708110947761935 idx= (np.int64(2), np.int64(12), np.int64(215), np.int64(71))
# selected elements: 16282
# ------------
# cluster= 5
# amplitude= 0.540341857425534 idx= (np.int64(2), np.int64(10), np.int64(276), np.int64(96))
# selected elements: 11007
# ------------
# cluster= 6
# amplitude= 0.5062007573041005 idx= (np.int64(12), np.int64(12), np.int64(204), np.int64(95))
# selected elements: 72547
# ------------
# cluster= 7
# amplitude= 0.4787314050486044 idx= (np.int64(2), np.int64(12), np.int64(174), np.int64(43))
# selected elements: 3553
# ------------
# cluster= 8
# amplitude= 0.46422953826977076 idx= (np.int64(0), np.int64(12), np.int64(295), np.int64(51))
# selected elements: 11098
# ------------
# cluster= 9
# amplitude= 0.4529381068644895 idx= (np.int64(8), np.int64(11), np.int64(333), np.int64(126))
# selected elements: 1990
# ------------
# cluster= 10
# amplitude= 0.42514122334305954 idx= (np.int64(9), np.int64(13), np.int64(113), np.int64(67))
# selected elements: 119775
# ------------
# cluster= 11
# amplitude= 0.41974604087841483 idx= (np.int64(1), np.int64(13), np.int64(214), np.int64(70))
# selected elements: 1511
# ------------
# cluster= 12
# amplitude= 0.41172160940065505 idx= (np.int64(18), np.int64(11), np.int64(322), np.int64(128))
# selected elements: 21568
# ------------
# cluster= 13
# amplitude= 0.4087568721218457 idx= (np.int64(19), np.int64(13), np.int64(91), np.int64(81))
# selected elements: 85871
# ------------
# cluster= 14
# amplitude= 0.40526944415233734 idx= (np.int64(8), np.int64(11), np.int64(180), np.int64(129))
# selected elements: 5632
# ------------
# cluster= 15
# amplitude= 0.4022550920742804 idx= (np.int64(9), np.int64(10), np.int64(332), np.int64(127))
# selected elements: 6568
# ------------
# cluster= 16
# amplitude= 0.3965510601942493 idx= (np.int64(22), np.int64(10), np.int64(295), np.int64(128))
# selected elements: 9977
# ------------
# cluster= 17
# amplitude= 0.39084469558422086 idx= (np.int64(14), np.int64(13), np.int64(288), np.int64(33))
# selected elements: 69511
# ------------
# cluster= 18
# amplitude= 0.3531680225999842 idx= (np.int64(14), np.int64(13), np.int64(204), np.int64(91))
# selected elements: 48386
# ------------
# cluster= 19
# amplitude= 0.3472699345028102 idx= (np.int64(5), np.int64(10), np.int64(288), np.int64(128))
# selected elements: 10834
# ------------
# cluster= 20
# amplitude= 0.3433686848940297 idx= (np.int64(5), np.int64(13), np.int64(230), np.int64(16))
# selected elements: 2758
# ------------
# cluster= 21
# amplitude= 0.33961028245203084 idx= (np.int64(5), np.int64(11), np.int64(222), np.int64(126))
# selected elements: 1033
# ------------
# cluster= 22
# amplitude= 0.33323951940452545 idx= (np.int64(2), np.int64(9), np.int64(304), np.int64(20))
# selected elements: 11916
# ------------
# cluster= 23
# amplitude= 0.32032059052280165 idx= (np.int64(5), np.int64(11), np.int64(329), np.int64(99))
# selected elements: 7259
# ------------
# cluster= 24
# amplitude= 0.31680010881924137 idx= (np.int64(6), np.int64(13), np.int64(317), np.int64(13))
# selected elements: 1701
# ------------
# cluster= 25
# amplitude= 0.31492669462288364 idx= (np.int64(12), np.int64(10), np.int64(333), np.int64(130))
# selected elements: 6606
# ------------
# cluster= 26
# amplitude= 0.31278303845607885 idx= (np.int64(21), np.int64(10), np.int64(222), np.int64(88))
# selected elements: 4120
# ------------
# cluster= 27
# amplitude= 0.31246885400267554 idx= (np.int64(0), np.int64(12), np.int64(318), np.int64(58))
# selected elements: 356
# ------------
# cluster= 28
# amplitude= 0.30958642467783976 idx= (np.int64(19), np.int64(11), np.int64(203), np.int64(95))
# selected elements: 3066
# ------------
# cluster= 29
# amplitude= 0.3088818286233461 idx= (np.int64(13), np.int64(11), np.int64(288), np.int64(31))
# selected elements: 5523
# ------------
# cluster= 30
# amplitude= 0.30446157930719214 idx= (np.int64(11), np.int64(12), np.int64(333), np.int64(130))
# selected elements: 2214
# ------------
# cluster= 31
# amplitude= 0.30234756076525243 idx= (np.int64(6), np.int64(9), np.int64(327), np.int64(47))
# selected elements: 2692
# ------------
# cluster= 32
# amplitude= 0.2890133409998655 idx= (np.int64(4), np.int64(12), np.int64(166), np.int64(104))
# selected elements: 5051
# ------------
# cluster= 33
# amplitude= 0.2784910124993449 idx= (np.int64(3), np.int64(13), np.int64(174), np.int64(43))
# selected elements: 3846
# ------------
# cluster= 34
# amplitude= 0.2774123559994985 idx= (np.int64(20), np.int64(12), np.int64(329), np.int64(134))
# selected elements: 10026
# ------------
# cluster= 35
# amplitude= 0.27398406802733843 idx= (np.int64(23), np.int64(14), np.int64(339), np.int64(108))
# selected elements: 9836
# ------------
# cluster= 36
# amplitude= 0.27118350196186336 idx= (np.int64(22), np.int64(12), np.int64(330), np.int64(135))
# selected elements: 1507
# ------------
# cluster= 37
# amplitude= 0.2706347125881583 idx= (np.int64(18), np.int64(11), np.int64(110), np.int64(113))
# selected elements: 10364
# ------------
# cluster= 38
# amplitude= 0.26657278988315697 idx= (np.int64(6), np.int64(13), np.int64(17), np.int64(41))
# selected elements: 16911
# ------------
# cluster= 39
# amplitude= 0.26142325290450197 idx= (np.int64(22), np.int64(15), np.int64(126), np.int64(58))
# selected elements: 35284
# ------------
# cluster= 40
# amplitude= 0.2599021471574405 idx= (np.int64(3), np.int64(13), np.int64(227), np.int64(16))
# selected elements: 972
# ------------
# cluster= 41
# amplitude= 0.25694066547459804 idx= (np.int64(5), np.int64(13), np.int64(153), np.int64(114))
# selected elements: 3809
# ------------
# cluster= 42
# amplitude= 0.25534678355854123 idx= (np.int64(2), np.int64(13), np.int64(232), np.int64(41))
# selected elements: 1273
# ------------
# cluster= 43
# amplitude= 0.2551507772843031 idx= (np.int64(0), np.int64(10), np.int64(240), np.int64(80))
# selected elements: 560
# ------------
# cluster= 44
# amplitude= 0.2550589932281035 idx= (np.int64(1), np.int64(11), np.int64(232), np.int64(40))
# selected elements: 1219
# ------------
# cluster= 45
# amplitude= 0.2526112978505159 idx= (np.int64(5), np.int64(13), np.int64(117), np.int64(52))
# selected elements: 4257
# ------------
# cluster= 46
# amplitude= 0.24928365447220072 idx= (np.int64(3), np.int64(13), np.int64(152), np.int64(88))
# selected elements: 5449
# ------------
# cluster= 47
# amplitude= 0.2478051506363776 idx= (np.int64(12), np.int64(11), np.int64(204), np.int64(29))
# selected elements: 6490
# ------------
# cluster= 48
# amplitude= 0.2465472964434813 idx= (np.int64(9), np.int64(14), np.int64(69), np.int64(31))
# selected elements: 9552
# ------------
# cluster= 49
# amplitude= 0.24484156959230513 idx= (np.int64(6), np.int64(12), np.int64(336), np.int64(122))
# selected elements: 1298
# ------------
# cluster= 50
# amplitude= 0.24377076676120055 idx= (np.int64(7), np.int64(9), np.int64(335), np.int64(16))
# selected elements: 1617
# ------------
# cluster= 51
# amplitude= 0.24215631846079547 idx= (np.int64(14), np.int64(14), np.int64(119), np.int64(82))
# selected elements: 4007
# ------------
# cluster= 52
# amplitude= 0.2420613452885502 idx= (np.int64(7), np.int64(14), np.int64(96), np.int64(67))
# selected elements: 3952
# ------------
# cluster= 53
# amplitude= 0.24040094809847584 idx= (np.int64(5), np.int64(12), np.int64(50), np.int64(62))
# selected elements: 6923
# ------------
# cluster= 54
# amplitude= 0.24036586617073555 idx= (np.int64(0), np.int64(11), np.int64(174), np.int64(44))
# selected elements: 697
# ------------
# cluster= 55
# amplitude= 0.24012745825102313 idx= (np.int64(6), np.int64(12), np.int64(185), np.int64(16))
# selected elements: 786
# ------------
# cluster= 56
# amplitude= 0.23992106320166232 idx= (np.int64(9), np.int64(10), np.int64(297), np.int64(89))
# selected elements: 1022
# ------------
# cluster= 57
# amplitude= 0.23736432895514914 idx= (np.int64(1), np.int64(11), np.int64(333), np.int64(28))
# selected elements: 981
# ------------
# cluster= 58
# amplitude= 0.23715731444618765 idx= (np.int64(3), np.int64(9), np.int64(326), np.int64(47))
# selected elements: 1263
# ------------
# cluster= 59
# amplitude= 0.23694585689851166 idx= (np.int64(4), np.int64(10), np.int64(240), np.int64(88))
# selected elements: 2156
# ------------
# cluster= 60
# amplitude= 0.23488098634008692 idx= (np.int64(23), np.int64(11), np.int64(69), np.int64(124))
# selected elements: 13658
# ------------
# cluster= 61
# amplitude= 0.23263427623624847 idx= (np.int64(11), np.int64(12), np.int64(39), np.int64(58))
# selected elements: 15721
# ------------
# cluster= 62
# amplitude= 0.23227162138181803 idx= (np.int64(1), np.int64(13), np.int64(175), np.int64(44))
# selected elements: 1219
# ------------
# cluster= 63
# amplitude= 0.2311505705214241 idx= (np.int64(9), np.int64(12), np.int64(46), np.int64(100))
# selected elements: 11615
# ------------
# cluster= 64
# amplitude= 0.2297319283710547 idx= (np.int64(23), np.int64(9), np.int64(333), np.int64(68))
# selected elements: 3970
# ------------
# cluster= 65
# amplitude= 0.22661433260715028 idx= (np.int64(0), np.int64(10), np.int64(333), np.int64(62))
# selected elements: 230
# ------------
# cluster= 66
# amplitude= 0.22442591648493107 idx= (np.int64(3), np.int64(13), np.int64(339), np.int64(39))
# selected elements: 1079
# ------------
# cluster= 67
# amplitude= 0.22262118594462493 idx= (np.int64(13), np.int64(9), np.int64(339), np.int64(76))
# selected elements: 5251
# ------------
# cluster= 68
# amplitude= 0.21976279343948313 idx= (np.int64(15), np.int64(11), np.int64(94), np.int64(114))
# selected elements: 6718
# ------------
# cluster= 69
# amplitude= 0.2185081820117388 idx= (np.int64(1), np.int64(12), np.int64(295), np.int64(97))
# selected elements: 1072
# ------------
# cluster= 70
# amplitude= 0.2146941519844131 idx= (np.int64(2), np.int64(12), np.int64(226), np.int64(125))
# selected elements: 2650
# ------------
# cluster= 71
# amplitude= 0.21464114590189942 idx= (np.int64(0), np.int64(13), np.int64(209), np.int64(49))
# selected elements: 424
# ------------
# cluster= 72
# amplitude= 0.21095559362815192 idx= (np.int64(3), np.int64(11), np.int64(162), np.int64(99))
# selected elements: 1010
# ------------
# cluster= 73
# amplitude= 0.20796894861451895 idx= (np.int64(23), np.int64(9), np.int64(230), np.int64(75))
# selected elements: 3211
# ------------
# cluster= 74
# amplitude= 0.2066069278499313 idx= (np.int64(1), np.int64(11), np.int64(253), np.int64(65))
# selected elements: 630
# ------------
# cluster= 75
# amplitude= 0.2055786411970637 idx= (np.int64(1), np.int64(13), np.int64(309), np.int64(38))
# selected elements: 454
# ------------
# cluster= 76
# amplitude= 0.20531415605105077 idx= (np.int64(0), np.int64(12), np.int64(253), np.int64(66))
# selected elements: 289
# ------------
# cluster= 77
# amplitude= 0.20410953108398636 idx= (np.int64(6), np.int64(10), np.int64(197), np.int64(60))
# selected elements: 2880
# ------------
# cluster= 78
# amplitude= 0.20219669794302206 idx= (np.int64(3), np.int64(14), np.int64(268), np.int64(11))
# selected elements: 1499
# ------------
# cluster= 79
# amplitude= 0.20212388056999217 idx= (np.int64(1), np.int64(13), np.int64(276), np.int64(54))
# selected elements: 379
# ------------
# cluster= 80
# amplitude= 0.20160435955547354 idx= (np.int64(4), np.int64(11), np.int64(243), np.int64(121))
# selected elements: 719
# ------------
# cluster= 81
# amplitude= 0.2013045704762022 idx= (np.int64(18), np.int64(13), np.int64(337), np.int64(73))
# selected elements: 4829
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 83.32it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=2400:3000 ext=2350:3050 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_02400_03000_xext_02350_03050
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.9062631306848401 idx= (np.int64(6), np.int64(11), np.int64(26), np.int64(69))
# selected elements: 434886
# ------------
# cluster= 1
# amplitude= 0.7757797865084223 idx= (np.int64(22), np.int64(6), np.int64(264), np.int64(100))
# selected elements: 231264
# ------------
# cluster= 2
# amplitude= 0.5936111768844795 idx= (np.int64(8), np.int64(10), np.int64(184), np.int64(55))
# selected elements: 179338
# ------------
# cluster= 3
# amplitude= 0.5934578413098209 idx= (np.int64(4), np.int64(7), np.int64(261), np.int64(91))
# selected elements: 102204
# ------------
# cluster= 4
# amplitude= 0.5777230606000325 idx= (np.int64(23), np.int64(11), np.int64(31), np.int64(70))
# selected elements: 244200
# ------------
# cluster= 5
# amplitude= 0.5557010839891114 idx= (np.int64(22), np.int64(10), np.int64(86), np.int64(125))
# selected elements: 20305
# ------------
# cluster= 6
# amplitude= 0.4785609808954426 idx= (np.int64(13), np.int64(7), np.int64(252), np.int64(72))
# selected elements: 89644
# ------------
# cluster= 7
# amplitude= 0.4769431951138775 idx= (np.int64(8), np.int64(12), np.int64(16), np.int64(13))
# selected elements: 5875
# ------------
# cluster= 8
# amplitude= 0.4671700020520447 idx= (np.int64(4), np.int64(8), np.int64(190), np.int64(80))
# selected elements: 22020
# ------------
# cluster= 9
# amplitude= 0.46168216877603724 idx= (np.int64(7), np.int64(9), np.int64(99), np.int64(35))
# selected elements: 20695
# ------------
# cluster= 10
# amplitude= 0.4611976226206019 idx= (np.int64(9), np.int64(10), np.int64(74), np.int64(79))
# selected elements: 10985
# ------------
# cluster= 11
# amplitude= 0.45465121873162445 idx= (np.int64(18), np.int64(8), np.int64(204), np.int64(86))
# selected elements: 26783
# ------------
# cluster= 12
# amplitude= 0.4501124355100644 idx= (np.int64(4), np.int64(9), np.int64(170), np.int64(92))
# selected elements: 1900
# ------------
# cluster= 13
# amplitude= 0.4417054590740462 idx= (np.int64(20), np.int64(9), np.int64(93), np.int64(110))
# selected elements: 28311
# ------------
# cluster= 14
# amplitude= 0.4382895855006836 idx= (np.int64(11), np.int64(10), np.int64(101), np.int64(135))
# selected elements: 30197
# ------------
# cluster= 15
# amplitude= 0.4374077750863903 idx= (np.int64(7), np.int64(9), np.int64(97), np.int64(77))
# selected elements: 1982
# ------------
# cluster= 16
# amplitude= 0.4262742273539608 idx= (np.int64(13), np.int64(11), np.int64(39), np.int64(129))
# selected elements: 25763
# ------------
# cluster= 17
# amplitude= 0.4230641915408707 idx= (np.int64(5), np.int64(12), np.int64(17), np.int64(12))
# selected elements: 1195
# ------------
# cluster= 18
# amplitude= 0.41884981980843033 idx= (np.int64(4), np.int64(9), np.int64(105), np.int64(37))
# selected elements: 5979
# ------------
# cluster= 19
# amplitude= 0.41858335411369574 idx= (np.int64(6), np.int64(10), np.int64(207), np.int64(58))
# selected elements: 1572
# ------------
# cluster= 20
# amplitude= 0.40818909180079765 idx= (np.int64(19), np.int64(11), np.int64(26), np.int64(134))
# selected elements: 5864
# ------------
# cluster= 21
# amplitude= 0.39855329136299333 idx= (np.int64(9), np.int64(9), np.int64(145), np.int64(125))
# selected elements: 13022
# ------------
# cluster= 22
# amplitude= 0.3962712112801582 idx= (np.int64(9), np.int64(11), np.int64(19), np.int64(12))
# selected elements: 808
# ------------
# cluster= 23
# amplitude= 0.3922533876173972 idx= (np.int64(0), np.int64(10), np.int64(115), np.int64(28))
# selected elements: 2491
# ------------
# cluster= 24
# amplitude= 0.3907034836039974 idx= (np.int64(0), np.int64(11), np.int64(201), np.int64(57))
# selected elements: 1273
# ------------
# cluster= 25
# amplitude= 0.3882176378222456 idx= (np.int64(18), np.int64(10), np.int64(29), np.int64(134))
# selected elements: 2490
# ------------
# cluster= 26
# amplitude= 0.3832082525346751 idx= (np.int64(9), np.int64(10), np.int64(211), np.int64(58))
# selected elements: 1656
# ------------
# cluster= 27
# amplitude= 0.38224098944358353 idx= (np.int64(22), np.int64(9), np.int64(182), np.int64(108))
# selected elements: 17451
# ------------
# cluster= 28
# amplitude= 0.38144778990105754 idx= (np.int64(16), np.int64(10), np.int64(141), np.int64(26))
# selected elements: 35354
# ------------
# cluster= 29
# amplitude= 0.37785530490716046 idx= (np.int64(21), np.int64(11), np.int64(27), np.int64(136))
# selected elements: 6167
# ------------
# cluster= 30
# amplitude= 0.37430958614050064 idx= (np.int64(2), np.int64(9), np.int64(116), np.int64(28))
# selected elements: 7398
# ------------
# cluster= 31
# amplitude= 0.37367396812253617 idx= (np.int64(18), np.int64(9), np.int64(153), np.int64(35))
# selected elements: 2848
# ------------
# cluster= 32
# amplitude= 0.37259796157952596 idx= (np.int64(11), np.int64(12), np.int64(72), np.int64(81))
# selected elements: 6334
# ------------
# cluster= 33
# amplitude= 0.37177788668849776 idx= (np.int64(11), np.int64(9), np.int64(106), np.int64(30))
# selected elements: 6336
# ------------
# cluster= 34
# amplitude= 0.36820930292996806 idx= (np.int64(7), np.int64(9), np.int64(62), np.int64(115))
# selected elements: 11282
# ------------
# cluster= 35
# amplitude= 0.3578032136092608 idx= (np.int64(7), np.int64(13), np.int64(17), np.int64(14))
# selected elements: 1292
# ------------
# cluster= 36
# amplitude= 0.35499239149399286 idx= (np.int64(2), np.int64(12), np.int64(205), np.int64(58))
# selected elements: 4533
# ------------
# cluster= 37
# amplitude= 0.34964819066627 idx= (np.int64(8), np.int64(10), np.int64(100), np.int64(139))
# selected elements: 955
# ------------
# cluster= 38
# amplitude= 0.3489306665061807 idx= (np.int64(20), np.int64(9), np.int64(198), np.int64(98))
# selected elements: 15955
# ------------
# cluster= 39
# amplitude= 0.3426242757242496 idx= (np.int64(18), np.int64(11), np.int64(124), np.int64(30))
# selected elements: 21585
# ------------
# cluster= 40
# amplitude= 0.3397122092930723 idx= (np.int64(17), np.int64(12), np.int64(32), np.int64(125))
# selected elements: 4972
# ------------
# cluster= 41
# amplitude= 0.3358006087880805 idx= (np.int64(5), np.int64(7), np.int64(271), np.int64(53))
# selected elements: 4025
# ------------
# cluster= 42
# amplitude= 0.32949730258277665 idx= (np.int64(0), np.int64(11), np.int64(16), np.int64(56))
# selected elements: 4084
# ------------
# cluster= 43
# amplitude= 0.32099895965724795 idx= (np.int64(3), np.int64(11), np.int64(251), np.int64(101))
# selected elements: 8717
# ------------
# cluster= 44
# amplitude= 0.3207634895167894 idx= (np.int64(4), np.int64(7), np.int64(259), np.int64(122))
# selected elements: 6680
# ------------
# cluster= 45
# amplitude= 0.32050066242056874 idx= (np.int64(20), np.int64(7), np.int64(166), np.int64(113))
# selected elements: 9025
# ------------
# cluster= 46
# amplitude= 0.3109313058543332 idx= (np.int64(23), np.int64(9), np.int64(100), np.int64(16))
# selected elements: 8081
# ------------
# cluster= 47
# amplitude= 0.31057331655721343 idx= (np.int64(4), np.int64(11), np.int64(28), np.int64(99))
# selected elements: 2980
# ------------
# cluster= 48
# amplitude= 0.309771137804413 idx= (np.int64(3), np.int64(13), np.int64(60), np.int64(27))
# selected elements: 6846
# ------------
# cluster= 49
# amplitude= 0.3052126056661874 idx= (np.int64(8), np.int64(12), np.int64(32), np.int64(127))
# selected elements: 1951
# ------------
# cluster= 50
# amplitude= 0.3047321227629021 idx= (np.int64(20), np.int64(11), np.int64(91), np.int64(119))
# selected elements: 3509
# ------------
# cluster= 51
# amplitude= 0.30426077721004263 idx= (np.int64(6), np.int64(8), np.int64(268), np.int64(53))
# selected elements: 383
# ------------
# cluster= 52
# amplitude= 0.3017377360753696 idx= (np.int64(4), np.int64(9), np.int64(27), np.int64(46))
# selected elements: 3087
# ------------
# cluster= 53
# amplitude= 0.30063329376615283 idx= (np.int64(7), np.int64(8), np.int64(267), np.int64(123))
# selected elements: 6213
# ------------
# cluster= 54
# amplitude= 0.29918765938752195 idx= (np.int64(9), np.int64(9), np.int64(63), np.int64(115))
# selected elements: 580
# ------------
# cluster= 55
# amplitude= 0.2990607463213299 idx= (np.int64(3), np.int64(8), np.int64(148), np.int64(122))
# selected elements: 3240
# ------------
# cluster= 56
# amplitude= 0.2974301702099178 idx= (np.int64(8), np.int64(5), np.int64(276), np.int64(52))
# selected elements: 16312
# ------------
# cluster= 57
# amplitude= 0.29658265364066316 idx= (np.int64(3), np.int64(13), np.int64(8), np.int64(40))
# selected elements: 1937
# ------------
# cluster= 58
# amplitude= 0.29528950048451874 idx= (np.int64(2), np.int64(12), np.int64(142), np.int64(35))
# selected elements: 4529
# ------------
# cluster= 59
# amplitude= 0.29442387423356103 idx= (np.int64(7), np.int64(9), np.int64(99), np.int64(138))
# selected elements: 3033
# ------------
# cluster= 60
# amplitude= 0.29409037850192205 idx= (np.int64(4), np.int64(7), np.int64(231), np.int64(38))
# selected elements: 2865
# ------------
# cluster= 61
# amplitude= 0.2923228712161638 idx= (np.int64(7), np.int64(7), np.int64(197), np.int64(84))
# selected elements: 1514
# ------------
# cluster= 62
# amplitude= 0.29090324767056513 idx= (np.int64(8), np.int64(10), np.int64(152), np.int64(33))
# selected elements: 7990
# ------------
# cluster= 63
# amplitude= 0.28914775913368024 idx= (np.int64(0), np.int64(5), np.int64(250), np.int64(94))
# selected elements: 335
# ------------
# cluster= 64
# amplitude= 0.28878688644966777 idx= (np.int64(5), np.int64(10), np.int64(257), np.int64(54))
# selected elements: 4597
# ------------
# cluster= 65
# amplitude= 0.2854052608355351 idx= (np.int64(2), np.int64(10), np.int64(30), np.int64(27))
# selected elements: 1818
# ------------
# cluster= 66
# amplitude= 0.281592159885186 idx= (np.int64(4), np.int64(6), np.int64(225), np.int64(78))
# selected elements: 6672
# ------------
# cluster= 67
# amplitude= 0.27842592264192345 idx= (np.int64(20), np.int64(10), np.int64(237), np.int64(50))
# selected elements: 15165
# ------------
# cluster= 68
# amplitude= 0.2782716519726374 idx= (np.int64(1), np.int64(9), np.int64(93), np.int64(24))
# selected elements: 1303
# ------------
# cluster= 69
# amplitude= 0.2758956179509263 idx= (np.int64(1), np.int64(12), np.int64(71), np.int64(77))
# selected elements: 1925
# ------------
# cluster= 70
# amplitude= 0.27448722564260186 idx= (np.int64(17), np.int64(6), np.int64(247), np.int64(19))
# selected elements: 12407
# ------------
# cluster= 71
# amplitude= 0.2741742175421942 idx= (np.int64(13), np.int64(8), np.int64(251), np.int64(135))
# selected elements: 13460
# ------------
# cluster= 72
# amplitude= 0.273938180470716 idx= (np.int64(14), np.int64(9), np.int64(115), np.int64(103))
# selected elements: 6635
# ------------
# cluster= 73
# amplitude= 0.27284790077993376 idx= (np.int64(7), np.int64(5), np.int64(194), np.int64(11))
# selected elements: 14273
# ------------
# cluster= 74
# amplitude= 0.2716502108781018 idx= (np.int64(6), np.int64(6), np.int64(194), np.int64(11))
# selected elements: 1076
# ------------
# cluster= 75
# amplitude= 0.270626441897716 idx= (np.int64(8), np.int64(7), np.int64(215), np.int64(52))
# selected elements: 912
# ------------
# cluster= 76
# amplitude= 0.2696104742818993 idx= (np.int64(3), np.int64(9), np.int64(245), np.int64(120))
# selected elements: 1687
# ------------
# cluster= 77
# amplitude= 0.26679491911810455 idx= (np.int64(3), np.int64(12), np.int64(103), np.int64(47))
# selected elements: 2474
# ------------
# cluster= 78
# amplitude= 0.26672550607935014 idx= (np.int64(6), np.int64(8), np.int64(296), np.int64(61))
# selected elements: 2149
# ------------
# cluster= 79
# amplitude= 0.2657481471900662 idx= (np.int64(5), np.int64(11), np.int64(74), np.int64(117))
# selected elements: 300
# ------------
# cluster= 80
# amplitude= 0.2653705139107801 idx= (np.int64(7), np.int64(13), np.int64(61), np.int64(82))
# selected elements: 1113
# ------------
# cluster= 81
# amplitude= 0.26492074726434334 idx= (np.int64(7), np.int64(12), np.int64(60), np.int64(21))
# selected elements: 766
# ------------
# cluster= 82
# amplitude= 0.2630488823662383 idx= (np.int64(4), np.int64(8), np.int64(200), np.int64(50))
# selected elements: 911
# ------------
# cluster= 83
# amplitude= 0.26170282558225244 idx= (np.int64(14), np.int64(12), np.int64(87), np.int64(92))
# selected elements: 3109
# ------------
# cluster= 84
# amplitude= 0.26072712842150425 idx= (np.int64(2), np.int64(9), np.int64(278), np.int64(82))
# selected elements: 3165
# ------------
# cluster= 85
# amplitude= 0.25764227462815553 idx= (np.int64(3), np.int64(9), np.int64(97), np.int64(80))
# selected elements: 1298
# ------------
# cluster= 86
# amplitude= 0.25745109500866825 idx= (np.int64(7), np.int64(9), np.int64(36), np.int64(16))
# selected elements: 1370
# ------------
# cluster= 87
# amplitude= 0.25690131015301565 idx= (np.int64(23), np.int64(14), np.int64(8), np.int64(85))
# selected elements: 3970
# ------------
# cluster= 88
# amplitude= 0.25495584004716854 idx= (np.int64(9), np.int64(7), np.int64(265), np.int64(125))
# selected elements: 1668
# ------------
# cluster= 89
# amplitude= 0.25359278435123417 idx= (np.int64(1), np.int64(11), np.int64(59), np.int64(46))
# selected elements: 1404
# ------------
# cluster= 90
# amplitude= 0.25312843517674466 idx= (np.int64(5), np.int64(8), np.int64(95), np.int64(81))
# selected elements: 1724
# ------------
# cluster= 91
# amplitude= 0.25212171560487556 idx= (np.int64(3), np.int64(9), np.int64(106), np.int64(126))
# selected elements: 2014
# ------------
# cluster= 92
# amplitude= 0.25057636562187474 idx= (np.int64(0), np.int64(11), np.int64(120), np.int64(76))
# selected elements: 820
# ------------
# cluster= 93
# amplitude= 0.2504254243088629 idx= (np.int64(14), np.int64(9), np.int64(49), np.int64(73))
# selected elements: 2369
# ------------
# cluster= 94
# amplitude= 0.25004233107381285 idx= (np.int64(6), np.int64(11), np.int64(53), np.int64(16))
# selected elements: 546
# ------------
# cluster= 95
# amplitude= 0.24978873709681895 idx= (np.int64(1), np.int64(12), np.int64(107), np.int64(41))
# selected elements: 351
# ------------
# cluster= 96
# amplitude= 0.24939055105408536 idx= (np.int64(2), np.int64(12), np.int64(166), np.int64(71))
# selected elements: 1841
# ------------
# cluster= 97
# amplitude= 0.24787843223426909 idx= (np.int64(11), np.int64(5), np.int64(302), np.int64(46))
# selected elements: 8129
# ------------
# cluster= 98
# amplitude= 0.24749071935731887 idx= (np.int64(9), np.int64(10), np.int64(118), np.int64(23))
# selected elements: 1228
# ------------
# cluster= 99
# amplitude= 0.24729663286441259 idx= (np.int64(2), np.int64(10), np.int64(259), np.int64(53))
# selected elements: 3183
# ------------
# cluster= 100
# amplitude= 0.24702267288986607 idx= (np.int64(12), np.int64(9), np.int64(67), np.int64(16))
# selected elements: 1697
# ------------
# cluster= 101
# amplitude= 0.24598414945864508 idx= (np.int64(7), np.int64(9), np.int64(27), np.int64(48))
# selected elements: 755
# ------------
# cluster= 102
# amplitude= 0.24536079416273604 idx= (np.int64(7), np.int64(10), np.int64(251), np.int64(112))
# selected elements: 1304
# ------------
# cluster= 103
# amplitude= 0.2448904100707574 idx= (np.int64(3), np.int64(12), np.int64(22), np.int64(10))
# selected elements: 643
# ------------
# cluster= 104
# amplitude= 0.24204232359970648 idx= (np.int64(15), np.int64(6), np.int64(244), np.int64(14))
# selected elements: 7095
# ------------
# cluster= 105
# amplitude= 0.2419504068629813 idx= (np.int64(9), np.int64(9), np.int64(262), np.int64(89))
# selected elements: 1778
# ------------
# cluster= 106
# amplitude= 0.24117510389881502 idx= (np.int64(7), np.int64(12), np.int64(79), np.int64(46))
# selected elements: 1772
# ------------
# cluster= 107
# amplitude= 0.24108781802587387 idx= (np.int64(3), np.int64(4), np.int64(249), np.int64(95))
# selected elements: 1172
# ------------
# cluster= 108
# amplitude= 0.2407592517122271 idx= (np.int64(10), np.int64(9), np.int64(223), np.int64(95))
# selected elements: 3811
# ------------
# cluster= 109
# amplitude= 0.24067324949998564 idx= (np.int64(3), np.int64(8), np.int64(160), np.int64(62))
# selected elements: 3691
# ------------
# cluster= 110
# amplitude= 0.2402692732832247 idx= (np.int64(2), np.int64(8), np.int64(147), np.int64(77))
# selected elements: 754
# ------------
# cluster= 111
# amplitude= 0.23972491503274668 idx= (np.int64(4), np.int64(6), np.int64(326), np.int64(78))
# selected elements: 7664
# ------------
# cluster= 112
# amplitude= 0.23951709184807912 idx= (np.int64(6), np.int64(9), np.int64(121), np.int64(28))
# selected elements: 199
# ------------
# cluster= 113
# amplitude= 0.2390430820829237 idx= (np.int64(23), np.int64(10), np.int64(270), np.int64(86))
# selected elements: 2853
# ------------
# cluster= 114
# amplitude= 0.23895375720860598 idx= (np.int64(0), np.int64(11), np.int64(166), np.int64(74))
# selected elements: 268
# ------------
# cluster= 115
# amplitude= 0.23888384756022754 idx= (np.int64(5), np.int64(7), np.int64(150), np.int64(71))
# selected elements: 4813
# ------------
# cluster= 116
# amplitude= 0.2384939333163673 idx= (np.int64(0), np.int64(11), np.int64(71), np.int64(77))
# selected elements: 942
# ------------
# cluster= 117
# amplitude= 0.23718807175872766 idx= (np.int64(18), np.int64(9), np.int64(160), np.int64(137))
# selected elements: 5737
# ------------
# cluster= 118
# amplitude= 0.23468562059399603 idx= (np.int64(17), np.int64(7), np.int64(258), np.int64(115))
# selected elements: 1729
# ------------
# cluster= 119
# amplitude= 0.23443308562797108 idx= (np.int64(5), np.int64(9), np.int64(220), np.int64(124))
# selected elements: 2512
# ------------
# cluster= 120
# amplitude= 0.23327214299664747 idx= (np.int64(10), np.int64(11), np.int64(64), np.int64(22))
# selected elements: 3143
# ------------
# cluster= 121
# amplitude= 0.23326195710764472 idx= (np.int64(21), np.int64(9), np.int64(85), np.int64(5))
# selected elements: 2680
# ------------
# cluster= 122
# amplitude= 0.23264376346822918 idx= (np.int64(13), np.int64(10), np.int64(71), np.int64(15))
# selected elements: 929
# ------------
# cluster= 123
# amplitude= 0.2315686426331335 idx= (np.int64(1), np.int64(10), np.int64(69), np.int64(118))
# selected elements: 1385
# ------------
# cluster= 124
# amplitude= 0.2315580106326033 idx= (np.int64(17), np.int64(13), np.int64(13), np.int64(61))
# selected elements: 1741
# ------------
# cluster= 125
# amplitude= 0.23138799391770792 idx= (np.int64(2), np.int64(11), np.int64(185), np.int64(88))
# selected elements: 1830
# ------------
# cluster= 126
# amplitude= 0.23082057764879524 idx= (np.int64(16), np.int64(5), np.int64(312), np.int64(35))
# selected elements: 8563
# ------------
# cluster= 127
# amplitude= 0.22983136123653317 idx= (np.int64(5), np.int64(12), np.int64(116), np.int64(116))
# selected elements: 428
# ------------
# cluster= 128
# amplitude= 0.2289663825859616 idx= (np.int64(12), np.int64(3), np.int64(330), np.int64(12))
# selected elements: 14835
# ------------
# cluster= 129
# amplitude= 0.2279226312720614 idx= (np.int64(0), np.int64(10), np.int64(146), np.int64(50))
# selected elements: 1218
# ------------
# cluster= 130
# amplitude= 0.22768273188437607 idx= (np.int64(1), np.int64(10), np.int64(175), np.int64(35))
# selected elements: 1073
# ------------
# cluster= 131
# amplitude= 0.2276431900470104 idx= (np.int64(19), np.int64(11), np.int64(117), np.int64(100))
# selected elements: 812
# ------------
# cluster= 132
# amplitude= 0.22748522517639955 idx= (np.int64(19), np.int64(8), np.int64(161), np.int64(41))
# selected elements: 1524
# ------------
# cluster= 133
# amplitude= 0.22745632828570558 idx= (np.int64(2), np.int64(6), np.int64(287), np.int64(106))
# selected elements: 1218
# ------------
# cluster= 134
# amplitude= 0.22735630436714824 idx= (np.int64(0), np.int64(10), np.int64(33), np.int64(62))
# selected elements: 247
# ------------
# cluster= 135
# amplitude= 0.22592875202571147 idx= (np.int64(3), np.int64(9), np.int64(91), np.int64(55))
# selected elements: 1129
# ------------
# cluster= 136
# amplitude= 0.2256331525786363 idx= (np.int64(6), np.int64(12), np.int64(35), np.int64(121))
# selected elements: 1650
# ------------
# cluster= 137
# amplitude= 0.22498088911392802 idx= (np.int64(3), np.int64(9), np.int64(166), np.int64(10))
# selected elements: 1364
# ------------
# cluster= 138
# amplitude= 0.2242324121618817 idx= (np.int64(5), np.int64(8), np.int64(193), np.int64(10))
# selected elements: 532
# ------------
# cluster= 139
# amplitude= 0.2237930628850134 idx= (np.int64(5), np.int64(13), np.int64(236), np.int64(39))
# selected elements: 4586
# ------------
# cluster= 140
# amplitude= 0.22328839479766133 idx= (np.int64(0), np.int64(5), np.int64(273), np.int64(84))
# selected elements: 417
# ------------
# cluster= 141
# amplitude= 0.22313522060971525 idx= (np.int64(2), np.int64(11), np.int64(32), np.int64(100))
# selected elements: 2112
# ------------
# cluster= 142
# amplitude= 0.22270039822563886 idx= (np.int64(9), np.int64(8), np.int64(269), np.int64(52))
# selected elements: 530
# ------------
# cluster= 143
# amplitude= 0.2226598197098618 idx= (np.int64(6), np.int64(9), np.int64(10), np.int64(63))
# selected elements: 1079
# ------------
# cluster= 144
# amplitude= 0.22248207576200077 idx= (np.int64(11), np.int64(8), np.int64(37), np.int64(64))
# selected elements: 1366
# ------------
# cluster= 145
# amplitude= 0.22218701575255465 idx= (np.int64(9), np.int64(8), np.int64(170), np.int64(18))
# selected elements: 549
# ------------
# cluster= 146
# amplitude= 0.22204790651032782 idx= (np.int64(12), np.int64(12), np.int64(20), np.int64(13))
# selected elements: 613
# ------------
# cluster= 147
# amplitude= 0.2218094146377053 idx= (np.int64(15), np.int64(9), np.int64(254), np.int64(134))
# selected elements: 1769
# ------------
# cluster= 148
# amplitude= 0.22134126567462142 idx= (np.int64(4), np.int64(13), np.int64(200), np.int64(106))
# selected elements: 4248
# ------------
# cluster= 149
# amplitude= 0.22128710047341163 idx= (np.int64(3), np.int64(7), np.int64(194), np.int64(10))
# selected elements: 2283
# ------------
# cluster= 150
# amplitude= 0.2208522015784204 idx= (np.int64(8), np.int64(12), np.int64(127), np.int64(112))
# selected elements: 2921
# ------------
# cluster= 151
# amplitude= 0.21981210753251473 idx= (np.int64(8), np.int64(13), np.int64(14), np.int64(50))
# selected elements: 1066
# ------------
# cluster= 152
# amplitude= 0.21964631017625813 idx= (np.int64(0), np.int64(9), np.int64(244), np.int64(47))
# selected elements: 976
# ------------
# cluster= 153
# amplitude= 0.2196220401353071 idx= (np.int64(0), np.int64(9), np.int64(145), np.int64(75))
# selected elements: 273
# ------------
# cluster= 154
# amplitude= 0.21852794290077635 idx= (np.int64(16), np.int64(5), np.int64(190), np.int64(28))
# selected elements: 6224
# ------------
# cluster= 155
# amplitude= 0.21851461295845578 idx= (np.int64(6), np.int64(8), np.int64(81), np.int64(20))
# selected elements: 3911
# ------------
# cluster= 156
# amplitude= 0.21820232822730018 idx= (np.int64(5), np.int64(9), np.int64(13), np.int64(19))
# selected elements: 2803
# ------------
# cluster= 157
# amplitude= 0.2179645141308875 idx= (np.int64(3), np.int64(7), np.int64(243), np.int64(102))
# selected elements: 731
# ------------
# cluster= 158
# amplitude= 0.21766553024942129 idx= (np.int64(7), np.int64(7), np.int64(156), np.int64(99))
# selected elements: 3517
# ------------
# cluster= 159
# amplitude= 0.21731230861564632 idx= (np.int64(1), np.int64(9), np.int64(297), np.int64(49))
# selected elements: 3097
# ------------
# cluster= 160
# amplitude= 0.21695318170192446 idx= (np.int64(5), np.int64(11), np.int64(215), np.int64(46))
# selected elements: 628
# ------------
# cluster= 161
# amplitude= 0.21674171910553908 idx= (np.int64(0), np.int64(8), np.int64(279), np.int64(82))
# selected elements: 128
# ------------
# cluster= 162
# amplitude= 0.2163455337811935 idx= (np.int64(19), np.int64(9), np.int64(17), np.int64(132))
# selected elements: 551
# ------------
# cluster= 163
# amplitude= 0.2153424985887952 idx= (np.int64(3), np.int64(11), np.int64(242), np.int64(63))
# selected elements: 363
# ------------
# cluster= 164
# amplitude= 0.21301958748551064 idx= (np.int64(8), np.int64(10), np.int64(139), np.int64(58))
# selected elements: 1075
# ------------
# cluster= 165
# amplitude= 0.21157349602854952 idx= (np.int64(23), np.int64(11), np.int64(251), np.int64(109))
# selected elements: 919
# ------------
# cluster= 166
# amplitude= 0.21148823844362888 idx= (np.int64(2), np.int64(10), np.int64(235), np.int64(66))
# selected elements: 531
# ------------
# cluster= 167
# amplitude= 0.21023440849648486 idx= (np.int64(14), np.int64(8), np.int64(155), np.int64(27))
# selected elements: 1383
# ------------
# cluster= 168
# amplitude= 0.2101860178109204 idx= (np.int64(2), np.int64(11), np.int64(68), np.int64(118))
# selected elements: 507
# ------------
# cluster= 169
# amplitude= 0.20990010432269998 idx= (np.int64(3), np.int64(8), np.int64(174), np.int64(111))
# selected elements: 970
# ------------
# cluster= 170
# amplitude= 0.20827236230482488 idx= (np.int64(16), np.int64(8), np.int64(255), np.int64(125))
# selected elements: 864
# ------------
# cluster= 171
# amplitude= 0.20757346867770385 idx= (np.int64(14), np.int64(10), np.int64(225), np.int64(43))
# selected elements: 1468
# ------------
# cluster= 172
# amplitude= 0.20671133519936624 idx= (np.int64(7), np.int64(13), np.int64(46), np.int64(38))
# selected elements: 580
# ------------
# cluster= 173
# amplitude= 0.20643609477770564 idx= (np.int64(4), np.int64(9), np.int64(50), np.int64(70))
# selected elements: 1123
# ------------
# cluster= 174
# amplitude= 0.20603067334724476 idx= (np.int64(11), np.int64(8), np.int64(86), np.int64(95))
# selected elements: 3308
# ------------
# cluster= 175
# amplitude= 0.20518090339060724 idx= (np.int64(20), np.int64(14), np.int64(6), np.int64(65))
# selected elements: 307
# ------------
# cluster= 176
# amplitude= 0.20484911481283236 idx= (np.int64(1), np.int64(10), np.int64(243), np.int64(46))
# selected elements: 137
# ------------
# cluster= 177
# amplitude= 0.20471274568684783 idx= (np.int64(17), np.int64(9), np.int64(250), np.int64(47))
# selected elements: 866
# ------------
# cluster= 178
# amplitude= 0.2041466398808073 idx= (np.int64(2), np.int64(12), np.int64(112), np.int64(27))
# selected elements: 309
# ------------
# cluster= 179
# amplitude= 0.20400924607302098 idx= (np.int64(5), np.int64(12), np.int64(125), np.int64(84))
# selected elements: 841
# ------------
# cluster= 180
# amplitude= 0.20357005503660283 idx= (np.int64(2), np.int64(8), np.int64(169), np.int64(92))
# selected elements: 467
# ------------
# cluster= 181
# amplitude= 0.20310359997855384 idx= (np.int64(8), np.int64(9), np.int64(18), np.int64(118))
# selected elements: 2665
# ------------
# cluster= 182
# amplitude= 0.2030782799666488 idx= (np.int64(18), np.int64(4), np.int64(274), np.int64(77))
# selected elements: 527
# ------------
# cluster= 183
# amplitude= 0.20296902080216958 idx= (np.int64(20), np.int64(11), np.int64(223), np.int64(47))
# selected elements: 900
# ------------
# cluster= 184
# amplitude= 0.20151124686216976 idx= (np.int64(7), np.int64(14), np.int64(27), np.int64(55))
# selected elements: 904
# ------------
# cluster= 185
# amplitude= 0.2005345786879261 idx= (np.int64(2), np.int64(12), np.int64(87), np.int64(46))
# selected elements: 461
# ------------
# cluster= 186
# amplitude= 0.20038411427186326 idx= (np.int64(5), np.int64(5), np.int64(297), np.int64(58))
# selected elements: 1352
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 87.90it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=3000:3600 ext=2950:3650 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_03000_03600_xext_02950_03650
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.3891458705961054 idx= (np.int64(15), np.int64(3), np.int64(193), np.int64(34))
# selected elements: 119284
# ------------
# cluster= 1
# amplitude= 0.3072204980007918 idx= (np.int64(11), np.int64(3), np.int64(92), np.int64(61))
# selected elements: 80188
# ------------
# cluster= 2
# amplitude= 0.3028745533869196 idx= (np.int64(14), np.int64(4), np.int64(60), np.int64(17))
# selected elements: 43840
# ------------
# cluster= 3
# amplitude= 0.28494501326734134 idx= (np.int64(23), np.int64(4), np.int64(59), np.int64(37))
# selected elements: 37111
# ------------
# cluster= 4
# amplitude= 0.2665338225823375 idx= (np.int64(11), np.int64(3), np.int64(133), np.int64(26))
# selected elements: 17426
# ------------
# cluster= 5
# amplitude= 0.24168149587123153 idx= (np.int64(8), np.int64(3), np.int64(64), np.int64(28))
# selected elements: 8827
# ------------
# cluster= 6
# amplitude= 0.24051166732086493 idx= (np.int64(16), np.int64(3), np.int64(123), np.int64(81))
# selected elements: 11016
# ------------
# cluster= 7
# amplitude= 0.23968771617606147 idx= (np.int64(4), np.int64(6), np.int64(26), np.int64(78))
# selected elements: 10227
# ------------
# cluster= 8
# amplitude= 0.23914300434532007 idx= (np.int64(8), np.int64(4), np.int64(105), np.int64(87))
# selected elements: 6114
# ------------
# cluster= 9
# amplitude= 0.22746842904238534 idx= (np.int64(18), np.int64(16), np.int64(282), np.int64(73))
# selected elements: 19091
# ------------
# cluster= 10
# amplitude= 0.2245939312400963 idx= (np.int64(18), np.int64(9), np.int64(321), np.int64(144))
# selected elements: 24744
# ------------
# cluster= 11
# amplitude= 0.22175979273766527 idx= (np.int64(10), np.int64(6), np.int64(19), np.int64(17))
# selected elements: 12118
# ------------
# cluster= 12
# amplitude= 0.22063294884637757 idx= (np.int64(11), np.int64(3), np.int64(28), np.int64(12))
# selected elements: 10320
# ------------
# cluster= 13
# amplitude= 0.21061585620928164 idx= (np.int64(13), np.int64(5), np.int64(76), np.int64(65))
# selected elements: 6858
# ------------
# cluster= 14
# amplitude= 0.2086187454930739 idx= (np.int64(22), np.int64(4), np.int64(155), np.int64(113))
# selected elements: 7497
# ------------
# cluster= 15
# amplitude= 0.20658804013150667 idx= (np.int64(21), np.int64(3), np.int64(255), np.int64(36))
# selected elements: 14327
# ------------
# cluster= 16
# amplitude= 0.20515018216438793 idx= (np.int64(18), np.int64(4), np.int64(149), np.int64(122))
# selected elements: 6742
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 88.09it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=3600:4200 ext=3550:4250 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_03600_04200_xext_03550_04250
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 88.38it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=4200:4800 ext=4150:4850 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_04200_04800_xext_04150_04850
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 85.76it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=4800:5400 ext=4750:5450 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_04800_05400_xext_04750_05450
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.20087603029938747 idx= (np.int64(19), np.int64(15), np.int64(274), np.int64(36))
# selected elements: 60142
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 89.53it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# [base | offset 0] core=5400:5951 ext=5350:5951 saved to outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\xcore_05400_05951_xext_05350_05951
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 0.45616087841922737 idx= (np.int64(6), np.int64(0), np.int64(183), np.int64(66))
# selected elements: 62383
# ------------
# cluster= 1
# amplitude= 0.4532128728425397 idx= (np.int64(0), np.int64(0), np.int64(184), np.int64(65))
# selected elements: 5424
# ------------
# cluster= 2
# amplitude= 0.3980998382821777 idx= (np.int64(21), np.int64(0), np.int64(181), np.int64(77))
# selected elements: 115656
# ------------
# cluster= 3
# amplitude= 0.39712949754551 idx= (np.int64(13), np.int64(0), np.int64(183), np.int64(95))
# selected elements: 30556
# ------------
# cluster= 4
# amplitude= 0.27812055018496323 idx= (np.int64(6), np.int64(17), np.int64(183), np.int64(66))
# selected elements: 25173
# ------------
# cluster= 5
# amplitude= 0.27161655058044143 idx= (np.int64(20), np.int64(17), np.int64(180), np.int64(61))
# selected elements: 79650
# ------------
# cluster= 6
# amplitude= 0.25724416604552863 idx= (np.int64(0), np.int64(17), np.int64(184), np.int64(63))
# selected elements: 1185
# ------------
# cluster= 7
# amplitude= 0.25628376935486763 idx= (np.int64(23), np.int64(13), np.int64(74), np.int64(106))
# selected elements: 71533
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 88.34it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Done. Outputs in C:\Users\domin\juwavelet\Momentum Flux\outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000
# Saved output with clusters: C:\Users\domin\juwavelet\Momentum Flux\outputs_decompose2d_slices_single_noise_filtering_AUTO\01770\base_offset_0000\awe_l6c_q20_2024075T0538_01770_v23.nc

# %% [markdown]
# 1054 s > 994 s

# %% [markdown]
# ## Batch processing

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Dict, Any, List

import gc
import copy

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

try:
    from scipy import stats
except Exception:
    stats = None


# ==========================
# CHANGES (summary)
# ==========================
# 1) True plotting disable
#    All plotting functions now return immediately when saving is off
#    This skips creating figures entirely (big speedup)
#
# 2) Stitched plot saving can be fully disabled
#    stitch_and_save_final_09 returns immediately if SAVE_STITCHED_PLOT is False
#
# 3) Red noise diagnostics writing can be disabled
#    No per slice text output when SAVE_REDNOISE_DIAGNOSTICS is False
#
# 4) Red noise filter no longer deep copies the entire cwt dict
#    It shallow copies the dict and copies only decomposition (much faster, less memory)
#
# 5) Fixed batch loop bug
#    continuelo -> continue


# --------------------------
# User params
# --------------------------
INPUT_FOLDER = Path("l3/OneFile")
FILE_GLOB = "*.nc"

OUTPUT_ROOT = Path("outputs_decompose2d_slices_single_noise_filtering_AUTO_BATCH")
SAVE_DPI = 200

OUTPUT_L6_FOLDER = Path("l6/OneFile")

FRAME_IDX = 0

X_CHUNK = 600
Y_SLICE = slice(None, None)
SLICE_PAD = 50

X_OFFSET = 0

REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

APPLY_BINNING = True
BIN_FACTOR = 2

APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10

S0 = 16
DJ = 1 / 8
JS = 24
JT = 18
ASPECT = 1

DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

N_SHOW = 6

AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

APPLY_RED_NOISE_FILTER = True

# Turn these on only if you actually want files written
SAVE_REDNOISE_DIAGNOSTICS = False
SAVE_SLICE_PLOTS = False
SAVE_STITCHED_PLOT = True


# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)


# --------------------------
# Small helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path, *, enable: bool = True) -> None:
    """
    Save and close a figure if enable=True.
    Always closes the figure to avoid matplotlib memory buildup.
    """
    try:
        if enable:
            outpath.parent.mkdir(parents=True, exist_ok=True)
            fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    finally:
        plt.close(fig)


def cleanup_memory() -> None:
    try:
        plt.close("all")
    except Exception:
        pass
    gc.collect()


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def diverging_limits(*arrays: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    vals = []
    for A in arrays:
        if A is None:
            continue
        a = np.asarray(A)
        good = np.isfinite(a)
        if np.any(good):
            vals.append(a[good].ravel())
    if not vals:
        return (-1.0, 1.0)
    stacked = np.concatenate(vals)
    lo, hi = np.nanpercentile(stacked, [p_lo, p_hi])
    vmax = max(abs(lo), abs(hi))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    return (-vmax, vmax)


# --------------------------
# Product detection + RUNS
# --------------------------
def detect_product_type(file_path: Path) -> str:
    name = file_path.name.lower()
    if "_l3a_" in name:
        return "l3a"
    if "_l3c_" in name:
        return "l3c"
    if "_l5c_" in name:
        return "l5c"
    raise ValueError(f"Cannot detect product type from file name: {file_path.name}")


def get_runs_for_product(product_type: str) -> List[Dict[str, Any]]:
    if product_type == "l3a":
        return [
            dict(
                name="base",
                MIN_AMP=1.25,
                THR=0.6,
                WHITE_NOISE_THRESHOLD=0.1,
                WPS_NOISE_THRESHOLD=8.0,
            ),
        ]
    return [
        dict(
            name="base",
            MIN_AMP=0.2,
            THR=0.15,
            WHITE_NOISE_THRESHOLD=0.02,
            WPS_NOISE_THRESHOLD=8.0,
        ),
    ]


# --------------------------
# Data helpers
# --------------------------
def read_frame(path: str | Path, frame_idx: int, product_type: str) -> np.ndarray:
    with Dataset(str(path), "r") as nc:
        varname = "Temperature" if product_type == "l3a" else "Radiance"
        data = nc.variables[varname][:]  # (t, y, x)

    if data.ndim != 3:
        raise ValueError(f"{varname} expected 3D (t,y,x); got {data.shape}")

    if not (0 <= frame_idx < data.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{data.shape[0]-1}")

    return np.asarray(data[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def unbin_repeat_xy(A: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return A
    f = int(factor)
    return np.repeat(np.repeat(A, f, axis=0), f, axis=1)


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    return np.cos(theta_xy), np.sin(theta_xy)


# --------------------------
# Red noise style filtering helper
# --------------------------
def apply_red_noise_filter_cwt(
    cwt: dict,
    white_noise_threshold: float = 0.1,
    wps_noise_threshold: float = 8.0,
) -> Tuple[dict, Dict[str, Any]]:
    """
    Robust per scale WPS filtering.
    Returns filtered_cwt and diagnostics.

    Change: no deepcopy of entire cwt dict.
    Only decomposition is copied since that is what we mutate.
    """
    diag: Dict[str, Any] = {}
    if stats is None:
        diag["skipped"] = True
        diag["reason"] = "scipy not available"
        return cwt, diag

    # Shallow copy of dict and copy only decomposition
    cwt_copy = dict(cwt)
    dec0 = cwt["decomposition"]
    dec = dec0.copy()
    cwt_copy["decomposition"] = dec

    WPS0 = np.abs(dec) ** 2
    diag["n_coeff_total"] = int(WPS0.size)

    mask_1 = WPS0 < (float(white_noise_threshold) ** 2)
    dec[mask_1] = 0

    WPS1 = np.abs(dec) ** 2
    diag["n_zero_after_white"] = int(np.count_nonzero(WPS1 == 0))

    median_WPS = np.median(WPS1, axis=(1, 2, 3))  # (ns,)
    mad = stats.median_abs_deviation(WPS1, axis=(1, 2, 3), scale=1.0)  # (ns,)
    sMAD_WPS = 1.4826 * mad

    sMAD_safe = np.where(sMAD_WPS > 0, sMAD_WPS, np.nan)
    WPS_scaled = (WPS1 - median_WPS[:, None, None, None]) / sMAD_safe[:, None, None, None]

    mask = WPS_scaled < float(wps_noise_threshold)
    dec[mask] = 0

    WPS2 = np.abs(dec) ** 2
    diag["n_zero_after_scaled"] = int(np.count_nonzero(WPS2 == 0))

    finite_scaled = np.isfinite(WPS_scaled)

    diag["sMAD_min"] = float(np.nanmin(sMAD_WPS))
    diag["sMAD_median"] = float(np.nanmedian(sMAD_WPS))

    if np.any(finite_scaled):
        diag["WPS_scaled_min"] = float(np.nanmin(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_median"] = float(np.nanmedian(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_max"] = float(np.nanmax(WPS_scaled[finite_scaled]))
    else:
        diag["WPS_scaled_min"] = np.nan
        diag["WPS_scaled_median"] = np.nan
        diag["WPS_scaled_max"] = np.nan

    return cwt_copy, diag


# --------------------------
# Quicklook plots (now true no-op if not saving)
# --------------------------
def quicklook_save(
    x1d: np.ndarray,
    y1d: np.ndarray,
    Z: np.ndarray,
    title: str,
    outpath: Path,
    *,
    save_plots: bool,
) -> None:
    if not save_plots:
        return
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("arb")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath, enable=True)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
    *,
    wavy_after_noise_xy: np.ndarray | None = None,
    save_plots: bool,
) -> None:
    if not save_plots:
        return

    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    arrays = [orig_c, bg_c, rem_c, rem_tapered_c]
    if wavy_after_noise_xy is not None:
        arrays.append(wavy_after_noise_xy)

    vmin, vmax = diverging_limits(*arrays, p_lo=1, p_hi=99)

    fig, axs = plt.subplots(2, 3, figsize=(16, 10), constrained_layout=True)
    axs = axs.flatten()

    panels = [
        (orig_c, "Original (median sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    if wavy_after_noise_xy is not None:
        panels.append((wavy_after_noise_xy, "Wavy stuff (wavelet reconstruction after noise filtering)"))

    im0 = None
    for ax, (Zp, title) in zip(axs, panels):
        im0 = ax.pcolormesh(x1d_km, y1d_km, Zp, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    for ax in axs[len(panels) :]:
        ax.axis("off")

    cbar = fig.colorbar(im0, ax=axs[: len(panels)], orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("arb")
    save_fig(fig, outpath, enable=True)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
    *,
    save_plots: bool,
) -> None:
    if not save_plots:
        return

    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2
    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])
        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_vmin, bg_vmax = diverging_limits(bg_xy, p_lo=2, p_hi=98)
    cl_vmin, cl_vmax = diverging_limits(rec_xy, p_lo=2, p_hi=98)

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if (not np.isfinite(lam_vmin)) or (not np.isfinite(lam_vmax)) or (lam_vmin == lam_vmax):
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n"
            + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        arrow_len_km = 40.0
        u = u * arrow_len_km
        v = v * arrow_len_km

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good],
            Yqs[good],
            uqs[good],
            vqs[good],
            angles="xy",
            scale_units="xy",
            scale=QUIVER_SCALE,
            width=0.0025,
        )

    save_fig(fig, outpath, enable=True)


# --------------------------
# Cluster products (for L6C/L6A outputs)
# --------------------------
def cluster_dominant_lambda_map(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_mask_xy: np.ndarray | None = None,
) -> np.ndarray:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power0 = np.abs(dec) ** 2
    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power0.shape
    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)
    valid = np.isfinite(pmax) & (pmax > 0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if amp_mask_xy is not None:
        lam_xy[~np.isfinite(amp_mask_xy)] = np.nan

    return lam_xy


def copy_lxc_to_l6x_with_clusters(
    lxc_path: str | Path,
    l6x_path: str | Path,
    clusters: List[Dict[str, Any]],
    y_dim: int,
    x_dim: int,
    unbin_factor: int = 1,
    product_type: str = "l5c",
) -> None:
    def _unbin_repeat_xy_local(A: np.ndarray, factor: int) -> np.ndarray:
        if factor is None or int(factor) <= 1:
            return A
        f = int(factor)
        return np.repeat(np.repeat(A, f, axis=0), f, axis=1)

    lxc_path = Path(lxc_path)
    l6x_path = Path(l6x_path)
    l6x_path.parent.mkdir(parents=True, exist_ok=True)

    ncl = int(len(clusters))
    has_rec = any((c.get("rec_xy", None) is not None) for c in clusters)

    fup = int(unbin_factor) if (unbin_factor is not None and int(unbin_factor) > 1) else 1
    y_dim_w = int(y_dim) * fup
    x_dim_w = int(x_dim) * fup

    with Dataset(lxc_path, "r") as src, Dataset(l6x_path, "w", format="NETCDF4") as dst:
        dst.setncatts({k: src.getncattr(k) for k in src.ncattrs()})

        for dname, dim in src.dimensions.items():
            dst.createDimension(dname, (len(dim) if not dim.isunlimited() else None))

        for vname, var in src.variables.items():
            out = dst.createVariable(
                vname,
                var.datatype,
                var.dimensions,
                zlib=True,
                complevel=4,
                fill_value=getattr(var, "_FillValue", None),
            )
            out.setncatts({k: var.getncattr(k) for k in var.ncattrs()})
            out[:] = var[:]

        dst.createDimension("cluster", ncl)
        dst.createDimension("y_cluster", y_dim_w)
        dst.createDimension("x_cluster", x_dim_w)

        v_slice = dst.createVariable("SlicesNo", "i4", ("cluster",), zlib=True, complevel=4)
        v_area = dst.createVariable("Area", "f4", ("cluster",), zlib=True, complevel=4)
        v_pabs = dst.createVariable("ClusterPowerAbs", "f8", ("cluster",), zlib=True, complevel=4)
        v_ppct = dst.createVariable("ClusterPowerPct", "f4", ("cluster",), zlib=True, complevel=4)

        v_amp = dst.createVariable(
            "Amplitude",
            "f4",
            ("cluster", "y_cluster", "x_cluster"),
            zlib=True,
            complevel=4,
            fill_value=np.float32(np.nan),
        )
        v_lam = dst.createVariable(
            "DominantWavelength",
            "f4",
            ("cluster", "y_cluster", "x_cluster"),
            zlib=True,
            complevel=4,
            fill_value=np.float32(np.nan),
        )
        v_ang = dst.createVariable(
            "Angle",
            "f4",
            ("cluster", "y_cluster", "x_cluster"),
            zlib=True,
            complevel=4,
            fill_value=np.float32(np.nan),
        )

        v_rec = None
        if has_rec:
            v_rec = dst.createVariable(
                "ClusterReconstruction",
                "f4",
                ("cluster", "y_cluster", "x_cluster"),
                zlib=True,
                complevel=4,
                fill_value=np.float32(np.nan),
            )
            v_rec.units = "arb"
            v_rec.long_name = "Per cluster wavelet reconstruction map (relative; median subtracted)"

        v_area.units = "km2"
        v_lam.units = "km"
        v_ang.units = "rad"
        v_slice.long_name = "Slice index (starts at 0) for each cluster"
        v_pabs.units = "arb"
        v_ppct.units = "percent"

        v_amp.units = "K" if product_type == "l3a" else "kR"

        if ncl == 0:
            return

        v_slice[:] = np.asarray([c["slice_no"] for c in clusters], dtype=np.int32)
        v_area[:] = np.asarray([c["area_km2"] for c in clusters], dtype=np.float32)
        v_pabs[:] = np.asarray([c.get("power_abs", np.nan) for c in clusters], dtype=np.float64)
        v_ppct[:] = np.asarray([c.get("power_pct", np.nan) for c in clusters], dtype=np.float32)

        amp_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        lam_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        ang_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        rec_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32) if has_rec else None

        def _force_shape(M: np.ndarray) -> np.ndarray:
            if M.shape == (y_dim_w, x_dim_w):
                return M.astype(np.float32)
            tmp = np.full((y_dim_w, x_dim_w), np.nan, dtype=np.float32)
            yy = min(y_dim_w, M.shape[0])
            xx = min(x_dim_w, M.shape[1])
            tmp[:yy, :xx] = M[:yy, :xx]
            return tmp

        for i, c in enumerate(clusters):
            A = _unbin_repeat_xy_local(c["A_xy"], fup)
            L = _unbin_repeat_xy_local(c["lam_xy"], fup)
            T = _unbin_repeat_xy_local(c["theta_xy"], fup)

            amp_stack[i] = _force_shape(A)
            lam_stack[i] = _force_shape(L)
            ang_stack[i] = _force_shape(T)

            if has_rec and rec_stack is not None and v_rec is not None:
                R = c.get("rec_xy", None)
                if R is not None:
                    R = _force_shape(_unbin_repeat_xy_local(R, fup))
                    rec_stack[i] = R

        v_amp[:] = amp_stack
        v_lam[:] = lam_stack
        v_ang[:] = ang_stack
        if has_rec and v_rec is not None and rec_stack is not None:
            v_rec[:] = rec_stack


def make_output_cluster_path(input_path: str | Path) -> Path:
    p = Path(input_path)
    name = p.name
    if "_l5c_" in name:
        name = name.replace("_l5c_", "_l6c_")
    elif "_l3c_" in name:
        name = name.replace("_l3c_", "_l6c_")
    elif "_l3a_" in name:
        name = name.replace("_l3a_", "_l6a_")
    else:
        name = p.stem + "_clusters.nc"
    return p.with_name(name)


# --------------------------
# Slice pipeline
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
    cfg: Dict[str, Any],
    slice_no: int,
    product_type: str,
) -> Dict[str, Any]:
    outdir.mkdir(parents=True, exist_ok=True)
    save_plots = bool(SAVE_SLICE_PLOTS)

    min_amp = float(cfg.get("MIN_AMP"))
    thr = float(cfg.get("THR"))
    white_noise_threshold = float(cfg.get("WHITE_NOISE_THRESHOLD"))
    wps_noise_threshold = float(cfg.get("WPS_NOISE_THRESHOLD"))
    run_name = str(cfg.get("name", "run"))

    STORE_CLUSTER_RECON = True

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        f = int(BIN_FACTOR)
        dx_km = DX_KM_BASE * f
        dy_km = DY_KM_BASE * f
    else:
        f = 1
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f
    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    raw_win = np.asarray(rad2d_flat[Y_SLICE, x_slice], dtype=float)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    label0 = "Temperature" if product_type == "l3a" else "Radiance"

    quicklook_save(
        x1d_km,
        y1d_km,
        raw_win,
        f"{label0} (window, flattened){bin_tag}\n{run_name} MIN_AMP={min_amp} THR={thr}",
        outdir / "00_window.png",
        save_plots=save_plots,
    )

    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt_raw = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    if APPLY_RED_NOISE_FILTER:
        cwt, diag = apply_red_noise_filter_cwt(
            cwt_raw,
            white_noise_threshold=white_noise_threshold,
            wps_noise_threshold=wps_noise_threshold,
        )

        if SAVE_REDNOISE_DIAGNOSTICS:
            lines = []
            lines.append("Red noise filter diagnostics\n\n")
            lines.append(f"name                  = {run_name}\n")
            lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
            lines.append(f"WPS_NOISE_THRESHOLD   = {wps_noise_threshold}\n\n")
            if diag.get("skipped", False):
                lines.append(f"SKIPPED: {diag.get('reason','unknown')}\n")
            else:
                lines.append(f"n_coeff_total        = {diag.get('n_coeff_total')}\n")
                lines.append(f"n_zero_after_white   = {diag.get('n_zero_after_white')}\n")
                lines.append(f"n_zero_after_scaled  = {diag.get('n_zero_after_scaled')}\n")
                lines.append(f"sMAD_WPS min         = {diag.get('sMAD_min')}\n")
                lines.append(f"sMAD_WPS median      = {diag.get('sMAD_median')}\n")
                lines.append(f"WPS_scaled min       = {diag.get('WPS_scaled_min')}\n")
                lines.append(f"WPS_scaled median    = {diag.get('WPS_scaled_median')}\n")
                lines.append(f"WPS_scaled max       = {diag.get('WPS_scaled_max')}\n")
            (outdir / "02a_rednoise_diagnostics.txt").write_text("".join(lines))
    else:
        cwt = cwt_raw

    rec_wavy = transform.reconstruct2d(cwt)  # (nx, ny)
    wavy_xy = rec_wavy.T - np.median(rec_wavy)

    quicklook_background_decomp_4panel_save(
        x1d_km,
        y1d_km,
        proc0,
        background,
        remaining,
        remaining_tapered,
        TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_5panel.png",
        wavy_after_noise_xy=wavy_xy,
        save_plots=save_plots,
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=min_amp, thr=thr)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    if save_plots:
        cmap_cwt = matplotlib.cm.turbo
        norm_cwt = matplotlib.colors.BoundaryNorm(np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N)
        fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
        save_fig(fig_cwt, outdir / "02_decomposition_overview.png", enable=True)

        plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
        fig_spec = plt.gcf()
        save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png", enable=True)

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text(
            "No clusters found.\n\n"
            f"Run name: {run_name}\n"
            f"Used MIN_AMP={min_amp}, THR={thr}\n"
            f"Used WHITE_NOISE_THRESHOLD={white_noise_threshold}, WPS_NOISE_THRESHOLD={wps_noise_threshold}\n\n"
            "Try lowering MIN_AMP or THR.\n"
            "If red noise filter is on, try lowering WPS_NOISE_THRESHOLD or WHITE_NOISE_THRESHOLD.\n"
        )
        remaining_core_xy = crop_pad_core(proc)
        nan_core = np.full_like(remaining_core_xy, np.nan)

        cleanup_memory()
        return {
            "has_clusters": False,
            "x_start_unbinned": core_start_unbinned,
            "dx_km": dx_km,
            "dy_km": dy_km,
            "remaining_xy": remaining_core_xy,
            "wavy_xy": nan_core,
            "rec_all_xy": nan_core,
            "cluster_records": [],
        }

    power_abs_map = {int(k): float(p) for k, p in zip(cluster_ids, P_abs)}
    power_pct_map = {int(k): float(p) for k, p in zip(cluster_ids, P_pct)}

    cluster_records: List[Dict[str, Any]] = []
    for kcl in cluster_ids.astype(int):
        kcl = int(kcl)

        A_xy, theta_xy = cluster_amp_theta_maps(
            cwt,
            iwave,
            kcl,
            amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX,
        )
        lam_xy = cluster_dominant_lambda_map(cwt, iwave, kcl, amp_mask_xy=A_xy)

        rec_core = None
        if STORE_CLUSTER_RECON:
            decomposition[:] = orig_decomp
            decomposition[iwave != kcl] = 0
            rec = transform.reconstruct2d(cwt)  # (nx, ny)
            rec_xy = rec.T
            rec_xy = rec_xy - np.nanmedian(rec_xy)
            rec_core = crop_pad_core(rec_xy)
            decomposition[:] = orig_decomp

        A_core = crop_pad_core(A_xy)
        th_core = crop_pad_core(theta_xy)
        lam_core = crop_pad_core(lam_xy)

        n_pix = int(np.count_nonzero(np.isfinite(A_core)))
        area_km2 = float(n_pix) * float(dx_km) * float(dy_km)

        cluster_records.append(
            dict(
                slice_no=int(slice_no),
                kcl=kcl,
                area_km2=area_km2,
                power_abs=power_abs_map.get(kcl, np.nan),
                power_pct=power_pct_map.get(kcl, np.nan),
                A_xy=A_core,
                lam_xy=lam_core,
                theta_xy=th_core,
                rec_xy=rec_core,
            )
        )

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    lines = []
    lines.append("Cluster power ranking (clustered only)\n\n")
    lines.append(f"name = {run_name}\n")
    lines.append(f"MIN_AMP = {min_amp}\n")
    lines.append(f"THR = {thr}\n")
    lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
    lines.append(f"WPS_NOISE_THRESHOLD = {wps_noise_threshold}\n\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]
    theta_vals = np.asarray(cwt["theta"], dtype=float)

    if save_plots:
        nrow = int(np.ceil(np.sqrt(n_show)))
        ncol = int(np.ceil(n_show / nrow))

        def plot_cluster_grid(kind: str, outname: str) -> None:
            fig, axs = plt.subplots(nrow, ncol, figsize=(12, 10))
            axs = np.atleast_1d(axs).reshape(-1)

            bg_vmin, bg_vmax = diverging_limits(bg, p_lo=2, p_hi=98)
            number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}

            for ax, kcl in zip(axs, biggest):
                decomposition[:] = orig_decomp
                decomposition[iwave != kcl] = 0
                rec = transform.reconstruct2d(cwt)
                rec_centered = rec.T - np.median(rec)

                s_idx = int(idxs[kcl][0])
                t_idx = int(idxs[kcl][1])
                _, _, lam = effective_lambda(cwt, s_idx, t_idx)

                theta_dom_rad = float(theta_vals[t_idx])
                theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

                ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
                Pk = float(P_abs_sorted[ii])
                pk = float(P_pct_sorted[ii])

                if kind == "standalone":
                    ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0)
                elif kind == "overlay":
                    ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
                    ax.pcolormesh(
                        x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0, alpha=0.6
                    )
                else:
                    raise ValueError(kind)

                ax.set_title(
                    rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
                    + "\n"
                    + rf"P={Pk:.2e} ({pk:.1f}%)"
                )
                ax.set_aspect("equal", adjustable="box")

            for ax in axs[n_show:]:
                ax.axis("off")
            for ax in axs[:n_show]:
                ax.set_xlabel("x (km)")
                ax.set_ylabel("y (km)")

            for i, ax in enumerate(axs, start=1):
                if ax.has_data():
                    ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

            fig.tight_layout()
            save_fig(fig, outdir / outname, enable=True)

        plot_cluster_grid("standalone", "05_clusters_standalone.png")
        plot_cluster_grid("overlay", "06_clusters_overlay.png")

        for kcl in biggest:
            plot_cluster_individual_save(
                cwt=cwt,
                iwave=iwave,
                kcl=int(kcl),
                x1d_km=x1d_km,
                y1d_km=y1d_km,
                orig_decomp=orig_decomp,
                bg_xy=bg,
                dx_km=dx_km,
                dy_km=dy_km,
                outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
                save_plots=True,
            )

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)
    decomposition[:] = orig_decomp

    remaining_after_preproc_xy = proc

    if save_plots:
        vmin, vmax = diverging_limits(remaining_after_preproc_xy, wavy_xy, rec_all_xy, p_lo=2, p_hi=98)

        figR, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(18, 8), constrained_layout=True, sharex=True, sharey=True)

        im1 = ax1.pcolormesh(
            x1d_km, y1d_km, remaining_after_preproc_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax1.set_title("Remaining (after preprocessing, input to CWT)")
        ax1.set_xlabel("x (km)")
        ax1.set_ylabel("y (km)")
        ax1.set_aspect("equal", adjustable="box")

        im2 = ax2.pcolormesh(x1d_km, y1d_km, wavy_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
        ax2.set_title("Wavy stuff (wavelet reconstruction after noise filtering)")
        ax2.set_xlabel("x (km)")
        ax2.set_ylabel("y (km)")
        ax2.set_aspect("equal", adjustable="box")

        im3 = ax3.pcolormesh(x1d_km, y1d_km, rec_all_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
        ax3.set_title("Reconstruction after clustering (all clusters combined)")
        ax3.set_xlabel("x (km)")
        ax3.set_ylabel("y (km)")
        ax3.set_aspect("equal", adjustable="box")

        cbar = figR.colorbar(im1, ax=[ax1, ax2, ax3], orientation="vertical", fraction=0.015, pad=0.01)
        cbar.set_label("arb")
        save_fig(figR, outdir / "09_remaining_vs_wavy_vs_allclusters.png", enable=True)

    remaining_core_xy = crop_pad_core(remaining_after_preproc_xy)
    wavy_core_xy = crop_pad_core(wavy_xy)
    rec_all_core_xy = crop_pad_core(rec_all_xy)

    try:
        del raw_win, proc0, plane, detrended, fourier_bg, background, remaining, remaining_tapered, proc, wave_xy
        del cwt_raw, cwt, amps, idxs, iwave, decomposition, orig_decomp, rec_wavy, rec_all
        del bg, cluster_ids, P_abs, P_pct, cluster_ids_sorted, P_abs_sorted, P_pct_sorted
    except Exception:
        pass
    cleanup_memory()

    return {
        "has_clusters": True,
        "x_start_unbinned": core_start_unbinned,
        "dx_km": dx_km,
        "dy_km": dy_km,
        "remaining_xy": remaining_core_xy,
        "wavy_xy": wavy_core_xy,
        "rec_all_xy": rec_all_core_xy,
        "cluster_records": cluster_records,
    }


def stitch_and_save_final_09(slice_results: List[Dict[str, Any]], outroot: Path, tag: str, product_type: str) -> None:
    if not SAVE_STITCHED_PLOT:
        return
    if not slice_results:
        return

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    x0_unbinned = int(slice_results[0].get("x_start_unbinned", 0))
    x0_km = x0_unbinned * DX_KM_BASE

    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    wavy_stitched = np.concatenate([d["wavy_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)

    ny, nx_tot = remaining_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    vmin, vmax = diverging_limits(remaining_stitched, wavy_stitched, rec_all_stitched, p_lo=2, p_hi=98)

    figR, (axT, axM, axB) = plt.subplots(3, 1, figsize=(18, 6), constrained_layout=True, sharex=True, sharey=True)

    imT = axT.pcolormesh(x1d_km, y1d_km, remaining_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axT.set_title(f"STITCHED (core tiles) {tag}: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imM = axM.pcolormesh(x1d_km, y1d_km, wavy_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axM.set_title(f"STITCHED (core tiles) {tag}: Wavy stuff (wavelet reconstruction after noise filtering)")
    axM.set_xlabel("x (km)")
    axM.set_ylabel("y (km)")
    axM.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(x1d_km, y1d_km, rec_all_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axB.set_title(f"STITCHED (core tiles) {tag}: Reconstruction after clustering (all clusters combined)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    cbar = figR.colorbar(imT, ax=[axT, axM, axB], orientation="vertical", fraction=0.012, pad=0.01)
    cbar.set_label("K (Relative)" if product_type == "l3a" else "kRayleigh (Relative)")

    save_fig(
        figR,
        outroot / f"FINAL_09_remaining_vs_wavy_vs_allclusters_STITCHED_{tag}.png",
        enable=True,
    )

    try:
        del remaining_stitched, wavy_stitched, rec_all_stitched
    except Exception:
        pass
    cleanup_memory()


# --------------------------
# Per file runner
# --------------------------
def run_one_file(file_path: Path) -> None:
    product_type = detect_product_type(file_path)
    runs = get_runs_for_product(product_type)

    print("\n========================================")
    print("File:", file_path.name)
    print("Detected product:", product_type)
    print("Runs:", runs)

    rad2d = read_frame(file_path, FRAME_IDX, product_type=product_type)
    rad2d_flat = flatten_swath(rad2d, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    x_offset = int(X_OFFSET)
    if x_offset >= nx_total:
        raise ValueError(f"X_OFFSET={x_offset} too large for nx_total={nx_total} in file {file_path.name}")

    for cfg in runs:
        run_name = str(cfg.get("name", "run"))

        outroot = OUTPUT_ROOT / file_path.stem / f"{run_name}_offset_{x_offset:04d}"
        outroot.mkdir(parents=True, exist_ok=True)

        (outroot / "RUN_CONFIG.txt").write_text(
            "\n".join([f"{k} = {v}" for k, v in cfg.items()])
            + f"\nproduct_type = {product_type}\nfile = {file_path.name}\n"
        )

        core_starts = list(range(x_offset, nx_total, X_CHUNK))
        stitch_results: List[Dict[str, Any]] = []
        all_cluster_records: List[Dict[str, Any]] = []

        f = int(BIN_FACTOR) if (APPLY_BINNING and int(BIN_FACTOR) > 1) else 1
        y_dim = int(rad2d_flat[Y_SLICE, :].shape[0] // f)
        x_dim = int(X_CHUNK // f)

        for slice_no, core_start in enumerate(core_starts):
            core_end = min(core_start + X_CHUNK, nx_total)

            ext_start = max(0, core_start - SLICE_PAD)
            ext_end = min(nx_total, core_end + SLICE_PAD)
            x_slice = slice(ext_start, ext_end)

            outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
            print(f"[{file_path.name} | {run_name}] core={core_start}:{core_end} ext={ext_start}:{ext_end}")

            res = run_pipeline_for_slice(
                rad2d_flat=rad2d_flat,
                x_slice=x_slice,
                outdir=outdir,
                x_start_unbinned=ext_start,
                core_start_unbinned=core_start,
                core_end_unbinned=core_end,
                cfg=cfg,
                slice_no=slice_no,
                product_type=product_type,
            )

            stitch_results.append(res)
            all_cluster_records.extend(res.get("cluster_records", []))

            cleanup_memory()

        stitch_and_save_final_09(
            stitch_results,
            outroot,
            tag=f"{run_name}_offset_{x_offset:04d}",
            product_type=product_type,
        )
        print("Done per slice processing. Outputs in", outroot.resolve())

        OUTPUT_L6_FOLDER.mkdir(parents=True, exist_ok=True)
        out_path = OUTPUT_L6_FOLDER / make_output_cluster_path(file_path).name

        copy_lxc_to_l6x_with_clusters(
            lxc_path=file_path,
            l6x_path=out_path,
            clusters=all_cluster_records,
            y_dim=y_dim,
            x_dim=x_dim,
            unbin_factor=(BIN_FACTOR if (APPLY_BINNING and int(BIN_FACTOR) > 1) else 1),
            product_type=product_type,
        )

        print("Saved output with clusters:", out_path.resolve())

    try:
        del rad2d, rad2d_flat
    except Exception:
        pass
    cleanup_memory()


# --------------------------
# Batch loop over folder
# --------------------------
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

files = sorted(INPUT_FOLDER.glob(FILE_GLOB))
if not files:
    raise FileNotFoundError(f"No files matched {FILE_GLOB} in {INPUT_FOLDER.resolve()}")

print("Found", len(files), "files in", INPUT_FOLDER.resolve())
print("Will write L6* cluster netCDF to:", OUTPUT_L6_FOLDER.resolve())
print("Will write plot outputs to:", OUTPUT_ROOT.resolve())
print("SAVE_SLICE_PLOTS =", SAVE_SLICE_PLOTS)
print("SAVE_STITCHED_PLOT =", SAVE_STITCHED_PLOT)
print("SAVE_REDNOISE_DIAGNOSTICS =", SAVE_REDNOISE_DIAGNOSTICS)

for fpath in files:
    try:
        run_one_file(fpath)
    except Exception as e:
        print("FAILED:", fpath.name)
        print("Reason:", repr(e))
        cleanup_memory()
        continue

print("\nAll done.")
# Out:
# Found 2 files in C:\Users\domin\juwavelet\examples\CWT Whole Orbit\l3\OneFile
# Will write L6* cluster netCDF to: C:\Users\domin\juwavelet\examples\CWT Whole Orbit\l6\OneFile
# Will write plot outputs to: C:\Users\domin\juwavelet\examples\CWT Whole Orbit\outputs_decompose2d_slices_single_noise_filtering_AUTO_BATCH
# SAVE_SLICE_PLOTS = False
# SAVE_STITCHED_PLOT = True
# SAVE_REDNOISE_DIAGNOSTICS = False
#
# ========================================
# File: awe_l3a_tmp_2025153T1853_08658_v01.nc
# Detected product: l3a
# Runs: [{'name': 'base', 'MIN_AMP': 1.25, 'THR': 0.6, 'WHITE_NOISE_THRESHOLD': 0.1, 'WPS_NOISE_THRESHOLD': 8.0}]
# [awe_l3a_tmp_2025153T1853_08658_v01.nc | base] core=0:600 ext=0:650
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 2.987175064396076 idx= (np.int64(13), np.int64(0), np.int64(92), np.int64(36))
# selected elements: 40928
# ------------
# cluster= 1
# amplitude= 2.663788036215939 idx= (np.int64(1), np.int64(0), np.int64(90), np.int64(43))
# selected elements: 7715
# ------------
# cluster= 2
# amplitude= 2.602569958047438 idx= (np.int64(14), np.int64(17), np.int64(91), np.int64(37))
# selected elements: 27782
# ------------
# cluster= 3
# amplitude= 2.560280986299106 idx= (np.int64(5), np.int64(9), np.int64(138), np.int64(24))
# selected elements: 150847
# ------------
# cluster= 4
# amplitude= 2.4738937823888554 idx= (np.int64(0), np.int64(9), np.int64(28), np.int64(23))
# selected elements: 24069
# ------------
# cluster= 5
# amplitude= 2.441215134284769 idx= (np.int64(0), np.int64(9), np.int64(304), np.int64(23))
# selected elements: 13368
# ------------
# cluster= 6
# amplitude= 2.347290673391176 idx= (np.int64(0), np.int64(0), np.int64(20), np.int64(34))
# selected elements: 17031
# ------------
# cluster= 7
# amplitude= 2.2772505983079845 idx= (np.int64(21), np.int64(9), np.int64(190), np.int64(22))
# selected elements: 117851
# ------------
# cluster= 8
# amplitude= 2.1302299584225413 idx= (np.int64(15), np.int64(9), np.int64(203), np.int64(23))
# selected elements: 11354
# ------------
# cluster= 9
# amplitude= 2.004584479065084 idx= (np.int64(1), np.int64(4), np.int64(137), np.int64(32))
# selected elements: 952
# ------------
# cluster= 10
# amplitude= 1.9588481961214341 idx= (np.int64(1), np.int64(17), np.int64(91), np.int64(44))
# selected elements: 2719
# ------------
# cluster= 11
# amplitude= 1.9000664619879217 idx= (np.int64(1), np.int64(8), np.int64(128), np.int64(29))
# selected elements: 1884
# ------------
# cluster= 12
# amplitude= 1.8445166859805944 idx= (np.int64(12), np.int64(9), np.int64(306), np.int64(24))
# selected elements: 16714
# ------------
# cluster= 13
# amplitude= 1.5879307563598781 idx= (np.int64(1), np.int64(9), np.int64(139), np.int64(32))
# selected elements: 84
# ------------
# cluster= 14
# amplitude= 1.537751079987633 idx= (np.int64(0), np.int64(7), np.int64(130), np.int64(29))
# selected elements: 159
# ------------
# cluster= 15
# amplitude= 1.5085825399066937 idx= (np.int64(0), np.int64(14), np.int64(129), np.int64(31))
# selected elements: 2461
# ------------
# cluster= 16
# amplitude= 1.475851418928572 idx= (np.int64(11), np.int64(17), np.int64(20), np.int64(34))
# selected elements: 4724
# ------------
# cluster= 17
# amplitude= 1.4666395601339692 idx= (np.int64(1), np.int64(13), np.int64(128), np.int64(31))
# selected elements: 217
# ------------
# cluster= 18
# amplitude= 1.4255327394346748 idx= (np.int64(3), np.int64(16), np.int64(136), np.int64(33))
# selected elements: 2136
# ------------
# cluster= 19
# amplitude= 1.4224271655698317 idx= (np.int64(6), np.int64(17), np.int64(21), np.int64(33))
# selected elements: 2058
# ------------
# cluster= 20
# amplitude= 1.414953123091111 idx= (np.int64(0), np.int64(17), np.int64(21), np.int64(29))
# selected elements: 827
# ------------
# cluster= 21
# amplitude= 1.41313261705845 idx= (np.int64(16), np.int64(10), np.int64(34), np.int64(23))
# selected elements: 5847
# ------------
# cluster= 22
# amplitude= 1.3641945982216686 idx= (np.int64(23), np.int64(11), np.int64(288), np.int64(31))
# selected elements: 1347
# ------------
# cluster= 23
# amplitude= 1.3497719274927964 idx= (np.int64(18), np.int64(8), np.int64(38), np.int64(22))
# selected elements: 5842
# ------------
# cluster= 24
# amplitude= 1.3489185829037358 idx= (np.int64(0), np.int64(7), np.int64(91), np.int64(24))
# selected elements: 2856
# ------------
# cluster= 25
# amplitude= 1.336020263492151 idx= (np.int64(13), np.int64(10), np.int64(260), np.int64(28))
# selected elements: 3637
# ------------
# cluster= 26
# amplitude= 1.3061087215624403 idx= (np.int64(0), np.int64(8), np.int64(312), np.int64(39))
# selected elements: 165
# ------------
# cluster= 27
# amplitude= 1.2789071477980152 idx= (np.int64(13), np.int64(8), np.int64(185), np.int64(22))
# selected elements: 4615
# [awe_l3a_tmp_2025153T1853_08658_v01.nc | base] core=600:1200 ext=550:1250
# ------------
# cluster= 0
# amplitude= 2.9148223868827574 idx= (np.int64(8), np.int64(9), np.int64(84), np.int64(23))
# selected elements: 95787
# ------------
# cluster= 1
# amplitude= 2.4753306788172695 idx= (np.int64(0), np.int64(9), np.int64(85), np.int64(22))
# selected elements: 1363
# ------------
# cluster= 2
# amplitude= 2.3623299142272547 idx= (np.int64(0), np.int64(9), np.int64(296), np.int64(23))
# selected elements: 12828
# ------------
# cluster= 3
# amplitude= 2.3094429453171434 idx= (np.int64(17), np.int64(9), np.int64(233), np.int64(26))
# selected elements: 59004
# ------------
# cluster= 4
# amplitude= 2.272671984489097 idx= (np.int64(17), np.int64(9), np.int64(90), np.int64(22))
# selected elements: 26134
# ------------
# cluster= 5
# amplitude= 2.2503534347601315 idx= (np.int64(8), np.int64(9), np.int64(293), np.int64(24))
# selected elements: 33428
# ------------
# cluster= 6
# amplitude= 2.2452468176145803 idx= (np.int64(0), np.int64(9), np.int64(165), np.int64(23))
# selected elements: 29495
# ------------
# cluster= 7
# amplitude= 2.0144659331298405 idx= (np.int64(21), np.int64(9), np.int64(282), np.int64(26))
# selected elements: 12050
# ------------
# cluster= 8
# amplitude= 1.7758763284536065 idx= (np.int64(11), np.int64(4), np.int64(300), np.int64(38))
# selected elements: 20392
# ------------
# cluster= 9
# amplitude= 1.6984732216321932 idx= (np.int64(4), np.int64(5), np.int64(332), np.int64(40))
# selected elements: 9011
# ------------
# cluster= 10
# amplitude= 1.695437248530689 idx= (np.int64(0), np.int64(10), np.int64(233), np.int64(23))
# selected elements: 1779
# ------------
# cluster= 11
# amplitude= 1.660768690648613 idx= (np.int64(14), np.int64(10), np.int64(32), np.int64(28))
# selected elements: 7582
# ------------
# cluster= 12
# amplitude= 1.561246474913225 idx= (np.int64(19), np.int64(8), np.int64(300), np.int64(29))
# selected elements: 1907
# ------------
# cluster= 13
# amplitude= 1.550576789647968 idx= (np.int64(18), np.int64(8), np.int64(171), np.int64(25))
# selected elements: 3701
# ------------
# cluster= 14
# amplitude= 1.548040685659005 idx= (np.int64(6), np.int64(8), np.int64(231), np.int64(24))
# selected elements: 3963
# ------------
# cluster= 15
# amplitude= 1.5108490038854965 idx= (np.int64(21), np.int64(7), np.int64(158), np.int64(32))
# selected elements: 4881
# ------------
# cluster= 16
# amplitude= 1.4999207600397915 idx= (np.int64(7), np.int64(4), np.int64(273), np.int64(37))
# selected elements: 3557
# ------------
# cluster= 17
# amplitude= 1.4672217881608258 idx= (np.int64(23), np.int64(9), np.int64(56), np.int64(27))
# selected elements: 2381
# ------------
# cluster= 18
# amplitude= 1.4670546206224033 idx= (np.int64(13), np.int64(11), np.int64(111), np.int64(38))
# selected elements: 10777
# ------------
# cluster= 19
# amplitude= 1.4293648424922665 idx= (np.int64(6), np.int64(5), np.int64(274), np.int64(38))
# selected elements: 5063
# ------------
# cluster= 20
# amplitude= 1.4076136847052565 idx= (np.int64(14), np.int64(9), np.int64(173), np.int64(22))
# selected elements: 877
# ------------
# cluster= 21
# amplitude= 1.3871721504552583 idx= (np.int64(22), np.int64(8), np.int64(64), np.int64(27))
# selected elements: 1248
# ------------
# cluster= 22
# amplitude= 1.379350365804255 idx= (np.int64(10), np.int64(8), np.int64(227), np.int64(22))
# selected elements: 2549
# ------------
# cluster= 23
# amplitude= 1.3280783775771805 idx= (np.int64(0), np.int64(8), np.int64(225), np.int64(23))
# selected elements: 845
# ------------
# cluster= 24
# amplitude= 1.325517461646483 idx= (np.int64(18), np.int64(4), np.int64(179), np.int64(35))
# selected elements: 933
# ------------
# cluster= 25
# amplitude= 1.3254520143080548 idx= (np.int64(19), np.int64(7), np.int64(165), np.int64(31))
# selected elements: 111
# ------------
# cluster= 26
# amplitude= 1.316240739859577 idx= (np.int64(19), np.int64(3), np.int64(177), np.int64(35))
# selected elements: 77
# ------------
# cluster= 27
# amplitude= 1.3111120103157796 idx= (np.int64(10), np.int64(10), np.int64(230), np.int64(23))
# selected elements: 1596
# ------------
# cluster= 28
# amplitude= 1.302588090123615 idx= (np.int64(1), np.int64(4), np.int64(270), np.int64(37))
# selected elements: 905
# ------------
# cluster= 29
# amplitude= 1.3021074121879594 idx= (np.int64(9), np.int64(8), np.int64(48), np.int64(24))
# selected elements: 3994
# ------------
# cluster= 30
# amplitude= 1.3004303394494514 idx= (np.int64(0), np.int64(8), np.int64(37), np.int64(39))
# selected elements: 1335
# ------------
# cluster= 31
# amplitude= 1.284959680981465 idx= (np.int64(18), np.int64(5), np.int64(264), np.int64(35))
# selected elements: 2939
# [awe_l3a_tmp_2025153T1853_08658_v01.nc | base] core=1200:1529 ext=1150:1529
# ------------
# cluster= 0
# amplitude= 4.683106707460237 idx= (np.int64(0), np.int64(9), np.int64(58), np.int64(32))
# selected elements: 151499
# ------------
# cluster= 1
# amplitude= 2.9261671494824513 idx= (np.int64(2), np.int64(9), np.int64(89), np.int64(23))
# selected elements: 1185
# ------------
# cluster= 2
# amplitude= 2.178374943457481 idx= (np.int64(16), np.int64(8), np.int64(68), np.int64(34))
# selected elements: 54101
# ------------
# cluster= 3
# amplitude= 2.088895637518816 idx= (np.int64(11), np.int64(9), np.int64(111), np.int64(21))
# selected elements: 17334
# ------------
# cluster= 4
# amplitude= 2.043749980978042 idx= (np.int64(7), np.int64(16), np.int64(61), np.int64(37))
# selected elements: 2839
# ------------
# cluster= 5
# amplitude= 1.9489452611431195 idx= (np.int64(0), np.int64(17), np.int64(88), np.int64(38))
# selected elements: 4639
# ------------
# cluster= 6
# amplitude= 1.9438048734741287 idx= (np.int64(5), np.int64(6), np.int64(90), np.int64(37))
# selected elements: 11554
# ------------
# cluster= 7
# amplitude= 1.9395477083060138 idx= (np.int64(11), np.int64(13), np.int64(59), np.int64(39))
# selected elements: 2923
# ------------
# cluster= 8
# amplitude= 1.9213154294123043 idx= (np.int64(20), np.int64(14), np.int64(68), np.int64(34))
# selected elements: 10869
# ------------
# cluster= 9
# amplitude= 1.9030556513231038 idx= (np.int64(19), np.int64(9), np.int64(101), np.int64(23))
# selected elements: 10707
# ------------
# cluster= 10
# amplitude= 1.8414317278643537 idx= (np.int64(23), np.int64(8), np.int64(108), np.int64(26))
# selected elements: 137
# ------------
# cluster= 11
# amplitude= 1.7725222603941226 idx= (np.int64(5), np.int64(13), np.int64(68), np.int64(37))
# selected elements: 1992
# ------------
# cluster= 12
# amplitude= 1.7694984349324032 idx= (np.int64(0), np.int64(6), np.int64(63), np.int64(30))
# selected elements: 657
# ------------
# cluster= 13
# amplitude= 1.7655513070002942 idx= (np.int64(6), np.int64(13), np.int64(51), np.int64(36))
# selected elements: 269
# ------------
# cluster= 14
# amplitude= 1.718407230129453 idx= (np.int64(1), np.int64(11), np.int64(91), np.int64(35))
# selected elements: 2257
# ------------
# cluster= 15
# amplitude= 1.711628325098622 idx= (np.int64(22), np.int64(8), np.int64(113), np.int64(26))
# selected elements: 30
# ------------
# cluster= 16
# amplitude= 1.7059559587149855 idx= (np.int64(8), np.int64(14), np.int64(68), np.int64(38))
# selected elements: 1749
# ------------
# cluster= 17
# amplitude= 1.7043764971997943 idx= (np.int64(22), np.int64(7), np.int64(116), np.int64(34))
# selected elements: 6
# ------------
# cluster= 18
# amplitude= 1.6947360919587784 idx= (np.int64(4), np.int64(5), np.int64(31), np.int64(40))
# selected elements: 8526
# ------------
# cluster= 19
# amplitude= 1.65886235576256 idx= (np.int64(3), np.int64(7), np.int64(91), np.int64(35))
# selected elements: 1160
# ------------
# cluster= 20
# amplitude= 1.6445445923062416 idx= (np.int64(0), np.int64(7), np.int64(90), np.int64(35))
# selected elements: 221
# ------------
# cluster= 21
# amplitude= 1.5752191022432684 idx= (np.int64(9), np.int64(0), np.int64(64), np.int64(36))
# selected elements: 1539
# ------------
# cluster= 22
# amplitude= 1.5633740291333909 idx= (np.int64(9), np.int64(7), np.int64(89), np.int64(31))
# selected elements: 5416
# ------------
# cluster= 23
# amplitude= 1.5467006140405992 idx= (np.int64(20), np.int64(8), np.int64(56), np.int64(25))
# selected elements: 285
# ------------
# cluster= 24
# amplitude= 1.4950930327306582 idx= (np.int64(20), np.int64(5), np.int64(50), np.int64(32))
# selected elements: 540
# ------------
# cluster= 25
# amplitude= 1.4420540503387413 idx= (np.int64(15), np.int64(10), np.int64(82), np.int64(34))
# selected elements: 1788
# ------------
# cluster= 26
# amplitude= 1.415224351429909 idx= (np.int64(1), np.int64(6), np.int64(63), np.int64(41))
# selected elements: 178
# ------------
# cluster= 27
# amplitude= 1.383198209227826 idx= (np.int64(19), np.int64(11), np.int64(79), np.int64(40))
# selected elements: 283
# ------------
# cluster= 28
# amplitude= 1.3519490945121253 idx= (np.int64(8), np.int64(10), np.int64(60), np.int64(40))
# selected elements: 1431
# ------------
# cluster= 29
# amplitude= 1.321229254168367 idx= (np.int64(5), np.int64(17), np.int64(48), np.int64(32))
# selected elements: 380
# ------------
# cluster= 30
# amplitude= 1.3157020119349 idx= (np.int64(1), np.int64(9), np.int64(87), np.int64(35))
# selected elements: 59
# ------------
# cluster= 31
# amplitude= 1.2946762309600255 idx= (np.int64(1), np.int64(0), np.int64(87), np.int64(41))
# selected elements: 647
# ------------
# cluster= 32
# amplitude= 1.2822087207312027 idx= (np.int64(10), np.int64(15), np.int64(67), np.int64(38))
# selected elements: 735
# ------------
# cluster= 33
# amplitude= 1.281024102665096 idx= (np.int64(11), np.int64(1), np.int64(64), np.int64(35))
# selected elements: 3005
# Done per slice processing. Outputs in C:\Users\domin\juwavelet\examples\CWT Whole Orbit\outputs_decompose2d_slices_single_noise_filtering_AUTO_BATCH\awe_l3a_tmp_2025153T1853_08658_v01\base_offset_0000
# Saved output with clusters: C:\Users\domin\juwavelet\examples\CWT Whole Orbit\l6\OneFile\awe_l6a_tmp_2025153T1853_08658_v01.nc
#
# ========================================
# File: awe_l3c_q20_2025153T1853_08658_v01.nc
# Detected product: l3c
# Runs: [{'name': 'base', 'MIN_AMP': 0.2, 'THR': 0.15, 'WHITE_NOISE_THRESHOLD': 0.02, 'WPS_NOISE_THRESHOLD': 8.0}]
# [awe_l3c_q20_2025153T1853_08658_v01.nc | base] core=0:600 ext=0:650
# ------------
# cluster= 0
# amplitude= 1.065008202242747 idx= (np.int64(12), np.int64(0), np.int64(110), np.int64(24))
# selected elements: 251797
# ------------
# cluster= 1
# amplitude= 0.7790753687534796 idx= (np.int64(10), np.int64(17), np.int64(111), np.int64(22))
# selected elements: 108535
# ------------
# cluster= 2
# amplitude= 0.7528656522346165 idx= (np.int64(17), np.int64(17), np.int64(110), np.int64(19))
# selected elements: 87524
# ------------
# cluster= 3
# amplitude= 0.529570013063408 idx= (np.int64(8), np.int64(9), np.int64(276), np.int64(118))
# selected elements: 38726
# ------------
# cluster= 4
# amplitude= 0.47845135971017644 idx= (np.int64(11), np.int64(17), np.int64(109), np.int64(125))
# selected elements: 16587
# ------------
# cluster= 5
# amplitude= 0.4735017978553 idx= (np.int64(16), np.int64(1), np.int64(110), np.int64(121))
# selected elements: 20494
# ------------
# cluster= 6
# amplitude= 0.4489385728778952 idx= (np.int64(11), np.int64(15), np.int64(129), np.int64(14))
# selected elements: 20631
# ------------
# cluster= 7
# amplitude= 0.4445751872530144 idx= (np.int64(18), np.int64(17), np.int64(109), np.int64(121))
# selected elements: 6428
# ------------
# cluster= 8
# amplitude= 0.4407096861376555 idx= (np.int64(8), np.int64(1), np.int64(109), np.int64(127))
# selected elements: 9081
# ------------
# cluster= 9
# amplitude= 0.4348323509736829 idx= (np.int64(23), np.int64(17), np.int64(110), np.int64(121))
# selected elements: 7205
# ------------
# cluster= 10
# amplitude= 0.4279956403402982 idx= (np.int64(23), np.int64(1), np.int64(110), np.int64(117))
# selected elements: 6288
# ------------
# cluster= 11
# amplitude= 0.416837440724312 idx= (np.int64(7), np.int64(16), np.int64(125), np.int64(42))
# selected elements: 8313
# ------------
# cluster= 12
# amplitude= 0.39758292334972434 idx= (np.int64(19), np.int64(13), np.int64(134), np.int64(46))
# selected elements: 30212
# ------------
# cluster= 13
# amplitude= 0.39010304771943927 idx= (np.int64(23), np.int64(7), np.int64(174), np.int64(47))
# selected elements: 75600
# ------------
# cluster= 14
# amplitude= 0.3885270622439965 idx= (np.int64(23), np.int64(10), np.int64(170), np.int64(40))
# selected elements: 10522
# ------------
# cluster= 15
# amplitude= 0.3877651843256887 idx= (np.int64(23), np.int64(13), np.int64(172), np.int64(46))
# selected elements: 3729
# ------------
# cluster= 16
# amplitude= 0.38648829023760833 idx= (np.int64(9), np.int64(14), np.int64(128), np.int64(13))
# selected elements: 3159
# ------------
# cluster= 17
# amplitude= 0.37732236743229636 idx= (np.int64(10), np.int64(8), np.int64(172), np.int64(38))
# selected elements: 57190
# ------------
# cluster= 18
# amplitude= 0.3706180850553238 idx= (np.int64(3), np.int64(14), np.int64(166), np.int64(39))
# selected elements: 8353
# ------------
# cluster= 19
# amplitude= 0.36007157242100996 idx= (np.int64(3), np.int64(15), np.int64(129), np.int64(49))
# selected elements: 2629
# ------------
# cluster= 20
# amplitude= 0.3596768146772987 idx= (np.int64(4), np.int64(13), np.int64(119), np.int64(120))
# selected elements: 5243
# ------------
# cluster= 21
# amplitude= 0.344249447331722 idx= (np.int64(7), np.int64(15), np.int64(124), np.int64(12))
# selected elements: 802
# ------------
# cluster= 22
# amplitude= 0.32393531286215993 idx= (np.int64(17), np.int64(8), np.int64(125), np.int64(9))
# selected elements: 35553
# ------------
# cluster= 23
# amplitude= 0.3058612807354655 idx= (np.int64(21), np.int64(15), np.int64(172), np.int64(32))
# selected elements: 5807
# ------------
# cluster= 24
# amplitude= 0.2999113050326432 idx= (np.int64(16), np.int64(10), np.int64(276), np.int64(133))
# selected elements: 29534
# ------------
# cluster= 25
# amplitude= 0.2903814391485401 idx= (np.int64(5), np.int64(14), np.int64(124), np.int64(15))
# selected elements: 2082
# ------------
# cluster= 26
# amplitude= 0.29017301782842625 idx= (np.int64(23), np.int64(17), np.int64(280), np.int64(119))
# selected elements: 2670
# ------------
# cluster= 27
# amplitude= 0.2880632948275161 idx= (np.int64(8), np.int64(2), np.int64(109), np.int64(9))
# selected elements: 2588
# ------------
# cluster= 28
# amplitude= 0.28461651132820914 idx= (np.int64(13), np.int64(11), np.int64(173), np.int64(63))
# selected elements: 12627
# ------------
# cluster= 29
# amplitude= 0.2812692123167272 idx= (np.int64(15), np.int64(10), np.int64(170), np.int64(65))
# selected elements: 5467
# ------------
# cluster= 30
# amplitude= 0.276167732531401 idx= (np.int64(12), np.int64(13), np.int64(155), np.int64(68))
# selected elements: 6640
# ------------
# cluster= 31
# amplitude= 0.2742542616806663 idx= (np.int64(21), np.int64(11), np.int64(122), np.int64(18))
# selected elements: 4250
# ------------
# cluster= 32
# amplitude= 0.271014976303341 idx= (np.int64(10), np.int64(17), np.int64(110), np.int64(63))
# selected elements: 450
# ------------
# cluster= 33
# amplitude= 0.2676728521066292 idx= (np.int64(19), np.int64(9), np.int64(165), np.int64(118))
# selected elements: 19202
# ------------
# cluster= 34
# amplitude= 0.26266939195913735 idx= (np.int64(2), np.int64(15), np.int64(118), np.int64(16))
# selected elements: 710
# ------------
# cluster= 35
# amplitude= 0.26200475096793546 idx= (np.int64(12), np.int64(8), np.int64(165), np.int64(117))
# selected elements: 9102
# ------------
# cluster= 36
# amplitude= 0.25497369760933936 idx= (np.int64(4), np.int64(10), np.int64(188), np.int64(99))
# selected elements: 2509
# ------------
# cluster= 37
# amplitude= 0.25213809783757796 idx= (np.int64(23), np.int64(12), np.int64(180), np.int64(46))
# selected elements: 35
# ------------
# cluster= 38
# amplitude= 0.25174082198367714 idx= (np.int64(5), np.int64(16), np.int64(111), np.int64(6))
# selected elements: 525
# ------------
# cluster= 39
# amplitude= 0.25125422845286743 idx= (np.int64(14), np.int64(15), np.int64(152), np.int64(79))
# selected elements: 2040
# ------------
# cluster= 40
# amplitude= 0.2511678477211606 idx= (np.int64(7), np.int64(15), np.int64(141), np.int64(56))
# selected elements: 1153
# ------------
# cluster= 41
# amplitude= 0.2503240102956359 idx= (np.int64(20), np.int64(3), np.int64(110), np.int64(8))
# selected elements: 2643
# ------------
# cluster= 42
# amplitude= 0.25012790756030495 idx= (np.int64(17), np.int64(8), np.int64(149), np.int64(115))
# selected elements: 2759
# ------------
# cluster= 43
# amplitude= 0.24898602284550364 idx= (np.int64(6), np.int64(15), np.int64(168), np.int64(75))
# selected elements: 4086
# ------------
# cluster= 44
# amplitude= 0.24881558886905453 idx= (np.int64(11), np.int64(15), np.int64(119), np.int64(46))
# selected elements: 769
# ------------
# cluster= 45
# amplitude= 0.24438524892346838 idx= (np.int64(9), np.int64(11), np.int64(164), np.int64(47))
# selected elements: 1932
# ------------
# cluster= 46
# amplitude= 0.2431505044235265 idx= (np.int64(7), np.int64(13), np.int64(131), np.int64(18))
# selected elements: 506
# ------------
# cluster= 47
# amplitude= 0.24182106799675251 idx= (np.int64(10), np.int64(10), np.int64(162), np.int64(117))
# selected elements: 3053
# ------------
# cluster= 48
# amplitude= 0.24043409329095505 idx= (np.int64(9), np.int64(15), np.int64(117), np.int64(85))
# selected elements: 5895
# ------------
# cluster= 49
# amplitude= 0.23954717847928614 idx= (np.int64(15), np.int64(13), np.int64(129), np.int64(28))
# selected elements: 1303
# ------------
# cluster= 50
# amplitude= 0.23937039292816137 idx= (np.int64(6), np.int64(16), np.int64(300), np.int64(85))
# selected elements: 2474
# ------------
# cluster= 51
# amplitude= 0.23514879251733115 idx= (np.int64(12), np.int64(16), np.int64(185), np.int64(25))
# selected elements: 5432
# ------------
# cluster= 52
# amplitude= 0.2345900603003082 idx= (np.int64(7), np.int64(15), np.int64(118), np.int64(79))
# selected elements: 618
# ------------
# cluster= 53
# amplitude= 0.23373212898167173 idx= (np.int64(0), np.int64(9), np.int64(206), np.int64(72))
# selected elements: 573
# ------------
# cluster= 54
# amplitude= 0.23090258275039027 idx= (np.int64(21), np.int64(12), np.int64(125), np.int64(38))
# selected elements: 525
# ------------
# cluster= 55
# amplitude= 0.2297598222052426 idx= (np.int64(22), np.int64(17), np.int64(269), np.int64(120))
# selected elements: 266
# ------------
# cluster= 56
# amplitude= 0.22797241498440068 idx= (np.int64(16), np.int64(15), np.int64(155), np.int64(87))
# selected elements: 2266
# ------------
# cluster= 57
# amplitude= 0.22789970481714147 idx= (np.int64(10), np.int64(15), np.int64(189), np.int64(92))
# selected elements: 5397
# ------------
# cluster= 58
# amplitude= 0.22769210950938365 idx= (np.int64(1), np.int64(12), np.int64(124), np.int64(127))
# selected elements: 211
# ------------
# cluster= 59
# amplitude= 0.22649255565941243 idx= (np.int64(20), np.int64(6), np.int64(113), np.int64(6))
# selected elements: 438
# ------------
# cluster= 60
# amplitude= 0.22580706304013928 idx= (np.int64(11), np.int64(14), np.int64(184), np.int64(25))
# selected elements: 993
# ------------
# cluster= 61
# amplitude= 0.22452666543397326 idx= (np.int64(16), np.int64(3), np.int64(109), np.int64(7))
# selected elements: 1224
# ------------
# cluster= 62
# amplitude= 0.22250412627650554 idx= (np.int64(13), np.int64(11), np.int64(187), np.int64(18))
# selected elements: 2999
# ------------
# cluster= 63
# amplitude= 0.22246646204119172 idx= (np.int64(2), np.int64(14), np.int64(167), np.int64(77))
# selected elements: 425
# ------------
# cluster= 64
# amplitude= 0.22097421749202545 idx= (np.int64(9), np.int64(9), np.int64(190), np.int64(125))
# selected elements: 2775
# ------------
# cluster= 65
# amplitude= 0.22017477218236822 idx= (np.int64(16), np.int64(11), np.int64(112), np.int64(6))
# selected elements: 1563
# ------------
# cluster= 66
# amplitude= 0.21956939179291532 idx= (np.int64(18), np.int64(16), np.int64(108), np.int64(137))
# selected elements: 393
# ------------
# cluster= 67
# amplitude= 0.21624978481529405 idx= (np.int64(2), np.int64(15), np.int64(143), np.int64(40))
# selected elements: 414
# ------------
# cluster= 68
# amplitude= 0.21376478005163044 idx= (np.int64(10), np.int64(2), np.int64(116), np.int64(30))
# selected elements: 410
# ------------
# cluster= 69
# amplitude= 0.2114946559917757 idx= (np.int64(21), np.int64(16), np.int64(263), np.int64(120))
# selected elements: 164
# ------------
# cluster= 70
# amplitude= 0.2096728434947445 idx= (np.int64(6), np.int64(14), np.int64(241), np.int64(130))
# selected elements: 1154
# ------------
# cluster= 71
# amplitude= 0.2088727656703119 idx= (np.int64(3), np.int64(9), np.int64(272), np.int64(112))
# selected elements: 185
# ------------
# cluster= 72
# amplitude= 0.207960367540568 idx= (np.int64(21), np.int64(4), np.int64(114), np.int64(4))
# selected elements: 48
# ------------
# cluster= 73
# amplitude= 0.20784670245436132 idx= (np.int64(6), np.int64(9), np.int64(184), np.int64(105))
# selected elements: 381
# ------------
# cluster= 74
# amplitude= 0.20694472749891682 idx= (np.int64(2), np.int64(14), np.int64(121), np.int64(23))
# selected elements: 149
# ------------
# cluster= 75
# amplitude= 0.2062058304863496 idx= (np.int64(3), np.int64(14), np.int64(119), np.int64(40))
# selected elements: 63
# ------------
# cluster= 76
# amplitude= 0.20496106034559367 idx= (np.int64(17), np.int64(0), np.int64(216), np.int64(105))
# selected elements: 2050
# ------------
# cluster= 77
# amplitude= 0.20418814280154607 idx= (np.int64(5), np.int64(16), np.int64(161), np.int64(12))
# selected elements: 433
# ------------
# cluster= 78
# amplitude= 0.2037406802976791 idx= (np.int64(11), np.int64(12), np.int64(185), np.int64(23))
# selected elements: 593
# ------------
# cluster= 79
# amplitude= 0.20127075456279714 idx= (np.int64(15), np.int64(16), np.int64(116), np.int64(45))
# selected elements: 253
# [awe_l3c_q20_2025153T1853_08658_v01.nc | base] core=600:1200 ext=550:1250
# ------------
# cluster= 0
# amplitude= 0.5853157701088189 idx= (np.int64(21), np.int64(11), np.int64(275), np.int64(62))
# selected elements: 172742
# ------------
# cluster= 1
# amplitude= 0.4547317214105166 idx= (np.int64(7), np.int64(9), np.int64(247), np.int64(50))
# selected elements: 51567
# ------------
# cluster= 2
# amplitude= 0.3943128180411792 idx= (np.int64(12), np.int64(7), np.int64(54), np.int64(101))
# selected elements: 75006
# ------------
# cluster= 3
# amplitude= 0.39257290285445906 idx= (np.int64(11), np.int64(8), np.int64(187), np.int64(110))
# selected elements: 46539
# ------------
# cluster= 4
# amplitude= 0.3667284576289815 idx= (np.int64(16), np.int64(7), np.int64(191), np.int64(110))
# selected elements: 33295
# ------------
# cluster= 5
# amplitude= 0.35378358135295335 idx= (np.int64(17), np.int64(7), np.int64(53), np.int64(102))
# selected elements: 11730
# ------------
# cluster= 6
# amplitude= 0.3462687355930563 idx= (np.int64(18), np.int64(9), np.int64(253), np.int64(48))
# selected elements: 5218
# ------------
# cluster= 7
# amplitude= 0.34398628706709666 idx= (np.int64(18), np.int64(8), np.int64(54), np.int64(105))
# selected elements: 12626
# ------------
# cluster= 8
# amplitude= 0.31973024145985335 idx= (np.int64(3), np.int64(7), np.int64(302), np.int64(45))
# selected elements: 5499
# ------------
# cluster= 9
# amplitude= 0.3173749501696696 idx= (np.int64(14), np.int64(15), np.int64(192), np.int64(118))
# selected elements: 25383
# ------------
# cluster= 10
# amplitude= 0.3144472510081977 idx= (np.int64(15), np.int64(9), np.int64(47), np.int64(143))
# selected elements: 12553
# ------------
# cluster= 11
# amplitude= 0.29126837394033633 idx= (np.int64(13), np.int64(9), np.int64(47), np.int64(144))
# selected elements: 2104
# ------------
# cluster= 12
# amplitude= 0.2712992924637902 idx= (np.int64(20), np.int64(5), np.int64(192), np.int64(111))
# selected elements: 13400
# ------------
# cluster= 13
# amplitude= 0.2635161869390585 idx= (np.int64(3), np.int64(10), np.int64(236), np.int64(38))
# selected elements: 969
# ------------
# cluster= 14
# amplitude= 0.25193427354809256 idx= (np.int64(19), np.int64(7), np.int64(136), np.int64(88))
# selected elements: 12404
# ------------
# cluster= 15
# amplitude= 0.2517689575596733 idx= (np.int64(18), np.int64(8), np.int64(133), np.int64(91))
# selected elements: 3085
# ------------
# cluster= 16
# amplitude= 0.2504407992001548 idx= (np.int64(20), np.int64(7), np.int64(253), np.int64(51))
# selected elements: 2900
# ------------
# cluster= 17
# amplitude= 0.24811668132182493 idx= (np.int64(23), np.int64(16), np.int64(56), np.int64(106))
# selected elements: 6621
# ------------
# cluster= 18
# amplitude= 0.23921406319908958 idx= (np.int64(6), np.int64(16), np.int64(25), np.int64(85))
# selected elements: 2752
# ------------
# cluster= 19
# amplitude= 0.2388376486927337 idx= (np.int64(22), np.int64(7), np.int64(258), np.int64(49))
# selected elements: 2075
# ------------
# cluster= 20
# amplitude= 0.2337923019656327 idx= (np.int64(11), np.int64(11), np.int64(295), np.int64(62))
# selected elements: 4340
# ------------
# cluster= 21
# amplitude= 0.23354131909693368 idx= (np.int64(15), np.int64(10), np.int64(309), np.int64(63))
# selected elements: 3226
# ------------
# cluster= 22
# amplitude= 0.23128932999023216 idx= (np.int64(15), np.int64(12), np.int64(309), np.int64(64))
# selected elements: 1804
# ------------
# cluster= 23
# amplitude= 0.23019629082780654 idx= (np.int64(4), np.int64(6), np.int64(319), np.int64(40))
# selected elements: 857
# ------------
# cluster= 24
# amplitude= 0.22844970073868134 idx= (np.int64(22), np.int64(17), np.int64(33), np.int64(100))
# selected elements: 4498
# ------------
# cluster= 25
# amplitude= 0.22844690318105748 idx= (np.int64(9), np.int64(14), np.int64(41), np.int64(28))
# selected elements: 5394
# ------------
# cluster= 26
# amplitude= 0.22691986633840774 idx= (np.int64(17), np.int64(6), np.int64(137), np.int64(90))
# selected elements: 2265
# ------------
# cluster= 27
# amplitude= 0.22189781028878383 idx= (np.int64(21), np.int64(14), np.int64(65), np.int64(26))
# selected elements: 4964
# ------------
# cluster= 28
# amplitude= 0.22000859583411383 idx= (np.int64(13), np.int64(8), np.int64(137), np.int64(96))
# selected elements: 1163
# ------------
# cluster= 29
# amplitude= 0.21792115176644047 idx= (np.int64(9), np.int64(16), np.int64(165), np.int64(74))
# selected elements: 2583
# ------------
# cluster= 30
# amplitude= 0.21350213994243009 idx= (np.int64(23), np.int64(15), np.int64(68), np.int64(115))
# selected elements: 780
# ------------
# cluster= 31
# amplitude= 0.21263498320584273 idx= (np.int64(15), np.int64(15), np.int64(45), np.int64(36))
# selected elements: 7171
# ------------
# cluster= 32
# amplitude= 0.21240472171727162 idx= (np.int64(7), np.int64(17), np.int64(75), np.int64(125))
# selected elements: 1782
# ------------
# cluster= 33
# amplitude= 0.2097628365804322 idx= (np.int64(7), np.int64(11), np.int64(277), np.int64(62))
# selected elements: 1314
# ------------
# cluster= 34
# amplitude= 0.20853419744125126 idx= (np.int64(11), np.int64(15), np.int64(41), np.int64(37))
# selected elements: 475
# ------------
# cluster= 35
# amplitude= 0.20844577605136674 idx= (np.int64(8), np.int64(6), np.int64(286), np.int64(55))
# selected elements: 1025
# ------------
# cluster= 36
# amplitude= 0.20532958600181153 idx= (np.int64(20), np.int64(1), np.int64(52), np.int64(96))
# selected elements: 4403
# ------------
# cluster= 37
# amplitude= 0.2053110111841092 idx= (np.int64(15), np.int64(10), np.int64(216), np.int64(132))
# selected elements: 2715
# ------------
# cluster= 38
# amplitude= 0.20475990200674968 idx= (np.int64(6), np.int64(16), np.int64(52), np.int64(76))
# selected elements: 1092
# ------------
# cluster= 39
# amplitude= 0.20397153420731048 idx= (np.int64(14), np.int64(15), np.int64(34), np.int64(87))
# selected elements: 4722
# ------------
# cluster= 40
# amplitude= 0.20357840304575617 idx= (np.int64(11), np.int64(7), np.int64(306), np.int64(42))
# selected elements: 1864
# ------------
# cluster= 41
# amplitude= 0.20149393741413757 idx= (np.int64(18), np.int64(5), np.int64(137), np.int64(90))
# selected elements: 482
# [awe_l3c_q20_2025153T1853_08658_v01.nc | base] core=1200:1800 ext=1150:1850
# ------------
# cluster= 0
# amplitude= 0.7976845655967509 idx= (np.int64(0), np.int64(9), np.int64(115), np.int64(85))
# selected elements: 5656
# ------------
# cluster= 1
# amplitude= 0.5561615128508507 idx= (np.int64(2), np.int64(9), np.int64(112), np.int64(37))
# selected elements: 22835
# ------------
# cluster= 2
# amplitude= 0.5373331354287789 idx= (np.int64(2), np.int64(9), np.int64(119), np.int64(62))
# selected elements: 7574
# ------------
# cluster= 3
# amplitude= 0.4292930554668385 idx= (np.int64(5), np.int64(9), np.int64(230), np.int64(24))
# selected elements: 11284
# ------------
# cluster= 4
# amplitude= 0.4173352956750017 idx= (np.int64(1), np.int64(9), np.int64(95), np.int64(61))
# selected elements: 3015
# ------------
# cluster= 5
# amplitude= 0.3585298042936317 idx= (np.int64(1), np.int64(9), np.int64(228), np.int64(31))
# selected elements: 1271
# ------------
# cluster= 6
# amplitude= 0.31399817838498495 idx= (np.int64(1), np.int64(9), np.int64(152), np.int64(15))
# selected elements: 2178
# ------------
# cluster= 7
# amplitude= 0.29679608716092104 idx= (np.int64(2), np.int64(9), np.int64(191), np.int64(48))
# selected elements: 2145
# ------------
# cluster= 8
# amplitude= 0.27149448631896095 idx= (np.int64(3), np.int64(9), np.int64(118), np.int64(24))
# selected elements: 406
# ------------
# cluster= 9
# amplitude= 0.2690335824384526 idx= (np.int64(9), np.int64(8), np.int64(117), np.int64(26))
# selected elements: 11482
# ------------
# cluster= 10
# amplitude= 0.26863060813282874 idx= (np.int64(0), np.int64(9), np.int64(218), np.int64(109))
# selected elements: 381
# ------------
# cluster= 11
# amplitude= 0.26272048863297504 idx= (np.int64(10), np.int64(10), np.int64(116), np.int64(26))
# selected elements: 623
# ------------
# cluster= 12
# amplitude= 0.2521197724305852 idx= (np.int64(8), np.int64(9), np.int64(70), np.int64(49))
# selected elements: 7698
# ------------
# cluster= 13
# amplitude= 0.25015543190771594 idx= (np.int64(0), np.int64(9), np.int64(159), np.int64(53))
# selected elements: 1055
# ------------
# cluster= 14
# amplitude= 0.24570143891362262 idx= (np.int64(0), np.int64(11), np.int64(118), np.int64(26))
# selected elements: 119
# ------------
# cluster= 15
# amplitude= 0.24367345546845037 idx= (np.int64(0), np.int64(9), np.int64(192), np.int64(23))
# selected elements: 1366
# ------------
# cluster= 16
# amplitude= 0.2424520587006447 idx= (np.int64(4), np.int64(10), np.int64(120), np.int64(23))
# selected elements: 191
# ------------
# cluster= 17
# amplitude= 0.23365134121810296 idx= (np.int64(0), np.int64(9), np.int64(158), np.int64(82))
# selected elements: 629
# ------------
# cluster= 18
# amplitude= 0.23212570453151934 idx= (np.int64(4), np.int64(6), np.int64(19), np.int64(40))
# selected elements: 1792
# ------------
# cluster= 19
# amplitude= 0.23130256012389586 idx= (np.int64(9), np.int64(9), np.int64(219), np.int64(20))
# selected elements: 1676
# ------------
# cluster= 20
# amplitude= 0.22784210722847353 idx= (np.int64(18), np.int64(9), np.int64(94), np.int64(39))
# selected elements: 8057
# ------------
# cluster= 21
# amplitude= 0.22665811023066082 idx= (np.int64(3), np.int64(9), np.int64(79), np.int64(27))
# selected elements: 951
# ------------
# cluster= 22
# amplitude= 0.22521850777615762 idx= (np.int64(2), np.int64(9), np.int64(227), np.int64(18))
# selected elements: 319
# ------------
# cluster= 23
# amplitude= 0.2241859468955088 idx= (np.int64(8), np.int64(10), np.int64(114), np.int64(121))
# selected elements: 1782
# ------------
# cluster= 24
# amplitude= 0.22065269029323256 idx= (np.int64(0), np.int64(10), np.int64(130), np.int64(17))
# selected elements: 69
# ------------
# cluster= 25
# amplitude= 0.21952642182007226 idx= (np.int64(1), np.int64(8), np.int64(127), np.int64(18))
# selected elements: 330
# ------------
# cluster= 26
# amplitude= 0.21719933568709537 idx= (np.int64(7), np.int64(7), np.int64(118), np.int64(27))
# selected elements: 374
# ------------
# cluster= 27
# amplitude= 0.21577538738547658 idx= (np.int64(3), np.int64(7), np.int64(223), np.int64(27))
# selected elements: 173
# ------------
# cluster= 28
# amplitude= 0.21551565580285617 idx= (np.int64(19), np.int64(13), np.int64(131), np.int64(80))
# selected elements: 9827
# ------------
# cluster= 29
# amplitude= 0.21172894157429634 idx= (np.int64(15), np.int64(11), np.int64(16), np.int64(66))
# selected elements: 8552
# ------------
# cluster= 30
# amplitude= 0.21070722451212714 idx= (np.int64(17), np.int64(10), np.int64(91), np.int64(50))
# selected elements: 3983
# ------------
# cluster= 31
# amplitude= 0.20589985199426447 idx= (np.int64(2), np.int64(8), np.int64(125), np.int64(39))
# selected elements: 109
# ------------
# cluster= 32
# amplitude= 0.20475427815225952 idx= (np.int64(8), np.int64(7), np.int64(223), np.int64(15))
# selected elements: 1212
# ------------
# cluster= 33
# amplitude= 0.2043399876318608 idx= (np.int64(5), np.int64(12), np.int64(117), np.int64(34))
# selected elements: 187
# ------------
# cluster= 34
# amplitude= 0.20427419518986728 idx= (np.int64(19), np.int64(12), np.int64(19), np.int64(78))
# selected elements: 11818
# ------------
# cluster= 35
# amplitude= 0.2041955065354012 idx= (np.int64(3), np.int64(9), np.int64(102), np.int64(108))
# selected elements: 764
# ------------
# cluster= 36
# amplitude= 0.20405929160478428 idx= (np.int64(6), np.int64(7), np.int64(224), np.int64(26))
# selected elements: 113
# ------------
# cluster= 37
# amplitude= 0.20254669142741943 idx= (np.int64(0), np.int64(8), np.int64(124), np.int64(39))
# selected elements: 39
# [awe_l3c_q20_2025153T1853_08658_v01.nc | base] core=1800:2400 ext=1750:2450
# ------------
# cluster= 0
# amplitude= 0.225785230085554 idx= (np.int64(15), np.int64(11), np.int64(300), np.int64(129))
# selected elements: 11059
# [awe_l3c_q20_2025153T1853_08658_v01.nc | base] core=2400:3000 ext=2350:3050
# ------------
# cluster= 0
# amplitude= 0.4127051722451599 idx= (np.int64(16), np.int64(7), np.int64(332), np.int64(105))
# selected elements: 121917
# ------------
# cluster= 1
# amplitude= 0.4049303872529722 idx= (np.int64(14), np.int64(11), np.int64(266), np.int64(105))
# selected elements: 25879
# ------------
# cluster= 2
# amplitude= 0.37430449384976655 idx= (np.int64(18), np.int64(11), np.int64(304), np.int64(117))
# selected elements: 25823
# ------------
# cluster= 3
# amplitude= 0.3496570039315595 idx= (np.int64(10), np.int64(5), np.int64(284), np.int64(83))
# selected elements: 17952
# ------------
# cluster= 4
# amplitude= 0.34692995136546195 idx= (np.int64(12), np.int64(11), np.int64(266), np.int64(103))
# selected elements: 9015
# ------------
# cluster= 5
# amplitude= 0.3047367855775629 idx= (np.int64(10), np.int64(2), np.int64(330), np.int64(127))
# selected elements: 10863
# ------------
# cluster= 6
# amplitude= 0.2962200680300553 idx= (np.int64(19), np.int64(0), np.int64(334), np.int64(125))
# selected elements: 51088
# ------------
# cluster= 7
# amplitude= 0.27880580180290915 idx= (np.int64(21), np.int64(17), np.int64(331), np.int64(119))
# selected elements: 18069
# ------------
# cluster= 8
# amplitude= 0.25744900437800033 idx= (np.int64(12), np.int64(6), np.int64(333), np.int64(84))
# selected elements: 3717
# ------------
# cluster= 9
# amplitude= 0.25685355012417266 idx= (np.int64(22), np.int64(10), np.int64(223), np.int64(124))
# selected elements: 20940
# ------------
# cluster= 10
# amplitude= 0.24430624038316576 idx= (np.int64(11), np.int64(10), np.int64(302), np.int64(93))
# selected elements: 7620
# ------------
# cluster= 11
# amplitude= 0.24018088092244194 idx= (np.int64(16), np.int64(6), np.int64(320), np.int64(39))
# selected elements: 4117
# ------------
# cluster= 12
# amplitude= 0.23997924778265706 idx= (np.int64(12), np.int64(6), np.int64(332), np.int64(118))
# selected elements: 2412
# ------------
# cluster= 13
# amplitude= 0.23777487678036113 idx= (np.int64(21), np.int64(9), np.int64(214), np.int64(114))
# selected elements: 10903
# ------------
# cluster= 14
# amplitude= 0.23731930285772226 idx= (np.int64(12), np.int64(10), np.int64(193), np.int64(99))
# selected elements: 7047
# ------------
# cluster= 15
# amplitude= 0.23388307371081807 idx= (np.int64(14), np.int64(6), np.int64(290), np.int64(107))
# selected elements: 8313
# ------------
# cluster= 16
# amplitude= 0.2303622263813657 idx= (np.int64(18), np.int64(6), np.int64(326), np.int64(28))
# selected elements: 5823
# ------------
# cluster= 17
# amplitude= 0.22964937556128937 idx= (np.int64(17), np.int64(9), np.int64(287), np.int64(102))
# selected elements: 3936
# ------------
# cluster= 18
# amplitude= 0.2287597152948966 idx= (np.int64(6), np.int64(11), np.int64(160), np.int64(109))
# selected elements: 3325
# ------------
# cluster= 19
# amplitude= 0.22549731082040939 idx= (np.int64(14), np.int64(3), np.int64(294), np.int64(116))
# selected elements: 1703
# ------------
# cluster= 20
# amplitude= 0.22425553064382317 idx= (np.int64(7), np.int64(6), np.int64(300), np.int64(115))
# selected elements: 3310
# ------------
# cluster= 21
# amplitude= 0.22229169057642348 idx= (np.int64(15), np.int64(5), np.int64(317), np.int64(25))
# selected elements: 2995
# ------------
# cluster= 22
# amplitude= 0.21885361661017788 idx= (np.int64(18), np.int64(9), np.int64(342), np.int64(117))
# selected elements: 991
# ------------
# cluster= 23
# amplitude= 0.21700793979126226 idx= (np.int64(17), np.int64(8), np.int64(152), np.int64(85))
# selected elements: 11423
# ------------
# cluster= 24
# amplitude= 0.21200773503857034 idx= (np.int64(4), np.int64(5), np.int64(319), np.int64(25))
# selected elements: 1441
# ------------
# cluster= 25
# amplitude= 0.20944180776387533 idx= (np.int64(17), np.int64(5), np.int64(322), np.int64(23))
# selected elements: 1450
# ------------
# cluster= 26
# amplitude= 0.2089421085951876 idx= (np.int64(16), np.int64(12), np.int64(250), np.int64(84))
# selected elements: 1325
# ------------
# cluster= 27
# amplitude= 0.20861054476253565 idx= (np.int64(18), np.int64(5), np.int64(283), np.int64(106))
# selected elements: 10413
# ------------
# cluster= 28
# amplitude= 0.2076269774101661 idx= (np.int64(10), np.int64(11), np.int64(216), np.int64(83))
# selected elements: 1576
# ------------
# cluster= 29
# amplitude= 0.2060453818777206 idx= (np.int64(10), np.int64(4), np.int64(322), np.int64(132))
# selected elements: 1145
# ------------
# cluster= 30
# amplitude= 0.2035651503486699 idx= (np.int64(15), np.int64(4), np.int64(334), np.int64(92))
# selected elements: 1226
# ------------
# cluster= 31
# amplitude= 0.2032494978661353 idx= (np.int64(21), np.int64(11), np.int64(212), np.int64(83))
# selected elements: 7122
# ------------
# cluster= 32
# amplitude= 0.202974916613502 idx= (np.int64(5), np.int64(9), np.int64(271), np.int64(111))
# selected elements: 855
# ------------
# cluster= 33
# amplitude= 0.20154050908944857 idx= (np.int64(11), np.int64(6), np.int64(247), np.int64(63))
# selected elements: 2400
# ------------
# cluster= 34
# amplitude= 0.20047485093259018 idx= (np.int64(14), np.int64(4), np.int64(315), np.int64(25))
# selected elements: 1980
# ------------
# cluster= 35
# amplitude= 0.20043794894379988 idx= (np.int64(11), np.int64(3), np.int64(212), np.int64(96))
# selected elements: 2797
# ------------
# cluster= 36
# amplitude= 0.20025529711664564 idx= (np.int64(11), np.int64(10), np.int64(312), np.int64(124))
# selected elements: 1500
# [awe_l3c_q20_2025153T1853_08658_v01.nc | base] core=3000:3600 ext=2950:3650
# ------------
# cluster= 0
# amplitude= 0.6828651887266074 idx= (np.int64(19), np.int64(8), np.int64(136), np.int64(74))
# selected elements: 347855
# ------------
# cluster= 1
# amplitude= 0.6454728155626301 idx= (np.int64(12), np.int64(6), np.int64(131), np.int64(122))
# selected elements: 195015
# ------------
# cluster= 2
# amplitude= 0.6267779306812499 idx= (np.int64(8), np.int64(8), np.int64(157), np.int64(60))
# selected elements: 37014
# ------------
# cluster= 3
# amplitude= 0.5302096114810406 idx= (np.int64(13), np.int64(9), np.int64(75), np.int64(101))
# selected elements: 15700
# ------------
# cluster= 4
# amplitude= 0.4635608608439119 idx= (np.int64(16), np.int64(11), np.int64(66), np.int64(102))
# selected elements: 33702
# ------------
# cluster= 5
# amplitude= 0.46004337509712573 idx= (np.int64(15), np.int64(10), np.int64(74), np.int64(96))
# selected elements: 4319
# ------------
# cluster= 6
# amplitude= 0.42053209366322397 idx= (np.int64(5), np.int64(4), np.int64(138), np.int64(135))
# selected elements: 7577
# ------------
# cluster= 7
# amplitude= 0.41199548307092576 idx= (np.int64(16), np.int64(4), np.int64(53), np.int64(94))
# selected elements: 46970
# ------------
# cluster= 8
# amplitude= 0.40547875936318734 idx= (np.int64(19), np.int64(9), np.int64(145), np.int64(136))
# selected elements: 10588
# ------------
# cluster= 9
# amplitude= 0.4051202485830448 idx= (np.int64(10), np.int64(10), np.int64(144), np.int64(109))
# selected elements: 7847
# ------------
# cluster= 10
# amplitude= 0.3929951571511462 idx= (np.int64(17), np.int64(9), np.int64(78), np.int64(90))
# selected elements: 1685
# ------------
# cluster= 11
# amplitude= 0.3917627066410666 idx= (np.int64(16), np.int64(6), np.int64(91), np.int64(64))
# selected elements: 5038
# ------------
# cluster= 12
# amplitude= 0.3915826976954441 idx= (np.int64(19), np.int64(6), np.int64(67), np.int64(121))
# selected elements: 25902
# ------------
# cluster= 13
# amplitude= 0.36479357715039806 idx= (np.int64(15), np.int64(6), np.int64(35), np.int64(105))
# selected elements: 5564
# ------------
# cluster= 14
# amplitude= 0.3642468960143396 idx= (np.int64(23), np.int64(10), np.int64(136), np.int64(102))
# selected elements: 9598
# ------------
# cluster= 15
# amplitude= 0.35743107118892586 idx= (np.int64(13), np.int64(6), np.int64(95), np.int64(89))
# selected elements: 6432
# ------------
# cluster= 16
# amplitude= 0.3571235201084529 idx= (np.int64(18), np.int64(10), np.int64(33), np.int64(121))
# selected elements: 4730
# ------------
# cluster= 17
# amplitude= 0.35229971096625823 idx= (np.int64(23), np.int64(1), np.int64(66), np.int64(82))
# selected elements: 27004
# ------------
# cluster= 18
# amplitude= 0.340228053868323 idx= (np.int64(6), np.int64(4), np.int64(52), np.int64(110))
# selected elements: 23744
# ------------
# cluster= 19
# amplitude= 0.339824657413233 idx= (np.int64(16), np.int64(7), np.int64(170), np.int64(125))
# selected elements: 1690
# ------------
# cluster= 20
# amplitude= 0.3210061131195916 idx= (np.int64(11), np.int64(7), np.int64(43), np.int64(80))
# selected elements: 3154
# ------------
# cluster= 21
# amplitude= 0.31626672366809677 idx= (np.int64(6), np.int64(9), np.int64(139), np.int64(122))
# selected elements: 4700
# ------------
# cluster= 22
# amplitude= 0.3139403908048481 idx= (np.int64(12), np.int64(3), np.int64(45), np.int64(117))
# selected elements: 6597
# ------------
# cluster= 23
# amplitude= 0.3126827755981292 idx= (np.int64(17), np.int64(2), np.int64(37), np.int64(127))
# selected elements: 15203
# ------------
# cluster= 24
# amplitude= 0.3100732928806831 idx= (np.int64(23), np.int64(3), np.int64(50), np.int64(111))
# selected elements: 6674
# ------------
# cluster= 25
# amplitude= 0.3062186794671457 idx= (np.int64(23), np.int64(9), np.int64(49), np.int64(138))
# selected elements: 2021
# ------------
# cluster= 26
# amplitude= 0.3030747767764709 idx= (np.int64(15), np.int64(10), np.int64(94), np.int64(137))
# selected elements: 1372
# ------------
# cluster= 27
# amplitude= 0.29714728328391604 idx= (np.int64(5), np.int64(6), np.int64(69), np.int64(99))
# selected elements: 2665
# ------------
# cluster= 28
# amplitude= 0.2953502244990647 idx= (np.int64(19), np.int64(0), np.int64(30), np.int64(127))
# selected elements: 5314
# ------------
# cluster= 29
# amplitude= 0.2924962982529902 idx= (np.int64(0), np.int64(10), np.int64(153), np.int64(110))
# selected elements: 1059
# ------------
# cluster= 30
# amplitude= 0.2923991983720905 idx= (np.int64(20), np.int64(10), np.int64(88), np.int64(139))
# selected elements: 1096
# ------------
# cluster= 31
# amplitude= 0.29145137782166886 idx= (np.int64(14), np.int64(15), np.int64(280), np.int64(125))
# selected elements: 12760
# ------------
# cluster= 32
# amplitude= 0.29103492603977127 idx= (np.int64(3), np.int64(8), np.int64(169), np.int64(67))
# selected elements: 1344
# ------------
# cluster= 33
# amplitude= 0.28981549108902926 idx= (np.int64(20), np.int64(10), np.int64(150), np.int64(124))
# selected elements: 3506
# ------------
# cluster= 34
# amplitude= 0.2895165768874036 idx= (np.int64(13), np.int64(11), np.int64(70), np.int64(98))
# selected elements: 3641
# ------------
# cluster= 35
# amplitude= 0.2885937670394115 idx= (np.int64(23), np.int64(7), np.int64(85), np.int64(114))
# selected elements: 2135
# ------------
# cluster= 36
# amplitude= 0.28185131255117246 idx= (np.int64(9), np.int64(2), np.int64(28), np.int64(130))
# selected elements: 2031
# ------------
# cluster= 37
# amplitude= 0.28177613188053174 idx= (np.int64(13), np.int64(8), np.int64(50), np.int64(71))
# selected elements: 2221
# ------------
# cluster= 38
# amplitude= 0.2796396470140002 idx= (np.int64(9), np.int64(10), np.int64(190), np.int64(128))
# selected elements: 3456
# ------------
# cluster= 39
# amplitude= 0.27941702094310616 idx= (np.int64(17), np.int64(3), np.int64(129), np.int64(110))
# selected elements: 8502
# ------------
# cluster= 40
# amplitude= 0.27804384928817755 idx= (np.int64(20), np.int64(17), np.int64(35), np.int64(115))
# selected elements: 7816
# ------------
# cluster= 41
# amplitude= 0.2780053882524231 idx= (np.int64(8), np.int64(8), np.int64(155), np.int64(122))
# selected elements: 1056
# ------------
# cluster= 42
# amplitude= 0.2735607223423554 idx= (np.int64(20), np.int64(10), np.int64(116), np.int64(33))
# selected elements: 3499
# ------------
# cluster= 43
# amplitude= 0.27173553809416745 idx= (np.int64(1), np.int64(7), np.int64(156), np.int64(65))
# selected elements: 683
# ------------
# cluster= 44
# amplitude= 0.26946667572580973 idx= (np.int64(15), np.int64(8), np.int64(160), np.int64(134))
# selected elements: 1943
# ------------
# cluster= 45
# amplitude= 0.26868807719299204 idx= (np.int64(9), np.int64(11), np.int64(62), np.int64(108))
# selected elements: 8284
# ------------
# cluster= 46
# amplitude= 0.2675299965221264 idx= (np.int64(9), np.int64(10), np.int64(122), np.int64(134))
# selected elements: 1670
# ------------
# cluster= 47
# amplitude= 0.2667346254150494 idx= (np.int64(10), np.int64(4), np.int64(78), np.int64(109))
# selected elements: 4725
# ------------
# cluster= 48
# amplitude= 0.26215621403299894 idx= (np.int64(22), np.int64(9), np.int64(288), np.int64(141))
# selected elements: 6829
# ------------
# cluster= 49
# amplitude= 0.2608629782833196 idx= (np.int64(12), np.int64(6), np.int64(34), np.int64(84))
# selected elements: 1143
# ------------
# cluster= 50
# amplitude= 0.2601455907940991 idx= (np.int64(13), np.int64(11), np.int64(117), np.int64(31))
# selected elements: 7410
# ------------
# cluster= 51
# amplitude= 0.25911940518142224 idx= (np.int64(18), np.int64(6), np.int64(30), np.int64(28))
# selected elements: 5599
# ------------
# cluster= 52
# amplitude= 0.2569895446259989 idx= (np.int64(17), np.int64(10), np.int64(198), np.int64(117))
# selected elements: 7039
# ------------
# cluster= 53
# amplitude= 0.256835896409526 idx= (np.int64(16), np.int64(8), np.int64(86), np.int64(129))
# selected elements: 525
# ------------
# cluster= 54
# amplitude= 0.2543507508607524 idx= (np.int64(20), np.int64(11), np.int64(43), np.int64(116))
# selected elements: 1884
# ------------
# cluster= 55
# amplitude= 0.25213933834294683 idx= (np.int64(4), np.int64(7), np.int64(161), np.int64(65))
# selected elements: 301
# ------------
# cluster= 56
# amplitude= 0.24765195089813855 idx= (np.int64(22), np.int64(5), np.int64(76), np.int64(91))
# selected elements: 774
# ------------
# cluster= 57
# amplitude= 0.24734521229556236 idx= (np.int64(12), np.int64(11), np.int64(25), np.int64(96))
# selected elements: 3260
# ------------
# cluster= 58
# amplitude= 0.24671904325484093 idx= (np.int64(8), np.int64(8), np.int64(184), np.int64(117))
# selected elements: 1932
# ------------
# cluster= 59
# amplitude= 0.24648244077746898 idx= (np.int64(7), np.int64(10), np.int64(138), np.int64(103))
# selected elements: 1455
# ------------
# cluster= 60
# amplitude= 0.2433166000514553 idx= (np.int64(12), np.int64(2), np.int64(144), np.int64(66))
# selected elements: 5650
# ------------
# cluster= 61
# amplitude= 0.24035166111561665 idx= (np.int64(11), np.int64(10), np.int64(160), np.int64(135))
# selected elements: 926
# ------------
# cluster= 62
# amplitude= 0.23936183576734849 idx= (np.int64(23), np.int64(4), np.int64(72), np.int64(85))
# selected elements: 281
# ------------
# cluster= 63
# amplitude= 0.2393286906756024 idx= (np.int64(8), np.int64(1), np.int64(54), np.int64(120))
# selected elements: 1072
# ------------
# cluster= 64
# amplitude= 0.2391767013213083 idx= (np.int64(12), np.int64(9), np.int64(119), np.int64(64))
# selected elements: 707
# ------------
# cluster= 65
# amplitude= 0.23868351021808246 idx= (np.int64(9), np.int64(8), np.int64(65), np.int64(97))
# selected elements: 348
# ------------
# cluster= 66
# amplitude= 0.2374330936814213 idx= (np.int64(8), np.int64(9), np.int64(126), np.int64(62))
# selected elements: 899
# ------------
# cluster= 67
# amplitude= 0.23644154076387544 idx= (np.int64(13), np.int64(7), np.int64(149), np.int64(53))
# selected elements: 372
# ------------
# cluster= 68
# amplitude= 0.2360631056693984 idx= (np.int64(18), np.int64(6), np.int64(166), np.int64(103))
# selected elements: 1476
# ------------
# cluster= 69
# amplitude= 0.23391777765610258 idx= (np.int64(16), np.int64(11), np.int64(23), np.int64(136))
# selected elements: 1825
# ------------
# cluster= 70
# amplitude= 0.23123854542666195 idx= (np.int64(22), np.int64(17), np.int64(53), np.int64(97))
# selected elements: 585
# ------------
# cluster= 71
# amplitude= 0.2292199370313651 idx= (np.int64(0), np.int64(9), np.int64(159), np.int64(57))
# selected elements: 129
# ------------
# cluster= 72
# amplitude= 0.22597939666957095 idx= (np.int64(22), np.int64(12), np.int64(320), np.int64(113))
# selected elements: 714
# ------------
# cluster= 73
# amplitude= 0.22569778407778968 idx= (np.int64(5), np.int64(4), np.int64(69), np.int64(101))
# selected elements: 482
# ------------
# cluster= 74
# amplitude= 0.22503719510756914 idx= (np.int64(16), np.int64(5), np.int64(17), np.int64(27))
# selected elements: 2633
# ------------
# cluster= 75
# amplitude= 0.22466586937247826 idx= (np.int64(12), np.int64(12), np.int64(156), np.int64(133))
# selected elements: 2785
# ------------
# cluster= 76
# amplitude= 0.2236947170505051 idx= (np.int64(9), np.int64(10), np.int64(231), np.int64(137))
# selected elements: 2833
# ------------
# cluster= 77
# amplitude= 0.22222683239483798 idx= (np.int64(22), np.int64(10), np.int64(280), np.int64(139))
# selected elements: 176
# ------------
# cluster= 78
# amplitude= 0.2221852736017511 idx= (np.int64(13), np.int64(5), np.int64(29), np.int64(94))
# selected elements: 1881
# ------------
# cluster= 79
# amplitude= 0.221344391604521 idx= (np.int64(11), np.int64(6), np.int64(188), np.int64(133))
# selected elements: 5275
# ------------
# cluster= 80
# amplitude= 0.21945353902013082 idx= (np.int64(16), np.int64(11), np.int64(124), np.int64(50))
# selected elements: 675
# ------------
# cluster= 81
# amplitude= 0.2179461247835553 idx= (np.int64(6), np.int64(10), np.int64(179), np.int64(124))
# selected elements: 593
# ------------
# cluster= 82
# amplitude= 0.2161906738914004 idx= (np.int64(8), np.int64(8), np.int64(164), np.int64(90))
# selected elements: 827
# ------------
# cluster= 83
# amplitude= 0.21603736549679275 idx= (np.int64(12), np.int64(6), np.int64(30), np.int64(120))
# selected elements: 1130
# ------------
# cluster= 84
# amplitude= 0.21488779863806962 idx= (np.int64(20), np.int64(1), np.int64(88), np.int64(100))
# selected elements: 712
# ------------
# cluster= 85
# amplitude= 0.21421493397999247 idx= (np.int64(14), np.int64(9), np.int64(150), np.int64(144))
# selected elements: 692
# ------------
# cluster= 86
# amplitude= 0.2135387111742394 idx= (np.int64(10), np.int64(1), np.int64(128), np.int64(134))
# selected elements: 457
# ------------
# cluster= 87
# amplitude= 0.21330244154938333 idx= (np.int64(11), np.int64(17), np.int64(229), np.int64(83))
# selected elements: 1747
# ------------
# cluster= 88
# amplitude= 0.2126377167568562 idx= (np.int64(14), np.int64(11), np.int64(155), np.int64(138))
# selected elements: 387
# ------------
# cluster= 89
# amplitude= 0.21256470016267104 idx= (np.int64(21), np.int64(1), np.int64(27), np.int64(42))
# selected elements: 418
# ------------
# cluster= 90
# amplitude= 0.21230759922768414 idx= (np.int64(21), np.int64(2), np.int64(117), np.int64(58))
# selected elements: 414
# ------------
# cluster= 91
# amplitude= 0.21212890381400318 idx= (np.int64(19), np.int64(7), np.int64(25), np.int64(108))
# selected elements: 272
# ------------
# cluster= 92
# amplitude= 0.2118916637890723 idx= (np.int64(4), np.int64(5), np.int64(19), np.int64(25))
# selected elements: 1320
# ------------
# cluster= 93
# amplitude= 0.21167078586722113 idx= (np.int64(20), np.int64(11), np.int64(142), np.int64(107))
# selected elements: 359
# ------------
# cluster= 94
# amplitude= 0.21032720750749206 idx= (np.int64(21), np.int64(1), np.int64(23), np.int64(132))
# selected elements: 193
# ------------
# cluster= 95
# amplitude= 0.21010807394897366 idx= (np.int64(13), np.int64(8), np.int64(147), np.int64(143))
# selected elements: 375
# ------------
# cluster= 96
# amplitude= 0.20998842745794474 idx= (np.int64(12), np.int64(8), np.int64(32), np.int64(116))
# selected elements: 419
# ------------
# cluster= 97
# amplitude= 0.20810548174988577 idx= (np.int64(19), np.int64(11), np.int64(206), np.int64(117))
# selected elements: 169
# ------------
# cluster= 98
# amplitude= 0.2077154454344313 idx= (np.int64(16), np.int64(7), np.int64(37), np.int64(39))

# %% [markdown]
# 3060 s => 2450 s

# %% [markdown]
# ## Trimming the beginning and the end

# %%
# %%
from __future__ import annotations

from pathlib import Path
from typing import Tuple, Dict, Any, List

import gc
import copy

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset

from juwavelet import transform, utils, plot_utils

try:
    from scipy import stats
except Exception:
    stats = None


# ==========================
# CHANGES (summary)
# ==========================
# 1) Trim leading and trailing columns that are initially all NaN (or non finite) in the RAW frame
#    This happens BEFORE flatten_swath fills NaNs, so you do not carry fake empty edge columns
#    Helps first and last slice not include empty padding
#
# 2) X_OFFSET is interpreted in ORIGINAL x coordinates (global)
#    After trimming, it is converted to trimmed local coordinates and clamped
#
# 3) Stitching uses global x start for correct x axis after trimming
#    slice results carry x_start_unbinned_global
#
# 4) True plotting disable
#    Plotting functions return immediately when saving is off
#
# 5) Stitched plot saving can be fully disabled
#    stitch_and_save_final_09 returns immediately if SAVE_STITCHED_PLOT is False
#
# 6) Red noise diagnostics writing can be disabled
#    No per slice text output when SAVE_REDNOISE_DIAGNOSTICS is False
#
# 7) Red noise filter no longer deep copies the entire cwt dict
#    It shallow copies the dict and copies only decomposition
#
# 8) Fixed batch loop bug
#    continuelo -> continue


# --------------------------
# User params
# --------------------------
INPUT_FOLDER = Path("l3")
FILE_GLOB = "*.nc"

OUTPUT_ROOT = Path("outputs_decompose2d_slices_single_noise_filtering_AUTO_BATCH")
SAVE_DPI = 200

OUTPUT_L6_FOLDER = INPUT_FOLDER.parent / "l6"

FRAME_IDX = 0

X_CHUNK = 600
Y_SLICE = slice(None, None)
SLICE_PAD = 50

X_OFFSET = 0

REMOVE_TREND = True
STANDARDIZE = False
GAUSS_BLUR_SIGMA = 0.0

APPLY_BINNING = True
BIN_FACTOR = 2

APPLY_TAPER = True
TAPER_EDGE_PIXELS = 10

S0 = 16
DJ = 1 / 8
JS = 24
JT = 18
ASPECT = 1

DX_KM_BASE = 2.0
DY_KM_BASE = 2.0

N_SHOW = 6

AMP_MIN_FRACTION_OF_CLUSTER_MAX = 0.10
QUIVER_STEP_X = 20
QUIVER_STEP_Y = 20
QUIVER_SCALE = 1

APPLY_RED_NOISE_FILTER = True

# Turn these on only if you actually want files written
SAVE_REDNOISE_DIAGNOSTICS = False
SAVE_SLICE_PLOTS = False
SAVE_STITCHED_PLOT = True


# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update(
    {
        "axes.labelsize": 16,
        "font.size": 16,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
        "figure.figsize": [2 * 6.94, 2 * 4.29],
    }
)


# --------------------------
# Small helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path, *, enable: bool = True) -> None:
    """
    Save and close a figure if enable=True.
    Always closes the figure to avoid matplotlib memory buildup.
    """
    try:
        if enable:
            outpath.parent.mkdir(parents=True, exist_ok=True)
            fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    finally:
        plt.close(fig)


def cleanup_memory() -> None:
    try:
        plt.close("all")
    except Exception:
        pass
    gc.collect()


def _fmt(v: float) -> str:
    if not np.isfinite(v):
        return "∞"
    v = float(v)
    if abs(v) >= 1000 or abs(v) < 0.1:
        return f"{v:.2e}"
    if abs(v) >= 100:
        return f"{v:.0f}"
    return f"{v:.1f}"


def diverging_limits(*arrays: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    vals = []
    for A in arrays:
        if A is None:
            continue
        a = np.asarray(A)
        good = np.isfinite(a)
        if np.any(good):
            vals.append(a[good].ravel())
    if not vals:
        return (-1.0, 1.0)
    stacked = np.concatenate(vals)
    lo, hi = np.nanpercentile(stacked, [p_lo, p_hi])
    vmax = max(abs(lo), abs(hi))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    return (-vmax, vmax)


def trim_all_nan_edge_columns(Z: np.ndarray) -> Tuple[np.ndarray, int, int]:
    """
    Trim leading and trailing columns that are entirely non finite (all NaN or inf) in the raw 2D frame.
    Returns Z_trimmed, x0, x1_exclusive where x0 is the first kept column index in the original Z.
    """
    if Z.ndim != 2:
        raise ValueError(f"Expected 2D array, got {Z.shape}")

    col_has_data = np.any(np.isfinite(Z), axis=0)
    if not np.any(col_has_data):
        return Z, 0, Z.shape[1]

    x0 = int(np.argmax(col_has_data))
    x1 = int(len(col_has_data) - np.argmax(col_has_data[::-1]))
    return Z[:, x0:x1], x0, x1


# --------------------------
# Product detection + RUNS
# --------------------------
def detect_product_type(file_path: Path) -> str:
    name = file_path.name.lower()
    if "_l3a_" in name:
        return "l3a"
    if "_l3c_" in name:
        return "l3c"
    if "_l5c_" in name:
        return "l5c"
    raise ValueError(f"Cannot detect product type from file name: {file_path.name}")


def get_runs_for_product(product_type: str) -> List[Dict[str, Any]]:
    if product_type == "l3a":
        return [
            dict(
                name="base",
                MIN_AMP=1.25,
                THR=0.6,
                WHITE_NOISE_THRESHOLD=0.1,
                WPS_NOISE_THRESHOLD=8.0,
            ),
        ]
    return [
        dict(
            name="base",
            MIN_AMP=0.2,
            THR=0.15,
            WHITE_NOISE_THRESHOLD=0.02,
            WPS_NOISE_THRESHOLD=8.0,
        ),
    ]

# --------------------------
# Data helpers
# --------------------------
def read_frame(path: str | Path, frame_idx: int, product_type: str) -> np.ndarray:
    with Dataset(str(path), "r") as nc:
        varname = "Temperature" if product_type == "l3a" else "Radiance"
        data = nc.variables[varname][:]  # (t, y, x)

    if data.ndim != 3:
        raise ValueError(f"{varname} expected 3D (t,y,x); got {data.shape}")

    if not (0 <= frame_idx < data.shape[0]):
        raise IndexError(f"FRAME_IDX={frame_idx} out of range 0..{data.shape[0]-1}")

    return np.asarray(data[frame_idx, :, :], dtype=float)


def flatten_swath(Z: np.ndarray, target_ny: int = 300) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


def bin2d_block_mean(Z: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return Z
    f = int(factor)
    ny, nx = Z.shape
    ny2 = (ny // f) * f
    nx2 = (nx // f) * f
    if ny2 == 0 or nx2 == 0:
        raise ValueError(f"Binning factor {f} too large for array {Z.shape}")
    Z2 = Z[:ny2, :nx2]
    return Z2.reshape(ny2 // f, f, nx2 // f, f).mean(axis=(1, 3))


def unbin_repeat_xy(A: np.ndarray, factor: int) -> np.ndarray:
    if factor is None or int(factor) <= 1:
        return A
    f = int(factor)
    return np.repeat(np.repeat(A, f, axis=0), f, axis=1)


def fit_plane(Z: np.ndarray) -> np.ndarray:
    ny, nx = Z.shape
    yy, xx = np.mgrid[0:ny, 0:nx]
    G = np.stack([xx.ravel(), yy.ravel(), np.ones(nx * ny)], axis=1)
    coeff, *_ = np.linalg.lstsq(G, Z.ravel(), rcond=None)
    return coeff[0] * xx + coeff[1] * yy + coeff[2]


def extract_first_fourier_bg(Z: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    ny, nx = Z.shape
    F = np.fft.fft2(Z)
    F_bg = np.zeros_like(F, dtype=complex)

    if nx > 1:
        F_bg[0, 1] = F[0, 1]
        F_bg[0, -1] = F[0, -1]
    if ny > 1:
        F_bg[1, 0] = F[1, 0]
        F_bg[-1, 0] = F[-1, 0]

    bg = np.fft.ifft2(F_bg).real
    return bg, Z - bg


def maybe_blur(Z: np.ndarray, sigma: float) -> np.ndarray:
    if sigma <= 0:
        return Z
    try:
        from scipy.ndimage import gaussian_filter
    except Exception:
        return Z
    return gaussian_filter(Z, sigma=float(sigma))


def _hanning_edge_1d(n: int, edge: int) -> np.ndarray:
    w = np.ones(n, dtype=float)
    if edge <= 0:
        return w
    edge = min(edge, n // 2)
    ramp = 0.5 * (1.0 - np.cos(np.linspace(0, np.pi, edge, endpoint=True)))
    w[:edge] = ramp
    w[-edge:] = ramp[::-1]
    return w


def apply_edge_hanning_taper(Z: np.ndarray, edge: int) -> np.ndarray:
    if edge <= 0:
        return Z
    ny, nx = Z.shape
    wx = _hanning_edge_1d(nx, edge)
    wy = _hanning_edge_1d(ny, edge)
    W = np.outer(wy, wx)
    return Z * W


def effective_lambda(cwt: dict, s_idx: int, t_idx: int) -> Tuple[float, float, float]:
    lamx = float(cwt["wavelength_x"][s_idx, t_idx])
    lamy = float(cwt["wavelength_y"][s_idx, t_idx])
    inv2 = 0.0
    if np.isfinite(lamx) and lamx != 0:
        inv2 += (1.0 / lamx) ** 2
    if np.isfinite(lamy) and lamy != 0:
        inv2 += (1.0 / lamy) ** 2
    lam = np.inf if inv2 == 0 else 1.0 / np.sqrt(inv2)
    return lamx, lamy, lam


def compute_cluster_power_table(cwt: dict, iwave: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]
    power4d = np.abs(dec) ** 2

    cluster_ids = np.unique(iwave[iwave >= 0]).astype(int)
    if cluster_ids.size == 0:
        return cluster_ids, np.array([]), np.array([])

    P_abs = np.zeros(cluster_ids.size, dtype=float)
    for i, kcl in enumerate(cluster_ids):
        P_abs[i] = float(np.sum(power4d[iwave == kcl]))

    total = float(np.sum(P_abs))
    if total > 0 and np.isfinite(total):
        P_pct = 100.0 * P_abs / total
    else:
        P_pct = np.full_like(P_abs, np.nan)

    return cluster_ids, P_abs, P_pct


def cluster_amp_theta_maps(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_min_fraction_of_cluster_max: float = 0.2,
) -> Tuple[np.ndarray, np.ndarray]:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power = np.abs(dec) ** 2

    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan), np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power.shape
    power2 = power.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    valid = np.isfinite(pmax) & (pmax > 0)

    A = np.full(nx * ny, np.nan, dtype=float)
    theta = np.full(nx * ny, np.nan, dtype=float)

    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        t_idx = arg % nt

        A_valid = np.sqrt(pmax[valid])
        theta_valid = np.asarray(cwt["theta"], dtype=float)[t_idx]

        A[valid] = A_valid
        theta[valid] = theta_valid

    A_xy = A.reshape(nx, ny).T
    theta_xy = theta.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(amp_min_fraction_of_cluster_max) * float(np.nanmax(A_xy))
        low = A_xy < thr
        A_xy[low] = np.nan
        theta_xy[low] = np.nan

    return A_xy, theta_xy


def theta_to_uv(theta_xy: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    return np.cos(theta_xy), np.sin(theta_xy)


# --------------------------
# Red noise style filtering helper
# --------------------------
def apply_red_noise_filter_cwt(
    cwt: dict,
    white_noise_threshold: float = 0.1,
    wps_noise_threshold: float = 8.0,
) -> Tuple[dict, Dict[str, Any]]:
    """
    Robust per scale WPS filtering.
    Returns filtered_cwt and diagnostics.

    Change: no deepcopy of entire cwt dict.
    Only decomposition is copied since that is what we mutate.
    """
    diag: Dict[str, Any] = {}
    if stats is None:
        diag["skipped"] = True
        diag["reason"] = "scipy not available"
        return cwt, diag

    cwt_copy = dict(cwt)
    dec0 = cwt["decomposition"]
    dec = dec0.copy()
    cwt_copy["decomposition"] = dec

    WPS0 = np.abs(dec) ** 2
    diag["n_coeff_total"] = int(WPS0.size)

    mask_1 = WPS0 < (float(white_noise_threshold) ** 2)
    dec[mask_1] = 0

    WPS1 = np.abs(dec) ** 2
    diag["n_zero_after_white"] = int(np.count_nonzero(WPS1 == 0))

    median_WPS = np.median(WPS1, axis=(1, 2, 3))  # (ns,)
    mad = stats.median_abs_deviation(WPS1, axis=(1, 2, 3), scale=1.0)  # (ns,)
    sMAD_WPS = 1.4826 * mad

    sMAD_safe = np.where(sMAD_WPS > 0, sMAD_WPS, np.nan)
    WPS_scaled = (WPS1 - median_WPS[:, None, None, None]) / sMAD_safe[:, None, None, None]

    mask = WPS_scaled < float(wps_noise_threshold)
    dec[mask] = 0

    WPS2 = np.abs(dec) ** 2
    diag["n_zero_after_scaled"] = int(np.count_nonzero(WPS2 == 0))

    finite_scaled = np.isfinite(WPS_scaled)

    diag["sMAD_min"] = float(np.nanmin(sMAD_WPS))
    diag["sMAD_median"] = float(np.nanmedian(sMAD_WPS))

    if np.any(finite_scaled):
        diag["WPS_scaled_min"] = float(np.nanmin(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_median"] = float(np.nanmedian(WPS_scaled[finite_scaled]))
        diag["WPS_scaled_max"] = float(np.nanmax(WPS_scaled[finite_scaled]))
    else:
        diag["WPS_scaled_min"] = np.nan
        diag["WPS_scaled_median"] = np.nan
        diag["WPS_scaled_max"] = np.nan

    return cwt_copy, diag


# --------------------------
# Quicklook plots (true no op if not saving)
# --------------------------
def quicklook_save(
    x1d: np.ndarray,
    y1d: np.ndarray,
    Z: np.ndarray,
    title: str,
    outpath: Path,
    *,
    save_plots: bool,
) -> None:
    if not save_plots:
        return
    fig, ax = plt.subplots()
    im = ax.pcolormesh(x1d, y1d, Z, shading="auto", cmap="gray")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04).set_label("arb")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    save_fig(fig, outpath, enable=True)


def quicklook_background_decomp_4panel_save(
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    original: np.ndarray,
    background: np.ndarray,
    remaining: np.ndarray,
    remaining_tapered: np.ndarray,
    taper_edge_px: int,
    outpath: Path,
    *,
    wavy_after_noise_xy: np.ndarray | None = None,
    save_plots: bool,
) -> None:
    if not save_plots:
        return

    med = np.nanmedian(original)
    orig_c = original - med
    bg_c = background - med
    rem_c = remaining
    rem_tapered_c = remaining_tapered

    arrays = [orig_c, bg_c, rem_c, rem_tapered_c]
    if wavy_after_noise_xy is not None:
        arrays.append(wavy_after_noise_xy)

    vmin, vmax = diverging_limits(*arrays, p_lo=1, p_hi=99)

    fig, axs = plt.subplots(2, 3, figsize=(16, 10), constrained_layout=True)
    axs = axs.flatten()

    panels = [
        (orig_c, "Original (median sub)"),
        (bg_c, "Background (plane + first Fourier)"),
        (rem_c, "Remaining = original - background"),
        (rem_tapered_c, f"Remaining with edge taper (width={taper_edge_px})"),
    ]

    if wavy_after_noise_xy is not None:
        panels.append((wavy_after_noise_xy, "Wavy stuff (wavelet reconstruction after noise filtering)"))

    im0 = None
    for ax, (Zp, title) in zip(axs, panels):
        im0 = ax.pcolormesh(x1d_km, y1d_km, Zp, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
        ax.set_title(title)
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_aspect("equal", adjustable="box")

    for ax in axs[len(panels) :]:
        ax.axis("off")

    cbar = fig.colorbar(im0, ax=axs[: len(panels)], orientation="vertical", fraction=0.04, pad=0.02)
    cbar.set_label("arb")
    save_fig(fig, outpath, enable=True)


def plot_cluster_individual_save(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    x1d_km: np.ndarray,
    y1d_km: np.ndarray,
    orig_decomp: np.ndarray,
    bg_xy: np.ndarray,
    dx_km: float,
    dy_km: float,
    outpath: Path,
    *,
    save_plots: bool,
) -> None:
    if not save_plots:
        return

    decomposition = cwt["decomposition"]
    decomposition[:] = orig_decomp
    decomposition[iwave != kcl] = 0

    rec = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_xy = rec.T - np.median(rec)

    A_xy, theta_xy = cluster_amp_theta_maps(
        cwt, iwave, kcl, amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX
    )

    dec0 = orig_decomp
    power0 = np.abs(dec0) ** 2
    mask4d = (iwave == kcl)
    ns, nt, nx, ny = power0.shape

    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)
    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    valid = np.isfinite(pmax) & (pmax > 0)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])
        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if np.isfinite(np.nanmax(A_xy)):
        thr = float(AMP_MIN_FRACTION_OF_CLUSTER_MAX) * float(np.nanmax(A_xy))
        lam_xy[A_xy < thr] = np.nan

    bg_vmin, bg_vmax = diverging_limits(bg_xy, p_lo=2, p_hi=98)
    cl_vmin, cl_vmax = diverging_limits(rec_xy, p_lo=2, p_hi=98)

    theta_vals = np.asarray(cwt["theta"], dtype=float)
    theta_min = float(np.nanmin(theta_vals))
    theta_max = float(np.nanmax(theta_vals))

    if np.any(np.isfinite(lam_xy)):
        lam_vmin, lam_vmax = np.nanpercentile(lam_xy, [5, 95])
        if (not np.isfinite(lam_vmin)) or (not np.isfinite(lam_vmax)) or (lam_vmin == lam_vmax):
            lam_vmin = float(np.nanmin(lam_xy))
            lam_vmax = float(np.nanmax(lam_xy))
    else:
        lam_vmin, lam_vmax = 0.0, 1.0

    fig, axs = plt.subplots(2, 2, figsize=(16, 11), constrained_layout=True)
    ax00, ax01, ax10, ax11 = axs[0, 0], axs[0, 1], axs[1, 0], axs[1, 1]

    ax00.pcolormesh(x1d_km, y1d_km, bg_xy, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
    im00 = ax00.pcolormesh(
        x1d_km, y1d_km, rec_xy, shading="auto", cmap="RdBu_r", vmin=cl_vmin, vmax=cl_vmax, alpha=0.6
    )
    ax00.set_title(f"Cluster {kcl} overlay")
    ax00.set_xlabel("x (km)")
    ax00.set_ylabel("y (km)")
    ax00.set_aspect("equal", adjustable="box")
    fig.colorbar(im00, ax=ax00, fraction=0.046, pad=0.02)

    im01 = ax01.pcolormesh(x1d_km, y1d_km, A_xy, shading="auto", cmap="plasma")
    n_pix = int(np.count_nonzero(np.isfinite(A_xy)))
    area_km2 = n_pix * float(dx_km) * float(dy_km)
    ax01.set_title("A(x,y) = max |coeff| in cluster\n" + rf"Area = {area_km2:.0f} km$^2$ ({n_pix} px)")
    ax01.set_xlabel("x (km)")
    ax01.set_ylabel("y (km)")
    ax01.set_aspect("equal", adjustable="box")
    fig.colorbar(im01, ax=ax01, fraction=0.046, pad=0.02)

    im10 = ax10.pcolormesh(x1d_km, y1d_km, lam_xy, shading="auto", cmap="viridis", vmin=lam_vmin, vmax=lam_vmax)
    if np.any(np.isfinite(lam_xy)):
        lam_med = float(np.nanmedian(lam_xy))
        lam_p10, lam_p90 = np.nanpercentile(lam_xy, [10, 90])
        ax10.set_title(
            r"Dominant $\lambda(x,y)$ in cluster" + "\n"
            + rf"median={_fmt(lam_med)} km (10–90%: {_fmt(lam_p10)}–{_fmt(lam_p90)} km)"
        )
    else:
        ax10.set_title(r"Dominant $\lambda(x,y)$ in cluster")
    ax10.set_xlabel("x (km)")
    ax10.set_ylabel("y (km)")
    ax10.set_aspect("equal", adjustable="box")
    fig.colorbar(im10, ax=ax10, fraction=0.046, pad=0.02).set_label("km")

    im11 = ax11.pcolormesh(x1d_km, y1d_km, theta_xy, shading="auto", cmap="PiYG", vmin=theta_min, vmax=theta_max)
    ax11.set_title("θ(x,y) + quiver")
    ax11.set_xlabel("x (km)")
    ax11.set_ylabel("y (km)")
    ax11.set_aspect("equal", adjustable="box")
    fig.colorbar(im11, ax=ax11, fraction=0.046, pad=0.02)

    if np.any(np.isfinite(theta_xy)):
        u, v = theta_to_uv(theta_xy)
        arrow_len_km = 40.0
        u = u * arrow_len_km
        v = v * arrow_len_km

        Xq, Yq = np.meshgrid(x1d_km, y1d_km)
        Xqs = Xq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        Yqs = Yq[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        uqs = u[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        vqs = v[::QUIVER_STEP_Y, ::QUIVER_STEP_X]
        good = np.isfinite(uqs) & np.isfinite(vqs)
        ax11.quiver(
            Xqs[good],
            Yqs[good],
            uqs[good],
            vqs[good],
            angles="xy",
            scale_units="xy",
            scale=QUIVER_SCALE,
            width=0.0025,
        )

    save_fig(fig, outpath, enable=True)


# --------------------------
# Cluster products (for L6C/L6A outputs)
# --------------------------
def cluster_dominant_lambda_map(
    cwt: dict,
    iwave: np.ndarray,
    kcl: int,
    amp_mask_xy: np.ndarray | None = None,
) -> np.ndarray:
    dec = cwt["decomposition"]  # (ns, nt, nx, ny) complex
    power0 = np.abs(dec) ** 2
    mask4d = (iwave == kcl)
    if not np.any(mask4d):
        ny = dec.shape[3]
        nx = dec.shape[2]
        return np.full((ny, nx), np.nan)

    ns, nt, nx, ny = power0.shape
    power2 = power0.reshape(ns * nt, nx * ny)
    mask2 = mask4d.reshape(ns * nt, nx * ny)

    p = np.where(mask2, power2, -np.inf)
    pmax = np.max(p, axis=0)
    valid = np.isfinite(pmax) & (pmax > 0)

    lam_xy = np.full(nx * ny, np.nan, dtype=float)
    if np.any(valid):
        arg = np.argmax(p[:, valid], axis=0)
        s_idx = arg // nt
        t_idx = arg % nt

        lamx = np.asarray(cwt["wavelength_x"], dtype=float)[s_idx, t_idx]
        lamy = np.asarray(cwt["wavelength_y"], dtype=float)[s_idx, t_idx]

        inv2 = np.zeros_like(lamx, dtype=float)
        goodx = np.isfinite(lamx) & (lamx != 0)
        goody = np.isfinite(lamy) & (lamy != 0)
        inv2[goodx] += (1.0 / lamx[goodx]) ** 2
        inv2[goody] += (1.0 / lamy[goody]) ** 2

        lam = np.full_like(inv2, np.nan, dtype=float)
        ok = inv2 > 0
        lam[ok] = 1.0 / np.sqrt(inv2[ok])

        lam_xy[valid] = lam

    lam_xy = lam_xy.reshape(nx, ny).T

    if amp_mask_xy is not None:
        lam_xy[~np.isfinite(amp_mask_xy)] = np.nan

    return lam_xy


def copy_lxc_to_l6x_with_clusters(
    lxc_path: str | Path,
    l6x_path: str | Path,
    clusters: List[Dict[str, Any]],
    y_dim: int,
    x_dim: int,
    unbin_factor: int = 1,
    product_type: str = "l5c",
) -> None:
    def _unbin_repeat_xy_local(A: np.ndarray, factor: int) -> np.ndarray:
        if factor is None or int(factor) <= 1:
            return A
        f = int(factor)
        return np.repeat(np.repeat(A, f, axis=0), f, axis=1)

    lxc_path = Path(lxc_path)
    l6x_path = Path(l6x_path)
    l6x_path.parent.mkdir(parents=True, exist_ok=True)

    ncl = int(len(clusters))
    has_rec = any((c.get("rec_xy", None) is not None) for c in clusters)

    fup = int(unbin_factor) if (unbin_factor is not None and int(unbin_factor) > 1) else 1
    y_dim_w = int(y_dim) * fup
    x_dim_w = int(x_dim) * fup

    with Dataset(lxc_path, "r") as src, Dataset(l6x_path, "w", format="NETCDF4") as dst:
        dst.setncatts({k: src.getncattr(k) for k in src.ncattrs()})

        for dname, dim in src.dimensions.items():
            dst.createDimension(dname, (len(dim) if not dim.isunlimited() else None))

        for vname, var in src.variables.items():
            out = dst.createVariable(
                vname,
                var.datatype,
                var.dimensions,
                zlib=True,
                complevel=4,
                fill_value=getattr(var, "_FillValue", None),
            )
            out.setncatts({k: var.getncattr(k) for k in var.ncattrs()})
            out[:] = var[:]

        dst.createDimension("cluster", ncl)
        dst.createDimension("y_cluster", y_dim_w)
        dst.createDimension("x_cluster", x_dim_w)

        v_slice = dst.createVariable("SlicesNo", "i4", ("cluster",), zlib=True, complevel=4)
        v_area = dst.createVariable("Area", "f4", ("cluster",), zlib=True, complevel=4)
        v_pabs = dst.createVariable("ClusterPowerAbs", "f8", ("cluster",), zlib=True, complevel=4)
        v_ppct = dst.createVariable("ClusterPowerPct", "f4", ("cluster",), zlib=True, complevel=4)

        v_amp = dst.createVariable(
            "Amplitude",
            "f4",
            ("cluster", "y_cluster", "x_cluster"),
            zlib=True,
            complevel=4,
            fill_value=np.float32(np.nan),
        )
        v_lam = dst.createVariable(
            "DominantWavelength",
            "f4",
            ("cluster", "y_cluster", "x_cluster"),
            zlib=True,
            complevel=4,
            fill_value=np.float32(np.nan),
        )
        v_ang = dst.createVariable(
            "Angle",
            "f4",
            ("cluster", "y_cluster", "x_cluster"),
            zlib=True,
            complevel=4,
            fill_value=np.float32(np.nan),
        )

        v_rec = None
        if has_rec:
            v_rec = dst.createVariable(
                "ClusterReconstruction",
                "f4",
                ("cluster", "y_cluster", "x_cluster"),
                zlib=True,
                complevel=4,
                fill_value=np.float32(np.nan),
            )
            v_rec.units = "arb"
            v_rec.long_name = "Per cluster wavelet reconstruction map (relative; median subtracted)"

        v_area.units = "km2"
        v_lam.units = "km"
        v_ang.units = "rad"
        v_slice.long_name = "Slice index (starts at 0) for each cluster"
        v_pabs.units = "arb"
        v_ppct.units = "percent"

        v_amp.units = "K" if product_type == "l3a" else "kR"

        if ncl == 0:
            return

        v_slice[:] = np.asarray([c["slice_no"] for c in clusters], dtype=np.int32)
        v_area[:] = np.asarray([c["area_km2"] for c in clusters], dtype=np.float32)
        v_pabs[:] = np.asarray([c.get("power_abs", np.nan) for c in clusters], dtype=np.float64)
        v_ppct[:] = np.asarray([c.get("power_pct", np.nan) for c in clusters], dtype=np.float32)

        amp_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        lam_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        ang_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32)
        rec_stack = np.full((ncl, y_dim_w, x_dim_w), np.nan, dtype=np.float32) if has_rec else None

        def _force_shape(M: np.ndarray) -> np.ndarray:
            if M.shape == (y_dim_w, x_dim_w):
                return M.astype(np.float32)
            tmp = np.full((y_dim_w, x_dim_w), np.nan, dtype=np.float32)
            yy = min(y_dim_w, M.shape[0])
            xx = min(x_dim_w, M.shape[1])
            tmp[:yy, :xx] = M[:yy, :xx]
            return tmp

        for i, c in enumerate(clusters):
            A = _unbin_repeat_xy_local(c["A_xy"], fup)
            L = _unbin_repeat_xy_local(c["lam_xy"], fup)
            T = _unbin_repeat_xy_local(c["theta_xy"], fup)

            amp_stack[i] = _force_shape(A)
            lam_stack[i] = _force_shape(L)
            ang_stack[i] = _force_shape(T)

            if has_rec and rec_stack is not None and v_rec is not None:
                R = c.get("rec_xy", None)
                if R is not None:
                    R = _force_shape(_unbin_repeat_xy_local(R, fup))
                    rec_stack[i] = R

        v_amp[:] = amp_stack
        v_lam[:] = lam_stack
        v_ang[:] = ang_stack
        if has_rec and v_rec is not None and rec_stack is not None:
            v_rec[:] = rec_stack


def make_output_cluster_path(input_path: str | Path) -> Path:
    p = Path(input_path)
    name = p.name
    if "_l5c_" in name:
        name = name.replace("_l5c_", "_l6c_")
    elif "_l3c_" in name:
        name = name.replace("_l3c_", "_l6c_")
    elif "_l3a_" in name:
        name = name.replace("_l3a_", "_l6a_")
    else:
        name = p.stem + "_clusters.nc"
    return p.with_name(name)


# --------------------------
# Slice pipeline
# --------------------------
def run_pipeline_for_slice(
    rad2d_flat: np.ndarray,
    x_slice: slice,
    outdir: Path,
    x_start_unbinned: int,
    core_start_unbinned: int,
    core_end_unbinned: int,
    x_base_unbinned: int,
    cfg: Dict[str, Any],
    slice_no: int,
    product_type: str,
) -> Dict[str, Any]:
    outdir.mkdir(parents=True, exist_ok=True)
    save_plots = bool(SAVE_SLICE_PLOTS)

    min_amp = float(cfg.get("MIN_AMP"))
    thr = float(cfg.get("THR"))
    white_noise_threshold = float(cfg.get("WHITE_NOISE_THRESHOLD"))
    wps_noise_threshold = float(cfg.get("WPS_NOISE_THRESHOLD"))
    run_name = str(cfg.get("name", "run"))

    STORE_CLUSTER_RECON = True

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        f = int(BIN_FACTOR)
        dx_km = DX_KM_BASE * f
        dy_km = DY_KM_BASE * f
    else:
        f = 1
        dx_km = DX_KM_BASE
        dy_km = DY_KM_BASE

    core_width_unbinned = int(core_end_unbinned - core_start_unbinned)
    core_w_binned = core_width_unbinned // f
    rel0_unbinned = int(core_start_unbinned - x_start_unbinned)
    rel0_binned = rel0_unbinned // f
    rel1_binned = rel0_binned + core_w_binned

    def crop_pad_core(A: np.ndarray) -> np.ndarray:
        nyA, nxA = A.shape
        left = max(0, rel0_binned)
        right = min(nxA, rel1_binned)
        core = A[:, left:right]
        need = core_w_binned - core.shape[1]
        if need > 0:
            core = np.concatenate([core, np.full((nyA, need), np.nan)], axis=1)
        elif need < 0:
            core = core[:, :core_w_binned]
        return core

    raw_win = np.asarray(rad2d_flat[Y_SLICE, x_slice], dtype=float)

    if APPLY_BINNING and int(BIN_FACTOR) > 1:
        raw_win = bin2d_block_mean(raw_win, BIN_FACTOR)

    ny, nx = raw_win.shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    bin_tag = f" (binned {BIN_FACTOR}x{BIN_FACTOR})" if (APPLY_BINNING and int(BIN_FACTOR) > 1) else ""
    label0 = "Temperature" if product_type == "l3a" else "Radiance"

    quicklook_save(
        x1d_km,
        y1d_km,
        raw_win,
        f"{label0} (window, flattened){bin_tag}\n{run_name} MIN_AMP={min_amp} THR={thr}",
        outdir / "00_window.png",
        save_plots=save_plots,
    )

    proc0 = raw_win.astype(float, copy=True)

    if REMOVE_TREND:
        plane = fit_plane(proc0)
        detrended = proc0 - plane
    else:
        plane = np.zeros_like(proc0)
        detrended = proc0

    fourier_bg, _ = extract_first_fourier_bg(detrended)
    background = plane + fourier_bg
    remaining = proc0 - background

    if APPLY_TAPER:
        remaining_tapered = apply_edge_hanning_taper(remaining, TAPER_EDGE_PIXELS)
    else:
        remaining_tapered = remaining.copy()

    proc = remaining_tapered.copy()
    if STANDARDIZE:
        m = float(np.median(proc))
        s = float(np.std(proc))
        proc = (proc - m) / s if s > 0 else (proc - m)
    proc = maybe_blur(proc, GAUSS_BLUR_SIGMA)

    wave_xy = proc.T  # (nx, ny)

    cwt_raw = transform.decompose2d(
        wave_xy, dx=dx_km, dy=dy_km, s0=S0, dj=DJ, js=JS, jt=JT, aspect=ASPECT
    )

    if APPLY_RED_NOISE_FILTER:
        cwt, diag = apply_red_noise_filter_cwt(
            cwt_raw,
            white_noise_threshold=white_noise_threshold,
            wps_noise_threshold=wps_noise_threshold,
        )

        if SAVE_REDNOISE_DIAGNOSTICS:
            lines = []
            lines.append("Red noise filter diagnostics\n\n")
            lines.append(f"name                  = {run_name}\n")
            lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
            lines.append(f"WPS_NOISE_THRESHOLD   = {wps_noise_threshold}\n\n")
            if diag.get("skipped", False):
                lines.append(f"SKIPPED: {diag.get('reason','unknown')}\n")
            else:
                lines.append(f"n_coeff_total        = {diag.get('n_coeff_total')}\n")
                lines.append(f"n_zero_after_white   = {diag.get('n_zero_after_white')}\n")
                lines.append(f"n_zero_after_scaled  = {diag.get('n_zero_after_scaled')}\n")
                lines.append(f"sMAD_WPS min         = {diag.get('sMAD_min')}\n")
                lines.append(f"sMAD_WPS median      = {diag.get('sMAD_median')}\n")
                lines.append(f"WPS_scaled min       = {diag.get('WPS_scaled_min')}\n")
                lines.append(f"WPS_scaled median    = {diag.get('WPS_scaled_median')}\n")
                lines.append(f"WPS_scaled max       = {diag.get('WPS_scaled_max')}\n")
            (outdir / "02a_rednoise_diagnostics.txt").write_text("".join(lines))
    else:
        cwt = cwt_raw

    rec_wavy = transform.reconstruct2d(cwt)  # (nx, ny)
    wavy_xy = rec_wavy.T - np.median(rec_wavy)

    quicklook_background_decomp_4panel_save(
        x1d_km,
        y1d_km,
        proc0,
        background,
        remaining,
        remaining_tapered,
        TAPER_EDGE_PIXELS,
        outdir / "01_background_decomp_5panel.png",
        wavy_after_noise_xy=wavy_xy,
        save_plots=save_plots,
    )

    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=min_amp, thr=thr)
    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    if save_plots:
        cmap_cwt = matplotlib.cm.turbo
        norm_cwt = matplotlib.colors.BoundaryNorm(np.exp(np.linspace(np.log(0.05), np.log(1.0), 10)), cmap_cwt.N)
        fig_cwt, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap_cwt, norm=norm_cwt)
        save_fig(fig_cwt, outdir / "02_decomposition_overview.png", enable=True)

        plot_utils.plot_fov_wavelet_spectrum(cwt, stat="max")
        fig_spec = plt.gcf()
        save_fig(fig_spec, outdir / "03_fov_wavelet_spectrum.png", enable=True)

    bg = remaining_tapered - np.median(remaining_tapered)

    cluster_ids, P_abs, P_pct = compute_cluster_power_table(cwt, iwave)
    if cluster_ids.size == 0:
        (outdir / "NO_CLUSTERS.txt").write_text(
            "No clusters found.\n\n"
            f"Run name: {run_name}\n"
            f"Used MIN_AMP={min_amp}, THR={thr}\n"
            f"Used WHITE_NOISE_THRESHOLD={white_noise_threshold}, WPS_NOISE_THRESHOLD={wps_noise_threshold}\n\n"
            "Try lowering MIN_AMP or THR.\n"
            "If red noise filter is on, try lowering WPS_NOISE_THRESHOLD or WHITE_NOISE_THRESHOLD.\n"
        )
        remaining_core_xy = crop_pad_core(proc)
        nan_core = np.full_like(remaining_core_xy, np.nan)

        cleanup_memory()
        return {
            "has_clusters": False,
            "x_start_unbinned": int(core_start_unbinned),
            "x_start_unbinned_global": int(core_start_unbinned + x_base_unbinned),
            "dx_km": dx_km,
            "dy_km": dy_km,
            "remaining_xy": remaining_core_xy,
            "wavy_xy": nan_core,
            "rec_all_xy": nan_core,
            "cluster_records": [],
        }

    power_abs_map = {int(k): float(p) for k, p in zip(cluster_ids, P_abs)}
    power_pct_map = {int(k): float(p) for k, p in zip(cluster_ids, P_pct)}

    cluster_records: List[Dict[str, Any]] = []
    for kcl in cluster_ids.astype(int):
        kcl = int(kcl)

        A_xy, theta_xy = cluster_amp_theta_maps(
            cwt,
            iwave,
            kcl,
            amp_min_fraction_of_cluster_max=AMP_MIN_FRACTION_OF_CLUSTER_MAX,
        )
        lam_xy = cluster_dominant_lambda_map(cwt, iwave, kcl, amp_mask_xy=A_xy)

        rec_core = None
        if STORE_CLUSTER_RECON:
            decomposition[:] = orig_decomp
            decomposition[iwave != kcl] = 0
            rec = transform.reconstruct2d(cwt)  # (nx, ny)
            rec_xy = rec.T
            rec_xy = rec_xy - np.nanmedian(rec_xy)
            rec_core = crop_pad_core(rec_xy)
            decomposition[:] = orig_decomp

        A_core = crop_pad_core(A_xy)
        th_core = crop_pad_core(theta_xy)
        lam_core = crop_pad_core(lam_xy)

        n_pix = int(np.count_nonzero(np.isfinite(A_core)))
        area_km2 = float(n_pix) * float(dx_km) * float(dy_km)

        cluster_records.append(
            dict(
                slice_no=int(slice_no),
                kcl=kcl,
                area_km2=area_km2,
                power_abs=power_abs_map.get(kcl, np.nan),
                power_pct=power_pct_map.get(kcl, np.nan),
                A_xy=A_core,
                lam_xy=lam_core,
                theta_xy=th_core,
                rec_xy=rec_core,
            )
        )

    order_power = np.argsort(P_abs)[::-1]
    cluster_ids_sorted = cluster_ids[order_power]
    P_abs_sorted = P_abs[order_power]
    P_pct_sorted = P_pct[order_power]

    lines = []
    lines.append("Cluster power ranking (clustered only)\n\n")
    lines.append(f"name = {run_name}\n")
    lines.append(f"MIN_AMP = {min_amp}\n")
    lines.append(f"THR = {thr}\n")
    lines.append(f"WHITE_NOISE_THRESHOLD = {white_noise_threshold}\n")
    lines.append(f"WPS_NOISE_THRESHOLD = {wps_noise_threshold}\n\n")
    lines.append("rank  kcl      P_abs           P_pct\n")
    for r, (kcl, Pk, pk) in enumerate(zip(cluster_ids_sorted, P_abs_sorted, P_pct_sorted), start=1):
        lines.append(f"{r:4d}  {int(kcl):3d}  {Pk: .6e}   {pk:6.2f}%\n")
    (outdir / "04_cluster_power_ranking.txt").write_text("".join(lines))

    n_show = int(min(N_SHOW, cluster_ids_sorted.size))
    biggest = cluster_ids_sorted[:n_show]
    theta_vals = np.asarray(cwt["theta"], dtype=float)

    if save_plots:
        nrow = int(np.ceil(np.sqrt(n_show)))
        ncol = int(np.ceil(n_show / nrow))

        def plot_cluster_grid(kind: str, outname: str) -> None:
            fig, axs = plt.subplots(nrow, ncol, figsize=(12, 10))
            axs = np.atleast_1d(axs).reshape(-1)

            bg_vmin, bg_vmax = diverging_limits(bg, p_lo=2, p_hi=98)
            number_box = {"boxstyle": "square", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}

            for ax, kcl in zip(axs, biggest):
                decomposition[:] = orig_decomp
                decomposition[iwave != kcl] = 0
                rec = transform.reconstruct2d(cwt)
                rec_centered = rec.T - np.median(rec)

                s_idx = int(idxs[kcl][0])
                t_idx = int(idxs[kcl][1])
                _, _, lam = effective_lambda(cwt, s_idx, t_idx)

                theta_dom_rad = float(theta_vals[t_idx])
                theta_dom_deg = (np.degrees(theta_dom_rad) + 180.0) % 180.0

                ii = int(np.where(cluster_ids_sorted == kcl)[0][0])
                Pk = float(P_abs_sorted[ii])
                pk = float(P_pct_sorted[ii])

                if kind == "standalone":
                    ax.pcolormesh(x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0)
                elif kind == "overlay":
                    ax.pcolormesh(x1d_km, y1d_km, bg, shading="auto", cmap="gray", vmin=bg_vmin, vmax=bg_vmax)
                    ax.pcolormesh(
                        x1d_km, y1d_km, rec_centered, shading="auto", cmap="RdBu_r", vmin=-1.0, vmax=1.0, alpha=0.6
                    )
                else:
                    raise ValueError(kind)

                ax.set_title(
                    rf"$\lambda$={_fmt(lam)} km, $\theta$={theta_dom_deg:.0f}$^\circ$"
                    + "\n"
                    + rf"P={Pk:.2e} ({pk:.1f}%)"
                )
                ax.set_aspect("equal", adjustable="box")

            for ax in axs[n_show:]:
                ax.axis("off")
            for ax in axs[:n_show]:
                ax.set_xlabel("x (km)")
                ax.set_ylabel("y (km)")

            for i, ax in enumerate(axs, start=1):
                if ax.has_data():
                    ax.text(0.12, 0.15, str(i), transform=ax.transAxes, bbox=number_box, va="top", ha="right")

            fig.tight_layout()
            save_fig(fig, outdir / outname, enable=True)

        plot_cluster_grid("standalone", "05_clusters_standalone.png")
        plot_cluster_grid("overlay", "06_clusters_overlay.png")

        for kcl in biggest:
            plot_cluster_individual_save(
                cwt=cwt,
                iwave=iwave,
                kcl=int(kcl),
                x1d_km=x1d_km,
                y1d_km=y1d_km,
                orig_decomp=orig_decomp,
                bg_xy=bg,
                dx_km=dx_km,
                dy_km=dy_km,
                outpath=outdir / f"07_cluster_{int(kcl):03d}_maps.png",
                save_plots=True,
            )

    decomposition[:] = orig_decomp
    decomposition[iwave < 0] = 0
    rec_all = transform.reconstruct2d(cwt)  # (nx, ny)
    rec_all_xy = rec_all.T - np.median(rec_all)
    decomposition[:] = orig_decomp

    remaining_after_preproc_xy = proc

    if save_plots:
        vmin, vmax = diverging_limits(remaining_after_preproc_xy, wavy_xy, rec_all_xy, p_lo=2, p_hi=98)

        figR, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(18, 8), constrained_layout=True, sharex=True, sharey=True)

        im1 = ax1.pcolormesh(
            x1d_km, y1d_km, remaining_after_preproc_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax
        )
        ax1.set_title("Remaining (after preprocessing, input to CWT)")
        ax1.set_xlabel("x (km)")
        ax1.set_ylabel("y (km)")
        ax1.set_aspect("equal", adjustable="box")

        im2 = ax2.pcolormesh(x1d_km, y1d_km, wavy_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
        ax2.set_title("Wavy stuff (wavelet reconstruction after noise filtering)")
        ax2.set_xlabel("x (km)")
        ax2.set_ylabel("y (km)")
        ax2.set_aspect("equal", adjustable="box")

        im3 = ax3.pcolormesh(x1d_km, y1d_km, rec_all_xy, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
        ax3.set_title("Reconstruction after clustering (all clusters combined)")
        ax3.set_xlabel("x (km)")
        ax3.set_ylabel("y (km)")
        ax3.set_aspect("equal", adjustable="box")

        cbar = figR.colorbar(im1, ax=[ax1, ax2, ax3], orientation="vertical", fraction=0.015, pad=0.01)
        cbar.set_label("arb")
        save_fig(figR, outdir / "09_remaining_vs_wavy_vs_allclusters.png", enable=True)

    remaining_core_xy = crop_pad_core(remaining_after_preproc_xy)
    wavy_core_xy = crop_pad_core(wavy_xy)
    rec_all_core_xy = crop_pad_core(rec_all_xy)

    try:
        del raw_win, proc0, plane, detrended, fourier_bg, background, remaining, remaining_tapered, proc, wave_xy
        del cwt_raw, cwt, amps, idxs, iwave, decomposition, orig_decomp, rec_wavy, rec_all
        del bg, cluster_ids, P_abs, P_pct, cluster_ids_sorted, P_abs_sorted, P_pct_sorted
    except Exception:
        pass
    cleanup_memory()

    return {
        "has_clusters": True,
        "x_start_unbinned": int(core_start_unbinned),
        "x_start_unbinned_global": int(core_start_unbinned + x_base_unbinned),
        "dx_km": dx_km,
        "dy_km": dy_km,
        "remaining_xy": remaining_core_xy,
        "wavy_xy": wavy_core_xy,
        "rec_all_xy": rec_all_core_xy,
        "cluster_records": cluster_records,
    }


def stitch_and_save_final_09(slice_results: List[Dict[str, Any]], outroot: Path, tag: str, product_type: str) -> None:
    if not SAVE_STITCHED_PLOT:
        return
    if not slice_results:
        return

    slice_results = sorted(slice_results, key=lambda d: int(d.get("x_start_unbinned_global", 0)))

    dx_km = float(slice_results[0]["dx_km"])
    dy_km = float(slice_results[0]["dy_km"])
    x0_unbinned_global = int(slice_results[0].get("x_start_unbinned_global", 0))
    x0_km = x0_unbinned_global * DX_KM_BASE

    remaining_stitched = np.concatenate([d["remaining_xy"] for d in slice_results], axis=1)
    wavy_stitched = np.concatenate([d["wavy_xy"] for d in slice_results], axis=1)
    rec_all_stitched = np.concatenate([d["rec_all_xy"] for d in slice_results], axis=1)

    ny, nx_tot = remaining_stitched.shape
    x1d_km = x0_km + np.arange(nx_tot, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    vmin, vmax = diverging_limits(remaining_stitched, wavy_stitched, rec_all_stitched, p_lo=2, p_hi=98)

    figR, (axT, axM, axB) = plt.subplots(3, 1, figsize=(18, 6), constrained_layout=True, sharex=True, sharey=True)

    imT = axT.pcolormesh(x1d_km, y1d_km, remaining_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axT.set_title(f"STITCHED (core tiles) {tag}: Remaining (after preprocessing, input to CWT)")
    axT.set_xlabel("x (km)")
    axT.set_ylabel("y (km)")
    axT.set_aspect("equal", adjustable="box")

    imM = axM.pcolormesh(x1d_km, y1d_km, wavy_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axM.set_title(f"STITCHED (core tiles) {tag}: Wavy stuff (wavelet reconstruction after noise filtering)")
    axM.set_xlabel("x (km)")
    axM.set_ylabel("y (km)")
    axM.set_aspect("equal", adjustable="box")

    imB = axB.pcolormesh(x1d_km, y1d_km, rec_all_stitched, shading="auto", cmap="RdBu_r", vmin=vmin, vmax=vmax)
    axB.set_title(f"STITCHED (core tiles) {tag}: Reconstruction after clustering (all clusters combined)")
    axB.set_xlabel("x (km)")
    axB.set_ylabel("y (km)")
    axB.set_aspect("equal", adjustable="box")

    cbar = figR.colorbar(imT, ax=[axT, axM, axB], orientation="vertical", fraction=0.012, pad=0.01)
    cbar.set_label("K (Relative)" if product_type == "l3a" else "kRayleigh (Relative)")

    save_fig(
        figR,
        outroot / f"FINAL_09_remaining_vs_wavy_vs_allclusters_STITCHED_{tag}.png",
        enable=True,
    )

    try:
        del remaining_stitched, wavy_stitched, rec_all_stitched
    except Exception:
        pass
    cleanup_memory()


# --------------------------
# Per file runner
# --------------------------
def run_one_file(file_path: Path) -> None:
    product_type = detect_product_type(file_path)
    runs = get_runs_for_product(product_type)

    print("\n========================================")
    print("File:", file_path.name)
    print("Detected product:", product_type)
    print("Runs:", runs)

    rad2d = read_frame(file_path, FRAME_IDX, product_type=product_type)

    # NEW: trim edge columns that are initially all NaN before flatten_swath fills them
    rad2d_trim, x0_trim, x1_trim = trim_all_nan_edge_columns(rad2d)
    x_base_unbinned = int(x0_trim)

    if rad2d_trim.shape[1] != rad2d.shape[1]:
        print(f"Trimmed raw frame columns: kept [{x0_trim}:{x1_trim}] (nx {rad2d.shape[1]} -> {rad2d_trim.shape[1]})")
    else:
        print("No raw edge columns trimmed")

    rad2d_flat = flatten_swath(rad2d_trim, target_ny=300)
    nx_total = rad2d_flat.shape[1]

    # X_OFFSET is in original global coordinates
    x_offset_global = int(X_OFFSET)
    x_offset = x_offset_global - x_base_unbinned
    if x_offset < 0:
        x_offset = 0

    if x_offset >= nx_total:
        raise ValueError(
            f"X_OFFSET={x_offset_global} (global) maps to {x_offset} (trimmed local) "
            f"but nx_total after trimming is {nx_total} in file {file_path.name}"
        )

    for cfg in runs:
        run_name = str(cfg.get("name", "run"))

        outroot = OUTPUT_ROOT / file_path.stem / f"{run_name}_offset_{x_offset_global:04d}"
        outroot.mkdir(parents=True, exist_ok=True)

        (outroot / "RUN_CONFIG.txt").write_text(
            "\n".join([f"{k} = {v}" for k, v in cfg.items()])
            + f"\nproduct_type = {product_type}\nfile = {file_path.name}\n"
            + f"x_trim_kept = [{x0_trim}:{x1_trim}]\n"
            + f"x_base_unbinned = {x_base_unbinned}\n"
            + f"X_OFFSET_global = {x_offset_global}\n"
            + f"X_OFFSET_trimmed_local = {x_offset}\n"
        )

        core_starts = list(range(x_offset, nx_total, X_CHUNK))
        stitch_results: List[Dict[str, Any]] = []
        all_cluster_records: List[Dict[str, Any]] = []

        f = int(BIN_FACTOR) if (APPLY_BINNING and int(BIN_FACTOR) > 1) else 1
        y_dim = int(rad2d_flat[Y_SLICE, :].shape[0] // f)
        x_dim = int(X_CHUNK // f)

        for slice_no, core_start in enumerate(core_starts):
            core_end = min(core_start + X_CHUNK, nx_total)

            ext_start = max(0, core_start - SLICE_PAD)
            ext_end = min(nx_total, core_end + SLICE_PAD)
            x_slice = slice(ext_start, ext_end)

            outdir = outroot / f"xcore_{core_start:05d}_{core_end:05d}_xext_{ext_start:05d}_{ext_end:05d}"
            print(f"[{file_path.name} | {run_name}] core={core_start}:{core_end} ext={ext_start}:{ext_end}")

            res = run_pipeline_for_slice(
                rad2d_flat=rad2d_flat,
                x_slice=x_slice,
                outdir=outdir,
                x_start_unbinned=ext_start,
                core_start_unbinned=core_start,
                core_end_unbinned=core_end,
                x_base_unbinned=x_base_unbinned,
                cfg=cfg,
                slice_no=slice_no,
                product_type=product_type,
            )

            stitch_results.append(res)
            all_cluster_records.extend(res.get("cluster_records", []))

            cleanup_memory()

        stitch_and_save_final_09(
            stitch_results,
            outroot,
            tag=f"{run_name}_offset_{x_offset_global:04d}",
            product_type=product_type,
        )
        print("Done per slice processing. Outputs in", outroot.resolve())

        OUTPUT_L6_FOLDER.mkdir(parents=True, exist_ok=True)
        out_path = OUTPUT_L6_FOLDER / make_output_cluster_path(file_path).name

        copy_lxc_to_l6x_with_clusters(
            lxc_path=file_path,
            l6x_path=out_path,
            clusters=all_cluster_records,
            y_dim=y_dim,
            x_dim=x_dim,
            unbin_factor=(BIN_FACTOR if (APPLY_BINNING and int(BIN_FACTOR) > 1) else 1),
            product_type=product_type,
        )

        print("Saved output with clusters:", out_path.resolve())

    try:
        del rad2d, rad2d_trim, rad2d_flat
    except Exception:
        pass
    cleanup_memory()


# --------------------------
# Batch loop over folder
# --------------------------
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

files = sorted(INPUT_FOLDER.glob(FILE_GLOB))
if not files:
    raise FileNotFoundError(f"No files matched {FILE_GLOB} in {INPUT_FOLDER.resolve()}")

print("Found", len(files), "files in", INPUT_FOLDER.resolve())
print("Will write L6* cluster netCDF to:", OUTPUT_L6_FOLDER.resolve())
print("Will write plot outputs to:", OUTPUT_ROOT.resolve())
print("SAVE_SLICE_PLOTS =", SAVE_SLICE_PLOTS)
print("SAVE_STITCHED_PLOT =", SAVE_STITCHED_PLOT)
print("SAVE_REDNOISE_DIAGNOSTICS =", SAVE_REDNOISE_DIAGNOSTICS)

for fpath in files:
    try:
        run_one_file(fpath)
    except Exception as e:
        print("FAILED:", fpath.name)
        print("Reason:", repr(e))
        cleanup_memory()
        continue

print("\nAll done.")
# Out:
# Found 1 files in /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/l3/OneFile
# Will write L6* cluster netCDF to: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/l3/l6/OneFile
# Will write plot outputs to: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_decompose2d_slices_single_noise_filtering_AUTO_BATCH
# SAVE_SLICE_PLOTS = False
# SAVE_STITCHED_PLOT = True
# SAVE_REDNOISE_DIAGNOSTICS = False
#
# ========================================
# File: awe_l3a_tmp_2024165T1335_03170_v01.nc
# Detected product: l3a
# Runs: [{'name': 'base', 'MIN_AMP': 1.25, 'THR': 0.6, 'WHITE_NOISE_THRESHOLD': 0.1, 'WPS_NOISE_THRESHOLD': 8.0}]
# Trimmed raw frame columns: kept [233:5225] (nx 5451 -> 4992)
# [awe_l3a_tmp_2024165T1335_03170_v01.nc | base] core=0:600 ext=0:650
# ------------
# cluster= 0
# amplitude= 1.3445068132834581 idx= (5, 7, 68, 63)
# selected elements: 10689
# ------------
# cluster= 1
# amplitude= 1.3109188068193292 idx= (0, 14, 16, 140)
# selected elements: 2917
# [awe_l3a_tmp_2024165T1335_03170_v01.nc | base] core=600:1200 ext=550:1250
# [awe_l3a_tmp_2024165T1335_03170_v01.nc | base] core=1200:1800 ext=1150:1850
# ------------
# cluster= 0
# amplitude= 1.5546581699111222 idx= (12, 9, 324, 121)
# selected elements: 27283
# ------------
# cluster= 1
# amplitude= 1.543525747893287 idx= (2, 8, 101, 131)
# selected elements: 5741
# ------------
# cluster= 2
# amplitude= 1.4642339878348365 idx= (5, 12, 332, 138)
# selected elements: 5988
# ------------
# cluster= 3
# amplitude= 1.358142233917481 idx= (2, 12, 297, 11)
# selected elements: 4873
# ------------
# cluster= 4
# amplitude= 1.3509985456049767 idx= (6, 9, 334, 126)
# selected elements: 5046
# ------------
# cluster= 5
# amplitude= 1.3372866844112206 idx= (0, 9, 327, 94)
# selected elements: 694
# ------------
# cluster= 6
# amplitude= 1.3272856775419375 idx= (4, 9, 259, 25)
# selected elements: 5666
# ------------
# cluster= 7
# amplitude= 1.3154584437077028 idx= (11, 10, 48, 135)
# selected elements: 32932
# ------------
# cluster= 8
# amplitude= 1.309543172076154 idx= (13, 9, 211, 64)
# selected elements: 14259
# ------------
# cluster= 9
# amplitude= 1.2924235252385627 idx= (1, 9, 218, 16)
# selected elements: 1664
# ------------
# cluster= 10
# amplitude= 1.2569502727654815 idx= (1, 10, 50, 129)
# selected elements: 3052
# [awe_l3a_tmp_2024165T1335_03170_v01.nc | base] core=1800:2400 ext=1750:2450
# ------------
# cluster= 0
# amplitude= 2.4100732068273913 idx= (5, 10, 328, 53)
# selected elements: 35021
# ------------
# cluster= 1
# amplitude= 2.0306669248923463 idx= (3, 13, 191, 27)
# selected elements: 10907
# ------------
# cluster= 2
# amplitude= 1.8968310379859188 idx= (3, 9, 268, 73)
# selected elements: 4281
# ------------
# cluster= 3
# amplitude= 1.879303533978222 idx= (1, 9, 319, 78)
# selected elements: 4693
# ------------
# cluster= 4
# amplitude= 1.8156921396171968 idx= (6, 10, 257, 92)
# selected elements: 1773
# ------------
# cluster= 5
# amplitude= 1.8113087321153323 idx= (7, 10, 288, 101)
# selected elements: 8461
# ------------
# cluster= 6
# amplitude= 1.7984104711843756 idx= (9, 10, 322, 30)
# selected elements: 13032
# ------------
# cluster= 7
# amplitude= 1.7151143688670054 idx= (4, 10, 257, 90)
# selected elements: 1039
# ------------
# cluster= 8
# amplitude= 1.685481448863896 idx= (23, 9, 275, 138)
# selected elements: 21122
# ------------
# cluster= 9
# amplitude= 1.6844100020738468 idx= (2, 10, 136, 15)
# selected elements: 2880
# ------------
# cluster= 10
# amplitude= 1.6811750245535648 idx= (19, 9, 275, 141)
# selected elements: 19946
# ------------
# cluster= 11
# amplitude= 1.6670189149653418 idx= (0, 4, 155, 34)
# selected elements: 2626
# ------------
# cluster= 12
# amplitude= 1.658378013651494 idx= (0, 10, 190, 28)
# selected elements: 102
# ------------
# cluster= 13
# amplitude= 1.6578159490185838 idx= (0, 8, 310, 129)
# selected elements: 2264
# ------------
# cluster= 14
# amplitude= 1.6136859807632316 idx= (21, 9, 59, 137)
# selected elements: 19614
# ------------
# cluster= 15
# amplitude= 1.6062056565446472 idx= (0, 6, 316, 67)
# selected elements: 735
# ------------
# cluster= 16
# amplitude= 1.591771145480366 idx= (2, 10, 253, 74)
# selected elements: 447
# ------------
# cluster= 17
# amplitude= 1.5801362268830206 idx= (0, 10, 284, 34)
# selected elements: 1435
# ------------
# cluster= 18
# amplitude= 1.5682985849863702 idx= (3, 9, 322, 24)
# selected elements: 2619
# ------------
# cluster= 19
# amplitude= 1.5653290009370562 idx= (0, 10, 156, 44)
# selected elements: 890
# ------------
# cluster= 20
# amplitude= 1.5625811718789102 idx= (12, 9, 27, 121)
# selected elements: 15234
# ------------
# cluster= 21
# amplitude= 1.5441763670452937 idx= (1, 9, 325, 48)
# selected elements: 475
# ------------
# cluster= 22
# amplitude= 1.5319405270042437 idx= (5, 12, 35, 138)
# selected elements: 4406
# ------------
# cluster= 23
# amplitude= 1.52951266955861 idx= (7, 3, 157, 34)
# selected elements: 5443
# ------------
# cluster= 24
# amplitude= 1.482645574428728 idx= (1, 9, 319, 111)
# selected elements: 817
# ------------
# cluster= 25
# amplitude= 1.4751624749987118 idx= (7, 9, 320, 96)
# selected elements: 1364
# ------------
# cluster= 26
# amplitude= 1.4729072714689007 idx= (0, 9, 297, 24)
# selected elements: 854
# ------------
# cluster= 27
# amplitude= 1.4500274763712118 idx= (0, 8, 321, 113)
# selected elements: 185
# ------------
# cluster= 28
# amplitude= 1.4480394540075952 idx= (9, 8, 322, 14)
# selected elements: 2148
# ------------
# cluster= 29
# amplitude= 1.4418753681965537 idx= (3, 10, 289, 95)
# selected elements: 676
# ------------
# cluster= 30
# amplitude= 1.4387590871612694 idx= (3, 8, 323, 49)
# selected elements: 1001
# ------------
# cluster= 31
# amplitude= 1.437538142674286 idx= (1, 9, 311, 90)
# selected elements: 747
# ------------
# cluster= 32
# amplitude= 1.4265798416630837 idx= (0, 17, 154, 36)
# selected elements: 416
# ------------
# cluster= 33
# amplitude= 1.4238302479675335 idx= (2, 7, 68, 87)
# selected elements: 1684
# ------------
# cluster= 34
# amplitude= 1.4232499099679568 idx= (2, 5, 190, 28)
# selected elements: 1935
# ------------
# cluster= 35
# amplitude= 1.4175921241097333 idx= (1, 10, 53, 96)
# selected elements: 892
# ------------
# cluster= 36
# amplitude= 1.4168233641982961 idx= (0, 8, 293, 35)
# selected elements: 321
# ------------
# cluster= 37
# amplitude= 1.4155995224709776 idx= (6, 9, 35, 126)
# selected elements: 2305
# ------------
# cluster= 38
# amplitude= 1.4010962210388058 idx= (2, 9, 267, 12)
# selected elements: 2418
# ------------
# cluster= 39
# amplitude= 1.3910759331807168 idx= (2, 0, 331, 31)
# selected elements: 696
# ------------
# cluster= 40
# amplitude= 1.3885630405101315 idx= (17, 9, 327, 11)
# selected elements: 14919
# ------------
# cluster= 41
# amplitude= 1.3856587072081095 idx= (0, 9, 272, 99)
# selected elements: 573
# ------------
# cluster= 42
# amplitude= 1.3821764395264575 idx= (3, 17, 329, 32)
# selected elements: 2367
# ------------
# cluster= 43
# amplitude= 1.3763409111621805 idx= (9, 12, 334, 33)
# selected elements: 5160
# ------------
# cluster= 44
# amplitude= 1.3619592452133193 idx= (2, 9, 322, 98)
# selected elements: 406
# ------------
# cluster= 45
# amplitude= 1.357961999578812 idx= (0, 7, 337, 43)
# selected elements: 417
# ------------
# cluster= 46
# amplitude= 1.3551673451926571 idx= (0, 1, 189, 27)
# selected elements: 1283
# ------------
# cluster= 47
# amplitude= 1.3452753502129315 idx= (11, 9, 324, 6)
# selected elements: 1623
# ------------
# cluster= 48
# amplitude= 1.337264918735747 idx= (0, 9, 27, 94)
# selected elements: 295
# ------------
# cluster= 49
# amplitude= 1.337219571104934 idx= (2, 10, 306, 64)
# selected elements: 820
# ------------
# cluster= 50
# amplitude= 1.336114583153332 idx= (0, 13, 289, 26)
# selected elements: 688
# ------------
# cluster= 51
# amplitude= 1.3320007032748011 idx= (0, 10, 176, 34)
# selected elements: 415
# ------------
# cluster= 52
# amplitude= 1.3278524673443306 idx= (5, 12, 182, 130)
# selected elements: 2594
# ------------
# cluster= 53
# amplitude= 1.3233428215254173 idx= (4, 8, 321, 72)
# selected elements: 314
# ------------
# cluster= 54
# amplitude= 1.3137541173088314 idx= (2, 11, 193, 114)
# selected elements: 1548
# ------------
# cluster= 55
# amplitude= 1.313026746804016 idx= (0, 8, 313, 96)
# selected elements: 83
# ------------
# cluster= 56
# amplitude= 1.2961779368454902 idx= (9, 10, 283, 118)
# selected elements: 4246
# ------------
# cluster= 57
# amplitude= 1.293988699578175 idx= (0, 7, 323, 78)
# selected elements: 157
# ------------
# cluster= 58
# amplitude= 1.2930550150099445 idx= (0, 17, 332, 31)
# selected elements: 85
# ------------
# cluster= 59
# amplitude= 1.2916289192584116 idx= (3, 3, 326, 13)
# selected elements: 1182
# ------------
# cluster= 60
# amplitude= 1.2884153963046563 idx= (6, 10, 61, 14)
# selected elements: 3061
# ------------
# cluster= 61
# amplitude= 1.2862023125739726 idx= (13, 0, 223, 52)
# selected elements: 11080
# ------------
# cluster= 62
# amplitude= 1.285051082748657 idx= (0, 10, 328, 24)
# selected elements: 274
# ------------
# cluster= 63
# amplitude= 1.2839526809654473 idx= (0, 9, 314, 14)
# selected elements: 86
# ------------
# cluster= 64
# amplitude= 1.2832631132500514 idx= (4, 8, 274, 96)
# selected elements: 1254
# ------------
# cluster= 65
# amplitude= 1.2745009843322068 idx= (2, 3, 321, 115)
# selected elements: 903
# ------------
# cluster= 66
# amplitude= 1.2696796504821766 idx= (1, 5, 177, 120)
# selected elements: 659
# ------------
# cluster= 67
# amplitude= 1.2663725563160229 idx= (0, 9, 131, 19)
# selected elements: 403
# ------------
# cluster= 68
# amplitude= 1.2641548332969845 idx= (0, 10, 186, 103)
# selected elements: 312
# ------------
# cluster= 69
# amplitude= 1.2564901965129749 idx= (4, 11, 335, 9)
# selected elements: 1518
# ------------
# cluster= 70
# amplitude= 1.2553658128125196 idx= (4, 5, 320, 19)
# selected elements: 1416
# ------------
# cluster= 71
# amplitude= 1.2546856663685546 idx= (19, 13, 239, 69)
# selected elements: 11054
# ------------
# cluster= 72
# amplitude= 1.2503933979285207 idx= (1, 9, 238, 19)
# selected elements: 609
# [awe_l3a_tmp_2024165T1335_03170_v01.nc | base] core=2400:3000 ext=2350:3050
# ------------
# cluster= 0
# amplitude= 2.4140955386694367 idx= (5, 10, 28, 53)
# selected elements: 20845
# ------------
# cluster= 1
# amplitude= 2.056788432988007 idx= (14, 14, 90, 33)
# selected elements: 51403
# ------------
# cluster= 2
# amplitude= 1.8801498772810292 idx= (1, 9, 19, 78)
# selected elements: 4228
# ------------
# cluster= 3
# amplitude= 1.7836736213884683 idx= (9, 10, 23, 30)
# selected elements: 10814
# ------------
# cluster= 4
# amplitude= 1.7179154101199805 idx= (6, 9, 17, 95)
# selected elements: 3999
# ------------
# cluster= 5
# amplitude= 1.6103574811068448 idx= (12, 10, 103, 58)
# selected elements: 26366
# ------------
# cluster= 6
# amplitude= 1.6085871094687525 idx= (0, 6, 16, 67)
# selected elements: 787
# ------------
# cluster= 7
# amplitude= 1.6070481802452719 idx= (2, 10, 177, 35)
# selected elements: 3073
# ------------
# cluster= 8
# amplitude= 1.599411894810797 idx= (0, 8, 11, 128)
# selected elements: 1441
# ------------
# cluster= 9
# amplitude= 1.5899795626611406 idx= (0, 9, 44, 74)
# selected elements: 880
# ------------
# cluster= 10
# amplitude= 1.5675663290315893 idx= (3, 9, 22, 24)
# selected elements: 2810
# ------------
# cluster= 11
# amplitude= 1.5612657657356375 idx= (1, 9, 76, 87)
# selected elements: 3061
# ------------
# cluster= 12
# amplitude= 1.5489847458881716 idx= (23, 2, 20, 41)
# selected elements: 24044
# ------------
# cluster= 13
# amplitude= 1.544164307119862 idx= (1, 9, 25, 48)
# selected elements: 578
# ------------
# cluster= 14
# amplitude= 1.507290291622949 idx= (0, 13, 190, 103)
# selected elements: 687
# ------------
# cluster= 15
# amplitude= 1.4831716202020997 idx= (1, 9, 19, 111)
# selected elements: 912
# ------------
# cluster= 16
# amplitude= 1.4500243838327713 idx= (0, 8, 21, 113)
# selected elements: 348
# ------------
# cluster= 17
# amplitude= 1.4455205156348185 idx= (1, 10, 62, 44)
# selected elements: 2193
# ------------
# cluster= 18
# amplitude= 1.4388312174142868 idx= (3, 8, 23, 49)
# selected elements: 931
# ------------
# cluster= 19
# amplitude= 1.4312025518236073 idx= (1, 10, 12, 89)
# selected elements: 197
# ------------
# cluster= 20
# amplitude= 1.4285937297659408 idx= (17, 0, 14, 64)
# selected elements: 8912
# ------------
# cluster= 21
# amplitude= 1.4237743933885427 idx= (12, 9, 86, 101)
# selected elements: 5993
# ------------
# cluster= 22
# amplitude= 1.4075407330514738 idx= (13, 16, 136, 37)
# selected elements: 8744
# ------------
# cluster= 23
# amplitude= 1.3933892263916223 idx= (2, 0, 31, 31)
# selected elements: 798
# ------------
# cluster= 24
# amplitude= 1.3841273215470973 idx= (0, 9, 97, 117)
# selected elements: 409
# ------------
# cluster= 25
# amplitude= 1.3814198534725743 idx= (3, 17, 29, 32)
# selected elements: 2972
# ------------
# cluster= 26
# amplitude= 1.3781391690510896 idx= (9, 12, 34, 35)
# selected elements: 6281
# ------------
# cluster= 27
# amplitude= 1.375521470348438 idx= (9, 8, 23, 15)
# selected elements: 1653
# ------------
# cluster= 28
# amplitude= 1.3715567063543161 idx= (0, 7, 37, 43)
# selected elements: 607
# ------------
# cluster= 29
# amplitude= 1.3618899740219519 idx= (2, 9, 22, 98)
# selected elements: 466
# ------------
# cluster= 30
# amplitude= 1.3616225745934345 idx= (18, 17, 21, 65)
# selected elements: 12695
# ------------
# cluster= 31
# amplitude= 1.3315274518318279 idx= (3, 9, 140, 9)
# selected elements: 1538
# ------------
# cluster= 32
# amplitude= 1.3307013582082432 idx= (1, 9, 90, 37)
# selected elements: 1478
# ------------
# cluster= 33
# amplitude= 1.3119005984982532 idx= (1, 14, 119, 14)
# selected elements: 1054
# ------------
# cluster= 34
# amplitude= 1.2939890001773278 idx= (0, 7, 23, 78)
# selected elements: 279
# ------------
# cluster= 35
# amplitude= 1.2918400545411615 idx= (3, 3, 26, 13)
# selected elements: 1296
# ------------
# cluster= 36
# amplitude= 1.289800560506207 idx= (0, 9, 14, 14)
# selected elements: 225
# ------------
# cluster= 37
# amplitude= 1.2893939898793567 idx= (0, 10, 137, 29)
# selected elements: 488
# ------------
# cluster= 38
# amplitude= 1.2853538922371528 idx= (0, 15, 122, 25)
# selected elements: 271
# ------------
# cluster= 39
# amplitude= 1.2830789932039912 idx= (2, 14, 134, 44)
# selected elements: 1032
# ------------
# cluster= 40
# amplitude= 1.2745198002132403 idx= (2, 3, 21, 115)
# selected elements: 1142
# ------------
# cluster= 41
# amplitude= 1.2714513928002416 idx= (1, 12, 102, 19)
# selected elements: 1299
# ------------
# cluster= 42
# amplitude= 1.2693117123858995 idx= (9, 12, 133, 32)
# selected elements: 5009
# ------------
# cluster= 43
# amplitude= 1.2679528682514118 idx= (0, 10, 66, 135)
# selected elements: 827
# ------------
# cluster= 44
# amplitude= 1.2672703975722501 idx= (1, 10, 116, 37)
# selected elements: 963
# ------------
# cluster= 45
# amplitude= 1.2590590739881264 idx= (5, 9, 187, 18)
# selected elements: 2039
# ------------
# cluster= 46
# amplitude= 1.258010948699778 idx= (4, 5, 20, 19)
# selected elements: 1354
# ------------
# cluster= 47
# amplitude= 1.257291313277999 idx= (4, 11, 35, 9)
# selected elements: 1876
# ------------
# cluster= 48
# amplitude= 1.2569356264313074 idx= (4, 11, 71, 41)
# selected elements: 1328
# ------------
# cluster= 49
# amplitude= 1.2511913908324586 idx= (6, 3, 15, 43)
# selected elements: 3807
# ------------
# cluster= 50
# amplitude= 1.2511379472850075 idx= (1, 10, 153, 28)
# selected elements: 740
# [awe_l3a_tmp_2024165T1335_03170_v01.nc | base] core=3000:3600 ext=2950:3650
# ------------
# cluster= 0
# amplitude= 2.0126458723809244 idx= (0, 2, 331, 94)
# selected elements: 2463
# ------------
# cluster= 1
# amplitude= 1.7192660043178334 idx= (4, 9, 88, 27)
# selected elements: 9616
# ------------
# cluster= 2
# amplitude= 1.598663664883684 idx= (0, 0, 138, 133)
# selected elements: 1029
# ------------
# cluster= 3
# amplitude= 1.5601264422158252 idx= (13, 3, 53, 111)
# selected elements: 22484
# ------------
# cluster= 4
# amplitude= 1.5423338527659969 idx= (15, 2, 51, 111)
# selected elements: 14511
# ------------
# cluster= 5
# amplitude= 1.5301765031641592 idx= (4, 9, 301, 18)
# selected elements: 9050
# ------------
# cluster= 6
# amplitude= 1.496002137367708 idx= (0, 13, 97, 19)
# selected elements: 3495
# ------------
# cluster= 7
# amplitude= 1.4808789431496385 idx= (0, 2, 317, 125)
# selected elements: 1758
# ------------
# cluster= 8
# amplitude= 1.4592694269780877 idx= (0, 0, 331, 84)
# selected elements: 757
# ------------
# cluster= 9
# amplitude= 1.4370114273260308 idx= (7, 9, 300, 65)
# selected elements: 12771
# ------------
# cluster= 10
# amplitude= 1.421424113418496 idx= (10, 10, 114, 11)
# selected elements: 18965
# ------------
# cluster= 11
# amplitude= 1.4078169038955022 idx= (4, 3, 205, 77)
# selected elements: 5263
# ------------
# cluster= 12
# amplitude= 1.3711724051077852 idx= (11, 8, 252, 81)
# selected elements: 12155
# ------------
# cluster= 13
# amplitude= 1.3664848324128402 idx= (10, 8, 118, 120)
# selected elements: 8804
# ------------
# cluster= 14
# amplitude= 1.3550321430758643 idx= (17, 2, 87, 25)
# selected elements: 15891
# ------------
# cluster= 15
# amplitude= 1.3439523876412378 idx= (0, 17, 58, 52)
# selected elements: 811
# ------------
# cluster= 16
# amplitude= 1.3391478037024989 idx= (4, 10, 183, 63)
# selected elements: 5084
# ------------
# cluster= 17
# amplitude= 1.3216072945896782 idx= (0, 5, 326, 82)
# selected elements: 1732
# ------------
# cluster= 18
# amplitude= 1.3083892002383897 idx= (0, 8, 335, 82)
# selected elements: 355
# ------------
# cluster= 19
# amplitude= 1.3072083247988682 idx= (1, 10, 105, 16)
# selected elements: 1322
# ------------
# cluster= 20
# amplitude= 1.2867541397119178 idx= (19, 9, 153, 112)
# selected elements: 23329
# ------------
# cluster= 21
# amplitude= 1.2766815252078059 idx= (0, 0, 58, 52)
# selected elements: 597
# ------------
# cluster= 22
# amplitude= 1.2745042669297921 idx= (0, 9, 93, 33)
# selected elements: 462
# [awe_l3a_tmp_2024165T1335_03170_v01.nc | base] core=3600:4200 ext=3550:4250
# ------------
# cluster= 0
# amplitude= 2.0128808993255576 idx= (0, 2, 31, 94)
# selected elements: 4225
# ------------
# cluster= 1
# amplitude= 2.0042023077668225 idx= (5, 8, 146, 56)
# selected elements: 23700
# ------------
# cluster= 2
# amplitude= 1.6516462003071477 idx= (7, 9, 76, 28)
# selected elements: 40384
# ------------
# cluster= 3
# amplitude= 1.638113024177803 idx= (4, 2, 60, 66)
# selected elements: 10746
# ------------
# cluster= 4
# amplitude= 1.6348407581346982 idx= (7, 9, 190, 52)
# selected elements: 17503
# ------------
# cluster= 5
# amplitude= 1.5784683472645165 idx= (11, 9, 72, 69)
# selected elements: 26983
# ------------
# cluster= 6
# amplitude= 1.5756800847860795 idx= (17, 9, 92, 34)
# selected elements: 46311
# ------------
# cluster= 7
# amplitude= 1.5285799576982066 idx= (1, 10, 76, 64)
# selected elements: 6937
# ------------
# cluster= 8
# amplitude= 1.5031607020684556 idx= (9, 3, 192, 122)
# selected elements: 27869
# ------------
# cluster= 9
# amplitude= 1.4801987601599234 idx= (0, 2, 17, 125)
# selected elements: 2209
# ------------
# cluster= 10
# amplitude= 1.4602888610511786 idx= (0, 0, 31, 84)
# selected elements: 1775
# ------------
# cluster= 11
# amplitude= 1.440550413583274 idx= (2, 0, 49, 73)
# selected elements: 428
# ------------
# cluster= 12
# amplitude= 1.4371054507767758 idx= (2, 8, 110, 72)
# selected elements: 4247
# ------------
# cluster= 13
# amplitude= 1.4122400371743644 idx= (23, 8, 149, 72)
# selected elements: 59791
# ------------
# cluster= 14
# amplitude= 1.3617711075029448 idx= (9, 9, 74, 73)
# selected elements: 3631
# ------------
# cluster= 15
# amplitude= 1.3216116479908062 idx= (0, 5, 26, 82)
# selected elements: 3388
# ------------
# cluster= 16
# amplitude= 1.3210813936851207 idx= (0, 2, 48, 75)
# selected elements: 560
# ------------
# cluster= 17
# amplitude= 1.3198243580763382 idx= (15, 10, 155, 66)
# selected elements: 24589
# ------------
# cluster= 18
# amplitude= 1.3127528399280866 idx= (10, 8, 188, 50)
# selected elements: 7301
# ------------
# cluster= 19
# amplitude= 1.2678185888052562 idx= (3, 9, 49, 33)
# selected elements: 2833
# [awe_l3a_tmp_2024165T1335_03170_v01.nc | base] core=4200:4800 ext=4150:4850
# ------------
# cluster= 0
# amplitude= 1.4460936842946857 idx= (19, 6, 104, 68)
# selected elements: 66696
# [awe_l3a_tmp_2024165T1335_03170_v01.nc | base] core=4800:4992 ext=4750:4992
# ------------
# cluster= 0
# amplitude= 1.7030967315594616 idx= (8, 4, 92, 123)
# selected elements: 14675
# Done per slice processing. Outputs in /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_decompose2d_slices_single_noise_filtering_AUTO_BATCH/awe_l3a_tmp_2024165T1335_03170_v01/base_offset_0000
# Saved output with clusters: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/l3/l6/OneFile/awe_l6a_tmp_2024165T1335_03170_v01.nc
#
# All done.

# %% [markdown]
# ## .py file run_batch_parallel***

# %% [markdown]
# ## Calculating MF using both l6a and l6c

# %%
# %%
"""
ALL-SLICES matching + per-slice combined L6A recon + FULL-ORBIT stitched recon
+ slice Temperature + momentum flux for PASSED clusters only
+ sum MF per slice + stitch MF across orbit
+ output NetCDF contains original L6A global attrs + variables, but ONLY PASSED clusters
  are kept for cluster-dimension variables.

Momentum flux (per cluster pixel, masked to cluster area):
MF = 1/2 * g^2 / N^2 * (lambda_z / lambda_x) * (Amplitude / Temperature)^2 * (1/c^2)

Constants:
g = 9.52 m/s^2
lambda_z = 10 km
c = 1
N^2 = 0.0004 everywhere (synthetic)
u=v=0 everywhere (synthetic)

Key rules:
- SliceNo already exists in L6A, keep it (but subset to passed clusters)
- Area, Amplitude, DominantWavelength, Angle already exist (subset to passed clusters)
- Also slice Temperature into Temp_cluster (passed clusters only)
- Add geodesic Bearing (0 = East, counter-clockwise) as Bearing + Bearing_cluster
- Only save passed clusters (output file cluster vars are subset)
- Add MF_cluster, MF_slice_sum, MF_toprows
"""

from __future__ import annotations

from pathlib import Path
from typing import Dict, Any, List, Tuple

import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset

# --------------------------
# User params
# --------------------------
L6C_PATH = Path("awe_l6c_q20_2024165T2120_03175_v01.nc")  # Radiance-based clusters
L6A_PATH = Path("awe_l6a_tmp_2024165T2120_03175_v01.nc")  # Temperature-based clusters

OUTDIR = Path("outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF")
OUTDIR.mkdir(parents=True, exist_ok=True)
SAVE_DPI = 200

DX_KM = 2.0
DY_KM = 2.0

# ---- Synthetic u,v,N^2 settings ----
TEMP_VAR_NAME = "Temperature"  # variable name in L6A
TIME_INDEX = 0                 # which t index to use when slicing
N2_VALUE = 4e-4                # N=0.02 -> N^2=0.0004
U_VALUE = 0.0
V_VALUE = 0.0

# ---- Momentum flux constants ----
G_MS2 = 9.52
LAMBDA_Z_KM = 10.0
C_CANCEL = 1.0
CP_JKGK = 1005.0

# Output NetCDF
OUT_L6A_PASSED = OUTDIR / f"{L6A_PATH.stem}_PASSED_with_u_v_NS2_Bearing_TempCluster_MF.nc"

# --------------------------
# Matching thresholds (tune)
# --------------------------
MIN_IOU = 0.05
MIN_INTERSECTION_PIX = 50
MAX_LAMBDA_MED_RATIO = 1.25
MAX_ANGLE_DIFF_DEG = 15.0

# Save best match plot even if FAIL (does NOT affect passing)
ASSIGN_BEST_EVEN_IF_FAILS = True


# --------------------------
# Helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def robust_limits(A: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    a = np.asarray(A)
    good = np.isfinite(a)
    if not np.any(good):
        return (-1.0, 1.0)
    lo, hi = np.nanpercentile(a[good], [p_lo, p_hi])
    if (not np.isfinite(lo)) or (not np.isfinite(hi)) or lo == hi:
        lo = float(np.nanmin(a[good]))
        hi = float(np.nanmax(a[good]))
    return (float(lo), float(hi))


def nanpercentile_safe(a: np.ndarray, q: float) -> float:
    good = np.isfinite(a)
    if not np.any(good):
        return np.nan
    return float(np.nanpercentile(a[good], q))


def circ_diff_deg_180(a_deg: float, b_deg: float) -> float:
    if (not np.isfinite(a_deg)) or (not np.isfinite(b_deg)):
        return np.nan
    d = abs(a_deg - b_deg) % 180.0
    return min(d, 180.0 - d)


def circ_median_deg_180(theta_rad: np.ndarray, mask: np.ndarray) -> float:
    th = np.asarray(theta_rad, dtype=float)
    m = mask & np.isfinite(th)
    if not np.any(m):
        return np.nan
    ang = th[m]
    z = np.exp(1j * 2.0 * ang)
    zmean = np.mean(z)
    if (not np.isfinite(zmean.real)) or (not np.isfinite(zmean.imag)) or abs(zmean) == 0:
        return np.nan
    th_mean = 0.5 * np.angle(zmean)
    deg = (np.degrees(th_mean) + 180.0) % 180.0
    return float(deg)


# -------------------------
# Geodesic bearing: 0 = East, counter-clockwise (CCW)
# -------------------------
def initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    """
    Vectorized initial bearing (forward azimuth) from (lat1, lon1) to (lat2, lon2).
    This returns azimuth degrees in [0, 360) measured from North, clockwise.
    """
    lat1 = np.deg2rad(lat1_deg)
    lon1 = np.deg2rad(lon1_deg)
    lat2 = np.deg2rad(lat2_deg)
    lon2 = np.deg2rad(lon2_deg)

    dlon = lon2 - lon1
    x = np.sin(dlon) * np.cos(lat2)
    y = np.cos(lat1) * np.sin(lat2) - np.sin(lat1) * np.cos(lat2) * np.cos(dlon)

    az = np.arctan2(x, y)  # radians, azimuth from North
    az_deg = (np.rad2deg(az) + 360.0) % 360.0
    return az_deg


def bearing_deg_east_ccw_from_points(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    """
    Convert azimuth (North=0, CW) into your convention:
    East=0 and increasing counter-clockwise (CCW).
    """
    az_north_cw = initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg)
    # North-CW -> East-CCW
    # East-CCW angle = (90 - az_north_cw) mod 360
    return (90.0 - az_north_cw) % 360.0


def compute_bearing_to_x_neighbor_east_ccw(lat2d: np.ndarray, lon2d: np.ndarray) -> np.ndarray:
    """
    Bearing at each pixel to its +x neighbor (last column uses -x neighbor),
    in degrees: 0=East, CCW positive.
    """
    lat = np.asarray(lat2d, dtype=float)
    lon = np.asarray(lon2d, dtype=float)
    ny, nx = lat.shape

    lat2 = np.empty_like(lat)
    lon2 = np.empty_like(lon)

    lat2[:, :-1] = lat[:, 1:]
    lon2[:, :-1] = lon[:, 1:]
    lat2[:, -1] = lat[:, -2]
    lon2[:, -1] = lon[:, -2]

    bearing = bearing_deg_east_ccw_from_points(lat, lon, lat2, lon2)

    good = np.isfinite(lat) & np.isfinite(lon) & np.isfinite(lat2) & np.isfinite(lon2)
    return np.where(good, bearing, np.nan)


def load_l6_for_matching(path: Path) -> Dict[str, Any]:
    with Dataset(path, "r") as nc:
        out: Dict[str, Any] = {
            "SlicesNo": np.asarray(nc.variables["SlicesNo"][:], dtype=int),
            "Amplitude": np.asarray(nc.variables["Amplitude"][:], dtype=float),
            "DominantWavelength": np.asarray(nc.variables["DominantWavelength"][:], dtype=float),
            "Angle": np.asarray(nc.variables["Angle"][:], dtype=float),
        }
        if "ClusterReconstruction" in nc.variables:
            out["ClusterReconstruction"] = np.asarray(nc.variables["ClusterReconstruction"][:], dtype=float)
        else:
            out["ClusterReconstruction"] = None
    return out


def get_cluster_maps(data: Dict[str, Any], idx: int) -> Dict[str, np.ndarray]:
    A = np.asarray(data["Amplitude"][idx], dtype=float)
    L = np.asarray(data["DominantWavelength"][idx], dtype=float)
    T = np.asarray(data["Angle"][idx], dtype=float)
    if data.get("ClusterReconstruction", None) is None:
        R = np.full_like(A, np.nan)
    else:
        R = np.asarray(data["ClusterReconstruction"][idx], dtype=float)
    return dict(R=R, A=A, L=L, T=T)


def compute_match_metrics(
    A_src: np.ndarray, L_src: np.ndarray, T_src: np.ndarray,
    A_cand: np.ndarray, L_cand: np.ndarray, T_cand: np.ndarray,
) -> Dict[str, Any]:
    mask_src = np.isfinite(A_src)
    mask_cand = np.isfinite(A_cand)
    inter = mask_src & mask_cand
    union = mask_src | mask_cand

    n_inter = int(np.count_nonzero(inter))
    n_union = int(np.count_nonzero(union))
    iou = (n_inter / n_union) if n_union > 0 else 0.0

    lam_src = L_src[inter]
    lam_cand = L_cand[inter]
    lam_src_med = nanpercentile_safe(lam_src, 50)
    lam_cand_med = nanpercentile_safe(lam_cand, 50)

    if np.isfinite(lam_src_med) and np.isfinite(lam_cand_med) and lam_src_med > 0 and lam_cand_med > 0:
        lam_ratio = max(lam_src_med, lam_cand_med) / min(lam_src_med, lam_cand_med)
    else:
        lam_ratio = np.nan

    ang_src_deg = circ_median_deg_180(T_src, inter)
    ang_cand_deg = circ_median_deg_180(T_cand, inter)
    ang_diff_deg = circ_diff_deg_180(ang_src_deg, ang_cand_deg)

    return dict(
        n_intersection=n_inter,
        iou=float(iou),
        lam_src_med=float(lam_src_med),
        lam_cand_med=float(lam_cand_med),
        lam_ratio=float(lam_ratio),
        ang_src_deg=float(ang_src_deg),
        ang_cand_deg=float(ang_cand_deg),
        ang_diff_deg=float(ang_diff_deg),
    )


def passes_thresholds(m: Dict[str, Any]) -> bool:
    if m["iou"] < MIN_IOU:
        return False
    if m["n_intersection"] < MIN_INTERSECTION_PIX:
        return False
    if (not np.isfinite(m["lam_ratio"])) or (m["lam_ratio"] > MAX_LAMBDA_MED_RATIO):
        return False
    if (not np.isfinite(m["ang_diff_deg"])) or (m["ang_diff_deg"] > MAX_ANGLE_DIFF_DEG):
        return False
    return True


def score(m: Dict[str, Any]) -> float:
    ang = m["ang_diff_deg"]
    if not np.isfinite(ang):
        ang = 999.0
    r = m["lam_ratio"]
    if (not np.isfinite(r)) or r <= 0:
        return 0.0
    return float(m["iou"]) * (1.0 / float(r)) / (1.0 + float(ang))


def plot_side_by_side_4rows(
    left: Dict[str, np.ndarray],
    right: Dict[str, np.ndarray],
    title_left: str,
    title_right: str,
    outpath: Path,
    dx_km: float,
    dy_km: float,
) -> None:
    ny, nx = left["A"].shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    Rl_vmin, Rl_vmax = robust_limits(left["R"])
    Rr_vmin, Rr_vmax = robust_limits(right["R"])
    Al_vmin, Al_vmax = robust_limits(left["A"])
    Ar_vmin, Ar_vmax = robust_limits(right["A"])

    L_vmin, L_vmax = robust_limits(np.concatenate([left["L"].ravel(), right["L"].ravel()]), 5, 95)
    T_vmin, T_vmax = robust_limits(np.concatenate([left["T"].ravel(), right["T"].ravel()]))

    fig, axs = plt.subplots(4, 2, figsize=(16, 14), constrained_layout=True, sharex=True, sharey=True)

    def _panel(ax, Z, vmin, vmax, label, cmap=None):
        im = ax.pcolormesh(x1d_km, y1d_km, Z, shading="auto", vmin=vmin, vmax=vmax, cmap=cmap)
        cb = fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01)
        cb.set_label(label)
        ax.set_aspect("equal", adjustable="box")

    axs[0, 0].set_title(title_left)
    axs[0, 1].set_title(title_right)

    _panel(axs[0, 0], left["R"], Rl_vmin, Rl_vmax, "arb", cmap="RdBu_r")
    _panel(axs[0, 1], right["R"], Rr_vmin, Rr_vmax, "arb", cmap="RdBu_r")
    axs[0, 0].set_ylabel("Recon\ny (km)")

    _panel(axs[1, 0], left["A"], Al_vmin, Al_vmax, "K")
    _panel(axs[1, 1], right["A"], Ar_vmin, Ar_vmax, "kR")
    axs[1, 0].set_ylabel("Amp\ny (km)")

    _panel(axs[2, 0], left["L"], L_vmin, L_vmax, "km")
    _panel(axs[2, 1], right["L"], L_vmin, L_vmax, "km")
    axs[2, 0].set_ylabel("Lambda\ny (km)")

    _panel(axs[3, 0], left["T"], T_vmin, T_vmax, "rad")
    _panel(axs[3, 1], right["T"], T_vmin, T_vmax, "rad")
    axs[3, 0].set_ylabel("Angle\ny (km)")

    for r in range(4):
        for c in range(2):
            axs[r, c].set_xlabel("x (km)")

    save_fig(fig, outpath)


# --------------------------
# Flatten swath BEFORE slicing
# --------------------------
def flatten_swath(Z: np.ndarray, target_ny: int | None = None) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


# --------------------------
# L6A cloning with PASSED-only cluster variables + new vars (u,v,N^2,Bearing, MF)
# --------------------------
def create_passed_only_l6a_with_new_vars(
    src_l6a: Path,
    dst_l6a: Path,
    passed_cluster_indices: np.ndarray,
    time_index: int,
) -> Tuple[str, str, str]:
    """
    Creates a passed only copy of L6A and adds

    Full field vars
    Bearing  degrees, 0 East, CCW, written only for top y_tile rows at time_index

    Cluster masked vars
    Temp_cluster
    u_cluster
    v_cluster
    NSquared_cluster
    Bearing_cluster
    MF_cluster
    MF_zonal_cluster        MF cos^2(phi)
    MF_meridional_cluster   MF sin^2(phi)

    Per slice sums on tile grid
    MF_slice_sum
    MF_zonal_slice_sum
    MF_meridional_slice_sum

    Full field stitched top rows at time_index
    MF_toprows
    MF_zonal_toprows
    MF_meridional_toprows
    """
    passed_cluster_indices = np.asarray(passed_cluster_indices, dtype=int)
    if passed_cluster_indices.size == 0:
        raise ValueError("No passed clusters. Output would be empty.")

    dst_l6a.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(src_l6a, "r") as src:
        amp_var = src.variables["Amplitude"]
        cluster_dim, ytile_dim, xtile_dim = amp_var.dimensions[:3]

        temp_var = src.variables[TEMP_VAR_NAME]
        temp_dims = temp_var.dimensions
        temp_shape = temp_var.shape
        temp_raw_2d = np.asarray(temp_var[time_index], dtype=float)

        amp_all = np.asarray(src.variables["Amplitude"][:], dtype=float)
        _, y_tile, x_tile = amp_all.shape

        # full field u v N2
        u_raw_2d = (
            np.asarray(src.variables["u"][time_index], dtype=float)
            if "u" in src.variables
            else np.full_like(temp_raw_2d, U_VALUE, dtype=float)
        )
        v_raw_2d = (
            np.asarray(src.variables["v"][time_index], dtype=float)
            if "v" in src.variables
            else np.full_like(temp_raw_2d, V_VALUE, dtype=float)
        )
        n2_raw_2d = (
            np.asarray(src.variables["NSquared"][time_index], dtype=float)
            if "NSquared" in src.variables
            else np.full_like(temp_raw_2d, N2_VALUE, dtype=float)
        )

        # bearing from lat lon if present
        if ("Latitude" in src.variables) and ("Longitude" in src.variables):
            lat_raw_2d = np.asarray(src.variables["Latitude"][time_index], dtype=float)
            lon_raw_2d = np.asarray(src.variables["Longitude"][time_index], dtype=float)
            bearing_raw_2d = compute_bearing_to_x_neighbor_east_ccw(lat_raw_2d, lon_raw_2d)
        else:
            bearing_raw_2d = np.full_like(temp_raw_2d, np.nan, dtype=float)

        # flatten to match tile y dimension
        temp_full_2d = flatten_swath(temp_raw_2d, target_ny=y_tile)
        u_full_2d = flatten_swath(u_raw_2d, target_ny=y_tile)
        v_full_2d = flatten_swath(v_raw_2d, target_ny=y_tile)
        n2_full_2d = flatten_swath(n2_raw_2d, target_ny=y_tile)
        bearing_full_2d = flatten_swath(bearing_raw_2d, target_ny=y_tile)

        n_passed = int(passed_cluster_indices.size)

        with Dataset(dst_l6a, "w") as dst:
            # global attrs
            for aname in src.ncattrs():
                dst.setncattr(aname, src.getncattr(aname))

            # dimensions, subset cluster dim
            for dname, dim in src.dimensions.items():
                if dname == cluster_dim:
                    dst.createDimension(dname, n_passed)
                else:
                    dst.createDimension(dname, (None if dim.isunlimited() else len(dim)))

            # variables copied, subset cluster dim vars
            for vname, vsrc in src.variables.items():
                fill_value = vsrc.getncattr("_FillValue") if "_FillValue" in vsrc.ncattrs() else None
                vdst = dst.createVariable(
                    vname,
                    vsrc.dtype,
                    vsrc.dimensions,
                    zlib=True,
                    complevel=4,
                    fill_value=fill_value,
                )
                for aname in vsrc.ncattrs():
                    if aname != "_FillValue":
                        vdst.setncattr(aname, vsrc.getncattr(aname))

                if cluster_dim in vsrc.dimensions:
                    ax = vsrc.dimensions.index(cluster_dim)
                    data_sub = np.take(vsrc[:], passed_cluster_indices, axis=ax)
                    vdst[:] = data_sub
                else:
                    vdst[:] = vsrc[:]

            # full field Bearing
            bearing_full = np.zeros(temp_shape, dtype=np.float32)
            bearing_full[time_index, 0:y_tile, :] = bearing_full_2d.astype(np.float32)

            if "Bearing" in dst.variables:
                dst.variables["Bearing"][:] = bearing_full
            else:
                vB = dst.createVariable("Bearing", "f4", temp_dims, zlib=True, complevel=4)
                vB.setncattr("long_name", "Geodesic bearing to +x neighbor (0=East, CCW)")
                vB.setncattr("units", "degree")
                vB[:] = bearing_full

            # allocate cluster masked arrays (NaN outside cluster mask)
            temp_cluster = np.full((n_passed, y_tile, x_tile), np.nan, dtype=np.float32)
            u_cluster = np.full_like(temp_cluster, np.nan)
            v_cluster = np.full_like(temp_cluster, np.nan)
            n2_cluster = np.full_like(temp_cluster, np.nan)
            bearing_cluster = np.full_like(temp_cluster, np.nan)
            
            mf_cluster = np.full_like(temp_cluster, np.nan)
            mf_zonal_cluster = np.full_like(temp_cluster, np.nan)
            mf_meridional_cluster = np.full_like(temp_cluster, np.nan)

            amp_passed = np.asarray(dst.variables["Amplitude"][:], dtype=float)
            lam_passed = np.asarray(dst.variables["DominantWavelength"][:], dtype=float)
            slice_passed = np.asarray(dst.variables["SlicesNo"][:], dtype=int)
            ang_rad_passed = np.asarray(dst.variables["Angle"][:], dtype=float)  # radians, propagation direction in tile

            for j in range(n_passed):
                s = int(slice_passed[j])
                x0 = s * x_tile
                x1 = x0 + x_tile

                mask = np.isfinite(amp_passed[j])

                Ttile = temp_full_2d[:, x0:x1]
                Utile = u_full_2d[:, x0:x1]
                Vtile = v_full_2d[:, x0:x1]
                N2tile = n2_full_2d[:, x0:x1]
                Btile = bearing_full_2d[:, x0:x1]

                temp_cluster[j][mask] = Ttile[mask]
                u_cluster[j][mask] = Utile[mask]
                v_cluster[j][mask] = Vtile[mask]
                n2_cluster[j][mask] = N2tile[mask]
                bearing_cluster[j][mask] = Btile[mask]

                A = amp_passed[j]
                Lx = lam_passed[j]

                ang_deg_tile = (np.rad2deg(ang_rad_passed[j]) % 360.0)

                good = mask
                good = good & np.isfinite(Ttile) & np.isfinite(N2tile) & np.isfinite(Lx) & np.isfinite(Btile)
                good = good & (Ttile != 0.0) & (N2tile > 0.0) & (Lx > 0.0)

                if np.any(good):
                    mf_val = (
                        0.5
                        * (G_MS2**2)
                        / N2tile[good]
                        * (LAMBDA_Z_KM / Lx[good])
                        * (A[good] / Ttile[good]) ** 2
                        * (1.0 / (C_CANCEL**2))
                    )
                    mf_cluster[j][good] = mf_val

                    # phi is geographic propagation angle, degrees, 0 East, CCW
                    phi_deg = (Btile[good] + ang_deg_tile[good]) % 360.0
                    phi_rad = np.deg2rad(phi_deg)

                    mf_zonal_cluster[j][good] = mf_val * (np.cos(phi_rad) ** 2)
                    mf_meridional_cluster[j][good] = mf_val * (np.sin(phi_rad) ** 2)

            # write cluster vars
            if "Temp_cluster" in dst.variables:
                dst.variables["Temp_cluster"][:] = temp_cluster
            else:
                dst.createVariable("Temp_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))[:] = temp_cluster

            if "u_cluster" in dst.variables:
                dst.variables["u_cluster"][:] = u_cluster
            else:
                dst.createVariable("u_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))[:] = u_cluster

            if "v_cluster" in dst.variables:
                dst.variables["v_cluster"][:] = v_cluster
            else:
                dst.createVariable("v_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))[:] = v_cluster

            if "NSquared_cluster" in dst.variables:
                dst.variables["NSquared_cluster"][:] = n2_cluster
            else:
                dst.createVariable("NSquared_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))[:] = n2_cluster

            if "Bearing_cluster" in dst.variables:
                dst.variables["Bearing_cluster"][:] = bearing_cluster
            else:
                vBC = dst.createVariable("Bearing_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                vBC.setncattr("long_name", "Geodesic bearing to +x neighbor (0=East, CCW), cluster masked")
                vBC.setncattr("units", "degree")
                vBC[:] = bearing_cluster

            if "MF_cluster" in dst.variables:
                dst.variables["MF_cluster"][:] = mf_cluster
            else:
                vMF = dst.createVariable("MF_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                vMF.setncattr("long_name", "Momentum flux proxy per pixel, cluster masked")
                vMF.setncattr("units", "m^2 s^-2")
                vMF[:] = mf_cluster

            if "MF_zonal_cluster" in dst.variables:
                dst.variables["MF_zonal_cluster"][:] = mf_zonal_cluster
            else:
                vMFZ = dst.createVariable("MF_zonal_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                vMFZ.setncattr("long_name", "Zonal aligned MF magnitude share, MF cos^2(phi)")
                vMFZ.setncattr("units", "m^2 s^-2")
                vMFZ[:] = mf_zonal_cluster

            if "MF_meridional_cluster" in dst.variables:
                dst.variables["MF_meridional_cluster"][:] = mf_meridional_cluster
            else:
                vMFM = dst.createVariable("MF_meridional_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                vMFM.setncattr("long_name", "Meridional aligned MF magnitude share, MF sin^2(phi)")
                vMFM.setncattr("units", "m^2 s^-2")
                vMFM[:] = mf_meridional_cluster

            # slice sums and stitched top rows
            smin, smax = int(np.min(slice_passed)), int(np.max(slice_passed))
            full_slices = np.arange(smin, smax + 1)

            if "slice" not in dst.dimensions:
                dst.createDimension("slice", len(full_slices))

            if "SliceNo_passed_slices" in dst.variables:
                dst.variables["SliceNo_passed_slices"][:] = full_slices
            else:
                dst.createVariable("SliceNo_passed_slices", "i4", ("slice",))[:] = full_slices

            mf_slice_sum = np.zeros((len(full_slices), y_tile, x_tile), dtype=np.float32)
            mfz_slice_sum = np.zeros_like(mf_slice_sum)
            mfm_slice_sum = np.zeros_like(mf_slice_sum)

            for k, s in enumerate(full_slices):
                idx = np.where(slice_passed == s)[0]
                if idx.size > 0:
                    mf_slice_sum[k]  = np.nansum(mf_cluster[idx], axis=0)
                    mfz_slice_sum[k] = np.nansum(mf_zonal_cluster[idx], axis=0)
                    mfm_slice_sum[k] = np.nansum(mf_meridional_cluster[idx], axis=0)

                # else keep zeros

            if "MF_slice_sum" in dst.variables:
                dst.variables["MF_slice_sum"][:] = mf_slice_sum
            else:
                dst.createVariable("MF_slice_sum", "f4", ("slice", ytile_dim, xtile_dim))[:] = mf_slice_sum

            if "MF_zonal_slice_sum" in dst.variables:
                dst.variables["MF_zonal_slice_sum"][:] = mfz_slice_sum
            else:
                v = dst.createVariable("MF_zonal_slice_sum", "f4", ("slice", ytile_dim, xtile_dim))
                v.setncattr("long_name", "Per slice zonal MF magnitude share sum")
                v.setncattr("units", "m^2 s^-2")
                v[:] = mfz_slice_sum

            if "MF_meridional_slice_sum" in dst.variables:
                dst.variables["MF_meridional_slice_sum"][:] = mfm_slice_sum
            else:
                v = dst.createVariable("MF_meridional_slice_sum", "f4", ("slice", ytile_dim, xtile_dim))
                v.setncattr("long_name", "Per slice meridional MF magnitude share sum")
                v.setncattr("units", "m^2 s^-2")
                v[:] = mfm_slice_sum

            MF_toprows = np.zeros(temp_shape, dtype=np.float32)
            MFZ_toprows = np.zeros(temp_shape, dtype=np.float32)
            MFM_toprows = np.zeros(temp_shape, dtype=np.float32)

            for k, s in enumerate(full_slices):
                x0 = s * x_tile
                x1 = x0 + x_tile
                MF_toprows[time_index, 0:y_tile, x0:x1] = mf_slice_sum[k]
                MFZ_toprows[time_index, 0:y_tile, x0:x1] = mfz_slice_sum[k]
                MFM_toprows[time_index, 0:y_tile, x0:x1] = mfm_slice_sum[k]

            if "MF_toprows" in dst.variables:
                dst.variables["MF_toprows"][:] = MF_toprows
            else:
                dst.createVariable("MF_toprows", "f4", temp_dims)[:] = MF_toprows

            if "MF_zonal_toprows" in dst.variables:
                dst.variables["MF_zonal_toprows"][:] = MFZ_toprows
            else:
                v = dst.createVariable("MF_zonal_toprows", "f4", temp_dims)
                v.setncattr("long_name", "Stitched zonal MF magnitude share, top tile rows only")
                v.setncattr("units", "m^2 s^-2")
                v[:] = MFZ_toprows

            if "MF_meridional_toprows" in dst.variables:
                dst.variables["MF_meridional_toprows"][:] = MFM_toprows
            else:
                v = dst.createVariable("MF_meridional_toprows", "f4", temp_dims)
                v.setncattr("long_name", "Stitched meridional MF magnitude share, top tile rows only")
                v.setncattr("units", "m^2 s^-2")
                v[:] = MFM_toprows

    return cluster_dim, ytile_dim, xtile_dim

# --------------------------
# Main: matching -> passed clusters -> output passed-only netCDF -> stitched MF plot
# --------------------------
l6c = load_l6_for_matching(L6C_PATH)
l6a_match = load_l6_for_matching(L6A_PATH)

all_slices_a = np.unique(l6a_match["SlicesNo"]).astype(int)
all_slices_a = all_slices_a[all_slices_a >= 0]
all_slices_a = np.sort(all_slices_a)

print("Slices in L6A:", all_slices_a.tolist())

summary_lines: List[str] = []
summary_lines.append(f"L6A: {L6A_PATH}\n")
summary_lines.append(f"L6C: {L6C_PATH}\n\n")
summary_lines.append("slice  nA  nC  nBestSaved  nPassed  note\n")

passed_global_indices: List[int] = []

for slice_no in all_slices_a:
    idx_a = np.where(l6a_match["SlicesNo"] == int(slice_no))[0]
    idx_c = np.where(l6c["SlicesNo"] == int(slice_no))[0]

    slice_dir = OUTDIR / f"slice_{slice_no:03d}"
    pairs_dir = slice_dir / "pairs"
    pairs_dir.mkdir(parents=True, exist_ok=True)

    if idx_a.size == 0:
        summary_lines.append(f"{slice_no:5d}  {0:2d}  {idx_c.size:2d}  {0:10d}  {0:7d}  no L6A clusters\n")
        continue
    if idx_c.size == 0:
        (slice_dir / "NO_L6C_CLUSTERS.txt").write_text(f"No L6C clusters for slice {slice_no}\n")
        summary_lines.append(f"{slice_no:5d}  {idx_a.size:2d}  {0:2d}  {0:10d}  {0:7d}  no L6C clusters\n")
        continue

    all_candidate_rows: List[Dict[str, Any]] = []
    best_rows: List[Dict[str, Any]] = []

    for a_idx in idx_a:
        a_idx = int(a_idx)
        A_a = l6a_match["Amplitude"][a_idx]
        L_a = l6a_match["DominantWavelength"][a_idx]
        T_a = l6a_match["Angle"][a_idx]

        candidates: List[Dict[str, Any]] = []
        for c_idx in idx_c:
            c_idx = int(c_idx)
            A_c = l6c["Amplitude"][c_idx]
            L_c = l6c["DominantWavelength"][c_idx]
            T_c = l6c["Angle"][c_idx]

            m = compute_match_metrics(A_a, L_a, T_a, A_c, L_c, T_c)
            m["cluster_a"] = a_idx
            m["cluster_c"] = c_idx
            m["passes"] = bool(passes_thresholds(m))
            m["score"] = float(score(m))
            candidates.append(m)
            all_candidate_rows.append(m)

        passed = [c for c in candidates if c["passes"]]
        if passed:
            best = max(passed, key=lambda d: d["score"])
        else:
            best = max(candidates, key=lambda d: d["score"])

        if best["passes"] or ASSIGN_BEST_EVEN_IF_FAILS:
            best_rows.append(best)

            left_maps = get_cluster_maps(l6a_match, best["cluster_a"])
            right_maps = get_cluster_maps(l6c, best["cluster_c"])

            pass_tag = "PASS" if best["passes"] else "FAIL"
            outpng = pairs_dir / f"slice_{slice_no:03d}_A_{best['cluster_a']:04d}_to_C_{best['cluster_c']:04d}_{pass_tag}.png"

            title_left = (
                f"L6A Temp | slice {slice_no} | idx {best['cluster_a']} | "
                f"n={np.count_nonzero(np.isfinite(left_maps['A']))}"
            )
            title_right = (
                f"L6C Rad | slice {slice_no} | idx {best['cluster_c']} | "
                f"IoU={best['iou']:.3f} inter={best['n_intersection']} "
                f"ratio={best['lam_ratio']:.3f} Δθ={best['ang_diff_deg']:.1f}°"
            )

            plot_side_by_side_4rows(
                left=left_maps,
                right=right_maps,
                title_left=title_left,
                title_right=title_right,
                outpath=outpng,
                dx_km=DX_KM,
                dy_km=DY_KM,
            )

    cand_path = slice_dir / f"slice_{slice_no:03d}_ALL_candidates_ratio.txt"
    lines = []
    lines.append(f"L6A file: {L6A_PATH}\n")
    lines.append(f"L6C file: {L6C_PATH}\n")
    lines.append(f"Slice: {slice_no}\n\n")
    lines.append(
        "cluster_a  cluster_c  passes  score    iou    inter  "
        "lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
    )
    for m in sorted(all_candidate_rows, key=lambda d: (d["cluster_a"], -d["score"])):
        lines.append(
            f"{m['cluster_a']:9d}  {m['cluster_c']:9d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
            f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
            f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
            f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
            f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
        )
    cand_path.write_text("".join(lines))

    best_path = slice_dir / f"slice_{slice_no:03d}_BEST_matches_A_to_C_ratio.txt"
    lines = []
    lines.append(f"L6A file: {L6A_PATH}\n")
    lines.append(f"L6C file: {L6C_PATH}\n")
    lines.append(f"Slice: {slice_no}\n\n")
    lines.append(
        "cluster_a  best_cluster_c  passes  score    iou    inter  "
        "lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
    )
    for m in sorted(best_rows, key=lambda d: d["cluster_a"]):
        lines.append(
            f"{m['cluster_a']:9d}  {m['cluster_c']:14d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
            f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
            f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
            f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
            f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
        )
    best_path.write_text("".join(lines))

    passed_here = [int(m["cluster_a"]) for m in best_rows if bool(m["passes"])]
    passed_global_indices.extend(passed_here)

    summary_lines.append(
        f"{slice_no:5d}  {idx_a.size:2d}  {idx_c.size:2d}  {len(best_rows):10d}  {len(passed_here):7d}  ok\n"
    )

summary_path = OUTDIR / "SUMMARY_all_slices.txt"
summary_path.write_text("".join(summary_lines))

passed_global_indices = sorted(set(passed_global_indices))
passed_global_indices_np = np.asarray(passed_global_indices, dtype=int)
print("Total passed clusters:", passed_global_indices_np.size)

if passed_global_indices_np.size == 0:
    raise RuntimeError("No passed clusters found. Nothing to save/stitch.")

cluster_dim_name, ytile_dim_name, xtile_dim_name = create_passed_only_l6a_with_new_vars(
    src_l6a=L6A_PATH,
    dst_l6a=OUT_L6A_PASSED,
    passed_cluster_indices=passed_global_indices_np,
    time_index=TIME_INDEX,
)

# ---- Plot MF_toprows stitched (2D at TIME_INDEX) ----
with Dataset(OUT_L6A_PASSED, "r") as nc:
    MF2 = np.asarray(nc.variables["MF_toprows"][TIME_INDEX], dtype=float)  # (y,x)
    ny, nx = MF2.shape
    x1d_km = np.arange(nx, dtype=float) * DX_KM
    y1d_km = np.arange(ny, dtype=float) * DY_KM

    vmin, vmax = robust_limits(MF2, 2, 99.9)

    fig, ax = plt.subplots(figsize=(22, 3), constrained_layout=True)
    im = ax.pcolormesh(x1d_km, y1d_km, MF2, shading="auto", vmin=vmin, vmax=vmax)
    ax.set_title("Momentum Flux (passed clusters summed)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_ylim(0, 600)
    ax.set_aspect("equal", adjustable="box")
    fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01).set_label("MF (m²/s²)")
    save_fig(fig, OUTDIR / "MF_stitched.png")

print("\nDone.")
print("Outputs in:", OUTDIR.resolve())
print("Summary:", summary_path.resolve())
print("PASSED-only augmented L6A:", OUT_L6A_PASSED.resolve())
print("New vars in output: Bearing, Bearing_cluster, Temp_cluster, u_cluster, v_cluster, NSquared_cluster, MF_cluster, MF_slice_sum, MF_toprows")


# --------------------------
# Plot per-passed-cluster panels:
# Recon, Amp, Lambda, Angle, Bearing, N^2, Temperature, MF
# --------------------------
def plot_passed_clusters_panels(nc_path: Path, outdir: Path) -> None:
    """
    Per passed cluster panels, 5 rows x 2 columns

    Row 1  Recon | Amplitude
    Row 2  Lambda | Temperature
    Row 3  Angle deg | Bearing deg
    Row 4  N2 | MF
    Row 5  MF zonal share | MF meridional share
    """
    outdir.mkdir(parents=True, exist_ok=True)

    with Dataset(nc_path, "r") as nc:
        amp = np.asarray(nc.variables["Amplitude"][:], dtype=float)
        lam = np.asarray(nc.variables["DominantWavelength"][:], dtype=float)

        ang_rad = np.asarray(nc.variables["Angle"][:], dtype=float)
        ang_deg = (np.rad2deg(ang_rad) % 360.0)

        brg = (
            np.asarray(nc.variables["Bearing_cluster"][:], dtype=float)
            if "Bearing_cluster" in nc.variables
            else np.full_like(amp, np.nan)
        )

        n2 = np.asarray(nc.variables["NSquared_cluster"][:], dtype=float)
        tmp = np.asarray(nc.variables["Temp_cluster"][:], dtype=float)
        mf = np.asarray(nc.variables["MF_cluster"][:], dtype=float)

        mfz = (
            np.asarray(nc.variables["MF_zonal_cluster"][:], dtype=float)
            if "MF_zonal_cluster" in nc.variables
            else np.full_like(mf, np.nan)
        )
        mfm = (
            np.asarray(nc.variables["MF_meridional_cluster"][:], dtype=float)
            if "MF_meridional_cluster" in nc.variables
            else np.full_like(mf, np.nan)
        )

        slc = np.asarray(nc.variables["SlicesNo"][:], dtype=int)

        if "ClusterReconstruction" in nc.variables:
            recon = np.asarray(nc.variables["ClusterReconstruction"][:], dtype=float)
        else:
            recon = np.full_like(amp, np.nan)

        n_cluster, ny, nx = amp.shape
        x1d_km = np.arange(nx, dtype=float) * DX_KM
        y1d_km = np.arange(ny, dtype=float) * DY_KM

        ang_vmin, ang_vmax = (0.0, 360.0)
        brg_vmin, brg_vmax = (0.0, 360.0)

        n2_center = float(N2_VALUE)
        n2_vmin, n2_vmax = (0.5 * n2_center, 1.5 * n2_center)

        for i in range(n_cluster):
            s = int(slc[i])

            r_vmin, r_vmax = robust_limits(recon[i], 2, 98)
            a_vmin, a_vmax = robust_limits(amp[i], 2, 98)
            l_vmin, l_vmax = robust_limits(lam[i], 5, 95)
            T_vmin, T_vmax = robust_limits(tmp[i], 2, 98)

            mf_vmin, mf_vmax = robust_limits(mf[i], 2, 98)
            mfz_vmin, mfz_vmax = robust_limits(mfz[i], 2, 98)
            mfm_vmin, mfm_vmax = robust_limits(mfm[i], 2, 98)

            fig, axs = plt.subplots(
                5, 2,
                figsize=(16, 22),
                constrained_layout=True,
                sharex=True,
                sharey=True,
            )

            def _panel(ax, Z, vmin, vmax, label, cmap=None):
                im = ax.pcolormesh(
                    x1d_km, y1d_km, Z,
                    shading="auto",
                    vmin=vmin,
                    vmax=vmax,
                    cmap=cmap,
                )
                cb = fig.colorbar(im, ax=ax, fraction=0.04, pad=0.02)
                cb.set_label(label)
                ax.set_aspect("equal", adjustable="box")

            axs[0, 0].set_title(f"Passed cluster {i:04d}  SliceNo {s}")

            _panel(axs[0, 0], recon[i], r_vmin, r_vmax, "Recon", cmap="RdBu_r")
            _panel(axs[0, 1], amp[i], a_vmin, a_vmax, "Amplitude K")

            _panel(axs[1, 0], lam[i], l_vmin, l_vmax, "DominantWavelength km")
            _panel(axs[1, 1], tmp[i], T_vmin, T_vmax, "Temperature K")

            _panel(axs[2, 0], ang_deg[i], ang_vmin, ang_vmax, "Angle deg propagation")
            _panel(axs[2, 1], brg[i], brg_vmin, brg_vmax, "Bearing deg 0 East CCW")

            _panel(axs[3, 0], n2[i], n2_vmin, n2_vmax, "N2 1 per s2")
            _panel(axs[3, 1], mf[i], mf_vmin, mf_vmax, "MF m2 per s2")

            _panel(axs[4, 0], mfz[i], mfz_vmin, mfz_vmax, "MF zonal share cos2")
            _panel(axs[4, 1], mfm[i], mfm_vmin, mfm_vmax, "MF meridional share sin2")

            for r in range(5):
                axs[r, 0].set_ylabel("y km")
                axs[r, 1].set_ylabel("y km")

            axs[4, 0].set_xlabel("x km")
            axs[4, 1].set_xlabel("x km")

            outpng = outdir / (
                f"passed_cluster_{i:04d}_slice_{s:03d}"
                "_Recon_Amp_Lam_Temp_Ang_Bearing_N2_MF_MFz_MFm.png"
            )
            save_fig(fig, outpng)

    print("Per cluster plots saved to:", outdir.resolve())

def plot_stitched_mf_components(nc_path: Path, outpng: Path, time_index: int) -> None:
    """
    Makes a stitched 3 panel figure

    Panel 1 MF_toprows
    Panel 2 MF_zonal_toprows
    Panel 3 MF_meridional_toprows
    """
    outpng.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(nc_path, "r") as nc:
        MF = np.asarray(nc.variables["MF_toprows"][time_index], dtype=float)
        MFZ = np.asarray(nc.variables["MF_zonal_toprows"][time_index], dtype=float)
        MFM = np.asarray(nc.variables["MF_meridional_toprows"][time_index], dtype=float)

    ny, nx = MF.shape
    x1d_km = np.arange(nx, dtype=float) * DX_KM
    y1d_km = np.arange(ny, dtype=float) * DY_KM

    stacked = np.concatenate([MF.ravel(), MFZ.ravel(), MFM.ravel()])
    vmin, vmax = robust_limits(stacked, 2, 99.9)

    fig, axs = plt.subplots(3, 1, figsize=(22, 8), constrained_layout=True, sharex=True, sharey=True)

    im0 = axs[0].pcolormesh(x1d_km, y1d_km, MF, shading="auto", vmin=vmin, vmax=vmax)
    axs[0].set_title("Stitched MF passed clusters summed")
    axs[0].set_ylabel("y km")
    axs[0].set_aspect("equal", adjustable="box")

    im1 = axs[1].pcolormesh(x1d_km, y1d_km, MFZ, shading="auto", vmin=vmin, vmax=vmax)
    axs[1].set_title("Stitched MF zonal share cos2")
    axs[1].set_ylabel("y km")
    axs[1].set_aspect("equal", adjustable="box")

    im2 = axs[2].pcolormesh(x1d_km, y1d_km, MFM, shading="auto", vmin=vmin, vmax=vmax)
    axs[2].set_title("Stitched MF meridional share sin2")
    axs[2].set_xlabel("x km")
    axs[2].set_ylabel("y km")
    axs[2].set_aspect("equal", adjustable="box")

    for ax in axs:
        ax.set_ylim(0, 600)

    cbar = fig.colorbar(im2, ax=axs, fraction=0.02, pad=0.01)
    cbar.set_label("MF m2 per s2")

    save_fig(fig, outpng)


plot_passed_clusters_panels(
    nc_path=OUT_L6A_PASSED,
    outdir=OUTDIR / "passed_cluster_plots_panels",
)

plot_stitched_mf_components(
    nc_path=OUT_L6A_PASSED,
    outpng=OUTDIR / "MF_stitched_components.png",
    time_index=TIME_INDEX,
)
# Out:
# Slices in L6A: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Total passed clusters: 28
#
# Done.
# Outputs in: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF
# Summary: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF/SUMMARY_all_slices.txt
# PASSED-only augmented L6A: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF/awe_l6a_tmp_2024165T2120_03175_v01_PASSED_with_u_v_NS2_Bearing_TempCluster_MF.nc
# New vars in output: Bearing, Bearing_cluster, Temp_cluster, u_cluster, v_cluster, NSquared_cluster, MF_cluster, MF_slice_sum, MF_toprows
# Per cluster plots saved to: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF/passed_cluster_plots_panels

# %% [markdown]
# 192 s

# %% [markdown]
# ## Clean up memory
#
# Brief list of changes
#
# Matching load no longer reads ClusterReconstruction[:] into memory. It is lazy loaded only for the specific best pair plot.
#
# Candidate logging is streamed as strings (cand_lines) instead of storing a huge list of dicts for all A by C pairs.
#
# In create_passed_only_l6a_with_new_vars, the tile shape comes from amp_var.shape (metadata) instead of Amplitude[:].
#
# Per cluster plotting reads one cluster at a time (var[i]) instead of var[:] for all clusters.
#
# Added aggressive cleanup (del, gc.collect(), and plt.close) after heavy steps so memory can actually drop instead of only going up.

# %%
# %%
"""
ALL-SLICES matching + per-slice combined L6A recon + FULL-ORBIT stitched recon
+ slice Temperature + momentum flux for PASSED clusters only
+ sum MF per slice + stitch MF across orbit
+ output NetCDF contains original L6A global attrs + variables, but ONLY PASSED clusters
  are kept for cluster-dimension variables.

Momentum flux (per cluster pixel, masked to cluster area):
MF = 1/2 * g^2 / N^2 * (lambda_z / lambda_x) * (Amplitude / Temperature)^2 * (1/c^2)

Constants:
g = 9.52 m/s^2
lambda_z = 10 km
c = 1
N^2 = 0.0004 everywhere (synthetic)
u=v=0 everywhere (synthetic)

Key rules:
- SliceNo already exists in L6A, keep it (but subset to passed clusters)
- Area, Amplitude, DominantWavelength, Angle already exist (subset to passed clusters)
- Also slice Temperature into Temp_cluster (passed clusters only)
- Add geodesic Bearing (0 = East, counter-clockwise) as Bearing + Bearing_cluster
- Only save passed clusters (output file cluster vars are subset)
- Add MF_cluster, MF_slice_sum, MF_toprows
"""

from __future__ import annotations

from pathlib import Path
from typing import Dict, Any, List, Tuple

import gc
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from netCDF4 import Dataset

# --------------------------
# User params
# --------------------------
L6C_PATH = Path("awe_l6c_q20_2024165T2120_03175_v01.nc")  # Radiance-based clusters
L6A_PATH = Path("awe_l6a_tmp_2024165T2120_03175_v01.nc")  # Temperature-based clusters

OUTDIR = Path("outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF")
OUTDIR.mkdir(parents=True, exist_ok=True)
SAVE_DPI = 200

DX_KM = 2.0
DY_KM = 2.0

# ---- Synthetic u,v,N^2 settings ----
TEMP_VAR_NAME = "Temperature"  # variable name in L6A
TIME_INDEX = 0                 # which t index to use when slicing
N2_VALUE = 4e-4                # N=0.02 -> N^2=0.0004
U_VALUE = 0.0
V_VALUE = 0.0

# ---- Momentum flux constants ----
G_MS2 = 9.52
LAMBDA_Z_KM = 10.0
C_CANCEL = 1.0
CP_JKGK = 1005.0

# Output NetCDF
OUT_L6A_PASSED = OUTDIR / f"{L6A_PATH.stem}_PASSED_with_u_v_NS2_Bearing_TempCluster_MF.nc"

# --------------------------
# Matching thresholds (tune)
# --------------------------
MIN_IOU = 0.05
MIN_INTERSECTION_PIX = 50
MAX_LAMBDA_MED_RATIO = 1.25
MAX_ANGLE_DIFF_DEG = 15.0

# Save best match plot even if FAIL (does NOT affect passing)
ASSIGN_BEST_EVEN_IF_FAILS = True

# --------------------------
# Helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def robust_limits(A: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    a = np.asarray(A)
    good = np.isfinite(a)
    if not np.any(good):
        return (-1.0, 1.0)
    lo, hi = np.nanpercentile(a[good], [p_lo, p_hi])
    if (not np.isfinite(lo)) or (not np.isfinite(hi)) or lo == hi:
        lo = float(np.nanmin(a[good]))
        hi = float(np.nanmax(a[good]))
    return (float(lo), float(hi))


def nanpercentile_safe(a: np.ndarray, q: float) -> float:
    good = np.isfinite(a)
    if not np.any(good):
        return np.nan
    return float(np.nanpercentile(a[good], q))


def circ_diff_deg_180(a_deg: float, b_deg: float) -> float:
    if (not np.isfinite(a_deg)) or (not np.isfinite(b_deg)):
        return np.nan
    d = abs(a_deg - b_deg) % 180.0
    return min(d, 180.0 - d)


def circ_median_deg_180(theta_rad: np.ndarray, mask: np.ndarray) -> float:
    th = np.asarray(theta_rad, dtype=float)
    m = mask & np.isfinite(th)
    if not np.any(m):
        return np.nan
    ang = th[m]
    z = np.exp(1j * 2.0 * ang)
    zmean = np.mean(z)
    if (not np.isfinite(zmean.real)) or (not np.isfinite(zmean.imag)) or abs(zmean) == 0:
        return np.nan
    th_mean = 0.5 * np.angle(zmean)
    deg = (np.degrees(th_mean) + 180.0) % 180.0
    return float(deg)


# -------------------------
# Geodesic bearing: 0 = East, counter-clockwise (CCW)
# -------------------------
def initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    """
    Vectorized initial bearing (forward azimuth) from (lat1, lon1) to (lat2, lon2).
    Returns azimuth degrees in [0, 360) measured from North, clockwise.
    """
    lat1 = np.deg2rad(lat1_deg)
    lon1 = np.deg2rad(lon1_deg)
    lat2 = np.deg2rad(lat2_deg)
    lon2 = np.deg2rad(lon2_deg)

    dlon = lon2 - lon1
    x = np.sin(dlon) * np.cos(lat2)
    y = np.cos(lat1) * np.sin(lat2) - np.sin(lat1) * np.cos(lat2) * np.cos(dlon)

    az = np.arctan2(x, y)
    az_deg = (np.rad2deg(az) + 360.0) % 360.0
    return az_deg


def bearing_deg_east_ccw_from_points(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    """
    Convert azimuth (North=0, CW) into your convention:
    East=0 and increasing counter-clockwise (CCW).
    East-CCW angle = (90 - az_north_cw) mod 360
    """
    az_north_cw = initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg)
    return (90.0 - az_north_cw) % 360.0


def compute_bearing_to_x_neighbor_east_ccw(lat2d: np.ndarray, lon2d: np.ndarray) -> np.ndarray:
    """
    Bearing at each pixel to its +x neighbor (last column uses -x neighbor),
    in degrees: 0=East, CCW positive.
    """
    lat = np.asarray(lat2d, dtype=float)
    lon = np.asarray(lon2d, dtype=float)
    ny, nx = lat.shape

    lat2 = np.empty_like(lat)
    lon2 = np.empty_like(lon)

    lat2[:, :-1] = lat[:, 1:]
    lon2[:, :-1] = lon[:, 1:]
    lat2[:, -1] = lat[:, -2]
    lon2[:, -1] = lon[:, -2]

    bearing = bearing_deg_east_ccw_from_points(lat, lon, lat2, lon2)

    good = np.isfinite(lat) & np.isfinite(lon) & np.isfinite(lat2) & np.isfinite(lon2)
    return np.where(good, bearing, np.nan)


# --------------------------
# IO: load only the variables needed for matching (no ClusterReconstruction here)
# --------------------------
def load_l6_for_matching(path: Path) -> Dict[str, Any]:
    with Dataset(path, "r") as nc:
        return {
            "path": str(path),
            "SlicesNo": np.asarray(nc.variables["SlicesNo"][:], dtype=int),
            "Amplitude": np.asarray(nc.variables["Amplitude"][:], dtype=float),
            "DominantWavelength": np.asarray(nc.variables["DominantWavelength"][:], dtype=float),
            "Angle": np.asarray(nc.variables["Angle"][:], dtype=float),
        }


def get_cluster_maps(data: Dict[str, Any], idx: int) -> Dict[str, np.ndarray]:
    """
    Lazy load ClusterReconstruction only for the requested idx.
    This keeps memory much flatter than reading ClusterReconstruction[:] upfront.
    """
    A = np.asarray(data["Amplitude"][idx], dtype=float)
    L = np.asarray(data["DominantWavelength"][idx], dtype=float)
    T = np.asarray(data["Angle"][idx], dtype=float)

    R = np.full_like(A, np.nan)
    with Dataset(data["path"], "r") as nc:
        if "ClusterReconstruction" in nc.variables:
            R = np.asarray(nc.variables["ClusterReconstruction"][idx], dtype=float)

    return dict(R=R, A=A, L=L, T=T)


def compute_match_metrics(
    A_src: np.ndarray, L_src: np.ndarray, T_src: np.ndarray,
    A_cand: np.ndarray, L_cand: np.ndarray, T_cand: np.ndarray,
) -> Dict[str, Any]:
    mask_src = np.isfinite(A_src)
    mask_cand = np.isfinite(A_cand)
    inter = mask_src & mask_cand
    union = mask_src | mask_cand

    n_inter = int(np.count_nonzero(inter))
    n_union = int(np.count_nonzero(union))
    iou = (n_inter / n_union) if n_union > 0 else 0.0

    lam_src = L_src[inter]
    lam_cand = L_cand[inter]
    lam_src_med = nanpercentile_safe(lam_src, 50)
    lam_cand_med = nanpercentile_safe(lam_cand, 50)

    if np.isfinite(lam_src_med) and np.isfinite(lam_cand_med) and lam_src_med > 0 and lam_cand_med > 0:
        lam_ratio = max(lam_src_med, lam_cand_med) / min(lam_src_med, lam_cand_med)
    else:
        lam_ratio = np.nan

    ang_src_deg = circ_median_deg_180(T_src, inter)
    ang_cand_deg = circ_median_deg_180(T_cand, inter)
    ang_diff_deg = circ_diff_deg_180(ang_src_deg, ang_cand_deg)

    return dict(
        n_intersection=n_inter,
        iou=float(iou),
        lam_src_med=float(lam_src_med),
        lam_cand_med=float(lam_cand_med),
        lam_ratio=float(lam_ratio),
        ang_src_deg=float(ang_src_deg),
        ang_cand_deg=float(ang_cand_deg),
        ang_diff_deg=float(ang_diff_deg),
    )


def passes_thresholds(m: Dict[str, Any]) -> bool:
    if m["iou"] < MIN_IOU:
        return False
    if m["n_intersection"] < MIN_INTERSECTION_PIX:
        return False
    if (not np.isfinite(m["lam_ratio"])) or (m["lam_ratio"] > MAX_LAMBDA_MED_RATIO):
        return False
    if (not np.isfinite(m["ang_diff_deg"])) or (m["ang_diff_deg"] > MAX_ANGLE_DIFF_DEG):
        return False
    return True


def score(m: Dict[str, Any]) -> float:
    ang = m["ang_diff_deg"]
    if not np.isfinite(ang):
        ang = 999.0
    r = m["lam_ratio"]
    if (not np.isfinite(r)) or r <= 0:
        return 0.0
    return float(m["iou"]) * (1.0 / float(r)) / (1.0 + float(ang))


def plot_side_by_side_4rows(
    left: Dict[str, np.ndarray],
    right: Dict[str, np.ndarray],
    title_left: str,
    title_right: str,
    outpath: Path,
    dx_km: float,
    dy_km: float,
) -> None:
    ny, nx = left["A"].shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    Rl_vmin, Rl_vmax = robust_limits(left["R"])
    Rr_vmin, Rr_vmax = robust_limits(right["R"])
    Al_vmin, Al_vmax = robust_limits(left["A"])
    Ar_vmin, Ar_vmax = robust_limits(right["A"])

    L_vmin, L_vmax = robust_limits(np.concatenate([left["L"].ravel(), right["L"].ravel()]), 5, 95)
    T_vmin, T_vmax = robust_limits(np.concatenate([left["T"].ravel(), right["T"].ravel()]))

    fig, axs = plt.subplots(4, 2, figsize=(16, 14), constrained_layout=True, sharex=True, sharey=True)

    def _panel(ax, Z, vmin, vmax, label, cmap=None):
        im = ax.pcolormesh(x1d_km, y1d_km, Z, shading="auto", vmin=vmin, vmax=vmax, cmap=cmap)
        cb = fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01)
        cb.set_label(label)
        ax.set_aspect("equal", adjustable="box")

    axs[0, 0].set_title(title_left)
    axs[0, 1].set_title(title_right)

    _panel(axs[0, 0], left["R"], Rl_vmin, Rl_vmax, "arb", cmap="RdBu_r")
    _panel(axs[0, 1], right["R"], Rr_vmin, Rr_vmax, "arb", cmap="RdBu_r")
    axs[0, 0].set_ylabel("Recon\ny (km)")

    _panel(axs[1, 0], left["A"], Al_vmin, Al_vmax, "K")
    _panel(axs[1, 1], right["A"], Ar_vmin, Ar_vmax, "kR")
    axs[1, 0].set_ylabel("Amp\ny (km)")

    _panel(axs[2, 0], left["L"], L_vmin, L_vmax, "km")
    _panel(axs[2, 1], right["L"], L_vmin, L_vmax, "km")
    axs[2, 0].set_ylabel("Lambda\ny (km)")

    _panel(axs[3, 0], left["T"], T_vmin, T_vmax, "rad")
    _panel(axs[3, 1], right["T"], T_vmin, T_vmax, "rad")
    axs[3, 0].set_ylabel("Angle\ny (km)")

    for r in range(4):
        for c in range(2):
            axs[r, c].set_xlabel("x (km)")

    save_fig(fig, outpath)


# --------------------------
# Flatten swath BEFORE slicing
# --------------------------
def flatten_swath(Z: np.ndarray, target_ny: int | None = None) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


# --------------------------
# L6A cloning with PASSED-only cluster variables + new vars (u,v,N^2,Bearing, MF)
# --------------------------
def create_passed_only_l6a_with_new_vars(
    src_l6a: Path,
    dst_l6a: Path,
    passed_cluster_indices: np.ndarray,
    time_index: int,
) -> Tuple[str, str, str]:
    """
    Creates a passed only copy of L6A and adds

    Full field vars
    Bearing degrees, 0 East, CCW, written only for top y_tile rows at time_index

    Cluster masked vars
    Temp_cluster
    u_cluster
    v_cluster
    NSquared_cluster
    Bearing_cluster
    MF_cluster
    MF_zonal_cluster        MF cos^2(phi)
    MF_meridional_cluster   MF sin^2(phi)

    Per slice sums on tile grid
    MF_slice_sum
    MF_zonal_slice_sum
    MF_meridional_slice_sum

    Full field stitched top rows at time_index
    MF_toprows
    MF_zonal_toprows
    MF_meridional_toprows
    """
    passed_cluster_indices = np.asarray(passed_cluster_indices, dtype=int)
    if passed_cluster_indices.size == 0:
        raise ValueError("No passed clusters. Output would be empty.")

    dst_l6a.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(src_l6a, "r") as src:
        amp_var = src.variables["Amplitude"]
        cluster_dim, ytile_dim, xtile_dim = amp_var.dimensions[:3]

        # IMPORTANT: do not read amp_all[:] just to get shapes
        _, y_tile, x_tile = amp_var.shape

        temp_var = src.variables[TEMP_VAR_NAME]
        temp_dims = temp_var.dimensions
        temp_shape = temp_var.shape
        temp_raw_2d = np.asarray(temp_var[time_index], dtype=float)

        # full field u v N2
        u_raw_2d = (
            np.asarray(src.variables["u"][time_index], dtype=float)
            if "u" in src.variables
            else np.full_like(temp_raw_2d, U_VALUE, dtype=float)
        )
        v_raw_2d = (
            np.asarray(src.variables["v"][time_index], dtype=float)
            if "v" in src.variables
            else np.full_like(temp_raw_2d, V_VALUE, dtype=float)
        )
        n2_raw_2d = (
            np.asarray(src.variables["NSquared"][time_index], dtype=float)
            if "NSquared" in src.variables
            else np.full_like(temp_raw_2d, N2_VALUE, dtype=float)
        )

        # bearing from lat lon if present
        if ("Latitude" in src.variables) and ("Longitude" in src.variables):
            lat_raw_2d = np.asarray(src.variables["Latitude"][time_index], dtype=float)
            lon_raw_2d = np.asarray(src.variables["Longitude"][time_index], dtype=float)
            bearing_raw_2d = compute_bearing_to_x_neighbor_east_ccw(lat_raw_2d, lon_raw_2d)
        else:
            bearing_raw_2d = np.full_like(temp_raw_2d, np.nan, dtype=float)

        # flatten to match tile y dimension
        temp_full_2d = flatten_swath(temp_raw_2d, target_ny=y_tile)
        u_full_2d = flatten_swath(u_raw_2d, target_ny=y_tile)
        v_full_2d = flatten_swath(v_raw_2d, target_ny=y_tile)
        n2_full_2d = flatten_swath(n2_raw_2d, target_ny=y_tile)
        bearing_full_2d = flatten_swath(bearing_raw_2d, target_ny=y_tile)

        n_passed = int(passed_cluster_indices.size)

        with Dataset(dst_l6a, "w") as dst:
            # global attrs
            for aname in src.ncattrs():
                dst.setncattr(aname, src.getncattr(aname))

            # dimensions, subset cluster dim
            for dname, dim in src.dimensions.items():
                if dname == cluster_dim:
                    dst.createDimension(dname, n_passed)
                else:
                    dst.createDimension(dname, (None if dim.isunlimited() else len(dim)))

            # variables copied, subset cluster dim vars
            for vname, vsrc in src.variables.items():
                fill_value = vsrc.getncattr("_FillValue") if "_FillValue" in vsrc.ncattrs() else None
                vdst = dst.createVariable(
                    vname,
                    vsrc.dtype,
                    vsrc.dimensions,
                    zlib=True,
                    complevel=4,
                    fill_value=fill_value,
                )
                for aname in vsrc.ncattrs():
                    if aname != "_FillValue":
                        vdst.setncattr(aname, vsrc.getncattr(aname))

                if cluster_dim in vsrc.dimensions:
                    ax = vsrc.dimensions.index(cluster_dim)
                    data_sub = np.take(vsrc[:], passed_cluster_indices, axis=ax)
                    vdst[:] = data_sub
                else:
                    vdst[:] = vsrc[:]

            # full field Bearing
            bearing_full = np.zeros(temp_shape, dtype=np.float32)
            bearing_full[time_index, 0:y_tile, :] = bearing_full_2d.astype(np.float32)

            if "Bearing" in dst.variables:
                dst.variables["Bearing"][:] = bearing_full
            else:
                vB = dst.createVariable("Bearing", "f4", temp_dims, zlib=True, complevel=4)
                vB.setncattr("long_name", "Geodesic bearing to +x neighbor (0=East, CCW)")
                vB.setncattr("units", "degree")
                vB[:] = bearing_full

            # allocate cluster masked arrays (NaN outside cluster mask)
            temp_cluster = np.full((n_passed, y_tile, x_tile), np.nan, dtype=np.float32)
            u_cluster = np.full_like(temp_cluster, np.nan)
            v_cluster = np.full_like(temp_cluster, np.nan)
            n2_cluster = np.full_like(temp_cluster, np.nan)
            bearing_cluster = np.full_like(temp_cluster, np.nan)

            mf_cluster = np.full_like(temp_cluster, np.nan)
            mf_zonal_cluster = np.full_like(temp_cluster, np.nan)
            mf_meridional_cluster = np.full_like(temp_cluster, np.nan)

            amp_passed = np.asarray(dst.variables["Amplitude"][:], dtype=float)
            lam_passed = np.asarray(dst.variables["DominantWavelength"][:], dtype=float)
            slice_passed = np.asarray(dst.variables["SlicesNo"][:], dtype=int)
            ang_rad_passed = np.asarray(dst.variables["Angle"][:], dtype=float)

            for j in range(n_passed):
                s = int(slice_passed[j])
                x0 = s * x_tile
                x1 = x0 + x_tile

                mask = np.isfinite(amp_passed[j])

                Ttile = temp_full_2d[:, x0:x1]
                Utile = u_full_2d[:, x0:x1]
                Vtile = v_full_2d[:, x0:x1]
                N2tile = n2_full_2d[:, x0:x1]
                Btile = bearing_full_2d[:, x0:x1]

                temp_cluster[j][mask] = Ttile[mask]
                u_cluster[j][mask] = Utile[mask]
                v_cluster[j][mask] = Vtile[mask]
                n2_cluster[j][mask] = N2tile[mask]
                bearing_cluster[j][mask] = Btile[mask]

                A = amp_passed[j]
                Lx = lam_passed[j]
                ang_deg_tile = (np.rad2deg(ang_rad_passed[j]) % 360.0)

                good = mask
                good = good & np.isfinite(Ttile) & np.isfinite(N2tile) & np.isfinite(Lx) & np.isfinite(Btile)
                good = good & (Ttile != 0.0) & (N2tile > 0.0) & (Lx > 0.0)

                if np.any(good):
                    mf_val = (
                        0.5
                        * (G_MS2**2)
                        / N2tile[good]
                        * (LAMBDA_Z_KM / Lx[good])
                        * (A[good] / Ttile[good]) ** 2
                        * (1.0 / (C_CANCEL**2))
                    )
                    mf_cluster[j][good] = mf_val

                    # phi is geographic propagation angle, degrees, 0 East, CCW
                    phi_deg = (Btile[good] + ang_deg_tile[good]) % 360.0
                    phi_rad = np.deg2rad(phi_deg)

                    mf_zonal_cluster[j][good] = mf_val * (np.cos(phi_rad) ** 2)
                    mf_meridional_cluster[j][good] = mf_val * (np.sin(phi_rad) ** 2)

            # write cluster vars
            if "Temp_cluster" in dst.variables:
                dst.variables["Temp_cluster"][:] = temp_cluster
            else:
                v = dst.createVariable("Temp_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                v.setncattr("long_name", "Temperature, cluster masked")
                v.setncattr("units", "K")
                v[:] = temp_cluster

            if "u_cluster" in dst.variables:
                dst.variables["u_cluster"][:] = u_cluster
            else:
                v = dst.createVariable("u_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                v.setncattr("long_name", "u, cluster masked")
                v.setncattr("units", "m s-1")
                v[:] = u_cluster

            if "v_cluster" in dst.variables:
                dst.variables["v_cluster"][:] = v_cluster
            else:
                v = dst.createVariable("v_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                v.setncattr("long_name", "v, cluster masked")
                v.setncattr("units", "m s-1")
                v[:] = v_cluster

            if "NSquared_cluster" in dst.variables:
                dst.variables["NSquared_cluster"][:] = n2_cluster
            else:
                v = dst.createVariable("NSquared_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                v.setncattr("long_name", "N^2, cluster masked")
                v.setncattr("units", "s-2")
                v[:] = n2_cluster

            if "Bearing_cluster" in dst.variables:
                dst.variables["Bearing_cluster"][:] = bearing_cluster
            else:
                vBC = dst.createVariable("Bearing_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                vBC.setncattr("long_name", "Geodesic bearing to +x neighbor (0=East, CCW), cluster masked")
                vBC.setncattr("units", "degree")
                vBC[:] = bearing_cluster

            if "MF_cluster" in dst.variables:
                dst.variables["MF_cluster"][:] = mf_cluster
            else:
                vMF = dst.createVariable("MF_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                vMF.setncattr("long_name", "Momentum flux proxy per pixel, cluster masked")
                vMF.setncattr("units", "m2 s-2")
                vMF[:] = mf_cluster

            if "MF_zonal_cluster" in dst.variables:
                dst.variables["MF_zonal_cluster"][:] = mf_zonal_cluster
            else:
                vMFZ = dst.createVariable("MF_zonal_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                vMFZ.setncattr("long_name", "Zonal aligned MF magnitude share, MF cos^2(phi)")
                vMFZ.setncattr("units", "m2 s-2")
                vMFZ[:] = mf_zonal_cluster

            if "MF_meridional_cluster" in dst.variables:
                dst.variables["MF_meridional_cluster"][:] = mf_meridional_cluster
            else:
                vMFM = dst.createVariable("MF_meridional_cluster", "f4", (cluster_dim, ytile_dim, xtile_dim))
                vMFM.setncattr("long_name", "Meridional aligned MF magnitude share, MF sin^2(phi)")
                vMFM.setncattr("units", "m2 s-2")
                vMFM[:] = mf_meridional_cluster

            # slice sums and stitched top rows
            smin, smax = int(np.min(slice_passed)), int(np.max(slice_passed))
            full_slices = np.arange(smin, smax + 1)

            if "slice" not in dst.dimensions:
                dst.createDimension("slice", len(full_slices))

            if "SliceNo_passed_slices" in dst.variables:
                dst.variables["SliceNo_passed_slices"][:] = full_slices
            else:
                dst.createVariable("SliceNo_passed_slices", "i4", ("slice",))[:] = full_slices

            mf_slice_sum = np.zeros((len(full_slices), y_tile, x_tile), dtype=np.float32)
            mfz_slice_sum = np.zeros_like(mf_slice_sum)
            mfm_slice_sum = np.zeros_like(mf_slice_sum)

            for k, s in enumerate(full_slices):
                idx = np.where(slice_passed == s)[0]
                if idx.size > 0:
                    mf_slice_sum[k] = np.nansum(mf_cluster[idx], axis=0)
                    mfz_slice_sum[k] = np.nansum(mf_zonal_cluster[idx], axis=0)
                    mfm_slice_sum[k] = np.nansum(mf_meridional_cluster[idx], axis=0)

            if "MF_slice_sum" in dst.variables:
                dst.variables["MF_slice_sum"][:] = mf_slice_sum
            else:
                v = dst.createVariable("MF_slice_sum", "f4", ("slice", ytile_dim, xtile_dim))
                v.setncattr("long_name", "Per slice MF sum (passed clusters), tile grid")
                v.setncattr("units", "m2 s-2")
                v[:] = mf_slice_sum

            if "MF_zonal_slice_sum" in dst.variables:
                dst.variables["MF_zonal_slice_sum"][:] = mfz_slice_sum
            else:
                v = dst.createVariable("MF_zonal_slice_sum", "f4", ("slice", ytile_dim, xtile_dim))
                v.setncattr("long_name", "Per slice zonal MF magnitude share sum")
                v.setncattr("units", "m2 s-2")
                v[:] = mfz_slice_sum

            if "MF_meridional_slice_sum" in dst.variables:
                dst.variables["MF_meridional_slice_sum"][:] = mfm_slice_sum
            else:
                v = dst.createVariable("MF_meridional_slice_sum", "f4", ("slice", ytile_dim, xtile_dim))
                v.setncattr("long_name", "Per slice meridional MF magnitude share sum")
                v.setncattr("units", "m2 s-2")
                v[:] = mfm_slice_sum

            MF_toprows = np.zeros(temp_shape, dtype=np.float32)
            MFZ_toprows = np.zeros(temp_shape, dtype=np.float32)
            MFM_toprows = np.zeros(temp_shape, dtype=np.float32)

            for k, s in enumerate(full_slices):
                x0 = s * x_tile
                x1 = x0 + x_tile
                MF_toprows[time_index, 0:y_tile, x0:x1] = mf_slice_sum[k]
                MFZ_toprows[time_index, 0:y_tile, x0:x1] = mfz_slice_sum[k]
                MFM_toprows[time_index, 0:y_tile, x0:x1] = mfm_slice_sum[k]

            if "MF_toprows" in dst.variables:
                dst.variables["MF_toprows"][:] = MF_toprows
            else:
                v = dst.createVariable("MF_toprows", "f4", temp_dims)
                v.setncattr("long_name", "Stitched MF sum (passed clusters) on top tile rows only")
                v.setncattr("units", "m2 s-2")
                v[:] = MF_toprows

            if "MF_zonal_toprows" in dst.variables:
                dst.variables["MF_zonal_toprows"][:] = MFZ_toprows
            else:
                v = dst.createVariable("MF_zonal_toprows", "f4", temp_dims)
                v.setncattr("long_name", "Stitched zonal MF magnitude share, top tile rows only")
                v.setncattr("units", "m2 s-2")
                v[:] = MFZ_toprows

            if "MF_meridional_toprows" in dst.variables:
                dst.variables["MF_meridional_toprows"][:] = MFM_toprows
            else:
                v = dst.createVariable("MF_meridional_toprows", "f4", temp_dims)
                v.setncattr("long_name", "Stitched meridional MF magnitude share, top tile rows only")
                v.setncattr("units", "m2 s-2")
                v[:] = MFM_toprows

        # help Python actually let go of big arrays once the file is written
        del temp_raw_2d, u_raw_2d, v_raw_2d, n2_raw_2d, bearing_raw_2d
        del temp_full_2d, u_full_2d, v_full_2d, n2_full_2d, bearing_full_2d
        del temp_cluster, u_cluster, v_cluster, n2_cluster, bearing_cluster
        del mf_cluster, mf_zonal_cluster, mf_meridional_cluster
        gc.collect()

    return cluster_dim, ytile_dim, xtile_dim


# --------------------------
# Plot per passed cluster panels, memory safe (read one cluster at a time)
# --------------------------
def plot_passed_clusters_panels(nc_path: Path, outdir: Path) -> None:
    """
    Per passed cluster panels, 5 rows x 2 columns

    Row 1  Recon | Amplitude
    Row 2  Lambda | Temperature
    Row 3  Angle deg | Bearing deg
    Row 4  N2 | MF
    Row 5  MF zonal share | MF meridional share
    """
    outdir.mkdir(parents=True, exist_ok=True)

    with Dataset(nc_path, "r") as nc:
        # assume cluster dimension name exists on Amplitude
        cluster_dim = nc.variables["Amplitude"].dimensions[0]
        ytile_dim = nc.variables["Amplitude"].dimensions[1]
        xtile_dim = nc.variables["Amplitude"].dimensions[2]
        n_cluster = nc.dimensions[cluster_dim].size

        slc = np.asarray(nc.variables["SlicesNo"][:], dtype=int)

        ny = nc.dimensions[ytile_dim].size
        nx = nc.dimensions[xtile_dim].size
        x1d_km = np.arange(nx, dtype=float) * DX_KM
        y1d_km = np.arange(ny, dtype=float) * DY_KM

        ang_vmin, ang_vmax = (0.0, 360.0)
        brg_vmin, brg_vmax = (0.0, 360.0)

        n2_center = float(N2_VALUE)
        n2_vmin, n2_vmax = (0.5 * n2_center, 1.5 * n2_center)

        for i in range(n_cluster):
            s = int(slc[i])

            amp = np.asarray(nc.variables["Amplitude"][i], dtype=float)
            lam = np.asarray(nc.variables["DominantWavelength"][i], dtype=float)
            ang_rad = np.asarray(nc.variables["Angle"][i], dtype=float)
            ang_deg = (np.rad2deg(ang_rad) % 360.0)

            brg = (
                np.asarray(nc.variables["Bearing_cluster"][i], dtype=float)
                if "Bearing_cluster" in nc.variables
                else np.full_like(amp, np.nan)
            )
            n2 = np.asarray(nc.variables["NSquared_cluster"][i], dtype=float)
            tmp = np.asarray(nc.variables["Temp_cluster"][i], dtype=float)
            mf = np.asarray(nc.variables["MF_cluster"][i], dtype=float)

            mfz = (
                np.asarray(nc.variables["MF_zonal_cluster"][i], dtype=float)
                if "MF_zonal_cluster" in nc.variables
                else np.full_like(mf, np.nan)
            )
            mfm = (
                np.asarray(nc.variables["MF_meridional_cluster"][i], dtype=float)
                if "MF_meridional_cluster" in nc.variables
                else np.full_like(mf, np.nan)
            )

            if "ClusterReconstruction" in nc.variables:
                recon = np.asarray(nc.variables["ClusterReconstruction"][i], dtype=float)
            else:
                recon = np.full_like(amp, np.nan)

            r_vmin, r_vmax = robust_limits(recon, 2, 98)
            a_vmin, a_vmax = robust_limits(amp, 2, 98)
            l_vmin, l_vmax = robust_limits(lam, 5, 95)
            t_vmin, t_vmax = robust_limits(tmp, 2, 98)

            mf_vmin, mf_vmax = robust_limits(mf, 2, 98)
            mfz_vmin, mfz_vmax = robust_limits(mfz, 2, 98)
            mfm_vmin, mfm_vmax = robust_limits(mfm, 2, 98)

            fig, axs = plt.subplots(
                5, 2,
                figsize=(16, 22),
                constrained_layout=True,
                sharex=True,
                sharey=True,
            )

            def _panel(ax, Z, vmin, vmax, label, cmap=None):
                im = ax.pcolormesh(
                    x1d_km, y1d_km, Z,
                    shading="auto",
                    vmin=vmin,
                    vmax=vmax,
                    cmap=cmap,
                )
                cb = fig.colorbar(im, ax=ax, fraction=0.04, pad=0.02)
                cb.set_label(label)
                ax.set_aspect("equal", adjustable="box")

            axs[0, 0].set_title(f"Passed cluster {i:04d}  SliceNo {s}")

            _panel(axs[0, 0], recon, r_vmin, r_vmax, "Recon", cmap="RdBu_r")
            _panel(axs[0, 1], amp, a_vmin, a_vmax, "Amplitude K")

            _panel(axs[1, 0], lam, l_vmin, l_vmax, "DominantWavelength km")
            _panel(axs[1, 1], tmp, t_vmin, t_vmax, "Temperature K")

            _panel(axs[2, 0], ang_deg, ang_vmin, ang_vmax, "Angle deg propagation")
            _panel(axs[2, 1], brg, brg_vmin, brg_vmax, "Bearing deg 0 East CCW")

            _panel(axs[3, 0], n2, n2_vmin, n2_vmax, "N2 s-2")
            _panel(axs[3, 1], mf, mf_vmin, mf_vmax, "MF m2 s-2")

            _panel(axs[4, 0], mfz, mfz_vmin, mfz_vmax, "MF zonal share cos2")
            _panel(axs[4, 1], mfm, mfm_vmin, mfm_vmax, "MF meridional share sin2")

            for r in range(5):
                axs[r, 0].set_ylabel("y km")
                axs[r, 1].set_ylabel("y km")
            axs[4, 0].set_xlabel("x km")
            axs[4, 1].set_xlabel("x km")

            outpng = outdir / (
                f"passed_cluster_{i:04d}_slice_{s:03d}"
                "_Recon_Amp_Lam_Temp_Ang_Bearing_N2_MF_MFz_MFm.png"
            )
            save_fig(fig, outpng)

            # free per cluster arrays aggressively
            del amp, lam, ang_rad, ang_deg, brg, n2, tmp, mf, mfz, mfm, recon, fig, axs
            gc.collect()

    mpl.pyplot.close("all")
    gc.collect()
    print("Per cluster plots saved to:", outdir.resolve())


def plot_stitched_mf_components(nc_path: Path, outpng: Path, time_index: int) -> None:
    """
    Makes a stitched 3 panel figure

    Panel 1 MF_toprows
    Panel 2 MF_zonal_toprows
    Panel 3 MF_meridional_toprows
    """
    outpng.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(nc_path, "r") as nc:
        MF = np.asarray(nc.variables["MF_toprows"][time_index], dtype=float)
        MFZ = np.asarray(nc.variables["MF_zonal_toprows"][time_index], dtype=float)
        MFM = np.asarray(nc.variables["MF_meridional_toprows"][time_index], dtype=float)

    ny, nx = MF.shape
    x1d_km = np.arange(nx, dtype=float) * DX_KM
    y1d_km = np.arange(ny, dtype=float) * DY_KM

    stacked = np.concatenate([MF.ravel(), MFZ.ravel(), MFM.ravel()])
    vmin, vmax = robust_limits(stacked, 2, 99.9)

    fig, axs = plt.subplots(3, 1, figsize=(22, 8), constrained_layout=True, sharex=True, sharey=True)

    im0 = axs[0].pcolormesh(x1d_km, y1d_km, MF, shading="auto", vmin=vmin, vmax=vmax)
    axs[0].set_title("Stitched MF passed clusters summed")
    axs[0].set_ylabel("y km")
    axs[0].set_aspect("equal", adjustable="box")

    im1 = axs[1].pcolormesh(x1d_km, y1d_km, MFZ, shading="auto", vmin=vmin, vmax=vmax)
    axs[1].set_title("Stitched MF zonal share cos2")
    axs[1].set_ylabel("y km")
    axs[1].set_aspect("equal", adjustable="box")

    im2 = axs[2].pcolormesh(x1d_km, y1d_km, MFM, shading="auto", vmin=vmin, vmax=vmax)
    axs[2].set_title("Stitched MF meridional share sin2")
    axs[2].set_xlabel("x km")
    axs[2].set_ylabel("y km")
    axs[2].set_aspect("equal", adjustable="box")

    for ax in axs:
        ax.set_ylim(0, 600)

    cbar = fig.colorbar(im2, ax=axs, fraction=0.02, pad=0.01)
    cbar.set_label("MF m2 s-2")

    save_fig(fig, outpng)

    del MF, MFZ, MFM, stacked, fig, axs
    gc.collect()


# --------------------------
# Main: matching -> passed clusters -> output passed-only netCDF -> stitched MF plot
# --------------------------
l6c = load_l6_for_matching(L6C_PATH)
l6a_match = load_l6_for_matching(L6A_PATH)

all_slices_a = np.unique(l6a_match["SlicesNo"]).astype(int)
all_slices_a = all_slices_a[all_slices_a >= 0]
all_slices_a = np.sort(all_slices_a)

print("Slices in L6A:", all_slices_a.tolist())

summary_lines: List[str] = []
summary_lines.append(f"L6A: {L6A_PATH}\n")
summary_lines.append(f"L6C: {L6C_PATH}\n\n")
summary_lines.append("slice  nA  nC  nBestSaved  nPassed  note\n")

passed_global_indices: List[int] = []

for slice_no in all_slices_a:
    idx_a = np.where(l6a_match["SlicesNo"] == int(slice_no))[0]
    idx_c = np.where(l6c["SlicesNo"] == int(slice_no))[0]

    slice_dir = OUTDIR / f"slice_{slice_no:03d}"
    pairs_dir = slice_dir / "pairs"
    pairs_dir.mkdir(parents=True, exist_ok=True)

    if idx_a.size == 0:
        summary_lines.append(f"{slice_no:5d}  {0:2d}  {idx_c.size:2d}  {0:10d}  {0:7d}  no L6A clusters\n")
        continue
    if idx_c.size == 0:
        (slice_dir / "NO_L6C_CLUSTERS.txt").write_text(f"No L6C clusters for slice {slice_no}\n")
        summary_lines.append(f"{slice_no:5d}  {idx_a.size:2d}  {0:2d}  {0:10d}  {0:7d}  no L6C clusters\n")
        continue

    best_rows: List[Dict[str, Any]] = []

    # Stream candidate lines instead of storing giant lists of dicts
    cand_lines: List[str] = []
    cand_header = []
    cand_header.append(f"L6A file: {L6A_PATH}\n")
    cand_header.append(f"L6C file: {L6C_PATH}\n")
    cand_header.append(f"Slice: {slice_no}\n\n")
    cand_header.append(
        "cluster_a  cluster_c  passes  score    iou    inter  "
        "lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
    )

    for a_idx in idx_a:
        a_idx = int(a_idx)
        A_a = l6a_match["Amplitude"][a_idx]
        L_a = l6a_match["DominantWavelength"][a_idx]
        T_a = l6a_match["Angle"][a_idx]

        candidates: List[Dict[str, Any]] = []
        for c_idx in idx_c:
            c_idx = int(c_idx)
            A_c = l6c["Amplitude"][c_idx]
            L_c = l6c["DominantWavelength"][c_idx]
            T_c = l6c["Angle"][c_idx]

            m = compute_match_metrics(A_a, L_a, T_a, A_c, L_c, T_c)
            m["cluster_a"] = a_idx
            m["cluster_c"] = c_idx
            m["passes"] = bool(passes_thresholds(m))
            m["score"] = float(score(m))

            candidates.append(m)

            cand_lines.append(
                f"{m['cluster_a']:9d}  {m['cluster_c']:9d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
                f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
                f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
                f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
                f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
            )

        passed = [c for c in candidates if c["passes"]]
        if passed:
            best = max(passed, key=lambda d: d["score"])
        else:
            best = max(candidates, key=lambda d: d["score"])

        if best["passes"] or ASSIGN_BEST_EVEN_IF_FAILS:
            best_rows.append(best)

            # Lazy map loads include ClusterReconstruction only for these two indices
            left_maps = get_cluster_maps(l6a_match, best["cluster_a"])
            right_maps = get_cluster_maps(l6c, best["cluster_c"])

            pass_tag = "PASS" if best["passes"] else "FAIL"
            outpng = pairs_dir / f"slice_{slice_no:03d}_A_{best['cluster_a']:04d}_to_C_{best['cluster_c']:04d}_{pass_tag}.png"

            title_left = (
                f"L6A Temp | slice {slice_no} | idx {best['cluster_a']} | "
                f"n={np.count_nonzero(np.isfinite(left_maps['A']))}"
            )
            title_right = (
                f"L6C Rad | slice {slice_no} | idx {best['cluster_c']} | "
                f"IoU={best['iou']:.3f} inter={best['n_intersection']} "
                f"ratio={best['lam_ratio']:.3f} Δθ={best['ang_diff_deg']:.1f}°"
            )

            plot_side_by_side_4rows(
                left=left_maps,
                right=right_maps,
                title_left=title_left,
                title_right=title_right,
                outpath=outpng,
                dx_km=DX_KM,
                dy_km=DY_KM,
            )

            # free per plot
            del left_maps, right_maps
            gc.collect()

        del candidates
        gc.collect()

    cand_path = slice_dir / f"slice_{slice_no:03d}_ALL_candidates_ratio.txt"
    cand_path.write_text("".join(cand_header) + "".join(cand_lines))
    del cand_lines
    gc.collect()

    best_path = slice_dir / f"slice_{slice_no:03d}_BEST_matches_A_to_C_ratio.txt"
    best_lines = []
    best_lines.append(f"L6A file: {L6A_PATH}\n")
    best_lines.append(f"L6C file: {L6C_PATH}\n")
    best_lines.append(f"Slice: {slice_no}\n\n")
    best_lines.append(
        "cluster_a  best_cluster_c  passes  score    iou    inter  "
        "lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
    )
    for m in sorted(best_rows, key=lambda d: d["cluster_a"]):
        best_lines.append(
            f"{m['cluster_a']:9d}  {m['cluster_c']:14d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
            f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
            f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
            f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
            f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
        )
    best_path.write_text("".join(best_lines))

    passed_here = [int(m["cluster_a"]) for m in best_rows if bool(m["passes"])]
    passed_global_indices.extend(passed_here)

    summary_lines.append(
        f"{slice_no:5d}  {idx_a.size:2d}  {idx_c.size:2d}  {len(best_rows):10d}  {len(passed_here):7d}  ok\n"
    )

    del best_rows, best_lines
    gc.collect()

summary_path = OUTDIR / "SUMMARY_all_slices.txt"
summary_path.write_text("".join(summary_lines))

passed_global_indices = sorted(set(passed_global_indices))
passed_global_indices_np = np.asarray(passed_global_indices, dtype=int)
print("Total passed clusters:", passed_global_indices_np.size)

if passed_global_indices_np.size == 0:
    raise RuntimeError("No passed clusters found. Nothing to save or stitch.")

cluster_dim_name, ytile_dim_name, xtile_dim_name = create_passed_only_l6a_with_new_vars(
    src_l6a=L6A_PATH,
    dst_l6a=OUT_L6A_PASSED,
    passed_cluster_indices=passed_global_indices_np,
    time_index=TIME_INDEX,
)

# plot stitched MF quicklook (single panel)
with Dataset(OUT_L6A_PASSED, "r") as nc:
    MF2 = np.asarray(nc.variables["MF_toprows"][TIME_INDEX], dtype=float)
    ny, nx = MF2.shape
    x1d_km = np.arange(nx, dtype=float) * DX_KM
    y1d_km = np.arange(ny, dtype=float) * DY_KM

    vmin, vmax = robust_limits(MF2, 2, 99.9)

    fig, ax = plt.subplots(figsize=(22, 3), constrained_layout=True)
    im = ax.pcolormesh(x1d_km, y1d_km, MF2, shading="auto", vmin=vmin, vmax=vmax)
    ax.set_title("Momentum Flux (passed clusters summed)")
    ax.set_xlabel("x (km)")
    ax.set_ylabel("y (km)")
    ax.set_ylim(0, 600)
    ax.set_aspect("equal", adjustable="box")
    fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01).set_label("MF (m2 s-2)")
    save_fig(fig, OUTDIR / "MF_stitched.png")

del MF2, fig, ax
gc.collect()

# heavy plotting
plot_passed_clusters_panels(
    nc_path=OUT_L6A_PASSED,
    outdir=OUTDIR / "passed_cluster_plots_panels",
)

plot_stitched_mf_components(
    nc_path=OUT_L6A_PASSED,
    outpng=OUTDIR / "MF_stitched_components.png",
    time_index=TIME_INDEX,
)

# final cleanup
del l6c, l6a_match, passed_global_indices_np
mpl.pyplot.close("all")
gc.collect()

print("\nDone.")
print("Outputs in:", OUTDIR.resolve())
print("Summary:", summary_path.resolve())
print("PASSED-only augmented L6A:", OUT_L6A_PASSED.resolve())
print("New vars in output: Bearing, Bearing_cluster, Temp_cluster, u_cluster, v_cluster, NSquared_cluster, MF_cluster, MF_slice_sum, MF_toprows")
# Out:
# Slices in L6A: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Total passed clusters: 28
# Per cluster plots saved to: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF/passed_cluster_plots_panels
#
# Done.
# Outputs in: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF
# Summary: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF/SUMMARY_all_slices.txt
# PASSED-only augmented L6A: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF/awe_l6a_tmp_2024165T2120_03175_v01_PASSED_with_u_v_NS2_Bearing_TempCluster_MF.nc
# New vars in output: Bearing, Bearing_cluster, Temp_cluster, u_cluster, v_cluster, NSquared_cluster, MF_cluster, MF_slice_sum, MF_toprows

# %% [markdown]
# 221 s

# %% [markdown]
# ## Skip Saving Plots

# %%
# %%
"""
ALL-SLICES matching + per-slice combined L6A recon + FULL-ORBIT stitched recon
+ slice Temperature + momentum flux for PASSED clusters only
+ sum MF per slice + stitch MF across orbit
+ output NetCDF contains original L6A global attrs + variables, but ONLY PASSED clusters
  are kept for cluster-dimension variables.

Momentum flux (per cluster pixel, masked to cluster area):
MF = 1/2 * g^2 / N^2 * (lambda_z / lambda_x) * (Amplitude / Temperature)^2 * (1/c^2)

Key rules:
- SliceNo already exists in L6A, keep it (but subset to passed clusters)
- Area, Amplitude, DominantWavelength, Angle already exist (subset to passed clusters)
- Also slice Temperature into Temp_cluster (passed clusters only)
- Add geodesic Bearing (0 = East, counter-clockwise) as Bearing + Bearing_cluster
- Only save passed clusters (output file cluster vars are subset)
- Add MF_cluster, MF_slice_sum, MF_toprows
"""

from __future__ import annotations

from pathlib import Path
from typing import Dict, Any, List, Tuple

import gc
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from netCDF4 import Dataset

# --------------------------
# User params
# --------------------------
L6C_PATH = Path("awe_l6c_q20_2024165T2120_03175_v01.nc")  # Radiance-based clusters
L6A_PATH = Path("awe_l6a_tmp_2024165T2120_03175_v01.nc")  # Temperature-based clusters

OUTDIR = Path("outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF")
OUTDIR.mkdir(parents=True, exist_ok=True)
SAVE_DPI = 200

DX_KM = 2.0
DY_KM = 2.0

# ---- Synthetic u,v,N^2 settings ----
TEMP_VAR_NAME = "Temperature"  # variable name in L6A
TIME_INDEX = 0                 # which t index to use when slicing
N2_VALUE = 4e-4                # N=0.02 -> N^2=0.0004
U_VALUE = 0.0
V_VALUE = 0.0

# ---- Momentum flux constants ----
G_MS2 = 9.52
LAMBDA_Z_KM = 10.0
C_CANCEL = 1.0

# Output NetCDF
OUT_L6A_PASSED = OUTDIR / f"{L6A_PATH.stem}_PASSED_with_u_v_NS2_Bearing_TempCluster_MF.nc"

# --------------------------
# Matching thresholds (tune)
# --------------------------
MIN_IOU = 0.05
MIN_INTERSECTION_PIX = 50
MAX_LAMBDA_MED_RATIO = 1.25
MAX_ANGLE_DIFF_DEG = 15.0

# Save best match selection even if FAIL (does NOT affect passing)
ASSIGN_BEST_EVEN_IF_FAILS = True

# --------------------------
# Plot saving switches
# --------------------------
SAVE_PAIR_PLOTS = False          # side-by-side A vs C match PNGs per slice
SAVE_PER_CLUSTER_PANELS = False  # big 5x2 panels for every passed cluster
SAVE_STITCHED_PLOTS = True       # MF_stitched.png + MF_stitched_components.png

# --------------------------
# Helpers
# --------------------------
def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def robust_limits(A: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    a = np.asarray(A)
    good = np.isfinite(a)
    if not np.any(good):
        return (-1.0, 1.0)
    lo, hi = np.nanpercentile(a[good], [p_lo, p_hi])
    if (not np.isfinite(lo)) or (not np.isfinite(hi)) or lo == hi:
        lo = float(np.nanmin(a[good]))
        hi = float(np.nanmax(a[good]))
    return (float(lo), float(hi))


def nanpercentile_safe(a: np.ndarray, q: float) -> float:
    good = np.isfinite(a)
    if not np.any(good):
        return np.nan
    return float(np.nanpercentile(a[good], q))


def circ_diff_deg_180(a_deg: float, b_deg: float) -> float:
    if (not np.isfinite(a_deg)) or (not np.isfinite(b_deg)):
        return np.nan
    d = abs(a_deg - b_deg) % 180.0
    return min(d, 180.0 - d)


def circ_median_deg_180(theta_rad: np.ndarray, mask: np.ndarray) -> float:
    th = np.asarray(theta_rad, dtype=float)
    m = mask & np.isfinite(th)
    if not np.any(m):
        return np.nan
    ang = th[m]
    z = np.exp(1j * 2.0 * ang)
    zmean = np.mean(z)
    if (not np.isfinite(zmean.real)) or (not np.isfinite(zmean.imag)) or abs(zmean) == 0:
        return np.nan
    th_mean = 0.5 * np.angle(zmean)
    deg = (np.degrees(th_mean) + 180.0) % 180.0
    return float(deg)


# -------------------------
# Geodesic bearing: 0 = East, counter-clockwise (CCW)
# -------------------------
def initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    """
    Vectorized initial bearing (forward azimuth) from (lat1, lon1) to (lat2, lon2).
    Returns azimuth degrees in [0, 360) measured from North, clockwise.
    """
    lat1 = np.deg2rad(lat1_deg)
    lon1 = np.deg2rad(lon1_deg)
    lat2 = np.deg2rad(lat2_deg)
    lon2 = np.deg2rad(lon2_deg)

    dlon = lon2 - lon1
    x = np.sin(dlon) * np.cos(lat2)
    y = np.cos(lat1) * np.sin(lat2) - np.sin(lat1) * np.cos(lat2) * np.cos(dlon)

    az = np.arctan2(x, y)
    az_deg = (np.rad2deg(az) + 360.0) % 360.0
    return az_deg


def bearing_deg_east_ccw_from_points(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    """
    Convert azimuth (North=0, CW) into your convention:
    East=0 and increasing counter-clockwise (CCW).
    East-CCW angle = (90 - az_north_cw) mod 360
    """
    az_north_cw = initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg)
    return (90.0 - az_north_cw) % 360.0


def compute_bearing_to_x_neighbor_east_ccw(lat2d: np.ndarray, lon2d: np.ndarray) -> np.ndarray:
    """
    Bearing at each pixel to its +x neighbor (last column uses -x neighbor),
    in degrees: 0=East, CCW positive.
    """
    lat = np.asarray(lat2d, dtype=float)
    lon = np.asarray(lon2d, dtype=float)
    ny, nx = lat.shape

    lat2 = np.empty_like(lat)
    lon2 = np.empty_like(lon)

    lat2[:, :-1] = lat[:, 1:]
    lon2[:, :-1] = lon[:, 1:]
    lat2[:, -1] = lat[:, -2]
    lon2[:, -1] = lon[:, -2]

    bearing = bearing_deg_east_ccw_from_points(lat, lon, lat2, lon2)

    good = np.isfinite(lat) & np.isfinite(lon) & np.isfinite(lat2) & np.isfinite(lon2)
    return np.where(good, bearing, np.nan)


# --------------------------
# IO: load only variables needed for matching (no ClusterReconstruction here)
# --------------------------
def load_l6_for_matching(path: Path) -> Dict[str, Any]:
    with Dataset(path, "r") as nc:
        return {
            "path": str(path),
            "SlicesNo": np.asarray(nc.variables["SlicesNo"][:], dtype=int),
            "Amplitude": np.asarray(nc.variables["Amplitude"][:], dtype=float),
            "DominantWavelength": np.asarray(nc.variables["DominantWavelength"][:], dtype=float),
            "Angle": np.asarray(nc.variables["Angle"][:], dtype=float),
        }


def get_cluster_maps(data: Dict[str, Any], idx: int) -> Dict[str, np.ndarray]:
    """
    Lazy load ClusterReconstruction only for the requested idx.
    """
    A = np.asarray(data["Amplitude"][idx], dtype=float)
    L = np.asarray(data["DominantWavelength"][idx], dtype=float)
    T = np.asarray(data["Angle"][idx], dtype=float)

    R = np.full_like(A, np.nan)
    with Dataset(data["path"], "r") as nc:
        if "ClusterReconstruction" in nc.variables:
            R = np.asarray(nc.variables["ClusterReconstruction"][idx], dtype=float)

    return dict(R=R, A=A, L=L, T=T)


def compute_match_metrics(
    A_src: np.ndarray, L_src: np.ndarray, T_src: np.ndarray,
    A_cand: np.ndarray, L_cand: np.ndarray, T_cand: np.ndarray,
) -> Dict[str, Any]:
    mask_src = np.isfinite(A_src)
    mask_cand = np.isfinite(A_cand)
    inter = mask_src & mask_cand
    union = mask_src | mask_cand

    n_inter = int(np.count_nonzero(inter))
    n_union = int(np.count_nonzero(union))
    iou = (n_inter / n_union) if n_union > 0 else 0.0

    lam_src = L_src[inter]
    lam_cand = L_cand[inter]
    lam_src_med = nanpercentile_safe(lam_src, 50)
    lam_cand_med = nanpercentile_safe(lam_cand, 50)

    if np.isfinite(lam_src_med) and np.isfinite(lam_cand_med) and lam_src_med > 0 and lam_cand_med > 0:
        lam_ratio = max(lam_src_med, lam_cand_med) / min(lam_src_med, lam_cand_med)
    else:
        lam_ratio = np.nan

    ang_src_deg = circ_median_deg_180(T_src, inter)
    ang_cand_deg = circ_median_deg_180(T_cand, inter)
    ang_diff_deg = circ_diff_deg_180(ang_src_deg, ang_cand_deg)

    return dict(
        n_intersection=n_inter,
        iou=float(iou),
        lam_src_med=float(lam_src_med),
        lam_cand_med=float(lam_cand_med),
        lam_ratio=float(lam_ratio),
        ang_src_deg=float(ang_src_deg),
        ang_cand_deg=float(ang_cand_deg),
        ang_diff_deg=float(ang_diff_deg),
    )


def passes_thresholds(m: Dict[str, Any]) -> bool:
    if m["iou"] < MIN_IOU:
        return False
    if m["n_intersection"] < MIN_INTERSECTION_PIX:
        return False
    if (not np.isfinite(m["lam_ratio"])) or (m["lam_ratio"] > MAX_LAMBDA_MED_RATIO):
        return False
    if (not np.isfinite(m["ang_diff_deg"])) or (m["ang_diff_deg"] > MAX_ANGLE_DIFF_DEG):
        return False
    return True


def score(m: Dict[str, Any]) -> float:
    ang = m["ang_diff_deg"]
    if not np.isfinite(ang):
        ang = 999.0
    r = m["lam_ratio"]
    if (not np.isfinite(r)) or r <= 0:
        return 0.0
    return float(m["iou"]) * (1.0 / float(r)) / (1.0 + float(ang))


def plot_side_by_side_4rows(
    left: Dict[str, np.ndarray],
    right: Dict[str, np.ndarray],
    title_left: str,
    title_right: str,
    outpath: Path,
    dx_km: float,
    dy_km: float,
) -> None:
    ny, nx = left["A"].shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    Rl_vmin, Rl_vmax = robust_limits(left["R"])
    Rr_vmin, Rr_vmax = robust_limits(right["R"])
    Al_vmin, Al_vmax = robust_limits(left["A"])
    Ar_vmin, Ar_vmax = robust_limits(right["A"])

    L_vmin, L_vmax = robust_limits(np.concatenate([left["L"].ravel(), right["L"].ravel()]), 5, 95)
    T_vmin, T_vmax = robust_limits(np.concatenate([left["T"].ravel(), right["T"].ravel()]))

    fig, axs = plt.subplots(4, 2, figsize=(16, 14), constrained_layout=True, sharex=True, sharey=True)

    def _panel(ax, Z, vmin, vmax, label, cmap=None):
        im = ax.pcolormesh(x1d_km, y1d_km, Z, shading="auto", vmin=vmin, vmax=vmax, cmap=cmap)
        cb = fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01)
        cb.set_label(label)
        ax.set_aspect("equal", adjustable="box")

    axs[0, 0].set_title(title_left)
    axs[0, 1].set_title(title_right)

    _panel(axs[0, 0], left["R"], Rl_vmin, Rl_vmax, "arb", cmap="RdBu_r")
    _panel(axs[0, 1], right["R"], Rr_vmin, Rr_vmax, "arb", cmap="RdBu_r")
    axs[0, 0].set_ylabel("Recon\ny (km)")

    _panel(axs[1, 0], left["A"], Al_vmin, Al_vmax, "K")
    _panel(axs[1, 1], right["A"], Ar_vmin, Ar_vmax, "kR")
    axs[1, 0].set_ylabel("Amp\ny (km)")

    _panel(axs[2, 0], left["L"], L_vmin, L_vmax, "km")
    _panel(axs[2, 1], right["L"], L_vmin, L_vmax, "km")
    axs[2, 0].set_ylabel("Lambda\ny (km)")

    _panel(axs[3, 0], left["T"], T_vmin, T_vmax, "rad")
    _panel(axs[3, 1], right["T"], T_vmin, T_vmax, "rad")
    axs[3, 0].set_ylabel("Angle\ny (km)")

    for r in range(4):
        for c in range(2):
            axs[r, c].set_xlabel("x (km)")

    save_fig(fig, outpath)


# --------------------------
# Flatten swath BEFORE slicing
# --------------------------
def flatten_swath(Z: np.ndarray, target_ny: int | None = None) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


# --------------------------
# L6A cloning with PASSED-only cluster variables + new vars (u,v,N^2,Bearing, MF)
# --------------------------
def create_passed_only_l6a_with_new_vars(
    src_l6a: Path,
    dst_l6a: Path,
    passed_cluster_indices: np.ndarray,
    time_index: int,
) -> Tuple[str, str, str]:
    passed_cluster_indices = np.asarray(passed_cluster_indices, dtype=int)
    if passed_cluster_indices.size == 0:
        raise ValueError("No passed clusters. Output would be empty.")

    dst_l6a.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(src_l6a, "r") as src:
        amp_var = src.variables["Amplitude"]
        cluster_dim, ytile_dim, xtile_dim = amp_var.dimensions[:3]
        _, y_tile, x_tile = amp_var.shape

        temp_var = src.variables[TEMP_VAR_NAME]
        temp_dims = temp_var.dimensions
        temp_shape = temp_var.shape
        temp_raw_2d = np.asarray(temp_var[time_index], dtype=float)

        u_raw_2d = (
            np.asarray(src.variables["u"][time_index], dtype=float)
            if "u" in src.variables
            else np.full_like(temp_raw_2d, U_VALUE, dtype=float)
        )
        v_raw_2d = (
            np.asarray(src.variables["v"][time_index], dtype=float)
            if "v" in src.variables
            else np.full_like(temp_raw_2d, V_VALUE, dtype=float)
        )
        n2_raw_2d = (
            np.asarray(src.variables["NSquared"][time_index], dtype=float)
            if "NSquared" in src.variables
            else np.full_like(temp_raw_2d, N2_VALUE, dtype=float)
        )

        if ("Latitude" in src.variables) and ("Longitude" in src.variables):
            lat_raw_2d = np.asarray(src.variables["Latitude"][time_index], dtype=float)
            lon_raw_2d = np.asarray(src.variables["Longitude"][time_index], dtype=float)
            bearing_raw_2d = compute_bearing_to_x_neighbor_east_ccw(lat_raw_2d, lon_raw_2d)
        else:
            bearing_raw_2d = np.full_like(temp_raw_2d, np.nan, dtype=float)

        temp_full_2d = flatten_swath(temp_raw_2d, target_ny=y_tile)
        u_full_2d = flatten_swath(u_raw_2d, target_ny=y_tile)
        v_full_2d = flatten_swath(v_raw_2d, target_ny=y_tile)
        n2_full_2d = flatten_swath(n2_raw_2d, target_ny=y_tile)
        bearing_full_2d = flatten_swath(bearing_raw_2d, target_ny=y_tile)

        n_passed = int(passed_cluster_indices.size)

        with Dataset(dst_l6a, "w") as dst:
            for aname in src.ncattrs():
                dst.setncattr(aname, src.getncattr(aname))

            for dname, dim in src.dimensions.items():
                if dname == cluster_dim:
                    dst.createDimension(dname, n_passed)
                else:
                    dst.createDimension(dname, (None if dim.isunlimited() else len(dim)))

            for vname, vsrc in src.variables.items():
                fill_value = vsrc.getncattr("_FillValue") if "_FillValue" in vsrc.ncattrs() else None
                vdst = dst.createVariable(
                    vname,
                    vsrc.dtype,
                    vsrc.dimensions,
                    zlib=True,
                    complevel=4,
                    fill_value=fill_value,
                )
                for aname in vsrc.ncattrs():
                    if aname != "_FillValue":
                        vdst.setncattr(aname, vsrc.getncattr(aname))

                if cluster_dim in vsrc.dimensions:
                    ax = vsrc.dimensions.index(cluster_dim)
                    data_sub = np.take(vsrc[:], passed_cluster_indices, axis=ax)
                    vdst[:] = data_sub
                else:
                    vdst[:] = vsrc[:]

            bearing_full = np.zeros(temp_shape, dtype=np.float32)
            bearing_full[time_index, 0:y_tile, :] = bearing_full_2d.astype(np.float32)

            if "Bearing" in dst.variables:
                dst.variables["Bearing"][:] = bearing_full
            else:
                vB = dst.createVariable("Bearing", "f4", temp_dims, zlib=True, complevel=4)
                vB.setncattr("long_name", "Geodesic bearing to +x neighbor (0=East, CCW)")
                vB.setncattr("units", "degree")
                vB[:] = bearing_full

            temp_cluster = np.full((n_passed, y_tile, x_tile), np.nan, dtype=np.float32)
            u_cluster = np.full_like(temp_cluster, np.nan)
            v_cluster = np.full_like(temp_cluster, np.nan)
            n2_cluster = np.full_like(temp_cluster, np.nan)
            bearing_cluster = np.full_like(temp_cluster, np.nan)

            mf_cluster = np.full_like(temp_cluster, np.nan)
            mf_zonal_cluster = np.full_like(temp_cluster, np.nan)
            mf_meridional_cluster = np.full_like(temp_cluster, np.nan)

            amp_passed = np.asarray(dst.variables["Amplitude"][:], dtype=float)
            lam_passed = np.asarray(dst.variables["DominantWavelength"][:], dtype=float)
            slice_passed = np.asarray(dst.variables["SlicesNo"][:], dtype=int)
            ang_rad_passed = np.asarray(dst.variables["Angle"][:], dtype=float)

            for j in range(n_passed):
                s = int(slice_passed[j])
                x0 = s * x_tile
                x1 = x0 + x_tile

                mask = np.isfinite(amp_passed[j])

                Ttile = temp_full_2d[:, x0:x1]
                Utile = u_full_2d[:, x0:x1]
                Vtile = v_full_2d[:, x0:x1]
                N2tile = n2_full_2d[:, x0:x1]
                Btile = bearing_full_2d[:, x0:x1]

                temp_cluster[j][mask] = Ttile[mask]
                u_cluster[j][mask] = Utile[mask]
                v_cluster[j][mask] = Vtile[mask]
                n2_cluster[j][mask] = N2tile[mask]
                bearing_cluster[j][mask] = Btile[mask]

                A = amp_passed[j]
                Lx = lam_passed[j]
                ang_deg_tile = (np.rad2deg(ang_rad_passed[j]) % 360.0)

                good = mask
                good = good & np.isfinite(Ttile) & np.isfinite(N2tile) & np.isfinite(Lx) & np.isfinite(Btile)
                good = good & (Ttile != 0.0) & (N2tile > 0.0) & (Lx > 0.0)

                if np.any(good):
                    mf_val = (
                        0.5
                        * (G_MS2**2)
                        / N2tile[good]
                        * (LAMBDA_Z_KM / Lx[good])
                        * (A[good] / Ttile[good]) ** 2
                        * (1.0 / (C_CANCEL**2))
                    )
                    mf_cluster[j][good] = mf_val

                    phi_deg = (Btile[good] + ang_deg_tile[good]) % 360.0
                    phi_rad = np.deg2rad(phi_deg)

                    mf_zonal_cluster[j][good] = mf_val * (np.cos(phi_rad) ** 2)
                    mf_meridional_cluster[j][good] = mf_val * (np.sin(phi_rad) ** 2)

            def _write(name: str, arr: np.ndarray, dims: Tuple[str, ...], long_name: str, units: str):
                if name in dst.variables:
                    dst.variables[name][:] = arr
                else:
                    v = dst.createVariable(name, "f4", dims)
                    v.setncattr("long_name", long_name)
                    v.setncattr("units", units)
                    v[:] = arr

            _write("Temp_cluster", temp_cluster, (cluster_dim, ytile_dim, xtile_dim), "Temperature, cluster masked", "K")
            _write("u_cluster", u_cluster, (cluster_dim, ytile_dim, xtile_dim), "u, cluster masked", "m s-1")
            _write("v_cluster", v_cluster, (cluster_dim, ytile_dim, xtile_dim), "v, cluster masked", "m s-1")
            _write("NSquared_cluster", n2_cluster, (cluster_dim, ytile_dim, xtile_dim), "N^2, cluster masked", "s-2")
            _write("Bearing_cluster", bearing_cluster, (cluster_dim, ytile_dim, xtile_dim), "Bearing (0=East, CCW), cluster masked", "degree")
            _write("MF_cluster", mf_cluster, (cluster_dim, ytile_dim, xtile_dim), "MF proxy per pixel, cluster masked", "m2 s-2")
            _write("MF_zonal_cluster", mf_zonal_cluster, (cluster_dim, ytile_dim, xtile_dim), "MF zonal share, cos^2(phi)", "m2 s-2")
            _write("MF_meridional_cluster", mf_meridional_cluster, (cluster_dim, ytile_dim, xtile_dim), "MF meridional share, sin^2(phi)", "m2 s-2")

            smin, smax = int(np.min(slice_passed)), int(np.max(slice_passed))
            full_slices = np.arange(smin, smax + 1)

            if "slice" not in dst.dimensions:
                dst.createDimension("slice", len(full_slices))
            if "SliceNo_passed_slices" not in dst.variables:
                dst.createVariable("SliceNo_passed_slices", "i4", ("slice",))[:] = full_slices
            else:
                dst.variables["SliceNo_passed_slices"][:] = full_slices

            mf_slice_sum = np.zeros((len(full_slices), y_tile, x_tile), dtype=np.float32)
            mfz_slice_sum = np.zeros_like(mf_slice_sum)
            mfm_slice_sum = np.zeros_like(mf_slice_sum)

            for k, s in enumerate(full_slices):
                idx = np.where(slice_passed == s)[0]
                if idx.size > 0:
                    mf_slice_sum[k] = np.nansum(mf_cluster[idx], axis=0)
                    mfz_slice_sum[k] = np.nansum(mf_zonal_cluster[idx], axis=0)
                    mfm_slice_sum[k] = np.nansum(mf_meridional_cluster[idx], axis=0)

            _write("MF_slice_sum", mf_slice_sum, ("slice", ytile_dim, xtile_dim), "Per slice MF sum (passed clusters), tile grid", "m2 s-2")
            _write("MF_zonal_slice_sum", mfz_slice_sum, ("slice", ytile_dim, xtile_dim), "Per slice zonal MF sum (passed clusters)", "m2 s-2")
            _write("MF_meridional_slice_sum", mfm_slice_sum, ("slice", ytile_dim, xtile_dim), "Per slice meridional MF sum (passed clusters)", "m2 s-2")

            MF_toprows = np.zeros(temp_shape, dtype=np.float32)
            MFZ_toprows = np.zeros(temp_shape, dtype=np.float32)
            MFM_toprows = np.zeros(temp_shape, dtype=np.float32)

            for k, s in enumerate(full_slices):
                x0 = s * x_tile
                x1 = x0 + x_tile
                MF_toprows[time_index, 0:y_tile, x0:x1] = mf_slice_sum[k]
                MFZ_toprows[time_index, 0:y_tile, x0:x1] = mfz_slice_sum[k]
                MFM_toprows[time_index, 0:y_tile, x0:x1] = mfm_slice_sum[k]

            _write("MF_toprows", MF_toprows, temp_dims, "Stitched MF sum (passed clusters) on top tile rows only", "m2 s-2")
            _write("MF_zonal_toprows", MFZ_toprows, temp_dims, "Stitched zonal MF share on top tile rows only", "m2 s-2")
            _write("MF_meridional_toprows", MFM_toprows, temp_dims, "Stitched meridional MF share on top tile rows only", "m2 s-2")

        del temp_raw_2d, u_raw_2d, v_raw_2d, n2_raw_2d, bearing_raw_2d
        del temp_full_2d, u_full_2d, v_full_2d, n2_full_2d, bearing_full_2d
        del temp_cluster, u_cluster, v_cluster, n2_cluster, bearing_cluster
        del mf_cluster, mf_zonal_cluster, mf_meridional_cluster
        gc.collect()

    return cluster_dim, ytile_dim, xtile_dim


def plot_passed_clusters_panels(nc_path: Path, outdir: Path) -> None:
    """
    Memory safe: read one cluster at a time.
    """
    outdir.mkdir(parents=True, exist_ok=True)

    with Dataset(nc_path, "r") as nc:
        cluster_dim = nc.variables["Amplitude"].dimensions[0]
        ytile_dim = nc.variables["Amplitude"].dimensions[1]
        xtile_dim = nc.variables["Amplitude"].dimensions[2]
        n_cluster = nc.dimensions[cluster_dim].size

        slc = np.asarray(nc.variables["SlicesNo"][:], dtype=int)

        ny = nc.dimensions[ytile_dim].size
        nx = nc.dimensions[xtile_dim].size
        x1d_km = np.arange(nx, dtype=float) * DX_KM
        y1d_km = np.arange(ny, dtype=float) * DY_KM

        ang_vmin, ang_vmax = (0.0, 360.0)
        brg_vmin, brg_vmax = (0.0, 360.0)
        n2_center = float(N2_VALUE)
        n2_vmin, n2_vmax = (0.5 * n2_center, 1.5 * n2_center)

        for i in range(n_cluster):
            s = int(slc[i])

            amp = np.asarray(nc.variables["Amplitude"][i], dtype=float)
            lam = np.asarray(nc.variables["DominantWavelength"][i], dtype=float)
            ang_rad = np.asarray(nc.variables["Angle"][i], dtype=float)
            ang_deg = (np.rad2deg(ang_rad) % 360.0)

            brg = np.asarray(nc.variables["Bearing_cluster"][i], dtype=float)
            n2 = np.asarray(nc.variables["NSquared_cluster"][i], dtype=float)
            tmp = np.asarray(nc.variables["Temp_cluster"][i], dtype=float)
            mf = np.asarray(nc.variables["MF_cluster"][i], dtype=float)
            mfz = np.asarray(nc.variables["MF_zonal_cluster"][i], dtype=float)
            mfm = np.asarray(nc.variables["MF_meridional_cluster"][i], dtype=float)

            if "ClusterReconstruction" in nc.variables:
                recon = np.asarray(nc.variables["ClusterReconstruction"][i], dtype=float)
            else:
                recon = np.full_like(amp, np.nan)

            r_vmin, r_vmax = robust_limits(recon, 2, 98)
            a_vmin, a_vmax = robust_limits(amp, 2, 98)
            l_vmin, l_vmax = robust_limits(lam, 5, 95)
            t_vmin, t_vmax = robust_limits(tmp, 2, 98)
            mf_vmin, mf_vmax = robust_limits(mf, 2, 98)
            mfz_vmin, mfz_vmax = robust_limits(mfz, 2, 98)
            mfm_vmin, mfm_vmax = robust_limits(mfm, 2, 98)

            fig, axs = plt.subplots(5, 2, figsize=(16, 22), constrained_layout=True, sharex=True, sharey=True)

            def _panel(ax, Z, vmin, vmax, label, cmap=None):
                im = ax.pcolormesh(x1d_km, y1d_km, Z, shading="auto", vmin=vmin, vmax=vmax, cmap=cmap)
                cb = fig.colorbar(im, ax=ax, fraction=0.04, pad=0.02)
                cb.set_label(label)
                ax.set_aspect("equal", adjustable="box")

            axs[0, 0].set_title(f"Passed cluster {i:04d}  SliceNo {s}")

            _panel(axs[0, 0], recon, r_vmin, r_vmax, "Recon", cmap="RdBu_r")
            _panel(axs[0, 1], amp, a_vmin, a_vmax, "Amplitude K")
            _panel(axs[1, 0], lam, l_vmin, l_vmax, "DominantWavelength km")
            _panel(axs[1, 1], tmp, t_vmin, t_vmax, "Temperature K")
            _panel(axs[2, 0], ang_deg, ang_vmin, ang_vmax, "Angle deg propagation")
            _panel(axs[2, 1], brg, brg_vmin, brg_vmax, "Bearing deg 0 East CCW")
            _panel(axs[3, 0], n2, n2_vmin, n2_vmax, "N2 s-2")
            _panel(axs[3, 1], mf, mf_vmin, mf_vmax, "MF m2 s-2")
            _panel(axs[4, 0], mfz, mfz_vmin, mfz_vmax, "MF zonal share cos2")
            _panel(axs[4, 1], mfm, mfm_vmin, mfm_vmax, "MF meridional share sin2")

            axs[4, 0].set_xlabel("x km")
            axs[4, 1].set_xlabel("x km")

            outpng = outdir / (
                f"passed_cluster_{i:04d}_slice_{s:03d}"
                "_Recon_Amp_Lam_Temp_Ang_Bearing_N2_MF_MFz_MFm.png"
            )
            save_fig(fig, outpng)

            del amp, lam, ang_rad, ang_deg, brg, n2, tmp, mf, mfz, mfm, recon, fig, axs
            gc.collect()

    mpl.pyplot.close("all")
    gc.collect()
    print("Per cluster plots saved to:", outdir.resolve())


def plot_stitched_mf_components(nc_path: Path, outpng: Path, time_index: int) -> None:
    outpng.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(nc_path, "r") as nc:
        MF = np.asarray(nc.variables["MF_toprows"][time_index], dtype=float)
        MFZ = np.asarray(nc.variables["MF_zonal_toprows"][time_index], dtype=float)
        MFM = np.asarray(nc.variables["MF_meridional_toprows"][time_index], dtype=float)

    ny, nx = MF.shape
    x1d_km = np.arange(nx, dtype=float) * DX_KM
    y1d_km = np.arange(ny, dtype=float) * DY_KM

    stacked = np.concatenate([MF.ravel(), MFZ.ravel(), MFM.ravel()])
    vmin, vmax = robust_limits(stacked, 2, 99.9)

    fig, axs = plt.subplots(3, 1, figsize=(22, 8), constrained_layout=True, sharex=True, sharey=True)

    im0 = axs[0].pcolormesh(x1d_km, y1d_km, MF, shading="auto", vmin=vmin, vmax=vmax)
    axs[0].set_title("Stitched MF passed clusters summed")
    axs[0].set_ylabel("y km")
    axs[0].set_aspect("equal", adjustable="box")

    im1 = axs[1].pcolormesh(x1d_km, y1d_km, MFZ, shading="auto", vmin=vmin, vmax=vmax)
    axs[1].set_title("Stitched MF zonal share cos2")
    axs[1].set_ylabel("y km")
    axs[1].set_aspect("equal", adjustable="box")

    im2 = axs[2].pcolormesh(x1d_km, y1d_km, MFM, shading="auto", vmin=vmin, vmax=vmax)
    axs[2].set_title("Stitched MF meridional share sin2")
    axs[2].set_xlabel("x km")
    axs[2].set_ylabel("y km")
    axs[2].set_aspect("equal", adjustable="box")

    for ax in axs:
        ax.set_ylim(0, 600)

    cbar = fig.colorbar(im2, ax=axs, fraction=0.02, pad=0.01)
    cbar.set_label("MF m2 s-2")

    save_fig(fig, outpng)

    del MF, MFZ, MFM, stacked, fig, axs
    gc.collect()


# --------------------------
# Main: matching -> passed clusters -> output passed-only netCDF -> stitched plots
# --------------------------
l6c = load_l6_for_matching(L6C_PATH)
l6a_match = load_l6_for_matching(L6A_PATH)

all_slices_a = np.unique(l6a_match["SlicesNo"]).astype(int)
all_slices_a = all_slices_a[all_slices_a >= 0]
all_slices_a = np.sort(all_slices_a)

print("Slices in L6A:", all_slices_a.tolist())

summary_lines: List[str] = []
summary_lines.append(f"L6A: {L6A_PATH}\n")
summary_lines.append(f"L6C: {L6C_PATH}\n\n")
summary_lines.append("slice  nA  nC  nBestSaved  nPassed  note\n")

passed_global_indices: List[int] = []

for slice_no in all_slices_a:
    idx_a = np.where(l6a_match["SlicesNo"] == int(slice_no))[0]
    idx_c = np.where(l6c["SlicesNo"] == int(slice_no))[0]

    slice_dir = OUTDIR / f"slice_{slice_no:03d}"
    pairs_dir = slice_dir / "pairs"
    pairs_dir.mkdir(parents=True, exist_ok=True)

    if idx_a.size == 0:
        summary_lines.append(f"{slice_no:5d}  {0:2d}  {idx_c.size:2d}  {0:10d}  {0:7d}  no L6A clusters\n")
        continue
    if idx_c.size == 0:
        (slice_dir / "NO_L6C_CLUSTERS.txt").write_text(f"No L6C clusters for slice {slice_no}\n")
        summary_lines.append(f"{slice_no:5d}  {idx_a.size:2d}  {0:2d}  {0:10d}  {0:7d}  no L6C clusters\n")
        continue

    best_rows: List[Dict[str, Any]] = []

    cand_lines: List[str] = []
    cand_header = []
    cand_header.append(f"L6A file: {L6A_PATH}\n")
    cand_header.append(f"L6C file: {L6C_PATH}\n")
    cand_header.append(f"Slice: {slice_no}\n\n")
    cand_header.append(
        "cluster_a  cluster_c  passes  score    iou    inter  "
        "lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
    )

    for a_idx in idx_a:
        a_idx = int(a_idx)
        A_a = l6a_match["Amplitude"][a_idx]
        L_a = l6a_match["DominantWavelength"][a_idx]
        T_a = l6a_match["Angle"][a_idx]

        candidates: List[Dict[str, Any]] = []
        for c_idx in idx_c:
            c_idx = int(c_idx)
            A_c = l6c["Amplitude"][c_idx]
            L_c = l6c["DominantWavelength"][c_idx]
            T_c = l6c["Angle"][c_idx]

            m = compute_match_metrics(A_a, L_a, T_a, A_c, L_c, T_c)
            m["cluster_a"] = a_idx
            m["cluster_c"] = c_idx
            m["passes"] = bool(passes_thresholds(m))
            m["score"] = float(score(m))
            candidates.append(m)

            cand_lines.append(
                f"{m['cluster_a']:9d}  {m['cluster_c']:9d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
                f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
                f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
                f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
                f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
            )

        passed = [c for c in candidates if c["passes"]]
        if passed:
            best = max(passed, key=lambda d: d["score"])
        else:
            best = max(candidates, key=lambda d: d["score"])

        if best["passes"] or ASSIGN_BEST_EVEN_IF_FAILS:
            best_rows.append(best)

            if SAVE_PAIR_PLOTS:
                left_maps = get_cluster_maps(l6a_match, best["cluster_a"])
                right_maps = get_cluster_maps(l6c, best["cluster_c"])

                pass_tag = "PASS" if best["passes"] else "FAIL"
                outpng = pairs_dir / f"slice_{slice_no:03d}_A_{best['cluster_a']:04d}_to_C_{best['cluster_c']:04d}_{pass_tag}.png"

                title_left = (
                    f"L6A Temp | slice {slice_no} | idx {best['cluster_a']} | "
                    f"n={np.count_nonzero(np.isfinite(left_maps['A']))}"
                )
                title_right = (
                    f"L6C Rad | slice {slice_no} | idx {best['cluster_c']} | "
                    f"IoU={best['iou']:.3f} inter={best['n_intersection']} "
                    f"ratio={best['lam_ratio']:.3f} Δθ={best['ang_diff_deg']:.1f}°"
                )

                plot_side_by_side_4rows(
                    left=left_maps,
                    right=right_maps,
                    title_left=title_left,
                    title_right=title_right,
                    outpath=outpng,
                    dx_km=DX_KM,
                    dy_km=DY_KM,
                )

                del left_maps, right_maps
                gc.collect()

        del candidates
        gc.collect()

    cand_path = slice_dir / f"slice_{slice_no:03d}_ALL_candidates_ratio.txt"
    cand_path.write_text("".join(cand_header) + "".join(cand_lines))
    del cand_lines
    gc.collect()

    best_path = slice_dir / f"slice_{slice_no:03d}_BEST_matches_A_to_C_ratio.txt"
    best_lines = []
    best_lines.append(f"L6A file: {L6A_PATH}\n")
    best_lines.append(f"L6C file: {L6C_PATH}\n")
    best_lines.append(f"Slice: {slice_no}\n\n")
    best_lines.append(
        "cluster_a  best_cluster_c  passes  score    iou    inter  "
        "lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
    )
    for m in sorted(best_rows, key=lambda d: d["cluster_a"]):
        best_lines.append(
            f"{m['cluster_a']:9d}  {m['cluster_c']:14d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
            f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
            f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
            f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
            f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
        )
    best_path.write_text("".join(best_lines))

    passed_here = [int(m["cluster_a"]) for m in best_rows if bool(m["passes"])]
    passed_global_indices.extend(passed_here)

    summary_lines.append(
        f"{slice_no:5d}  {idx_a.size:2d}  {idx_c.size:2d}  {len(best_rows):10d}  {len(passed_here):7d}  ok\n"
    )

    del best_rows, best_lines
    gc.collect()

summary_path = OUTDIR / "SUMMARY_all_slices.txt"
summary_path.write_text("".join(summary_lines))

passed_global_indices = sorted(set(passed_global_indices))
passed_global_indices_np = np.asarray(passed_global_indices, dtype=int)
print("Total passed clusters:", passed_global_indices_np.size)

if passed_global_indices_np.size == 0:
    raise RuntimeError("No passed clusters found. Nothing to save or stitch.")

create_passed_only_l6a_with_new_vars(
    src_l6a=L6A_PATH,
    dst_l6a=OUT_L6A_PASSED,
    passed_cluster_indices=passed_global_indices_np,
    time_index=TIME_INDEX,
)

if SAVE_STITCHED_PLOTS:
    with Dataset(OUT_L6A_PASSED, "r") as nc:
        MF2 = np.asarray(nc.variables["MF_toprows"][TIME_INDEX], dtype=float)
        ny, nx = MF2.shape
        x1d_km = np.arange(nx, dtype=float) * DX_KM
        y1d_km = np.arange(ny, dtype=float) * DY_KM

        vmin, vmax = robust_limits(MF2, 2, 99.9)

        fig, ax = plt.subplots(figsize=(22, 3), constrained_layout=True)
        im = ax.pcolormesh(x1d_km, y1d_km, MF2, shading="auto", vmin=vmin, vmax=vmax)
        ax.set_title("Momentum Flux (passed clusters summed)")
        ax.set_xlabel("x (km)")
        ax.set_ylabel("y (km)")
        ax.set_ylim(0, 600)
        ax.set_aspect("equal", adjustable="box")
        fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01).set_label("MF (m2 s-2)")
        save_fig(fig, OUTDIR / "MF_stitched.png")

    plot_stitched_mf_components(
        nc_path=OUT_L6A_PASSED,
        outpng=OUTDIR / "MF_stitched_components.png",
        time_index=TIME_INDEX,
    )

if SAVE_PER_CLUSTER_PANELS:
    plot_passed_clusters_panels(
        nc_path=OUT_L6A_PASSED,
        outdir=OUTDIR / "passed_cluster_plots_panels",
    )

del l6c, l6a_match, passed_global_indices_np
mpl.pyplot.close("all")
gc.collect()

print("\nDone.")
print("Outputs in:", OUTDIR.resolve())
print("Summary:", summary_path.resolve())
print("PASSED-only augmented L6A:", OUT_L6A_PASSED.resolve())
print("New vars in output: Bearing, Bearing_cluster, Temp_cluster, u_cluster, v_cluster, NSquared_cluster, MF_cluster, MF_slice_sum, MF_toprows")
# Out:
# Slices in L6A: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Total passed clusters: 28
#
# Done.
# Outputs in: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF
# Summary: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF/SUMMARY_all_slices.txt
# PASSED-only augmented L6A: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_ALLSLICES_l6a_to_l6c_matching_ratio_STITCH_MF/awe_l6a_tmp_2024165T2120_03175_v01_PASSED_with_u_v_NS2_Bearing_TempCluster_MF.nc
# New vars in output: Bearing, Bearing_cluster, Temp_cluster, u_cluster, v_cluster, NSquared_cluster, MF_cluster, MF_slice_sum, MF_toprows

# %% [markdown]
# 20 s

# %% [markdown]
# ## Batch Calculating

# %%
# %%
"""
BATCH: ALL-SLICES matching + per-slice combined L6A recon + FULL-ORBIT stitched recon
+ slice Temperature + momentum flux for PASSED clusters only
+ sum MF per slice + stitch MF across orbit
+ output NetCDF contains original L6A global attrs + variables, but ONLY PASSED clusters
  are kept for cluster-dimension variables.

Momentum flux (per cluster pixel, masked to cluster area):
MF = 1/2 * g^2 / N^2 * (lambda_z / lambda_x) * (Amplitude / Temperature)^2 * (1/c^2)

Key rules:
- SliceNo already exists in L6A, keep it (but subset to passed clusters)
- Area, Amplitude, DominantWavelength, Angle already exist (subset to passed clusters)
- Also slice Temperature into Temp_cluster (passed clusters only)
- Add geodesic Bearing (0 = East, counter-clockwise) as Bearing + Bearing_cluster
- Only save passed clusters (output file cluster vars are subset)
- Add MF_cluster, MF_slice_sum, MF_toprows

BATCH behavior:
- Scan L6_DIR for L6A and L6C files
- Pair by common suffix key like: 2024165T2120_03175_v01
- For each pair, write the new file into L7_DIR and rename l6a -> l7a
- Save plots + text into outputs folder per key
"""

from __future__ import annotations

from pathlib import Path
from typing import Dict, Any, List, Tuple
import traceback
import gc

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from netCDF4 import Dataset

# ============================================================
# Batch params
# ============================================================
L6_DIR = Path("l6")  # contains many L6A/L6C files
L7_DIR = Path("l7")  # where new NetCDFs go
L7_DIR.mkdir(parents=True, exist_ok=True)

BATCH_OUTROOT = Path("outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF")
BATCH_OUTROOT.mkdir(parents=True, exist_ok=True)

SAVE_DPI = 200
DX_KM = 2.0
DY_KM = 2.0

# ---- Synthetic u,v,N^2 settings ----
TEMP_VAR_NAME = "Temperature"
TIME_INDEX = 0
N2_VALUE = 4e-4
U_VALUE = 0.0
V_VALUE = 0.0

# ---- Momentum flux constants ----
G_MS2 = 9.52
LAMBDA_Z_KM = 10.0
C_CANCEL = 1.0

# --------------------------
# Matching thresholds (tune)
# --------------------------
MIN_IOU = 0.05
MIN_INTERSECTION_PIX = 50
MAX_LAMBDA_MED_RATIO = 1.25
MAX_ANGLE_DIFF_DEG = 15.0

# Save best match even if FAIL (does NOT affect passing)
ASSIGN_BEST_EVEN_IF_FAILS = True

# --------------------------
# Plot saving switches (batch friendly)
# --------------------------
SAVE_PAIR_PLOTS = False          # side-by-side A vs C match PNGs per slice (heavy)
SAVE_PER_CLUSTER_PANELS = False  # big 5x2 panels per passed cluster (heavy)
SAVE_STITCHED_PLOTS = True       # MF_stitched.png + MF_stitched_components.png


# ============================================================
# Helpers
# ============================================================
def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def robust_limits(A: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    a = np.asarray(A)
    good = np.isfinite(a)
    if not np.any(good):
        return (-1.0, 1.0)
    lo, hi = np.nanpercentile(a[good], [p_lo, p_hi])
    if (not np.isfinite(lo)) or (not np.isfinite(hi)) or lo == hi:
        lo = float(np.nanmin(a[good]))
        hi = float(np.nanmax(a[good]))
    return (float(lo), float(hi))


def nanpercentile_safe(a: np.ndarray, q: float) -> float:
    good = np.isfinite(a)
    if not np.any(good):
        return np.nan
    return float(np.nanpercentile(a[good], q))


def circ_diff_deg_180(a_deg: float, b_deg: float) -> float:
    if (not np.isfinite(a_deg)) or (not np.isfinite(b_deg)):
        return np.nan
    d = abs(a_deg - b_deg) % 180.0
    return min(d, 180.0 - d)


def circ_median_deg_180(theta_rad: np.ndarray, mask: np.ndarray) -> float:
    th = np.asarray(theta_rad, dtype=float)
    m = mask & np.isfinite(th)
    if not np.any(m):
        return np.nan
    ang = th[m]
    z = np.exp(1j * 2.0 * ang)
    zmean = np.mean(z)
    if (not np.isfinite(zmean.real)) or (not np.isfinite(zmean.imag)) or abs(zmean) == 0:
        return np.nan
    th_mean = 0.5 * np.angle(zmean)
    deg = (np.degrees(th_mean) + 180.0) % 180.0
    return float(deg)


# -------------------------
# Geodesic bearing: 0 = East, counter-clockwise (CCW)
# -------------------------
def initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    lat1 = np.deg2rad(lat1_deg)
    lon1 = np.deg2rad(lon1_deg)
    lat2 = np.deg2rad(lat2_deg)
    lon2 = np.deg2rad(lon2_deg)

    dlon = lon2 - lon1
    x = np.sin(dlon) * np.cos(lat2)
    y = np.cos(lat1) * np.sin(lat2) - np.sin(lat1) * np.cos(lat2) * np.cos(dlon)

    az = np.arctan2(x, y)
    return (np.rad2deg(az) + 360.0) % 360.0


def bearing_deg_east_ccw_from_points(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    az_north_cw = initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg)
    return (90.0 - az_north_cw) % 360.0


def compute_bearing_to_x_neighbor_east_ccw(lat2d: np.ndarray, lon2d: np.ndarray) -> np.ndarray:
    lat = np.asarray(lat2d, dtype=float)
    lon = np.asarray(lon2d, dtype=float)

    lat2 = np.empty_like(lat)
    lon2 = np.empty_like(lon)

    lat2[:, :-1] = lat[:, 1:]
    lon2[:, :-1] = lon[:, 1:]
    lat2[:, -1] = lat[:, -2]
    lon2[:, -1] = lon[:, -2]

    bearing = bearing_deg_east_ccw_from_points(lat, lon, lat2, lon2)
    good = np.isfinite(lat) & np.isfinite(lon) & np.isfinite(lat2) & np.isfinite(lon2)
    return np.where(good, bearing, np.nan)


# ============================================================
# Matching IO (memory friendly): do NOT load ClusterReconstruction upfront
# ============================================================
def load_l6_for_matching(path: Path) -> Dict[str, Any]:
    with Dataset(path, "r") as nc:
        return {
            "path": str(path),
            "SlicesNo": np.asarray(nc.variables["SlicesNo"][:], dtype=int),
            "Amplitude": np.asarray(nc.variables["Amplitude"][:], dtype=float),
            "DominantWavelength": np.asarray(nc.variables["DominantWavelength"][:], dtype=float),
            "Angle": np.asarray(nc.variables["Angle"][:], dtype=float),
        }


def get_cluster_maps(data: Dict[str, Any], idx: int) -> Dict[str, np.ndarray]:
    """
    Lazy load ClusterReconstruction only for requested idx (only used if SAVE_PAIR_PLOTS=True).
    """
    A = np.asarray(data["Amplitude"][idx], dtype=float)
    L = np.asarray(data["DominantWavelength"][idx], dtype=float)
    T = np.asarray(data["Angle"][idx], dtype=float)

    R = np.full_like(A, np.nan)
    with Dataset(data["path"], "r") as nc:
        if "ClusterReconstruction" in nc.variables:
            R = np.asarray(nc.variables["ClusterReconstruction"][idx], dtype=float)

    return dict(R=R, A=A, L=L, T=T)


def compute_match_metrics(
    A_src: np.ndarray, L_src: np.ndarray, T_src: np.ndarray,
    A_cand: np.ndarray, L_cand: np.ndarray, T_cand: np.ndarray,
) -> Dict[str, Any]:
    mask_src = np.isfinite(A_src)
    mask_cand = np.isfinite(A_cand)
    inter = mask_src & mask_cand
    union = mask_src | mask_cand

    n_inter = int(np.count_nonzero(inter))
    n_union = int(np.count_nonzero(union))
    iou = (n_inter / n_union) if n_union > 0 else 0.0

    lam_src = L_src[inter]
    lam_cand = L_cand[inter]
    lam_src_med = nanpercentile_safe(lam_src, 50)
    lam_cand_med = nanpercentile_safe(lam_cand, 50)

    if np.isfinite(lam_src_med) and np.isfinite(lam_cand_med) and lam_src_med > 0 and lam_cand_med > 0:
        lam_ratio = max(lam_src_med, lam_cand_med) / min(lam_src_med, lam_cand_med)
    else:
        lam_ratio = np.nan

    ang_src_deg = circ_median_deg_180(T_src, inter)
    ang_cand_deg = circ_median_deg_180(T_cand, inter)
    ang_diff_deg = circ_diff_deg_180(ang_src_deg, ang_cand_deg)

    return dict(
        n_intersection=n_inter,
        iou=float(iou),
        lam_src_med=float(lam_src_med),
        lam_cand_med=float(lam_cand_med),
        lam_ratio=float(lam_ratio),
        ang_src_deg=float(ang_src_deg),
        ang_cand_deg=float(ang_cand_deg),
        ang_diff_deg=float(ang_diff_deg),
    )


def passes_thresholds(m: Dict[str, Any]) -> bool:
    if m["iou"] < MIN_IOU:
        return False
    if m["n_intersection"] < MIN_INTERSECTION_PIX:
        return False
    if (not np.isfinite(m["lam_ratio"])) or (m["lam_ratio"] > MAX_LAMBDA_MED_RATIO):
        return False
    if (not np.isfinite(m["ang_diff_deg"])) or (m["ang_diff_deg"] > MAX_ANGLE_DIFF_DEG):
        return False
    return True


def score(m: Dict[str, Any]) -> float:
    ang = m["ang_diff_deg"]
    if not np.isfinite(ang):
        ang = 999.0
    r = m["lam_ratio"]
    if (not np.isfinite(r)) or r <= 0:
        return 0.0
    return float(m["iou"]) * (1.0 / float(r)) / (1.0 + float(ang))


def plot_side_by_side_4rows(
    left: Dict[str, np.ndarray],
    right: Dict[str, np.ndarray],
    title_left: str,
    title_right: str,
    outpath: Path,
    dx_km: float,
    dy_km: float,
) -> None:
    ny, nx = left["A"].shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    Rl_vmin, Rl_vmax = robust_limits(left["R"])
    Rr_vmin, Rr_vmax = robust_limits(right["R"])
    Al_vmin, Al_vmax = robust_limits(left["A"])
    Ar_vmin, Ar_vmax = robust_limits(right["A"])

    L_vmin, L_vmax = robust_limits(np.concatenate([left["L"].ravel(), right["L"].ravel()]), 5, 95)
    T_vmin, T_vmax = robust_limits(np.concatenate([left["T"].ravel(), right["T"].ravel()]))

    fig, axs = plt.subplots(4, 2, figsize=(16, 14), constrained_layout=True, sharex=True, sharey=True)

    def _panel(ax, Z, vmin, vmax, label, cmap=None):
        im = ax.pcolormesh(x1d_km, y1d_km, Z, shading="auto", vmin=vmin, vmax=vmax, cmap=cmap)
        cb = fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01)
        cb.set_label(label)
        ax.set_aspect("equal", adjustable="box")

    axs[0, 0].set_title(title_left)
    axs[0, 1].set_title(title_right)

    _panel(axs[0, 0], left["R"], Rl_vmin, Rl_vmax, "arb", cmap="RdBu_r")
    _panel(axs[0, 1], right["R"], Rr_vmin, Rr_vmax, "arb", cmap="RdBu_r")
    axs[0, 0].set_ylabel("Recon\ny (km)")

    _panel(axs[1, 0], left["A"], Al_vmin, Al_vmax, "K")
    _panel(axs[1, 1], right["A"], Ar_vmin, Ar_vmax, "kR")
    axs[1, 0].set_ylabel("Amp\ny (km)")

    _panel(axs[2, 0], left["L"], L_vmin, L_vmax, "km")
    _panel(axs[2, 1], right["L"], L_vmin, L_vmax, "km")
    axs[2, 0].set_ylabel("Lambda\ny (km)")

    _panel(axs[3, 0], left["T"], T_vmin, T_vmax, "rad")
    _panel(axs[3, 1], right["T"], T_vmin, T_vmax, "rad")
    axs[3, 0].set_ylabel("Angle\ny (km)")

    for r in range(4):
        for c in range(2):
            axs[r, c].set_xlabel("x (km)")

    save_fig(fig, outpath)


# --------------------------
# Flatten swath BEFORE slicing
# --------------------------
def flatten_swath(Z: np.ndarray, target_ny: int | None = None) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


# ============================================================
# L6A cloning with PASSED-only cluster variables + new vars
# ============================================================
def create_passed_only_l6a_with_new_vars(
    src_l6a: Path,
    dst_l7a: Path,
    passed_cluster_indices: np.ndarray,
    time_index: int,
) -> Tuple[str, str, str]:
    passed_cluster_indices = np.asarray(passed_cluster_indices, dtype=int)
    if passed_cluster_indices.size == 0:
        raise ValueError("No passed clusters. Output would be empty.")

    dst_l7a.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(src_l6a, "r") as src:
        amp_var = src.variables["Amplitude"]
        cluster_dim, ytile_dim, xtile_dim = amp_var.dimensions[:3]
        _, y_tile, x_tile = amp_var.shape

        temp_var = src.variables[TEMP_VAR_NAME]
        temp_dims = temp_var.dimensions
        temp_shape = temp_var.shape
        temp_raw_2d = np.asarray(temp_var[time_index], dtype=float)

        u_raw_2d = (
            np.asarray(src.variables["u"][time_index], dtype=float)
            if "u" in src.variables
            else np.full_like(temp_raw_2d, U_VALUE, dtype=float)
        )
        v_raw_2d = (
            np.asarray(src.variables["v"][time_index], dtype=float)
            if "v" in src.variables
            else np.full_like(temp_raw_2d, V_VALUE, dtype=float)
        )
        n2_raw_2d = (
            np.asarray(src.variables["NSquared"][time_index], dtype=float)
            if "NSquared" in src.variables
            else np.full_like(temp_raw_2d, N2_VALUE, dtype=float)
        )

        if ("Latitude" in src.variables) and ("Longitude" in src.variables):
            lat_raw_2d = np.asarray(src.variables["Latitude"][time_index], dtype=float)
            lon_raw_2d = np.asarray(src.variables["Longitude"][time_index], dtype=float)
            bearing_raw_2d = compute_bearing_to_x_neighbor_east_ccw(lat_raw_2d, lon_raw_2d)
        else:
            bearing_raw_2d = np.full_like(temp_raw_2d, np.nan, dtype=float)

        temp_full_2d = flatten_swath(temp_raw_2d, target_ny=y_tile)
        u_full_2d = flatten_swath(u_raw_2d, target_ny=y_tile)
        v_full_2d = flatten_swath(v_raw_2d, target_ny=y_tile)
        n2_full_2d = flatten_swath(n2_raw_2d, target_ny=y_tile)
        bearing_full_2d = flatten_swath(bearing_raw_2d, target_ny=y_tile)

        n_passed = int(passed_cluster_indices.size)

        with Dataset(dst_l7a, "w") as dst:
            for aname in src.ncattrs():
                dst.setncattr(aname, src.getncattr(aname))

            for dname, dim in src.dimensions.items():
                if dname == cluster_dim:
                    dst.createDimension(dname, n_passed)
                else:
                    dst.createDimension(dname, (None if dim.isunlimited() else len(dim)))

            for vname, vsrc in src.variables.items():
                fill_value = vsrc.getncattr("_FillValue") if "_FillValue" in vsrc.ncattrs() else None
                vdst = dst.createVariable(
                    vname,
                    vsrc.dtype,
                    vsrc.dimensions,
                    zlib=True,
                    complevel=4,
                    fill_value=fill_value,
                )
                for aname in vsrc.ncattrs():
                    if aname != "_FillValue":
                        vdst.setncattr(aname, vsrc.getncattr(aname))

                if cluster_dim in vsrc.dimensions:
                    ax = vsrc.dimensions.index(cluster_dim)
                    vdst[:] = np.take(vsrc[:], passed_cluster_indices, axis=ax)
                else:
                    vdst[:] = vsrc[:]

            bearing_full = np.zeros(temp_shape, dtype=np.float32)
            bearing_full[time_index, 0:y_tile, :] = bearing_full_2d.astype(np.float32)

            if "Bearing" in dst.variables:
                dst.variables["Bearing"][:] = bearing_full
            else:
                vB = dst.createVariable("Bearing", "f4", temp_dims, zlib=True, complevel=4)
                vB.setncattr("long_name", "Geodesic bearing to +x neighbor (0=East, CCW)")
                vB.setncattr("units", "degree")
                vB[:] = bearing_full

            temp_cluster = np.full((n_passed, y_tile, x_tile), np.nan, dtype=np.float32)
            u_cluster = np.full_like(temp_cluster, np.nan)
            v_cluster = np.full_like(temp_cluster, np.nan)
            n2_cluster = np.full_like(temp_cluster, np.nan)
            bearing_cluster = np.full_like(temp_cluster, np.nan)

            mf_cluster = np.full_like(temp_cluster, np.nan)
            mf_zonal_cluster = np.full_like(temp_cluster, np.nan)
            mf_meridional_cluster = np.full_like(temp_cluster, np.nan)

            amp_passed = np.asarray(dst.variables["Amplitude"][:], dtype=float)
            lam_passed = np.asarray(dst.variables["DominantWavelength"][:], dtype=float)
            slice_passed = np.asarray(dst.variables["SlicesNo"][:], dtype=int)
            ang_rad_passed = np.asarray(dst.variables["Angle"][:], dtype=float)

            for j in range(n_passed):
                s = int(slice_passed[j])
                x0 = s * x_tile
                x1 = x0 + x_tile

                mask = np.isfinite(amp_passed[j])

                Ttile = temp_full_2d[:, x0:x1]
                Utile = u_full_2d[:, x0:x1]
                Vtile = v_full_2d[:, x0:x1]
                N2tile = n2_full_2d[:, x0:x1]
                Btile = bearing_full_2d[:, x0:x1]

                temp_cluster[j][mask] = Ttile[mask]
                u_cluster[j][mask] = Utile[mask]
                v_cluster[j][mask] = Vtile[mask]
                n2_cluster[j][mask] = N2tile[mask]
                bearing_cluster[j][mask] = Btile[mask]

                A = amp_passed[j]
                Lx = lam_passed[j]
                ang_deg_tile = (np.rad2deg(ang_rad_passed[j]) % 360.0)

                good = mask
                good = good & np.isfinite(Ttile) & np.isfinite(N2tile) & np.isfinite(Lx) & np.isfinite(Btile)
                good = good & (Ttile != 0.0) & (N2tile > 0.0) & (Lx > 0.0)

                if np.any(good):
                    mf_val = (
                        0.5
                        * (G_MS2**2)
                        / N2tile[good]
                        * (LAMBDA_Z_KM / Lx[good])
                        * (A[good] / Ttile[good]) ** 2
                        * (1.0 / (C_CANCEL**2))
                    )
                    mf_cluster[j][good] = mf_val

                    phi_deg = (Btile[good] + ang_deg_tile[good]) % 360.0
                    phi_rad = np.deg2rad(phi_deg)

                    mf_zonal_cluster[j][good] = mf_val * (np.cos(phi_rad) ** 2)
                    mf_meridional_cluster[j][good] = mf_val * (np.sin(phi_rad) ** 2)

            def _write(name: str, arr: np.ndarray, dims: Tuple[str, ...], long_name: str, units: str):
                if name in dst.variables:
                    dst.variables[name][:] = arr
                else:
                    v = dst.createVariable(name, "f4", dims, zlib=True, complevel=4)
                    v.setncattr("long_name", long_name)
                    v.setncattr("units", units)
                    v[:] = arr

            _write("Temp_cluster", temp_cluster, (cluster_dim, ytile_dim, xtile_dim), "Temperature, cluster masked", "K")
            _write("u_cluster", u_cluster, (cluster_dim, ytile_dim, xtile_dim), "u wind, cluster masked", "m/s")
            _write("v_cluster", v_cluster, (cluster_dim, ytile_dim, xtile_dim), "v wind, cluster masked", "m/s")
            _write("NSquared_cluster", n2_cluster, (cluster_dim, ytile_dim, xtile_dim), "N^2, cluster masked", "s^-2")
            _write("Bearing_cluster", bearing_cluster, (cluster_dim, ytile_dim, xtile_dim), "Bearing (0=East, CCW), cluster masked", "degree")

            _write("MF_cluster", mf_cluster, (cluster_dim, ytile_dim, xtile_dim), "MF proxy per pixel, cluster masked", "m2 s-2")
            _write("MF_zonal_cluster", mf_zonal_cluster, (cluster_dim, ytile_dim, xtile_dim), "MF cos^2(phi)", "m2 s-2")
            _write("MF_meridional_cluster", mf_meridional_cluster, (cluster_dim, ytile_dim, xtile_dim), "MF sin^2(phi)", "m2 s-2")

            smin, smax = int(np.min(slice_passed)), int(np.max(slice_passed))
            full_slices = np.arange(smin, smax + 1)

            if "slice" not in dst.dimensions:
                dst.createDimension("slice", len(full_slices))
            if "SliceNo_passed_slices" not in dst.variables:
                dst.createVariable("SliceNo_passed_slices", "i4", ("slice",))[:] = full_slices
            else:
                dst.variables["SliceNo_passed_slices"][:] = full_slices

            mf_slice_sum = np.zeros((len(full_slices), y_tile, x_tile), dtype=np.float32)
            mfz_slice_sum = np.zeros_like(mf_slice_sum)
            mfm_slice_sum = np.zeros_like(mf_slice_sum)

            for k, s in enumerate(full_slices):
                idx = np.where(slice_passed == s)[0]
                if idx.size > 0:
                    mf_slice_sum[k] = np.nansum(mf_cluster[idx], axis=0)
                    mfz_slice_sum[k] = np.nansum(mf_zonal_cluster[idx], axis=0)
                    mfm_slice_sum[k] = np.nansum(mf_meridional_cluster[idx], axis=0)

            _write("MF_slice_sum", mf_slice_sum, ("slice", ytile_dim, xtile_dim), "Per slice MF sum (passed clusters), tile grid", "m2 s-2")
            _write("MF_zonal_slice_sum", mfz_slice_sum, ("slice", ytile_dim, xtile_dim), "Per slice zonal MF sum (passed clusters), tile grid", "m2 s-2")
            _write("MF_meridional_slice_sum", mfm_slice_sum, ("slice", ytile_dim, xtile_dim), "Per slice meridional MF sum (passed clusters), tile grid", "m2 s-2")

            MF_toprows = np.zeros(temp_shape, dtype=np.float32)
            MFZ_toprows = np.zeros(temp_shape, dtype=np.float32)
            MFM_toprows = np.zeros(temp_shape, dtype=np.float32)

            for k, s in enumerate(full_slices):
                x0 = s * x_tile
                x1 = x0 + x_tile
                MF_toprows[time_index, 0:y_tile, x0:x1] = mf_slice_sum[k]
                MFZ_toprows[time_index, 0:y_tile, x0:x1] = mfz_slice_sum[k]
                MFM_toprows[time_index, 0:y_tile, x0:x1] = mfm_slice_sum[k]

            _write("MF_toprows", MF_toprows, temp_dims, "Stitched MF sum (passed clusters) on top tile rows only", "m2 s-2")
            _write("MF_zonal_toprows", MFZ_toprows, temp_dims, "Stitched zonal MF share on top tile rows only", "m2 s-2")
            _write("MF_meridional_toprows", MFM_toprows, temp_dims, "Stitched meridional MF share on top tile rows only", "m2 s-2")

        del temp_raw_2d, u_raw_2d, v_raw_2d, n2_raw_2d, bearing_raw_2d
        del temp_full_2d, u_full_2d, v_full_2d, n2_full_2d, bearing_full_2d
        del temp_cluster, u_cluster, v_cluster, n2_cluster, bearing_cluster
        del mf_cluster, mf_zonal_cluster, mf_meridional_cluster
        gc.collect()

    return cluster_dim, ytile_dim, xtile_dim


# ============================================================
# Plotting
# ============================================================
def plot_stitched_mf_components(nc_path: Path, outpng: Path, time_index: int) -> None:
    outpng.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(nc_path, "r") as nc:
        MF = np.asarray(nc.variables["MF_toprows"][time_index], dtype=float)
        MFZ = np.asarray(nc.variables["MF_zonal_toprows"][time_index], dtype=float)
        MFM = np.asarray(nc.variables["MF_meridional_toprows"][time_index], dtype=float)

    ny, nx = MF.shape
    x1d_km = np.arange(nx, dtype=float) * DX_KM
    y1d_km = np.arange(ny, dtype=float) * DY_KM

    stacked = np.concatenate([MF.ravel(), MFZ.ravel(), MFM.ravel()])
    vmin, vmax = robust_limits(stacked, 2, 99.9)

    fig, axs = plt.subplots(3, 1, figsize=(22, 8), constrained_layout=True, sharex=True, sharey=True)

    axs[0].pcolormesh(x1d_km, y1d_km, MF, shading="auto", vmin=vmin, vmax=vmax)
    axs[0].set_title("Stitched MF passed clusters summed")
    axs[0].set_ylabel("y km")
    axs[0].set_aspect("equal", adjustable="box")

    axs[1].pcolormesh(x1d_km, y1d_km, MFZ, shading="auto", vmin=vmin, vmax=vmax)
    axs[1].set_title("Stitched MF zonal share cos2")
    axs[1].set_ylabel("y km")
    axs[1].set_aspect("equal", adjustable="box")

    im2 = axs[2].pcolormesh(x1d_km, y1d_km, MFM, shading="auto", vmin=vmin, vmax=vmax)
    axs[2].set_title("Stitched MF meridional share sin2")
    axs[2].set_xlabel("x km")
    axs[2].set_ylabel("y km")
    axs[2].set_aspect("equal", adjustable="box")

    for ax in axs:
        ax.set_ylim(0, 600)

    cbar = fig.colorbar(im2, ax=axs, fraction=0.02, pad=0.01)
    cbar.set_label("MF m2 s-2")
    save_fig(fig, outpng)

    del MF, MFZ, MFM, stacked, fig, axs
    gc.collect()


# ============================================================
# Pairing utilities
# ============================================================
def _key_from_stem(stem: str) -> str:
    """
    Turn:
      awe_l6c_q20_2024165T2120_03175_v01
      awe_l6a_tmp_2024165T2120_03175_v01
    into the common key:
      2024165T2120_03175_v01
    """
    parts = stem.split("_")
    if len(parts) < 5:
        return stem
    kind = parts[1]  # l6a or l6c
    if kind in {"l6c", "l6a"}:
        return "_".join(parts[3:])
    return "_".join(parts[2:])


def find_l6_pairs(l6_dir: Path) -> List[Tuple[Path, Path, str]]:
    """
    Returns list of (l6c_path, l6a_path, key)
    """
    l6_dir = Path(l6_dir)
    l6c_files = sorted(l6_dir.glob("*l6c*.nc"))
    l6a_files = sorted(l6_dir.glob("*l6a*.nc"))

    l6c_by_key: Dict[str, Path] = {_key_from_stem(p.stem): p for p in l6c_files}
    l6a_by_key: Dict[str, Path] = {_key_from_stem(p.stem): p for p in l6a_files}

    keys = sorted(set(l6c_by_key) & set(l6a_by_key))
    return [(l6c_by_key[k], l6a_by_key[k], k) for k in keys]


def make_l7a_name_from_l6a(l6a_path: Path) -> str:
    """
    Rename l6a -> l7a in the filename, keep everything else.
    """
    name = l6a_path.name
    name = name.replace("_l6a_", "_l7a_")
    name = name.replace("l6a", "l7a")
    return name


# ============================================================
# One pair runner
# ============================================================
def run_one_pair(l6c_path: Path, l6a_path: Path, outdir: Path) -> Dict[str, Any]:
    outdir.mkdir(parents=True, exist_ok=True)

    out_l7a = L7_DIR / make_l7a_name_from_l6a(l6a_path)

    l6c = load_l6_for_matching(l6c_path)
    l6a = load_l6_for_matching(l6a_path)

    all_slices_a = np.unique(l6a["SlicesNo"]).astype(int)
    all_slices_a = all_slices_a[all_slices_a >= 0]
    all_slices_a = np.sort(all_slices_a)

    summary_lines: List[str] = []
    summary_lines.append(f"L6A: {l6a_path}\n")
    summary_lines.append(f"L6C: {l6c_path}\n\n")
    summary_lines.append("slice  nA  nC  nBestSaved  nPassed  note\n")

    passed_global_indices: List[int] = []

    for slice_no in all_slices_a:
        idx_a = np.where(l6a["SlicesNo"] == int(slice_no))[0]
        idx_c = np.where(l6c["SlicesNo"] == int(slice_no))[0]

        slice_dir = outdir / f"slice_{slice_no:03d}"
        pairs_dir = slice_dir / "pairs"
        pairs_dir.mkdir(parents=True, exist_ok=True)

        if idx_a.size == 0:
            summary_lines.append(f"{slice_no:5d}  {0:2d}  {idx_c.size:2d}  {0:10d}  {0:7d}  no L6A clusters\n")
            continue
        if idx_c.size == 0:
            (slice_dir / "NO_L6C_CLUSTERS.txt").write_text(f"No L6C clusters for slice {slice_no}\n")
            summary_lines.append(f"{slice_no:5d}  {idx_a.size:2d}  {0:2d}  {0:10d}  {0:7d}  no L6C clusters\n")
            continue

        all_candidate_rows: List[Dict[str, Any]] = []
        best_rows: List[Dict[str, Any]] = []

        for a_idx in idx_a:
            a_idx = int(a_idx)
            A_a = l6a["Amplitude"][a_idx]
            L_a = l6a["DominantWavelength"][a_idx]
            T_a = l6a["Angle"][a_idx]

            candidates: List[Dict[str, Any]] = []
            for c_idx in idx_c:
                c_idx = int(c_idx)
                A_c = l6c["Amplitude"][c_idx]
                L_c = l6c["DominantWavelength"][c_idx]
                T_c = l6c["Angle"][c_idx]

                m = compute_match_metrics(A_a, L_a, T_a, A_c, L_c, T_c)
                m["cluster_a"] = a_idx
                m["cluster_c"] = c_idx
                m["passes"] = bool(passes_thresholds(m))
                m["score"] = float(score(m))
                candidates.append(m)
                all_candidate_rows.append(m)

            passed = [c for c in candidates if c["passes"]]
            best = max(passed, key=lambda d: d["score"]) if passed else max(candidates, key=lambda d: d["score"])

            if best["passes"] or ASSIGN_BEST_EVEN_IF_FAILS:
                best_rows.append(best)

                if SAVE_PAIR_PLOTS:
                    left_maps = get_cluster_maps(l6a, best["cluster_a"])
                    right_maps = get_cluster_maps(l6c, best["cluster_c"])

                    pass_tag = "PASS" if best["passes"] else "FAIL"
                    outpng = pairs_dir / f"slice_{slice_no:03d}_A_{best['cluster_a']:04d}_to_C_{best['cluster_c']:04d}_{pass_tag}.png"

                    title_left = (
                        f"L6A Temp | slice {slice_no} | idx {best['cluster_a']} | "
                        f"n={np.count_nonzero(np.isfinite(left_maps['A']))}"
                    )
                    title_right = (
                        f"L6C Rad | slice {slice_no} | idx {best['cluster_c']} | "
                        f"IoU={best['iou']:.3f} inter={best['n_intersection']} "
                        f"ratio={best['lam_ratio']:.3f} Δθ={best['ang_diff_deg']:.1f}°"
                    )

                    plot_side_by_side_4rows(
                        left=left_maps,
                        right=right_maps,
                        title_left=title_left,
                        title_right=title_right,
                        outpath=outpng,
                        dx_km=DX_KM,
                        dy_km=DY_KM,
                    )

                    del left_maps, right_maps
                    gc.collect()

        # Write candidate lists for this slice
        (slice_dir / f"slice_{slice_no:03d}_ALL_candidates_ratio.txt").write_text(
            "cluster_a  cluster_c  passes  score    iou    inter  lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
            + "".join(
                f"{m['cluster_a']:9d}  {m['cluster_c']:9d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
                f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
                f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
                f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
                f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
                for m in sorted(all_candidate_rows, key=lambda d: (d["cluster_a"], -d["score"]))
            )
        )

        (slice_dir / f"slice_{slice_no:03d}_BEST_matches_A_to_C_ratio.txt").write_text(
            "cluster_a  best_cluster_c  passes  score    iou    inter  lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
            + "".join(
                f"{m['cluster_a']:9d}  {m['cluster_c']:14d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
                f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
                f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
                f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
                f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
                for m in sorted(best_rows, key=lambda d: d["cluster_a"])
            )
        )

        passed_here = [int(m["cluster_a"]) for m in best_rows if bool(m["passes"])]
        passed_global_indices.extend(passed_here)

        summary_lines.append(
            f"{slice_no:5d}  {idx_a.size:2d}  {idx_c.size:2d}  {len(best_rows):10d}  {len(passed_here):7d}  ok\n"
        )

        del all_candidate_rows, best_rows
        gc.collect()

    summary_path = outdir / "SUMMARY_all_slices.txt"
    summary_path.write_text("".join(summary_lines))

    passed_global_indices = sorted(set(passed_global_indices))
    passed_idx = np.asarray(passed_global_indices, dtype=int)

    if passed_idx.size == 0:
        return dict(ok=False, l6c=str(l6c_path), l6a=str(l6a_path), outdir=str(outdir), l7a=str(out_l7a), n_passed=0,
                    summary=str(summary_path), note="No passed clusters")

    create_passed_only_l6a_with_new_vars(
        src_l6a=l6a_path,
        dst_l7a=out_l7a,
        passed_cluster_indices=passed_idx,
        time_index=TIME_INDEX,
    )

    if SAVE_STITCHED_PLOTS:
        with Dataset(out_l7a, "r") as nc:
            MF2 = np.asarray(nc.variables["MF_toprows"][TIME_INDEX], dtype=float)
            ny, nx = MF2.shape
            x1d_km = np.arange(nx, dtype=float) * DX_KM
            y1d_km = np.arange(ny, dtype=float) * DY_KM
            vmin, vmax = robust_limits(MF2, 2, 99.9)

            fig, ax = plt.subplots(figsize=(22, 3), constrained_layout=True)
            im = ax.pcolormesh(x1d_km, y1d_km, MF2, shading="auto", vmin=vmin, vmax=vmax)
            ax.set_title("Momentum Flux (passed clusters summed)")
            ax.set_xlabel("x (km)")
            ax.set_ylabel("y (km)")
            ax.set_ylim(0, 600)
            ax.set_aspect("equal", adjustable="box")
            fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01).set_label("MF (m2 s-2)")
            save_fig(fig, outdir / "MF_stitched.png")

        plot_stitched_mf_components(out_l7a, outdir / "MF_stitched_components.png", TIME_INDEX)

    # Per-cluster panels are optional and heavy
    # (kept as a hook, but default is False)
    if SAVE_PER_CLUSTER_PANELS:
        # You can plug your per-cluster plotting function here if you want it in batch.
        pass

    del l6c, l6a, passed_idx
    mpl.pyplot.close("all")
    gc.collect()

    return dict(ok=True, l6c=str(l6c_path), l6a=str(l6a_path), outdir=str(outdir), l7a=str(out_l7a),
                n_passed=int(passed_global_indices.__len__()), summary=str(summary_path), note="ok")


# ============================================================
# Main batch
# ============================================================
pairs = find_l6_pairs(L6_DIR)
print(f"Found {len(pairs)} L6C/L6A pairs in: {L6_DIR.resolve()}")

results: List[Dict[str, Any]] = []
errors: List[Dict[str, Any]] = []

for l6c_path, l6a_path, key in pairs:
    pair_outdir = BATCH_OUTROOT / key
    print(f"\n--- Running pair key={key} ---")
    print("L6C:", l6c_path.name)
    print("L6A:", l6a_path.name)
    try:
        res = run_one_pair(l6c_path, l6a_path, pair_outdir)
        results.append(res)
        print(f"OK={res['ok']}  n_passed={res.get('n_passed', 'NA')}")
        print("L7A:", res.get("l7a"))
        print("Outdir:", pair_outdir)
    except Exception as e:
        err = dict(
            ok=False,
            l6c=str(l6c_path),
            l6a=str(l6a_path),
            key=key,
            outdir=str(pair_outdir),
            error=str(e),
            traceback=traceback.format_exc(),
        )
        errors.append(err)
        print("FAILED:", e)

# batch summary
summary_txt = BATCH_OUTROOT / "BATCH_SUMMARY.txt"
lines: List[str] = []
lines.append(f"Input dir: {L6_DIR.resolve()}\n")
lines.append(f"Output nc dir (l7): {L7_DIR.resolve()}\n")
lines.append(f"Pairs found: {len(pairs)}\n")
lines.append(f"Success: {sum(1 for r in results if r.get('ok'))}\n")
lines.append(f"Fail: {len(errors)}\n\n")

lines.append("Per pair:\n")
for r in results:
    key = Path(r["outdir"]).name
    lines.append(f"{key}  ok={r['ok']}  n_passed={r.get('n_passed', 0)}  l7a={r.get('l7a')}\n")

if errors:
    lines.append("\nErrors:\n")
    for e in errors:
        lines.append(f"{e['key']}  {e['error']}\n")

summary_txt.write_text("".join(lines))

mpl.pyplot.close("all")
gc.collect()

print("\nBatch done.")
print("Batch outroot:", BATCH_OUTROOT.resolve())
print("L7 output folder:", L7_DIR.resolve())
print("Batch summary:", summary_txt.resolve())
# Out:
# Found 9 L6C/L6A pairs in: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/l6
#
# --- Running pair key=2024165T1335_03170_v01 ---
# L6C: awe_l6c_q20_2024165T1335_03170_v01.nc
# L6A: awe_l6a_tmp_2024165T1335_03170_v01.nc
# OK=True  n_passed=22
# L7A: l7/awe_l7a_tmp_2024165T1335_03170_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T1335_03170_v01
#
# --- Running pair key=2024165T1508_03171_v01 ---
# L6C: awe_l6c_q20_2024165T1508_03171_v01.nc
# L6A: awe_l6a_tmp_2024165T1508_03171_v01.nc
# OK=True  n_passed=38
# L7A: l7/awe_l7a_tmp_2024165T1508_03171_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T1508_03171_v01
#
# --- Running pair key=2024165T1641_03172_v01 ---
# L6C: awe_l6c_q20_2024165T1641_03172_v01.nc
# L6A: awe_l6a_tmp_2024165T1641_03172_v01.nc
# OK=True  n_passed=77
# L7A: l7/awe_l7a_tmp_2024165T1641_03172_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T1641_03172_v01
#
# --- Running pair key=2024165T1814_03173_v01 ---
# L6C: awe_l6c_q20_2024165T1814_03173_v01.nc
# L6A: awe_l6a_tmp_2024165T1814_03173_v01.nc
# OK=True  n_passed=18
# L7A: l7/awe_l7a_tmp_2024165T1814_03173_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T1814_03173_v01
#
# --- Running pair key=2024165T2120_03175_v01 ---
# L6C: awe_l6c_q20_2024165T2120_03175_v01.nc
# L6A: awe_l6a_tmp_2024165T2120_03175_v01.nc
# OK=True  n_passed=34
# L7A: l7/awe_l7a_tmp_2024165T2120_03175_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T2120_03175_v01
#
# --- Running pair key=2024165T2252_03176_v01 ---
# L6C: awe_l6c_q20_2024165T2252_03176_v01.nc
# L6A: awe_l6a_tmp_2024165T2252_03176_v01.nc
# OK=True  n_passed=73
# L7A: l7/awe_l7a_tmp_2024165T2252_03176_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T2252_03176_v01
#
# --- Running pair key=2024166T0025_03177_v01 ---
# L6C: awe_l6c_q20_2024166T0025_03177_v01.nc
# L6A: awe_l6a_tmp_2024166T0025_03177_v01.nc
# OK=True  n_passed=69
# L7A: l7/awe_l7a_tmp_2024166T0025_03177_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024166T0025_03177_v01
#
# --- Running pair key=2024166T0158_03178_v01 ---
# L6C: awe_l6c_q20_2024166T0158_03178_v01.nc
# L6A: awe_l6a_tmp_2024166T0158_03178_v01.nc
# OK=True  n_passed=222
# L7A: l7/awe_l7a_tmp_2024166T0158_03178_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024166T0158_03178_v01
#
# --- Running pair key=2024166T0331_03179_v01 ---
# L6C: awe_l6c_q20_2024166T0331_03179_v01.nc
# L6A: awe_l6a_tmp_2024166T0331_03179_v01.nc
# OK=True  n_passed=488
# L7A: l7/awe_l7a_tmp_2024166T0331_03179_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024166T0331_03179_v01
#
# Batch done.
# Batch outroot: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF
# L7 output folder: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/l7
# Batch summary: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/BATCH_SUMMARY.txt

# %% [markdown]
# ## Flat Lat, Lon, T

# %%
# %%
"""
BATCH: ALL-SLICES matching + per-slice combined L6A recon + FULL-ORBIT stitched recon
+ slice Temperature + momentum flux for PASSED clusters only
+ sum MF per slice + stitch MF across orbit
+ output NetCDF contains original L6A global attrs + variables, but ONLY PASSED clusters
  are kept for cluster-dimension variables.

Momentum flux (per cluster pixel, masked to cluster area):
MF = 1/2 * g^2 / N^2 * (lambda_z / lambda_x) * (Amplitude / Temperature)^2 * (1/c^2)

Key rules:
- SliceNo already exists in L6A, keep it (but subset to passed clusters)
- Area, Amplitude, DominantWavelength, Angle already exist (subset to passed clusters)
- Also slice Temperature into Temp_cluster (passed clusters only)
- Add geodesic Bearing (0 = East, counter-clockwise) as Bearing + Bearing_cluster
- Only save passed clusters (output file cluster vars are subset)
- Add MF_cluster, MF_slice_sum, MF_toprows
- Also write flattened toprows Temperature, Latitude, Longitude aligned with MF_toprows

BATCH behavior:
- Scan L6_DIR for L6A and L6C files
- Pair by common suffix key like: 2024165T2120_03175_v01
- For each pair, write the new file into L7_DIR and rename l6a -> l7a
- Save plots + text into outputs folder per key
"""

from __future__ import annotations

from pathlib import Path
from typing import Dict, Any, List, Tuple
import traceback
import gc

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from netCDF4 import Dataset

# ============================================================
# Batch params
# ============================================================
L6_DIR = Path("l6")  # contains many L6A/L6C files
L7_DIR = Path("l7")  # where new NetCDFs go
L7_DIR.mkdir(parents=True, exist_ok=True)

BATCH_OUTROOT = Path("outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF")
BATCH_OUTROOT.mkdir(parents=True, exist_ok=True)

SAVE_DPI = 200
DX_KM = 2.0
DY_KM = 2.0

# ---- Synthetic u,v,N^2 settings ----
TEMP_VAR_NAME = "Temperature"
TIME_INDEX = 0
N2_VALUE = 4e-4
U_VALUE = 0.0
V_VALUE = 0.0

# ---- Momentum flux constants ----
G_MS2 = 9.52
LAMBDA_Z_KM = 10.0
C_CANCEL = 1.0

# --------------------------
# Matching thresholds (tune)
# --------------------------
MIN_IOU = 0.05
MIN_INTERSECTION_PIX = 50
MAX_LAMBDA_MED_RATIO = 1.25
MAX_ANGLE_DIFF_DEG = 15.0

# Save best match even if FAIL (does NOT affect passing)
ASSIGN_BEST_EVEN_IF_FAILS = True

# --------------------------
# Plot saving switches (batch friendly)
# --------------------------
SAVE_PAIR_PLOTS = False          # side-by-side A vs C match PNGs per slice (heavy)
SAVE_PER_CLUSTER_PANELS = False  # big panels per passed cluster (heavy)
SAVE_STITCHED_PLOTS = True       # MF_stitched.png + MF_stitched_components.png


# ============================================================
# Helpers
# ============================================================
def save_fig(fig: plt.Figure, outpath: Path) -> None:
    outpath.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(outpath, dpi=SAVE_DPI, bbox_inches="tight")
    plt.close(fig)


def robust_limits(A: np.ndarray, p_lo: float = 2, p_hi: float = 98) -> Tuple[float, float]:
    a = np.asarray(A)
    good = np.isfinite(a)
    if not np.any(good):
        return (-1.0, 1.0)
    lo, hi = np.nanpercentile(a[good], [p_lo, p_hi])
    if (not np.isfinite(lo)) or (not np.isfinite(hi)) or lo == hi:
        lo = float(np.nanmin(a[good]))
        hi = float(np.nanmax(a[good]))
    return (float(lo), float(hi))


def nanpercentile_safe(a: np.ndarray, q: float) -> float:
    good = np.isfinite(a)
    if not np.any(good):
        return np.nan
    return float(np.nanpercentile(a[good], q))


def circ_diff_deg_180(a_deg: float, b_deg: float) -> float:
    if (not np.isfinite(a_deg)) or (not np.isfinite(b_deg)):
        return np.nan
    d = abs(a_deg - b_deg) % 180.0
    return min(d, 180.0 - d)


def circ_median_deg_180(theta_rad: np.ndarray, mask: np.ndarray) -> float:
    th = np.asarray(theta_rad, dtype=float)
    m = mask & np.isfinite(th)
    if not np.any(m):
        return np.nan
    ang = th[m]
    z = np.exp(1j * 2.0 * ang)
    zmean = np.mean(z)
    if (not np.isfinite(zmean.real)) or (not np.isfinite(zmean.imag)) or abs(zmean) == 0:
        return np.nan
    th_mean = 0.5 * np.angle(zmean)
    deg = (np.degrees(th_mean) + 180.0) % 180.0
    return float(deg)


# -------------------------
# Geodesic bearing: 0 = East, CCW
# -------------------------
def initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    lat1 = np.deg2rad(lat1_deg)
    lon1 = np.deg2rad(lon1_deg)
    lat2 = np.deg2rad(lat2_deg)
    lon2 = np.deg2rad(lon2_deg)

    dlon = lon2 - lon1
    x = np.sin(dlon) * np.cos(lat2)
    y = np.cos(lat1) * np.sin(lat2) - np.sin(lat1) * np.cos(lat2) * np.cos(dlon)

    az = np.arctan2(x, y)
    return (np.rad2deg(az) + 360.0) % 360.0


def bearing_deg_east_ccw_from_points(lat1_deg, lon1_deg, lat2_deg, lon2_deg):
    az_north_cw = initial_bearing_deg_north_cw(lat1_deg, lon1_deg, lat2_deg, lon2_deg)
    return (90.0 - az_north_cw) % 360.0


def compute_bearing_to_x_neighbor_east_ccw(lat2d: np.ndarray, lon2d: np.ndarray) -> np.ndarray:
    lat = np.asarray(lat2d, dtype=float)
    lon = np.asarray(lon2d, dtype=float)

    lat2 = np.empty_like(lat)
    lon2 = np.empty_like(lon)

    lat2[:, :-1] = lat[:, 1:]
    lon2[:, :-1] = lon[:, 1:]
    lat2[:, -1] = lat[:, -2]
    lon2[:, -1] = lon[:, -2]

    bearing = bearing_deg_east_ccw_from_points(lat, lon, lat2, lon2)
    good = np.isfinite(lat) & np.isfinite(lon) & np.isfinite(lat2) & np.isfinite(lon2)
    return np.where(good, bearing, np.nan)


# ============================================================
# Matching IO (memory friendly): do NOT load ClusterReconstruction upfront
# ============================================================
def load_l6_for_matching(path: Path) -> Dict[str, Any]:
    with Dataset(path, "r") as nc:
        return {
            "path": str(path),
            "SlicesNo": np.asarray(nc.variables["SlicesNo"][:], dtype=int),
            "Amplitude": np.asarray(nc.variables["Amplitude"][:], dtype=float),
            "DominantWavelength": np.asarray(nc.variables["DominantWavelength"][:], dtype=float),
            "Angle": np.asarray(nc.variables["Angle"][:], dtype=float),
        }


def get_cluster_maps(data: Dict[str, Any], idx: int) -> Dict[str, np.ndarray]:
    """
    Lazy load ClusterReconstruction only for requested idx (only used if SAVE_PAIR_PLOTS=True).
    """
    A = np.asarray(data["Amplitude"][idx], dtype=float)
    L = np.asarray(data["DominantWavelength"][idx], dtype=float)
    T = np.asarray(data["Angle"][idx], dtype=float)

    R = np.full_like(A, np.nan)
    with Dataset(data["path"], "r") as nc:
        if "ClusterReconstruction" in nc.variables:
            R = np.asarray(nc.variables["ClusterReconstruction"][idx], dtype=float)

    return dict(R=R, A=A, L=L, T=T)


def compute_match_metrics(
    A_src: np.ndarray, L_src: np.ndarray, T_src: np.ndarray,
    A_cand: np.ndarray, L_cand: np.ndarray, T_cand: np.ndarray,
) -> Dict[str, Any]:
    mask_src = np.isfinite(A_src)
    mask_cand = np.isfinite(A_cand)
    inter = mask_src & mask_cand
    union = mask_src | mask_cand

    n_inter = int(np.count_nonzero(inter))
    n_union = int(np.count_nonzero(union))
    iou = (n_inter / n_union) if n_union > 0 else 0.0

    lam_src = L_src[inter]
    lam_cand = L_cand[inter]
    lam_src_med = nanpercentile_safe(lam_src, 50)
    lam_cand_med = nanpercentile_safe(lam_cand, 50)

    if np.isfinite(lam_src_med) and np.isfinite(lam_cand_med) and lam_src_med > 0 and lam_cand_med > 0:
        lam_ratio = max(lam_src_med, lam_cand_med) / min(lam_src_med, lam_cand_med)
    else:
        lam_ratio = np.nan

    ang_src_deg = circ_median_deg_180(T_src, inter)
    ang_cand_deg = circ_median_deg_180(T_cand, inter)
    ang_diff_deg = circ_diff_deg_180(ang_src_deg, ang_cand_deg)

    return dict(
        n_intersection=n_inter,
        iou=float(iou),
        lam_src_med=float(lam_src_med),
        lam_cand_med=float(lam_cand_med),
        lam_ratio=float(lam_ratio),
        ang_src_deg=float(ang_src_deg),
        ang_cand_deg=float(ang_cand_deg),
        ang_diff_deg=float(ang_diff_deg),
    )


def passes_thresholds(m: Dict[str, Any]) -> bool:
    if m["iou"] < MIN_IOU:
        return False
    if m["n_intersection"] < MIN_INTERSECTION_PIX:
        return False
    if (not np.isfinite(m["lam_ratio"])) or (m["lam_ratio"] > MAX_LAMBDA_MED_RATIO):
        return False
    if (not np.isfinite(m["ang_diff_deg"])) or (m["ang_diff_deg"] > MAX_ANGLE_DIFF_DEG):
        return False
    return True


def score(m: Dict[str, Any]) -> float:
    ang = m["ang_diff_deg"]
    if not np.isfinite(ang):
        ang = 999.0
    r = m["lam_ratio"]
    if (not np.isfinite(r)) or r <= 0:
        return 0.0
    return float(m["iou"]) * (1.0 / float(r)) / (1.0 + float(ang))


def plot_side_by_side_4rows(
    left: Dict[str, np.ndarray],
    right: Dict[str, np.ndarray],
    title_left: str,
    title_right: str,
    outpath: Path,
    dx_km: float,
    dy_km: float,
) -> None:
    ny, nx = left["A"].shape
    x1d_km = np.arange(nx, dtype=float) * dx_km
    y1d_km = np.arange(ny, dtype=float) * dy_km

    Rl_vmin, Rl_vmax = robust_limits(left["R"])
    Rr_vmin, Rr_vmax = robust_limits(right["R"])
    Al_vmin, Al_vmax = robust_limits(left["A"])
    Ar_vmin, Ar_vmax = robust_limits(right["A"])

    L_vmin, L_vmax = robust_limits(np.concatenate([left["L"].ravel(), right["L"].ravel()]), 5, 95)
    T_vmin, T_vmax = robust_limits(np.concatenate([left["T"].ravel(), right["T"].ravel()]))

    fig, axs = plt.subplots(4, 2, figsize=(16, 14), constrained_layout=True, sharex=True, sharey=True)

    def _panel(ax, Z, vmin, vmax, label, cmap=None):
        im = ax.pcolormesh(x1d_km, y1d_km, Z, shading="auto", vmin=vmin, vmax=vmax, cmap=cmap)
        cb = fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01)
        cb.set_label(label)
        ax.set_aspect("equal", adjustable="box")

    axs[0, 0].set_title(title_left)
    axs[0, 1].set_title(title_right)

    _panel(axs[0, 0], left["R"], Rl_vmin, Rl_vmax, "arb", cmap="RdBu_r")
    _panel(axs[0, 1], right["R"], Rr_vmin, Rr_vmax, "arb", cmap="RdBu_r")
    axs[0, 0].set_ylabel("Recon\ny (km)")

    _panel(axs[1, 0], left["A"], Al_vmin, Al_vmax, "K")
    _panel(axs[1, 1], right["A"], Ar_vmin, Ar_vmax, "kR")
    axs[1, 0].set_ylabel("Amp\ny (km)")

    _panel(axs[2, 0], left["L"], L_vmin, L_vmax, "km")
    _panel(axs[2, 1], right["L"], L_vmin, L_vmax, "km")
    axs[2, 0].set_ylabel("Lambda\ny (km)")

    _panel(axs[3, 0], left["T"], T_vmin, T_vmax, "rad")
    _panel(axs[3, 1], right["T"], T_vmin, T_vmax, "rad")
    axs[3, 0].set_ylabel("Angle\ny (km)")

    for r in range(4):
        for c in range(2):
            axs[r, c].set_xlabel("x (km)")

    save_fig(fig, outpath)


# --------------------------
# Flatten swath BEFORE slicing
# --------------------------
def flatten_swath(Z: np.ndarray, target_ny: int | None = None) -> np.ndarray:
    ny, nx = Z.shape
    out = np.full_like(Z, np.nan)

    bottoms = np.full(nx, np.nan, dtype=float)
    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size:
            bottoms[j] = valid_idx.max()

    valid_bottoms = bottoms[np.isfinite(bottoms)]
    if valid_bottoms.size == 0:
        med = float(np.nanmedian(Z)) if np.isfinite(np.nanmedian(Z)) else 0.0
        out = np.nan_to_num(Z, nan=med, posinf=med, neginf=med)
        if target_ny is not None and ny > target_ny:
            out = out[-target_ny:, :]
        return out

    max_bottom = int(valid_bottoms.max())

    for j in range(nx):
        col = Z[:, j]
        valid_idx = np.where(np.isfinite(col))[0]
        if valid_idx.size == 0:
            continue
        bottom = int(valid_idx.max())
        shift = max_bottom - bottom
        if shift == 0:
            out[:, j] = col
        elif shift > 0:
            out[shift:, j] = col[: ny - shift]
        else:
            shift_up = -shift
            out[: ny - shift_up, j] = col[shift_up:]

    med = float(np.nanmedian(out)) if np.isfinite(np.nanmedian(out)) else 0.0
    out = np.nan_to_num(out, nan=med, posinf=med, neginf=med)

    if target_ny is not None and ny > target_ny:
        start = max_bottom + 1 - target_ny
        start = max(start, 0)
        end = start + target_ny
        out = out[start:end, :]

    return out


# ============================================================
# L6A cloning with PASSED-only cluster variables + new vars
# ============================================================
def create_passed_only_l6a_with_new_vars(
    src_l6a: Path,
    dst_l7a: Path,
    passed_cluster_indices: np.ndarray,
    time_index: int,
) -> Tuple[str, str, str]:
    passed_cluster_indices = np.asarray(passed_cluster_indices, dtype=int)
    if passed_cluster_indices.size == 0:
        raise ValueError("No passed clusters. Output would be empty.")

    dst_l7a.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(src_l6a, "r") as src:
        amp_var = src.variables["Amplitude"]
        cluster_dim, ytile_dim, xtile_dim = amp_var.dimensions[:3]
        _, y_tile, x_tile = amp_var.shape

        temp_var = src.variables[TEMP_VAR_NAME]
        temp_dims = temp_var.dimensions
        temp_shape = temp_var.shape
        temp_raw_2d = np.asarray(temp_var[time_index], dtype=float)

        u_raw_2d = (
            np.asarray(src.variables["u"][time_index], dtype=float)
            if "u" in src.variables
            else np.full_like(temp_raw_2d, U_VALUE, dtype=float)
        )
        v_raw_2d = (
            np.asarray(src.variables["v"][time_index], dtype=float)
            if "v" in src.variables
            else np.full_like(temp_raw_2d, V_VALUE, dtype=float)
        )
        n2_raw_2d = (
            np.asarray(src.variables["NSquared"][time_index], dtype=float)
            if "NSquared" in src.variables
            else np.full_like(temp_raw_2d, N2_VALUE, dtype=float)
        )

        # ---- Latitude/Longitude (optional) + bearing uses RAW geo ----
        if ("Latitude" in src.variables) and ("Longitude" in src.variables):
            lat_raw_2d = np.asarray(src.variables["Latitude"][time_index], dtype=float)
            lon_raw_2d = np.asarray(src.variables["Longitude"][time_index], dtype=float)

            bearing_raw_2d = compute_bearing_to_x_neighbor_east_ccw(lat_raw_2d, lon_raw_2d)

            lat_full_2d = flatten_swath(lat_raw_2d, target_ny=y_tile)
            lon_full_2d = flatten_swath(lon_raw_2d, target_ny=y_tile)
        else:
            lat_raw_2d = None
            lon_raw_2d = None
            bearing_raw_2d = np.full_like(temp_raw_2d, np.nan, dtype=float)
            lat_full_2d = np.full((y_tile, temp_raw_2d.shape[1]), np.nan, dtype=float)
            lon_full_2d = np.full((y_tile, temp_raw_2d.shape[1]), np.nan, dtype=float)

        temp_full_2d = flatten_swath(temp_raw_2d, target_ny=y_tile)
        u_full_2d = flatten_swath(u_raw_2d, target_ny=y_tile)
        v_full_2d = flatten_swath(v_raw_2d, target_ny=y_tile)
        n2_full_2d = flatten_swath(n2_raw_2d, target_ny=y_tile)
        bearing_full_2d = flatten_swath(bearing_raw_2d, target_ny=y_tile)

        n_passed = int(passed_cluster_indices.size)

        with Dataset(dst_l7a, "w") as dst:
            for aname in src.ncattrs():
                dst.setncattr(aname, src.getncattr(aname))

            for dname, dim in src.dimensions.items():
                if dname == cluster_dim:
                    dst.createDimension(dname, n_passed)
                else:
                    dst.createDimension(dname, (None if dim.isunlimited() else len(dim)))

            # Copy all variables, but subset cluster_dim variables to PASSED ONLY
            for vname, vsrc in src.variables.items():
                fill_value = vsrc.getncattr("_FillValue") if "_FillValue" in vsrc.ncattrs() else None
                vdst = dst.createVariable(
                    vname,
                    vsrc.dtype,
                    vsrc.dimensions,
                    zlib=True,
                    complevel=4,
                    fill_value=fill_value,
                )
                for aname in vsrc.ncattrs():
                    if aname != "_FillValue":
                        vdst.setncattr(aname, vsrc.getncattr(aname))

                if cluster_dim in vsrc.dimensions:
                    ax = vsrc.dimensions.index(cluster_dim)
                    vdst[:] = np.take(vsrc[:], passed_cluster_indices, axis=ax)
                else:
                    vdst[:] = vsrc[:]

            # Bearing full field (same dims as Temperature)
            bearing_full = np.zeros(temp_shape, dtype=np.float32)
            bearing_full[time_index, 0:y_tile, :] = bearing_full_2d.astype(np.float32)

            if "Bearing" in dst.variables:
                dst.variables["Bearing"][:] = bearing_full
            else:
                vB = dst.createVariable("Bearing", "f4", temp_dims, zlib=True, complevel=4)
                vB.setncattr("long_name", "Geodesic bearing to +x neighbor (0=East, CCW)")
                vB.setncattr("units", "degree")
                vB[:] = bearing_full

            # Allocate per cluster masked tiles
            temp_cluster = np.full((n_passed, y_tile, x_tile), np.nan, dtype=np.float32)
            u_cluster = np.full_like(temp_cluster, np.nan)
            v_cluster = np.full_like(temp_cluster, np.nan)
            n2_cluster = np.full_like(temp_cluster, np.nan)
            bearing_cluster = np.full_like(temp_cluster, np.nan)

            mf_cluster = np.full_like(temp_cluster, np.nan)
            mfz_cluster = np.full_like(temp_cluster, np.nan)
            mfm_cluster = np.full_like(temp_cluster, np.nan)

            amp_passed = np.asarray(dst.variables["Amplitude"][:], dtype=float)
            lam_passed = np.asarray(dst.variables["DominantWavelength"][:], dtype=float)
            slice_passed = np.asarray(dst.variables["SlicesNo"][:], dtype=int)
            ang_rad_passed = np.asarray(dst.variables["Angle"][:], dtype=float)

            for j in range(n_passed):
                s = int(slice_passed[j])
                x0 = s * x_tile
                x1 = x0 + x_tile

                mask = np.isfinite(amp_passed[j])

                Ttile = temp_full_2d[:, x0:x1]
                Utile = u_full_2d[:, x0:x1]
                Vtile = v_full_2d[:, x0:x1]
                N2tile = n2_full_2d[:, x0:x1]
                Btile = bearing_full_2d[:, x0:x1]

                temp_cluster[j][mask] = Ttile[mask]
                u_cluster[j][mask] = Utile[mask]
                v_cluster[j][mask] = Vtile[mask]
                n2_cluster[j][mask] = N2tile[mask]
                bearing_cluster[j][mask] = Btile[mask]

                A = amp_passed[j]
                Lx = lam_passed[j]
                ang_deg_tile = (np.rad2deg(ang_rad_passed[j]) % 360.0)

                good = mask
                good = good & np.isfinite(Ttile) & np.isfinite(N2tile) & np.isfinite(Lx) & np.isfinite(Btile)
                good = good & (Ttile != 0.0) & (N2tile > 0.0) & (Lx > 0.0)

                if np.any(good):
                    mf_val = (
                        0.5
                        * (G_MS2**2)
                        / N2tile[good]
                        * (LAMBDA_Z_KM / Lx[good])
                        * (A[good] / Ttile[good]) ** 2
                        * (1.0 / (C_CANCEL**2))
                    )
                    mf_cluster[j][good] = mf_val

                    phi_deg = (Btile[good] + ang_deg_tile[good]) % 360.0
                    phi_rad = np.deg2rad(phi_deg)

                    mfz_cluster[j][good] = mf_val * (np.cos(phi_rad) ** 2)
                    mfm_cluster[j][good] = mf_val * (np.sin(phi_rad) ** 2)

            def _write(name: str, arr: np.ndarray, dims: Tuple[str, ...], long_name: str, units: str):
                if name in dst.variables:
                    dst.variables[name][:] = arr
                else:
                    v = dst.createVariable(name, "f4", dims, zlib=True, complevel=4)
                    v.setncattr("long_name", long_name)
                    v.setncattr("units", units)
                    v[:] = arr

            _write("Temp_cluster", temp_cluster, (cluster_dim, ytile_dim, xtile_dim), "Temperature, cluster masked", "K")
            _write("u_cluster", u_cluster, (cluster_dim, ytile_dim, xtile_dim), "u wind, cluster masked", "m/s")
            _write("v_cluster", v_cluster, (cluster_dim, ytile_dim, xtile_dim), "v wind, cluster masked", "m/s")
            _write("NSquared_cluster", n2_cluster, (cluster_dim, ytile_dim, xtile_dim), "N^2, cluster masked", "s^-2")
            _write("Bearing_cluster", bearing_cluster, (cluster_dim, ytile_dim, xtile_dim), "Bearing (0=East, CCW), cluster masked", "degree")

            _write("MF_cluster", mf_cluster, (cluster_dim, ytile_dim, xtile_dim), "MF proxy per pixel, cluster masked", "m2 s-2")
            _write("MFz_cluster", mfz_cluster, (cluster_dim, ytile_dim, xtile_dim), "MF cos^2(phi)", "m2 s-2")
            _write("MFm_cluster", mfm_cluster, (cluster_dim, ytile_dim, xtile_dim), "MF sin^2(phi)", "m2 s-2")

            # Slice sums on tile grid
            smin, smax = int(np.min(slice_passed)), int(np.max(slice_passed))
            full_slices = np.arange(smin, smax + 1)

            if "slice" not in dst.dimensions:
                dst.createDimension("slice", len(full_slices))
            if "SliceNo_passed_slices" not in dst.variables:
                dst.createVariable("SliceNo_passed_slices", "i4", ("slice",))[:] = full_slices
            else:
                dst.variables["SliceNo_passed_slices"][:] = full_slices

            mf_slice = np.zeros((len(full_slices), y_tile, x_tile), dtype=np.float32)
            mfz_slice = np.zeros_like(mf_slice)
            mfm_slice = np.zeros_like(mf_slice)

            for k, s in enumerate(full_slices):
                idx = np.where(slice_passed == s)[0]
                if idx.size > 0:
                    mf_slice[k] = np.nansum(mf_cluster[idx], axis=0)
                    mfz_slice[k] = np.nansum(mfz_cluster[idx], axis=0)
                    mfm_slice[k] = np.nansum(mfm_cluster[idx], axis=0)

            _write("MF_slice", mf_slice, ("slice", ytile_dim, xtile_dim), "Per slice MF sum (passed clusters), tile grid", "m2 s-2")
            _write("MFz_slice", mfz_slice, ("slice", ytile_dim, xtile_dim), "Per slice zonal MF sum (passed clusters), tile grid", "m2 s-2")
            _write("MFm_slice", mfm_slice, ("slice", ytile_dim, xtile_dim), "Per slice meridional MF sum (passed clusters), tile grid", "m2 s-2")

            # Stitch onto full x (top tile rows only)
            MF_top = np.full(temp_shape, np.nan, dtype=np.float32)
            MFz_top = np.full(temp_shape, np.nan, dtype=np.float32)
            MFm_top = np.full(temp_shape, np.nan, dtype=np.float32)

            for k, s in enumerate(full_slices):
                x0 = s * x_tile
                x1 = x0 + x_tile
                MF_top[time_index, 0:y_tile, x0:x1] = mf_slice[k]
                MFz_top[time_index, 0:y_tile, x0:x1] = mfz_slice[k]
                MFm_top[time_index, 0:y_tile, x0:x1] = mfm_slice[k]

            _write("MF_top", MF_top, temp_dims, "Stitched MF sum (passed clusters) on top tile rows only", "m2 s-2")
            _write("MFz_top", MFz_top, temp_dims, "Stitched zonal MF share on top tile rows only", "m2 s-2")
            _write("MFm_top", MFm_top, temp_dims, "Stitched meridional MF share on top tile rows only", "m2 s-2")

            # Flattened toprows Temperature, Latitude, Longitude aligned with MF_top
            T_top = np.full(temp_shape, np.nan, dtype=np.float32)
            Lat_top = np.full(temp_shape, np.nan, dtype=np.float32)
            Lon_top = np.full(temp_shape, np.nan, dtype=np.float32)

            T_top[time_index, 0:y_tile, :] = temp_full_2d.astype(np.float32)
            Lat_top[time_index, 0:y_tile, :] = lat_full_2d.astype(np.float32)
            Lon_top[time_index, 0:y_tile, :] = lon_full_2d.astype(np.float32)

            _write("T_top", T_top, temp_dims, "Flattened Temperature on MF_top grid (top tile rows only)", "K")
            _write("Lat_top", Lat_top, temp_dims, "Flattened Latitude on MF_top grid (top tile rows only)", "degree_north")
            _write("Lon_top", Lon_top, temp_dims, "Flattened Longitude on MF_top grid (top tile rows only)", "degree_east")

        del temp_raw_2d, u_raw_2d, v_raw_2d, n2_raw_2d
        del temp_full_2d, u_full_2d, v_full_2d, n2_full_2d
        del bearing_raw_2d, bearing_full_2d
        del temp_cluster, u_cluster, v_cluster, n2_cluster, bearing_cluster
        del mf_cluster, mfz_cluster, mfm_cluster
        gc.collect()

    return cluster_dim, ytile_dim, xtile_dim


# ============================================================
# Plotting
# ============================================================
def plot_stitched_mf_components(nc_path: Path, outpng: Path, time_index: int) -> None:
    outpng.parent.mkdir(parents=True, exist_ok=True)

    with Dataset(nc_path, "r") as nc:
        MF = np.asarray(nc.variables["MF_top"][time_index], dtype=float)
        MFz = np.asarray(nc.variables["MFz_top"][time_index], dtype=float)
        MFm = np.asarray(nc.variables["MFm_top"][time_index], dtype=float)

    ny, nx = MF.shape
    x1d_km = np.arange(nx, dtype=float) * DX_KM
    y1d_km = np.arange(ny, dtype=float) * DY_KM

    stacked = np.concatenate([MF.ravel(), MFz.ravel(), MFm.ravel()])
    vmin, vmax = robust_limits(stacked, 2, 99.9)

    fig, axs = plt.subplots(3, 1, figsize=(22, 8), constrained_layout=True, sharex=True, sharey=True)

    axs[0].pcolormesh(x1d_km, y1d_km, MF, shading="auto", vmin=vmin, vmax=vmax)
    axs[0].set_title("Stitched MF (passed clusters summed)")
    axs[0].set_ylabel("y km")
    axs[0].set_aspect("equal", adjustable="box")

    axs[1].pcolormesh(x1d_km, y1d_km, MFz, shading="auto", vmin=vmin, vmax=vmax)
    axs[1].set_title("Stitched MF zonal share cos2")
    axs[1].set_ylabel("y km")
    axs[1].set_aspect("equal", adjustable="box")

    im2 = axs[2].pcolormesh(x1d_km, y1d_km, MFm, shading="auto", vmin=vmin, vmax=vmax)
    axs[2].set_title("Stitched MF meridional share sin2")
    axs[2].set_xlabel("x km")
    axs[2].set_ylabel("y km")
    axs[2].set_aspect("equal", adjustable="box")

    for ax in axs:
        ax.set_ylim(0, 600)

    cbar = fig.colorbar(im2, ax=axs, fraction=0.02, pad=0.01)
    cbar.set_label("MF m2 s-2")
    save_fig(fig, outpng)

    del MF, MFz, MFm, stacked, fig, axs
    gc.collect()


# ============================================================
# Pairing utilities
# ============================================================
def _key_from_stem(stem: str) -> str:
    """
    Turn:
      awe_l6c_q20_2024165T2120_03175_v01
      awe_l6a_tmp_2024165T2120_03175_v01
    into the common key:
      2024165T2120_03175_v01
    """
    parts = stem.split("_")
    if len(parts) < 5:
        return stem
    kind = parts[1]  # l6a or l6c
    if kind in {"l6c", "l6a"}:
        return "_".join(parts[3:])
    return "_".join(parts[2:])


def find_l6_pairs(l6_dir: Path) -> List[Tuple[Path, Path, str]]:
    """
    Returns list of (l6c_path, l6a_path, key)
    """
    l6_dir = Path(l6_dir)
    l6c_files = sorted(l6_dir.glob("*l6c*.nc"))
    l6a_files = sorted(l6_dir.glob("*l6a*.nc"))

    l6c_by_key: Dict[str, Path] = {_key_from_stem(p.stem): p for p in l6c_files}
    l6a_by_key: Dict[str, Path] = {_key_from_stem(p.stem): p for p in l6a_files}

    keys = sorted(set(l6c_by_key) & set(l6a_by_key))
    return [(l6c_by_key[k], l6a_by_key[k], k) for k in keys]


def make_l7a_name_from_l6a(l6a_path: Path) -> str:
    """
    Rename l6a -> l7a in the filename, keep everything else.
    """
    name = l6a_path.name
    name = name.replace("_l6a_", "_l7a_")
    name = name.replace("l6a", "l7a")
    return name


# ============================================================
# One pair runner
# ============================================================
def run_one_pair(l6c_path: Path, l6a_path: Path, outdir: Path) -> Dict[str, Any]:
    outdir.mkdir(parents=True, exist_ok=True)

    out_l7a = L7_DIR / make_l7a_name_from_l6a(l6a_path)

    l6c = load_l6_for_matching(l6c_path)
    l6a = load_l6_for_matching(l6a_path)

    all_slices_a = np.unique(l6a["SlicesNo"]).astype(int)
    all_slices_a = all_slices_a[all_slices_a >= 0]
    all_slices_a = np.sort(all_slices_a)

    summary_lines: List[str] = []
    summary_lines.append(f"L6A: {l6a_path}\n")
    summary_lines.append(f"L6C: {l6c_path}\n\n")
    summary_lines.append("slice  nA  nC  nBestSaved  nPassed  note\n")

    passed_global_indices: List[int] = []

    for slice_no in all_slices_a:
        idx_a = np.where(l6a["SlicesNo"] == int(slice_no))[0]
        idx_c = np.where(l6c["SlicesNo"] == int(slice_no))[0]

        slice_dir = outdir / f"slice_{slice_no:03d}"
        pairs_dir = slice_dir / "pairs"
        pairs_dir.mkdir(parents=True, exist_ok=True)

        if idx_a.size == 0:
            summary_lines.append(f"{slice_no:5d}  {0:2d}  {idx_c.size:2d}  {0:10d}  {0:7d}  no L6A clusters\n")
            continue
        if idx_c.size == 0:
            (slice_dir / "NO_L6C_CLUSTERS.txt").write_text(f"No L6C clusters for slice {slice_no}\n")
            summary_lines.append(f"{slice_no:5d}  {idx_a.size:2d}  {0:2d}  {0:10d}  {0:7d}  no L6C clusters\n")
            continue

        all_candidate_rows: List[Dict[str, Any]] = []
        best_rows: List[Dict[str, Any]] = []

        for a_idx in idx_a:
            a_idx = int(a_idx)
            A_a = l6a["Amplitude"][a_idx]
            L_a = l6a["DominantWavelength"][a_idx]
            T_a = l6a["Angle"][a_idx]

            candidates: List[Dict[str, Any]] = []
            for c_idx in idx_c:
                c_idx = int(c_idx)
                A_c = l6c["Amplitude"][c_idx]
                L_c = l6c["DominantWavelength"][c_idx]
                T_c = l6c["Angle"][c_idx]

                m = compute_match_metrics(A_a, L_a, T_a, A_c, L_c, T_c)
                m["cluster_a"] = a_idx
                m["cluster_c"] = c_idx
                m["passes"] = bool(passes_thresholds(m))
                m["score"] = float(score(m))
                candidates.append(m)
                all_candidate_rows.append(m)

            passed = [c for c in candidates if c["passes"]]
            best = max(passed, key=lambda d: d["score"]) if passed else max(candidates, key=lambda d: d["score"])

            if best["passes"] or ASSIGN_BEST_EVEN_IF_FAILS:
                best_rows.append(best)

                if SAVE_PAIR_PLOTS:
                    left_maps = get_cluster_maps(l6a, best["cluster_a"])
                    right_maps = get_cluster_maps(l6c, best["cluster_c"])

                    pass_tag = "PASS" if best["passes"] else "FAIL"
                    outpng = pairs_dir / f"slice_{slice_no:03d}_A_{best['cluster_a']:04d}_to_C_{best['cluster_c']:04d}_{pass_tag}.png"

                    title_left = (
                        f"L6A Temp | slice {slice_no} | idx {best['cluster_a']} | "
                        f"n={np.count_nonzero(np.isfinite(left_maps['A']))}"
                    )
                    title_right = (
                        f"L6C Rad | slice {slice_no} | idx {best['cluster_c']} | "
                        f"IoU={best['iou']:.3f} inter={best['n_intersection']} "
                        f"ratio={best['lam_ratio']:.3f} dTheta={best['ang_diff_deg']:.1f}deg"
                    )

                    plot_side_by_side_4rows(
                        left=left_maps,
                        right=right_maps,
                        title_left=title_left,
                        title_right=title_right,
                        outpath=outpng,
                        dx_km=DX_KM,
                        dy_km=DY_KM,
                    )

                    del left_maps, right_maps
                    gc.collect()

        (slice_dir / f"slice_{slice_no:03d}_ALL_candidates_ratio.txt").write_text(
            "cluster_a  cluster_c  passes  score    iou    inter  lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
            + "".join(
                f"{m['cluster_a']:9d}  {m['cluster_c']:9d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
                f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
                f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
                f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
                f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
                for m in sorted(all_candidate_rows, key=lambda d: (d["cluster_a"], -d["score"]))
            )
        )

        (slice_dir / f"slice_{slice_no:03d}_BEST_matches_A_to_C_ratio.txt").write_text(
            "cluster_a  best_cluster_c  passes  score    iou    inter  lam_ratio  ang_diff_deg  thetaA_deg  thetaC_deg  lamA_med  lamC_med\n"
            + "".join(
                f"{m['cluster_a']:9d}  {m['cluster_c']:14d}  {int(m['passes']):6d}  {m['score']:6.3f}  "
                f"{m['iou']:.3f}  {m['n_intersection']:5d}  "
                f"{m['lam_ratio']:8.3f}  {m['ang_diff_deg']:12.1f}  "
                f"{m['ang_src_deg']:10.1f}  {m['ang_cand_deg']:10.1f}  "
                f"{m['lam_src_med']:8.1f}  {m['lam_cand_med']:8.1f}\n"
                for m in sorted(best_rows, key=lambda d: d["cluster_a"])
            )
        )

        passed_here = [int(m["cluster_a"]) for m in best_rows if bool(m["passes"])]
        passed_global_indices.extend(passed_here)

        summary_lines.append(
            f"{slice_no:5d}  {idx_a.size:2d}  {idx_c.size:2d}  {len(best_rows):10d}  {len(passed_here):7d}  ok\n"
        )

        del all_candidate_rows, best_rows
        gc.collect()

    summary_path = outdir / "SUMMARY_all_slices.txt"
    summary_path.write_text("".join(summary_lines))

    passed_global_indices = sorted(set(passed_global_indices))
    passed_idx = np.asarray(passed_global_indices, dtype=int)

    if passed_idx.size == 0:
        return dict(
            ok=False,
            l6c=str(l6c_path),
            l6a=str(l6a_path),
            outdir=str(outdir),
            l7a=str(out_l7a),
            n_passed=0,
            summary=str(summary_path),
            note="No passed clusters",
        )

    create_passed_only_l6a_with_new_vars(
        src_l6a=l6a_path,
        dst_l7a=out_l7a,
        passed_cluster_indices=passed_idx,
        time_index=TIME_INDEX,
    )

    if SAVE_STITCHED_PLOTS:
        with Dataset(out_l7a, "r") as nc:
            MF2 = np.asarray(nc.variables["MF_top"][TIME_INDEX], dtype=float)
            ny, nx = MF2.shape
            x1d_km = np.arange(nx, dtype=float) * DX_KM
            y1d_km = np.arange(ny, dtype=float) * DY_KM
            vmin, vmax = robust_limits(MF2, 2, 99.9)

            fig, ax = plt.subplots(figsize=(22, 3), constrained_layout=True)
            im = ax.pcolormesh(x1d_km, y1d_km, MF2, shading="auto", vmin=vmin, vmax=vmax)
            ax.set_title("Momentum Flux (passed clusters summed)")
            ax.set_xlabel("x (km)")
            ax.set_ylabel("y (km)")
            ax.set_ylim(0, 600)
            ax.set_aspect("equal", adjustable="box")
            fig.colorbar(im, ax=ax, fraction=0.03, pad=0.01).set_label("MF (m2 s-2)")
            save_fig(fig, outdir / "MF_stitched.png")

        plot_stitched_mf_components(out_l7a, outdir / "MF_stitched_components.png", TIME_INDEX)

    if SAVE_PER_CLUSTER_PANELS:
        pass

    del l6c, l6a, passed_idx
    mpl.pyplot.close("all")
    gc.collect()

    return dict(
        ok=True,
        l6c=str(l6c_path),
        l6a=str(l6a_path),
        outdir=str(outdir),
        l7a=str(out_l7a),
        n_passed=int(len(passed_global_indices)),
        summary=str(summary_path),
        note="ok",
    )


# ============================================================
# Main batch
# ============================================================
pairs = find_l6_pairs(L6_DIR)
print(f"Found {len(pairs)} L6C/L6A pairs in: {L6_DIR.resolve()}")

results: List[Dict[str, Any]] = []
errors: List[Dict[str, Any]] = []

for l6c_path, l6a_path, key in pairs:
    pair_outdir = BATCH_OUTROOT / key
    print(f"\nRunning pair key={key}")
    print("L6C:", l6c_path.name)
    print("L6A:", l6a_path.name)
    try:
        res = run_one_pair(l6c_path, l6a_path, pair_outdir)
        results.append(res)
        print(f"OK={res['ok']}  n_passed={res.get('n_passed', 'NA')}")
        print("L7A:", res.get("l7a"))
        print("Outdir:", pair_outdir)
    except Exception as e:
        err = dict(
            ok=False,
            l6c=str(l6c_path),
            l6a=str(l6a_path),
            key=key,
            outdir=str(pair_outdir),
            error=str(e),
            traceback=traceback.format_exc(),
        )
        errors.append(err)
        print("FAILED:", e)

summary_txt = BATCH_OUTROOT / "BATCH_SUMMARY.txt"
lines: List[str] = []
lines.append(f"Input dir: {L6_DIR.resolve()}\n")
lines.append(f"Output nc dir (l7): {L7_DIR.resolve()}\n")
lines.append(f"Pairs found: {len(pairs)}\n")
lines.append(f"Success: {sum(1 for r in results if r.get('ok'))}\n")
lines.append(f"Fail: {len(errors)}\n\n")

lines.append("Per pair:\n")
for r in results:
    key = Path(r["outdir"]).name
    lines.append(f"{key}  ok={r['ok']}  n_passed={r.get('n_passed', 0)}  l7a={r.get('l7a')}\n")

if errors:
    lines.append("\nErrors:\n")
    for e in errors:
        lines.append(f"{e['key']}  {e['error']}\n")

summary_txt.write_text("".join(lines))

mpl.pyplot.close("all")
gc.collect()

print("\nBatch done.")
print("Batch outroot:", BATCH_OUTROOT.resolve())
print("L7 output folder:", L7_DIR.resolve())
print("Batch summary:", summary_txt.resolve())
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Found 9 L6C/L6A pairs in: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/l6
#
# Running pair key=2024165T1335_03170_v01
# L6C: awe_l6c_q20_2024165T1335_03170_v01.nc
# L6A: awe_l6a_tmp_2024165T1335_03170_v01.nc
# OK=True  n_passed=22
# L7A: l7/awe_l7a_tmp_2024165T1335_03170_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T1335_03170_v01
#
# Running pair key=2024165T1508_03171_v01
# L6C: awe_l6c_q20_2024165T1508_03171_v01.nc
# L6A: awe_l6a_tmp_2024165T1508_03171_v01.nc
# OK=True  n_passed=32
# L7A: l7/awe_l7a_tmp_2024165T1508_03171_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T1508_03171_v01
#
# Running pair key=2024165T1641_03172_v01
# L6C: awe_l6c_q20_2024165T1641_03172_v01.nc
# L6A: awe_l6a_tmp_2024165T1641_03172_v01.nc
# OK=True  n_passed=69
# L7A: l7/awe_l7a_tmp_2024165T1641_03172_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T1641_03172_v01
#
# Running pair key=2024165T1814_03173_v01
# L6C: awe_l6c_q20_2024165T1814_03173_v01.nc
# L6A: awe_l6a_tmp_2024165T1814_03173_v01.nc
# OK=True  n_passed=22
# L7A: l7/awe_l7a_tmp_2024165T1814_03173_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T1814_03173_v01
#
# Running pair key=2024165T2120_03175_v01
# L6C: awe_l6c_q20_2024165T2120_03175_v01.nc
# L6A: awe_l6a_tmp_2024165T2120_03175_v01.nc
# OK=True  n_passed=30
# L7A: l7/awe_l7a_tmp_2024165T2120_03175_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T2120_03175_v01
#
# Running pair key=2024165T2252_03176_v01
# L6C: awe_l6c_q20_2024165T2252_03176_v01.nc
# L6A: awe_l6a_tmp_2024165T2252_03176_v01.nc
# OK=True  n_passed=59
# L7A: l7/awe_l7a_tmp_2024165T2252_03176_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024165T2252_03176_v01
#
# Running pair key=2024166T0025_03177_v01
# L6C: awe_l6c_q20_2024166T0025_03177_v01.nc
# L6A: awe_l6a_tmp_2024166T0025_03177_v01.nc
# OK=True  n_passed=47
# L7A: l7/awe_l7a_tmp_2024166T0025_03177_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024166T0025_03177_v01
#
# Running pair key=2024166T0158_03178_v01
# L6C: awe_l6c_q20_2024166T0158_03178_v01.nc
# L6A: awe_l6a_tmp_2024166T0158_03178_v01.nc
# OK=True  n_passed=254
# L7A: l7/awe_l7a_tmp_2024166T0158_03178_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024166T0158_03178_v01
#
# Running pair key=2024166T0331_03179_v01
# L6C: awe_l6c_q20_2024166T0331_03179_v01.nc
# L6A: awe_l6a_tmp_2024166T0331_03179_v01.nc
# OK=True  n_passed=526
# L7A: l7/awe_l7a_tmp_2024166T0331_03179_v01.nc
# Outdir: outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/2024166T0331_03179_v01
#
# Batch done.
# Batch outroot: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF
# L7 output folder: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/l7
# Batch summary: /Users/anhphan/juwavelet_awe/examples/CWT Whole Orbit/outputs_BATCH_l6a_to_l6c_matching_ratio_STITCH_MF/BATCH_SUMMARY.txt

# %% [markdown]
# 689s > 38s, 424

# %% [markdown]
# ## .py file run_batch_parallel_MF ***

# %% [markdown]
# ## Overall plot. Use mean value binning.

# %%
# %%
"""
Global stacked Cartopy maps for MFz and MFm from L7A outputs
for ALL months in a year.

What this does:
1. Loops over all 12 months in YEAR
2. Reads files from: BASE_L7_DIR / YEAR / MM
3. Makes one stacked figure per month
4. Saves all monthly figures into the SAME folder
5. Uses month/year in titles and filenames
"""

from __future__ import annotations

from pathlib import Path
from typing import List, Tuple, Dict
import calendar
import gc

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from netCDF4 import Dataset

# -------------------------
# User params
# -------------------------
YEAR = 2025
MONTHS = range(11, 13)   # 1..12

#BASE_L7_DIR = Path("/Volumes/aweread/socfiles/public/l7")
BASE_L7_DIR = Path("Z:\socfiles\public\l7")
FILE_GLOB = "*l7a*.nc"
TIME_INDEX = 0

LAT_NAME = "Lat_top"
LON_NAME = "Lon_top"

STACK_PAIR = ("MFz_top", "MFm_top")

DISPLAY_NAMES = {
    "MF_top": "Momentum Flux",
    "MFz_top": "Zonal Momentum Flux",
    "MFm_top": "Meridional Momentum Flux",
}

# All monthly stacked figures go here
OUTDIR = Path(f"outputs_MF_cartopy/{YEAR}/stacked_all_months")
OUTDIR.mkdir(parents=True, exist_ok=True)

MAX_POINTS_TOTAL = 4_500_000
GRID_DEG = 1.0

CLIP_PLO = 2.0
CLIP_PHI = 99.0

# -------------------------
# Latitude limit
# -------------------------
LAT_MIN = -60.0
LAT_MAX = 60.0

# -------------------------
# LOG scaling
# -------------------------
USE_LOG_SCALE = False
ZERO_MODE = "floor"   # "drop" or "floor"
LOG_FLOOR = 1e-4

# -------------------------
# Cartopy
# -------------------------
try:
    import cartopy.crs as ccrs
    import cartopy.feature as cfeature
except Exception as e:
    raise ImportError(
        "Cartopy is not available in this environment. "
        "If you're in conda: conda install -c conda-forge cartopy"
    ) from e


# -------------------------
# Helpers
# -------------------------
def wrap_lon180(lon: np.ndarray) -> np.ndarray:
    return ((lon + 180.0) % 360.0) - 180.0


def apply_zero_mode(v: np.ndarray) -> np.ndarray:
    out = v.copy()
    bad = np.isfinite(out) & (out <= 0)
    if ZERO_MODE == "drop":
        out[bad] = np.nan
    elif ZERO_MODE == "floor":
        out[bad] = LOG_FLOOR
    else:
        raise ValueError("ZERO_MODE must be 'drop' or 'floor'")
    return out


def robust_clip_linear(v: np.ndarray) -> Tuple[float, float]:
    good = np.isfinite(v)
    if not np.any(good):
        return 0.0, 1.0
    lo, hi = np.nanpercentile(v[good], [CLIP_PLO, CLIP_PHI])
    if (not np.isfinite(lo)) or (not np.isfinite(hi)) or (lo == hi):
        lo = float(np.nanmin(v[good]))
        hi = float(np.nanmax(v[good]))
    return float(lo), float(hi)


def robust_clip_log(v: np.ndarray) -> Tuple[float, float]:
    good = np.isfinite(v) & (v > 0)
    if not np.any(good):
        return LOG_FLOOR, LOG_FLOOR * 10.0
    lo, hi = np.nanpercentile(v[good], [CLIP_PLO, CLIP_PHI])
    lo = max(float(lo), LOG_FLOOR)
    hi = max(float(hi), lo * 10.0)
    return lo, hi


def binned_mean_2d(
    lat: np.ndarray, lon: np.ndarray, mf: np.ndarray, ddeg: float
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    lon_edges = np.arange(-180.0, 180.0 + ddeg, ddeg)
    lat_edges = np.arange(LAT_MIN, LAT_MAX + ddeg, ddeg)

    nlon = len(lon_edges) - 1
    nlat = len(lat_edges) - 1

    grid_sum = np.zeros((nlat, nlon), dtype=float)
    grid_cnt = np.zeros((nlat, nlon), dtype=np.int64)

    j = np.digitize(lon, lon_edges) - 1
    i = np.digitize(lat, lat_edges) - 1

    good = (
        (i >= 0) & (i < nlat) &
        (j >= 0) & (j < nlon) &
        np.isfinite(mf)
    )

    if not np.any(good):
        return lon_edges, lat_edges, np.full((nlat, nlon), np.nan, dtype=float)

    np.add.at(grid_sum, (i[good], j[good]), mf[good])
    np.add.at(grid_cnt, (i[good], j[good]), 1)

    grid_mean = np.full((nlat, nlon), np.nan, dtype=float)
    mask = grid_cnt > 0
    grid_mean[mask] = grid_sum[mask] / grid_cnt[mask]

    return lon_edges, lat_edges, grid_mean


def collect_component_data(
    l7_dir: Path,
    file_glob: str,
    components: Tuple[str, str],
) -> Dict[str, Dict[str, List[np.ndarray]]]:
    files = sorted(l7_dir.glob(file_glob))
    print(f"Found {len(files)} files in {l7_dir.resolve()} matching {file_glob}")

    data = {
        comp: {"lat": [], "lon": [], "val": []}
        for comp in components
    }

    if len(files) == 0:
        return data

    per_file_cap = max(50_000, MAX_POINTS_TOTAL // max(1, len(files)))

    for p in files:
        with Dataset(p, "r") as nc:
            if LAT_NAME not in nc.variables or LON_NAME not in nc.variables:
                print(f"Skip {p.name}: missing {LAT_NAME} or {LON_NAME}")
                continue

            lat_var = nc.variables[LAT_NAME]
            lon_var = nc.variables[LON_NAME]

            if lat_var.ndim == 3:
                if TIME_INDEX >= lat_var.shape[0] or TIME_INDEX >= lon_var.shape[0]:
                    print(f"Skip {p.name}: TIME_INDEX out of range")
                    continue
                lat = np.asarray(lat_var[TIME_INDEX], dtype=float)
                lon = np.asarray(lon_var[TIME_INDEX], dtype=float)
            elif lat_var.ndim == 2:
                lat = np.asarray(lat_var[:], dtype=float)
                lon = np.asarray(lon_var[:], dtype=float)
            else:
                print(f"Skip {p.name}: unsupported dims for {LAT_NAME}/{LON_NAME}")
                continue

            lon = wrap_lon180(lon)

            base = (
                np.isfinite(lat) &
                np.isfinite(lon) &
                (lat >= LAT_MIN) &
                (lat <= LAT_MAX)
            )

            idx = np.where(base.ravel())[0]
            if idx.size == 0:
                print(f"Skip {p.name}: no valid points in latitude range")
                continue

            if idx.size > per_file_cap:
                rng = np.random.default_rng(0)
                idx = rng.choice(idx, size=per_file_cap, replace=False)

            lat_flat = lat.ravel()[idx]
            lon_flat = lon.ravel()[idx]

            counts_this_file = {}

            for comp in components:
                if comp not in nc.variables:
                    counts_this_file[comp] = 0
                    continue

                var = nc.variables[comp]
                if var.ndim == 3:
                    if TIME_INDEX >= var.shape[0]:
                        counts_this_file[comp] = 0
                        continue
                    val = np.asarray(var[TIME_INDEX], dtype=float).ravel()[idx]
                elif var.ndim == 2:
                    val = np.asarray(var[:], dtype=float).ravel()[idx]
                else:
                    counts_this_file[comp] = 0
                    continue

                good = np.isfinite(val)
                n_good = int(np.count_nonzero(good))
                counts_this_file[comp] = n_good

                if n_good == 0:
                    continue

                data[comp]["lat"].append(lat_flat[good])
                data[comp]["lon"].append(lon_flat[good])
                data[comp]["val"].append(val[good])

            print(f"{p.name}: added points per component: {counts_this_file}")

    return data


def make_monthly_stacked_plot(year: int, month: int):
    month_str = f"{month:02d}"
    month_name = calendar.month_name[month]
    l7_dir = BASE_L7_DIR / str(year) / month_str

    if not l7_dir.exists():
        print(f"Skip {year}-{month_str}: folder does not exist -> {l7_dir}")
        return

    data = collect_component_data(l7_dir, FILE_GLOB, STACK_PAIR)

    mf_top, mf_bot = STACK_PAIR
    if not data[mf_top]["val"] or not data[mf_bot]["val"]:
        print(f"Skip {year}-{month_str}: missing samples for {STACK_PAIR}")
        return

    LAT1 = np.concatenate(data[mf_top]["lat"])
    LON1 = np.concatenate(data[mf_top]["lon"])
    V1 = np.concatenate(data[mf_top]["val"])

    LAT2 = np.concatenate(data[mf_bot]["lat"])
    LON2 = np.concatenate(data[mf_bot]["lon"])
    V2 = np.concatenate(data[mf_bot]["val"])

    if V1.size > MAX_POINTS_TOTAL:
        rng = np.random.default_rng(2)
        sel = rng.choice(np.arange(V1.size), size=MAX_POINTS_TOTAL, replace=False)
        LAT1, LON1, V1 = LAT1[sel], LON1[sel], V1[sel]

    if V2.size > MAX_POINTS_TOTAL:
        rng = np.random.default_rng(3)
        sel = rng.choice(np.arange(V2.size), size=MAX_POINTS_TOTAL, replace=False)
        LAT2, LON2, V2 = LAT2[sel], LON2[sel], V2[sel]

    pretty_top = DISPLAY_NAMES.get(mf_top, mf_top)
    pretty_bot = DISPLAY_NAMES.get(mf_bot, mf_bot)

    if USE_LOG_SCALE:
        V1d = apply_zero_mode(V1)
        V2d = apply_zero_mode(V2)
        vall = np.concatenate([V1d, V2d])
        lo, hi = robust_clip_log(vall)
        norm_shared = LogNorm(vmin=lo, vmax=hi)
        vmin = None
        vmax = None
        grid1 = apply_zero_mode(binned_mean_2d(LAT1, LON1, V1d, GRID_DEG)[2])
        grid2 = apply_zero_mode(binned_mean_2d(LAT2, LON2, V2d, GRID_DEG)[2])
        cbar_label = r"Momentum Flux (m$^2$ s$^{-2}$, log)"
        suptitle = f"{month_name} {year}: {pretty_top} and {pretty_bot} (shared LOG scale)"
    else:
        vall = np.concatenate([V1, V2])
        lo, hi = robust_clip_linear(vall)
        norm_shared = None
        #vmin = lo
        #vmax = hi
        vmin = 0
        vmax = 3
        grid1 = np.clip(binned_mean_2d(LAT1, LON1, V1, GRID_DEG)[2], lo, hi)
        grid2 = np.clip(binned_mean_2d(LAT2, LON2, V2, GRID_DEG)[2], lo, hi)
        cbar_label = r"Momentum Flux (m$^2$ s$^{-2}$)"
        suptitle = f"{month_name} {year}: {pretty_top} and {pretty_bot} (shared linear scale)"

    lon_e1, lat_e1, _ = binned_mean_2d(LAT1, LON1, V1 if not USE_LOG_SCALE else V1d, GRID_DEG)
    lon_e2, lat_e2, _ = binned_mean_2d(LAT2, LON2, V2 if not USE_LOG_SCALE else V2d, GRID_DEG)

    outpath = OUTDIR / f"{year}_{month_str}_MFz_MFm_stacked_global_maps.png"

    proj = ccrs.PlateCarree()
    fig = plt.figure(figsize=(14, 10), constrained_layout=True)
    gs = fig.add_gridspec(2, 1)

    ax1 = fig.add_subplot(gs[0, 0], projection=proj)
    ax1.set_extent([-180, 180, LAT_MIN, LAT_MAX], crs=proj)
    ax1.coastlines(linewidth=0.6)
    ax1.add_feature(cfeature.BORDERS, linewidth=0.3)
    ax1.gridlines(draw_labels=False, linewidth=0.2, alpha=0.5)
    im1 = ax1.pcolormesh(
        lon_e1, lat_e1, grid1,
        transform=proj,
        shading="auto",
        norm=norm_shared,
        vmin=vmin,
        vmax=vmax,
    )
    ax1.set_title(pretty_top)

    ax2 = fig.add_subplot(gs[1, 0], projection=proj)
    ax2.set_extent([-180, 180, LAT_MIN, LAT_MAX], crs=proj)
    ax2.coastlines(linewidth=0.6)
    ax2.add_feature(cfeature.BORDERS, linewidth=0.3)
    ax2.gridlines(draw_labels=False, linewidth=0.2, alpha=0.5)
    im2 = ax2.pcolormesh(
        lon_e2, lat_e2, grid2,
        transform=proj,
        shading="auto",
        norm=norm_shared,
        vmin=vmin,
        vmax=vmax,
    )
    ax2.set_title(pretty_bot)

    cb = fig.colorbar(im2, ax=[ax1, ax2], fraction=0.03, pad=0.02)
    cb.set_label(cbar_label)

    fig.suptitle(suptitle, fontsize=14)
    fig.savefig(outpath, dpi=200)
    plt.close(fig)

    print(f"Saved: {outpath.resolve()}")
    gc.collect()


# -------------------------
# Run all months
# -------------------------
for month in MONTHS:
    print("\n" + "=" * 80)
    print(f"Processing {YEAR}-{month:02d}")
    print("=" * 80)
    make_monthly_stacked_plot(YEAR, month)

print("\nDone.")
print(f"All monthly stacked figures are in: {OUTDIR.resolve()}")
# Out:
# ================================================================================
# Processing 2025-11
# ================================================================================
# Found 432 files in \\awex2.physics.usu.edu\awewrite\socfiles\public\l7\2025\11 matching *l7a*.nc
# awe_l7a_tmp_2025305T0133_11002_v01.nc: added points per component: {'MFz_top': 39239, 'MFm_top': 39239}
# awe_l7a_tmp_2025305T0306_11003_v01.nc: added points per component: {'MFz_top': 30325, 'MFm_top': 30325}
# awe_l7a_tmp_2025305T0439_11004_v01.nc: added points per component: {'MFz_top': 38194, 'MFm_top': 38194}
# awe_l7a_tmp_2025305T0612_11005_v01.nc: added points per component: {'MFz_top': 19683, 'MFm_top': 19683}
# awe_l7a_tmp_2025305T0745_11006_v01.nc: added points per component: {'MFz_top': 3875, 'MFm_top': 3875}
# awe_l7a_tmp_2025305T0918_11007_v01.nc: added points per component: {'MFz_top': 43474, 'MFm_top': 43474}
# awe_l7a_tmp_2025305T1051_11008_v01.nc: added points per component: {'MFz_top': 42058, 'MFm_top': 42058}
# awe_l7a_tmp_2025305T1224_11009_v01.nc: added points per component: {'MFz_top': 31985, 'MFm_top': 31985}
# awe_l7a_tmp_2025305T1357_11010_v01.nc: added points per component: {'MFz_top': 35625, 'MFm_top': 35625}
# awe_l7a_tmp_2025305T1530_11011_v01.nc: added points per component: {'MFz_top': 22379, 'MFm_top': 22379}
# awe_l7a_tmp_2025305T1703_11012_v01.nc: added points per component: {'MFz_top': 19728, 'MFm_top': 19728}
# awe_l7a_tmp_2025305T1836_11013_v01.nc: added points per component: {'MFz_top': 35607, 'MFm_top': 35607}
# awe_l7a_tmp_2025305T2009_11014_v01.nc: added points per component: {'MFz_top': 35607, 'MFm_top': 35607}
# awe_l7a_tmp_2025305T2142_11015_v01.nc: added points per component: {'MFz_top': 31726, 'MFm_top': 31726}
# awe_l7a_tmp_2025305T2315_11016_v01.nc: added points per component: {'MFz_top': 47682, 'MFm_top': 47682}
# awe_l7a_tmp_2025306T0048_11017_v01.nc: added points per component: {'MFz_top': 38106, 'MFm_top': 38106}
# awe_l7a_tmp_2025306T0221_11018_v01.nc: added points per component: {'MFz_top': 35788, 'MFm_top': 35788}
# awe_l7a_tmp_2025306T0354_11019_v01.nc: added points per component: {'MFz_top': 45988, 'MFm_top': 45988}
# awe_l7a_tmp_2025306T0527_11020_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025306T0700_11021_v01.nc: added points per component: {'MFz_top': 4050, 'MFm_top': 4050}
# awe_l7a_tmp_2025306T0832_11022_v01.nc: added points per component: {'MFz_top': 26305, 'MFm_top': 26305}
# awe_l7a_tmp_2025306T1006_11023_v01.nc: added points per component: {'MFz_top': 19951, 'MFm_top': 19951}
# awe_l7a_tmp_2025306T1139_11024_v01.nc: added points per component: {'MFz_top': 44048, 'MFm_top': 44048}
# awe_l7a_tmp_2025306T1312_11025_v01.nc: added points per component: {'MFz_top': 45988, 'MFm_top': 45988}
# awe_l7a_tmp_2025306T1445_11026_v01.nc: added points per component: {'MFz_top': 29962, 'MFm_top': 29962}
# awe_l7a_tmp_2025306T1617_11027_v01.nc: added points per component: {'MFz_top': 19951, 'MFm_top': 19951}
# awe_l7a_tmp_2025306T1751_11028_v01.nc: added points per component: {'MFz_top': 27943, 'MFm_top': 27943}
# awe_l7a_tmp_2025306T2056_11030_v01.nc: added points per component: {'MFz_top': 39856, 'MFm_top': 39856}
# awe_l7a_tmp_2025306T2229_11031_v01.nc: added points per component: {'MFz_top': 47682, 'MFm_top': 47682}
# awe_l7a_tmp_2025307T0002_11032_v01.nc: added points per component: {'MFz_top': 28161, 'MFm_top': 28161}
# awe_l7a_tmp_2025307T0135_11033_v01.nc: added points per component: {'MFz_top': 24163, 'MFm_top': 24163}
# awe_l7a_tmp_2025307T0308_11034_v01.nc: added points per component: {'MFz_top': 32267, 'MFm_top': 32267}
# awe_l7a_tmp_2025307T0441_11035_v01.nc: added points per component: {'MFz_top': 47981, 'MFm_top': 47981}
# awe_l7a_tmp_2025307T0614_11036_v01.nc: added points per component: {'MFz_top': 12077, 'MFm_top': 12077}
# awe_l7a_tmp_2025307T0747_11037_v01.nc: added points per component: {'MFz_top': 40107, 'MFm_top': 40107}
# awe_l7a_tmp_2025307T0920_11038_v01.nc: added points per component: {'MFz_top': 24001, 'MFm_top': 24001}
# awe_l7a_tmp_2025307T1053_11039_v01.nc: added points per component: {'MFz_top': 43759, 'MFm_top': 43759}
# awe_l7a_tmp_2025307T1226_11040_v01.nc: added points per component: {'MFz_top': 40430, 'MFm_top': 40430}
# awe_l7a_tmp_2025307T1359_11041_v01.nc: added points per component: {'MFz_top': 28123, 'MFm_top': 28123}
# awe_l7a_tmp_2025307T1532_11042_v01.nc: added points per component: {'MFz_top': 19859, 'MFm_top': 19859}
# awe_l7a_tmp_2025307T1705_11043_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025307T1838_11044_v01.nc: added points per component: {'MFz_top': 44270, 'MFm_top': 44270}
# awe_l7a_tmp_2025307T2011_11045_v01.nc: added points per component: {'MFz_top': 44270, 'MFm_top': 44270}
# awe_l7a_tmp_2025307T2144_11046_v01.nc: added points per component: {'MFz_top': 43969, 'MFm_top': 43969}
# awe_l7a_tmp_2025307T2317_11047_v01.nc: added points per component: {'MFz_top': 44375, 'MFm_top': 44375}
# awe_l7a_tmp_2025308T0050_11048_v01.nc: added points per component: {'MFz_top': 32267, 'MFm_top': 32267}
# awe_l7a_tmp_2025308T0356_11050_v01.nc: added points per component: {'MFz_top': 44270, 'MFm_top': 44270}
# awe_l7a_tmp_2025308T0529_11051_v01.nc: added points per component: {'MFz_top': 16459, 'MFm_top': 16459}
# awe_l7a_tmp_2025308T0701_11052_v01.nc: added points per component: {'MFz_top': 36001, 'MFm_top': 36001}
# awe_l7a_tmp_2025308T1007_11054_v01.nc: added points per component: {'MFz_top': 32322, 'MFm_top': 32322}
# awe_l7a_tmp_2025308T1140_11055_v01.nc: added points per component: {'MFz_top': 44375, 'MFm_top': 44375}
# awe_l7a_tmp_2025308T1314_11056_v01.nc: added points per component: {'MFz_top': 32412, 'MFm_top': 32412}
# awe_l7a_tmp_2025308T1619_11058_v01.nc: added points per component: {'MFz_top': 40227, 'MFm_top': 40227}
# awe_l7a_tmp_2025308T1753_11059_v01.nc: added points per component: {'MFz_top': 40957, 'MFm_top': 40957}
# awe_l7a_tmp_2025308T2058_11061_v01.nc: added points per component: {'MFz_top': 39934, 'MFm_top': 39934}
# awe_l7a_tmp_2025308T2231_11062_v01.nc: added points per component: {'MFz_top': 44375, 'MFm_top': 44375}
# awe_l7a_tmp_2025309T0005_11063_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025309T0137_11064_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025309T0310_11065_v01.nc: added points per component: {'MFz_top': 36738, 'MFm_top': 36738}
# awe_l7a_tmp_2025309T0443_11066_v01.nc: added points per component: {'MFz_top': 32626, 'MFm_top': 32626}
# awe_l7a_tmp_2025309T0749_11068_v01.nc: added points per component: {'MFz_top': 36473, 'MFm_top': 36473}
# awe_l7a_tmp_2025309T0922_11069_v01.nc: added points per component: {'MFz_top': 32674, 'MFm_top': 32674}
# awe_l7a_tmp_2025309T1055_11070_v01.nc: added points per component: {'MFz_top': 48633, 'MFm_top': 48633}
# awe_l7a_tmp_2025309T1228_11071_v01.nc: added points per component: {'MFz_top': 32626, 'MFm_top': 32626}
# awe_l7a_tmp_2025309T1401_11072_v01.nc: added points per component: {'MFz_top': 36890, 'MFm_top': 36890}
# awe_l7a_tmp_2025309T1534_11073_v01.nc: added points per component: {'MFz_top': 40479, 'MFm_top': 40479}
# awe_l7a_tmp_2025309T1707_11074_v01.nc: added points per component: {'MFz_top': 44884, 'MFm_top': 44884}
# awe_l7a_tmp_2025309T1840_11075_v01.nc: added points per component: {'MFz_top': 32674, 'MFm_top': 32674}
# awe_l7a_tmp_2025309T2013_11076_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025309T2146_11077_v01.nc: added points per component: {'MFz_top': 32455, 'MFm_top': 32455}
# awe_l7a_tmp_2025309T2319_11078_v01.nc: added points per component: {'MFz_top': 37021, 'MFm_top': 37021}
# awe_l7a_tmp_2025310T0358_11081_v01.nc: added points per component: {'MFz_top': 37021, 'MFm_top': 37021}
# awe_l7a_tmp_2025310T0531_11082_v01.nc: added points per component: {'MFz_top': 36678, 'MFm_top': 36678}
# awe_l7a_tmp_2025310T0704_11083_v01.nc: added points per component: {'MFz_top': 40742, 'MFm_top': 40742}
# awe_l7a_tmp_2025310T0837_11084_v01.nc: added points per component: {'MFz_top': 36678, 'MFm_top': 36678}
# awe_l7a_tmp_2025310T1010_11085_v01.nc: added points per component: {'MFz_top': 36678, 'MFm_top': 36678}
# awe_l7a_tmp_2025310T1143_11086_v01.nc: added points per component: {'MFz_top': 28406, 'MFm_top': 28406}
# awe_l7a_tmp_2025310T1316_11087_v01.nc: added points per component: {'MFz_top': 16688, 'MFm_top': 16688}
# awe_l7a_tmp_2025310T1449_11088_v01.nc: added points per component: {'MFz_top': 45205, 'MFm_top': 45205}
# awe_l7a_tmp_2025310T1622_11089_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025310T1754_11090_v01.nc: added points per component: {'MFz_top': 40742, 'MFm_top': 40742}
# awe_l7a_tmp_2025310T1927_11091_v01.nc: added points per component: {'MFz_top': 48633, 'MFm_top': 48633}
# awe_l7a_tmp_2025310T2101_11092_v01.nc: added points per component: {'MFz_top': 40742, 'MFm_top': 40742}
# awe_l7a_tmp_2025310T2234_11093_v01.nc: added points per component: {'MFz_top': 36738, 'MFm_top': 36738}
# awe_l7a_tmp_2025311T0006_11094_v01.nc: added points per component: {'MFz_top': 44884, 'MFm_top': 44884}
# awe_l7a_tmp_2025311T0140_11095_v01.nc: added points per component: {'MFz_top': 40742, 'MFm_top': 40742}
# awe_l7a_tmp_2025311T0446_11097_v01.nc: added points per component: {'MFz_top': 40957, 'MFm_top': 40957}
# awe_l7a_tmp_2025311T0619_11098_v01.nc: added points per component: {'MFz_top': 37185, 'MFm_top': 37185}
# awe_l7a_tmp_2025311T0751_11099_v01.nc: added points per component: {'MFz_top': 37021, 'MFm_top': 37021}
# awe_l7a_tmp_2025311T0925_11100_v01.nc: added points per component: {'MFz_top': 45487, 'MFm_top': 45487}
# awe_l7a_tmp_2025311T1057_11101_v01.nc: added points per component: {'MFz_top': 32849, 'MFm_top': 32849}
# awe_l7a_tmp_2025311T1231_11102_v01.nc: added points per component: {'MFz_top': 41352, 'MFm_top': 41352}
# awe_l7a_tmp_2025311T1403_11103_v01.nc: added points per component: {'MFz_top': 37201, 'MFm_top': 37201}
# awe_l7a_tmp_2025311T1537_11104_v01.nc: added points per component: {'MFz_top': 29095, 'MFm_top': 29095}
# awe_l7a_tmp_2025311T1710_11105_v01.nc: added points per component: {'MFz_top': 45804, 'MFm_top': 45804}
# awe_l7a_tmp_2025311T1843_11106_v01.nc: added points per component: {'MFz_top': 37752, 'MFm_top': 37752}
# awe_l7a_tmp_2025311T2015_11107_v01.nc: added points per component: {'MFz_top': 36678, 'MFm_top': 36678}
# awe_l7a_tmp_2025311T2148_11108_v01.nc: added points per component: {'MFz_top': 33214, 'MFm_top': 33214}
# awe_l7a_tmp_2025311T2321_11109_v01.nc: added points per component: {'MFz_top': 37381, 'MFm_top': 37381}
# awe_l7a_tmp_2025312T0227_11111_v01.nc: added points per component: {'MFz_top': 41352, 'MFm_top': 41352}
# awe_l7a_tmp_2025312T0400_11112_v01.nc: added points per component: {'MFz_top': 20398, 'MFm_top': 20398}
# awe_l7a_tmp_2025312T0533_11113_v01.nc: added points per component: {'MFz_top': 45511, 'MFm_top': 45511}
# awe_l7a_tmp_2025312T0706_11114_v01.nc: added points per component: {'MFz_top': 28707, 'MFm_top': 28707}
# awe_l7a_tmp_2025312T0839_11115_v01.nc: added points per component: {'MFz_top': 44884, 'MFm_top': 44884}
# awe_l7a_tmp_2025312T1012_11116_v01.nc: added points per component: {'MFz_top': 45511, 'MFm_top': 45511}
# awe_l7a_tmp_2025312T1145_11117_v01.nc: added points per component: {'MFz_top': 32748, 'MFm_top': 32748}
# awe_l7a_tmp_2025312T1318_11118_v01.nc: added points per component: {'MFz_top': 45511, 'MFm_top': 45511}
# awe_l7a_tmp_2025312T1451_11119_v01.nc: added points per component: {'MFz_top': 44884, 'MFm_top': 44884}
# awe_l7a_tmp_2025312T1624_11120_v01.nc: added points per component: {'MFz_top': 4119, 'MFm_top': 4119}
# awe_l7a_tmp_2025312T1757_11121_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025312T1930_11122_v01.nc: added points per component: {'MFz_top': 44884, 'MFm_top': 44884}
# awe_l7a_tmp_2025312T2103_11123_v01.nc: added points per component: {'MFz_top': 24632, 'MFm_top': 24632}
# awe_l7a_tmp_2025312T2236_11124_v01.nc: added points per component: {'MFz_top': 32626, 'MFm_top': 32626}
# awe_l7a_tmp_2025313T0009_11125_v01.nc: added points per component: {'MFz_top': 36738, 'MFm_top': 36738}
# awe_l7a_tmp_2025313T0142_11126_v01.nc: added points per component: {'MFz_top': 41234, 'MFm_top': 41234}
# awe_l7a_tmp_2025313T0315_11127_v01.nc: added points per component: {'MFz_top': 33214, 'MFm_top': 33214}
# awe_l7a_tmp_2025313T0448_11128_v01.nc: added points per component: {'MFz_top': 36916, 'MFm_top': 36916}
# awe_l7a_tmp_2025313T0621_11129_v01.nc: added points per component: {'MFz_top': 28744, 'MFm_top': 28744}
# awe_l7a_tmp_2025313T0754_11130_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025313T0927_11131_v01.nc: added points per component: {'MFz_top': 24703, 'MFm_top': 24703}
# awe_l7a_tmp_2025313T1100_11132_v01.nc: added points per component: {'MFz_top': 20591, 'MFm_top': 20591}
# awe_l7a_tmp_2025313T1233_11133_v01.nc: added points per component: {'MFz_top': 40957, 'MFm_top': 40957}
# awe_l7a_tmp_2025313T1406_11134_v01.nc: added points per component: {'MFz_top': 32820, 'MFm_top': 32820}
# awe_l7a_tmp_2025313T1539_11135_v01.nc: added points per component: {'MFz_top': 28658, 'MFm_top': 28658}
# awe_l7a_tmp_2025313T1712_11136_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025313T2018_11138_v01.nc: added points per component: {'MFz_top': 36473, 'MFm_top': 36473}
# awe_l7a_tmp_2025313T2151_11139_v01.nc: added points per component: {'MFz_top': 28562, 'MFm_top': 28562}
# awe_l7a_tmp_2025313T2324_11140_v01.nc: added points per component: {'MFz_top': 40479, 'MFm_top': 40479}
# awe_l7a_tmp_2025314T0057_11141_v01.nc: added points per component: {'MFz_top': 36916, 'MFm_top': 36916}
# awe_l7a_tmp_2025314T0230_11142_v01.nc: added points per component: {'MFz_top': 44556, 'MFm_top': 44556}
# awe_l7a_tmp_2025314T0403_11143_v01.nc: added points per component: {'MFz_top': 16279, 'MFm_top': 16279}
# awe_l7a_tmp_2025314T0536_11144_v01.nc: added points per component: {'MFz_top': 40742, 'MFm_top': 40742}
# awe_l7a_tmp_2025314T0709_11145_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025314T0841_11146_v01.nc: added points per component: {'MFz_top': 40957, 'MFm_top': 40957}
# awe_l7a_tmp_2025314T1015_11147_v01.nc: added points per component: {'MFz_top': 44270, 'MFm_top': 44270}
# awe_l7a_tmp_2025314T1148_11148_v01.nc: added points per component: {'MFz_top': 32820, 'MFm_top': 32820}
# awe_l7a_tmp_2025314T1320_11149_v01.nc: added points per component: {'MFz_top': 32604, 'MFm_top': 32604}
# awe_l7a_tmp_2025314T1454_11150_v01.nc: added points per component: {'MFz_top': 36916, 'MFm_top': 36916}
# awe_l7a_tmp_2025314T1627_11151_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025314T1800_11152_v01.nc: added points per component: {'MFz_top': 36916, 'MFm_top': 36916}
# awe_l7a_tmp_2025314T1932_11153_v01.nc: added points per component: {'MFz_top': 32340, 'MFm_top': 32340}
# awe_l7a_tmp_2025314T2105_11154_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025314T2238_11155_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025315T0011_11156_v01.nc: added points per component: {'MFz_top': 48633, 'MFm_top': 48633}
# awe_l7a_tmp_2025315T0144_11157_v01.nc: added points per component: {'MFz_top': 44270, 'MFm_top': 44270}
# awe_l7a_tmp_2025315T0317_11158_v01.nc: added points per component: {'MFz_top': 44375, 'MFm_top': 44375}
# awe_l7a_tmp_2025315T0450_11159_v01.nc: added points per component: {'MFz_top': 48335, 'MFm_top': 48335}
# awe_l7a_tmp_2025315T0623_11160_v01.nc: added points per component: {'MFz_top': 44270, 'MFm_top': 44270}
# awe_l7a_tmp_2025315T0759_11161_v01.nc: added points per component: {'MFz_top': 41614, 'MFm_top': 41614}
# awe_l7a_tmp_2025315T0932_11162_v01.nc: added points per component: {'MFz_top': 38479, 'MFm_top': 38479}
# awe_l7a_tmp_2025315T1104_11163_v01.nc: added points per component: {'MFz_top': 30605, 'MFm_top': 30605}
# awe_l7a_tmp_2025315T1238_11164_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025315T1411_11165_v01.nc: added points per component: {'MFz_top': 16416, 'MFm_top': 16416}
# awe_l7a_tmp_2025315T1544_11166_v01.nc: added points per component: {'MFz_top': 12098, 'MFm_top': 12098}
# awe_l7a_tmp_2025315T1716_11167_v01.nc: added points per component: {'MFz_top': 41967, 'MFm_top': 41967}
# awe_l7a_tmp_2025315T1850_11168_v01.nc: added points per component: {'MFz_top': 39078, 'MFm_top': 39078}
# awe_l7a_tmp_2025315T2023_11169_v01.nc: added points per component: {'MFz_top': 34116, 'MFm_top': 34116}
# awe_l7a_tmp_2025315T2156_11170_v01.nc: added points per component: {'MFz_top': 46886, 'MFm_top': 46886}
# awe_l7a_tmp_2025315T2329_11171_v01.nc: added points per component: {'MFz_top': 41614, 'MFm_top': 41614}
# awe_l7a_tmp_2025316T0102_11172_v01.nc: added points per component: {'MFz_top': 49448, 'MFm_top': 49448}
# awe_l7a_tmp_2025316T0234_11173_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025316T0407_11174_v01.nc: added points per component: {'MFz_top': 40371, 'MFm_top': 40371}
# awe_l7a_tmp_2025316T0540_11175_v01.nc: added points per component: {'MFz_top': 43209, 'MFm_top': 43209}
# awe_l7a_tmp_2025316T0712_11176_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025316T0845_11177_v01.nc: added points per component: {'MFz_top': 43102, 'MFm_top': 43102}
# awe_l7a_tmp_2025316T1018_11178_v01.nc: added points per component: {'MFz_top': 40935, 'MFm_top': 40935}
# awe_l7a_tmp_2025316T1153_11179_v01.nc: added points per component: {'MFz_top': 43842, 'MFm_top': 43842}
# awe_l7a_tmp_2025316T1325_11180_v01.nc: added points per component: {'MFz_top': 21690, 'MFm_top': 21690}
# awe_l7a_tmp_2025316T1458_11181_v01.nc: added points per component: {'MFz_top': 42736, 'MFm_top': 42736}
# awe_l7a_tmp_2025316T1631_11182_v01.nc: added points per component: {'MFz_top': 7574, 'MFm_top': 7574}
# awe_l7a_tmp_2025316T1804_11183_v01.nc: added points per component: {'MFz_top': 34116, 'MFm_top': 34116}
# awe_l7a_tmp_2025316T1937_11184_v01.nc: added points per component: {'MFz_top': 42394, 'MFm_top': 42394}
# awe_l7a_tmp_2025316T2110_11185_v01.nc: added points per component: {'MFz_top': 37816, 'MFm_top': 37816}
# awe_l7a_tmp_2025316T2243_11186_v01.nc: added points per component: {'MFz_top': 41657, 'MFm_top': 41657}
# awe_l7a_tmp_2025317T0016_11187_v01.nc: added points per component: {'MFz_top': 38086, 'MFm_top': 38086}
# awe_l7a_tmp_2025317T0148_11188_v01.nc: added points per component: {'MFz_top': 39897, 'MFm_top': 39897}
# awe_l7a_tmp_2025317T0323_11189_v01.nc: added points per component: {'MFz_top': 36385, 'MFm_top': 36385}
# awe_l7a_tmp_2025317T0455_11190_v01.nc: added points per component: {'MFz_top': 47512, 'MFm_top': 47512}
# awe_l7a_tmp_2025317T0628_11191_v01.nc: added points per component: {'MFz_top': 41366, 'MFm_top': 41366}
# awe_l7a_tmp_2025317T0800_11192_v01.nc: added points per component: {'MFz_top': 44237, 'MFm_top': 44237}
# awe_l7a_tmp_2025317T0933_11193_v01.nc: added points per component: {'MFz_top': 27468, 'MFm_top': 27468}
# awe_l7a_tmp_2025317T1106_11194_v01.nc: added points per component: {'MFz_top': 44880, 'MFm_top': 44880}
# awe_l7a_tmp_2025317T1240_11195_v01.nc: added points per component: {'MFz_top': 34213, 'MFm_top': 34213}
# awe_l7a_tmp_2025317T1413_11196_v01.nc: added points per component: {'MFz_top': 34858, 'MFm_top': 34858}
# awe_l7a_tmp_2025317T1546_11197_v01.nc: added points per component: {'MFz_top': 27468, 'MFm_top': 27468}
# awe_l7a_tmp_2025317T1719_11198_v01.nc: added points per component: {'MFz_top': 35862, 'MFm_top': 35862}
# awe_l7a_tmp_2025317T1851_11199_v01.nc: added points per component: {'MFz_top': 40895, 'MFm_top': 40895}
# awe_l7a_tmp_2025317T2024_11200_v01.nc: added points per component: {'MFz_top': 40935, 'MFm_top': 40935}
# awe_l7a_tmp_2025317T2158_11201_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025317T2331_11202_v01.nc: added points per component: {'MFz_top': 44858, 'MFm_top': 44858}
# awe_l7a_tmp_2025318T0103_11203_v01.nc: added points per component: {'MFz_top': 45658, 'MFm_top': 45658}
# awe_l7a_tmp_2025318T0237_11204_v01.nc: added points per component: {'MFz_top': 47718, 'MFm_top': 47718}
# awe_l7a_tmp_2025318T0409_11205_v01.nc: added points per component: {'MFz_top': 37816, 'MFm_top': 37816}
# awe_l7a_tmp_2025318T0543_11206_v01.nc: added points per component: {'MFz_top': 37817, 'MFm_top': 37817}
# awe_l7a_tmp_2025318T0714_11207_v01.nc: added points per component: {'MFz_top': 35793, 'MFm_top': 35793}
# awe_l7a_tmp_2025318T0847_11208_v01.nc: added points per component: {'MFz_top': 32396, 'MFm_top': 32396}
# awe_l7a_tmp_2025318T1020_11209_v01.nc: added points per component: {'MFz_top': 5618, 'MFm_top': 5618}
# awe_l7a_tmp_2025318T1155_11210_v01.nc: added points per component: {'MFz_top': 28713, 'MFm_top': 28713}
# awe_l7a_tmp_2025318T1327_11211_v01.nc: added points per component: {'MFz_top': 23472, 'MFm_top': 23472}
# awe_l7a_tmp_2025318T1500_11212_v01.nc: added points per component: {'MFz_top': 16932, 'MFm_top': 16932}
# awe_l7a_tmp_2025318T1633_11213_v01.nc: added points per component: {'MFz_top': 10791, 'MFm_top': 10791}
# awe_l7a_tmp_2025318T1806_11214_v01.nc: added points per component: {'MFz_top': 32481, 'MFm_top': 32481}
# awe_l7a_tmp_2025318T1939_11215_v01.nc: added points per component: {'MFz_top': 38715, 'MFm_top': 38715}
# awe_l7a_tmp_2025318T2112_11216_v01.nc: added points per component: {'MFz_top': 41657, 'MFm_top': 41657}
# awe_l7a_tmp_2025318T2245_11217_v01.nc: added points per component: {'MFz_top': 36686, 'MFm_top': 36686}
# awe_l7a_tmp_2025319T0018_11218_v01.nc: added points per component: {'MFz_top': 36202, 'MFm_top': 36202}
# awe_l7a_tmp_2025319T0152_11219_v01.nc: added points per component: {'MFz_top': 43209, 'MFm_top': 43209}
# awe_l7a_tmp_2025319T0323_11220_v01.nc: added points per component: {'MFz_top': 31862, 'MFm_top': 31862}
# awe_l7a_tmp_2025319T0457_11221_v01.nc: added points per component: {'MFz_top': 41010, 'MFm_top': 41010}
# awe_l7a_tmp_2025319T0630_11222_v01.nc: added points per component: {'MFz_top': 48630, 'MFm_top': 48630}
# awe_l7a_tmp_2025319T0802_11223_v01.nc: added points per component: {'MFz_top': 46886, 'MFm_top': 46886}
# awe_l7a_tmp_2025319T0936_11224_v01.nc: added points per component: {'MFz_top': 32288, 'MFm_top': 32288}
# awe_l7a_tmp_2025319T1108_11225_v01.nc: added points per component: {'MFz_top': 26734, 'MFm_top': 26734}
# awe_l7a_tmp_2025319T1241_11226_v01.nc: added points per component: {'MFz_top': 27817, 'MFm_top': 27817}
# awe_l7a_tmp_2025319T1414_11227_v01.nc: added points per component: {'MFz_top': 22931, 'MFm_top': 22931}
# awe_l7a_tmp_2025319T1547_11228_v01.nc: added points per component: {'MFz_top': 23265, 'MFm_top': 23265}
# awe_l7a_tmp_2025319T1720_11229_v01.nc: added points per component: {'MFz_top': 26388, 'MFm_top': 26388}
# awe_l7a_tmp_2025319T1854_11230_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025319T2026_11231_v01.nc: added points per component: {'MFz_top': 36202, 'MFm_top': 36202}
# awe_l7a_tmp_2025319T2159_11232_v01.nc: added points per component: {'MFz_top': 31387, 'MFm_top': 31387}
# awe_l7a_tmp_2025319T2331_11233_v01.nc: added points per component: {'MFz_top': 29579, 'MFm_top': 29579}
# awe_l7a_tmp_2025320T0104_11234_v01.nc: added points per component: {'MFz_top': 40587, 'MFm_top': 40587}
# awe_l7a_tmp_2025320T0238_11235_v01.nc: added points per component: {'MFz_top': 40935, 'MFm_top': 40935}
# awe_l7a_tmp_2025320T0411_11236_v01.nc: added points per component: {'MFz_top': 37141, 'MFm_top': 37141}
# awe_l7a_tmp_2025320T0544_11237_v01.nc: added points per component: {'MFz_top': 32481, 'MFm_top': 32481}
# awe_l7a_tmp_2025320T0715_11238_v01.nc: added points per component: {'MFz_top': 25670, 'MFm_top': 25670}
# awe_l7a_tmp_2025320T0848_11239_v01.nc: added points per component: {'MFz_top': 26266, 'MFm_top': 26266}
# awe_l7a_tmp_2025320T1022_11240_v01.nc: added points per component: {'MFz_top': 5186, 'MFm_top': 5186}
# awe_l7a_tmp_2025320T1155_11241_v01.nc: added points per component: {'MFz_top': 5317, 'MFm_top': 5317}
# awe_l7a_tmp_2025320T1502_11243_v01.nc: added points per component: {'MFz_top': 20935, 'MFm_top': 20935}
# awe_l7a_tmp_2025320T1634_11244_v01.nc: added points per component: {'MFz_top': 24861, 'MFm_top': 24861}
# awe_l7a_tmp_2025320T1807_11245_v01.nc: added points per component: {'MFz_top': 43979, 'MFm_top': 43979}
# awe_l7a_tmp_2025320T1940_11246_v01.nc: added points per component: {'MFz_top': 31266, 'MFm_top': 31266}
# awe_l7a_tmp_2025320T2113_11247_v01.nc: added points per component: {'MFz_top': 41284, 'MFm_top': 41284}
# awe_l7a_tmp_2025320T2246_11248_v01.nc: added points per component: {'MFz_top': 25292, 'MFm_top': 25292}
# awe_l7a_tmp_2025321T0019_11249_v01.nc: added points per component: {'MFz_top': 31266, 'MFm_top': 31266}
# awe_l7a_tmp_2025321T0152_11250_v01.nc: added points per component: {'MFz_top': 20804, 'MFm_top': 20804}
# awe_l7a_tmp_2025321T0325_11251_v01.nc: added points per component: {'MFz_top': 21716, 'MFm_top': 21716}
# awe_l7a_tmp_2025321T0458_11252_v01.nc: added points per component: {'MFz_top': 21795, 'MFm_top': 21795}
# awe_l7a_tmp_2025321T0630_11253_v01.nc: added points per component: {'MFz_top': 24878, 'MFm_top': 24878}
# awe_l7a_tmp_2025321T0802_11254_v01.nc: added points per component: {'MFz_top': 9796, 'MFm_top': 9796}
# awe_l7a_tmp_2025321T0937_11255_v01.nc: added points per component: {'MFz_top': 5906, 'MFm_top': 5906}
# awe_l7a_tmp_2025321T1110_11256_v01.nc: added points per component: {'MFz_top': 10918, 'MFm_top': 10918}
# awe_l7a_tmp_2025321T1242_11257_v01.nc: added points per component: {'MFz_top': 34284, 'MFm_top': 34284}
# awe_l7a_tmp_2025321T1415_11258_v01.nc: added points per component: {'MFz_top': 43979, 'MFm_top': 43979}
# awe_l7a_tmp_2025321T1547_11259_v01.nc: added points per component: {'MFz_top': 30812, 'MFm_top': 30812}
# awe_l7a_tmp_2025321T1721_11260_v01.nc: added points per component: {'MFz_top': 30663, 'MFm_top': 30663}
# awe_l7a_tmp_2025321T1854_11261_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025321T2027_11262_v01.nc: added points per component: {'MFz_top': 31036, 'MFm_top': 31036}
# awe_l7a_tmp_2025321T2200_11263_v01.nc: added points per component: {'MFz_top': 41318, 'MFm_top': 41318}
# awe_l7a_tmp_2025321T2333_11264_v01.nc: added points per component: {'MFz_top': 40935, 'MFm_top': 40935}
# awe_l7a_tmp_2025322T0106_11265_v01.nc: added points per component: {'MFz_top': 47718, 'MFm_top': 47718}
# awe_l7a_tmp_2025322T0238_11266_v01.nc: added points per component: {'MFz_top': 26037, 'MFm_top': 26037}
# awe_l7a_tmp_2025322T0412_11267_v01.nc: added points per component: {'MFz_top': 48164, 'MFm_top': 48164}
# awe_l7a_tmp_2025322T0544_11268_v01.nc: added points per component: {'MFz_top': 14772, 'MFm_top': 14772}
# awe_l7a_tmp_2025322T0717_11269_v01.nc: added points per component: {'MFz_top': 21595, 'MFm_top': 21595}
# awe_l7a_tmp_2025322T1023_11271_v01.nc: added points per component: {'MFz_top': 10574, 'MFm_top': 10574}
# awe_l7a_tmp_2025322T1155_11272_v01.nc: added points per component: {'MFz_top': 15424, 'MFm_top': 15424}
# awe_l7a_tmp_2025322T1329_11273_v01.nc: added points per component: {'MFz_top': 15988, 'MFm_top': 15988}
# awe_l7a_tmp_2025322T1502_11274_v01.nc: added points per component: {'MFz_top': 15912, 'MFm_top': 15912}
# awe_l7a_tmp_2025322T1634_11275_v01.nc: added points per component: {'MFz_top': 21449, 'MFm_top': 21449}
# awe_l7a_tmp_2025322T1808_11276_v01.nc: added points per component: {'MFz_top': 42052, 'MFm_top': 42052}
# awe_l7a_tmp_2025322T1941_11277_v01.nc: added points per component: {'MFz_top': 25386, 'MFm_top': 25386}
# awe_l7a_tmp_2025322T2114_11278_v01.nc: added points per component: {'MFz_top': 20373, 'MFm_top': 20373}
# awe_l7a_tmp_2025322T2247_11279_v01.nc: added points per component: {'MFz_top': 44858, 'MFm_top': 44858}
# awe_l7a_tmp_2025323T0019_11280_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025323T0153_11281_v01.nc: added points per component: {'MFz_top': 26388, 'MFm_top': 26388}
# awe_l7a_tmp_2025323T0326_11282_v01.nc: added points per component: {'MFz_top': 34790, 'MFm_top': 34790}
# awe_l7a_tmp_2025323T0459_11283_v01.nc: added points per component: {'MFz_top': 5719, 'MFm_top': 5719}
# awe_l7a_tmp_2025323T0631_11284_v01.nc: added points per component: {'MFz_top': 37712, 'MFm_top': 37712}
# awe_l7a_tmp_2025323T0804_11285_v01.nc: added points per component: {'MFz_top': 15530, 'MFm_top': 15530}
# awe_l7a_tmp_2025323T0936_11286_v01.nc: added points per component: {'MFz_top': 5244, 'MFm_top': 5244}
# awe_l7a_tmp_2025323T1110_11287_v01.nc: added points per component: {'MFz_top': 31862, 'MFm_top': 31862}
# awe_l7a_tmp_2025323T1239_11288_v01.nc: added points per component: {'MFz_top': 15390, 'MFm_top': 15390}
# awe_l7a_tmp_2025323T1548_11290_v01.nc: added points per component: {'MFz_top': 44521, 'MFm_top': 44521}
# awe_l7a_tmp_2025323T1722_11291_v01.nc: added points per component: {'MFz_top': 35251, 'MFm_top': 35251}
# awe_l7a_tmp_2025323T1855_11292_v01.nc: added points per component: {'MFz_top': 46037, 'MFm_top': 46037}
# awe_l7a_tmp_2025323T2027_11293_v01.nc: added points per component: {'MFz_top': 31266, 'MFm_top': 31266}
# awe_l7a_tmp_2025323T2200_11294_v01.nc: added points per component: {'MFz_top': 30217, 'MFm_top': 30217}
# awe_l7a_tmp_2025323T2334_11295_v01.nc: added points per component: {'MFz_top': 25799, 'MFm_top': 25799}
# awe_l7a_tmp_2025324T0106_11296_v01.nc: added points per component: {'MFz_top': 25561, 'MFm_top': 25561}
# awe_l7a_tmp_2025324T0239_11297_v01.nc: added points per component: {'MFz_top': 4962, 'MFm_top': 4962}
# awe_l7a_tmp_2025324T0412_11298_v01.nc: added points per component: {'MFz_top': 46886, 'MFm_top': 46886}
# awe_l7a_tmp_2025324T0545_11299_v01.nc: added points per component: {'MFz_top': 45658, 'MFm_top': 45658}
# awe_l7a_tmp_2025324T0718_11300_v01.nc: added points per component: {'MFz_top': 16932, 'MFm_top': 16932}
# awe_l7a_tmp_2025324T1023_11302_v01.nc: added points per component: {'MFz_top': 10111, 'MFm_top': 10111}
# awe_l7a_tmp_2025324T1158_11303_v01.nc: added points per component: {'MFz_top': 10432, 'MFm_top': 10432}
# awe_l7a_tmp_2025324T1329_11304_v01.nc: added points per component: {'MFz_top': 15988, 'MFm_top': 15988}
# awe_l7a_tmp_2025324T1503_11305_v01.nc: added points per component: {'MFz_top': 40935, 'MFm_top': 40935}
# awe_l7a_tmp_2025324T1636_11306_v01.nc: added points per component: {'MFz_top': 25561, 'MFm_top': 25561}
# awe_l7a_tmp_2025324T1808_11307_v01.nc: added points per component: {'MFz_top': 20373, 'MFm_top': 20373}
# awe_l7a_tmp_2025324T2114_11309_v01.nc: added points per component: {'MFz_top': 34512, 'MFm_top': 34512}
# awe_l7a_tmp_2025324T2248_11310_v01.nc: added points per component: {'MFz_top': 19188, 'MFm_top': 19188}
# awe_l7a_tmp_2025325T0020_11311_v01.nc: added points per component: {'MFz_top': 44866, 'MFm_top': 44866}
# awe_l7a_tmp_2025325T0154_11312_v01.nc: added points per component: {'MFz_top': 21958, 'MFm_top': 21958}
# awe_l7a_tmp_2025325T0326_11313_v01.nc: added points per component: {'MFz_top': 45254, 'MFm_top': 45254}
# awe_l7a_tmp_2025325T0500_11314_v01.nc: added points per component: {'MFz_top': 10484, 'MFm_top': 10484}
# awe_l7a_tmp_2025325T0632_11315_v01.nc: added points per component: {'MFz_top': 34965, 'MFm_top': 34965}
# awe_l7a_tmp_2025325T1244_11319_v01.nc: added points per component: {'MFz_top': 4342, 'MFm_top': 4342}
# awe_l7a_tmp_2025325T1417_11320_v01.nc: added points per component: {'MFz_top': 35574, 'MFm_top': 35574}
# awe_l7a_tmp_2025325T1550_11321_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025325T1721_11322_v01.nc: added points per component: {'MFz_top': 42148, 'MFm_top': 42148}
# awe_l7a_tmp_2025325T1855_11323_v01.nc: added points per component: {'MFz_top': 41614, 'MFm_top': 41614}
# awe_l7a_tmp_2025325T2029_11324_v01.nc: added points per component: {'MFz_top': 10568, 'MFm_top': 10568}
# awe_l7a_tmp_2025325T2202_11325_v01.nc: added points per component: {'MFz_top': 25326, 'MFm_top': 25326}
# awe_l7a_tmp_2025325T2335_11326_v01.nc: added points per component: {'MFz_top': 35889, 'MFm_top': 35889}
# awe_l7a_tmp_2025326T0108_11327_v01.nc: added points per component: {'MFz_top': 25662, 'MFm_top': 25662}
# awe_l7a_tmp_2025326T0242_11328_v01.nc: added points per component: {'MFz_top': 10571, 'MFm_top': 10571}
# awe_l7a_tmp_2025326T0414_11329_v01.nc: added points per component: {'MFz_top': 41318, 'MFm_top': 41318}
# awe_l7a_tmp_2025326T0547_11330_v01.nc: added points per component: {'MFz_top': 17170, 'MFm_top': 17170}
# awe_l7a_tmp_2025326T0853_11332_v01.nc: added points per component: {'MFz_top': 5362, 'MFm_top': 5362}
# awe_l7a_tmp_2025326T1025_11333_v01.nc: added points per component: {'MFz_top': 5341, 'MFm_top': 5341}
# awe_l7a_tmp_2025326T1158_11334_v01.nc: added points per component: {'MFz_top': 5428, 'MFm_top': 5428}
# awe_l7a_tmp_2025326T1331_11335_v01.nc: added points per component: {'MFz_top': 36454, 'MFm_top': 36454}
# awe_l7a_tmp_2025326T1505_11336_v01.nc: added points per component: {'MFz_top': 41284, 'MFm_top': 41284}
# awe_l7a_tmp_2025326T1638_11337_v01.nc: added points per component: {'MFz_top': 35889, 'MFm_top': 35889}
# awe_l7a_tmp_2025326T1811_11338_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025326T1944_11339_v01.nc: added points per component: {'MFz_top': 26388, 'MFm_top': 26388}
# awe_l7a_tmp_2025326T2117_11340_v01.nc: added points per component: {'MFz_top': 15706, 'MFm_top': 15706}
# awe_l7a_tmp_2025326T2250_11341_v01.nc: added points per component: {'MFz_top': 36402, 'MFm_top': 36402}
# awe_l7a_tmp_2025327T0022_11342_v01.nc: added points per component: {'MFz_top': 34372, 'MFm_top': 34372}
# awe_l7a_tmp_2025327T0155_11343_v01.nc: added points per component: {'MFz_top': 41657, 'MFm_top': 41657}
# awe_l7a_tmp_2025327T0328_11344_v01.nc: added points per component: {'MFz_top': 14426, 'MFm_top': 14426}
# awe_l7a_tmp_2025327T0501_11345_v01.nc: added points per component: {'MFz_top': 35746, 'MFm_top': 35746}
# awe_l7a_tmp_2025327T0635_11346_v01.nc: added points per component: {'MFz_top': 5208, 'MFm_top': 5208}
# awe_l7a_tmp_2025327T0807_11347_v01.nc: added points per component: {'MFz_top': 5393, 'MFm_top': 5393}
# awe_l7a_tmp_2025327T1246_11350_v01.nc: added points per component: {'MFz_top': 40895, 'MFm_top': 40895}
# awe_l7a_tmp_2025327T1419_11351_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025327T1552_11352_v01.nc: added points per component: {'MFz_top': 31862, 'MFm_top': 31862}
# awe_l7a_tmp_2025327T1725_11353_v01.nc: added points per component: {'MFz_top': 36846, 'MFm_top': 36846}
# awe_l7a_tmp_2025327T1858_11354_v01.nc: added points per component: {'MFz_top': 31862, 'MFm_top': 31862}
# awe_l7a_tmp_2025327T2032_11355_v01.nc: added points per component: {'MFz_top': 39826, 'MFm_top': 39826}
# awe_l7a_tmp_2025327T2204_11356_v01.nc: added points per component: {'MFz_top': 26486, 'MFm_top': 26486}
# awe_l7a_tmp_2025327T2337_11357_v01.nc: added points per component: {'MFz_top': 26521, 'MFm_top': 26521}
# awe_l7a_tmp_2025328T0110_11358_v01.nc: added points per component: {'MFz_top': 10574, 'MFm_top': 10574}
# awe_l7a_tmp_2025328T0243_11359_v01.nc: added points per component: {'MFz_top': 38086, 'MFm_top': 38086}
# awe_l7a_tmp_2025328T0416_11360_v01.nc: added points per component: {'MFz_top': 37060, 'MFm_top': 37060}
# awe_l7a_tmp_2025328T0722_11362_v01.nc: added points per component: {'MFz_top': 5373, 'MFm_top': 5373}
# awe_l7a_tmp_2025328T0854_11363_v01.nc: added points per component: {'MFz_top': 5468, 'MFm_top': 5468}
# awe_l7a_tmp_2025328T1201_11365_v01.nc: added points per component: {'MFz_top': 47718, 'MFm_top': 47718}
# awe_l7a_tmp_2025328T1333_11366_v01.nc: added points per component: {'MFz_top': 41614, 'MFm_top': 41614}
# awe_l7a_tmp_2025328T1507_11367_v01.nc: added points per component: {'MFz_top': 42377, 'MFm_top': 42377}
# awe_l7a_tmp_2025328T1639_11368_v01.nc: added points per component: {'MFz_top': 44771, 'MFm_top': 44771}
# awe_l7a_tmp_2025328T1813_11369_v01.nc: added points per component: {'MFz_top': 32481, 'MFm_top': 32481}
# awe_l7a_tmp_2025328T2118_11371_v01.nc: added points per component: {'MFz_top': 30339, 'MFm_top': 30339}
# awe_l7a_tmp_2025328T2252_11372_v01.nc: added points per component: {'MFz_top': 31691, 'MFm_top': 31691}
# awe_l7a_tmp_2025329T0025_11373_v01.nc: added points per component: {'MFz_top': 42377, 'MFm_top': 42377}
# awe_l7a_tmp_2025329T0158_11374_v01.nc: added points per component: {'MFz_top': 26953, 'MFm_top': 26953}
# awe_l7a_tmp_2025329T0331_11375_v01.nc: added points per component: {'MFz_top': 45654, 'MFm_top': 45654}
# awe_l7a_tmp_2025329T0504_11376_v01.nc: added points per component: {'MFz_top': 5409, 'MFm_top': 5409}
# awe_l7a_tmp_2025329T0637_11377_v01.nc: added points per component: {'MFz_top': 5292, 'MFm_top': 5292}
# awe_l7a_tmp_2025329T1115_11380_v01.nc: added points per component: {'MFz_top': 48630, 'MFm_top': 48630}
# awe_l7a_tmp_2025329T1248_11381_v01.nc: added points per component: {'MFz_top': 15628, 'MFm_top': 15628}
# awe_l7a_tmp_2025329T1421_11382_v01.nc: added points per component: {'MFz_top': 32989, 'MFm_top': 32989}
# awe_l7a_tmp_2025329T1555_11383_v01.nc: added points per component: {'MFz_top': 38374, 'MFm_top': 38374}
# awe_l7a_tmp_2025329T1728_11384_v01.nc: added points per component: {'MFz_top': 16416, 'MFm_top': 16416}
# awe_l7a_tmp_2025329T1901_11385_v01.nc: added points per component: {'MFz_top': 10706, 'MFm_top': 10706}
# awe_l7a_tmp_2025329T2034_11386_v01.nc: added points per component: {'MFz_top': 37681, 'MFm_top': 37681}
# awe_l7a_tmp_2025329T2206_11387_v01.nc: added points per component: {'MFz_top': 37712, 'MFm_top': 37712}
# awe_l7a_tmp_2025329T2340_11388_v01.nc: added points per component: {'MFz_top': 10772, 'MFm_top': 10772}
# awe_l7a_tmp_2025330T0113_11389_v01.nc: added points per component: {'MFz_top': 16086, 'MFm_top': 16086}
# awe_l7a_tmp_2025330T0246_11390_v01.nc: added points per component: {'MFz_top': 43519, 'MFm_top': 43519}
# awe_l7a_tmp_2025330T0418_11391_v01.nc: added points per component: {'MFz_top': 43102, 'MFm_top': 43102}
# awe_l7a_tmp_2025330T0725_11393_v01.nc: added points per component: {'MFz_top': 32396, 'MFm_top': 32396}
# awe_l7a_tmp_2025330T0857_11394_v01.nc: added points per component: {'MFz_top': 5433, 'MFm_top': 5433}
# awe_l7a_tmp_2025330T1029_11395_v01.nc: added points per component: {'MFz_top': 5317, 'MFm_top': 5317}
# awe_l7a_tmp_2025330T1202_11396_v01.nc: added points per component: {'MFz_top': 48164, 'MFm_top': 48164}
# awe_l7a_tmp_2025330T1336_11397_v01.nc: added points per component: {'MFz_top': 43102, 'MFm_top': 43102}
# awe_l7a_tmp_2025330T1509_11398_v01.nc: added points per component: {'MFz_top': 49500, 'MFm_top': 49500}
# awe_l7a_tmp_2025330T1642_11399_v01.nc: added points per component: {'MFz_top': 10918, 'MFm_top': 10918}
# awe_l7a_tmp_2025330T1815_11400_v01.nc: added points per component: {'MFz_top': 16777, 'MFm_top': 16777}
# awe_l7a_tmp_2025330T1949_11401_v01.nc: added points per component: {'MFz_top': 39078, 'MFm_top': 39078}
# awe_l7a_tmp_2025330T2121_11402_v01.nc: added points per component: {'MFz_top': 44290, 'MFm_top': 44290}
# awe_l7a_tmp_2025330T2254_11403_v01.nc: added points per component: {'MFz_top': 16385, 'MFm_top': 16385}
# awe_l7a_tmp_2025331T0200_11405_v01.nc: added points per component: {'MFz_top': 49500, 'MFm_top': 49500}
# awe_l7a_tmp_2025331T0332_11406_v01.nc: added points per component: {'MFz_top': 44771, 'MFm_top': 44771}
# awe_l7a_tmp_2025331T0506_11407_v01.nc: added points per component: {'MFz_top': 21977, 'MFm_top': 21977}
# awe_l7a_tmp_2025331T0812_11409_v01.nc: added points per component: {'MFz_top': 5348, 'MFm_top': 5348}
# awe_l7a_tmp_2025331T0941_11410_v01.nc: added points per component: {'MFz_top': 16468, 'MFm_top': 16468}
# awe_l7a_tmp_2025331T1114_11411_v01.nc: added points per component: {'MFz_top': 48951, 'MFm_top': 48951}
# awe_l7a_tmp_2025331T1246_11412_v01.nc: added points per component: {'MFz_top': 44884, 'MFm_top': 44884}
# awe_l7a_tmp_2025331T1421_11413_v01.nc: added points per component: {'MFz_top': 37816, 'MFm_top': 37816}
# awe_l7a_tmp_2025331T1557_11414_v01.nc: added points per component: {'MFz_top': 16708, 'MFm_top': 16708}
# awe_l7a_tmp_2025331T1730_11415_v01.nc: added points per component: {'MFz_top': 5719, 'MFm_top': 5719}
# awe_l7a_tmp_2025331T1902_11416_v01.nc: added points per component: {'MFz_top': 27523, 'MFm_top': 27523}
# awe_l7a_tmp_2025331T2036_11417_v01.nc: added points per component: {'MFz_top': 21958, 'MFm_top': 21958}
# awe_l7a_tmp_2025331T2209_11418_v01.nc: added points per component: {'MFz_top': 16868, 'MFm_top': 16868}
# awe_l7a_tmp_2025331T2341_11419_v01.nc: added points per component: {'MFz_top': 5335, 'MFm_top': 5335}
# awe_l7a_tmp_2025332T0114_11420_v01.nc: added points per component: {'MFz_top': 21853, 'MFm_top': 21853}
# awe_l7a_tmp_2025332T0248_11421_v01.nc: added points per component: {'MFz_top': 5574, 'MFm_top': 5574}
# awe_l7a_tmp_2025332T0421_11422_v01.nc: added points per component: {'MFz_top': 5658, 'MFm_top': 5658}
# awe_l7a_tmp_2025332T0553_11423_v01.nc: added points per component: {'MFz_top': 16319, 'MFm_top': 16319}
# awe_l7a_tmp_2025332T0726_11424_v01.nc: added points per component: {'MFz_top': 37712, 'MFm_top': 37712}
# awe_l7a_tmp_2025332T0859_11425_v01.nc: added points per component: {'MFz_top': 5658, 'MFm_top': 5658}
# awe_l7a_tmp_2025332T1032_11426_v01.nc: added points per component: {'MFz_top': 5528, 'MFm_top': 5528}
# awe_l7a_tmp_2025332T1204_11427_v01.nc: added points per component: {'MFz_top': 36454, 'MFm_top': 36454}
# awe_l7a_tmp_2025332T1338_11428_v01.nc: added points per component: {'MFz_top': 22830, 'MFm_top': 22830}
# awe_l7a_tmp_2025332T1512_11429_v01.nc: added points per component: {'MFz_top': 17047, 'MFm_top': 17047}
# awe_l7a_tmp_2025332T1643_11430_v01.nc: added points per component: {'MFz_top': 16205, 'MFm_top': 16205}
# awe_l7a_tmp_2025332T1817_11431_v01.nc: added points per component: {'MFz_top': 5779, 'MFm_top': 5779}
# awe_l7a_tmp_2025332T1950_11432_v01.nc: added points per component: {'MFz_top': 17170, 'MFm_top': 17170}
# awe_l7a_tmp_2025332T2123_11433_v01.nc: added points per component: {'MFz_top': 32834, 'MFm_top': 32834}
# awe_l7a_tmp_2025332T2256_11434_v01.nc: added points per component: {'MFz_top': 5471, 'MFm_top': 5471}
# awe_l7a_tmp_2025333T0029_11435_v01.nc: added points per component: {'MFz_top': 34900, 'MFm_top': 34900}
# awe_l7a_tmp_2025333T0202_11436_v01.nc: added points per component: {'MFz_top': 22257, 'MFm_top': 22257}
# awe_l7a_tmp_2025333T0335_11437_v01.nc: added points per component: {'MFz_top': 26940, 'MFm_top': 26940}
# awe_l7a_tmp_2025333T0508_11438_v01.nc: added points per component: {'MFz_top': 16868, 'MFm_top': 16868}
# awe_l7a_tmp_2025333T0639_11439_v01.nc: added points per component: {'MFz_top': 5188, 'MFm_top': 5188}
# awe_l7a_tmp_2025333T0813_11440_v01.nc: added points per component: {'MFz_top': 5369, 'MFm_top': 5369}
# awe_l7a_tmp_2025333T0947_11441_v01.nc: added points per component: {'MFz_top': 21977, 'MFm_top': 21977}
# awe_l7a_tmp_2025333T1119_11442_v01.nc: added points per component: {'MFz_top': 21690, 'MFm_top': 21690}
# awe_l7a_tmp_2025333T1253_11443_v01.nc: added points per component: {'MFz_top': 46511, 'MFm_top': 46511}
# awe_l7a_tmp_2025333T1427_11444_v01.nc: added points per component: {'MFz_top': 46511, 'MFm_top': 46511}
# awe_l7a_tmp_2025333T1559_11445_v01.nc: added points per component: {'MFz_top': 22395, 'MFm_top': 22395}
# awe_l7a_tmp_2025333T1732_11446_v01.nc: added points per component: {'MFz_top': 5848, 'MFm_top': 5848}
# awe_l7a_tmp_2025333T1904_11447_v01.nc: added points per component: {'MFz_top': 39826, 'MFm_top': 39826}
# awe_l7a_tmp_2025333T2038_11448_v01.nc: added points per component: {'MFz_top': 33491, 'MFm_top': 33491}
# awe_l7a_tmp_2025333T2343_11450_v01.nc: added points per component: {'MFz_top': 27605, 'MFm_top': 27605}
# awe_l7a_tmp_2025334T0116_11451_v01.nc: added points per component: {'MFz_top': 43979, 'MFm_top': 43979}
# awe_l7a_tmp_2025334T0248_11452_v01.nc: added points per component: {'MFz_top': 10577, 'MFm_top': 10577}
# awe_l7a_tmp_2025334T0422_11453_v01.nc: added points per component: {'MFz_top': 22479, 'MFm_top': 22479}
# awe_l7a_tmp_2025334T0727_11455_v01.nc: added points per component: {'MFz_top': 31730, 'MFm_top': 31730}
# awe_l7a_tmp_2025334T0901_11456_v01.nc: added points per component: {'MFz_top': 10814, 'MFm_top': 10814}
# awe_l7a_tmp_2025334T1034_11457_v01.nc: added points per component: {'MFz_top': 27860, 'MFm_top': 27860}
# awe_l7a_tmp_2025334T1208_11458_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025334T1340_11459_v01.nc: added points per component: {'MFz_top': 44652, 'MFm_top': 44652}
# awe_l7a_tmp_2025334T1513_11460_v01.nc: added points per component: {'MFz_top': 23002, 'MFm_top': 23002}
# awe_l7a_tmp_2025334T1645_11461_v01.nc: added points per component: {'MFz_top': 37681, 'MFm_top': 37681}
# awe_l7a_tmp_2025334T1818_11462_v01.nc: added points per component: {'MFz_top': 48630, 'MFm_top': 48630}
# awe_l7a_tmp_2025334T2125_11464_v01.nc: added points per component: {'MFz_top': 44244, 'MFm_top': 44244}
# awe_l7a_tmp_2025334T2258_11465_v01.nc: added points per component: {'MFz_top': 38479, 'MFm_top': 38479}
# awe_l7a_tmp_2025335T0030_11466_v01.nc: added points per component: {'MFz_top': 42377, 'MFm_top': 42377}
# Saved: C:\Users\domin\juwavelet\Momentum Flux\outputs_MF_cartopy\2025\stacked_all_months\2025_11_MFz_MFm_stacked_global_maps.png
#
# ================================================================================
# Processing 2025-12
# ================================================================================
# Found 386 files in \\awex2.physics.usu.edu\awewrite\socfiles\public\l7\2025\12 matching *l7a*.nc
# awe_l7a_tmp_2025335T0201_11467_v01.nc: added points per component: {'MFz_top': 35788, 'MFm_top': 35788}
# awe_l7a_tmp_2025335T0334_11468_v01.nc: added points per component: {'MFz_top': 8070, 'MFm_top': 8070}
# awe_l7a_tmp_2025335T0507_11469_v01.nc: added points per component: {'MFz_top': 7484, 'MFm_top': 7484}
# awe_l7a_tmp_2025335T0640_11470_v01.nc: added points per component: {'MFz_top': 14119, 'MFm_top': 14119}
# awe_l7a_tmp_2025335T0813_11471_v01.nc: added points per component: {'MFz_top': 33005, 'MFm_top': 33005}
# awe_l7a_tmp_2025335T0947_11472_v01.nc: added points per component: {'MFz_top': 47598, 'MFm_top': 47598}
# awe_l7a_tmp_2025335T1119_11473_v01.nc: added points per component: {'MFz_top': 47963, 'MFm_top': 47963}
# awe_l7a_tmp_2025335T1253_11474_v01.nc: added points per component: {'MFz_top': 48319, 'MFm_top': 48319}
# awe_l7a_tmp_2025335T1425_11475_v01.nc: added points per component: {'MFz_top': 47963, 'MFm_top': 47963}
# awe_l7a_tmp_2025335T1559_11476_v01.nc: added points per component: {'MFz_top': 34143, 'MFm_top': 34143}
# awe_l7a_tmp_2025335T1731_11477_v01.nc: added points per component: {'MFz_top': 33691, 'MFm_top': 33691}
# awe_l7a_tmp_2025335T1905_11478_v01.nc: added points per component: {'MFz_top': 34233, 'MFm_top': 34233}
# awe_l7a_tmp_2025335T2038_11479_v01.nc: added points per component: {'MFz_top': 24840, 'MFm_top': 24840}
# awe_l7a_tmp_2025335T2211_11480_v01.nc: added points per component: {'MFz_top': 29726, 'MFm_top': 29726}
# awe_l7a_tmp_2025335T2344_11481_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025336T0117_11482_v01.nc: added points per component: {'MFz_top': 34801, 'MFm_top': 34801}
# awe_l7a_tmp_2025336T0250_11483_v01.nc: added points per component: {'MFz_top': 15399, 'MFm_top': 15399}
# awe_l7a_tmp_2025336T0556_11485_v01.nc: added points per component: {'MFz_top': 24229, 'MFm_top': 24229}
# awe_l7a_tmp_2025336T0729_11486_v01.nc: added points per component: {'MFz_top': 25471, 'MFm_top': 25471}
# awe_l7a_tmp_2025336T0902_11487_v01.nc: added points per component: {'MFz_top': 10487, 'MFm_top': 10487}
# awe_l7a_tmp_2025336T1036_11488_v01.nc: added points per component: {'MFz_top': 26132, 'MFm_top': 26132}
# awe_l7a_tmp_2025336T1208_11489_v01.nc: added points per component: {'MFz_top': 44814, 'MFm_top': 44814}
# awe_l7a_tmp_2025336T1342_11490_v01.nc: added points per component: {'MFz_top': 48164, 'MFm_top': 48164}
# ...
# awe_l7a_tmp_2025355T1807_11787_v01.nc: added points per component: {'MFz_top': 45254, 'MFm_top': 45254}
# awe_l7a_tmp_2025355T1942_11788_v01.nc: added points per component: {'MFz_top': 15856, 'MFm_top': 15856}
# awe_l7a_tmp_2025355T2115_11789_v01.nc: added points per component: {'MFz_top': 5188, 'MFm_top': 5188}
# awe_l7a_tmp_2025356T0020_11791_v01.nc: added points per component: {'MFz_top': 43209, 'MFm_top': 43209}
# awe_l7a_tmp_2025356T0154_11792_v01.nc: added points per component: {'MFz_top': 42349, 'MFm_top': 42349}
# awe_l7a_tmp_2025356T0326_11793_v01.nc: added points per component: {'MFz_top': 35793, 'MFm_top': 35793}
# awe_l7a_tmp_2025356T0500_11794_v01.nc: added points per component: {'MFz_top': 15856, 'MFm_top': 15856}
# awe_l7a_tmp_2025356T0632_11795_v01.nc: added points per component: {'MFz_top': 15856, 'MFm_top': 15856}
# awe_l7a_tmp_2025356T0805_11796_v01.nc: added points per component: {'MFz_top': 39516, 'MFm_top': 39516}
# awe_l7a_tmp_2025356T0938_11797_v01.nc: added points per component: {'MFz_top': 43842, 'MFm_top': 43842}
# awe_l7a_tmp_2025356T1110_11798_v01.nc: added points per component: {'MFz_top': 34626, 'MFm_top': 34626}
# awe_l7a_tmp_2025356T1243_11799_v01.nc: added points per component: {'MFz_top': 20736, 'MFm_top': 20736}
# awe_l7a_tmp_2025356T1415_11800_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025356T1550_11801_v01.nc: added points per component: {'MFz_top': 15820, 'MFm_top': 15820}
# awe_l7a_tmp_2025356T1722_11802_v01.nc: added points per component: {'MFz_top': 14111, 'MFm_top': 14111}
# awe_l7a_tmp_2025356T1855_11803_v01.nc: added points per component: {'MFz_top': 14663, 'MFm_top': 14663}
# awe_l7a_tmp_2025356T2028_11804_v01.nc: added points per component: {'MFz_top': 46886, 'MFm_top': 46886}
# awe_l7a_tmp_2025356T2200_11805_v01.nc: added points per component: {'MFz_top': 34616, 'MFm_top': 34616}
# awe_l7a_tmp_2025356T2334_11806_v01.nc: added points per component: {'MFz_top': 21117, 'MFm_top': 21117}
# awe_l7a_tmp_2025357T0106_11807_v01.nc: added points per component: {'MFz_top': 31266, 'MFm_top': 31266}
# awe_l7a_tmp_2025357T0412_11809_v01.nc: added points per component: {'MFz_top': 24980, 'MFm_top': 24980}
# awe_l7a_tmp_2025357T0719_11811_v01.nc: added points per component: {'MFz_top': 36385, 'MFm_top': 36385}
# awe_l7a_tmp_2025357T0852_11812_v01.nc: added points per component: {'MFz_top': 5393, 'MFm_top': 5393}
# awe_l7a_tmp_2025357T1025_11813_v01.nc: added points per component: {'MFz_top': 47266, 'MFm_top': 47266}
# awe_l7a_tmp_2025357T1157_11814_v01.nc: added points per component: {'MFz_top': 10451, 'MFm_top': 10451}
# awe_l7a_tmp_2025357T1330_11815_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025357T1503_11816_v01.nc: added points per component: {'MFz_top': 15620, 'MFm_top': 15620}
# awe_l7a_tmp_2025357T1636_11817_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025357T1809_11818_v01.nc: added points per component: {'MFz_top': 10432, 'MFm_top': 10432}
# awe_l7a_tmp_2025357T1941_11819_v01.nc: added points per component: {'MFz_top': 20736, 'MFm_top': 20736}
# awe_l7a_tmp_2025357T2115_11820_v01.nc: added points per component: {'MFz_top': 5574, 'MFm_top': 5574}
# awe_l7a_tmp_2025357T2248_11821_v01.nc: added points per component: {'MFz_top': 37060, 'MFm_top': 37060}
# awe_l7a_tmp_2025358T0021_11822_v01.nc: added points per component: {'MFz_top': 32821, 'MFm_top': 32821}
# awe_l7a_tmp_2025358T0152_11823_v01.nc: added points per component: {'MFz_top': 10484, 'MFm_top': 10484}
# awe_l7a_tmp_2025358T0326_11824_v01.nc: added points per component: {'MFz_top': 31800, 'MFm_top': 31800}
# awe_l7a_tmp_2025358T0459_11825_v01.nc: added points per component: {'MFz_top': 38374, 'MFm_top': 38374}
# awe_l7a_tmp_2025358T0632_11826_v01.nc: added points per component: {'MFz_top': 15225, 'MFm_top': 15225}
# awe_l7a_tmp_2025358T0805_11827_v01.nc: added points per component: {'MFz_top': 15225, 'MFm_top': 15225}
# awe_l7a_tmp_2025358T0938_11828_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025358T1111_11829_v01.nc: added points per component: {'MFz_top': 8682, 'MFm_top': 8682}
# awe_l7a_tmp_2025358T1244_11830_v01.nc: added points per component: {'MFz_top': 5255, 'MFm_top': 5255}
# awe_l7a_tmp_2025358T1416_11831_v01.nc: added points per component: {'MFz_top': 41614, 'MFm_top': 41614}
# awe_l7a_tmp_2025358T1549_11832_v01.nc: added points per component: {'MFz_top': 9959, 'MFm_top': 9959}
# awe_l7a_tmp_2025358T1722_11833_v01.nc: added points per component: {'MFz_top': 5046, 'MFm_top': 5046}
# awe_l7a_tmp_2025358T1854_11834_v01.nc: added points per component: {'MFz_top': 5041, 'MFm_top': 5041}
# awe_l7a_tmp_2025358T2027_11835_v01.nc: added points per component: {'MFz_top': 39484, 'MFm_top': 39484}
# awe_l7a_tmp_2025358T2333_11837_v01.nc: added points per component: {'MFz_top': 39837, 'MFm_top': 39837}
# awe_l7a_tmp_2025359T0105_11838_v01.nc: added points per component: {'MFz_top': 40524, 'MFm_top': 40524}
# awe_l7a_tmp_2025359T0239_11839_v01.nc: added points per component: {'MFz_top': 36753, 'MFm_top': 36753}
# awe_l7a_tmp_2025359T0412_11840_v01.nc: added points per component: {'MFz_top': 26975, 'MFm_top': 26975}
# awe_l7a_tmp_2025359T0544_11841_v01.nc: added points per component: {'MFz_top': 14772, 'MFm_top': 14772}
# awe_l7a_tmp_2025359T0716_11842_v01.nc: added points per component: {'MFz_top': 9291, 'MFm_top': 9291}
# awe_l7a_tmp_2025359T0851_11843_v01.nc: added points per component: {'MFz_top': 15225, 'MFm_top': 15225}
# awe_l7a_tmp_2025359T1024_11844_v01.nc: added points per component: {'MFz_top': 9065, 'MFm_top': 9065}
# awe_l7a_tmp_2025359T1157_11845_v01.nc: added points per component: {'MFz_top': 19643, 'MFm_top': 19643}
# awe_l7a_tmp_2025359T1328_11846_v01.nc: added points per component: {'MFz_top': 18848, 'MFm_top': 18848}
# awe_l7a_tmp_2025359T1503_11847_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025359T1635_11848_v01.nc: added points per component: {'MFz_top': 34603, 'MFm_top': 34603}
# awe_l7a_tmp_2025359T1809_11849_v01.nc: added points per component: {'MFz_top': 20266, 'MFm_top': 20266}
# awe_l7a_tmp_2025359T1941_11850_v01.nc: added points per component: {'MFz_top': 40895, 'MFm_top': 40895}
# awe_l7a_tmp_2025359T2114_11851_v01.nc: added points per component: {'MFz_top': 34965, 'MFm_top': 34965}
# awe_l7a_tmp_2025359T2247_11852_v01.nc: added points per component: {'MFz_top': 29653, 'MFm_top': 29653}
# awe_l7a_tmp_2025360T0020_11853_v01.nc: added points per component: {'MFz_top': 49582, 'MFm_top': 49582}
# awe_l7a_tmp_2025360T0153_11854_v01.nc: added points per component: {'MFz_top': 9152, 'MFm_top': 9152}
# awe_l7a_tmp_2025360T0326_11855_v01.nc: added points per component: {'MFz_top': 44858, 'MFm_top': 44858}
# awe_l7a_tmp_2025360T0458_11856_v01.nc: added points per component: {'MFz_top': 29653, 'MFm_top': 29653}
# awe_l7a_tmp_2025360T0632_11857_v01.nc: added points per component: {'MFz_top': 9605, 'MFm_top': 9605}
# awe_l7a_tmp_2025360T0805_11858_v01.nc: added points per component: {'MFz_top': 5205, 'MFm_top': 5205}
# awe_l7a_tmp_2025360T0938_11859_v01.nc: added points per component: {'MFz_top': 44866, 'MFm_top': 44866}
# awe_l7a_tmp_2025360T1111_11860_v01.nc: added points per component: {'MFz_top': 34801, 'MFm_top': 34801}
# awe_l7a_tmp_2025360T1243_11861_v01.nc: added points per component: {'MFz_top': 35091, 'MFm_top': 35091}
# awe_l7a_tmp_2025360T1417_11862_v01.nc: added points per component: {'MFz_top': 44880, 'MFm_top': 44880}
# awe_l7a_tmp_2025360T1550_11863_v01.nc: added points per component: {'MFz_top': 40524, 'MFm_top': 40524}
# awe_l7a_tmp_2025360T1723_11864_v01.nc: added points per component: {'MFz_top': 34879, 'MFm_top': 34879}
# awe_l7a_tmp_2025360T1855_11865_v01.nc: added points per component: {'MFz_top': 10348, 'MFm_top': 10348}
# awe_l7a_tmp_2025360T2028_11866_v01.nc: added points per component: {'MFz_top': 30644, 'MFm_top': 30644}
# awe_l7a_tmp_2025360T2201_11867_v01.nc: added points per component: {'MFz_top': 41657, 'MFm_top': 41657}
# awe_l7a_tmp_2025360T2335_11868_v01.nc: added points per component: {'MFz_top': 37008, 'MFm_top': 37008}
# awe_l7a_tmp_2025361T0106_11869_v01.nc: added points per component: {'MFz_top': 48776, 'MFm_top': 48776}
# awe_l7a_tmp_2025361T0240_11870_v01.nc: added points per component: {'MFz_top': 35889, 'MFm_top': 35889}
# awe_l7a_tmp_2025361T0413_11871_v01.nc: added points per component: {'MFz_top': 5034, 'MFm_top': 5034}
# awe_l7a_tmp_2025361T0545_11872_v01.nc: added points per component: {'MFz_top': 47963, 'MFm_top': 47963}
# awe_l7a_tmp_2025361T0718_11873_v01.nc: added points per component: {'MFz_top': 19747, 'MFm_top': 19747}
# awe_l7a_tmp_2025361T0852_11874_v01.nc: added points per component: {'MFz_top': 20480, 'MFm_top': 20480}
# awe_l7a_tmp_2025361T1026_11875_v01.nc: added points per component: {'MFz_top': 15164, 'MFm_top': 15164}
# awe_l7a_tmp_2025361T1158_11876_v01.nc: added points per component: {'MFz_top': 19811, 'MFm_top': 19811}
# awe_l7a_tmp_2025361T1329_11877_v01.nc: added points per component: {'MFz_top': 38867, 'MFm_top': 38867}
# awe_l7a_tmp_2025361T1504_11878_v01.nc: added points per component: {'MFz_top': 41614, 'MFm_top': 41614}
# awe_l7a_tmp_2025361T1637_11879_v01.nc: added points per component: {'MFz_top': 21148, 'MFm_top': 21148}
# awe_l7a_tmp_2025361T1810_11880_v01.nc: added points per component: {'MFz_top': 23612, 'MFm_top': 23612}
# awe_l7a_tmp_2025361T1941_11881_v01.nc: added points per component: {'MFz_top': 15154, 'MFm_top': 15154}
# awe_l7a_tmp_2025361T2115_11882_v01.nc: added points per component: {'MFz_top': 36402, 'MFm_top': 36402}
# awe_l7a_tmp_2025361T2249_11883_v01.nc: added points per component: {'MFz_top': 39516, 'MFm_top': 39516}
# awe_l7a_tmp_2025362T0020_11884_v01.nc: added points per component: {'MFz_top': 49582, 'MFm_top': 49582}
# awe_l7a_tmp_2025362T0155_11885_v01.nc: added points per component: {'MFz_top': 23850, 'MFm_top': 23850}
# awe_l7a_tmp_2025362T0327_11886_v01.nc: added points per component: {'MFz_top': 25970, 'MFm_top': 25970}
# awe_l7a_tmp_2025362T0500_11887_v01.nc: added points per component: {'MFz_top': 9629, 'MFm_top': 9629}
# awe_l7a_tmp_2025362T0633_11888_v01.nc: added points per component: {'MFz_top': 10650, 'MFm_top': 10650}
# awe_l7a_tmp_2025362T0805_11889_v01.nc: added points per component: {'MFz_top': 19868, 'MFm_top': 19868}
# awe_l7a_tmp_2025362T0939_11890_v01.nc: added points per component: {'MFz_top': 31446, 'MFm_top': 31446}
# awe_l7a_tmp_2025362T1112_11891_v01.nc: added points per component: {'MFz_top': 40935, 'MFm_top': 40935}
# awe_l7a_tmp_2025362T1244_11892_v01.nc: added points per component: {'MFz_top': 44903, 'MFm_top': 44903}
# awe_l7a_tmp_2025362T1418_11893_v01.nc: added points per component: {'MFz_top': 10728, 'MFm_top': 10728}
# awe_l7a_tmp_2025362T1551_11894_v01.nc: added points per component: {'MFz_top': 10851, 'MFm_top': 10851}
# awe_l7a_tmp_2025362T1724_11895_v01.nc: added points per component: {'MFz_top': 37712, 'MFm_top': 37712}
# awe_l7a_tmp_2025362T1857_11896_v01.nc: added points per component: {'MFz_top': 5334, 'MFm_top': 5334}
# awe_l7a_tmp_2025362T2029_11897_v01.nc: added points per component: {'MFz_top': 25598, 'MFm_top': 25598}
# awe_l7a_tmp_2025362T2202_11898_v01.nc: added points per component: {'MFz_top': 36385, 'MFm_top': 36385}
# awe_l7a_tmp_2025362T2334_11899_v01.nc: added points per component: {'MFz_top': 15047, 'MFm_top': 15047}
# awe_l7a_tmp_2025363T0107_11900_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025363T0240_11901_v01.nc: added points per component: {'MFz_top': 36320, 'MFm_top': 36320}
# awe_l7a_tmp_2025363T0721_11904_v01.nc: added points per component: {'MFz_top': 35746, 'MFm_top': 35746}
# awe_l7a_tmp_2025363T0854_11905_v01.nc: added points per component: {'MFz_top': 41657, 'MFm_top': 41657}
# awe_l7a_tmp_2025363T1027_11906_v01.nc: added points per component: {'MFz_top': 34372, 'MFm_top': 34372}
# awe_l7a_tmp_2025363T1200_11907_v01.nc: added points per component: {'MFz_top': 20878, 'MFm_top': 20878}
# awe_l7a_tmp_2025363T1333_11908_v01.nc: added points per component: {'MFz_top': 39516, 'MFm_top': 39516}
# awe_l7a_tmp_2025363T1506_11909_v01.nc: added points per component: {'MFz_top': 41657, 'MFm_top': 41657}
# awe_l7a_tmp_2025363T1633_11910_v01.nc: added points per component: {'MFz_top': 42368, 'MFm_top': 42368}
# awe_l7a_tmp_2025363T1806_11911_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025363T1945_11912_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025363T2118_11913_v01.nc: added points per component: {'MFz_top': 38850, 'MFm_top': 38850}
# awe_l7a_tmp_2025364T0033_11915_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025364T0156_11916_v01.nc: added points per component: {'MFz_top': 42736, 'MFm_top': 42736}
# awe_l7a_tmp_2025364T0329_11917_v01.nc: added points per component: {'MFz_top': 21700, 'MFm_top': 21700}
# awe_l7a_tmp_2025364T0503_11918_v01.nc: added points per component: {'MFz_top': 34284, 'MFm_top': 34284}
# awe_l7a_tmp_2025364T0634_11919_v01.nc: added points per component: {'MFz_top': 31258, 'MFm_top': 31258}
# awe_l7a_tmp_2025364T0807_11920_v01.nc: added points per component: {'MFz_top': 26132, 'MFm_top': 26132}
# awe_l7a_tmp_2025364T0940_11921_v01.nc: added points per component: {'MFz_top': 36067, 'MFm_top': 36067}
# awe_l7a_tmp_2025364T1112_11922_v01.nc: added points per component: {'MFz_top': 30663, 'MFm_top': 30663}
# awe_l7a_tmp_2025364T1245_11923_v01.nc: added points per component: {'MFz_top': 34879, 'MFm_top': 34879}
# awe_l7a_tmp_2025364T1419_11924_v01.nc: added points per component: {'MFz_top': 42377, 'MFm_top': 42377}
# awe_l7a_tmp_2025364T1552_11925_v01.nc: added points per component: {'MFz_top': 44771, 'MFm_top': 44771}
# awe_l7a_tmp_2025364T1724_11926_v01.nc: added points per component: {'MFz_top': 25471, 'MFm_top': 25471}
# awe_l7a_tmp_2025364T1858_11927_v01.nc: added points per component: {'MFz_top': 26521, 'MFm_top': 26521}
# awe_l7a_tmp_2025364T2030_11928_v01.nc: added points per component: {'MFz_top': 34965, 'MFm_top': 34965}
# awe_l7a_tmp_2025364T2203_11929_v01.nc: added points per component: {'MFz_top': 45254, 'MFm_top': 45254}
# awe_l7a_tmp_2025364T2337_11930_v01.nc: added points per component: {'MFz_top': 26486, 'MFm_top': 26486}
# awe_l7a_tmp_2025365T0110_11931_v01.nc: added points per component: {'MFz_top': 49016, 'MFm_top': 49016}
# awe_l7a_tmp_2025365T0243_11932_v01.nc: added points per component: {'MFz_top': 41657, 'MFm_top': 41657}
# awe_l7a_tmp_2025365T0415_11933_v01.nc: added points per component: {'MFz_top': 41657, 'MFm_top': 41657}
# awe_l7a_tmp_2025365T0548_11934_v01.nc: added points per component: {'MFz_top': 34626, 'MFm_top': 34626}
# awe_l7a_tmp_2025365T0722_11935_v01.nc: added points per component: {'MFz_top': 32396, 'MFm_top': 32396}
# awe_l7a_tmp_2025365T0855_11936_v01.nc: added points per component: {'MFz_top': 42052, 'MFm_top': 42052}
# awe_l7a_tmp_2025365T1028_11937_v01.nc: added points per component: {'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2025365T1201_11938_v01.nc: added points per component: {'MFz_top': 31258, 'MFm_top': 31258}
# awe_l7a_tmp_2025365T1333_11939_v01.nc: added points per component: {'MFz_top': 36385, 'MFm_top': 36385}
# awe_l7a_tmp_2025365T1640_11941_v01.nc: added points per component: {'MFz_top': 49500, 'MFm_top': 49500}
# awe_l7a_tmp_2025365T1812_11942_v01.nc: added points per component: {'MFz_top': 36686, 'MFm_top': 36686}
# awe_l7a_tmp_2025365T1944_11943_v01.nc: added points per component: {'MFz_top': 46886, 'MFm_top': 46886}
# awe_l7a_tmp_2025365T2119_11944_v01.nc: added points per component: {'MFz_top': 27426, 'MFm_top': 27426}
# awe_l7a_tmp_2025365T2252_11945_v01.nc: added points per component: {'MFz_top': 27426, 'MFm_top': 27426}
# Saved: C:\Users\domin\juwavelet\Momentum Flux\outputs_MF_cartopy\2025\stacked_all_months\2025_12_MFz_MFm_stacked_global_maps.png
#
# Done.
# All monthly stacked figures are in: C:\Users\domin\juwavelet\Momentum Flux\outputs_MF_cartopy\2025\stacked_all_months

# %% [markdown]
# ## DOY vs Lat plots for MF

# %%
# %%
"""
DOY vs latitude plots for MFz_top and MFm_top from L7A outputs
for all days in 2024.

Memory strategy:
1. Find all L7A files in all months of YEAR
2. Group files by DOY
3. Process one DOY at a time
4. For each file, copy it to a temporary local folder before opening
5. For that DOY, accumulate latitude-bin sums/counts
6. Write the DOY result into the final grid
7. Release that day's arrays before moving on
"""

from __future__ import annotations

from pathlib import Path
from collections import defaultdict
import re
import gc
import shutil
import tempfile

import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset


# -------------------------
# User params
# -------------------------
YEAR = 2024
BASE_L7_DIR = Path("/Volumes/aweread/socfiles/public/l7")
FILE_GLOB = "*l7a*.nc"
TIME_INDEX = 0

LAT_NAME = "Lat_top"
COMPONENTS = ("MFz_top", "MFm_top")

DISPLAY_NAMES = {
    "MFz_top": "Zonal Momentum Flux",
    "MFm_top": "Meridional Momentum Flux",
}

OUTDIR = Path(f"outputs_MF_doy_latitude/{YEAR}")
OUTDIR.mkdir(parents=True, exist_ok=True)

# Latitude binning
LAT_MIN = -60.0
LAT_MAX = 60.0
LAT_BIN_DEG = 1.0

# Plot scaling
USE_SYMMETRIC_PERCENTILE = True
PCTL = 99.0   # use symmetric percentile for color limits

# Filename DOY pattern like: awe_l7a_tmp_2024005T0917_00688_v01.nc
DOY_RE = re.compile(rf"{YEAR}(\d{{3}})T\d{{4}}")


# -------------------------
# Helpers
# -------------------------
def extract_doy_from_name(path: Path) -> int | None:
    m = DOY_RE.search(path.name)
    if m is None:
        return None
    return int(m.group(1))


def get_var_2d(nc: Dataset, var_name: str, time_index: int = 0) -> np.ndarray | None:
    if var_name not in nc.variables:
        return None

    var = nc.variables[var_name]

    try:
        var.set_auto_mask(False)
    except Exception:
        pass

    if var.ndim == 3:
        if time_index >= var.shape[0]:
            return None
        arr = np.array(var[time_index, :, :], dtype=np.float64, copy=True)
    elif var.ndim == 2:
        arr = np.array(var[:, :], dtype=np.float64, copy=True)
    else:
        return None

    return arr


def robust_symmetric_limit(arr: np.ndarray, percentile: float = 99.0) -> float:
    good = np.isfinite(arr)
    if not np.any(good):
        return 1.0
    vmax = np.nanpercentile(np.abs(arr[good]), percentile)
    if not np.isfinite(vmax) or vmax == 0:
        vmax = np.nanmax(np.abs(arr[good]))
    if not np.isfinite(vmax) or vmax == 0:
        vmax = 1.0
    return float(vmax)


def copy_to_temp(src_path: Path, temp_dir: Path) -> Path:
    local_path = temp_dir / src_path.name
    shutil.copy2(src_path, local_path)
    return local_path


# -------------------------
# Build file list grouped by DOY
# -------------------------
files_by_doy = defaultdict(list)

for month in range(1, 13):
    month_dir = BASE_L7_DIR / str(YEAR) / f"{month:02d}"
    if not month_dir.exists():
        print(f"Skip missing folder: {month_dir}")
        continue

    for p in sorted(month_dir.glob(FILE_GLOB)):
        doy = extract_doy_from_name(p)
        if doy is None:
            print(f"Could not parse DOY from filename, skip: {p.name}")
            continue
        files_by_doy[doy].append(p)

all_doys = sorted(files_by_doy.keys())

if len(all_doys) == 0:
    raise FileNotFoundError(f"No L7A files found for year {YEAR} in {BASE_L7_DIR}")

print(f"Found {sum(len(v) for v in files_by_doy.values())} files across {len(all_doys)} DOYs")


# -------------------------
# Final grids: DOY x latitude
# -------------------------
lat_edges = np.arange(LAT_MIN, LAT_MAX + LAT_BIN_DEG, LAT_BIN_DEG)
lat_centers = 0.5 * (lat_edges[:-1] + lat_edges[1:])
nlat = len(lat_centers)

# Full year axis
ndoy = 366 if ((YEAR % 4 == 0 and YEAR % 100 != 0) or (YEAR % 400 == 0)) else 365
doy_axis = np.arange(1, ndoy + 1)

final_grids = {
    comp: np.full((ndoy, nlat), np.nan, dtype=np.float32)
    for comp in COMPONENTS
}


# -------------------------
# Process one DOY at a time
# -------------------------
for i_doy, doy in enumerate(all_doys, start=1):
    doy_files = files_by_doy[doy]
    print("\n" + "=" * 80)
    print(f"Processing DOY {doy:03d}  ({i_doy}/{len(all_doys)})  with {len(doy_files)} files")
    print("=" * 80)

    # Per-DOY accumulators
    doy_sum = {comp: np.zeros(nlat, dtype=np.float64) for comp in COMPONENTS}
    doy_cnt = {comp: np.zeros(nlat, dtype=np.int64) for comp in COMPONENTS}

    with tempfile.TemporaryDirectory(prefix=f"l7a_{YEAR}_{doy:03d}_") as tmpdir:
        tmpdir = Path(tmpdir)

        for p in doy_files:
            local_p = None
            lat = None
            arr = None

            try:
                print(f"  Copying {p.name} to temp...")
                local_p = copy_to_temp(p, tmpdir)

                with Dataset(local_p, "r") as nc:
                    try:
                        nc.set_auto_mask(False)
                    except Exception:
                        pass
                    try:
                        nc.set_auto_maskandscale(False)
                    except Exception:
                        pass

                    lat = get_var_2d(nc, LAT_NAME, TIME_INDEX)
                    if lat is None:
                        print(f"  Skip {p.name}: missing or invalid {LAT_NAME}")
                        continue

                    lat_flat = lat.ravel()
                    base = np.isfinite(lat_flat) & (lat_flat >= LAT_MIN) & (lat_flat <= LAT_MAX)

                    if not np.any(base):
                        print(f"  Skip {p.name}: no valid latitude points")
                        continue

                    lat_use = lat_flat[base]
                    lat_idx = np.digitize(lat_use, lat_edges) - 1
                    good_lat = (lat_idx >= 0) & (lat_idx < nlat)

                    if not np.any(good_lat):
                        print(f"  Skip {p.name}: no valid latitude bins")
                        continue

                    lat_idx = lat_idx[good_lat]

                    for comp in COMPONENTS:
                        arr = get_var_2d(nc, comp, TIME_INDEX)
                        if arr is None:
                            print(f"  {p.name}: missing {comp}")
                            continue

                        val = arr.ravel()[base][good_lat]
                        good = np.isfinite(val)

                        if not np.any(good):
                            continue

                        np.add.at(doy_sum[comp], lat_idx[good], val[good])
                        np.add.at(doy_cnt[comp], lat_idx[good], 1)

                print(f"  Finished {p.name}")

            except Exception as e:
                print(f"  Error reading {p.name}: {e}")
                continue

            finally:
                del lat, arr
                gc.collect()

    # Write this DOY into final grid
    doy_row = doy - 1
    for comp in COMPONENTS:
        mask = doy_cnt[comp] > 0
        if np.any(mask):
            final_grids[comp][doy_row, mask] = (doy_sum[comp][mask] / doy_cnt[comp][mask]).astype(np.float32)

    # Release memory for this DOY
    del doy_sum, doy_cnt, doy_files
    gc.collect()


# -------------------------
# Plot helper
# -------------------------
def make_doy_lat_plot(grid: np.ndarray, comp: str, outname: str):
    fig, ax = plt.subplots(figsize=(16, 6))

    if USE_SYMMETRIC_PERCENTILE:
        vmax = robust_symmetric_limit(grid, PCTL)
        vmin = -vmax
    else:
        good = np.isfinite(grid)
        if np.any(good):
            vmin = float(np.nanmin(grid))
            vmax = float(np.nanmax(grid))
            if vmin == vmax:
                vmin, vmax = -1.0, 1.0
        else:
            vmin, vmax = -1.0, 1.0

    # transpose so y = latitude, x = DOY
    im = ax.pcolormesh(
        doy_axis,
        lat_edges,
        grid.T,
        shading="auto",
        cmap="RdBu_r",
        vmin=vmin,
        vmax=vmax,
    )

    ax.set_title(f"{DISPLAY_NAMES.get(comp, comp)} in {YEAR}")
    ax.set_xlabel("Day of Year")
    ax.set_ylabel("Latitude (deg)")
    ax.set_xlim(1, ndoy)
    ax.set_ylim(LAT_MIN, LAT_MAX)

    cbar = fig.colorbar(im, ax=ax, pad=0.02)
    cbar.set_label(r"Momentum Flux (m$^2$ s$^{-2}$)")

    outpath = OUTDIR / outname
    fig.tight_layout()
    fig.savefig(outpath, dpi=200)
    plt.close(fig)

    print(f"Saved: {outpath.resolve()}")


# -------------------------
# Make plots
# -------------------------
make_doy_lat_plot(
    final_grids["MFz_top"],
    "MFz_top",
    f"{YEAR}_MFz_top_DOY_vs_latitude.png",
)

make_doy_lat_plot(
    final_grids["MFm_top"],
    "MFm_top",
    f"{YEAR}_MFm_top_DOY_vs_latitude.png",
)


# -------------------------
# Optional: save arrays too
# -------------------------
np.savez_compressed(
    OUTDIR / f"{YEAR}_MFz_MFm_DOY_latitude_grids.npz",
    doy_axis=doy_axis,
    lat_edges=lat_edges,
    lat_centers=lat_centers,
    MFz_top=final_grids["MFz_top"],
    MFm_top=final_grids["MFm_top"],
)

print("\nDone.")
print(f"Outputs saved in: {OUTDIR.resolve()}")
# Out:
# Found 5187 files across 365 DOYs
#
# ================================================================================
# Processing DOY 001  (1/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024001T0131_00621_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T0131_00621_v01.nc
#   Copying awe_l7a_tmp_2024001T0304_00622_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T0304_00622_v01.nc
#   Copying awe_l7a_tmp_2024001T0437_00623_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T0437_00623_v01.nc
#   Copying awe_l7a_tmp_2024001T0610_00624_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T0610_00624_v01.nc
#   Copying awe_l7a_tmp_2024001T0743_00625_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T0743_00625_v01.nc
#   Copying awe_l7a_tmp_2024001T0916_00626_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T0916_00626_v01.nc
#   Copying awe_l7a_tmp_2024001T1049_00627_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T1049_00627_v01.nc
#   Copying awe_l7a_tmp_2024001T1222_00628_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T1222_00628_v01.nc
#   Copying awe_l7a_tmp_2024001T1355_00629_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T1355_00629_v01.nc
#   Copying awe_l7a_tmp_2024001T1527_00630_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T1527_00630_v01.nc
#   Copying awe_l7a_tmp_2024001T1700_00631_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T1700_00631_v01.nc
#   Copying awe_l7a_tmp_2024001T1833_00632_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T1833_00632_v01.nc
#   Copying awe_l7a_tmp_2024001T2006_00633_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T2006_00633_v01.nc
#   Copying awe_l7a_tmp_2024001T2139_00634_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T2139_00634_v01.nc
#   Copying awe_l7a_tmp_2024001T2312_00635_v01.nc to temp...
#   Finished awe_l7a_tmp_2024001T2312_00635_v01.nc
#
# ================================================================================
# Processing DOY 002  (2/365)  with 16 files
# ================================================================================
#   Copying awe_l7a_tmp_2024002T0045_00636_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T0045_00636_v01.nc
#   Copying awe_l7a_tmp_2024002T0218_00637_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T0218_00637_v01.nc
#   Copying awe_l7a_tmp_2024002T0351_00638_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T0351_00638_v01.nc
#   Copying awe_l7a_tmp_2024002T0524_00639_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T0524_00639_v01.nc
#   Copying awe_l7a_tmp_2024002T0657_00640_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T0657_00640_v01.nc
#   Copying awe_l7a_tmp_2024002T0830_00641_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T0830_00641_v01.nc
#   Copying awe_l7a_tmp_2024002T1003_00642_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T1003_00642_v01.nc
#   Copying awe_l7a_tmp_2024002T1135_00643_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T1135_00643_v01.nc
#   Copying awe_l7a_tmp_2024002T1308_00644_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T1308_00644_v01.nc
#   Copying awe_l7a_tmp_2024002T1441_00645_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T1441_00645_v01.nc
#   Copying awe_l7a_tmp_2024002T1614_00646_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T1614_00646_v01.nc
#   Copying awe_l7a_tmp_2024002T1747_00647_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T1747_00647_v01.nc
#   Copying awe_l7a_tmp_2024002T1920_00648_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T1920_00648_v01.nc
#   Copying awe_l7a_tmp_2024002T2053_00649_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T2053_00649_v01.nc
#   Copying awe_l7a_tmp_2024002T2226_00650_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T2226_00650_v01.nc
#   Copying awe_l7a_tmp_2024002T2359_00651_v01.nc to temp...
#   Finished awe_l7a_tmp_2024002T2359_00651_v01.nc
#
# ================================================================================
# Processing DOY 003  (3/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024003T0132_00652_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T0132_00652_v01.nc
#   Copying awe_l7a_tmp_2024003T0305_00653_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T0305_00653_v01.nc
#   Copying awe_l7a_tmp_2024003T0437_00654_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T0437_00654_v01.nc
#   Copying awe_l7a_tmp_2024003T0611_00655_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T0611_00655_v01.nc
#   Copying awe_l7a_tmp_2024003T0743_00656_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T0743_00656_v01.nc
#   Copying awe_l7a_tmp_2024003T0916_00657_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T0916_00657_v01.nc
#   Copying awe_l7a_tmp_2024003T1222_00659_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T1222_00659_v01.nc
#   Copying awe_l7a_tmp_2024003T1355_00660_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T1355_00660_v01.nc
#   Copying awe_l7a_tmp_2024003T1528_00661_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T1528_00661_v01.nc
#   Copying awe_l7a_tmp_2024003T1701_00662_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T1701_00662_v01.nc
#   Copying awe_l7a_tmp_2024003T1834_00663_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T1834_00663_v01.nc
#   Copying awe_l7a_tmp_2024003T2007_00664_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T2007_00664_v01.nc
#   Copying awe_l7a_tmp_2024003T2140_00665_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T2140_00665_v01.nc
#   Copying awe_l7a_tmp_2024003T2313_00666_v01.nc to temp...
#   Finished awe_l7a_tmp_2024003T2313_00666_v01.nc
#
# ================================================================================
# Processing DOY 004  (4/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024004T0045_00667_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T0045_00667_v01.nc
#   Copying awe_l7a_tmp_2024004T0218_00668_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T0218_00668_v01.nc
#   Copying awe_l7a_tmp_2024004T0351_00669_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T0351_00669_v01.nc
#   Copying awe_l7a_tmp_2024004T0524_00670_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T0524_00670_v01.nc
#   Copying awe_l7a_tmp_2024004T0657_00671_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T0657_00671_v01.nc
#   Copying awe_l7a_tmp_2024004T0830_00672_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T0830_00672_v01.nc
#   Copying awe_l7a_tmp_2024004T1003_00673_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T1003_00673_v01.nc
#   Copying awe_l7a_tmp_2024004T1309_00675_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T1309_00675_v01.nc
#   Copying awe_l7a_tmp_2024004T1442_00676_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T1442_00676_v01.nc
#   Copying awe_l7a_tmp_2024004T1615_00677_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T1615_00677_v01.nc
#   Copying awe_l7a_tmp_2024004T1748_00678_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T1748_00678_v01.nc
#   Copying awe_l7a_tmp_2024004T1921_00679_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T1921_00679_v01.nc
#   Copying awe_l7a_tmp_2024004T2053_00680_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T2053_00680_v01.nc
#   Copying awe_l7a_tmp_2024004T2226_00681_v01.nc to temp...
#   Finished awe_l7a_tmp_2024004T2226_00681_v01.nc
#
# ================================================================================
# Processing DOY 005  (5/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024005T0132_00683_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T0132_00683_v01.nc
#   Copying awe_l7a_tmp_2024005T0305_00684_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T0305_00684_v01.nc
#   Copying awe_l7a_tmp_2024005T0438_00685_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T0438_00685_v01.nc
#   Copying awe_l7a_tmp_2024005T0611_00686_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T0611_00686_v01.nc
#   Copying awe_l7a_tmp_2024005T0744_00687_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T0744_00687_v01.nc
#   Copying awe_l7a_tmp_2024005T0917_00688_v01.nc to temp...
#   Error reading awe_l7a_tmp_2024005T0917_00688_v01.nc: [Errno 9] Bad file descriptor
#   Copying awe_l7a_tmp_2024005T1050_00689_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T1050_00689_v01.nc
#   Copying awe_l7a_tmp_2024005T1223_00690_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T1223_00690_v01.nc
#   Copying awe_l7a_tmp_2024005T1356_00691_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T1356_00691_v01.nc
#   Copying awe_l7a_tmp_2024005T1529_00692_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T1529_00692_v01.nc
#   Copying awe_l7a_tmp_2024005T1702_00693_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T1702_00693_v01.nc
#   Copying awe_l7a_tmp_2024005T1834_00694_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T1834_00694_v01.nc
#   Copying awe_l7a_tmp_2024005T2007_00695_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T2007_00695_v01.nc
#   Copying awe_l7a_tmp_2024005T2140_00696_v01.nc to temp...
#   Finished awe_l7a_tmp_2024005T2140_00696_v01.nc
#
# ================================================================================
# Processing DOY 006  (6/365)  with 13 files
# ================================================================================
#   Copying awe_l7a_tmp_2024006T0046_00698_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T0046_00698_v01.nc
#   Copying awe_l7a_tmp_2024006T0352_00700_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T0352_00700_v01.nc
#   Copying awe_l7a_tmp_2024006T0658_00702_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T0658_00702_v01.nc
#   Copying awe_l7a_tmp_2024006T0831_00703_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T0831_00703_v01.nc
#   Copying awe_l7a_tmp_2024006T1004_00704_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T1004_00704_v01.nc
#   Copying awe_l7a_tmp_2024006T1137_00705_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T1137_00705_v01.nc
#   Copying awe_l7a_tmp_2024006T1310_00706_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T1310_00706_v01.nc
#   Copying awe_l7a_tmp_2024006T1442_00707_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T1442_00707_v01.nc
#   Copying awe_l7a_tmp_2024006T1615_00708_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T1615_00708_v01.nc
#   Copying awe_l7a_tmp_2024006T1748_00709_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T1748_00709_v01.nc
#   Copying awe_l7a_tmp_2024006T1921_00710_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T1921_00710_v01.nc
#   Copying awe_l7a_tmp_2024006T2054_00711_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T2054_00711_v01.nc
#   Copying awe_l7a_tmp_2024006T2227_00712_v01.nc to temp...
#   Finished awe_l7a_tmp_2024006T2227_00712_v01.nc
#
# ================================================================================
# Processing DOY 007  (7/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024007T0000_00713_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T0000_00713_v01.nc
#   Copying awe_l7a_tmp_2024007T0133_00714_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T0133_00714_v01.nc
#   Copying awe_l7a_tmp_2024007T0306_00715_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T0306_00715_v01.nc
#   Copying awe_l7a_tmp_2024007T0439_00716_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T0439_00716_v01.nc
#   Copying awe_l7a_tmp_2024007T0612_00717_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T0612_00717_v01.nc
#   Copying awe_l7a_tmp_2024007T0745_00718_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T0745_00718_v01.nc
#   Copying awe_l7a_tmp_2024007T0918_00719_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T0918_00719_v01.nc
#   Copying awe_l7a_tmp_2024007T1051_00720_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T1051_00720_v01.nc
#   Copying awe_l7a_tmp_2024007T1223_00721_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T1223_00721_v01.nc
#   Copying awe_l7a_tmp_2024007T1356_00722_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T1356_00722_v01.nc
#   Copying awe_l7a_tmp_2024007T1529_00723_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T1529_00723_v01.nc
#   Copying awe_l7a_tmp_2024007T1702_00724_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T1702_00724_v01.nc
#   Copying awe_l7a_tmp_2024007T1835_00725_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T1835_00725_v01.nc
#   Copying awe_l7a_tmp_2024007T2141_00727_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T2141_00727_v01.nc
#   Copying awe_l7a_tmp_2024007T2314_00728_v01.nc to temp...
#   Finished awe_l7a_tmp_2024007T2314_00728_v01.nc
#
# ================================================================================
# Processing DOY 008  (8/365)  with 16 files
# ================================================================================
#   Copying awe_l7a_tmp_2024008T0001_00744_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T0001_00744_v01.nc
#   Copying awe_l7a_tmp_2024008T0047_00729_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T0047_00729_v01.nc
#   Copying awe_l7a_tmp_2024008T0220_00730_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T0220_00730_v01.nc
#   Copying awe_l7a_tmp_2024008T0353_00731_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T0353_00731_v01.nc
#   Copying awe_l7a_tmp_2024008T0526_00732_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T0526_00732_v01.nc
#   Copying awe_l7a_tmp_2024008T0659_00733_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T0659_00733_v01.nc
#   Copying awe_l7a_tmp_2024008T0832_00734_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T0832_00734_v01.nc
#   Copying awe_l7a_tmp_2024008T1004_00735_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T1004_00735_v01.nc
#   Copying awe_l7a_tmp_2024008T1137_00736_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T1137_00736_v01.nc
#   Copying awe_l7a_tmp_2024008T1310_00737_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T1310_00737_v01.nc
#   Copying awe_l7a_tmp_2024008T1443_00738_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T1443_00738_v01.nc
#   Copying awe_l7a_tmp_2024008T1616_00739_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T1616_00739_v01.nc
#   Copying awe_l7a_tmp_2024008T1749_00740_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T1749_00740_v01.nc
#   Copying awe_l7a_tmp_2024008T1922_00741_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T1922_00741_v01.nc
#   Copying awe_l7a_tmp_2024008T2055_00742_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T2055_00742_v01.nc
#   Copying awe_l7a_tmp_2024008T2228_00743_v01.nc to temp...
#   Finished awe_l7a_tmp_2024008T2228_00743_v01.nc
#
# ================================================================================
# Processing DOY 009  (9/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024009T0134_00745_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T0134_00745_v01.nc
#   Copying awe_l7a_tmp_2024009T0307_00746_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T0307_00746_v01.nc
#   Copying awe_l7a_tmp_2024009T0440_00747_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T0440_00747_v01.nc
#   Copying awe_l7a_tmp_2024009T0613_00748_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T0613_00748_v01.nc
#   Copying awe_l7a_tmp_2024009T0746_00749_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T0746_00749_v01.nc
#   Copying awe_l7a_tmp_2024009T0918_00750_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T0918_00750_v01.nc
#   Copying awe_l7a_tmp_2024009T1052_00751_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T1052_00751_v01.nc
#   Copying awe_l7a_tmp_2024009T1224_00752_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T1224_00752_v01.nc
#   Copying awe_l7a_tmp_2024009T1357_00753_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T1357_00753_v01.nc
#   Copying awe_l7a_tmp_2024009T1530_00754_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T1530_00754_v01.nc
#   Copying awe_l7a_tmp_2024009T1703_00755_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T1703_00755_v01.nc
#   Copying awe_l7a_tmp_2024009T1836_00756_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T1836_00756_v01.nc
#   Copying awe_l7a_tmp_2024009T2009_00757_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T2009_00757_v01.nc
#   Copying awe_l7a_tmp_2024009T2142_00758_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T2142_00758_v01.nc
#   Copying awe_l7a_tmp_2024009T2315_00759_v01.nc to temp...
#   Finished awe_l7a_tmp_2024009T2315_00759_v01.nc
#
# ================================================================================
# Processing DOY 010  (10/365)  with 16 files
# ================================================================================
#   Copying awe_l7a_tmp_2024010T0002_00775_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T0002_00775_v01.nc
#   Copying awe_l7a_tmp_2024010T0048_00760_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T0048_00760_v01.nc
#   Copying awe_l7a_tmp_2024010T0221_00761_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T0221_00761_v01.nc
#   Copying awe_l7a_tmp_2024010T0354_00762_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T0354_00762_v01.nc
#   Copying awe_l7a_tmp_2024010T0526_00763_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T0526_00763_v01.nc
#   Copying awe_l7a_tmp_2024010T0700_00764_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T0700_00764_v01.nc
#   Copying awe_l7a_tmp_2024010T0833_00765_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T0833_00765_v01.nc
#   Copying awe_l7a_tmp_2024010T1006_00766_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T1006_00766_v01.nc
#   Copying awe_l7a_tmp_2024010T1139_00767_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T1139_00767_v01.nc
#   Copying awe_l7a_tmp_2024010T1311_00768_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T1311_00768_v01.nc
#   Copying awe_l7a_tmp_2024010T1444_00769_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T1444_00769_v01.nc
#   Copying awe_l7a_tmp_2024010T1617_00770_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T1617_00770_v01.nc
#   Copying awe_l7a_tmp_2024010T1750_00771_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T1750_00771_v01.nc
#   Copying awe_l7a_tmp_2024010T1923_00772_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T1923_00772_v01.nc
#   Copying awe_l7a_tmp_2024010T2056_00773_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T2056_00773_v01.nc
#   Copying awe_l7a_tmp_2024010T2229_00774_v01.nc to temp...
#   Finished awe_l7a_tmp_2024010T2229_00774_v01.nc
#
# ================================================================================
# Processing DOY 011  (11/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024011T0135_00776_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T0135_00776_v01.nc
#   Copying awe_l7a_tmp_2024011T0308_00777_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T0308_00777_v01.nc
#   Copying awe_l7a_tmp_2024011T0441_00778_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T0441_00778_v01.nc
#   Copying awe_l7a_tmp_2024011T0614_00779_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T0614_00779_v01.nc
#   Copying awe_l7a_tmp_2024011T0746_00780_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T0746_00780_v01.nc
#   Copying awe_l7a_tmp_2024011T0920_00781_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T0920_00781_v01.nc
#   Copying awe_l7a_tmp_2024011T1052_00782_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T1052_00782_v01.nc
#   Copying awe_l7a_tmp_2024011T1225_00783_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T1225_00783_v01.nc
#   Copying awe_l7a_tmp_2024011T1358_00784_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T1358_00784_v01.nc
#   Copying awe_l7a_tmp_2024011T1531_00785_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T1531_00785_v01.nc
#   Copying awe_l7a_tmp_2024011T1704_00786_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T1704_00786_v01.nc
#   Copying awe_l7a_tmp_2024011T1837_00787_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T1837_00787_v01.nc
#   Copying awe_l7a_tmp_2024011T2010_00788_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T2010_00788_v01.nc
#   Copying awe_l7a_tmp_2024011T2143_00789_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T2143_00789_v01.nc
#   Copying awe_l7a_tmp_2024011T2316_00790_v01.nc to temp...
#   Finished awe_l7a_tmp_2024011T2316_00790_v01.nc
#
# ================================================================================
# Processing DOY 012  (12/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024012T0049_00791_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T0049_00791_v01.nc
#   Copying awe_l7a_tmp_2024012T0222_00792_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T0222_00792_v01.nc
#   Copying awe_l7a_tmp_2024012T0355_00793_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T0355_00793_v01.nc
#   Copying awe_l7a_tmp_2024012T0528_00794_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T0528_00794_v01.nc
#   Copying awe_l7a_tmp_2024012T0701_00795_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T0701_00795_v01.nc
#   Copying awe_l7a_tmp_2024012T0834_00796_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T0834_00796_v01.nc
#   Copying awe_l7a_tmp_2024012T1007_00797_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T1007_00797_v01.nc
#   Copying awe_l7a_tmp_2024012T1139_00798_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T1139_00798_v01.nc
#   Copying awe_l7a_tmp_2024012T1312_00799_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T1312_00799_v01.nc
#   Copying awe_l7a_tmp_2024012T1446_00800_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T1446_00800_v01.nc
#   Copying awe_l7a_tmp_2024012T1615_00801_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T1615_00801_v01.nc
#   Copying awe_l7a_tmp_2024012T1802_00802_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T1802_00802_v01.nc
#   Copying awe_l7a_tmp_2024012T1924_00803_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T1924_00803_v01.nc
#   Copying awe_l7a_tmp_2024012T2058_00804_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T2058_00804_v01.nc
#   Copying awe_l7a_tmp_2024012T2231_00805_v01.nc to temp...
#   Finished awe_l7a_tmp_2024012T2231_00805_v01.nc
#
# ================================================================================
# Processing DOY 013  (13/365)  with 16 files
# ================================================================================
#   Copying awe_l7a_tmp_2024013T0003_00806_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T0003_00806_v01.nc
#   Copying awe_l7a_tmp_2024013T0136_00807_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T0136_00807_v01.nc
#   Copying awe_l7a_tmp_2024013T0309_00808_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T0309_00808_v01.nc
#   Copying awe_l7a_tmp_2024013T0443_00809_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T0443_00809_v01.nc
#   Copying awe_l7a_tmp_2024013T0615_00810_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T0615_00810_v01.nc
#   Copying awe_l7a_tmp_2024013T0748_00811_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T0748_00811_v01.nc
#   Copying awe_l7a_tmp_2024013T0922_00812_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T0922_00812_v01.nc
#   Copying awe_l7a_tmp_2024013T1054_00813_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T1054_00813_v01.nc
#   Copying awe_l7a_tmp_2024013T1227_00814_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T1227_00814_v01.nc
#   Copying awe_l7a_tmp_2024013T1400_00815_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T1400_00815_v01.nc
#   Copying awe_l7a_tmp_2024013T1533_00816_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T1533_00816_v01.nc
#   Copying awe_l7a_tmp_2024013T1706_00817_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T1706_00817_v01.nc
#   Copying awe_l7a_tmp_2024013T1839_00818_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T1839_00818_v01.nc
#   Copying awe_l7a_tmp_2024013T2012_00819_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T2012_00819_v01.nc
#   Copying awe_l7a_tmp_2024013T2145_00820_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T2145_00820_v01.nc
#   Copying awe_l7a_tmp_2024013T2318_00821_v01.nc to temp...
#   Finished awe_l7a_tmp_2024013T2318_00821_v01.nc
#
# ================================================================================
# Processing DOY 014  (14/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024014T0051_00822_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T0051_00822_v01.nc
#   Copying awe_l7a_tmp_2024014T0224_00823_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T0224_00823_v01.nc
#   Copying awe_l7a_tmp_2024014T0357_00824_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T0357_00824_v01.nc
#   Copying awe_l7a_tmp_2024014T0530_00825_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T0530_00825_v01.nc
#   Copying awe_l7a_tmp_2024014T0703_00826_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T0703_00826_v01.nc
#   Copying awe_l7a_tmp_2024014T0836_00827_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T0836_00827_v01.nc
#   Copying awe_l7a_tmp_2024014T1009_00828_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T1009_00828_v01.nc
#   Copying awe_l7a_tmp_2024014T1142_00829_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T1142_00829_v01.nc
#   Copying awe_l7a_tmp_2024014T1315_00830_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T1315_00830_v01.nc
#   Copying awe_l7a_tmp_2024014T1448_00831_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T1448_00831_v01.nc
#   Copying awe_l7a_tmp_2024014T1621_00832_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T1621_00832_v01.nc
#   Copying awe_l7a_tmp_2024014T1754_00833_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T1754_00833_v01.nc
#   Copying awe_l7a_tmp_2024014T1927_00834_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T1927_00834_v01.nc
#   Copying awe_l7a_tmp_2024014T2100_00835_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T2100_00835_v01.nc
#   Copying awe_l7a_tmp_2024014T2233_00836_v01.nc to temp...
#   Finished awe_l7a_tmp_2024014T2233_00836_v01.nc
#
# ================================================================================
# Processing DOY 015  (15/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024015T0006_00837_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T0006_00837_v01.nc
#   Copying awe_l7a_tmp_2024015T0139_00838_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T0139_00838_v01.nc
#   Copying awe_l7a_tmp_2024015T0312_00839_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T0312_00839_v01.nc
#   Copying awe_l7a_tmp_2024015T0445_00840_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T0445_00840_v01.nc
#   Copying awe_l7a_tmp_2024015T0618_00841_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T0618_00841_v01.nc
#   Copying awe_l7a_tmp_2024015T0751_00842_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T0751_00842_v01.nc
#   Copying awe_l7a_tmp_2024015T0924_00843_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T0924_00843_v01.nc
#   Copying awe_l7a_tmp_2024015T1057_00844_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T1057_00844_v01.nc
#   Copying awe_l7a_tmp_2024015T1229_00845_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T1229_00845_v01.nc
#   Copying awe_l7a_tmp_2024015T1542_00847_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T1542_00847_v01.nc
#   Copying awe_l7a_tmp_2024015T1708_00848_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T1708_00848_v01.nc
#   Copying awe_l7a_tmp_2024015T1841_00849_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T1841_00849_v01.nc
#   Copying awe_l7a_tmp_2024015T2147_00851_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T2147_00851_v01.nc
#   Copying awe_l7a_tmp_2024015T2321_00852_v01.nc to temp...
#   Finished awe_l7a_tmp_2024015T2321_00852_v01.nc
#
# ================================================================================
# Processing DOY 016  (16/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024016T0054_00853_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T0054_00853_v01.nc
#   Copying awe_l7a_tmp_2024016T0226_00854_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T0226_00854_v01.nc
#   Copying awe_l7a_tmp_2024016T0359_00855_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T0359_00855_v01.nc
#   Copying awe_l7a_tmp_2024016T0532_00856_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T0532_00856_v01.nc
#   Copying awe_l7a_tmp_2024016T0705_00857_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T0705_00857_v01.nc
#   Copying awe_l7a_tmp_2024016T0838_00858_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T0838_00858_v01.nc
#   Copying awe_l7a_tmp_2024016T1011_00859_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T1011_00859_v01.nc
#   Copying awe_l7a_tmp_2024016T1144_00860_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T1144_00860_v01.nc
#   Copying awe_l7a_tmp_2024016T1317_00861_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T1317_00861_v01.nc
#   Copying awe_l7a_tmp_2024016T1623_00863_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T1623_00863_v01.nc
#   Copying awe_l7a_tmp_2024016T1756_00864_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T1756_00864_v01.nc
#   Copying awe_l7a_tmp_2024016T1929_00865_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T1929_00865_v01.nc
#   Copying awe_l7a_tmp_2024016T2102_00866_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T2102_00866_v01.nc
#   Copying awe_l7a_tmp_2024016T2235_00867_v01.nc to temp...
#   Finished awe_l7a_tmp_2024016T2235_00867_v01.nc
#
# ================================================================================
# Processing DOY 017  (17/365)  with 16 files
# ================================================================================
#   Copying awe_l7a_tmp_2024017T0008_00868_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T0008_00868_v01.nc
#   Copying awe_l7a_tmp_2024017T0141_00869_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T0141_00869_v01.nc
#   Copying awe_l7a_tmp_2024017T0314_00870_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T0314_00870_v01.nc
#   Copying awe_l7a_tmp_2024017T0447_00871_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T0447_00871_v01.nc
#   Copying awe_l7a_tmp_2024017T0620_00872_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T0620_00872_v01.nc
#   Copying awe_l7a_tmp_2024017T0753_00873_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T0753_00873_v01.nc
#   Copying awe_l7a_tmp_2024017T0926_00874_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T0926_00874_v01.nc
#   Copying awe_l7a_tmp_2024017T1059_00875_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T1059_00875_v01.nc
#   Copying awe_l7a_tmp_2024017T1232_00876_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T1232_00876_v01.nc
#   Copying awe_l7a_tmp_2024017T1404_00877_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T1404_00877_v01.nc
#   Copying awe_l7a_tmp_2024017T1538_00878_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T1538_00878_v01.nc
#   Copying awe_l7a_tmp_2024017T1710_00879_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T1710_00879_v01.nc
#   Copying awe_l7a_tmp_2024017T1843_00880_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T1843_00880_v01.nc
#   Copying awe_l7a_tmp_2024017T2016_00881_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T2016_00881_v01.nc
#   Copying awe_l7a_tmp_2024017T2149_00882_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T2149_00882_v01.nc
#   Copying awe_l7a_tmp_2024017T2322_00883_v01.nc to temp...
#   Finished awe_l7a_tmp_2024017T2322_00883_v01.nc
#
# ================================================================================
# Processing DOY 018  (18/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024018T0055_00884_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T0055_00884_v01.nc
#   Copying awe_l7a_tmp_2024018T0228_00885_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T0228_00885_v01.nc
#   Copying awe_l7a_tmp_2024018T0401_00886_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T0401_00886_v01.nc
#   Copying awe_l7a_tmp_2024018T0534_00887_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T0534_00887_v01.nc
#   Copying awe_l7a_tmp_2024018T0707_00888_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T0707_00888_v01.nc
#   Copying awe_l7a_tmp_2024018T0840_00889_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T0840_00889_v01.nc
#   Copying awe_l7a_tmp_2024018T1013_00890_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T1013_00890_v01.nc
#   Copying awe_l7a_tmp_2024018T1146_00891_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T1146_00891_v01.nc
#   Copying awe_l7a_tmp_2024018T1319_00892_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T1319_00892_v01.nc
#   Copying awe_l7a_tmp_2024018T1452_00893_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T1452_00893_v01.nc
#   Copying awe_l7a_tmp_2024018T1625_00894_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T1625_00894_v01.nc
#   Copying awe_l7a_tmp_2024018T1758_00895_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T1758_00895_v01.nc
#   Copying awe_l7a_tmp_2024018T1931_00896_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T1931_00896_v01.nc
#   Copying awe_l7a_tmp_2024018T2103_00897_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T2103_00897_v01.nc
#   Copying awe_l7a_tmp_2024018T2236_00898_v01.nc to temp...
#   Finished awe_l7a_tmp_2024018T2236_00898_v01.nc
#
# ================================================================================
# Processing DOY 019  (19/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024019T0009_00899_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T0009_00899_v01.nc
#   Copying awe_l7a_tmp_2024019T0142_00900_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T0142_00900_v01.nc
#   Copying awe_l7a_tmp_2024019T0315_00901_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T0315_00901_v01.nc
#   Copying awe_l7a_tmp_2024019T0448_00902_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T0448_00902_v01.nc
#   Copying awe_l7a_tmp_2024019T0621_00903_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T0621_00903_v01.nc
#   Copying awe_l7a_tmp_2024019T0754_00904_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T0754_00904_v01.nc
#   Copying awe_l7a_tmp_2024019T0927_00905_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T0927_00905_v01.nc
#   Copying awe_l7a_tmp_2024019T1100_00906_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T1100_00906_v01.nc
#   Copying awe_l7a_tmp_2024019T1233_00907_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T1233_00907_v01.nc
#   Copying awe_l7a_tmp_2024019T1539_00909_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T1539_00909_v01.nc
#   Copying awe_l7a_tmp_2024019T1711_00910_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T1711_00910_v01.nc
#   Copying awe_l7a_tmp_2024019T1844_00911_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T1844_00911_v01.nc
#   Copying awe_l7a_tmp_2024019T2017_00912_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T2017_00912_v01.nc
#   Copying awe_l7a_tmp_2024019T2150_00913_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T2150_00913_v01.nc
#   Copying awe_l7a_tmp_2024019T2323_00914_v01.nc to temp...
#   Finished awe_l7a_tmp_2024019T2323_00914_v01.nc
#
# ================================================================================
# Processing DOY 020  (20/365)  with 12 files
# ================================================================================
#   Copying awe_l7a_tmp_2024020T0056_00915_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T0056_00915_v01.nc
#   Copying awe_l7a_tmp_2024020T0402_00917_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T0402_00917_v01.nc
#   Copying awe_l7a_tmp_2024020T0535_00918_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T0535_00918_v01.nc
#   Copying awe_l7a_tmp_2024020T1010_00921_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T1010_00921_v01.nc
#   Copying awe_l7a_tmp_2024020T1142_00922_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T1142_00922_v01.nc
#   Copying awe_l7a_tmp_2024020T1320_00923_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T1320_00923_v01.nc
#   Copying awe_l7a_tmp_2024020T1453_00924_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T1453_00924_v01.nc
#   Copying awe_l7a_tmp_2024020T1626_00925_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T1626_00925_v01.nc
#   Copying awe_l7a_tmp_2024020T1759_00926_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T1759_00926_v01.nc
#   Copying awe_l7a_tmp_2024020T1932_00927_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T1932_00927_v01.nc
#   Copying awe_l7a_tmp_2024020T2105_00928_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T2105_00928_v01.nc
#   Copying awe_l7a_tmp_2024020T2238_00929_v01.nc to temp...
#   Finished awe_l7a_tmp_2024020T2238_00929_v01.nc
#
# ================================================================================
# Processing DOY 021  (21/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024021T0011_00930_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T0011_00930_v01.nc
#   Copying awe_l7a_tmp_2024021T0144_00931_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T0144_00931_v01.nc
#   Copying awe_l7a_tmp_2024021T0316_00932_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T0316_00932_v01.nc
#   Copying awe_l7a_tmp_2024021T0449_00933_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T0449_00933_v01.nc
#   Copying awe_l7a_tmp_2024021T0755_00935_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T0755_00935_v01.nc
#   Copying awe_l7a_tmp_2024021T1101_00937_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T1101_00937_v01.nc
#   Copying awe_l7a_tmp_2024021T1234_00938_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T1234_00938_v01.nc
#   Copying awe_l7a_tmp_2024021T1407_00939_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T1407_00939_v01.nc
#   Copying awe_l7a_tmp_2024021T1540_00940_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T1540_00940_v01.nc
#   Copying awe_l7a_tmp_2024021T1713_00941_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T1713_00941_v01.nc
#   Copying awe_l7a_tmp_2024021T1845_00942_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T1845_00942_v01.nc
#   Copying awe_l7a_tmp_2024021T2018_00943_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T2018_00943_v01.nc
#   Copying awe_l7a_tmp_2024021T2151_00944_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T2151_00944_v01.nc
#   Copying awe_l7a_tmp_2024021T2324_00945_v01.nc to temp...
#   Finished awe_l7a_tmp_2024021T2324_00945_v01.nc
#
# ================================================================================
# Processing DOY 022  (22/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024022T0057_00946_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T0057_00946_v01.nc
#   Copying awe_l7a_tmp_2024022T0230_00947_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T0230_00947_v01.nc
#   Copying awe_l7a_tmp_2024022T0403_00948_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T0403_00948_v01.nc
#   Copying awe_l7a_tmp_2024022T0536_00949_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T0536_00949_v01.nc
#   Copying awe_l7a_tmp_2024022T0709_00950_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T0709_00950_v01.nc
#   Copying awe_l7a_tmp_2024022T0842_00951_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T0842_00951_v01.nc
#   Copying awe_l7a_tmp_2024022T1015_00952_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T1015_00952_v01.nc
#   Copying awe_l7a_tmp_2024022T1148_00953_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T1148_00953_v01.nc
#   Copying awe_l7a_tmp_2024022T1320_00954_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T1320_00954_v01.nc
#   Copying awe_l7a_tmp_2024022T1453_00955_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T1453_00955_v01.nc
#   Copying awe_l7a_tmp_2024022T1626_00956_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T1626_00956_v01.nc
#   Copying awe_l7a_tmp_2024022T1759_00957_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T1759_00957_v01.nc
#   Copying awe_l7a_tmp_2024022T1932_00958_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T1932_00958_v01.nc
#   Copying awe_l7a_tmp_2024022T2105_00959_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T2105_00959_v01.nc
#   Copying awe_l7a_tmp_2024022T2238_00960_v01.nc to temp...
#   Finished awe_l7a_tmp_2024022T2238_00960_v01.nc
#
# ================================================================================
# Processing DOY 023  (23/365)  with 13 files
# ================================================================================
#   Copying awe_l7a_tmp_2024023T0010_00961_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T0010_00961_v01.nc
#   Copying awe_l7a_tmp_2024023T0316_00963_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T0316_00963_v01.nc
#   Copying awe_l7a_tmp_2024023T0449_00964_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T0449_00964_v01.nc
#   Copying awe_l7a_tmp_2024023T0622_00965_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T0622_00965_v01.nc
#   Copying awe_l7a_tmp_2024023T0755_00966_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T0755_00966_v01.nc
#   Copying awe_l7a_tmp_2024023T1101_00968_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T1101_00968_v01.nc
#   Copying awe_l7a_tmp_2024023T1233_00969_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T1233_00969_v01.nc
#   Copying awe_l7a_tmp_2024023T1406_00970_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T1406_00970_v01.nc
#   Copying awe_l7a_tmp_2024023T1539_00971_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T1539_00971_v01.nc
#   Copying awe_l7a_tmp_2024023T1712_00972_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T1712_00972_v01.nc
#   Copying awe_l7a_tmp_2024023T1845_00973_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T1845_00973_v01.nc
#   Copying awe_l7a_tmp_2024023T2151_00975_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T2151_00975_v01.nc
#   Copying awe_l7a_tmp_2024023T2323_00976_v01.nc to temp...
#   Finished awe_l7a_tmp_2024023T2323_00976_v01.nc
#
# ================================================================================
# Processing DOY 024  (24/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024024T0056_00977_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T0056_00977_v01.nc
#   Copying awe_l7a_tmp_2024024T0229_00978_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T0229_00978_v01.nc
#   Copying awe_l7a_tmp_2024024T0402_00979_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T0402_00979_v01.nc
#   Copying awe_l7a_tmp_2024024T0535_00980_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T0535_00980_v01.nc
#   Copying awe_l7a_tmp_2024024T0708_00981_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T0708_00981_v01.nc
#   Copying awe_l7a_tmp_2024024T0841_00982_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T0841_00982_v01.nc
#   Copying awe_l7a_tmp_2024024T1014_00983_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T1014_00983_v01.nc
#   Copying awe_l7a_tmp_2024024T1147_00984_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T1147_00984_v01.nc
#   Copying awe_l7a_tmp_2024024T1320_00985_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T1320_00985_v01.nc
#   Copying awe_l7a_tmp_2024024T1453_00986_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T1453_00986_v01.nc
#   Copying awe_l7a_tmp_2024024T1626_00987_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T1626_00987_v01.nc
#   Copying awe_l7a_tmp_2024024T1759_00988_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T1759_00988_v01.nc
#   Copying awe_l7a_tmp_2024024T1932_00989_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T1932_00989_v01.nc
#   Copying awe_l7a_tmp_2024024T2105_00990_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T2105_00990_v01.nc
#   Copying awe_l7a_tmp_2024024T2238_00991_v01.nc to temp...
#   Finished awe_l7a_tmp_2024024T2238_00991_v01.nc
#
# ================================================================================
# Processing DOY 025  (25/365)  with 16 files
# ================================================================================
#   Copying awe_l7a_tmp_2024025T0011_00992_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T0011_00992_v01.nc
#   Copying awe_l7a_tmp_2024025T0144_00993_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T0144_00993_v01.nc
#   Copying awe_l7a_tmp_2024025T0317_00994_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T0317_00994_v01.nc
#   Copying awe_l7a_tmp_2024025T0450_00995_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T0450_00995_v01.nc
#   Copying awe_l7a_tmp_2024025T0623_00996_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T0623_00996_v01.nc
#   Copying awe_l7a_tmp_2024025T0756_00997_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T0756_00997_v01.nc
#   Copying awe_l7a_tmp_2024025T0929_00998_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T0929_00998_v01.nc
#   Copying awe_l7a_tmp_2024025T1102_00999_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T1102_00999_v01.nc
#   Copying awe_l7a_tmp_2024025T1235_01000_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T1235_01000_v01.nc
#   Copying awe_l7a_tmp_2024025T1407_01001_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T1407_01001_v01.nc
#   Copying awe_l7a_tmp_2024025T1540_01002_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T1540_01002_v01.nc
#   Copying awe_l7a_tmp_2024025T1713_01003_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T1713_01003_v01.nc
#   Copying awe_l7a_tmp_2024025T1846_01004_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T1846_01004_v01.nc
#   Copying awe_l7a_tmp_2024025T2019_01005_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T2019_01005_v01.nc
#   Copying awe_l7a_tmp_2024025T2152_01006_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T2152_01006_v01.nc
#   Copying awe_l7a_tmp_2024025T2325_01007_v01.nc to temp...
#   Finished awe_l7a_tmp_2024025T2325_01007_v01.nc
#
# ================================================================================
# Processing DOY 026  (26/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024026T0058_01008_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T0058_01008_v01.nc
#   Copying awe_l7a_tmp_2024026T0231_01009_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T0231_01009_v01.nc
#   Copying awe_l7a_tmp_2024026T0404_01010_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T0404_01010_v01.nc
#   Copying awe_l7a_tmp_2024026T0709_01012_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T0709_01012_v01.nc
#   Copying awe_l7a_tmp_2024026T0842_01013_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T0842_01013_v01.nc
#   Copying awe_l7a_tmp_2024026T1015_01014_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T1015_01014_v01.nc
#   Copying awe_l7a_tmp_2024026T1148_01015_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T1148_01015_v01.nc
#   Copying awe_l7a_tmp_2024026T1321_01016_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T1321_01016_v01.nc
#   Copying awe_l7a_tmp_2024026T1454_01017_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T1454_01017_v01.nc
#   Copying awe_l7a_tmp_2024026T1627_01018_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T1627_01018_v01.nc
#   Copying awe_l7a_tmp_2024026T1800_01019_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T1800_01019_v01.nc
#   Copying awe_l7a_tmp_2024026T1933_01020_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T1933_01020_v01.nc
#   Copying awe_l7a_tmp_2024026T2106_01021_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T2106_01021_v01.nc
#   Copying awe_l7a_tmp_2024026T2239_01022_v01.nc to temp...
#   Finished awe_l7a_tmp_2024026T2239_01022_v01.nc
#
# ================================================================================
# Processing DOY 027  (27/365)  with 16 files
# ================================================================================
#   Copying awe_l7a_tmp_2024027T0012_01023_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T0012_01023_v01.nc
#   Copying awe_l7a_tmp_2024027T0145_01024_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T0145_01024_v01.nc
#   Copying awe_l7a_tmp_2024027T0317_01025_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T0317_01025_v01.nc
#   Copying awe_l7a_tmp_2024027T0450_01026_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T0450_01026_v01.nc
#   Copying awe_l7a_tmp_2024027T0623_01027_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T0623_01027_v01.nc
#   Copying awe_l7a_tmp_2024027T0756_01028_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T0756_01028_v01.nc
#   Copying awe_l7a_tmp_2024027T0929_01029_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T0929_01029_v01.nc
#   Copying awe_l7a_tmp_2024027T1058_01030_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T1058_01030_v01.nc
#   Copying awe_l7a_tmp_2024027T1256_01031_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T1256_01031_v01.nc
#   Copying awe_l7a_tmp_2024027T1408_01032_v01.nc to temp...
#   Finished awe_l7a_tmp_2024027T1408_01032_v01.nc
# ...
#   Copying awe_l7a_tmp_2024080T1858_01856_v01.nc to temp...
#   Finished awe_l7a_tmp_2024080T1858_01856_v01.nc
#   Copying awe_l7a_tmp_2024080T2031_01857_v01.nc to temp...
#   Finished awe_l7a_tmp_2024080T2031_01857_v01.nc
#   Copying awe_l7a_tmp_2024080T2204_01858_v01.nc to temp...
#   Finished awe_l7a_tmp_2024080T2204_01858_v01.nc
#   Copying awe_l7a_tmp_2024080T2337_01859_v01.nc to temp...
#   Finished awe_l7a_tmp_2024080T2337_01859_v01.nc
#
# ================================================================================
# Processing DOY 081  (81/365)  with 11 files
# ================================================================================
#   Copying awe_l7a_tmp_2024081T0110_01860_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T0110_01860_v01.nc
#   Copying awe_l7a_tmp_2024081T0238_01861_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T0238_01861_v01.nc
#   Copying awe_l7a_tmp_2024081T0544_01863_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T0544_01863_v01.nc
#   Copying awe_l7a_tmp_2024081T0723_01864_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T0723_01864_v01.nc
#   Copying awe_l7a_tmp_2024081T1029_01866_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T1029_01866_v01.nc
#   Copying awe_l7a_tmp_2024081T1202_01867_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T1202_01867_v01.nc
#   Copying awe_l7a_tmp_2024081T1508_01869_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T1508_01869_v01.nc
#   Copying awe_l7a_tmp_2024081T1641_01870_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T1641_01870_v01.nc
#   Copying awe_l7a_tmp_2024081T1814_01871_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T1814_01871_v01.nc
#   Copying awe_l7a_tmp_2024081T1946_01872_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T1946_01872_v01.nc
#   Copying awe_l7a_tmp_2024081T2119_01873_v01.nc to temp...
#   Finished awe_l7a_tmp_2024081T2119_01873_v01.nc
#
# ================================================================================
# Processing DOY 082  (82/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024082T0025_01875_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T0025_01875_v01.nc
#   Copying awe_l7a_tmp_2024082T0158_01876_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T0158_01876_v01.nc
#   Copying awe_l7a_tmp_2024082T0326_01877_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T0326_01877_v01.nc
#   Copying awe_l7a_tmp_2024082T0632_01879_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T0632_01879_v01.nc
#   Copying awe_l7a_tmp_2024082T0805_01880_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T0805_01880_v01.nc
#   Copying awe_l7a_tmp_2024082T0941_01881_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T0941_01881_v01.nc
#   Copying awe_l7a_tmp_2024082T1248_01883_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T1248_01883_v01.nc
#   Copying awe_l7a_tmp_2024082T1421_01884_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T1421_01884_v01.nc
#   Copying awe_l7a_tmp_2024082T1554_01885_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T1554_01885_v01.nc
#   Copying awe_l7a_tmp_2024082T1727_01886_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T1727_01886_v01.nc
#   Copying awe_l7a_tmp_2024082T1900_01887_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T1900_01887_v01.nc
#   Copying awe_l7a_tmp_2024082T2033_01888_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T2033_01888_v01.nc
#   Copying awe_l7a_tmp_2024082T2206_01889_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T2206_01889_v01.nc
#   Copying awe_l7a_tmp_2024082T2339_01890_v01.nc to temp...
#   Finished awe_l7a_tmp_2024082T2339_01890_v01.nc
#
# ================================================================================
# Processing DOY 083  (83/365)  with 13 files
# ================================================================================
#   Copying awe_l7a_tmp_2024083T0112_01891_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T0112_01891_v01.nc
#   Copying awe_l7a_tmp_2024083T0244_01892_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T0244_01892_v01.nc
#   Copying awe_l7a_tmp_2024083T0417_01893_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T0417_01893_v01.nc
#   Copying awe_l7a_tmp_2024083T0550_01894_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T0550_01894_v01.nc
#   Copying awe_l7a_tmp_2024083T0723_01895_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T0723_01895_v01.nc
#   Copying awe_l7a_tmp_2024083T0852_01896_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T0852_01896_v01.nc
#   Copying awe_l7a_tmp_2024083T1335_01899_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T1335_01899_v01.nc
#   Copying awe_l7a_tmp_2024083T1508_01900_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T1508_01900_v01.nc
#   Copying awe_l7a_tmp_2024083T1641_01901_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T1641_01901_v01.nc
#   Copying awe_l7a_tmp_2024083T1814_01902_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T1814_01902_v01.nc
#   Copying awe_l7a_tmp_2024083T1947_01903_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T1947_01903_v01.nc
#   Copying awe_l7a_tmp_2024083T2120_01904_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T2120_01904_v01.nc
#   Copying awe_l7a_tmp_2024083T2253_01905_v01.nc to temp...
#   Finished awe_l7a_tmp_2024083T2253_01905_v01.nc
#
# ================================================================================
# Processing DOY 084  (84/365)  with 16 files
# ================================================================================
#   Copying awe_l7a_tmp_2024084T0026_01906_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T0026_01906_v01.nc
#   Copying awe_l7a_tmp_2024084T0159_01907_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T0159_01907_v01.nc
#   Copying awe_l7a_tmp_2024084T0332_01908_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T0332_01908_v01.nc
#   Copying awe_l7a_tmp_2024084T0505_01909_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T0505_01909_v01.nc
#   Copying awe_l7a_tmp_2024084T0638_01910_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T0638_01910_v01.nc
#   Copying awe_l7a_tmp_2024084T0810_01911_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T0810_01911_v01.nc
#   Copying awe_l7a_tmp_2024084T0943_01912_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T0943_01912_v01.nc
#   Copying awe_l7a_tmp_2024084T1116_01913_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T1116_01913_v01.nc
#   Copying awe_l7a_tmp_2024084T1249_01914_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T1249_01914_v01.nc
#   Copying awe_l7a_tmp_2024084T1421_01915_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T1421_01915_v01.nc
#   Copying awe_l7a_tmp_2024084T1554_01916_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T1554_01916_v01.nc
#   Copying awe_l7a_tmp_2024084T1727_01917_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T1727_01917_v01.nc
#   Copying awe_l7a_tmp_2024084T1901_01918_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T1901_01918_v01.nc
#   Copying awe_l7a_tmp_2024084T2034_01919_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T2034_01919_v01.nc
#   Copying awe_l7a_tmp_2024084T2207_01920_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T2207_01920_v01.nc
#   Copying awe_l7a_tmp_2024084T2340_01921_v01.nc to temp...
#   Finished awe_l7a_tmp_2024084T2340_01921_v01.nc
#
# ================================================================================
# Processing DOY 085  (85/365)  with 12 files
# ================================================================================
#   Copying awe_l7a_tmp_2024085T0553_01925_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T0553_01925_v01.nc
#   Copying awe_l7a_tmp_2024085T0726_01926_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T0726_01926_v01.nc
#   Copying awe_l7a_tmp_2024085T0859_01927_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T0859_01927_v01.nc
#   Copying awe_l7a_tmp_2024085T1032_01928_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T1032_01928_v01.nc
#   Copying awe_l7a_tmp_2024085T1205_01929_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T1205_01929_v01.nc
#   Copying awe_l7a_tmp_2024085T1332_01930_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T1332_01930_v01.nc
#   Copying awe_l7a_tmp_2024085T1504_01931_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T1504_01931_v01.nc
#   Copying awe_l7a_tmp_2024085T1644_01932_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T1644_01932_v01.nc
#   Copying awe_l7a_tmp_2024085T1817_01933_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T1817_01933_v01.nc
#   Copying awe_l7a_tmp_2024085T1950_01934_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T1950_01934_v01.nc
#   Copying awe_l7a_tmp_2024085T2123_01935_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T2123_01935_v01.nc
#   Copying awe_l7a_tmp_2024085T2256_01936_v01.nc to temp...
#   Finished awe_l7a_tmp_2024085T2256_01936_v01.nc
#
# ================================================================================
# Processing DOY 086  (86/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024086T0029_01937_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T0029_01937_v01.nc
#   Copying awe_l7a_tmp_2024086T0155_01938_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T0155_01938_v01.nc
#   Copying awe_l7a_tmp_2024086T0501_01940_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T0501_01940_v01.nc
#   Copying awe_l7a_tmp_2024086T0634_01941_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T0634_01941_v01.nc
#   Copying awe_l7a_tmp_2024086T0810_01942_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T0810_01942_v01.nc
#   Copying awe_l7a_tmp_2024086T0943_01943_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T0943_01943_v01.nc
#   Copying awe_l7a_tmp_2024086T1116_01944_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T1116_01944_v01.nc
#   Copying awe_l7a_tmp_2024086T1249_01945_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T1249_01945_v01.nc
#   Copying awe_l7a_tmp_2024086T1421_01946_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T1421_01946_v01.nc
#   Copying awe_l7a_tmp_2024086T1554_01947_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T1554_01947_v01.nc
#   Copying awe_l7a_tmp_2024086T1727_01948_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T1727_01948_v01.nc
#   Copying awe_l7a_tmp_2024086T1900_01949_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T1900_01949_v01.nc
#   Copying awe_l7a_tmp_2024086T2033_01950_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T2033_01950_v01.nc
#   Copying awe_l7a_tmp_2024086T2206_01951_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T2206_01951_v01.nc
#   Copying awe_l7a_tmp_2024086T2339_01952_v01.nc to temp...
#   Finished awe_l7a_tmp_2024086T2339_01952_v01.nc
#
# ================================================================================
# Processing DOY 087  (87/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024087T0112_01953_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T0112_01953_v01.nc
#   Copying awe_l7a_tmp_2024087T0245_01954_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T0245_01954_v01.nc
#   Copying awe_l7a_tmp_2024087T0418_01955_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T0418_01955_v01.nc
#   Copying awe_l7a_tmp_2024087T0551_01956_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T0551_01956_v01.nc
#   Copying awe_l7a_tmp_2024087T0724_01957_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T0724_01957_v01.nc
#   Copying awe_l7a_tmp_2024087T1031_01959_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T1031_01959_v01.nc
#   Copying awe_l7a_tmp_2024087T1202_01960_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T1202_01960_v01.nc
#   Copying awe_l7a_tmp_2024087T1335_01961_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T1335_01961_v01.nc
#   Copying awe_l7a_tmp_2024087T1508_01962_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T1508_01962_v01.nc
#   Copying awe_l7a_tmp_2024087T1641_01963_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T1641_01963_v01.nc
#   Copying awe_l7a_tmp_2024087T1814_01964_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T1814_01964_v01.nc
#   Copying awe_l7a_tmp_2024087T1947_01965_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T1947_01965_v01.nc
#   Copying awe_l7a_tmp_2024087T2120_01966_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T2120_01966_v01.nc
#   Copying awe_l7a_tmp_2024087T2253_01967_v01.nc to temp...
#   Finished awe_l7a_tmp_2024087T2253_01967_v01.nc
#
# ================================================================================
# Processing DOY 088  (88/365)  with 15 files
# ================================================================================
#   Copying awe_l7a_tmp_2024088T0026_01968_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T0026_01968_v01.nc
#   Copying awe_l7a_tmp_2024088T0159_01969_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T0159_01969_v01.nc
#   Copying awe_l7a_tmp_2024088T0331_01970_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T0331_01970_v01.nc
#   Copying awe_l7a_tmp_2024088T0504_01971_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T0504_01971_v01.nc
#   Copying awe_l7a_tmp_2024088T0637_01972_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T0637_01972_v01.nc
#   Copying awe_l7a_tmp_2024088T0810_01973_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T0810_01973_v01.nc
#   Copying awe_l7a_tmp_2024088T0943_01974_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T0943_01974_v01.nc
#   Copying awe_l7a_tmp_2024088T1249_01976_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T1249_01976_v01.nc
#   Copying awe_l7a_tmp_2024088T1422_01977_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T1422_01977_v01.nc
#   Copying awe_l7a_tmp_2024088T1555_01978_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T1555_01978_v01.nc
#   Copying awe_l7a_tmp_2024088T1728_01979_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T1728_01979_v01.nc
#   Copying awe_l7a_tmp_2024088T1901_01980_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T1901_01980_v01.nc
#   Copying awe_l7a_tmp_2024088T2034_01981_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T2034_01981_v01.nc
#   Copying awe_l7a_tmp_2024088T2208_01982_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T2208_01982_v01.nc
#   Copying awe_l7a_tmp_2024088T2340_01983_v01.nc to temp...
#   Finished awe_l7a_tmp_2024088T2340_01983_v01.nc
#
# ================================================================================
# Processing DOY 089  (89/365)  with 14 files
# ================================================================================
#   Copying awe_l7a_tmp_2024089T0113_01984_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T0113_01984_v01.nc
#   Copying awe_l7a_tmp_2024089T0246_01985_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T0246_01985_v01.nc
#   Copying awe_l7a_tmp_2024089T0419_01986_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T0419_01986_v01.nc
#   Copying awe_l7a_tmp_2024089T0725_01988_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T0725_01988_v01.nc
#   Copying awe_l7a_tmp_2024089T0858_01989_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T0858_01989_v01.nc
#   Copying awe_l7a_tmp_2024089T1031_01990_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T1031_01990_v01.nc
#   Copying awe_l7a_tmp_2024089T1205_01991_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T1205_01991_v01.nc
#   Copying awe_l7a_tmp_2024089T1337_01992_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T1337_01992_v01.nc
#   Copying awe_l7a_tmp_2024089T1509_01993_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T1509_01993_v01.nc
#   Copying awe_l7a_tmp_2024089T1642_01994_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T1642_01994_v01.nc
#   Copying awe_l7a_tmp_2024089T1815_01995_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T1815_01995_v01.nc
#   Copying awe_l7a_tmp_2024089T1949_01996_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T1949_01996_v01.nc
#   Copying awe_l7a_tmp_2024089T2122_01997_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T2122_01997_v01.nc
#   Copying awe_l7a_tmp_2024089T2255_01998_v01.nc to temp...
#   Finished awe_l7a_tmp_2024089T2255_01998_v01.nc
#
# ================================================================================
# Processing DOY 090  (90/365)  with 16 files
# ================================================================================
#   Copying awe_l7a_tmp_2024090T0027_01999_v01.nc to temp...

# %% [markdown]
# ## Test day 5

# %%
# %%
from pathlib import Path
import gc
import numpy as np
from netCDF4 import Dataset

p = Path("/Volumes/aweread/socfiles/public/l7/2024/01/awe_l7a_tmp_2024005T0917_00688_v01.nc")
TIME_INDEX = 0

LAT_NAME = "Lat_top"
STACK_PAIR = ("MFz_top", "MFm_top")

LAT_MIN = -60.0
LAT_MAX = 60.0
LAT_BIN_DEG = 1.0

USE_SUBSAMPLING = True
MAX_POINTS_PER_ROW = 2000
SUBSAMPLE_SEED = 0

lat_edges = np.arange(LAT_MIN, LAT_MAX + LAT_BIN_DEG, LAT_BIN_DEG)
nlat = len(lat_edges) - 1


def read_row(var, row_idx, time_index):
    if var.ndim == 3:
        return np.asarray(var[time_index, row_idx, :], dtype=float)
    elif var.ndim == 2:
        return np.asarray(var[row_idx, :], dtype=float)
    return None


def maybe_subsample_row(lat_row, val_row, max_points, seed):
    n = lat_row.size
    if n <= max_points:
        return lat_row, val_row
    rng = np.random.default_rng(seed)
    idx = rng.choice(n, size=max_points, replace=False)
    return lat_row[idx], val_row[idx]


def accumulate_row_into_profile(lat_row, val_row, lat_edges, prof_sum, prof_cnt):
    if lat_row.size == 0:
        return 0
    bin_idx = np.digitize(lat_row, lat_edges) - 1
    good = (
        np.isfinite(lat_row)
        & np.isfinite(val_row)
        & (bin_idx >= 0)
        & (bin_idx < len(prof_sum))
    )
    if not np.any(good):
        return 0
    bin_idx = bin_idx[good]
    val_good = val_row[good]
    np.add.at(prof_sum, bin_idx, val_good)
    np.add.at(prof_cnt, bin_idx, 1)
    return int(val_good.size)


print("Testing file:", p)

with Dataset(p, "r") as nc:
    lat_var = nc.variables[LAT_NAME]
    ny = lat_var.shape[1] if lat_var.ndim == 3 else lat_var.shape[0]
    print("ny =", ny)

    for icomp, comp in enumerate(STACK_PAIR):
        print(f"\n=== Component: {comp} ===")
        val_var = nc.variables[comp]

        prof_sum = np.zeros(nlat, dtype=np.float64)
        prof_cnt = np.zeros(nlat, dtype=np.int64)

        for iy in range(ny):
            if iy % 25 == 0:
                print(f"  row {iy}/{ny-1}")

            lat_row = read_row(lat_var, iy, TIME_INDEX)
            val_row = read_row(val_var, iy, TIME_INDEX)

            good = (
                np.isfinite(lat_row)
                & np.isfinite(val_row)
                & (lat_row >= LAT_MIN)
                & (lat_row <= LAT_MAX)
            )

            if np.any(good):
                lat_good = lat_row[good]
                val_good = val_row[good]

                if USE_SUBSAMPLING and lat_good.size > MAX_POINTS_PER_ROW:
                    seed = SUBSAMPLE_SEED + iy * 10 + icomp
                    lat_good, val_good = maybe_subsample_row(
                        lat_good, val_good, MAX_POINTS_PER_ROW, seed
                    )

                accumulate_row_into_profile(
                    lat_good, val_good, lat_edges, prof_sum, prof_cnt
                )

            del lat_row, val_row, good
            gc.collect()

        print(f"Finished component {comp}")
# Out:
# Testing file: /Volumes/aweread/socfiles/public/l7/2024/01/awe_l7a_tmp_2024005T0917_00688_v01.nc
# ny = 451
#
# === Component: MFz_top ===
#   row 0/450
#   row 25/450
#   row 50/450
#   row 75/450
#   row 100/450
#   row 125/450
#   row 150/450
#   row 175/450
#   row 200/450
#   row 225/450
#   row 250/450
#   row 275/450
#   row 300/450
#   row 325/450
#   row 350/450
#   row 375/450
#   row 400/450
#   row 425/450
#   row 450/450
# Finished component MFz_top
#
# === Component: MFm_top ===
#   row 0/450
#   row 25/450
#   row 50/450
#   row 75/450
#   row 100/450
#   row 125/450
#   row 150/450
#   row 175/450
#   row 200/450
#   row 225/450
#   row 250/450
#   row 275/450
#   row 300/450
#   row 325/450
#   row 350/450
#   row 375/450
#   row 400/450
#   row 425/450

# %% [markdown]
# ## Andes Region

# %%
#!/usr/bin/env python3
"""
Andes zoom map plots (Cartopy) for MF and its components vs lat lon from L7A outputs.

Reads (t,y,x) (names may vary by file):
  MF_top, MFz_top, MFm_top
  latitude variable (auto-detected)
  longitude variable (auto-detected)

Makes:
  Individual ANDES-ZOOM plots:
    <var>_andes_map.png              (binned GRID_DEG x GRID_DEG MEAN on PlateCarree)
  Plus a stacked plot:
    MFz_MFm_stacked_andes_maps.png   (MFz on top, MFm on bottom)

Notes:
  Supports LOG display with configurable handling of zeros.
  Uses percentile clipping for display only.
  Uses GRID_DEG bins (default 1°).
  Outputs go into:
    outputs_L7A_MF_cartopy_andes/<var>/
  Stacked plot outputs go into:
    outputs_L7A_MF_cartopy_andes/stacked/
"""

from __future__ import annotations

from pathlib import Path
from typing import List, Tuple, Dict, Optional
import gc

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from netCDF4 import Dataset

# -------------------------
# User params
# -------------------------
L7_DIR = Path("l7_062024")
FILE_GLOB = "*l7a*.nc"
TIME_INDEX = 0

# If you KNOW the names, set them here and leave the auto lists alone.
# Otherwise leave these as None to auto-detect.
LAT_NAME: Optional[str] = None
LON_NAME: Optional[str] = None

# Auto-detect candidates (first match wins)
LAT_CANDIDATES = [
    "Lat_top", "Latitude_top", "lat_top",
    "Lat", "Latitude", "lat", "LAT",
    "Lat_flat", "Latitude_flat", "lat_flat",
]
LON_CANDIDATES = [
    "Lon_top", "Longitude_top", "lon_top",
    "Lon", "Longitude", "lon", "LON",
    "Lon_flat", "Longitude_flat", "lon_flat",
]

# Individual plots for these
MF_COMPONENTS = ["MF_top", "MFz_top", "MFm_top"]

# Stacked plot: MFz + MFm
STACK_PAIR = ("MFz_top", "MFm_top")  # (top, bottom)

OUTDIR = Path("outputs_L7A_MF_cartopy_andes")
OUTDIR.mkdir(parents=True, exist_ok=True)

# Sampling cap (across ALL files) to keep it fast
MAX_POINTS_TOTAL = 4_500_000

# 2D bin size
GRID_DEG = .5  

# Display clipping percentiles (display only)
CLIP_PLO = 2.0
CLIP_PHI = 98.0

# -------------------------
# ANDES REGION (ZOOM)
# -------------------------
# Andes-ish box, SOUTH of the equator (0° down to -60°)
ANDES_LON_MIN = -92.0
ANDES_LON_MAX = -30.0
ANDES_LAT_MIN = -60.0
ANDES_LAT_MAX = 0.0

# -------------------------
# LOG scaling controls
# -------------------------
USE_LOG_SCALE = False  # set False for linear plots

# Zero-handling modes (log only):
#   "drop"  -> treat <=0 as missing (NaN) for display
#   "floor" -> replace <=0 with LOG_FLOOR for display
ZERO_MODE = "floor"
LOG_FLOOR = 1e-4  # used only when ZERO_MODE == "floor"

# -------------------------
# LIGHT COLORMAP (better coastline visibility)
# -------------------------
CMAP = "YlOrBr"   # other light-ish options: "Blues", "BuGn", "GnBu", "cividis"

# -------------------------
# Cartopy import
# -------------------------
try:
    import cartopy.crs as ccrs
    import cartopy.feature as cfeature
except Exception as e:
    raise ImportError(
        "Cartopy is not available in this environment. "
        "If you're in conda: conda install -c conda-forge cartopy"
    ) from e


# -------------------------
# Helpers
# -------------------------
def wrap_lon180(lon_deg: np.ndarray) -> np.ndarray:
    return ((lon_deg + 180.0) % 360.0) - 180.0


def apply_zero_mode(v: np.ndarray, zero_mode: str, floor: float) -> np.ndarray:
    out = v.copy()
    bad = np.isfinite(out) & (out <= 0)
    if zero_mode == "drop":
        out[bad] = np.nan
    elif zero_mode == "floor":
        out[bad] = floor
    else:
        raise ValueError(f"Unknown ZERO_MODE={zero_mode!r}. Use 'drop' or 'floor'.")
    return out


def robust_clip_linear(v: np.ndarray, plo: float, phi: float) -> Tuple[float, float]:
    good = np.isfinite(v)
    if not np.any(good):
        return (0.0, 1.0)
    lo, hi = np.nanpercentile(v[good], [plo, phi])
    if (not np.isfinite(lo)) or (not np.isfinite(hi)) or lo == hi:
        lo = float(np.nanmin(v[good]))
        hi = float(np.nanmax(v[good]))
    return float(lo), float(hi)


def robust_clip_log(v: np.ndarray, plo: float, phi: float, floor: float) -> Tuple[float, float]:
    good = np.isfinite(v) & (v > 0)
    if not np.any(good):
        return (floor, floor * 10.0)
    lo, hi = np.nanpercentile(v[good], [plo, phi])
    lo = max(float(lo), float(floor))
    hi = max(float(hi), lo * 10.0)
    return lo, hi


def pick_varname(nc: Dataset, preferred: Optional[str], candidates: List[str]) -> Optional[str]:
    if preferred is not None:
        return preferred if preferred in nc.variables else None
    for name in candidates:
        if name in nc.variables:
            return name
    return None


def binned_mean_2d_region(
    lat: np.ndarray,
    lon: np.ndarray,
    mf: np.ndarray,
    ddeg: float,
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Region-limited 2D mean binning.
    Returns:
      lon_edges, lat_edges, grid_mean (nlat, nlon)
    """
    # Align edges to degrees
    lon0 = np.floor(ANDES_LON_MIN / ddeg) * ddeg
    lon1 = np.ceil(ANDES_LON_MAX / ddeg) * ddeg
    lat0 = np.floor(ANDES_LAT_MIN / ddeg) * ddeg
    lat1 = np.ceil(ANDES_LAT_MAX / ddeg) * ddeg

    lon_edges = np.arange(lon0, lon1 + ddeg, ddeg)
    lat_edges = np.arange(lat0, lat1 + ddeg, ddeg)

    nlon = lon_edges.size - 1
    nlat = lat_edges.size - 1

    grid_sum = np.zeros((nlat, nlon), dtype=np.float64)
    grid_cnt = np.zeros((nlat, nlon), dtype=np.int64)

    in_region = (
        np.isfinite(lat) & np.isfinite(lon) & np.isfinite(mf) &
        (lon >= ANDES_LON_MIN) & (lon <= ANDES_LON_MAX) &
        (lat >= ANDES_LAT_MIN) & (lat <= ANDES_LAT_MAX)
    )

    if not np.any(in_region):
        return lon_edges, lat_edges, np.full((nlat, nlon), np.nan, dtype=float)

    lat_r = lat[in_region]
    lon_r = lon[in_region]
    mf_r = mf[in_region].astype(np.float64, copy=False)

    j = np.digitize(lon_r, lon_edges) - 1
    i = np.digitize(lat_r, lat_edges) - 1
    good = (i >= 0) & (i < nlat) & (j >= 0) & (j < nlon)

    if not np.any(good):
        return lon_edges, lat_edges, np.full((nlat, nlon), np.nan, dtype=float)

    i = i[good]
    j = j[good]
    v = mf_r[good]

    np.add.at(grid_sum, (i, j), v)
    np.add.at(grid_cnt, (i, j), 1)

    grid_mean = np.full((nlat, nlon), np.nan, dtype=np.float64)
    mask = grid_cnt > 0
    grid_mean[mask] = grid_sum[mask] / grid_cnt[mask]
    return lon_edges, lat_edges, grid_mean.astype(float)


def plot_andes_map(
    lon_edges: np.ndarray,
    lat_edges: np.ndarray,
    grid_disp: np.ndarray,
    title: str,
    cbar_label: str,
    outpath: Path,
    use_log: bool,
    norm: LogNorm | None,
    vmin: float | None,
    vmax: float | None,
) -> None:
    proj = ccrs.PlateCarree()
    fig = plt.figure(figsize=(12, 8), constrained_layout=True)
    ax = plt.axes(projection=proj)

    ax.set_extent(
        [ANDES_LON_MIN, ANDES_LON_MAX, ANDES_LAT_MIN, ANDES_LAT_MAX],
        crs=ccrs.PlateCarree(),
    )

    # Dark coastlines pop on light colormap
    ax.coastlines(linewidth=0.9, color="black")
    ax.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor="black")

    gl = ax.gridlines(draw_labels=True, linewidth=0.25, alpha=0.6)
    gl.top_labels = False
    gl.right_labels = False

    im = ax.pcolormesh(
        lon_edges,
        lat_edges,
        grid_disp,
        transform=ccrs.PlateCarree(),
        shading="auto",
        cmap=CMAP,
        norm=norm,
        vmin=None if use_log else vmin,
        vmax=None if use_log else vmax,
    )

    cb = plt.colorbar(im, ax=ax, fraction=0.035, pad=0.02)
    cb.set_label(cbar_label)

    ax.set_title(title)
    fig.savefig(outpath, dpi=200)
    plt.close(fig)


# -------------------------
# Sanity check zero mode
# -------------------------
if USE_LOG_SCALE:
    if ZERO_MODE not in ("drop", "floor"):
        raise ValueError("ZERO_MODE must be 'drop' or 'floor'")
    if ZERO_MODE == "floor" and (not np.isfinite(LOG_FLOOR) or LOG_FLOOR <= 0):
        raise ValueError("LOG_FLOOR must be a finite positive number when ZERO_MODE='floor'")

# -------------------------
# Load and sample across files
# -------------------------
files = sorted(L7_DIR.glob(FILE_GLOB))
print(f"Found {len(files)} files in {L7_DIR.resolve()} matching {FILE_GLOB}")

if len(files) == 0:
    raise RuntimeError("No L7A files found.")

per_file_cap = max(50_000, MAX_POINTS_TOTAL // max(1, len(files)))

lat_all: Dict[str, List[np.ndarray]] = {name: [] for name in MF_COMPONENTS}
lon_all: Dict[str, List[np.ndarray]] = {name: [] for name in MF_COMPONENTS}
mf_all: Dict[str, List[np.ndarray]] = {name: [] for name in MF_COMPONENTS}

picked_latlon_once = False

for p in files:
    with Dataset(p, "r") as nc:
        lat_name = pick_varname(nc, LAT_NAME, LAT_CANDIDATES)
        lon_name = pick_varname(nc, LON_NAME, LON_CANDIDATES)
        if lat_name is None or lon_name is None:
            print(f"Skip {p.name}: could not find lat/lon vars. "
                  f"Available vars example: {list(nc.variables.keys())[:25]}")
            continue

        if not picked_latlon_once:
            print(f"Using lat var: {lat_name} | lon var: {lon_name}")
            picked_latlon_once = True

        lat = np.asarray(nc.variables[lat_name][TIME_INDEX], dtype=float)
        lon = np.asarray(nc.variables[lon_name][TIME_INDEX], dtype=float)
        lon = wrap_lon180(lon)

        # Region filter first (saves sampling budget)
        base_good = (
            np.isfinite(lat) & np.isfinite(lon) &
            (lon >= ANDES_LON_MIN) & (lon <= ANDES_LON_MAX) &
            (lat >= ANDES_LAT_MIN) & (lat <= ANDES_LAT_MAX)
        )
        base_idx = np.where(base_good.ravel())[0]
        if base_idx.size == 0:
            print(f"Skip {p.name}: no valid lat/lon points inside Andes box")
            continue

        if base_idx.size > per_file_cap:
            rng = np.random.default_rng(0)  # deterministic sampling
            base_idx = rng.choice(base_idx, size=per_file_cap, replace=False)

        la = lat.ravel()[base_idx]
        lo = lon.ravel()[base_idx]

        any_used = False
        counts_this_file = {}

        for mf_name in MF_COMPONENTS:
            if mf_name not in nc.variables:
                counts_this_file[mf_name] = 0
                continue

            mf_raw = np.asarray(nc.variables[mf_name][TIME_INDEX], dtype=float).ravel()[base_idx]
            good = np.isfinite(mf_raw)

            n = int(np.count_nonzero(good))
            counts_this_file[mf_name] = n
            if n == 0:
                continue

            lat_all[mf_name].append(la[good])
            lon_all[mf_name].append(lo[good])
            mf_all[mf_name].append(mf_raw[good])
            any_used = True

        if any_used:
            print(f"{p.name}: added points per component: {counts_this_file}")
        else:
            print(f"{p.name}: no valid MF points for requested components")

# -------------------------
# Build grids + plot per component (ANDES ZOOM) USING MEAN
# -------------------------
for mf_name in MF_COMPONENTS:
    if not mf_all[mf_name]:
        print(f"\nNo samples for {mf_name}. Skipping plots.")
        continue

    LAT = np.concatenate(lat_all[mf_name])
    LON = np.concatenate(lon_all[mf_name])
    MF_raw = np.concatenate(mf_all[mf_name])

    if MF_raw.size > MAX_POINTS_TOTAL:
        rng = np.random.default_rng(1)
        idx = rng.choice(np.arange(MF_raw.size), size=MAX_POINTS_TOTAL, replace=False)
        LAT, LON, MF_raw = LAT[idx], LON[idx], MF_raw[idx]

    if USE_LOG_SCALE:
        MF = apply_zero_mode(MF_raw, ZERO_MODE, LOG_FLOOR)
        mf_lo, mf_hi = robust_clip_log(MF, CLIP_PLO, CLIP_PHI, LOG_FLOOR)
        title = (
            f"{mf_name} Andes map\n"
            f"(MEAN in {GRID_DEG:.1f}° bins, LOG display, "
            f"zeros->{'NaN' if ZERO_MODE=='drop' else f'{LOG_FLOOR:g}'} )"
        )
    else:
        MF = MF_raw
        mf_lo, mf_hi = robust_clip_linear(MF, CLIP_PLO, CLIP_PHI)
        title = (
            f"{mf_name} Andes map\n"
            f"(MEAN in {GRID_DEG:.1f}° bins, linear display)"
        )

    lon_edges, lat_edges, grid_mean = binned_mean_2d_region(LAT, LON, MF, GRID_DEG)

    if USE_LOG_SCALE:
        grid_disp = apply_zero_mode(grid_mean, ZERO_MODE, LOG_FLOOR)
        norm = LogNorm(vmin=mf_lo, vmax=mf_hi)
        vmin = vmax = None
        cbar_label = f"{mf_name} (m2 s-2, log)"
    else:
        grid_disp = np.clip(grid_mean, mf_lo, mf_hi)
        norm = None
        vmin, vmax = mf_lo, mf_hi
        cbar_label = f"{mf_name} (m2 s-2)"

    out_comp = OUTDIR / mf_name
    out_comp.mkdir(parents=True, exist_ok=True)

    plot_andes_map(
        lon_edges=lon_edges,
        lat_edges=lat_edges,
        grid_disp=grid_disp,
        title=title,
        cbar_label=cbar_label,
        outpath=out_comp / f"{mf_name}_andes_map.png",
        use_log=USE_LOG_SCALE,
        norm=norm,
        vmin=vmin,
        vmax=vmax,
    )

# -------------------------
# Stacked MFz + MFm plot (ANDES ZOOM)
# Shared scaling so panels are comparable
# -------------------------
mf_top, mf_bot = STACK_PAIR
if mf_all.get(mf_top) and mf_all.get(mf_bot):
    LAT1 = np.concatenate(lat_all[mf_top])
    LON1 = np.concatenate(lon_all[mf_top])
    V1 = np.concatenate(mf_all[mf_top])

    LAT2 = np.concatenate(lat_all[mf_bot])
    LON2 = np.concatenate(lon_all[mf_bot])
    V2 = np.concatenate(mf_all[mf_bot])

    if V1.size > MAX_POINTS_TOTAL:
        rng = np.random.default_rng(2)
        idx = rng.choice(np.arange(V1.size), size=MAX_POINTS_TOTAL, replace=False)
        LAT1, LON1, V1 = LAT1[idx], LON1[idx], V1[idx]
    if V2.size > MAX_POINTS_TOTAL:
        rng = np.random.default_rng(3)
        idx = rng.choice(np.arange(V2.size), size=MAX_POINTS_TOTAL, replace=False)
        LAT2, LON2, V2 = LAT2[idx], LON2[idx], V2[idx]

    if USE_LOG_SCALE:
        V1d = apply_zero_mode(V1, ZERO_MODE, LOG_FLOOR)
        V2d = apply_zero_mode(V2, ZERO_MODE, LOG_FLOOR)
        Vall = np.concatenate([V1d, V2d])
        v_lo, v_hi = robust_clip_log(Vall, CLIP_PLO, CLIP_PHI, LOG_FLOOR)
        norm_shared = LogNorm(vmin=v_lo, vmax=v_hi)
        vmin = vmax = None
        cbar_label = "MF (m2 s-2, log)"
        title = (
            f"{mf_top} (top) + {mf_bot} (bottom) Andes maps\n"
            f"(MEAN in {GRID_DEG:.1f}° bins, LOG display, shared scale)"
        )
        grid1_vals = V1d
        grid2_vals = V2d
    else:
        Vall = np.concatenate([V1, V2])
        v_lo, v_hi = robust_clip_linear(Vall, CLIP_PLO, CLIP_PHI)
        norm_shared = None
        vmin, vmax = v_lo, v_hi
        cbar_label = "MF (m2 s-2)"
        title = (
            f"{mf_top} (top) + {mf_bot} (bottom) Andes maps\n"
            f"(MEAN in {GRID_DEG:.1f}° bins, linear display, shared scale)"
        )
        grid1_vals = V1
        grid2_vals = V2

    lon_edges1, lat_edges1, grid1 = binned_mean_2d_region(LAT1, LON1, grid1_vals, GRID_DEG)
    lon_edges2, lat_edges2, grid2 = binned_mean_2d_region(LAT2, LON2, grid2_vals, GRID_DEG)

    if USE_LOG_SCALE:
        grid1_disp = apply_zero_mode(grid1, ZERO_MODE, LOG_FLOOR)
        grid2_disp = apply_zero_mode(grid2, ZERO_MODE, LOG_FLOOR)
    else:
        grid1_disp = np.clip(grid1, v_lo, v_hi)
        grid2_disp = np.clip(grid2, v_lo, v_hi)

    stacked_dir = OUTDIR / "stacked"
    stacked_dir.mkdir(parents=True, exist_ok=True)
    outpath = stacked_dir / "MFz_MFm_stacked_andes_maps.png"

    proj = ccrs.PlateCarree()
    fig = plt.figure(figsize=(12, 12), constrained_layout=True)
    gs = fig.add_gridspec(2, 1)

    ax1 = fig.add_subplot(gs[0, 0], projection=proj)
    ax1.set_extent([ANDES_LON_MIN, ANDES_LON_MAX, ANDES_LAT_MIN, ANDES_LAT_MAX], crs=ccrs.PlateCarree())
    ax1.coastlines(linewidth=0.9, color="black")
    ax1.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor="black")
    gl1 = ax1.gridlines(draw_labels=True, linewidth=0.25, alpha=0.6)
    gl1.top_labels = False
    gl1.right_labels = False
    im1 = ax1.pcolormesh(
        lon_edges1, lat_edges1, grid1_disp,
        transform=ccrs.PlateCarree(),
        shading="auto",
        cmap=CMAP,
        norm=norm_shared,
        vmin=None if USE_LOG_SCALE else vmin,
        vmax=None if USE_LOG_SCALE else vmax,
    )
    ax1.set_title(mf_top)

    ax2 = fig.add_subplot(gs[1, 0], projection=proj)
    ax2.set_extent([ANDES_LON_MIN, ANDES_LON_MAX, ANDES_LAT_MIN, ANDES_LAT_MAX], crs=ccrs.PlateCarree())
    ax2.coastlines(linewidth=0.9, color="black")
    ax2.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor="black")
    gl2 = ax2.gridlines(draw_labels=True, linewidth=0.25, alpha=0.6)
    gl2.top_labels = False
    gl2.right_labels = False
    im2 = ax2.pcolormesh(
        lon_edges2, lat_edges2, grid2_disp,
        transform=ccrs.PlateCarree(),
        shading="auto",
        cmap=CMAP,
        norm=norm_shared,
        vmin=None if USE_LOG_SCALE else vmin,
        vmax=None if USE_LOG_SCALE else vmax,
    )
    ax2.set_title(mf_bot)

    cb = fig.colorbar(im2, ax=[ax1, ax2], fraction=0.035, pad=0.02)
    cb.set_label(cbar_label)

    fig.suptitle(title, fontsize=14)
    fig.savefig(outpath, dpi=200)
    plt.close(fig)

    print("\nSaved stacked Andes plot to:", outpath.resolve())
else:
    print(f"\nSkipping stacked plot: missing samples for {STACK_PAIR}")

gc.collect()
print("\nSaved Andes plots to:", OUTDIR.resolve())
# Out:
# Found 440 files in C:\Users\domin\juwavelet\Momentum Flux\l7_062024 matching *l7a*.nc
# Using lat var: Lat_top | lon var: Lon_top
# Skip awe_l7a_tmp_2024153T0137_02976_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024153T0556_02979_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024153T0729_02980_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024153T0853_02981_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024153T1026_02982_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024153T1159_02983_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024153T1340_02984_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024153T1513_02985_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024153T1646_02986_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024153T1819_02987_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024153T1952_02988_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024153T2124_02989_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024153T2257_02990_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024154T0155_02992_v01.nc: added points per component: {'MF_top': 47020, 'MFz_top': 47020, 'MFm_top': 47020}
# awe_l7a_tmp_2024154T0332_02993_v01.nc: added points per component: {'MF_top': 29610, 'MFz_top': 29610, 'MFm_top': 29610}
# awe_l7a_tmp_2024154T0505_02994_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024154T0810_02996_v01.nc: added points per component: {'MF_top': 44738, 'MFz_top': 44738, 'MFm_top': 44738}
# Skip awe_l7a_tmp_2024154T0943_02997_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024154T1116_02998_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024154T1555_03001_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024154T1728_03002_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024154T2033_03004_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024154T2206_03005_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024155T0245_03008_v01.nc: added points per component: {'MF_top': 30709, 'MFz_top': 30709, 'MFm_top': 30709}
# awe_l7a_tmp_2024155T0418_03009_v01.nc: added points per component: {'MF_top': 44726, 'MFz_top': 44726, 'MFm_top': 44726}
# awe_l7a_tmp_2024155T0551_03010_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024155T0723_03011_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024155T0857_03012_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024155T1029_03013_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024155T1202_03014_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024155T1335_03015_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024155T1508_03016_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024155T1641_03017_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024155T1814_03018_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024155T1946_03019_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024155T2119_03020_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024155T2252_03021_v01.nc: no valid MF points for requested components
# awe_l7a_tmp_2024156T0025_03022_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024156T0158_03023_v01.nc: added points per component: {'MF_top': 26913, 'MFz_top': 26913, 'MFm_top': 26913}
# awe_l7a_tmp_2024156T0331_03024_v01.nc: added points per component: {'MF_top': 41844, 'MFz_top': 41844, 'MFm_top': 41844}
# awe_l7a_tmp_2024156T0504_03025_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024156T0637_03026_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024156T0810_03027_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024156T0943_03028_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024156T1115_03029_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024156T1248_03030_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024156T1421_03031_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024156T1554_03032_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024156T1727_03033_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024156T1900_03034_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024156T2033_03035_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024156T2206_03036_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024156T2338_03037_v01.nc: added points per component: {'MF_top': 4526, 'MFz_top': 4526, 'MFm_top': 4526}
# awe_l7a_tmp_2024157T0111_03038_v01.nc: added points per component: {'MF_top': 40274, 'MFz_top': 40274, 'MFm_top': 40274}
# awe_l7a_tmp_2024157T0244_03039_v01.nc: added points per component: {'MF_top': 39787, 'MFz_top': 39787, 'MFm_top': 39787}
# awe_l7a_tmp_2024157T0417_03040_v01.nc: added points per component: {'MF_top': 44666, 'MFz_top': 44666, 'MFm_top': 44666}
# awe_l7a_tmp_2024157T0550_03041_v01.nc: added points per component: {'MF_top': 33738, 'MFz_top': 33738, 'MFm_top': 33738}
# awe_l7a_tmp_2024157T0723_03042_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024157T0856_03043_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024157T1029_03044_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024157T1201_03045_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024157T1334_03046_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024157T1507_03047_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024157T1640_03048_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024157T1813_03049_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024157T1946_03050_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024157T2119_03051_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024157T2252_03052_v01.nc: added points per component: {'MF_top': 1592, 'MFz_top': 1592, 'MFm_top': 1592}
# awe_l7a_tmp_2024158T0025_03053_v01.nc: added points per component: {'MF_top': 38403, 'MFz_top': 38403, 'MFm_top': 38403}
# awe_l7a_tmp_2024158T0157_03054_v01.nc: added points per component: {'MF_top': 34418, 'MFz_top': 34418, 'MFm_top': 34418}
# awe_l7a_tmp_2024158T0330_03055_v01.nc: added points per component: {'MF_top': 45006, 'MFz_top': 45006, 'MFm_top': 45006}
# awe_l7a_tmp_2024158T0503_03056_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024158T0636_03057_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024158T0809_03058_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024158T0942_03059_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024158T1115_03060_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024158T1247_03061_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024158T1417_03062_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024158T1550_03063_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024158T1723_03064_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024158T1856_03065_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024158T2029_03066_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024158T2201_03067_v01.nc: no valid MF points for requested components
# awe_l7a_tmp_2024158T2334_03068_v01.nc: added points per component: {'MF_top': 42958, 'MFz_top': 42958, 'MFm_top': 42958}
# awe_l7a_tmp_2024159T0111_03069_v01.nc: added points per component: {'MF_top': 40357, 'MFz_top': 40357, 'MFm_top': 40357}
# awe_l7a_tmp_2024159T0244_03070_v01.nc: added points per component: {'MF_top': 43133, 'MFz_top': 43133, 'MFm_top': 43133}
# awe_l7a_tmp_2024159T0417_03071_v01.nc: added points per component: {'MF_top': 45211, 'MFz_top': 45211, 'MFm_top': 45211}
# awe_l7a_tmp_2024159T0550_03072_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024159T0723_03073_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024159T0856_03074_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024159T1029_03075_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024159T1201_03076_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024159T1334_03077_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024159T1507_03078_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024159T1640_03079_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024159T1813_03080_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024159T1946_03081_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024159T2119_03082_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024159T2252_03083_v01.nc: added points per component: {'MF_top': 30374, 'MFz_top': 30374, 'MFm_top': 30374}
# awe_l7a_tmp_2024160T0206_03085_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024160T0334_03086_v01.nc: added points per component: {'MF_top': 42314, 'MFz_top': 42314, 'MFm_top': 42314}
# awe_l7a_tmp_2024160T0507_03087_v01.nc: added points per component: {'MF_top': 45971, 'MFz_top': 45971, 'MFm_top': 45971}
# awe_l7a_tmp_2024160T0639_03088_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024160T0812_03089_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024160T0945_03090_v01.nc: added points per component: {'MF_top': 10742, 'MFz_top': 10742, 'MFm_top': 10742}
# Skip awe_l7a_tmp_2024160T1118_03091_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024160T1251_03092_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024160T1727_03095_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024160T1903_03096_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024160T2036_03097_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024160T2208_03098_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024161T0114_03100_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024161T0244_03101_v01.nc: added points per component: {'MF_top': 49189, 'MFz_top': 49189, 'MFm_top': 49189}
# awe_l7a_tmp_2024161T0417_03102_v01.nc: added points per component: {'MF_top': 44770, 'MFz_top': 44770, 'MFm_top': 44770}
# awe_l7a_tmp_2024161T0550_03103_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024161T0723_03104_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024161T0856_03105_v01.nc: added points per component: {'MF_top': 486, 'MFz_top': 486, 'MFm_top': 486}
# Skip awe_l7a_tmp_2024161T1029_03106_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024161T1201_03107_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024161T1334_03108_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024161T1507_03109_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024161T1640_03110_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024161T1813_03111_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024161T1946_03112_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024161T2119_03113_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024161T2252_03114_v01.nc: added points per component: {'MF_top': 31966, 'MFz_top': 31966, 'MFm_top': 31966}
# awe_l7a_tmp_2024162T0025_03115_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024162T0158_03116_v01.nc: added points per component: {'MF_top': 31921, 'MFz_top': 31921, 'MFm_top': 31921}
# awe_l7a_tmp_2024162T0331_03117_v01.nc: added points per component: {'MF_top': 46096, 'MFz_top': 46096, 'MFm_top': 46096}
# awe_l7a_tmp_2024162T0504_03118_v01.nc: added points per component: {'MF_top': 32482, 'MFz_top': 32482, 'MFm_top': 32482}
# awe_l7a_tmp_2024162T0637_03119_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024162T0809_03120_v01.nc: added points per component: {'MF_top': 28220, 'MFz_top': 28220, 'MFm_top': 28220}
# Skip awe_l7a_tmp_2024162T0942_03121_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024162T1115_03122_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024162T1248_03123_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024162T1421_03124_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024162T1554_03125_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024162T1727_03126_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024162T1900_03127_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024162T2033_03128_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024162T2206_03129_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024162T2339_03130_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024163T0112_03131_v01.nc: added points per component: {'MF_top': 28958, 'MFz_top': 28958, 'MFm_top': 28958}
# awe_l7a_tmp_2024163T0245_03132_v01.nc: added points per component: {'MF_top': 40679, 'MFz_top': 40679, 'MFm_top': 40679}
# awe_l7a_tmp_2024163T0417_03133_v01.nc: added points per component: {'MF_top': 44757, 'MFz_top': 44757, 'MFm_top': 44757}
# awe_l7a_tmp_2024163T0550_03134_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024163T0723_03135_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024163T0856_03136_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024163T1029_03137_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024163T1202_03138_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024163T1508_03140_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024163T1640_03141_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024163T1814_03142_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024163T2119_03144_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024163T2252_03145_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024164T0025_03146_v01.nc: added points per component: {'MF_top': 23425, 'MFz_top': 23425, 'MFm_top': 23425}
# awe_l7a_tmp_2024164T0331_03148_v01.nc: added points per component: {'MF_top': 45838, 'MFz_top': 45838, 'MFm_top': 45838}
# awe_l7a_tmp_2024164T0504_03149_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024164T0637_03150_v01.nc: added points per component: {'MF_top': 41128, 'MFz_top': 41128, 'MFm_top': 41128}
# awe_l7a_tmp_2024164T0810_03151_v01.nc: added points per component: {'MF_top': 31280, 'MFz_top': 31280, 'MFm_top': 31280}
# Skip awe_l7a_tmp_2024164T0943_03152_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024164T1116_03153_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024164T1248_03154_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024164T1421_03155_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024164T1554_03156_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024164T1727_03157_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024164T1900_03158_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024164T2206_03160_v01.nc: added points per component: {'MF_top': 301, 'MFz_top': 301, 'MFm_top': 301}
# awe_l7a_tmp_2024164T2339_03161_v01.nc: added points per component: {'MF_top': 11483, 'MFz_top': 11483, 'MFm_top': 11483}
# awe_l7a_tmp_2024165T0112_03162_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024165T0245_03163_v01.nc: added points per component: {'MF_top': 35115, 'MFz_top': 35115, 'MFm_top': 35115}
# awe_l7a_tmp_2024165T0418_03164_v01.nc: added points per component: {'MF_top': 42278, 'MFz_top': 42278, 'MFm_top': 42278}
# awe_l7a_tmp_2024165T0550_03165_v01.nc: added points per component: {'MF_top': 45350, 'MFz_top': 45350, 'MFm_top': 45350}
# awe_l7a_tmp_2024165T0723_03166_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024165T0855_03167_v01.nc: no valid MF points for requested components
# Skip awe_l7a_tmp_2024165T1028_03168_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024165T1201_03169_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024165T1335_03170_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024165T1508_03171_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024165T1641_03172_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024165T1814_03173_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024165T2120_03175_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024165T2252_03176_v01.nc: no valid MF points for requested components
# awe_l7a_tmp_2024166T0025_03177_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024166T0158_03178_v01.nc: added points per component: {'MF_top': 43525, 'MFz_top': 43525, 'MFm_top': 43525}
# awe_l7a_tmp_2024166T0331_03179_v01.nc: added points per component: {'MF_top': 41944, 'MFz_top': 41944, 'MFm_top': 41944}
# awe_l7a_tmp_2024166T0504_03180_v01.nc: added points per component: {'MF_top': 46056, 'MFz_top': 46056, 'MFm_top': 46056}
# awe_l7a_tmp_2024166T0637_03181_v01.nc: added points per component: {'MF_top': 40692, 'MFz_top': 40692, 'MFm_top': 40692}
# awe_l7a_tmp_2024166T0810_03182_v01.nc: added points per component: {'MF_top': 29435, 'MFz_top': 29435, 'MFm_top': 29435}
# Skip awe_l7a_tmp_2024166T0943_03183_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024166T1116_03184_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024166T1249_03185_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024166T1421_03186_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024166T1554_03187_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024166T1727_03188_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024166T1900_03189_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024166T2033_03190_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024166T2206_03191_v01.nc: no valid MF points for requested components
# awe_l7a_tmp_2024166T2339_03192_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024167T0111_03193_v01.nc: added points per component: {'MF_top': 41298, 'MFz_top': 41298, 'MFm_top': 41298}
# awe_l7a_tmp_2024167T0244_03194_v01.nc: added points per component: {'MF_top': 41904, 'MFz_top': 41904, 'MFm_top': 41904}
# awe_l7a_tmp_2024167T0414_03195_v01.nc: added points per component: {'MF_top': 46077, 'MFz_top': 46077, 'MFm_top': 46077}
# awe_l7a_tmp_2024167T0601_03196_v01.nc: added points per component: {'MF_top': 44798, 'MFz_top': 44798, 'MFm_top': 44798}
# awe_l7a_tmp_2024167T0723_03197_v01.nc: added points per component: {'MF_top': 48914, 'MFz_top': 48914, 'MFm_top': 48914}
# awe_l7a_tmp_2024167T0856_03198_v01.nc: added points per component: {'MF_top': 22423, 'MFz_top': 22423, 'MFm_top': 22423}
# Skip awe_l7a_tmp_2024167T1029_03199_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024167T1159_03200_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024167T1331_03201_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024167T1504_03202_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024167T1639_03203_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024167T1814_03204_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024167T2120_03206_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024167T2253_03207_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024168T0025_03208_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024168T0158_03209_v01.nc: added points per component: {'MF_top': 44240, 'MFz_top': 44240, 'MFm_top': 44240}
# awe_l7a_tmp_2024168T0331_03210_v01.nc: added points per component: {'MF_top': 31641, 'MFz_top': 31641, 'MFm_top': 31641}
# awe_l7a_tmp_2024168T0504_03211_v01.nc: added points per component: {'MF_top': 43646, 'MFz_top': 43646, 'MFm_top': 43646}
# awe_l7a_tmp_2024168T0637_03212_v01.nc: added points per component: {'MF_top': 36851, 'MFz_top': 36851, 'MFm_top': 36851}
# awe_l7a_tmp_2024168T0810_03213_v01.nc: no valid MF points for requested components
# Skip awe_l7a_tmp_2024168T0943_03214_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024168T1116_03215_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024168T1249_03216_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024168T1422_03217_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024168T1555_03218_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024168T1728_03219_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024168T2034_03221_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024168T2207_03222_v01.nc: no valid MF points for requested components
# awe_l7a_tmp_2024168T2340_03223_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024169T0113_03224_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024169T0245_03225_v01.nc: added points per component: {'MF_top': 35468, 'MFz_top': 35468, 'MFm_top': 35468}
# awe_l7a_tmp_2024169T0418_03226_v01.nc: added points per component: {'MF_top': 42165, 'MFz_top': 42165, 'MFm_top': 42165}
# awe_l7a_tmp_2024169T0552_03227_v01.nc: added points per component: {'MF_top': 36401, 'MFz_top': 36401, 'MFm_top': 36401}
# awe_l7a_tmp_2024169T0724_03228_v01.nc: no valid MF points for requested components
# Skip awe_l7a_tmp_2024169T0857_03229_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024169T1030_03230_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024169T1203_03231_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024169T1336_03232_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024169T1509_03233_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024169T1642_03234_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024169T1815_03235_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024169T1948_03236_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024169T2121_03237_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024169T2254_03238_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024170T0026_03239_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024170T0200_03240_v01.nc: added points per component: {'MF_top': 32407, 'MFz_top': 32407, 'MFm_top': 32407}
# awe_l7a_tmp_2024170T0333_03241_v01.nc: added points per component: {'MF_top': 23906, 'MFz_top': 23906, 'MFm_top': 23906}
# awe_l7a_tmp_2024170T0506_03242_v01.nc: added points per component: {'MF_top': 37425, 'MFz_top': 37425, 'MFm_top': 37425}
# awe_l7a_tmp_2024170T0638_03243_v01.nc: no valid MF points for requested components
# awe_l7a_tmp_2024170T0812_03244_v01.nc: no valid MF points for requested components
# Skip awe_l7a_tmp_2024170T0944_03245_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024170T1117_03246_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024170T1250_03247_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024170T1423_03248_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024170T1556_03249_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024170T1729_03250_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024170T1902_03251_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024170T2035_03252_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024170T2208_03253_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024170T2341_03254_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024171T0114_03255_v01.nc: added points per component: {'MF_top': 41165, 'MFz_top': 41165, 'MFm_top': 41165}
# awe_l7a_tmp_2024171T0247_03256_v01.nc: added points per component: {'MF_top': 28403, 'MFz_top': 28403, 'MFm_top': 28403}
# awe_l7a_tmp_2024171T0420_03257_v01.nc: added points per component: {'MF_top': 22641, 'MFz_top': 22641, 'MFm_top': 22641}
# awe_l7a_tmp_2024171T0552_03258_v01.nc: added points per component: {'MF_top': 35403, 'MFz_top': 35403, 'MFm_top': 35403}
# awe_l7a_tmp_2024171T0725_03259_v01.nc: no valid MF points for requested components
# Skip awe_l7a_tmp_2024171T0858_03260_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024171T1031_03261_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024171T1204_03262_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024171T1337_03263_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024171T1510_03264_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024171T1643_03265_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024171T1816_03266_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024171T1949_03267_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024171T2122_03268_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024171T2254_03269_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024172T0025_03270_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024172T0200_03271_v01.nc: added points per component: {'MF_top': 46338, 'MFz_top': 46338, 'MFm_top': 46338}
# awe_l7a_tmp_2024172T0333_03272_v01.nc: added points per component: {'MF_top': 33038, 'MFz_top': 33038, 'MFm_top': 33038}
# awe_l7a_tmp_2024172T0506_03273_v01.nc: added points per component: {'MF_top': 33378, 'MFz_top': 33378, 'MFm_top': 33378}
# awe_l7a_tmp_2024172T0639_03274_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024172T0812_03275_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024172T0944_03276_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024172T1117_03277_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024172T1250_03278_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024172T1423_03279_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024172T1556_03280_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024172T1729_03281_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024172T1902_03282_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024172T2035_03283_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024172T2208_03284_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024172T2341_03285_v01.nc: added points per component: {'MF_top': 36378, 'MFz_top': 36378, 'MFm_top': 36378}
# awe_l7a_tmp_2024173T0114_03286_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024173T0247_03287_v01.nc: added points per component: {'MF_top': 46972, 'MFz_top': 46972, 'MFm_top': 46972}
# awe_l7a_tmp_2024173T0420_03288_v01.nc: added points per component: {'MF_top': 29738, 'MFz_top': 29738, 'MFm_top': 29738}
# awe_l7a_tmp_2024173T0553_03289_v01.nc: added points per component: {'MF_top': 10644, 'MFz_top': 10644, 'MFm_top': 10644}
# awe_l7a_tmp_2024173T0726_03290_v01.nc: added points per component: {'MF_top': 14378, 'MFz_top': 14378, 'MFm_top': 14378}
# Skip awe_l7a_tmp_2024173T0859_03291_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024173T1032_03292_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024173T1205_03293_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024173T1338_03294_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024173T1511_03295_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024173T1644_03296_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024173T1817_03297_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024173T2123_03299_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024173T2255_03300_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024174T0029_03301_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024174T0202_03302_v01.nc: added points per component: {'MF_top': 39575, 'MFz_top': 39575, 'MFm_top': 39575}
# awe_l7a_tmp_2024174T0335_03303_v01.nc: added points per component: {'MF_top': 43361, 'MFz_top': 43361, 'MFm_top': 43361}
# awe_l7a_tmp_2024174T0507_03304_v01.nc: added points per component: {'MF_top': 46349, 'MFz_top': 46349, 'MFm_top': 46349}
# awe_l7a_tmp_2024174T0641_03305_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024174T0814_03306_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024174T0946_03307_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024174T1119_03308_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024174T1252_03309_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024174T1425_03310_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024174T1558_03311_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024174T1731_03312_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024174T1904_03313_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024174T2037_03314_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024174T2210_03315_v01.nc: added points per component: {'MF_top': 37024, 'MFz_top': 37024, 'MFm_top': 37024}
# awe_l7a_tmp_2024174T2343_03316_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024175T0116_03317_v01.nc: added points per component: {'MF_top': 43271, 'MFz_top': 43271, 'MFm_top': 43271}
# awe_l7a_tmp_2024175T0249_03318_v01.nc: added points per component: {'MF_top': 47554, 'MFz_top': 47554, 'MFm_top': 47554}
# awe_l7a_tmp_2024175T0422_03319_v01.nc: added points per component: {'MF_top': 9707, 'MFz_top': 9707, 'MFm_top': 9707}
# awe_l7a_tmp_2024175T0555_03320_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# Skip awe_l7a_tmp_2024175T0728_03321_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024175T0901_03322_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024175T1033_03323_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024175T1207_03324_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024175T1339_03325_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024175T1512_03326_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024175T1645_03327_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024175T1818_03328_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024175T1951_03329_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024175T2124_03330_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024175T2257_03331_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024176T0030_03332_v01.nc: added points per component: {'MF_top': 40763, 'MFz_top': 40763, 'MFm_top': 40763}
# awe_l7a_tmp_2024176T0203_03333_v01.nc: added points per component: {'MF_top': 33874, 'MFz_top': 33874, 'MFm_top': 33874}
# awe_l7a_tmp_2024176T0336_03334_v01.nc: added points per component: {'MF_top': 24888, 'MFz_top': 24888, 'MFm_top': 24888}
# awe_l7a_tmp_2024176T0509_03335_v01.nc: added points per component: {'MF_top': 44467, 'MFz_top': 44467, 'MFm_top': 44467}
# Skip awe_l7a_tmp_2024176T0642_03336_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024176T0815_03337_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024176T0947_03338_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024176T1120_03339_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024176T1253_03340_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024176T1425_03341_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024176T1559_03342_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024176T1732_03343_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024176T1905_03344_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024176T2038_03345_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024176T2211_03346_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024176T2344_03347_v01.nc: added points per component: {'MF_top': 36693, 'MFz_top': 36693, 'MFm_top': 36693}
# awe_l7a_tmp_2024177T0117_03348_v01.nc: added points per component: {'MF_top': 48562, 'MFz_top': 48562, 'MFm_top': 48562}
# awe_l7a_tmp_2024177T0249_03349_v01.nc: added points per component: {'MF_top': 39081, 'MFz_top': 39081, 'MFm_top': 39081}
# awe_l7a_tmp_2024177T0422_03350_v01.nc: added points per component: {'MF_top': 45331, 'MFz_top': 45331, 'MFm_top': 45331}
# awe_l7a_tmp_2024177T0555_03351_v01.nc: added points per component: {'MF_top': 20662, 'MFz_top': 20662, 'MFm_top': 20662}
# Skip awe_l7a_tmp_2024177T0728_03352_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024177T0901_03353_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024177T1034_03354_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024177T1207_03355_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024177T1340_03356_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024177T1513_03357_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024177T1646_03358_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024177T1818_03359_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024177T2124_03361_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024177T2257_03362_v01.nc: no valid MF points for requested components
# awe_l7a_tmp_2024178T0030_03363_v01.nc: added points per component: {'MF_top': 44782, 'MFz_top': 44782, 'MFm_top': 44782}
# awe_l7a_tmp_2024178T0203_03364_v01.nc: added points per component: {'MF_top': 35985, 'MFz_top': 35985, 'MFm_top': 35985}
# awe_l7a_tmp_2024178T0336_03365_v01.nc: added points per component: {'MF_top': 47445, 'MFz_top': 47445, 'MFm_top': 47445}
# awe_l7a_tmp_2024178T0509_03366_v01.nc: no valid MF points for requested components
# Skip awe_l7a_tmp_2024178T0815_03368_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024178T0948_03369_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024178T1121_03370_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024178T1253_03371_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024178T1426_03372_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024178T1559_03373_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024178T1732_03374_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024178T1905_03375_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024178T2038_03376_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024178T2211_03377_v01.nc: no valid MF points for requested components
# awe_l7a_tmp_2024178T2344_03378_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024179T0117_03379_v01.nc: added points per component: {'MF_top': 21791, 'MFz_top': 21791, 'MFm_top': 21791}
# awe_l7a_tmp_2024179T0250_03380_v01.nc: added points per component: {'MF_top': 41413, 'MFz_top': 41413, 'MFm_top': 41413}
# awe_l7a_tmp_2024179T0423_03381_v01.nc: added points per component: {'MF_top': 39291, 'MFz_top': 39291, 'MFm_top': 39291}
# Skip awe_l7a_tmp_2024179T0555_03382_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T0728_03383_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T0901_03384_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T1034_03385_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T1207_03386_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T1340_03387_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T1513_03388_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T1646_03389_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T1819_03390_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T1952_03391_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024179T2125_03392_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024179T2258_03393_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024180T0030_03394_v01.nc: added points per component: {'MF_top': 33197, 'MFz_top': 33197, 'MFm_top': 33197}
# awe_l7a_tmp_2024180T0203_03395_v01.nc: added points per component: {'MF_top': 33794, 'MFz_top': 33794, 'MFm_top': 33794}
# awe_l7a_tmp_2024180T0336_03396_v01.nc: added points per component: {'MF_top': 44778, 'MFz_top': 44778, 'MFm_top': 44778}
# Skip awe_l7a_tmp_2024180T0509_03397_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024180T0815_03399_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024180T0948_03400_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024180T1121_03401_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024180T1254_03402_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024180T1426_03403_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024180T1559_03404_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024180T1732_03405_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024180T1905_03406_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024180T2038_03407_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024180T2211_03408_v01.nc: added points per component: {'MF_top': 22898, 'MFz_top': 22898, 'MFm_top': 22898}
# awe_l7a_tmp_2024180T2344_03409_v01.nc: added points per component: {'MF_top': 32413, 'MFz_top': 32413, 'MFm_top': 32413}
# awe_l7a_tmp_2024181T0117_03410_v01.nc: added points per component: {'MF_top': 46979, 'MFz_top': 46979, 'MFm_top': 46979}
# awe_l7a_tmp_2024181T0250_03411_v01.nc: added points per component: {'MF_top': 49039, 'MFz_top': 49039, 'MFm_top': 49039}
# awe_l7a_tmp_2024181T0423_03412_v01.nc: added points per component: {'MF_top': 29871, 'MFz_top': 29871, 'MFm_top': 29871}
# Skip awe_l7a_tmp_2024181T0556_03413_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024181T0728_03414_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024181T1034_03416_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024181T1207_03417_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024181T1340_03418_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024181T1510_03419_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024181T1654_03420_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024181T1819_03421_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024181T1952_03422_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024181T2122_03423_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024181T2255_03424_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024182T0031_03425_v01.nc: added points per component: {'MF_top': 42699, 'MFz_top': 42699, 'MFm_top': 42699}
# awe_l7a_tmp_2024182T0203_03426_v01.nc: added points per component: {'MF_top': 6113, 'MFz_top': 6113, 'MFm_top': 6113}
# awe_l7a_tmp_2024182T0336_03427_v01.nc: added points per component: {'MF_top': 39484, 'MFz_top': 39484, 'MFm_top': 39484}
# Skip awe_l7a_tmp_2024182T0509_03428_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T0642_03429_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T0815_03430_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T0948_03431_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T1121_03432_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T1254_03433_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T1427_03434_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T1600_03435_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T1733_03436_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T1906_03437_v01.nc: no valid lat/lon points inside Andes box
# Skip awe_l7a_tmp_2024182T2038_03438_v01.nc: no valid lat/lon points inside Andes box
# awe_l7a_tmp_2024182T2211_03439_v01.nc: added points per component: {'MF_top': 50000, 'MFz_top': 50000, 'MFm_top': 50000}
# awe_l7a_tmp_2024182T2343_03440_v01.nc: added points per component: {'MF_top': 40125, 'MFz_top': 40125, 'MFm_top': 40125}
#
# Saved stacked Andes plot to: C:\Users\domin\juwavelet\Momentum Flux\outputs_L7A_MF_cartopy_andes\stacked\MFz_MFm_stacked_andes_maps.png
#
# Saved Andes plots to: C:\Users\domin\juwavelet\Momentum Flux\outputs_L7A_MF_cartopy_andes
