# %%
# example_decompose2d_synthetic_packets_only.py
# Synthetic 2D field with a couple of Gaussian wave packets (NO Kelvin wake),
# then run juwavelet 2D CWT and plot: original + 2 reconstructed clusters.

from __future__ import annotations
import math
import string
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from dataclasses import dataclass
from typing import Sequence, Tuple

# Inline plotting if you're in Jupyter
try:
    get_ipython  # type: ignore[name-defined]
    # %matplotlib inline
except Exception:
    pass

from juwavelet import transform, utils

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update({
    "axes.labelsize": 16,
    "font.size": 16,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "legend.fontsize": 14,
    "figure.figsize": [2 * 6.94, 2 * 4.29],
})

# --------------------------
# Wave packets
# --------------------------
@dataclass
class WavePacket:
    """2D plane-wave packet with Gaussian envelope.
       A * exp(-((x-x0)^2/(2*sx^2) + (y-y0)^2/(2*sy^2))) * cos(kx*x + ky*y + phi)
       Provide (kx, ky) or (k, theta) in radians.
    """
    amplitude: float = 1.0
    kx: float | None = None
    ky: float | None = None
    k: float | None = None
    theta: float | None = None
    x0: float = 0.0
    y0: float = 0.0
    sx: float = 10.0
    sy: float = 10.0
    phi: float = 0.0

    def k_components(self) -> Tuple[float, float]:
        if self.kx is not None and self.ky is not None:
            return self.kx, self.ky
        if self.k is None or self.theta is None:
            raise ValueError("Provide either (kx, ky) or (k, theta) for WavePacket.")
        return self.k * math.cos(self.theta), self.k * math.sin(self.theta)

# --------------------------
# Grid + helpers
# --------------------------
def make_grid(nx: int, ny: int, dx: float, dy: float) -> Tuple[np.ndarray, np.ndarray]:
    x = np.arange(nx, dtype=float) * dx
    y = np.arange(ny, dtype=float) * dy
    X, Y = np.meshgrid(x, y)  # shapes (ny, nx)
    return X, Y

def packet_field(xs: np.ndarray, ys: np.ndarray, pkt: WavePacket) -> np.ndarray:
    kx, ky = pkt.k_components()
    gauss = np.exp(
        -(
            ((xs - pkt.x0) ** 2) / (2 * pkt.sx ** 2)
            + ((ys - pkt.y0) ** 2) / (2 * pkt.sy ** 2)
        )
    )
    phase = kx * xs + ky * ys + pkt.phi
    return pkt.amplitude * gauss * np.cos(phase)

# --------------------------
# Synthetic field (packets only)
# --------------------------
def generate_synthetic_field(
    nx: int = 256,
    ny: int = 256,
    dx: float = 2.0,
    dy: float = 2.0,
    packets: Sequence[WavePacket] | None = None,
    noise_sigma: float = 0.10,
    seed: int | None = 0,
) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Returns xs, ys, total_field with shapes (ny, nx).
    """
    rng = np.random.default_rng(seed) if seed is not None else np.random.default_rng()
    xs, ys = make_grid(nx, ny, dx, dy)
    Lx = nx * dx
    Ly = ny * dy

    if packets is None:
        packets = [
            WavePacket(
                amplitude=3.0,
                k=2 * math.pi / 120.0,
                theta=math.radians(45),
                x0=0.35 * Lx,
                y0=0.30 * Ly,
                sx=86,
                sy=56,
                phi=0.0,
            ),
            WavePacket(
                amplitude=2.5,
                k=2 * math.pi / 16.0,
                theta=math.radians(28),
                x0=0.60 * Lx,
                y0=0.55 * Ly,
                sx=38,
                sy=28,
                phi=0.6,
            ),
        ]

    field = np.zeros_like(xs)
    for pkt in packets:
        field += packet_field(xs, ys, pkt)

    if noise_sigma > 0:
        field = field + rng.normal(0.0, noise_sigma, size=field.shape)

    return xs, ys, field

# --------------------------
# Pipeline
# --------------------------
def run_pipeline():
    # Build synthetic field (NO Kelvin wake)
    xs2d, ys2d, wave = generate_synthetic_field(
        nx=256, ny=256, dx=2.0, dy=2.0, seed=0
    )

    x1d = xs2d[0, :].copy()
    y1d = ys2d[:, 0].copy()
    x1d -= x1d[0]
    dx = np.diff(x1d).mean()
    dy = np.diff(y1d).mean()

    # juwavelet expects (nx, ny), so transpose
    wave_xy = wave.T

    cwt = transform.decompose2d(
        wave_xy, dx=dx, dy=dy, s0=10, dj=0.25, js=20, jt=36, aspect=1, mode = 'cwt'
    )

    # Identify clusters (waves)
    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=.5, thr=0.25)

    decomposition = cwt["decomposition"]
    orig_decomp = decomposition.copy()

    # Overview CWT plot (optional but nice)
    cmap = matplotlib.cm.turbo
    norm = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.12), np.log(2.5), 10)), cmap.N
    )
    fig1, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap, norm=norm)

    # Choose two clusters to plot (strongest two by amps, if available)
    if isinstance(amps, np.ndarray) and amps.size >= 2:
        pick = np.argsort(amps)[::-1][:2].tolist()
    else:
        pick = [0, 1]

    # Plot: original + 2 reconstructed clusters
    fig2, axs = plt.subplots(1, 3, figsize=(16, 5))
    opts = {"cmap": "RdBu_r", "vmin": -5, "vmax": 5, "rasterized": True}

    axs[0].set_title("original")
    axs[0].pcolormesh(x1d, y1d, wave, shading="auto", **opts)

    for j, cl in enumerate(pick, start=1):
        decomposition[:] = orig_decomp
        decomposition[iwave != cl] = 0
        rec = transform.reconstruct2d(cwt)  # (nx, ny)

        axs[j].set_title(f"cluster {cl}")
        axs[j].pcolormesh(x1d, y1d, rec.T, shading="auto", **opts)

        # mark the cluster's peak location (in the reconstructed map)
        A = np.abs(rec.T)  # (ny, nx) in plotting orientation
        iy, ix = np.unravel_index(np.argmax(A), A.shape)
        axs[j].plot(x1d[ix], y1d[iy], "o", color="w", mec="k", ms=10)

        # print a tiny summary
        try:
            print(f"cluster {cl}: amp={amps[cl]:.3f}, peak|rec|={A[iy, ix]:.3f}")
        except Exception:
            print(f"cluster {cl}: peak|rec|={A[iy, ix]:.3f}")

    for ax in axs:
        ax.set_xlabel("distance (km)")
        ax.set_ylabel("distance (km)")

    # letter tags
    letterbox = {"boxstyle": "circle", "lw": 0.67, "facecolor": "white", "edgecolor": "black"}
    for ax, letter in zip(axs, string.ascii_lowercase):
        ax.text(0.06, 0.92, letter, transform=ax.transAxes,
                bbox=letterbox, va="top", ha="left", weight="bold")

    fig2.tight_layout()
    plt.show(fig1)
    plt.show(fig2)

# --------------------------
# Run
# --------------------------
run_pipeline()
# Out:
# C:\Users\domin\juwavelet\juwavelet\transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# C:\Users\domin\juwavelet\juwavelet\transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),
# ------------
# cluster= 0
# amplitude= 157.66718840199545 idx= (np.int64(14), np.int64(9), np.int64(90), np.int64(77))
# selected elements: 13689962
# ------------
# cluster= 1
# amplitude= 54.81728338593263 idx= (np.int64(3), np.int64(6), np.int64(153), np.int64(141))
# selected elements: 514722
# ------------
# cluster= 2
# amplitude= 13.198792149287113 idx= (np.int64(16), np.int64(35), np.int64(90), np.int64(77))
# selected elements: 2814895
# ------------
# cluster= 3
# amplitude= 2.5496890562867924 idx= (np.int64(11), np.int64(3), np.int64(0), np.int64(80))
# selected elements: 4971
# ------------
# cluster= 4
# amplitude= 2.4340316390170385 idx= (np.int64(10), np.int64(6), np.int64(0), np.int64(75))
# selected elements: 3457
# ------------
# cluster= 5
# amplitude= 1.9005505796117725 idx= (np.int64(9), np.int64(4), np.int64(0), np.int64(75))
# selected elements: 162697
# ------------
# cluster= 6
# amplitude= 1.3074936512714417 idx= (np.int64(12), np.int64(29), np.int64(0), np.int64(81))
# selected elements: 209574
# ------------
# cluster= 7
# amplitude= 1.2917636579637828 idx= (np.int64(13), np.int64(28), np.int64(0), np.int64(87))
# selected elements: 143551
# ------------
# cluster= 8
# amplitude= 1.2392570723240794 idx= (np.int64(11), np.int64(30), np.int64(1), np.int64(78))
# selected elements: 10646
# ------------
# cluster= 9
# amplitude= 1.1613392661960953 idx= (np.int64(6), np.int64(35), np.int64(0), np.int64(86))
# selected elements: 135159
# ------------
# cluster= 10
# amplitude= 1.1188364540158615 idx= (np.int64(10), np.int64(32), np.int64(0), np.int64(80))
# selected elements: 33662
# ------------
# cluster= 11
# amplitude= 0.9908900342761437 idx= (np.int64(2), np.int64(0), np.int64(0), np.int64(84))
# selected elements: 4153
# ------------
# cluster= 12
# amplitude= 0.923705966042842 idx= (np.int64(12), np.int64(34), np.int64(0), np.int64(106))
# selected elements: 10123
# ------------
# cluster= 13
# amplitude= 0.846022960808027 idx= (np.int64(0), np.int64(1), np.int64(157), np.int64(131))
# selected elements: 1596
# ------------
# cluster= 14
# amplitude= 0.8434289973840734 idx= (np.int64(3), np.int64(0), np.int64(2), np.int64(45))
# selected elements: 1587
# ------------
# cluster= 15
# amplitude= 0.7616174226489639 idx= (np.int64(3), np.int64(35), np.int64(2), np.int64(44))
# selected elements: 2497
# ------------
# cluster= 16
# amplitude= 0.7288326536032229 idx= (np.int64(14), np.int64(19), np.int64(0), np.int64(72))
# selected elements: 1931
# ------------
# cluster= 17
# amplitude= 0.7076959895460708 idx= (np.int64(5), np.int64(0), np.int64(0), np.int64(46))
# selected elements: 430
# ------------
# cluster= 18
# amplitude= 0.6889820383211626 idx= (np.int64(2), np.int64(23), np.int64(76), np.int64(192))
# selected elements: 32026
# ------------
# cluster= 19
# amplitude= 0.684598897192873 idx= (np.int64(17), np.int64(26), np.int64(0), np.int64(99))
# selected elements: 49524
# ------------
# cluster= 20
# amplitude= 0.6745273155198739 idx= (np.int64(1), np.int64(5), np.int64(195), np.int64(12))
# selected elements: 22061
# ------------
# cluster= 21
# amplitude= 0.6706550702965873 idx= (np.int64(4), np.int64(19), np.int64(32), np.int64(14))
# selected elements: 48477
# ------------
# cluster= 22
# amplitude= 0.6591674650753252 idx= (np.int64(0), np.int64(11), np.int64(156), np.int64(128))
# selected elements: 1801
# ------------
# cluster= 23
# amplitude= 0.6491974529556644 idx= (np.int64(1), np.int64(32), np.int64(19), np.int64(214))
# selected elements: 26552
# ------------
# cluster= 24
# amplitude= 0.6450061414673296 idx= (np.int64(0), np.int64(20), np.int64(150), np.int64(46))
# selected elements: 12063
# ------------
# cluster= 25
# amplitude= 0.6384190611591768 idx= (np.int64(2), np.int64(25), np.int64(114), np.int64(128))
# selected elements: 55406
# ------------
# cluster= 26
# amplitude= 0.6359155783564322 idx= (np.int64(6), np.int64(21), np.int64(50), np.int64(155))
# selected elements: 60589
# ------------
# cluster= 27
# amplitude= 0.6357314798011152 idx= (np.int64(1), np.int64(13), np.int64(66), np.int64(71))
# selected elements: 16265
# ------------
# cluster= 28
# amplitude= 0.6341416662631716 idx= (np.int64(1), np.int64(28), np.int64(101), np.int64(22))
# selected elements: 32395
# ------------
# cluster= 29
# amplitude= 0.6256959304264913 idx= (np.int64(8), np.int64(10), np.int64(100), np.int64(98))
# selected elements: 55372
# ------------
# cluster= 30
# amplitude= 0.6236684070717905 idx= (np.int64(0), np.int64(12), np.int64(131), np.int64(187))
# selected elements: 6938
# ------------
# cluster= 31
# amplitude= 0.6232350480052073 idx= (np.int64(2), np.int64(1), np.int64(1), np.int64(49))
# selected elements: 1059
# ------------
# cluster= 32
# amplitude= 0.617369955651246 idx= (np.int64(0), np.int64(9), np.int64(134), np.int64(115))
# selected elements: 280
# ------------
# cluster= 33
# amplitude= 0.6133459461685326 idx= (np.int64(2), np.int64(30), np.int64(67), np.int64(15))
# selected elements: 12172
# ------------
# cluster= 34
# amplitude= 0.60937669431591 idx= (np.int64(4), np.int64(10), np.int64(184), np.int64(209))
# selected elements: 56504
# ------------
# cluster= 35
# amplitude= 0.6073478032687878 idx= (np.int64(1), np.int64(23), np.int64(65), np.int64(161))
# selected elements: 8820
# ------------
# cluster= 36
# amplitude= 0.606385474090483 idx= (np.int64(3), np.int64(29), np.int64(235), np.int64(46))
# selected elements: 146941
# ------------
# cluster= 37
# amplitude= 0.6040602622226181 idx= (np.int64(0), np.int64(20), np.int64(128), np.int64(212))
# selected elements: 4258
# ------------
# cluster= 38
# amplitude= 0.6037390677048381 idx= (np.int64(0), np.int64(25), np.int64(208), np.int64(240))
# selected elements: 4929
# ------------
# cluster= 39
# amplitude= 0.6034830286807584 idx= (np.int64(2), np.int64(10), np.int64(174), np.int64(56))
# selected elements: 33036
# ------------
# cluster= 40
# amplitude= 0.6018620229599474 idx= (np.int64(0), np.int64(32), np.int64(175), np.int64(71))
# selected elements: 4599
# ------------
# cluster= 41
# amplitude= 0.5979556660067207 idx= (np.int64(0), np.int64(9), np.int64(15), np.int64(217))
# selected elements: 23543
# ------------
# cluster= 42
# amplitude= 0.5950143539994402 idx= (np.int64(0), np.int64(1), np.int64(142), np.int64(151))
# selected elements: 346
# ------------
# cluster= 43
# amplitude= 0.593853812469694 idx= (np.int64(5), np.int64(9), np.int64(185), np.int64(205))
# selected elements: 2681
# ------------
# cluster= 44
# amplitude= 0.5885674379187149 idx= (np.int64(4), np.int64(22), np.int64(81), np.int64(72))
# selected elements: 5086
# ------------
# cluster= 45
# amplitude= 0.5863692758495318 idx= (np.int64(0), np.int64(0), np.int64(46), np.int64(133))
# selected elements: 5258
# ------------
# cluster= 46
# amplitude= 0.5853998996038691 idx= (np.int64(2), np.int64(35), np.int64(145), np.int64(156))
# selected elements: 13865
# ------------
# cluster= 47
# amplitude= 0.5853441702027825 idx= (np.int64(0), np.int64(35), np.int64(46), np.int64(132))
# selected elements: 2386
# ------------
# cluster= 48
# amplitude= 0.5848792603926667 idx= (np.int64(2), np.int64(30), np.int64(149), np.int64(181))
# selected elements: 28412
# ------------
# cluster= 49
# amplitude= 0.5840655668338399 idx= (np.int64(1), np.int64(29), np.int64(158), np.int64(160))
# selected elements: 9323
# ------------
# cluster= 50
# amplitude= 0.5800035173660806 idx= (np.int64(5), np.int64(33), np.int64(146), np.int64(105))
# selected elements: 34483
# ------------
# cluster= 51
# amplitude= 0.5751452926902396 idx= (np.int64(1), np.int64(16), np.int64(70), np.int64(118))
# selected elements: 5493
# ------------
# cluster= 52
# amplitude= 0.5747634731265718 idx= (np.int64(0), np.int64(21), np.int64(24), np.int64(220))
# selected elements: 9847
# ------------
# cluster= 53
# amplitude= 0.5739667433377889 idx= (np.int64(0), np.int64(10), np.int64(156), np.int64(117))
# selected elements: 108
# ------------
# cluster= 54
# amplitude= 0.5726097573504159 idx= (np.int64(0), np.int64(16), np.int64(176), np.int64(249))
# selected elements: 12450
# ------------
# cluster= 55
# amplitude= 0.5716118081512388 idx= (np.int64(8), np.int64(35), np.int64(0), np.int64(38))
# selected elements: 4365
# ------------
# cluster= 56
# amplitude= 0.5702609921353106 idx= (np.int64(2), np.int64(20), np.int64(199), np.int64(215))
# selected elements: 16632
# ------------
# cluster= 57
# amplitude= 0.5699358400796223 idx= (np.int64(0), np.int64(31), np.int64(235), np.int64(223))
# selected elements: 5258
# ------------
# cluster= 58
# amplitude= 0.5687987132246326 idx= (np.int64(5), np.int64(27), np.int64(183), np.int64(147))
# selected elements: 39424
# ------------
# cluster= 59
# amplitude= 0.5678412280306906 idx= (np.int64(2), np.int64(35), np.int64(172), np.int64(145))
# selected elements: 3483
# ------------
# cluster= 60
# amplitude= 0.5670012572418185 idx= (np.int64(1), np.int64(34), np.int64(222), np.int64(120))
# selected elements: 7450
# ------------
# cluster= 61
# amplitude= 0.5640371748277697 idx= (np.int64(5), np.int64(19), np.int64(183), np.int64(111))
# selected elements: 61060
# ------------
# cluster= 62
# amplitude= 0.5639513567238411 idx= (np.int64(1), np.int64(20), np.int64(86), np.int64(148))
# selected elements: 5216
# ------------
# cluster= 63
# amplitude= 0.5627399663444042 idx= (np.int64(1), np.int64(11), np.int64(41), np.int64(95))
# selected elements: 12478
# ------------
# cluster= 64
# amplitude= 0.5613228779927273 idx= (np.int64(3), np.int64(27), np.int64(208), np.int64(120))
# selected elements: 10898
# ------------
# cluster= 65
# amplitude= 0.558842521379982 idx= (np.int64(1), np.int64(34), np.int64(68), np.int64(228))
# selected elements: 17441
# ------------
# cluster= 66
# amplitude= 0.5586803959471999 idx= (np.int64(2), np.int64(21), np.int64(248), np.int64(205))
# selected elements: 10967
# ------------
# cluster= 67
# amplitude= 0.556860692074438 idx= (np.int64(4), np.int64(17), np.int64(18), np.int64(204))
# selected elements: 15342
# ------------
# cluster= 68
# amplitude= 0.5557208614369112 idx= (np.int64(0), np.int64(4), np.int64(90), np.int64(202))
# selected elements: 1249
# ------------
# cluster= 69
# amplitude= 0.5541169023183937 idx= (np.int64(5), np.int64(18), np.int64(159), np.int64(47))
# selected elements: 25922
# ------------
# cluster= 70
# amplitude= 0.5537333792215499 idx= (np.int64(3), np.int64(12), np.int64(50), np.int64(41))
# selected elements: 13739
# ------------
# cluster= 71
# amplitude= 0.5537326133530573 idx= (np.int64(1), np.int64(32), np.int64(13), np.int64(53))
# selected elements: 7046
# ------------
# cluster= 72
# amplitude= 0.5531461818915894 idx= (np.int64(0), np.int64(32), np.int64(129), np.int64(150))
# selected elements: 2487
# ------------
# cluster= 73
# amplitude= 0.5527390886370769 idx= (np.int64(0), np.int64(1), np.int64(15), np.int64(11))
# selected elements: 1746
# ------------
# cluster= 74
# amplitude= 0.5525636094241461 idx= (np.int64(10), np.int64(18), np.int64(42), np.int64(111))
# selected elements: 9293
# ------------
# cluster= 75
# amplitude= 0.5522343088360945 idx= (np.int64(0), np.int64(10), np.int64(39), np.int64(14))
# selected elements: 1716
# ------------
# cluster= 76
# amplitude= 0.5521874832519709 idx= (np.int64(0), np.int64(24), np.int64(223), np.int64(45))
# selected elements: 8020
# ------------
# cluster= 77
# amplitude= 0.549181981785854 idx= (np.int64(0), np.int64(19), np.int64(197), np.int64(18))
# selected elements: 5368
# ------------
# cluster= 78
# amplitude= 0.5471874861070445 idx= (np.int64(1), np.int64(32), np.int64(66), np.int64(215))
# selected elements: 17070
# ------------
# cluster= 79
# amplitude= 0.5466065370954991 idx= (np.int64(1), np.int64(29), np.int64(98), np.int64(52))
# selected elements: 7789
# ------------
# cluster= 80
# amplitude= 0.5461110672895212 idx= (np.int64(9), np.int64(5), np.int64(146), np.int64(71))
# selected elements: 14135
# ------------
# cluster= 81
# amplitude= 0.5448207059991094 idx= (np.int64(0), np.int64(34), np.int64(105), np.int64(173))
# selected elements: 964
# ------------
# cluster= 82
# amplitude= 0.5439991637410418 idx= (np.int64(1), np.int64(12), np.int64(150), np.int64(145))
# selected elements: 351
# ------------
# cluster= 83
# amplitude= 0.5435165411618034 idx= (np.int64(8), np.int64(25), np.int64(51), np.int64(118))
# selected elements: 61128
# ------------
# cluster= 84
# amplitude= 0.542524810343594 idx= (np.int64(3), np.int64(18), np.int64(58), np.int64(69))
# selected elements: 27704
# ------------
# cluster= 85
# amplitude= 0.5424611594898793 idx= (np.int64(0), np.int64(19), np.int64(112), np.int64(24))
# selected elements: 8817
# ------------
# cluster= 86
# amplitude= 0.5423926015779221 idx= (np.int64(1), np.int64(34), np.int64(238), np.int64(152))
# selected elements: 15366
# ------------
# cluster= 87
# amplitude= 0.5419949834404634 idx= (np.int64(8), np.int64(8), np.int64(149), np.int64(58))
# selected elements: 10456
# ------------
# cluster= 88
# amplitude= 0.5414835206521422 idx= (np.int64(1), np.int64(11), np.int64(232), np.int64(35))
# selected elements: 6359
# ------------
# cluster= 89
# amplitude= 0.5410339298527447 idx= (np.int64(3), np.int64(12), np.int64(11), np.int64(236))
# selected elements: 19289
# ------------
# cluster= 90
# amplitude= 0.5387916094385868 idx= (np.int64(4), np.int64(29), np.int64(160), np.int64(85))
# selected elements: 22891
# ------------
# cluster= 91
# amplitude= 0.5386679548266842 idx= (np.int64(4), np.int64(31), np.int64(41), np.int64(172))
# selected elements: 25040
# ------------
# cluster= 92
# amplitude= 0.5384934453256205 idx= (np.int64(1), np.int64(14), np.int64(46), np.int64(148))
# selected elements: 10180
# ------------
# cluster= 93
# amplitude= 0.5383383234171439 idx= (np.int64(0), np.int64(30), np.int64(203), np.int64(157))
# selected elements: 14805
# ------------
# cluster= 94
# amplitude= 0.5380216788194051 idx= (np.int64(4), np.int64(32), np.int64(138), np.int64(41))
# selected elements: 12172
# ------------
# cluster= 95
# amplitude= 0.5367165648798722 idx= (np.int64(1), np.int64(16), np.int64(38), np.int64(243))
# selected elements: 5593
# ------------
# cluster= 96
# amplitude= 0.5347707214987888 idx= (np.int64(0), np.int64(28), np.int64(89), np.int64(148))
# selected elements: 4681
# ------------
# cluster= 97
# amplitude= 0.534748544023558 idx= (np.int64(0), np.int64(19), np.int64(112), np.int64(162))
# selected elements: 2709
# ------------
# cluster= 98
# amplitude= 0.5347180832895396 idx= (np.int64(3), np.int64(32), np.int64(94), np.int64(212))
# selected elements: 7716
# ------------
# cluster= 99
# amplitude= 0.5340173808728751 idx= (np.int64(4), np.int64(8), np.int64(101), np.int64(16))
# selected elements: 26612
# ------------
# cluster= 100
# amplitude= 0.5331914493177472 idx= (np.int64(1), np.int64(0), np.int64(161), np.int64(7))
# selected elements: 3053
# ------------
# cluster= 101
# amplitude= 0.5330357916763745 idx= (np.int64(0), np.int64(6), np.int64(110), np.int64(30))
# selected elements: 4696
# ------------
# cluster= 102
# amplitude= 0.5306634738127818 idx= (np.int64(3), np.int64(16), np.int64(207), np.int64(177))
# selected elements: 23079
# ------------
# cluster= 103
# amplitude= 0.5303569572014344 idx= (np.int64(0), np.int64(23), np.int64(4), np.int64(14))
# selected elements: 4610
# ------------
# cluster= 104
# amplitude= 0.5294360697172426 idx= (np.int64(0), np.int64(7), np.int64(249), np.int64(63))
# selected elements: 5437
# ------------
# cluster= 105
# amplitude= 0.5289169102347703 idx= (np.int64(8), np.int64(27), np.int64(71), np.int64(78))
# selected elements: 53296
# ------------
# cluster= 106
# amplitude= 0.5278183023955645 idx= (np.int64(0), np.int64(4), np.int64(71), np.int64(174))
# selected elements: 5517
# ------------
# cluster= 107
# amplitude= 0.5264422961833859 idx= (np.int64(0), np.int64(19), np.int64(95), np.int64(55))
# selected elements: 4137
# ------------
# cluster= 108
# amplitude= 0.5258719625557681 idx= (np.int64(0), np.int64(14), np.int64(157), np.int64(129))
# selected elements: 3132
# ------------
# cluster= 109
# amplitude= 0.5253152666957294 idx= (np.int64(3), np.int64(20), np.int64(84), np.int64(120))
# selected elements: 1709
# ------------
# cluster= 110
# amplitude= 0.524917758575411 idx= (np.int64(6), np.int64(10), np.int64(197), np.int64(32))
# selected elements: 18133
# ------------
# cluster= 111
# amplitude= 0.5241083306588311 idx= (np.int64(4), np.int64(30), np.int64(203), np.int64(60))
# selected elements: 9949
# ------------
# cluster= 112
# amplitude= 0.523744733762396 idx= (np.int64(0), np.int64(17), np.int64(85), np.int64(25))
# selected elements: 416
# ------------
# cluster= 113
# amplitude= 0.5233405858310256 idx= (np.int64(1), np.int64(35), np.int64(161), np.int64(8))
# selected elements: 8518
# ------------
# cluster= 114
# amplitude= 0.52270216393042 idx= (np.int64(4), np.int64(14), np.int64(245), np.int64(173))
# selected elements: 20128
# ------------
# cluster= 115
# amplitude= 0.5222134837020479 idx= (np.int64(1), np.int64(16), np.int64(15), np.int64(150))
# selected elements: 15670
# ------------
# cluster= 116
# amplitude= 0.5216961909604446 idx= (np.int64(3), np.int64(13), np.int64(30), np.int64(196))
# selected elements: 2666
# ------------
# cluster= 117
# amplitude= 0.5215685948558678 idx= (np.int64(0), np.int64(25), np.int64(73), np.int64(155))
# selected elements: 229
# ------------
# cluster= 118
# amplitude= 0.5203266527695133 idx= (np.int64(1), np.int64(29), np.int64(112), np.int64(130))
# selected elements: 713
# ------------
# cluster= 119
# amplitude= 0.5197342551480807 idx= (np.int64(2), np.int64(18), np.int64(154), np.int64(187))
# selected elements: 28793
# ------------
# cluster= 120
# amplitude= 0.5193058978479872 idx= (np.int64(1), np.int64(11), np.int64(50), np.int64(227))
# selected elements: 4969
# ------------
# cluster= 121
# amplitude= 0.518913398039846 idx= (np.int64(2), np.int64(27), np.int64(235), np.int64(171))
# selected elements: 33670
# ------------
# cluster= 122
# amplitude= 0.5180571292943803 idx= (np.int64(5), np.int64(25), np.int64(171), np.int64(140))
# selected elements: 25317
# ------------
# cluster= 123
# amplitude= 0.5180156308412998 idx= (np.int64(7), np.int64(21), np.int64(242), np.int64(113))
# selected elements: 28740
# ------------
# cluster= 124
# amplitude= 0.5178627673757122 idx= (np.int64(5), np.int64(0), np.int64(97), np.int64(185))
# selected elements: 12103
# ------------
# cluster= 125
# amplitude= 0.5175758604863883 idx= (np.int64(1), np.int64(6), np.int64(33), np.int64(211))
# selected elements: 4210
# ------------
# cluster= 126
# amplitude= 0.5175089135376708 idx= (np.int64(0), np.int64(23), np.int64(46), np.int64(12))
# selected elements: 2140
# ------------
# cluster= 127
# amplitude= 0.5174974973028849 idx= (np.int64(3), np.int64(16), np.int64(94), np.int64(28))
# selected elements: 8959
# ------------
# cluster= 128
# amplitude= 0.5173829813888875 idx= (np.int64(0), np.int64(31), np.int64(191), np.int64(197))
# selected elements: 2619
# ------------
# cluster= 129
# amplitude= 0.5172706078737069 idx= (np.int64(2), np.int64(0), np.int64(160), np.int64(203))
# selected elements: 3792
# ------------
# cluster= 130
# amplitude= 0.5169482048207411 idx= (np.int64(1), np.int64(25), np.int64(198), np.int64(94))
# selected elements: 6941
# ------------
# cluster= 131
# amplitude= 0.5165678196387476 idx= (np.int64(0), np.int64(7), np.int64(121), np.int64(46))
# selected elements: 9128
# ------------
# cluster= 132
# amplitude= 0.5162199604041714 idx= (np.int64(2), np.int64(35), np.int64(185), np.int64(226))
# selected elements: 20825
# ------------
# cluster= 133
# amplitude= 0.515991137961999 idx= (np.int64(2), np.int64(1), np.int64(209), np.int64(126))
# selected elements: 935
# ------------
# cluster= 134
# amplitude= 0.515169398026867 idx= (np.int64(1), np.int64(24), np.int64(176), np.int64(30))
# selected elements: 12662
# ------------
# cluster= 135
# amplitude= 0.5147592560351387 idx= (np.int64(1), np.int64(10), np.int64(155), np.int64(214))
# selected elements: 5717
# ------------
# cluster= 136
# amplitude= 0.5147080871359859 idx= (np.int64(0), np.int64(10), np.int64(189), np.int64(236))
# selected elements: 1873
# ------------
# cluster= 137
# amplitude= 0.5140823158764122 idx= (np.int64(1), np.int64(0), np.int64(189), np.int64(229))
# selected elements: 4839
# ------------
# cluster= 138
# amplitude= 0.5140553138435473 idx= (np.int64(0), np.int64(2), np.int64(240), np.int64(136))
# selected elements: 9295
# ------------
# cluster= 139
# amplitude= 0.5140487270218003 idx= (np.int64(0), np.int64(30), np.int64(18), np.int64(46))
# selected elements: 2082
# ------------
# cluster= 140
# amplitude= 0.5131738266036526 idx= (np.int64(1), np.int64(9), np.int64(96), np.int64(54))
# selected elements: 554
# ------------
# cluster= 141
# amplitude= 0.5126766741129111 idx= (np.int64(0), np.int64(17), np.int64(215), np.int64(148))
# selected elements: 6497
# ------------
# cluster= 142
# amplitude= 0.5124520622511539 idx= (np.int64(0), np.int64(21), np.int64(197), np.int64(19))
# selected elements: 923
# ------------
# cluster= 143
# amplitude= 0.5107797892660947 idx= (np.int64(0), np.int64(0), np.int64(106), np.int64(174))
# selected elements: 330
# ------------
# cluster= 144
# amplitude= 0.5101677529983828 idx= (np.int64(0), np.int64(10), np.int64(158), np.int64(51))
# selected elements: 2566
# ------------
# cluster= 145
# amplitude= 0.509064749543949 idx= (np.int64(4), np.int64(2), np.int64(119), np.int64(247))
# selected elements: 16963
# ------------
# cluster= 146
# amplitude= 0.5090004808342123 idx= (np.int64(4), np.int64(27), np.int64(100), np.int64(24))
# selected elements: 3479
# ------------
# cluster= 147
# amplitude= 0.5088836232127506 idx= (np.int64(5), np.int64(35), np.int64(97), np.int64(185))
# selected elements: 15900
# ------------
# cluster= 148
# amplitude= 0.5086377912710256 idx= (np.int64(1), np.int64(6), np.int64(47), np.int64(138))
# selected elements: 3621
# ------------
# cluster= 149
# amplitude= 0.5072766681515684 idx= (np.int64(2), np.int64(20), np.int64(103), np.int64(240))
# selected elements: 12489
# ------------
# cluster= 150
# amplitude= 0.5069136532597192 idx= (np.int64(0), np.int64(7), np.int64(24), np.int64(231))
# selected elements: 832
# ------------
# cluster= 151
# amplitude= 0.5061327193166736 idx= (np.int64(3), np.int64(23), np.int64(87), np.int64(66))
# selected elements: 3661
# ------------
# cluster= 152
# amplitude= 0.5056445924949613 idx= (np.int64(1), np.int64(33), np.int64(126), np.int64(84))
# selected elements: 5624
# ------------
# cluster= 153
# amplitude= 0.5055640953870673 idx= (np.int64(0), np.int64(2), np.int64(142), np.int64(105))
# selected elements: 164
# ------------
# cluster= 154
# amplitude= 0.5047324693260328 idx= (np.int64(0), np.int64(12), np.int64(19), np.int64(43))
# selected elements: 3773
# ------------
# cluster= 155
# amplitude= 0.5044525266714616 idx= (np.int64(2), np.int64(28), np.int64(45), np.int64(88))
# selected elements: 13828
# ------------
# cluster= 156
# amplitude= 0.5032692941466674 idx= (np.int64(1), np.int64(8), np.int64(185), np.int64(188))
# selected elements: 1822
# ------------
# cluster= 157
# amplitude= 0.5028262255691825 idx= (np.int64(0), np.int64(1), np.int64(119), np.int64(153))
# selected elements: 807
# ------------
# cluster= 158
# amplitude= 0.5026691716777861 idx= (np.int64(1), np.int64(26), np.int64(112), np.int64(162))
# selected elements: 4264
# ------------
# cluster= 159
# amplitude= 0.502530926687577 idx= (np.int64(0), np.int64(32), np.int64(73), np.int64(190))
# selected elements: 1763
# ------------
# cluster= 160
# amplitude= 0.5024465869999438 idx= (np.int64(1), np.int64(8), np.int64(90), np.int64(244))
# selected elements: 2740
# ------------
# cluster= 161
# amplitude= 0.5024220610733531 idx= (np.int64(3), np.int64(29), np.int64(245), np.int64(104))
# selected elements: 7798
# ------------
# cluster= 162
# amplitude= 0.5006032609026544 idx= (np.int64(0), np.int64(29), np.int64(167), np.int64(66))
# selected elements: 5214
# C:\Users\domin\juwavelet\juwavelet\utils.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   hl = 1. / np.sin(theta[sel_t[j]])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 20.11it/s]
# C:\Users\domin\juwavelet\juwavelet\utils.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# cluster 0: amp=157.667, peak|rec|=2.932
# cluster 1: amp=54.817, peak|rec|=2.350

# %%
# example_decompose2d_synthetic_packets_only.py
# Synthetic 2D field with a couple of Gaussian wave packets (NO Kelvin wake),
# then run juwavelet 2D CWT and plot:
#   original + 2 reconstructed clusters + phase maps (dominant scale, theta) for each cluster

from __future__ import annotations
import math
import string
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from dataclasses import dataclass
from typing import Sequence, Tuple

# Inline plotting if you're in Jupyter
try:
    get_ipython  # type: ignore[name-defined]
    # %matplotlib inline
except Exception:
    pass

from juwavelet import transform, utils

# --------------------------
# Plot style
# --------------------------
matplotlib.rcParams.update({
    "axes.labelsize": 16,
    "font.size": 16,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "legend.fontsize": 14,
    "figure.figsize": [2 * 6.94, 2 * 4.29],
})

# --------------------------
# Wave packets
# --------------------------
@dataclass
class WavePacket:
    """2D plane-wave packet with Gaussian envelope.
       A * exp(-((x-x0)^2/(2*sx^2) + (y-y0)^2/(2*sy^2))) * cos(kx*x + ky*y + phi)
       Provide (kx, ky) or (k, theta) in radians.
    """
    amplitude: float = 1.0
    kx: float | None = None
    ky: float | None = None
    k: float | None = None
    theta: float | None = None
    x0: float = 0.0
    y0: float = 0.0
    sx: float = 10.0
    sy: float = 10.0
    phi: float = 0.0

    def k_components(self) -> Tuple[float, float]:
        if self.kx is not None and self.ky is not None:
            return self.kx, self.ky
        if self.k is None or self.theta is None:
            raise ValueError("Provide either (kx, ky) or (k, theta) for WavePacket.")
        return self.k * math.cos(self.theta), self.k * math.sin(self.theta)

# --------------------------
# Grid + helpers
# --------------------------
def make_grid(nx: int, ny: int, dx: float, dy: float) -> Tuple[np.ndarray, np.ndarray]:
    x = np.arange(nx, dtype=float) * dx
    y = np.arange(ny, dtype=float) * dy
    X, Y = np.meshgrid(x, y)  # shapes (ny, nx)
    return X, Y

def packet_field(xs: np.ndarray, ys: np.ndarray, pkt: WavePacket) -> np.ndarray:
    kx, ky = pkt.k_components()
    gauss = np.exp(
        -(
            ((xs - pkt.x0) ** 2) / (2 * pkt.sx ** 2)
            + ((ys - pkt.y0) ** 2) / (2 * pkt.sy ** 2)
        )
    )
    phase = kx * xs + ky * ys + pkt.phi
    return pkt.amplitude * gauss * np.cos(phase)

# --------------------------
# Synthetic field (packets only)
# --------------------------
def generate_synthetic_field(
    nx: int = 256,
    ny: int = 256,
    dx: float = 2.0,
    dy: float = 2.0,
    packets: Sequence[WavePacket] | None = None,
    noise_sigma: float = 0.10,
    seed: int | None = 0,
) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Returns xs, ys, total_field with shapes (ny, nx).
    """
    rng = np.random.default_rng(seed) if seed is not None else np.random.default_rng()
    xs, ys = make_grid(nx, ny, dx, dy)
    Lx = nx * dx
    Ly = ny * dy

    if packets is None:
        packets = [
            WavePacket(
                amplitude=3.0,
                k=2 * math.pi / 120.0,
                theta=math.radians(45),
                x0=0.35 * Lx,
                y0=0.30 * Ly,
                sx=86,
                sy=56,
                phi=0.0,
            ),
            WavePacket(
                amplitude=2.5,
                k=2 * math.pi / 16,
                theta=math.radians(28),
                x0=0.60 * Lx,
                y0=0.55 * Ly,
                sx=38,
                sy=28,
                phi=0.6,
            ),
        ]

    field = np.zeros_like(xs)
    for pkt in packets:
        field += packet_field(xs, ys, pkt)

    if noise_sigma > 0:
        field = field + rng.normal(0.0, noise_sigma, size=field.shape)

    return xs, ys, field

# --------------------------
# Helpers for phase plotting
# --------------------------
def phase_map_for_cluster(cwt: dict, iwave: np.ndarray, idxs, cluster_id: int) -> tuple[np.ndarray, float, float]:
    """
    Returns:
      phase_plot (ny, nx) with NaN outside the cluster mask at dominant (scale, theta),
      wavelength_x_dom, wavelength_y_dom
    """
    # dominant indices for this cluster
    udx = idxs[cluster_id]  # typically (a_scale, a_theta, ix, iy)
    a1 = int(udx[0])
    a2 = int(udx[1])

    coeff = cwt["decomposition"][a1, a2, :, :]  # (nx, ny), complex
    ph = np.angle(coeff)                        # (nx, ny) in wave_xy orientation

    # keep only coefficients that belong to this cluster at the dominant (a1,a2)
    mask = (iwave[a1, a2, :, :] == cluster_id)  # (nx, ny)
    ph_masked = np.full_like(ph, np.nan, dtype=float)
    ph_masked[mask] = ph[mask]

    # return in plotting orientation (ny, nx)
    ph_plot = ph_masked.T

    wx = float(cwt["wavelength_x"][a1, a2])
    wy = float(cwt["wavelength_y"][a1, a2])
    return ph_plot, wx, wy

# --------------------------
# Pipeline
# --------------------------
def run_pipeline():
    # Build synthetic field (NO Kelvin wake)
    xs2d, ys2d, wave = generate_synthetic_field(
        nx=256, ny=256, dx=2.0, dy=2.0, seed=0
    )

    x1d = xs2d[0, :].copy()
    y1d = ys2d[:, 0].copy()
    x1d -= x1d[0]
    dx = np.diff(x1d).mean()
    dy = np.diff(y1d).mean()

    # juwavelet expects (nx, ny), so transpose
    wave_xy = wave.T

    cwt = transform.decompose2d(
        wave_xy, dx=dx, dy=dy, s0=10, dj=0.25, js=20, jt=36, aspect=1, mode = 'cwt'
    )

    # Identify clusters (waves)
    amps, idxs, iwave = utils.identify_cluster2d(cwt, min_amp=50, thr=0.25)

    decomposition = cwt["decomposition"]          # (js, jt, nx, ny), complex
    orig_decomp = decomposition.copy()
    thetas = cwt["theta"]                         # (jt,)
    periods = cwt["period"]                       # (js,) overall wavelength/scale

    # Overview CWT plot (optional)
    cmap = matplotlib.cm.turbo
    norm = matplotlib.colors.BoundaryNorm(
        np.exp(np.linspace(np.log(0.12), np.log(2.5), 10)), cmap.N
    )
    fig1, _ = utils.plot_decomposition2d(cwt, redux_s=2, redux_t=2, cmap=cmap, norm=norm)

    # Pick two strongest clusters
    if isinstance(amps, np.ndarray) and amps.size >= 2:
        pick = np.argsort(amps)[::-1][:2].tolist()
    else:
        pick = [0, 1]

    # --- Main figure: top row amplitude, bottom row phase
    fig2, axs = plt.subplots(2, 3, figsize=(16, 9))
    cmap_amp = "RdBu_r"
    cmap_ph = "twilight"  # cyclic, good for phase
    opts_amp = {"cmap": cmap_amp, "vmin": -5, "vmax": 5, "rasterized": True}
    opts_ph = {"cmap": cmap_ph, "vmin": -np.pi, "vmax": np.pi, "rasterized": True}

    # original (top-left)
    axs[0, 0].set_title("original")
    im0 = axs[0, 0].pcolormesh(x1d, y1d, wave, shading="auto", **opts_amp)
    cb0 = fig2.colorbar(im0, ax=axs[0, 0], fraction=0.046, pad=0.04)
    cb0.set_label("amplitude (arb)")

    # bottom-left: just a label panel
    axs[1, 0].axis("off")
    axs[1, 0].text(
        0.5, 0.5, "phase maps\n(at dominant λ, θ)",
        ha="center", va="center", transform=axs[1, 0].transAxes
    )

    for col, cl in enumerate(pick, start=1):
        if not (isinstance(idxs, (list, tuple)) and cl < len(idxs)):
            axs[0, col].set_title(f"cluster {cl} not found")
            axs[0, col].axis("off")
            axs[1, col].axis("off")
            continue

        # Dominant index for this cluster: (iscale, itheta, ix_peak, iy_peak) in (nx, ny) indexing
        udx = idxs[cl]
        iscale, itheta = int(udx[0]), int(udx[1])

        lam = float(periods[iscale])                      # km
        theta_deg = float(np.degrees(thetas[itheta]))     # degrees

        # --- Reconstruct this cluster (amplitude plot)
        decomposition[:] = orig_decomp
        decomposition[iwave != cl] = 0
        rec = transform.reconstruct2d(cwt)  # (nx, ny), real

        axs[0, col].set_title(rf"cluster {cl}:  λ={lam:5.1f} km,  θ={theta_deg:5.1f}°")
        imA = axs[0, col].pcolormesh(x1d, y1d, rec.T, shading="auto", **opts_amp)
        cbA = fig2.colorbar(imA, ax=axs[0, col], fraction=0.046, pad=0.04)
        cbA.set_label("recon (arb)")

        # mark peak location in the reconstruction
        Aabs = np.abs(rec.T)  # (ny, nx)
        iy_max, ix_max = np.unravel_index(np.argmax(Aabs), Aabs.shape)
        axs[0, col].plot(x1d[ix_max], y1d[iy_max], "o", color="w", mec="k", ms=10)

        # --- Phase at dominant (iscale, itheta)
        coeff_dom = orig_decomp[iscale, itheta, :, :]          # (nx, ny), complex
        coeff_dom_plot = coeff_dom.T                           # (ny, nx) for plotting
        phase_dom = np.angle(coeff_dom_plot)                   # wrapped [-pi, pi]

        # mask: only keep pixels belonging to this cluster at (iscale, itheta)
        mask = (iwave[iscale, itheta, :, :].T == cl)           # (ny, nx)

        # Choose a reference phase from the strongest coefficient INSIDE the mask
        # (this makes the phase map visually consistent: peak -> phase 0)
        coeff_in = np.where(mask, coeff_dom_plot, np.nan + 1j*np.nan)
        # amplitude of coeffs, ignoring nans
        amp_in = np.abs(coeff_in)
        if np.all(~np.isfinite(amp_in)):
            # nothing to show
            axs[1, col].set_title("phase (no support)")
            axs[1, col].axis("off")
            continue

        iy_ref, ix_ref = np.unravel_index(np.nanargmax(amp_in), amp_in.shape)
        phi0 = np.angle(coeff_dom_plot[iy_ref, ix_ref])        # reference phase

        # re-reference phase: subtract phi0 (equivalently multiply by exp(-i phi0))
        phase_ref = np.angle(coeff_dom_plot * np.exp(-1j * phi0))

        # apply mask
        phase_plot = phase_ref.copy()
        phase_plot[~mask] = np.nan

        axs[1, col].set_title(rf"phase:  λ={lam:5.1f} km,  θ={theta_deg:5.1f}°")
        imP = axs[1, col].pcolormesh(x1d, y1d, phase_plot, shading="auto", **opts_ph)
        cbP = fig2.colorbar(imP, ax=axs[1, col], fraction=0.046, pad=0.04)
        cbP.set_label("phase (rad)")

        # mark reference point
        axs[1, col].plot(x1d[ix_ref], y1d[iy_ref], "x", color="k", ms=10, mew=2)

        # console summary
        print(
            f"cluster {cl}: amp={amps[cl]:.3f}, λ={lam:.2f} km, θ={theta_deg:.2f} deg, "
            f"ref_phase(phi0)={phi0:.3f} rad"
        )

    for r in range(2):
        for c in range(3):
            if axs[r, c].axison:
                axs[r, c].set_xlabel("distance (km)")
                axs[r, c].set_ylabel("distance (km)")

    fig2.tight_layout()
    plt.show(fig1)
    plt.show(fig2)

# --------------------------
# Run
# --------------------------
run_pipeline()
# Out:
# ------------
# cluster= 0
# amplitude= 157.66718840199545 idx= (np.int64(14), np.int64(9), np.int64(90), np.int64(77))
# selected elements: 13689962
# ------------
# cluster= 1
# amplitude= 54.81728338593263 idx= (np.int64(3), np.int64(6), np.int64(153), np.int64(141))
# selected elements: 514722
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 25.52it/s]
# cluster 0: amp=157.667, λ=113.14 km, θ=45.00 deg, ref_phase(phi0)=-0.200 rad
# cluster 1: amp=54.817, λ=16.82 km, θ=30.00 deg, ref_phase(phi0)=1.614 rad
